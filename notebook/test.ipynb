# %%
import sys

from blended_learning.nlp.translate_kh_service import TranslateKHService

if hasattr(sys.stdout, "reconfigure"):
    sys.stdout.reconfigure(encoding="utf-8")

translator = TranslateKHService()

texts = [
    "Good morning!",
    "Welcome to Cambodia.",
]

results = translator.translate_texts(
    texts=texts,
    src_lang="eng",
    tgt_lang="kh",
)

for original, translated in zip(texts, results):
    print(f"{original} => {translated}")
# Out:
# Good morning! => អរុណសួស្តី!
# Welcome to Cambodia. => សូមស្វាគមន៍មកកាន់ប្រទេសកម្ពុជា។
