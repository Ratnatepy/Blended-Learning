# %% [markdown]
# # Student Recommendation Reports
#
# This notebook was generated from:
#
# `C:\Users\Tepy\Documents\tepy\Final Internship Docs\blended_learning\data\processed\student_recommendation_reports.csv`
#
# **Total student records:** 420
#
# Each section below contains:
#
# - Student ID
# - Student segment label
# - Final recommendation tags
# - LLM-generated recommendation report

# %% [markdown]
# ## Student ID: `e20210528`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210528
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# Because the open‑ended responses about strengths and challenges are empty, the recommendations below are drawn primarily from the characteristics of the “Highly Engaged (Active) Learners” segment and the rule‑based tags assigned to this student.
#
# ---
#
# ### Main Strengths
# *No specific strengths were reported, but as a Highly Engaged learner you are typically motivated, participative, and comfortable with active learning formats.*
#
# ---
#
# ### Main Challenges
# *No specific challenges were reported. The segment profile suggests you may benefit from structured support that matches your active learning style.*
#
# ---
#
# ### Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Content Access** | Upload or request early access to slides, videos, reference links, exercises, and any other course materials. | Having the materials ahead of time lets you prepare, review, and stay ahead of class activities. |
# | **Digital Skills** | Take short tutorials on the LMS, online research tools, and any educational technologies used in the course. | Strong digital skills let you navigate resources quickly and make the most of online learning tools. |
# | **Engagement** | Participate in quizzes, games, practical tasks, discussion boards, and other interactive activities. | Interactive elements keep your high energy focused and deepen understanding. |
# | **Self‑Paced Learning** | Use recorded lessons and weekly learning paths; review materials at your own speed when needed. | Even active learners benefit from the flexibility to revisit complex topics or accelerate through familiar ones. |
#
# ---
#
# ### Short Action Plan (Next 2 Weeks)
#
# 1. **Day 1‑2:** Check the course portal for any missing slides or videos; request early uploads from the instructor if needed.
# 2. **Day 3‑5:** Complete a 30‑minute tutorial on the LMS’s key features (e.g., submitting assignments, using discussion forums).
# 3. **Day 6‑9:** Join at least one online quiz or game related to the current module; post a comment or question in the discussion board.
# 4. **Day 10‑12:** Review the recorded lecture for the upcoming topic and create a personal “weekly learning path” checklist.
# 5. **Day 13‑14:** Reflect on which resources helped you most and note any gaps to discuss with the instructor next week.
#
# By following these steps, you’ll reinforce the strengths of an active learner while ensuring you have the resources, skills, and flexibility needed for success in a blended learning environment.

# %% [markdown]
# ## Student ID: `e20210686`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210686
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# Your open‑ended responses did not highlight specific strengths or challenges, so the recommendations below are drawn primarily from the characteristics of your segment.
#
# ---
#
# ### Main Strengths
# *No specific strengths were reported.*
# (Recommendations are based on typical strengths of moderately engaged learners, such as the ability to work independently when given clear guidance.)
#
# ### Main Challenges
# *No specific challenges were reported.*
# (The suggestions address common hurdles for passive learners, like limited interaction and motivation.)
#
# ---
#
# ### Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join short Q&A sessions after lectures.<br>• Take part in small‑group discussions or peer‑collaboration activities.<br>• Request quicker feedback from the lecturer. | Increases engagement and helps you clarify doubts early. |
# | **Learning Support** | • Look for clear, step‑by‑step guides and example problems.<br>• Use recorded explanations that break down complex topics.<br>• Keep a list of instructions for each assignment. | Improves understanding and reduces confusion when studying independently. |
# | **Motivation & Self‑Discipline** | • Set a weekly check‑in (e.g., a 5‑minute self‑review) to track progress.<br>• Use reminders or a digital planner to schedule study blocks.<br>• Monitor your own progress with a simple checklist. | Keeps you on track and builds a habit of regular study. |
# | **Self‑Paced Learning** | • Watch recorded lessons before class and revisit them as needed.<br>• Follow the weekly learning path provided by the course.<br>• Review supplemental materials at your own speed. | Allows you to learn when you’re most focused and to revisit difficult concepts. |
#
# ---
#
# ### Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1 | **Join a Q&A** – Sign up for the upcoming live Q&A session (30 min). | Add the session to your calendar and prepare 1‑2 questions. |
# | 1 | **Create a Study Checklist** – List the topics for the week and tick them off daily. | Use a note‑taking app or paper planner. |
# | 2 | **Use Recorded Lessons** – Watch the week’s lecture recordings before the live class. | Allocate 45 min each evening; pause and take notes. |
# | 2 | **Peer Collaboration** – Pair with a classmate for a 20‑minute discussion on the assignment. | Reach out via the course forum or messaging app. |
#
# Stick to these steps, and you’ll gradually build stronger interaction, clearer understanding, and steadier motivation—all key for a moderately engaged learner. Good luck!

# %% [markdown]
# ## Student ID: `e20241146`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241146*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You show a very positive attitude toward learning, describing your strengths as “very good excellent” and reporting no major challenges.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You already feel that your current approach works well and you are comfortable with the tools you use.
#
# ### 3. Main Challenges
# - No specific challenges were identified in your responses.
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness** – Even highly engaged students can benefit from a balanced mix of online and face‑to‑face activities.
# - **Combine** the online review materials you already use with **in‑person explanations, guided practice, and timely feedback**. This blend helps solidify concepts, catches misunderstandings early, and keeps your high engagement level productive.
#
# ### 5. Short Action Plan
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1‑2 | Identify key topics you’ll review online. | Use your preferred digital resources (e.g., lecture videos, PDFs). |
# | 3‑4 | Schedule short in‑person sessions (or live virtual meetings) for each topic. | Meet with a tutor, study group, or instructor for a 15‑30 min explanation and practice. |
# | 5‑6 | Get feedback on practice tasks. | Submit a quick quiz or ask for verbal feedback during the session. |
# | Ongoing | Reflect on what helped you learn best and adjust the mix. | Note which topics needed more face‑to‑face help and plan accordingly. |
#
# By pairing your strong online study habits with targeted in‑person support, you’ll maintain your high engagement while boosting overall learning effectiveness. Keep leveraging the convenience you value, and add brief, interactive sessions for deeper mastery.

# %% [markdown]
# ## Student ID: `e20240609`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240609
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - Shows a strong willingness to try hard in your studies.
#
# **Main Challenges**
# - Finds it difficult to maintain self‑discipline and consistent motivation.
#
# **Personalized Recommendations**
# Because your primary challenge is motivation and self‑discipline, the following evidence‑based strategy is recommended:
#
# - **Support motivation and self‑discipline** – Use weekly check‑ins, set up reminders, track your progress, and follow a structured study schedule.
#
# These tactics align with the “motivation” tag identified for you and are especially useful for highly engaged learners who need a bit more structure to stay on track.
#
# **Short Action Plan**
#
# | Week | Action | Tool/Method |
# |------|--------|-------------|
# | 1 | Create a simple study timetable (e.g., 2‑hour blocks) | Google Calendar or a printable planner |
# | 1‑4 | Set a brief weekly check‑in (self‑review or with a peer/mentor) | Checklist or a short journal entry |
# | Ongoing | Enable daily reminders for study blocks and deadlines | Phone app notifications |
# | Ongoing | Record completed tasks and reflect on progress | Progress‑tracking sheet or habit‑tracker app |
# | End of each week | Review what worked, adjust the schedule if needed | 5‑minute reflection note |
#
# Stick to the schedule, use the reminders, and regularly review your progress. This structured approach will help turn your strong effort into consistent, self‑disciplined study habits.

# %% [markdown]
# ## Student ID: `e20240542`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240542
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You value **learning convenience and effectiveness** and are looking to gain more experience with your studies.
#
# **Main Challenges**
# - You find it difficult to keep **daily discipline and self‑motivation** for studying.
#
# **Personalized Recommendations**
#
# | Focus | Recommendation (based on rule‑based guidance) |
# |-------|-----------------------------------------------|
# | **Learning Effectiveness** | Combine the online review materials you already use with short, in‑person sessions where a tutor or peer can explain concepts, give you practice tasks, and provide immediate feedback. This blend helps turn convenient study time into deeper understanding. |
# | **Motivation & Self‑Discipline** | Set up a weekly check‑in routine (e.g., a brief meeting with a study buddy, mentor, or through a campus app). Use reminders and a simple progress‑tracking sheet to mark what you’ve completed each day. Build a structured study schedule that blocks specific times for review, practice, and reflection. |
#
# **Short Action Plan (2‑Week Starter)**
#
# 1. **Pick a core subject** you’re currently studying.
# 2. **Schedule 2 online review sessions** (30 min each) this week.
# 3. **Arrange 1 in‑person (or video‑call) session** with a tutor/peer to go over the same material, practice problems, and get feedback.
# 4. **Create a simple study log** (paper or app) to record daily study time and tasks.
# 5. **Set a weekly check‑in** (e.g., every Sunday evening) to review your log, adjust the schedule, and set goals for the next week.
#
# Following this plan will help you turn convenient online study into more effective learning while building the routine and accountability needed to stay motivated. Good luck!

# %% [markdown]
# ## Student ID: `e20220287`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220287*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from clear, readily‑available resources and opportunities to work at their own pace.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You are able to retrieve lesson content whenever you want to review it.
#
# ### 3. Main Challenges
# - You noted a desire for “add AI assistance,” but no specific challenge was identified in the evidence.
#
# ### 4. Personalized Recommendations
# | Tag | Recommendation |
# |-----|----------------|
# | **content_access** | **Strengthen access to learning materials** – Upload slides, videos, reference documents, exercises, and any other course materials **early** in the semester so you can review them whenever needed. |
#
# *Because the open‑ended responses were brief, this recommendation relies primarily on the characteristics of the “Moderately Engaged (Passive) Learners” segment.*
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | 1–2 | Check the course platform for any missing slides or videos. Request the instructor to upload any unavailable items. |
# | 3–4 | Create a personal folder (e.g., on cloud storage) where you collect all uploaded materials for quick reference. |
# | 5–6 | Review the compiled resources before each class to reinforce understanding. |
# | Ongoing | If AI tools become available (e.g., chat‑bots for quick answers), incorporate them to support your study sessions. |
#
# ---
#
# **Keep in mind:** Having all course materials organized and accessible early will let you study at your own pace and stay on track, even when you prefer a more passive learning style. If you later need additional support (such as AI‑based help), you can discuss it with your instructor or learning support team.

# %% [markdown]
# ## Student ID: `e20210180`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "learning_environment"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210180
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Shows a positive attitude toward “innovating yourself with the technology world.”
# - Identified strength theme: **Digital Skills Development** (sentiment = positive, compound ≈ 0.49).
#
# **Main Challenges**
# - Reports “lack of resources and misinformation,” indicating difficulty accessing reliable learning materials.
# - Identified challenge theme: **Learning Resources & Environment** (sentiment = negative, compound ≈ ‑0.56).
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to start |
# |----------------|----------------------|--------------|
# | **Develop digital learning skills** (digital_skill) | Gain confidence using the LMS, online research tools, and educational technologies so you can work more independently. | • Follow a short tutorial on your university’s LMS (e.g., how to locate course files, submit assignments, join discussion boards). <br>• Explore a curated list of free digital‑skill resources (e.g., tutorials on Google Scholar, citation managers, basic data‑visualisation tools). |
# | **Improve learning resources and environment** (learning_environment) | Make your study space and materials easier to use, reducing the impact of missing or confusing resources. | • Create a simple, organized folder structure for all course files (e.g., separate folders for lectures, readings, assignments). <br>• Check the university library’s digital collections for up‑to‑date texts and ask a librarian for reliable sources on topics you find confusing. <br>• Adjust your study area (lighting, seating, minimal distractions) to increase comfort and focus. |
#
# **Short Action Plan (2‑Week Sprint)**
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Watch the LMS “Getting Started” video provided by your department. |
# | **Day 3‑4** | Set up a personal folder system on your computer/cloud storage for the current course. |
# | **Day 5‑7** | Locate and bookmark at least two reputable online databases or library guides related to your subjects. |
# | **Day 8‑10** | Try one digital tool (e.g., citation manager or simple data‑visualisation app) on a small assignment task. |
# | **Day 11‑12** | Rearrange your study space: improve lighting, choose a comfortable chair, and remove non‑essential distractions. |
# | **Day 13‑14** | Reflect: note any improvements in ease of finding resources or confidence using digital tools; adjust the plan as needed. |
#
# These steps align with your segment’s typical needs and the specific strengths and challenges you reported. By building digital competence and creating a clearer, more supportive learning environment, you’ll be better positioned to engage actively with your coursework. Good luck!

# %% [markdown]
# ## Student ID: `e20241245`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241245
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate blended learning for its flexibility, the ability to review material anytime, and the way it combines the best of face‑to‑face and online instruction. Your comments highlight strong points such as easy access to learning materials, development of digital skills, and overall learning convenience.
#
# **Main Challenges**
# You note three recurring difficulties:
# 1. **Technical & Internet issues** – unstable connections and platform problems.
# 2. **Interaction & Communication** – limited direct contact with lecturers and peers.
# 3. **Staying focused & self‑discipline** – keeping motivation high during online sessions.
#
# **Personalized Recommendations**
#
# | Area | What to do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Lecturers should upload slides, videos, references, exercises, and any other course material **early** so you can plan ahead and review whenever needed. |
# | **Digital Skills** | Take short tutorials on the LMS, online research tools, and any educational apps your program uses. This will make navigating the platform smoother. |
# | **Engagement** | Participate in quizzes, quick games, practical tasks, and discussion boards that are built into the course. These activities help keep attention and make learning more active. |
# | **Interaction** | Join scheduled Q&A sessions, group discussions, and peer‑collaboration tasks. Ask for faster feedback from lecturers when you need clarification. |
# | **Learning Effectiveness** | Combine the online review resources (recorded lectures, slides) with the in‑person class where you can ask questions and practice skills with immediate feedback. |
# | **Learning Environment** | Use organized folders for course files, keep your study space tidy, and take advantage of any campus study rooms that offer reliable Wi‑Fi and comfortable seating. |
# | **Learning Support** | Look for clear step‑by‑step guides, example problems, and recorded explanations that lecturers provide. If instructions are vague, request additional examples. |
# | **Motivation & Self‑Discipline** | Set a weekly study schedule, use a progress‑tracking app, and treat yourself to brief check‑ins (e.g., a 5‑minute reflection) to stay on track. |
# | **Self‑Paced Learning** | Make use of recorded lessons and weekly learning paths so you can study at a pace that fits your other commitments. |
# | **Technical Issues** | If internet is unreliable, download offline copies of lectures and materials in advance. Keep the university’s technical support contact handy for quick help. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–2:** Create a dedicated folder for each course and download all available slides/videos.
# 2. **Day 3:** Watch a 10‑minute tutorial on your LMS’s key features (uploading files, discussion boards, quiz access).
# 3. **Day 4–5:** Set a simple weekly schedule (e.g., Monday 9‑11 am: review recorded lecture; Wednesday 2‑4 pm: group discussion). Add reminders to your phone.
# 4. **Day 6:** Join a scheduled Q&A or discussion session; prepare one question in advance.
# 5. **Day 7:** Complete a short quiz or interactive activity for one module and note any concepts that need clarification.
# 6. **Day 8–10:** If you experience internet problems, download offline copies of the next week’s materials and note the issue for the tech support team.
# 7. **Day 11:** Review your progress (what you’ve completed, what still needs work) and adjust the schedule if needed.
# 8. **Day 12–14:** Share a brief summary of what you learned with a peer or post it in the course forum to reinforce understanding and increase interaction.
#
# Follow these steps, and you’ll strengthen access to materials, improve digital confidence, stay motivated, and make the most of both online and face‑to‑face components of your blended courses. Good luck!

# %% [markdown]
# ## Student ID: `e20221090`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221090*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can choose how and when to study, mixing online and face‑to‑face activities at your own pace.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value the ability to learn both online and in‑class, arranging study time that fits your schedule.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You experience limited opportunities for live discussion and feedback.
# - **Internet & Technical Issues** – Unstable connections and platform problems hinder your learning.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | How It Helps |
# |------|------------|--------------|
# | **Interaction** | Add regular Q&A sessions, small‑group discussions, and peer‑collaboration tasks. Request quicker feedback from lecturers. | Increases real‑time communication, deepens understanding, and keeps you actively involved. |
# | **Self‑Paced Learning** | Use recorded lectures, weekly learning paths, and downloadable resources that you can revisit anytime. | Lets you study when you’re most focused and review material without pressure. |
# | **Technical Access** | Ensure you have a reliable internet connection (e.g., campus Wi‑Fi or a data plan). Download offline copies of key materials and keep a quick‑reference guide for the learning platform. Contact the tech‑support desk early if problems arise. | Reduces disruptions, so you can stay on track with your self‑paced schedule. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify any upcoming Q&A or discussion sessions in your courses and add them to your calendar. |
# | **Day 3** | Download the week’s recorded lectures and any supplemental PDFs for offline study. |
# | **Day 4** | Test your internet speed; if unstable, arrange campus Wi‑Fi access or a backup data plan. |
# | **Day 5** | Review the platform’s quick‑start guide; bookmark the tech‑support contact. |
# | **Day 6–7** | Form a small study group (2‑3 peers) to discuss key concepts and share notes. |
# | **Week 2** | Request feedback on one assignment within 48 hours; note any delays and follow up with the lecturer or support staff. |
#
# By focusing on richer interaction, leveraging self‑paced resources, and securing reliable technical access, you can make the most of your highly engaged learning style while overcoming the current challenges. Keep tracking what works and adjust the plan as needed—your active involvement is the key to success!

# %% [markdown]
# ## Student ID: `e20240956`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240956*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What this means:** You tend to follow the material but may not actively seek interaction or extra support. Your open‑ended responses did not provide additional details, so the recommendations below are based primarily on the typical characteristics of this segment.
#
# ---
#
# ### 2. Main Strengths
# - (No specific strengths were reported.)
# - Your current level of engagement suggests you are able to keep up with course content when it is clearly presented.
#
# ---
#
# ### 3. Main Challenges
# - (No specific challenges were reported.)
# - As a moderately engaged learner, you may benefit from more opportunities to interact, receive clear guidance, stay motivated, and control the pace of your study.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | Why it Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions or virtual office hours.<br>• Participate in small‑group discussions or peer‑collaboration activities.<br>• Request quicker feedback on assignments. | Increases engagement and helps you clarify doubts early. |
# | **Learning Support** | • Look for detailed instructions, examples, and step‑by‑step guides provided by the instructor.<br>• Use recorded explanations that break down complex topics. | Improves understanding and reduces uncertainty when studying independently. |
# | **Motivation & Self‑Discipline** | • Set a weekly check‑in with yourself (or a study buddy) to review progress.<br>• Use reminders or a simple planner to schedule study blocks.<br>• Track completed tasks in a checklist or digital tracker. | Keeps you on track and builds a habit of regular study. |
# | **Self‑Paced Learning** | • Access recorded lectures and supplemental videos at any time.<br>• Follow the weekly learning path outlines provided in the course portal.<br>• Review materials as needed before moving on. | Lets you study when you’re most focused and revisit content for better retention. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | **1** | **Join an interaction opportunity** – sign up for the next live Q&A or discussion forum. | Check the course calendar; add the session to your calendar. |
# |      | **Set up a simple study schedule** – block 2‑3 hours per week for the course. | Use a phone reminder or a free planner app. |
# |      | **Locate learning supports** – download any provided step‑by‑step guides and watch the first recorded lecture. | Look in the “Resources” section of the LMS. |
# | **2** | **Track progress** – mark each completed reading or video in a checklist. | Create a checklist in Google Docs or a paper notebook. |
# |      | **Try peer collaboration** – pair with a classmate for a 30‑minute study chat. | Post in the course forum asking for a study buddy. |
# |      | **Review and adjust** – at the end of the week, note what helped you stay motivated and plan any tweaks for the next week. | Write a brief reflection (2‑3 sentences). |
#
# ---
#
# **Remember:** Small, consistent steps—like attending one discussion, using a checklist, and reviewing a recorded lesson—can quickly boost your engagement and confidence. Feel free to reach out to your lecturer or teaching assistants if you need additional support. Good luck!

# %% [markdown]
# ## Student ID: `e20250089`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250089*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from clear structure, self‑paced options, and reliable technical support.
#
# ### 2. Main Strengths
# - You value having enough time to work on tasks at your own pace.
#
# ### 3. Main Challenges
# - Unstable or limited internet connectivity can interrupt your study sessions.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve technical access and reliability** (tech_issue) | Ensure you can study without frequent connection drops. | • Use campus Wi‑Fi hotspots or a reliable mobile data plan.<br>• Download lecture videos and readings in advance for offline use.<br>• Follow the short “How to use the learning platform” guide provided by the university.<br>• Contact the IT help desk early if you experience issues, so they can resolve them quickly. |
#
# *Because your open‑ended responses were brief, this recommendation is primarily based on the characteristics of your learner segment and the identified technical challenge.*
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate a reliable internet source (campus library, coffee shop, or mobile hotspot). |
# | **2** | Download all required course materials for the next two weeks and store them on your device. |
# | **3** | Review the platform instruction sheet and note any steps you find unclear; ask the support team for clarification. |
# | **4** | Test the offline materials by completing a short assignment without internet. If you encounter problems, contact technical support immediately. |
#
# By securing stable connectivity and preparing offline resources, you’ll be able to study at the pace that works best for you and stay on track with your courses. If you need further assistance, the university’s learning support and IT services are ready to help.

# %% [markdown]
# ## Student ID: `e20240950`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240950*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - Your open‑ended responses indicated agreement with both strengths and challenges, but did not provide specific details. Therefore, the recommendations below are drawn primarily from the characteristics of your segment.
#
# ### 2. Main Strengths
# - High level of engagement and motivation typical of active learners.
#
# ### 3. Main Challenges
# - No specific challenges were mentioned; the suggestions focus on supporting the ways you already learn best.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Having all slides, videos, readings, and exercises available early lets you dive in whenever you’re ready. | Upload or request early access to course content; keep a personal folder organized by week. |
# | **Develop digital learning skills** | Mastering the LMS, online libraries, and research tools helps you work efficiently. | Attend a short tutorial on the LMS, explore digital citation tools, and practice using any new educational apps the course offers. |
# | **Increase learner engagement** | Interactive quizzes, games, and discussion tasks keep your active style energized. | Participate in live polls, join discussion boards, and try out any gamified activities the instructor provides. |
# | **Support self‑paced learning** | Recorded lessons and clear weekly pathways let you review material on your own schedule. | Watch recorded lectures before class, follow the weekly learning path, and revisit difficult concepts at your own pace. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the course’s shared folder or LMS page; download all available slides and videos. |
# | **2** | Complete a quick LMS tutorial (often 10‑15 min) and bookmark useful digital research tools. |
# | **3** | Join the first discussion forum; answer the introductory quiz to gauge your baseline. |
# | **4** | Set a personal weekly schedule: watch the recorded lecture, then complete the associated practice tasks. |
# | **5‑8** | Continue the cycle: review materials early, use digital tools for note‑taking, engage in interactive activities, and adjust the pace as needed. |
#
# ---
#
# By following these steps, you’ll capitalize on your natural enthusiasm while ensuring you have the resources, digital skills, and flexibility needed for successful blended learning. Keep tracking what works best for you and adjust the plan as you progress. Good luck!

# %% [markdown]
# ## Student ID: `e20240099`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_effectiveness", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240099*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You appreciate blended learning for its **flexibility**, the chance to **study at your own pace**, and the way it helps you build **digital skills** and understand material better. At the same time, you find it challenging to stay **motivated**, manage your **time**, and deal with occasional **internet or technical problems** that can interrupt your study flow.
#
# ---
#
# ### 2. Main Strengths
# | Strength Theme | What you mentioned |
# |----------------|-------------------|
# | Access to learning materials | You like having slides, videos, and other resources available online. |
# | Digital skills development | You see blended learning as a way to improve your technology abilities. |
# | Flexibility & convenience | Studying online at your own pace makes learning more interesting for you. |
# | Engagement | The mix of online and face‑to‑face helps you stay engaged with the content. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge Theme | What you mentioned |
# |-----------------|-------------------|
# | Motivation & self‑discipline | Staying motivated and avoiding procrastination can be hard. |
# | Time management | Balancing online study with other tasks is difficult. |
# | Internet & technical issues | Unreliable connections or platform glitches sometimes stop you from following lessons. |
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation is linked to a specific tag from the rule‑based list.)
#
# | Tag | Recommendation |
# |-----|----------------|
# | **content_access** | **Upload slides, videos, references, exercises, and course materials early** so you can review them whenever you need. |
# | **digital_skill** | **Get short guides or short videos on how to use the LMS, online research tools, and other educational technologies** to boost your confidence with digital tasks. |
# | **engagement** | **Participate in quizzes, games, practical tasks, and discussion forums** that make the material interactive and keep you involved. |
# | **learning_effectiveness** | **Combine the online review materials with in‑person explanations, practice activities, and feedback** to reinforce what you learn. |
# | **learning_support** | **Look for clearer instructions, step‑by‑step guides, and recorded explanations** that you can replay if a concept isn’t clear. |
# | **motivation** | **Set up weekly check‑ins or reminders, track your progress, and follow a structured study schedule** to maintain momentum. |
# | **self_paced** | **Use recorded lessons and weekly learning paths** that let you study when it suits you best. |
# | **tech_issue** | **Make use of offline copies of materials, ask for stable internet options on campus, and contact technical support quickly when problems arise**. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How it helps |
# |------|--------|--------------|
# | **1** | Download all lecture slides and videos for the upcoming module (content_access). | Guarantees you have the material even if the connection drops. |
# |      | Watch a 10‑minute tutorial on the LMS’s key features (digital_skill). | Builds confidence using the platform. |
# |      | Create a simple study schedule with 2‑hour blocks for online work and 1‑hour blocks for in‑person review (motivation, self_paced). | Improves time management and reduces procrastination. |
# | **2** | Complete one interactive quiz or game related to the week’s topic (engagement). | Keeps you actively involved with the content. |
# |      | Post a question or comment in the discussion forum and reply to a peer (learning_support, engagement). | Enhances clarity and peer interaction. |
# |      | Test the offline version of the materials and note any technical issues; contact support if needed (tech_issue). | Ensures you can continue learning without interruptions. |
#
# Follow this plan, adjust the schedule as needed, and reach out to your instructor or tech support whenever a barrier appears. With these steps, you’ll strengthen your access to resources, stay motivated, and make the most of blended learning’s flexibility. Good luck!

# %% [markdown]
# ## Student ID: `e20241378`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241378*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility, deeper understanding, and the development of digital skills. You appreciate being able to review material online at your own pace and enjoy active, discussion‑based activities. At the same time, you notice that occasional internet problems, limited online interaction, and time‑management challenges can reduce the effectiveness of blended learning for you.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Self‑Paced Learning** – You make good use of the ability to study both in‑class and online.
# - **Learning Effectiveness** – Combining face‑to‑face explanations with videos, quizzes and other online resources helps you understand difficult topics.
# - **Digital Skills Development** – You are motivated to improve your use of LMS tools, online research, and other educational technologies.
# - **Engagement** – You enjoy active learning through discussions, group work and interactive online activities.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable connections can interrupt access to online classes and materials.
# - **Interaction & Communication** – Online sessions sometimes feel less interactive, making it harder to ask questions or collaborate.
# - **Time‑Management & Motivation** – Balancing self‑discipline with multiple deadlines can be difficult.
# - **Workload Clarity** – Managing the mix of online and in‑person assignments can feel overwhelming.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Lecturers will upload slides, videos, references, exercises and other course materials **early** so you can review them whenever you need. |
# | **Digital Skills** | Short guides and workshops will be provided on how to use the LMS, locate reliable online resources, and apply educational technologies effectively. |
# | **Engagement** | Courses will include quizzes, games, practical tasks and discussion prompts to keep you actively involved. |
# | **Interaction** | Scheduled Q&A sessions, peer‑group discussions and faster lecturer feedback will increase communication opportunities. |
# | **Learning Effectiveness** | You will receive a blend of in‑person explanations plus online review materials, practice activities and timely feedback to reinforce understanding. |
# | **Learning Environment** | Materials will be clearly organized; study spaces (both physical and virtual) will be improved for comfort and ease of use. |
# | **Learning Support** | Clear step‑by‑step instructions, examples and recorded explanations will be available to clarify complex topics. |
# | **Motivation & Self‑Discipline** | Weekly check‑ins, automated reminders and a progress‑tracking dashboard will help you stay on schedule. |
# | **Self‑Paced Learning** | Recorded lessons and a weekly learning path will let you study at a pace that fits your schedule. |
# | **Technical Issues** | The university will enhance campus Wi‑Fi, offer offline copies of key resources and provide a dedicated tech‑support help‑desk. |
# | **Workload Support** | Assignments will be balanced, deadlines clearly communicated, and online tasks aligned with in‑person sessions to reduce overload. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | How It Helps |
# |------|--------|--------------|
# | **1** | Review the **early‑uploaded course folder** and note any missing materials. | Guarantees you have everything you need for self‑paced study. |
# | **2** | Attend the **first Q&A session** and try a peer‑group discussion. | Boosts interaction and clarifies doubts early. |
# | **3** | Use the **progress‑tracking dashboard** to set personal milestones for the week’s assignments. | Supports motivation and time‑management. |
# | **4** | Test the **offline material download** option and report any connectivity issues to tech support. | Reduces disruption from internet problems. |
#
# Follow these steps, and keep using the university’s new resources (guides, quizzes, discussion boards, and tech support). They are designed to build on your strengths while addressing the challenges you identified, helping you get the most out of a blended learning experience.

# %% [markdown]
# ## Student ID: `e20210635`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210635*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and actively participate in learning activities.
#
# ### 2. Main Strengths
# - You appreciate tools that help you **track your study progress**.
#
# ### 3. Main Challenges
# - You find it **hard to convince others to use the platform** (e.g., classmates or peers).
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps you |
# |-------|------------|------------------|
# | **Content Access** | Upload slides, videos, reference links, exercises, and other course materials **early** in the LMS. | Gives you and your peers quick, reliable resources to follow and review, supporting your tracking habit. |
# | **Digital Skills** | Offer short guides or workshops on using LMS tools, finding online resources, and basic educational technologies. | Strengthens your ability to demonstrate the platform’s benefits to others and boosts confidence in digital work. |
# | **Engagement** | Include interactive elements such as quizzes, quick games, practical tasks, and discussion prompts. | Keeps the learning experience lively for you and makes it easier to showcase the platform’s value to peers. |
# | **Self‑Paced Learning** | Provide recorded lectures and a weekly learning path that students can revisit at any time. | Lets you review material whenever needed, reinforcing your tracking habit and giving you material to share with others. |
#
# *These recommendations are based primarily on the characteristics of the “Highly Engaged (Active) Learners” segment, complemented by your expressed strength and challenge.*
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Upload all core course materials (slides, videos, readings) to the LMS before the first class. |
# | **2** | Create a 5‑minute tutorial on key LMS features and share it with the class. |
# | **3** | Add a short quiz or poll at the end of each lesson to boost interaction. |
# | **4** | Publish a weekly “learning path” video that summarizes the week’s content and suggests optional review activities. |
# | **Ongoing** | Track your study progress using the platform’s tools and gather feedback from peers on what helps them engage. |
#
# By following these steps, you’ll reinforce your own learning, make the platform more attractive to others, and continue to thrive as a highly engaged learner. Good luck!

# %% [markdown]
# ## Student ID: `e20240052`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240052
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Finds learning “easy” and values convenience and effectiveness in study materials.
#
# **Main Challenges**
# - Experiences difficulties with internet connectivity and limited time for study.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** (learning_effectiveness) | Pair the online review resources you already find easy to use with short, in‑person sessions where a tutor or classmate can explain concepts, give you practice tasks, and provide feedback. | • Schedule brief (30‑45 min) face‑to‑face or live‑online study blocks each week.<br>• Use the online materials as pre‑reading, then discuss key points during the live session.<br>• Ask for quick feedback on any practice questions you complete. |
# | **Improve technical access and reliability** (tech_issue) | Ensure you can study even when internet is unstable and reduce the time needed to troubleshoot technical problems. | • Download lecture slides, readings, and practice quizzes to your device for offline use.<br>• Keep a list of campus or library locations with reliable Wi‑Fi for when you need to go online.<br>• Follow the platform’s short “how‑to” guide and note the contact details for technical support so you can get help quickly. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Download offline copies** of all upcoming online materials (slides, readings, quizzes).
# 2. **Identify a reliable Wi‑Fi spot** (e.g., campus library) and plan at least two study sessions there.
# 3. **Book one 45‑minute in‑person or live‑online review meeting** with a tutor or study group to go over the downloaded material.
# 4. **Create a quick checklist** of platform login steps and the tech‑support email/phone number for fast assistance.
#
# By combining the convenience of your online resources with targeted face‑to‑face practice and securing reliable access, you’ll boost both the effectiveness of your learning and reduce the impact of technical hurdles. Good luck!

# %% [markdown]
# ## Student ID: `e20240937`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240937
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You indicated a strength in **math**.
#
# **Main Challenges**
# - You also noted a challenge in **math**. (Because the open‑ended comments are brief, the rest of the analysis relies on the typical profile of your segment.)
#
# **Personalized Recommendations**
#
# | Focus | What the recommendation means for you | Suggested actions |
# |-------|----------------------------------------|-------------------|
# | **Interaction** | Increase opportunities to talk with peers and the instructor. | Join scheduled Q&A sessions, take part in small‑group discussions, collaborate on short problems with classmates, and look for quick feedback from the lecturer. |
# | **Learning Support** | Make the material clearer and easier to follow. | Use provided step‑by‑step guides, watch recorded explanations with examples, and refer to any detailed instructions the course offers. |
# | **Motivation** | Build habits that keep you on track. | Set a weekly check‑in (e.g., a brief self‑review on Friday), enable reminder notifications, track your progress in a simple spreadsheet or app, and follow a structured study schedule. |
# | **Self‑Paced Learning** | Take advantage of flexible study options. | Review recorded lessons before or after class, follow the weekly learning path outlined by the instructor, and revisit any material that feels unclear at your own speed. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Schedule Interaction** – Add one Q&A session and one peer‑discussion slot to your calendar.
# 2. **Use Support Materials** – Download the step‑by‑step guide for the upcoming math topic and watch the related recorded explanation.
# 3. **Set a Motivation Cue** – Create a Friday‑afternoon reminder to check your progress and adjust your study plan if needed.
# 4. **Plan Self‑Paced Time** – Block 30 minutes each day for reviewing recorded lessons and notes at your own pace.
#
# By following these focused steps, you’ll strengthen your engagement, get clearer guidance, stay motivated, and make the most of self‑paced resources—helping you turn your math strength into consistent success.

# %% [markdown]
# ## Student ID: `e20250073`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20250073
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# You recognize that blended learning gives you flexibility, quick access to materials, and helps you build digital skills. These advantages match the “Access to Learning Materials,” “Digital Skills Development,” and “Flexibility & Time Management” themes you highlighted.
#
# **Main Challenges**
# You noted several areas that can hinder your learning:
# - Unstable internet and other technical problems
# - Difficulty staying focused during online sessions
# - Occasionally unclear instructions for online tasks
#
# These concerns align with the “Internet & Technical Issues,” “Learning Difficulty & Clarity,” and “Motivation & Self‑Discipline” themes you mentioned.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps you |
# |------|------------|------------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** in the LMS. | Guarantees you can review content whenever your internet is unreliable or you need extra time. |
# | **Digital Skills** | Offer short guides or workshops on using the LMS, digital research tools, and other educational technologies. | Strengthens the digital competencies you already value and reduces friction when navigating online tasks. |
# | **Interaction** | Add regular Q&A sessions, small‑group discussions, and quicker lecturer feedback. | Increases engagement and helps you stay focused during online classes. |
# | **Learning Environment** | Organise all resources clearly, keep them up‑to‑date, and improve both virtual and physical study spaces. | Makes it easier to find what you need and creates a more comfortable setting for self‑directed work. |
# | **Learning Support** | Provide clearer, step‑by‑step instructions, example problems, and recorded explanations for online assignments. | Reduces confusion and supports the clarity you are looking for. |
# | **Motivation & Self‑Discipline** | Use weekly check‑ins, reminders, progress‑tracking dashboards, and a structured study schedule. | Helps maintain focus and momentum throughout the blended course. |
# | **Self‑Paced Learning** | Make recorded lessons and weekly learning paths available for you to review at any time. | Lets you manage your time flexibly while still covering all required material. |
# | **Technical Issues** | Ensure stable campus Wi‑Fi, provide offline copies of key resources, and offer a dedicated tech‑support helpdesk. | Minimises disruptions caused by internet instability. |
# | **Workload Support** | Balance the number of assignments, clarify all deadlines, and align online tasks with in‑person sessions. | Reduces assessment pressure and makes planning easier. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# | Week | Action | Who’s Involved |
# |------|--------|----------------|
# | 1 | Check that all course slides and videos are uploaded at least 48 hours before each class. | Lecturer / Course coordinator |
# | 2 | Attend a 30‑minute LMS tutorial focused on digital research tools. | Library staff / IT support |
# | 3 | Participate in a scheduled Q&A session and give feedback on clarity of instructions. | Lecturer & peers |
# | 4 | Review the weekly progress dashboard and set personal study milestones; report any technical issues to the support desk. | You & tech support |
#
# By following these steps, you can keep leveraging your high engagement while smoothing out the technical and clarity challenges you experience in blended learning. Good luck!

# %% [markdown]
# ## Student ID: `e20240164`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240164*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key strengths mentioned:** Ability to learn anything from anywhere (Flexibility & Time Management).
# - **Main challenges mentioned:** Difficulty understanding material and hesitancy to ask questions (Interaction & Communication; Learning Difficulty & Clarity).
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You are comfortable learning in different places and can adapt your schedule to study whenever it suits you.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You find it hard to ask questions and engage directly with instructors or peers.
# - **Learning Difficulty & Clarity** – The material sometimes feels unclear, making it tough to grasp concepts quickly.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Increase interaction and communication** | Add more opportunities to ask questions and work with classmates. | Join scheduled Q&A sessions, participate in group discussions, and use peer‑collaboration tools. Look for faster feedback from lecturers (e.g., short response windows in discussion forums). |
# | **Improve clarity and learning support** | Get clearer explanations and step‑by‑step guidance. | Use recorded explanations and example walkthroughs provided by the course. Follow any step‑by‑step learning guides or checklists that accompany assignments. |
# | **Support self‑paced learning** | Keep using your flexibility while having structured resources to review. | Access recorded lessons at any time, follow the weekly learning path outlines, and revisit materials as needed to reinforce understanding. |
#
# These three recommendations (interaction, learning support, self‑paced) are drawn directly from the rule‑based suggestions for your segment.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|-------------------|
# | 1 | Attend at least one live Q&A or discussion session. | Practice asking questions in a low‑pressure setting. |
# | 1‑2 | Locate and watch the recorded explanations for the current module; take notes on each step. | Improves clarity of the material. |
# | 2 | Form or join a small study group (2‑4 peers) for weekly peer review of assignments. | Increases interaction and provides quick feedback. |
# | Ongoing | Follow the weekly learning path and use recorded lessons to review any concepts that felt unclear. | Reinforces self‑paced learning and solidifies understanding. |
#
# Stick to this plan, and you’ll turn your strong flexibility into even more effective learning while reducing the barriers you face with interaction and clarity. Good luck!

# %% [markdown]
# ## Student ID: `e20250120`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250120*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What we know:** The open‑ended responses did not provide specific strengths or challenges, so the recommendations below are based primarily on the typical characteristics of this segment.
#
# ---
#
# ### 2. Main Strengths
# - No explicit strengths were reported.
#
# ---
#
# ### 3. Main Challenges
# - No explicit challenges were reported.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What it means for you | Practical actions |
# |-------|----------------------|-------------------|
# | **Interaction** | Increase opportunities to talk, ask questions, and work with peers. | • Join scheduled Q&A or live‑chat sessions.<br>• Participate in small‑group discussion boards.<br>• Pair up with a classmate for brief peer‑review activities.<br>• Request quicker feedback on assignments from the lecturer. |
# | **Learning Support** | Make the material clearer and easier to follow. | • Look for recorded explanations and step‑by‑step guides that the instructor provides.<br>• Use any example problems or templates shared in the course.<br>• If instructions are unclear, ask for clarification in the forum or during office hours. |
# | **Motivation** | Build self‑discipline and keep track of progress. | • Set a weekly check‑in (e.g., a 5‑minute reflection on what you completed).<br>• Use the course’s progress tracker or a simple checklist.<br>• Enable reminder notifications for upcoming deadlines.<br>• Create a short, structured study schedule each week. |
# | **Self‑Paced Learning** | Take advantage of materials you can review on your own time. | • Watch recorded lectures before or after class sessions.<br>• Follow the weekly learning path provided by the instructor.<br>• Re‑watch any sections that feel difficult, and take brief notes for later review. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Goal | Action |
# |------|------|--------|
# | **Week 1** | Boost interaction | • Attend at least one live Q&A session.<br>• Post one question or comment in the discussion board. |
# | **Week 1** | Clarify learning material | • Download the step‑by‑step guide for the current module.<br>• Watch the recorded lecture and note any unclear points. |
# | **Week 2** | Strengthen motivation | • Set a 10‑minute weekly check‑in on Friday.<br>• Mark completed tasks in the course tracker. |
# | **Week 2** | Practice self‑paced study | • Follow the weekly learning path and review any recorded lessons you missed.<br>• Summarize key concepts in a personal “cheat sheet.” |
#
# ---
#
# **Remember:** Even though you didn’t list specific strengths or challenges, these actions are designed to match the typical needs of Moderately Engaged (Passive) learners. Try the steps above, observe what helps you stay on track, and adjust as needed. Good luck!

# %% [markdown]
# ## Student ID: `e20230101`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20230101
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# - **Strengths (as you described):** You value **flexibility in time and place**, which helps you fit study around other commitments.
# - **Challenges (as you described):** Maintaining **motivation and self‑discipline** can be difficult.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you are good at arranging your study schedule to suit your lifestyle.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – staying consistently motivated and managing study habits needs support.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Support motivation and self‑discipline** | Build regular habits that keep you on track. | • Join weekly check‑ins (e.g., a short online meeting or a quick self‑reflection form).<br>• Set up automated reminders for study sessions and deadlines.<br>• Use a simple progress‑tracking tool (checklist or digital tracker) to see your achievements.<br>• Follow a structured weekly study schedule that aligns with your flexible availability. |
# | **Support self‑paced learning** | Take advantage of materials you can access whenever you need them. | • Use recorded lectures and downloadable resources instead of only live sessions.<br>• Follow a weekly learning path that outlines what to cover each week, but allows you to move through the content at your own speed.<br>• Review and revisit any lesson as many times as necessary before moving on. |
#
# These recommendations are drawn directly from the evidence for your segment and the specific tags **motivation** and **self_paced**.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Set up a weekly reminder (e.g., calendar alert) for a 30‑minute study block. |
# | **Tuesday** | Watch the first recorded lesson for the upcoming topic; add a note of one thing you learned. |
# | **Wednesday** | Complete a quick self‑check‑in (5‑minute reflection) on motivation level and adjust the study block if needed. |
# | **Thursday** | Update your progress tracker with the lesson completed and any quiz scores. |
# | **Friday** | Review the week’s material; re‑watch any part that feels unclear. |
# | **Weekend** | Plan next week’s learning path and schedule flexible study times. |
#
# Repeat the cycle, adjusting the schedule and reminders as you discover what works best for you.
#
# ---
#
# **Remember:** Your flexibility is a strong asset—use it to create a study routine that keeps you motivated and lets you learn at your own pace. If you need additional support, reach out to your course facilitator or peer study group. Good luck!

# %% [markdown]
# ## Student ID: `e20240144`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240144
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You appreciate having easy access to learning data and materials, which supports convenient and effective study habits.
#
# **Main Challenges**
# - You indicated uncertainty about specific challenges. Because the open‑ended response was brief, the recommendations below rely primarily on the characteristics of the “Highly Engaged (Active) Learners” segment.
#
# **Personalized Recommendations**
#
# | Tag | Recommendation Title | What to Do |
# |-----|----------------------|------------|
# | **content_access** | Strengthen access to learning materials | Upload or make available slides, videos, reference documents, exercises, and any other course resources **early** in the semester so you can review them whenever needed. |
# | **learning_effectiveness** | Improve learning effectiveness | Pair the online review materials you already use with **in‑person explanations, guided practice, and timely feedback**. This blend helps you apply concepts more deeply and retain information longer. |
#
# **Short Action Plan**
#
# 1. **Week 1–2:** Collect all upcoming lecture slides, reading lists, and video links; store them in a single, well‑organized folder (e.g., a course LMS or cloud drive).
# 2. **Ongoing:** Before each class, skim the relevant materials to prime your understanding.
# 3. **After each class:**
#    - Review the same materials again, focusing on points the instructor emphasized.
#    - Complete any practice exercises or quizzes.
#    - Seek quick feedback (office hours, peer discussion, or automated quiz results) to clarify misunderstandings.
# 4. **Mid‑term check:** Evaluate whether early access and the combined online‑in‑person approach are helping you study more efficiently; adjust the timing of uploads or the amount of practice as needed.
#
# By ensuring prompt access to all course content and coupling it with active, face‑to‑face learning activities, you can maintain your high engagement while boosting overall learning effectiveness.

# %% [markdown]
# ## Student ID: `e20210243`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210243*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and take an active role in your studies. Your open‑ended response highlighted a need to “improve study space wifi projector,” indicating that the physical and technical learning environment is the main area you want to strengthen.
#
# ### 2. Main Strengths
# - Your engagement level is high (as reflected by the “Highly Engaged” segment).
# - No specific strengths were listed in the open response, so this report relies primarily on the strengths typical of your segment (e.g., strong participation and self‑direction).
#
# ### 3. Main Challenges
# - **Learning Resources & Environment:** Need for a better‑organized study space and improved classroom comfort.
# - **Internet & Technical Issues:** Unreliable Wi‑Fi and projector access.
# - **Assessment & Workload:** Desire for clearer workload management.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Learning Environment** | • Arrange your study materials so they are easy to locate.<br>• Keep your study area tidy and comfortable (good lighting, ergonomic chair).<br>• If possible, choose a quiet spot on campus with reliable power outlets. | A well‑organized space reduces distraction and lets you focus on the active learning you enjoy. |
# | **Technical Access** | • Test the campus Wi‑Fi and projector before each class; report any issues to IT early.<br>• Download lecture slides or videos in advance so you have offline copies.<br>• Keep a short “tech checklist” (charger, headphones, login info) ready for each session. | Stable internet and reliable equipment prevent interruptions, letting you stay engaged throughout blended activities. |
# | **Workload Support** | • Use a simple planner (digital or paper) to note assignment due dates and exam periods.<br>• Break larger tasks into smaller, time‑boxed steps and schedule them alongside in‑person sessions.<br>• If deadlines feel tight, contact the instructor early to discuss possible extensions or clarification. | Balancing assignments with class time reduces pressure and helps you maintain the high level of participation you prefer. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Choose a dedicated study spot on campus; clear the desk and set up a comfortable chair. |
# | **Day 2** | Create a quick tech checklist (Wi‑Fi login, charger, projector remote) and test the classroom Wi‑Fi. |
# | **Day 3** | Download this week’s lecture materials for offline use. |
# | **Day 4** | Write down all upcoming deadlines in a planner; break the nearest assignment into 3‑hour chunks. |
# | **Day 5‑7** | Follow the chunked schedule; after each study session, note what worked and adjust the environment if needed. |
# | **Day 8** | Meet with campus IT (or use the help desk) to resolve any lingering Wi‑Fi/projector issues. |
# | **Day 9‑14** | Review the planner weekly; adjust time blocks to keep a balanced workload and maintain active participation in both online and face‑to‑face sessions. |
#
# ---
#
# **Remember:** Your strong engagement is a valuable asset. By fine‑tuning your study environment, securing reliable technology, and organizing your workload, you’ll be able to make the most of the blended learning format and continue to excel. If you need further support, reach out to your academic advisor or the university’s learning‑technology help desk.

# %% [markdown]
# ## Student ID: `e20240101`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240101*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You already appreciate how blended learning gives you flexibility and helps you study more effectively.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You value the ability to balance study with other commitments.
# - **Learning Convenience & Effectiveness:** You see blended formats as a way to learn more efficiently.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You would like more engagement with peers and instructors.
# - **Motivation & Self‑Discipline:** Maintaining attendance and staying motivated can be difficult without stricter structures.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do (based on rule‑based advice) |
# |-------|------------------------------------------|
# | **Interaction** | Join scheduled Q&A sessions, take part in group discussions, and collaborate with classmates on short projects. Ask your lecturer for quicker feedback on assignments. |
# | **Learning Effectiveness** | Pair the online review materials you already use with in‑person explanations and practice activities. Seek brief feedback after each practice session. |
# | **Learning Support** | Look for clear written instructions, concrete examples, and recorded step‑by‑step explanations that you can revisit when a concept isn’t clear. |
# | **Motivation & Self‑Discipline** | Set a weekly check‑in with yourself (or a study buddy) to review progress. Use reminders and a simple study schedule that marks required attendance and study blocks. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths. Review any material you missed before the next live session. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Add the upcoming Q&A session to your calendar; prepare one question in advance. |
# | **Tue** | Watch the recorded lecture for this week and note any unclear points. |
# | **Wed** | Join a peer‑study group discussion (online or in‑person). |
# | **Thu** | Complete a short practice exercise and request feedback from the lecturer. |
# | **Fri** | Do a 10‑minute self‑check‑in: mark attendance, record what you learned, and set goals for next week. |
# | **Weekend** | Review recorded lessons and any feedback; adjust your study schedule if needed. |
#
# Follow these steps consistently and you’ll strengthen interaction, keep motivation high, and make the most of the flexibility that blended learning offers. Good luck!

# %% [markdown]
# ## Student ID: `e20240618`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240618*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - Your open‑ended responses did not provide specific strengths or challenges, so the recommendations below are drawn from the typical profile of this segment.
#
# ### 2. Main Strengths
# - Not explicitly reported.
# - As a moderately engaged learner, you likely have a solid foundation for independent study when the right support is in place.
#
# ### 3. Main Challenges
# - Not explicitly reported.
# - Passive engagement often means limited interaction with peers or instructors and a need for clearer guidance and motivation structures.
#
# ### 4. Personalized Recommendations
#
# | Focus | What the recommendation means for you | Practical steps you can take |
# |-------|----------------------------------------|------------------------------|
# | **Interaction** | Increase communication with classmates and the lecturer. | • Join scheduled Q&A sessions.<br>• Participate in small‑group discussions or online forums.<br>• Seek quick feedback on assignments. |
# | **Learning Support** | Get clearer instructions and additional examples. | • Use recorded explanations and step‑by‑step guides provided by the course.<br>• Ask the lecturer for concrete examples when a concept is unclear. |
# | **Motivation** | Build self‑discipline and keep track of progress. | • Set a weekly check‑in with yourself (or a study buddy) to review goals.<br>• Use reminders or a planner to schedule study blocks.<br>• Monitor your progress with the course’s tracking tools. |
# | **Self‑Paced Learning** | Take advantage of materials you can review on your own schedule. | • Watch recorded lessons before or after live sessions.<br>• Follow the weekly learning path supplied by the instructor.<br>• Re‑visit any material that feels difficult until you’re confident. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **Week 1** | • Attend at least one Q&A session.<br>• Download the step‑by‑step guide for the current module and review the recorded explanations.<br>• Set a 30‑minute daily study slot and log your progress at the end of each day. |
# | **Week 2** | • Join a peer‑collaboration group (e.g., a study chat or discussion board).<br>• Use the course’s progress tracker to note completed tasks.<br>• Review any recorded lessons you missed and note questions to ask the lecturer. |
#
# ---
#
# **Remember:** Consistent interaction, clear guidance, and a structured study routine are key to moving from passive to active engagement. Use the resources your course provides, and don’t hesitate to reach out for help when you need it. Good luck!

# %% [markdown]
# ## Student ID: `e20220895`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "learning_effectiveness", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220895*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility and the ability to review material repeatedly. You appreciate having easy access to slides, videos, and other resources, which helps you balance study with other commitments.
#
# During online sessions you sometimes feel lost and find it harder to stay focused, which can affect motivation and self‑discipline.
#
# ---
#
# ### 2. Main Strengths
# | Strength theme | What you mentioned |
# |----------------|-------------------|
# | **Access to Learning Materials** | “Good for balancing… can review the recorded again and again.” |
# | **Learning Convenience & Effectiveness** | You find the ability to revisit content helpful for understanding. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge theme | What you mentioned |
# |-----------------|--------------------|
# | **Learning Difficulty & Clarity** | “Feel lost during the online time.” |
# | **Motivation & Self‑Discipline** | “Less concentration.” |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How it helps you |
# |----------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Ensure slides, videos, references, and exercises are uploaded early so you can plan review sessions. |
# | **Develop digital learning skills** (digital_skill) | Short guides or short videos on using the LMS, searching online resources, and basic edu‑tech tools will make navigation smoother. |
# | **Improve learning effectiveness** (learning_effectiveness) | Pair the recorded material you like with brief in‑person (or live‑online) explanations, practice activities, and quick feedback. |
# | **Improve clarity and learning support** (learning_support) | Instructors will provide clearer step‑by‑step instructions, concrete examples, and optional recorded walkthroughs of complex topics. |
# | **Support motivation and self‑discipline** (motivation) | Weekly check‑ins, gentle reminders, and a visual progress tracker will help you stay focused and keep momentum. |
# | **Support self‑paced learning** (self_paced) | A weekly learning path with suggested milestones, plus all recordings available for you to revisit at any time. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Access the course’s “Resources” folder; download the week’s slides and video. Set a 30‑minute review slot each day. |
# | **2** | Watch the short “LMS Basics” tutorial (5 min). Try uploading a note or posting a question in the forum. |
# | **3** | Attend the live Q&A (or watch the recorded version) that follows the lecture. Complete one practice exercise and request quick feedback. |
# | **4** | Use the progress tracker to mark completed items. Schedule a 10‑minute weekly check‑in with the tutor or a study buddy to discuss any unclear points. |
#
# By following this plan, you can keep the flexibility you enjoy while gaining clearer guidance and stronger motivation during online sessions. Feel free to adjust the timing to fit your personal schedule—your active engagement is the key driver of success!

# %% [markdown]
# ## Student ID: `e20220337`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20220337
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are identified as a highly engaged learner who values flexibility and manages your time well. You have noted that occasional network or technical problems can disrupt your study.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to adjust when and where you study, which helps you stay on track.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable connections sometimes make it hard to access online content.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|-----------------------|
# | **Support self‑paced learning** | Use recorded lectures, weekly learning paths, and downloadable materials so you can review content whenever your connection is reliable. |
# | **Improve technical access and reliability** | Take advantage of offline resources, clear step‑by‑step platform guides, and the university’s technical‑support services to minimise disruptions. |
#
# These suggestions are drawn directly from the rule‑based recommendations for your segment and the specific tags identified for you (*self_paced* and *tech_issue*).
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action |
# |------|--------|
# | **1** | Locate the recorded lessons for your current module and download them to your device. |
# | **2** | Follow the weekly learning path outline provided in the course portal; adjust the schedule to fit your personal timetable. |
# | **3** | Test your internet connection in a quiet spot; if problems persist, request a loaner Wi‑Fi hotspot or use campus computer labs. |
# | **4** | Review the platform’s “How‑to” guide and bookmark the technical‑support contact details for quick help. |
# | **Ongoing** | Keep a brief log of any connectivity issues and the steps you took to resolve them; share this with your instructor or support team to improve future access. |
#
# By leveraging self‑paced resources and proactively managing technical hurdles, you can maintain your high level of engagement and continue to succeed in a blended learning environment.

# %% [markdown]
# ## Student ID: `e20240334`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240334*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You appreciate the **flexibility and convenience** that blended formats give you for managing your time.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you value being able to study when it best fits your schedule.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – you would like more frequent conversation and a stronger dynamic with teachers.
# - **Motivation & Self‑Discipline** – you feel that occasional support or reminders could help keep you on track.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | How It Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join short Q&A sessions after each lecture.<br>• Participate in weekly group discussions or peer‑collaboration activities.<br>• Request quicker feedback from the lecturer on assignments. | Increases communication with peers and instructors, creating the supportive dynamic you want. |
# | **Motivation** | • Set up a weekly check‑in (e.g., a 5‑minute chat or a quick survey) with your tutor.<br>• Use reminders or a simple progress‑tracking board.<br>• Follow a structured study schedule that outlines what to do each day. | Provides regular encouragement and visible progress, boosting self‑discipline. |
# | **Self‑Paced Learning** | • Access recorded lessons so you can review material anytime.<br>• Follow the weekly learning path that outlines required readings, videos, and activities.<br>• Keep a personal “review folder” for concepts you want to revisit. | Lets you keep the convenience you value while still meeting course goals. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Watch the recorded lecture for this week and note any questions. |
# | **Tue** | Post your questions in the course Q&A forum; schedule a 10‑minute chat with the lecturer if needed. |
# | **Wed** | Join the scheduled group discussion; share one insight from the lecture. |
# | **Thu** | Complete a quick self‑check (tick off what you’ve learned) and set a reminder for tomorrow’s study block. |
# | **Fri** | Review any unclear points using the recorded lesson; update your progress tracker. |
# | **Weekend** | Plan next week’s study schedule (blocks for reading, practice, and discussion). |
#
# Repeat this cycle each week, adjusting the timing to fit your personal rhythm. By adding regular interaction, brief motivation check‑ins, and using self‑paced resources, you’ll keep the flexibility you like while strengthening communication and staying motivated. Good luck!

# %% [markdown]
# ## Student ID: `e20220370`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220370*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What this means:** You tend to participate less actively in class activities and may rely more on the material being presented to you. Because no specific strengths or challenges were shared, the recommendations below are drawn from the typical profile of this segment.
#
# ---
#
# ### 2. Main Strengths
# *No explicit strengths were reported.*
# > *The suggestions below are based on the common characteristics of moderately engaged learners.*
#
# ---
#
# ### 3. Main Challenges
# *No explicit challenges were reported.*
# > *The recommendations address the usual areas where passive learners can benefit the most.*
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | Why it Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join short Q&A sessions after lectures.<br>• Participate in small‑group discussions or peer‑collaboration activities.<br>• Request quicker feedback from the lecturer on assignments. | Increases engagement and gives you more opportunities to clarify doubts. |
# | **Learning Support** | • Look for clear, step‑by‑step guides and examples posted by the instructor.<br>• Use recorded explanations that break down complex topics.<br>• Keep a personal checklist of instructions for each task. | Makes the material easier to follow and reduces uncertainty. |
# | **Motivation & Self‑Discipline** | • Set a weekly check‑in (e.g., a 5‑minute self‑review) to note progress.<br>• Use calendar reminders for study sessions and deadlines.<br>• Track your progress with a simple spreadsheet or app. | Helps you stay on track and see tangible progress, boosting motivation. |
# | **Self‑Paced Learning** | • Watch recorded lessons before class to preview content.<br>• Follow the weekly learning path provided by the course and review any material you missed at your own speed.<br>• Keep a folder of all resources for easy revisiting. | Allows you to control the pace of learning and revisit difficult concepts as needed. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Locate the course’s recorded lectures and Q&A schedule. |
# | **Day 2** | Create a simple study calendar with 30‑minute blocks for each subject. |
# | **Day 3** | Join a peer‑study group or set up a virtual discussion with one classmate. |
# | **Day 4** | Review the first recorded lesson and write down 2‑3 questions. |
# | **Day 5** | Attend the next Q&A session and ask your prepared questions. |
# | **Day 6** | Complete a short self‑check‑in: note what you understood and what needs review. |
# | **Day 7** | Update your progress tracker (e.g., mark the lesson as “reviewed”). |
# | **Day 8‑14** | Repeat the cycle: watch the next lesson, schedule a discussion, use feedback, and track progress. |
#
# ---
#
# **Remember:** Small, consistent steps—like brief check‑ins and using available recordings—can quickly turn a passive learning style into a more active, confident experience. If you need additional support, reach out to your lecturer or the student help centre. Good luck!

# %% [markdown]
# ## Student ID: `e20241011`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20241011
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Learning Profile
# You are a highly engaged learner who values convenience and effectiveness in your studies. You appreciate that blended formats let teachers cover more material, especially when they are busy.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You see blended learning as a useful way to get more out of class time.
# - **Student Engagement** – You are motivated to participate actively in learning activities.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable internet access makes it hard to fully benefit from online components.
#
# *(Your open‑ended responses were brief, so the recommendations below rely mainly on the characteristics of your “Highly Engaged” segment and the challenges you reported.)*
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Engagement** | Incorporate short quizzes, game‑based tasks, practical exercises, and online discussions into each module. | Keeps your high energy directed toward active participation and deepens understanding. |
# | **Learning Effectiveness** | Pair online review materials (e.g., short videos or readings) with in‑person explanations, guided practice, and timely feedback. | Combines the convenience you value with the clarity of face‑to‑face instruction. |
# | **Technical Access** | • Use offline‑downloadable resources when possible.<br>• Follow the platform’s step‑by‑step guide for common issues.<br>• Contact the university’s tech support for stable Wi‑Fi or alternative access points. | Reduces interruptions caused by internet problems, ensuring you can stay engaged and learn effectively. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify which course materials can be downloaded for offline study. |
# | **Day 3–4** | Complete the platform’s quick‑start guide; note any questions for tech support. |
# | **Day 5** | Join a study group or forum where weekly quizzes or mini‑games are posted. |
# | **Day 6–7** | Attend the next in‑person session and ask the instructor for a brief recap of the online content. |
# | **Week 2** | Schedule a 15‑minute check‑in with technical support to confirm stable internet access for upcoming online activities. |
# | **End of Week 2** | Reflect on which engagement activities helped you most and adjust your study routine accordingly. |
#
# Stay proactive, use the interactive tools available, and make sure you have reliable access to the online components. With these steps, you’ll keep your high engagement level while overcoming technical hurdles and maximizing learning effectiveness.

# %% [markdown]
# ## Student ID: `e20250090`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "learning_effectiveness"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20250090
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You find self‑study and online teacher‑led classes convenient and effective.
# - You are actively engaged with the material.
#
# **Main Challenges**
# - You indicated difficulty with French. (No additional challenges were reported.)
#
# **Personalized Recommendations**
#
# | Focus | Recommendation (based on your segment and the rule‑based tags) |
# |-------|---------------------------------------------------------------|
# | **Engagement** | Keep your learning lively by adding quizzes, short games, practical tasks, and brief discussion prompts to your study sessions. These interactive elements help maintain the high level of involvement you already show. |
# | **Learning Effectiveness** | Pair the online review resources you already use with brief in‑person (or live‑online) explanations, practice activities, and quick feedback. This blend reinforces concepts and makes your self‑study more powerful, especially for French. |
#
# **Short Action Plan**
#
# 1. **Add Interactive Checks** – After each study block, complete a 5‑question quiz or a quick game related to the topic.
# 2. **Mix Modalities** – Schedule a 15‑minute live session (with a teacher or peer) to go over the most challenging French points, then practice with a short written or spoken task.
# 3. **Seek Immediate Feedback** – Use the platform’s comment feature or a study partner to get quick feedback on your practice tasks.
# 4. **Reflect Weekly** – Spend 5 minutes noting which interactive activities helped you understand French best, and adjust your study plan accordingly.
#
# These steps build on your strong engagement and self‑study habits while targeting the French language area where you seek improvement.

# %% [markdown]
# ## Student ID: `e20230912`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230912*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** The flexibility of online study saves you travel time and lets you manage your schedule.
# - **What you find challenging:** You feel a weak connection with teachers, notice limited attention from them, and sometimes struggle with motivation and technical reliability.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when and where it suits you, which helps you balance other commitments.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Limited real‑time contact and feedback from lecturers.
# - **Motivation & Self‑Discipline:** Keeping focus and momentum without strong external prompts.
# - **Internet & Technical Issues:** Unstable connectivity or platform difficulties that interrupt learning.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback on assignments. | Increases teacher‑student connection and gives you clearer guidance. |
# | **Motivation** | • Set up weekly check‑ins (with a tutor or study buddy).<br>• Use reminders and a simple progress‑tracking sheet.<br>• Follow a structured weekly study schedule. | Keeps you accountable and sustains momentum throughout the term. |
# | **Self‑Paced Learning** | • Access recorded lectures and downloadable resources.<br>• Follow the weekly learning path provided by the course.<br>• Review materials at your own speed when needed. | Lets you keep the flexibility you value while ensuring you don’t miss key content. |
# | **Technical Access** | • Use the university’s stable Wi‑Fi hotspots or loaned mobile data kits.<br>• Download offline copies of readings and videos in advance.<br>• Follow the short “how‑to” guide for the learning platform and contact tech support for any glitches. | Reduces interruptions caused by connectivity problems and makes the platform easier to use. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Register for the upcoming Q&A session and note the discussion forum link. |
# | **Tuesday** | Download this week’s lecture videos for offline viewing. |
# | **Wednesday** | Set a 30‑minute reminder for a mid‑week progress check (e.g., update a simple checklist). |
# | **Thursday** | Test the university’s Wi‑Fi hotspot or request a data loan; note any issues. |
# | **Friday** | Post a question or comment in the course forum to trigger lecturer feedback. |
# | **Weekend** | Review recorded lessons and update your progress tracker; plan next week’s study schedule. |
#
# Follow the plan, adjust the timing to fit your personal rhythm, and reach out to your lecturer or tech support whenever you hit a roadblock. You have the engagement and flexibility—these steps will help turn those strengths into consistent success.

# %% [markdown]
# ## Student ID: `e20221349`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221349*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners who attend classes regularly but tend to take a more passive role. They benefit from structures that increase interaction, motivation, and clear support while allowing self‑paced study.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You indicated that the current setup is “good,” reflecting a positive view of how convenient and effective your learning feels.
#
# ### 3. Main Challenges
# - Your open‑ended response about challenges was brief (“not sure”). Because of this limited information, the recommendation below relies primarily on the characteristics of your learner segment.
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness** – To boost the impact of your study time, blend online review resources (e.g., short videos, quizzes, or summary notes) with face‑to‑face sessions where the instructor can explain concepts, guide practice, and give immediate feedback. This combination helps turn passive attendance into active understanding.
#
# ### 5. Short Action Plan
#
# | Step | What to Do | How It Helps |
# |------|------------|--------------|
# | 1. Identify key topics | Before each class, list 2–3 concepts you want to master. | Focuses your online review on what matters most. |
# | 2. Use online review materials | Watch a 5‑10 min video or complete a quick quiz on those topics. | Gives you a first exposure at your own pace. |
# | 3. Attend the in‑person session | Come prepared with questions from the online review. | Allows the instructor to clarify doubts and provide guided practice. |
# | 4. Seek feedback | After class, ask the tutor to check one problem or explain a point you found tricky. | Immediate feedback reinforces learning and highlights any gaps. |
# | 5. Reflect & adjust | Spend a few minutes noting what worked and what still feels unclear. | Helps you fine‑tune the balance of online and face‑to‑face study for future sessions. |
#
# By consistently pairing brief, self‑paced online reviews with interactive, feedback‑rich classroom time, you’ll make your study more effective while staying within a structure that fits your moderate engagement style.
#
# ---
#
# *If you have any questions or need help locating suitable online review resources, feel free to reach out to your academic support team.*

# %% [markdown]
# ## Student ID: `e20240276`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "learning_effectiveness", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240276*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Moderately Engaged (Passive) Learners” segment. This group generally accesses digital content well but benefits from additional structure, clearer instructions, and opportunities to practice what is presented online.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate that course resources are easy to reach and see value in technology‑enhanced learning.
# - **Digital Skills Development** – You recognize the importance of digital tools for current and future studies.
# - **Learning Convenience & Effectiveness** – You find online formats convenient and believe they can be effective when well designed.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You would like visualizations to appear alongside explanations so that concepts become clearer.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Keep all slides, videos, readings, and exercises available early in the course. | Check the LMS at the start of each week; download or bookmark the posted files so you can review them before class. |
# | **Develop digital learning skills** | Get comfortable with the LMS, online research tools, and any interactive features used in the course. | Use short “how‑to” guides or tutorial videos provided by the instructor; practice searching the library’s digital databases and using discussion boards. |
# | **Improve learning effectiveness** | Pair the online review content with in‑person explanations, practice activities, and feedback. | Attend scheduled face‑to‑face sessions where the instructor expands on the online material; complete the practice exercises and ask for feedback on your work. |
# | **Improve clarity and learning support** | Receive clearer instructions, step‑by‑step guides, and recorded explanations that accompany visual content. | Look for supplemental recorded walkthroughs or example problems that the instructor posts; use the provided step‑by‑step guides when working through new topics. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Log into the LMS and locate the folder where all slides, videos, and readings are uploaded. Download the week’s materials. |
# | **Day 3** | Watch any introductory tutorial videos on using the LMS and digital research tools (e.g., library databases, citation managers). |
# | **Day 4–5** | Review the week’s online content, then attend the in‑person session to see the same concepts explained with live examples. |
# | **Day 6** | Complete the first set of practice exercises; submit them for feedback or discuss them in a study group. |
# | **Day 7** | Locate the recorded explanations or step‑by‑step guides that accompany the visualizations you found challenging; review them while following along with the slides. |
# | **Week 2** | Repeat the cycle, adding any new visual‑plus‑explanation resources the instructor provides. Keep a short note of what helped most for future reference. |
#
# ---
#
# **Remember:** By combining early access to materials, sharpening your digital skills, linking online content with face‑to‑face practice, and using clearer step‑by‑step supports, you’ll turn passive engagement into more active, confident learning. Good luck!

# %% [markdown]
# ## Student ID: `e20220467`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220467*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values being able to **re‑visit lecture material** whenever you need it. This flexibility is a clear strength for you. At the same time, you noted that **self‑discipline can be a challenge**, especially when you feel tempted to skip live online sessions because the content is always available later.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You make good use of recorded slides, videos, and other resources, which helps you keep up even after missing a class.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Limited real‑time engagement can reduce the sense of connection with peers and instructors.
# - **Motivation & Self‑Discipline** – The ability to view material later sometimes leads to procrastination and missed live sessions.
#
# ---
#
# ### 4. Personalized Recommendations
# | Focus | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Ensure that slides, videos, reference links, and exercises are uploaded **early** in the week. | You can continue to study at your own pace while still having fresh material to review. |
# | **Interaction** | Participate in scheduled **Q&A sessions**, join small‑group discussions, and collaborate on short peer activities. Request quicker feedback from the lecturer when possible. | More live interaction builds accountability and keeps you connected to the class community. |
# | **Motivation & Self‑Discipline** | Use **weekly check‑ins** (e.g., a short self‑reflection or a quick poll), set **reminders** for live sessions, and follow a **structured study schedule** that includes both live attendance and dedicated review time. Track your progress on a simple checklist or digital dashboard. | Regular prompts and visible progress make it easier to stay on track and reduce the temptation to postpone participation. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the week’s uploaded materials (slides + video) before the first live session. |
# | **Tuesday** | Attend the scheduled **Q&A** (10 min) and post one question in the discussion forum. |
# | **Wednesday** | Set a 15‑minute reminder for the next live class; add the session to your calendar. |
# | **Thursday** | Complete a short **self‑check‑in** (rate your attendance and understanding on a 1‑5 scale). |
# | **Friday** | Join a peer‑collaboration activity or study group for 20 minutes. |
# | **Weekend** | Review any missed content, update your progress tracker, and plan next week’s study schedule. |
#
# Repeat the cycle the following week, adjusting reminder times or study blocks as needed.
#
# ---
#
# **Keep in mind:** Your ability to access materials anytime is a strong advantage. By pairing that with regular interaction and simple motivation tools, you’ll maintain high engagement while strengthening self‑discipline. Good luck, and enjoy your learning journey!

# %% [markdown]
# ## Student ID: `e20241261`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241261*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - The open‑ended responses did not provide specific strengths or challenges, so the recommendations below are drawn primarily from the characteristics of the “Highly Engaged (Active) Learners” segment.
#
# ### 2. Main Strengths
# - (No specific strengths were reported.)
#
# ### 3. Main Challenges
# - (No specific challenges were reported.)
#
# ### 4. Personalized Recommendations
#
# | Focus Area | What It Means for You | Suggested Actions |
# |------------|----------------------|-------------------|
# | **Content Access** | You benefit from having all learning materials ready early, so you can dive straight into activities. | • Instructors should upload slides, videos, reading lists, and exercise files at the start of each week. |
# | **Digital Skill** | Strong digital skills let you navigate the LMS, locate resources, and use educational tools efficiently. | • Receive short guides or short videos on how to use the LMS, search academic databases, and apply common e‑learning tools. |
# | **Engagement** | As an active learner, interactive elements keep you motivated and deepen understanding. | • Participate in quizzes, gamified tasks, discussion boards, and hands‑on projects that are built into the course. |
# | **Self‑Paced Learning** | You like to control the speed of your study, reviewing concepts as needed. | • Access recorded lectures and a weekly learning path that you can follow or revisit at any time. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Check the course portal for all uploaded materials (slides, videos, readings). Bookmark them for quick reference. |
# | **Week 2** | Watch the “LMS Quick‑Start” tutorial and try a practice search in the library’s digital catalogue. |
# | **Week 3** | Complete the first interactive quiz and join the discussion thread on the week’s topic. |
# | **Week 4** | Review any recorded lessons you found challenging; note questions for the next live session. |
# | **Ongoing** | Follow the weekly learning path, use quizzes and games to test yourself, and keep the digital‑skill guides handy for any new tools introduced. |
#
# ---
#
# **Remember:** Even though you didn’t specify particular strengths or challenges, the recommendations align with the typical needs of highly engaged, active learners. Taking advantage of early material access, sharpening digital skills, staying involved in interactive activities, and using self‑paced resources will help you maintain momentum and achieve strong outcomes in a blended learning environment.

# %% [markdown]
# ## Student ID: `e20230656`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230656
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# You value the flexibility of blended learning. Access to online slides, recorded lectures, and other resources lets you study at your own pace, while in‑person sessions give you the chance for discussion, group work, and immediate feedback. This combination makes your learning more convenient and effective.
#
# **Main Challenges**
# - Inconsistent organization of online materials and unclear instructions across courses.
# - Technical problems such as unstable internet connections.
# - Need for clearer communication, better interaction, and balanced workload.
#
# **Personalized Recommendations**
#
# | Area | What to do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Lecturers should upload slides, videos, references, exercises, and other course materials **early** in the semester. |
# | **Engagement** | Include short quizzes, games, practical tasks, and structured discussions in both online and face‑to‑face sessions. |
# | **Interaction & Communication** | Add regular Q&A slots, small‑group discussions, peer‑collaboration activities, and faster lecturer feedback on assignments. |
# | **Learning Effectiveness** | Pair recorded review materials with in‑person explanations, practice opportunities, and timely feedback. |
# | **Learning Environment** | Organise all resources clearly on the platform, keep them up‑to‑date, and ensure classroom spaces are comfortable for active work. |
# | **Learning Support** | Provide clear step‑by‑step instructions, concrete examples, and short recorded explanations for complex topics. |
# | **Self‑Paced Learning** | Offer weekly learning paths and make recorded lessons available so you can revisit them whenever needed. |
# | **Technical Issues** | Ensure stable campus Wi‑Fi, provide offline copies of key materials, give clear platform guides, and maintain a responsive technical‑support service. |
# | **Workload Support** | Align online tasks with in‑person sessions, balance the number of assignments, and publish all deadlines well in advance. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# 1. **Week 1:** Check that all course slides and recordings are uploaded; create a personal folder for each module.
# 2. **Week 2:** Join a scheduled Q&A or peer‑discussion group; note any unclear instructions and ask the lecturer for clarification.
# 3. **Week 3:** Use the weekly learning path to review recorded lessons; complete any short quizzes to reinforce understanding.
# 4. **Week 4:** Report any technical problems to the support desk early; review the updated assignment schedule and plan your workload accordingly.
#
# By following these steps, you can keep leveraging the flexibility you enjoy while reducing the organisational and technical hurdles that currently limit your blended‑learning experience. Good luck!

# %% [markdown]
# ## Student ID: `e20220166`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220166*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility of blended learning. You like to set your own schedule and adjust the pace of different subjects to maximise academic performance. You also notice that the online component can feel less interactive, especially when students are hesitant to speak up.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to customise your learning timetable and study at a pace that suits you, which helps you achieve better grades.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Online sessions sometimes lack the lively discussion you need; smaller breakout groups could help.
# - **Learning Resources & Environment** – You would benefit from clearer organization of materials and more comfortable virtual study spaces.
# - **Assessment & Workload** – Balancing assignments and aligning online tasks with face‑to‑face sessions is a concern.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | Join scheduled Q&A sessions, take part in group discussions and peer‑collaboration activities, and request quicker feedback from lecturers. | Increases opportunities to speak up, builds confidence, and breaks down the “wall” you mentioned. |
# | **Learning Environment** | Use platforms that organise resources clearly; look for updated study guides and virtual “rooms” that are comfortable for you. | A well‑structured environment reduces distraction and supports your self‑directed study. |
# | **Self‑Paced Learning** | Access recorded lectures, follow weekly learning paths, and review materials whenever you need. | Keeps the flexibility you value while ensuring you don’t miss any key content. |
# | **Workload Support** | Check the course calendar for balanced assignment distribution, clarify deadlines early, and align online tasks with in‑person work. | Helps you manage the workload and reduces pressure around assessments. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the challenges you described.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Locate the recorded lectures for this week’s subjects and add them to your personal study schedule. |
# | **Tue** | Sign up for the upcoming Q&A session and note any questions you have from the recorded material. |
# | **Wed** | Join a breakout‑room discussion in your next online class; aim to contribute at least one idea. |
# | **Thu** | Review the course calendar; write down all assignment deadlines and flag any that seem clustered. |
# | **Fri** | Create a tidy folder (digital or physical) for this week’s resources, following the clear‑organization tip. |
# | **Weekend** | Reflect on how the new interaction opportunities felt; adjust your participation plan for the following week. |
#
# Follow these steps, and you’ll strengthen the interactive side of blended learning while keeping the flexibility that works best for you. Good luck!

# %% [markdown]
# ## Student ID: `e20230611`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20230611
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# - **What you value:** Convenient, effective learning that lets you study safely and have more time for self‑study.
# - **Current challenges you mentioned:** Unreliable internet connection and an unpredictable timetable that can make planning difficult.
#
# Because your open‑ended responses are brief, the recommendations below are also grounded in the typical profile of highly engaged, active learners in your segment.
#
# ---
#
# ### 2. Main Strengths
# - Strong motivation to learn independently.
# - Appreciate flexible, self‑paced study options.
#
# ---
#
# ### 3. Main Challenges
# - **Technical:** Inconsistent internet access.
# - **Scheduling:** Fluctuating timetable that can affect when you can engage with online content.
# - **Workload:** Need clear guidance to balance assignments and assessments.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | Recommendation (based on rule‑based tags) |
# |-------|-------------------------------------------|
# | **Learning Effectiveness** | Combine the online review materials you already use with short, in‑person sessions where the instructor can explain concepts, give you practice opportunities, and provide immediate feedback. This mix reinforces understanding and keeps you actively engaged. |
# | **Technical Access** | Ensure you have a reliable internet plan or use campus Wi‑Fi hotspots. Download offline versions of lecture videos and readings ahead of time, and keep a quick‑reference guide for the learning platform. If problems arise, contact the university’s technical support service promptly. |
# | **Workload & Assessment** | Work with your instructors to get a clear schedule of assignment deadlines and exam dates. Align online tasks (e.g., quizzes, discussion posts) with the topics covered in upcoming face‑to‑face sessions so you can study efficiently and avoid overload. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | List all upcoming assignments and their due dates; share the list with your course coordinator for clarification if needed. |
# | **Day 3–4** | Test your internet connection; if unstable, arrange access to a campus hotspot or a reliable backup data plan. |
# | **Day 5** | Download all online lecture videos and readings for the next week to have offline copies. |
# | **Day 6–7** | Schedule a 30‑minute in‑person meeting with the lecturer to review any concepts you find difficult after watching the videos. |
# | **Week 2** | Follow the combined study routine: review online material, attend the brief in‑person session, complete practice exercises, and submit assignments according to the clarified schedule. |
# | **Ongoing** | Keep a short log of any technical issues and report them to tech support; adjust your study timetable whenever your class schedule changes. |
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By pairing online resources with targeted face‑to‑face support, securing reliable internet, and keeping a clear view of deadlines, you can maintain effective learning while managing workload and technical hurdles. Good luck!

# %% [markdown]
# ## Student ID: `M080212`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** M080212
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values having all the expertise from lectures and strong knowledge of the subject. You appreciate learning materials that are easy to access and that support convenient, effective study. The main difficulty you reported is an unstable internet connection.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You benefit from having slides, videos, references, and exercises available.
# - **Learning Convenience & Effectiveness:** You are motivated to use resources that make studying efficient and productive.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable connectivity can limit your ability to use online resources smoothly.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What to Do | Why it Helps |
# |----------------|------------|--------------|
# | **Strengthen access to learning materials** | • Upload slides, videos, reference links, and practice exercises **early** in the course platform. <br>• Ensure materials are organized and easy to find. | Guarantees you can review content whenever you need it, supporting your strong desire for comprehensive resources. |
# | **Improve learning effectiveness** | • Pair online review items (slides, videos) with **in‑person explanations, guided practice, and timely feedback**. <br>• Use brief quizzes or reflection prompts after each topic. | Combines the convenience of digital content with the depth of face‑to‑face interaction, boosting retention and application of knowledge. |
# | **Improve technical access and reliability** | • Provide **offline versions** of key materials (PDFs, downloadable videos). <br>• Offer clear instructions for the learning platform and a quick‑response technical support channel. <br>• Explore campus Wi‑Fi hotspots or loaner devices for stable internet. | Reduces the impact of your unstable connection, ensuring you can continue learning without interruption. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Check the course portal for any missing slides or videos; download them for offline use. |
# | **Day 3–4** | Attend the upcoming in‑person session and ask the instructor to clarify any concepts from the online material. |
# | **Day 5** | Complete a short practice exercise and submit it for feedback. |
# | **Day 6–7** | Test the offline files on a different device (e.g., laptop, tablet) to confirm they work without internet. |
# | **Day 8** | Locate the nearest campus Wi‑Fi hotspot or request a loaner hotspot from the IT help desk. |
# | **Day 9–10** | Review the downloaded materials and note any questions; bring them to the next class or office hour. |
# | **Day 11–14** | Use the technical support channel if any platform issues arise; keep a log of problems and resolutions. |
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By securing reliable access to materials, blending online review with active classroom work, and addressing connectivity issues, you can maintain your momentum and achieve even better learning outcomes. If you need further assistance, reach out to your instructor or the university’s learning‑technology support team.

# %% [markdown]
# ## Student ID: `e20240594`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240594*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Key strength you mentioned:** You appreciate the **flexibility** that blended learning gives you.
# - **Main challenge you noted:** You sometimes experience a **lack of motivation** when you study on your own.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You are good at adapting your schedule and value the ability to learn when it fits your life.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Keeping momentum during self‑study periods can be difficult.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support motivation and self‑discipline** | Build regular habits that keep you on track. | • Set up **weekly check‑ins** (e.g., a short meeting with a tutor or peer). <br>• Use **reminders** and a simple **progress tracker** (check‑off completed modules). <br>• Follow a **structured study schedule** that blocks specific times for each topic. |
# | **Support self‑paced learning** | Take advantage of the flexibility you like while still having clear guidance. | • Access **recorded lessons** so you can review anytime. <br>• Follow the **weekly learning path** provided by the course (a list of what to study each week). <br>• Keep all **materials** (slides, readings, quizzes) organized for easy revisiting. |
#
# These suggestions come directly from the evidence for your segment and the tags identified for you (*motivation* and *self‑paced*).
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a simple weekly schedule (2‑3 study blocks) and add it to your calendar. |
# | **Tuesday** | Watch the first recorded lesson for the week; note any questions. |
# | **Wednesday** | Set a reminder for a 10‑minute self‑check‑in: what you’ve completed, what’s next. |
# | **Thursday** | Share a brief progress update with a study buddy or tutor (email or chat). |
# | **Friday** | Complete the week’s quiz; record your score in the progress tracker. |
# | **Weekend** | Review any unclear concepts using the recorded lessons; adjust next week’s schedule if needed. |
#
# Repeat the cycle each week, adding the check‑ins and progress tracking habit. Over time, the routine will help boost motivation while still letting you learn at your own pace.
#
# ---
#
# **You have the flexibility to shape your learning—these small, structured steps can turn that flexibility into consistent progress.** Good luck!

# %% [markdown]
# ## Student ID: `e20230093`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230093
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value **access to learning materials** that help students who feel they cannot keep up with in‑person lessons.
#
# **Main Challenges**
# - The current learning videos are outdated.
# - You would like lecturers to keep video content and other resources up‑to‑date.
#
# **Personalized Recommendations**
#
# | Recommendation Area | What to Do | Why it Helps |
# |---------------------|------------|--------------|
# | **Content Access** | • Upload slides, videos, reference links, exercises, and other course materials **early** in the semester. | Gives you and peers the chance to review material before class, supporting those who need extra time to catch up. |
# | **Interaction & Communication** | • Add regular Q&A sessions, small‑group discussions, and peer‑collaboration activities.<br>• Provide faster feedback from lecturers on questions and assignments. | Increases opportunities to clarify doubts about the material, especially when videos are refreshed. |
# | **Learning Environment** | • Keep all digital resources (videos, readings, examples) **up‑to‑date** and clearly organized in the LMS.<br>• Ensure study spaces (both virtual and physical) are comfortable and well‑structured. | A current, well‑organized resource set reduces confusion and makes self‑paced study more effective. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Check the LMS** for any newly uploaded slides or reference files for your current module.
# 2. **Request** that the lecturer post updated video recordings or note any outdated content in the discussion forum.
# 3. **Join a study group** or schedule a short Q&A session with classmates to discuss any unclear points from the videos.
# 4. **Give feedback** on the organization of the course materials (e.g., folder naming, navigation) so the teaching team can improve the learning environment.
#
# By focusing on timely access to updated content, richer interaction, and a well‑organized learning space, you can maintain your high level of engagement while overcoming the challenges you identified. Good luck!

# %% [markdown]
# ## Student ID: `e20250118`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_support", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250118*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values convenient, effective study. Your open‑ended feedback shows that you find the current study environment “easy for safe study,” but you experience three main difficulties:
#
# 1. **Interaction & Communication** – trouble interacting with teachers or classmates.
# 2. **Internet & Technical Issues** – occasional connectivity or platform problems.
# 3. **Learning Difficulty & Clarity** – lessons are sometimes hard to understand.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – you feel the study setup is convenient and helps you learn efficiently.
#
# ---
#
# ### 3. Main Challenges
# - Limited interaction with instructors and peers.
# - Unreliable internet or technical glitches that disrupt learning.
# - Lack of clear explanations, making some lessons difficult to grasp.
#
# ---
#
# ### 4. Personalized Recommendations
# | Focus | What to Do (based on rule‑based advice) |
# |-------|------------------------------------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from lecturers. |
# | **Learning Effectiveness** | • Use a mix of online review materials together with in‑person explanations and practice tasks.<br>• Seek regular feedback on your practice work. |
# | **Learning Support** | • Ask for clearer written instructions and concrete examples.<br>• Use recorded explanations and step‑by‑step guides when a concept feels unclear. |
# | **Technical Issues** | • Ensure you have a stable internet connection (e.g., campus Wi‑Fi, personal hotspot).<br>• Download offline copies of essential materials in advance.<br>• Keep a quick‑reference guide for the learning platform and know how to contact technical support. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the Q&A schedule and sign up for the next session. |
# | **Day 3‑4** | Download offline PDFs of this week’s readings and store them on your device. |
# | **Day 5** | Join a small study group or forum for peer collaboration; share one question you have. |
# | **Day 6‑7** | Watch a recorded explanation of a difficult topic; take notes using the step‑by‑step guide. |
# | **Day 8** | Submit a practice assignment and request specific feedback from the lecturer. |
# | **Day 9‑10** | Test your internet connection; if unstable, arrange an alternative (campus Wi‑Fi, hotspot). |
# | **Day 11‑12** | Review the platform’s quick‑start guide; note any steps you need help with and contact tech support. |
# | **Day 13‑14** | Reflect on the past two weeks: Which interaction or support helped most? Adjust your plan accordingly. |
#
# ---
#
# **Remember:** Your strong engagement is a great asset. By adding structured interaction, clearer support resources, and reliable technical access, you can turn the current challenges into opportunities for even more effective learning. Good luck!

# %% [markdown]
# ## Student ID: `e20230138`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "learning_environment", "learning_support", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230138
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You see yourself as working on **digital skill development** and feel positive about this area.
#
# **Main Challenges**
# - You experience **internet/technical problems** that make it hard to join online classes or access materials.
# - You also note difficulties with **interaction & communication**, **clarity of learning**, and the overall **learning environment**.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Digital Skills** | Follow short tutorials on the LMS, explore the university’s digital‑research guides, and practice using the key tools for assignments. | Strengthens the digital abilities you already value and makes online tasks smoother. |
# | **Interaction & Communication** | Join scheduled Q&A sessions, take part in small‑group discussion boards, and request quicker feedback from lecturers. | Increases engagement and reduces the feeling of passivity. |
# | **Learning Environment** | Keep course files organized in clearly labeled folders, use a quiet study space, and check that your device settings match the course requirements. | A tidy, comfortable environment reduces distractions and makes material easier to follow. |
# | **Learning Support** | Look for recorded explanations or step‑by‑step guides posted by the instructor, and ask for concrete examples when instructions are unclear. | Clearer guidance improves understanding and reduces confusion. |
# | **Technical Access** | Use the campus Wi‑Fi or a reliable hotspot when possible, download lecture videos for offline viewing, and keep the university’s tech‑support contact handy. | Reduces interruptions caused by connectivity issues and ensures you can keep up with coursework. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Watch the university’s 15‑minute LMS tutorial video and bookmark the digital‑research guide.
# 2. **Day 3‑5:** Set up a dedicated study folder structure for each course (syllabus, readings, assignments).
# 3. **Day 6‑7:** Join a peer‑study group on the course discussion board; schedule a 30‑minute Q&A slot with the lecturer.
# 4. **Day 8‑10:** Download this week’s lecture recordings for offline study; test your internet connection in a quiet location.
# 5. **Day 11‑14:** Review any unclear assignment instructions, request a concrete example from the lecturer, and note any technical issues to report to tech support.
#
# By focusing on these five areas, you can turn your digital‑skill strength into a solid foundation, improve communication, create a better study environment, get clearer guidance, and overcome technical hurdles. Good luck!

# %% [markdown]
# ## Student ID: `e20230502`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "tech_issue"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 2: Highly Engaged (Active) Learners** profile.
#
# ## 2. Main Strengths
# - Learning Convenience & Effectiveness
#
# ## 3. Main Challenges
# - Internet & Technical Issues
#
# ## 4. Personalized Recommendations
# - **Improve learning effectiveness:** Combine online review materials with in-person explanation, practice, and feedback.
# - **Improve technical access and reliability:** Provide stable internet access, offline materials, clear platform instructions, and technical support.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20240617`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "self_paced", "tech_issue"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 2: Highly Engaged (Active) Learners** profile.
#
# ## 2. Main Strengths
# - Flexibility & Time Management
# - Learning Convenience & Effectiveness
#
# ## 3. Main Challenges
# - Internet & Technical Issues
#
# ## 4. Personalized Recommendations
# - **Improve learning effectiveness:** Combine online review materials with in-person explanation, practice, and feedback.
# - **Support self-paced learning:** Provide recorded lessons, weekly learning paths, and materials students can review at their own pace.
# - **Improve technical access and reliability:** Provide stable internet access, offline materials, clear platform instructions, and technical support.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20241150`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "motivation"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 2: Highly Engaged (Active) Learners** profile.
#
# ## 2. Main Strengths
# - Learning Convenience & Effectiveness
#
# ## 3. Main Challenges
# - Learning Difficulty & Clarity
# - Motivation & Self-Discipline
#
# ## 4. Personalized Recommendations
# - **Improve learning effectiveness:** Combine online review materials with in-person explanation, practice, and feedback.
# - **Improve clarity and learning support:** Provide clearer instructions, examples, recorded explanations, and step-by-step learning guides.
# - **Support motivation and self-discipline:** Use weekly check-ins, reminders, progress tracking, and structured study schedules.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20240725`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation", "tech_issue"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 1: Moderately Engaged (Passive) Learners** profile.
#
# ## 2. Main Strengths
# - Learning Convenience & Effectiveness
#
# ## 3. Main Challenges
# - Internet & Technical Issues
# - Motivation & Self-Discipline
#
# ## 4. Personalized Recommendations
# - **Improve learning effectiveness:** Combine online review materials with in-person explanation, practice, and feedback.
# - **Support motivation and self-discipline:** Use weekly check-ins, reminders, progress tracking, and structured study schedules.
# - **Improve technical access and reliability:** Provide stable internet access, offline materials, clear platform instructions, and technical support.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20250082`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "learning_effectiveness", "learning_support", "motivation", "tech_issue", "workload_support"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 2: Highly Engaged (Active) Learners** profile.
#
# ## 2. Main Strengths
# - Digital Skills Development
# - Learning Convenience & Effectiveness
#
# ## 3. Main Challenges
# - Assessment & Workload
# - Interaction & Communication
# - Internet & Technical Issues
# - Learning Difficulty & Clarity
# - Motivation & Self-Discipline
#
# ## 4. Personalized Recommendations
# - **Develop digital learning skills:** Provide guidance on LMS tools, online resources, digital research, and educational technologies.
# - **Increase interaction and communication:** Add Q&A sessions, group discussion, peer collaboration, and faster lecturer feedback.
# - **Improve learning effectiveness:** Combine online review materials with in-person explanation, practice, and feedback.
# - **Improve clarity and learning support:** Provide clearer instructions, examples, recorded explanations, and step-by-step learning guides.
# - **Support motivation and self-discipline:** Use weekly check-ins, reminders, progress tracking, and structured study schedules.
# - **Improve technical access and reliability:** Provide stable internet access, offline materials, clear platform instructions, and technical support.
# - **Manage workload and assessment pressure:** Balance assignments, clarify deadlines, and align online tasks with in-person sessions.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `M080406`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 2: Highly Engaged (Active) Learners** profile.
#
# ## 2. Main Strengths
# - Access to Learning Materials
# - Flexibility & Time Management
# - Student Engagement
#
# ## 3. Main Challenges
# - Interaction & Communication
# - Internet & Technical Issues
# - Learning Difficulty & Clarity
# - Learning Resources & Environment
# - Motivation & Self-Discipline
#
# ## 4. Personalized Recommendations
# - **Strengthen access to learning materials:** Upload slides, videos, references, exercises, and course materials early.
# - **Increase learner engagement:** Use quizzes, games, practical tasks, discussions, and interactive activities.
# - **Increase interaction and communication:** Add Q&A sessions, group discussion, peer collaboration, and faster lecturer feedback.
# - **Improve learning resources and environment:** Organize materials clearly, update resources, improve study spaces, and support classroom comfort.
# - **Improve clarity and learning support:** Provide clearer instructions, examples, recorded explanations, and step-by-step learning guides.
# - **Support motivation and self-discipline:** Use weekly check-ins, reminders, progress tracking, and structured study schedules.
# - **Support self-paced learning:** Provide recorded lessons, weekly learning paths, and materials students can review at their own pace.
# - **Improve technical access and reliability:** Provide stable internet access, offline materials, clear platform instructions, and technical support.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20220813`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 1: Moderately Engaged (Passive) Learners** profile.
#
# ## 2. Main Strengths
# - Learning Convenience & Effectiveness
#
# ## 3. Main Challenges
# - Interaction & Communication
# - Internet & Technical Issues
#
# ## 4. Personalized Recommendations
# - **Increase interaction and communication:** Add Q&A sessions, group discussion, peer collaboration, and faster lecturer feedback.
# - **Improve learning effectiveness:** Combine online review materials with in-person explanation, practice, and feedback.
# - **Improve technical access and reliability:** Provide stable internet access, offline materials, clear platform instructions, and technical support.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20240294`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 1: Moderately Engaged (Passive) Learners** profile.
#
# ## 2. Main Strengths
# - Flexibility & Time Management
#
# ## 3. Main Challenges
# - Motivation & Self-Discipline
#
# ## 4. Personalized Recommendations
# - **Support motivation and self-discipline:** Use weekly check-ins, reminders, progress tracking, and structured study schedules.
# - **Support self-paced learning:** Provide recorded lessons, weekly learning paths, and materials students can review at their own pace.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20241252`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["engagement", "interaction", "motivation"]`
#
# ---
#
# # Personalized Blended Learning Recommendation Report
#
# ## 1. Student Learning Profile
# The student belongs to the **Cluster 1: Moderately Engaged (Passive) Learners** profile.
#
# ## 2. Main Strengths
# - Student Engagement
#
# ## 3. Main Challenges
# - Interaction & Communication
# - Motivation & Self-Discipline
#
# ## 4. Personalized Recommendations
# - **Increase learner engagement:** Use quizzes, games, practical tasks, discussions, and interactive activities.
# - **Increase interaction and communication:** Add Q&A sessions, group discussion, peer collaboration, and faster lecturer feedback.
# - **Support motivation and self-discipline:** Use weekly check-ins, reminders, progress tracking, and structured study schedules.
#
# ## 5. Short Action Plan
# - Review learning materials regularly.
# - Follow a weekly study schedule.
# - Ask questions during in-person or online sessions.
# - Use available digital resources and recorded lessons for revision.

# %% [markdown]
# ## Student ID: `e20241035`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241035*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Key Themes:**
#   - **Strength:** Flexibility & Time Management (you value “saving time”).
#   - **Challenge:** Motivation & Self‑Discipline (you reported a lack of motivation and poor self‑discipline).
#
# *Because the open‑ended responses were brief, the recommendations below rely primarily on the characteristics of your segment and the tagged needs identified by the system.*
#
# ---
#
# ### 2. Main Strengths
# - **Efficient use of time** – you appreciate learning formats that let you manage your schedule and “save time.”
#
# ---
#
# ### 3. Main Challenges
# - **Motivation** – staying driven to start or continue tasks.
# - **Self‑discipline** – maintaining consistent study habits without external pressure.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Support motivation and self‑discipline** | Build regular habits and keep track of progress so you stay engaged. | • Set up a **weekly check‑in** (e.g., a short 5‑minute reflection or a quick chat with a tutor). <br>• Use **reminders** (calendar alerts or app notifications) for study blocks. <br>• Follow a **structured study schedule** that breaks tasks into small, doable chunks. |
# | **Support self‑paced learning** | Take advantage of resources you can access whenever you have a free moment. | • Watch **recorded lectures** instead of live sessions when it fits your timetable. <br>• Follow the **weekly learning path** provided by the course (a roadmap of what to study each week). <br>• Review **materials** (slides, notes, quizzes) at your own speed, revisiting difficult parts as needed. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Day 1** | Create a simple weekly schedule: allocate 30 min‑1 h slots for each subject. Add calendar reminders. |
# | **Day 2** | Locate the recorded lessons for the upcoming topics and bookmark them. |
# | **Day 3** | Set a recurring **weekly check‑in** (e.g., every Sunday evening) to note what you completed and what needs attention. |
# | **Day 4‑7** | Follow the first week’s learning path, using the recorded lessons and reviewing notes at your own pace. |
# | **Week 2** | Continue the schedule, adjust time blocks if needed, and use the check‑in to celebrate any progress (even small wins). |
# | **End of Week 2** | Review your motivation log: note any patterns (times of day you feel more motivated) and plan the next week’s schedule accordingly. |
#
# ---
#
# **Remember:** Your ability to manage time is a strong asset. By pairing that flexibility with regular check‑ins, reminders, and self‑paced resources, you can boost motivation and build the self‑discipline needed for steady progress. Good luck!

# %% [markdown]
# ## Student ID: `e20250109`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250109*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You describe blended learning as **flexible**, allowing you to review materials anytime and develop digital skills while still interacting with lecturers and classmates. At the same time, you note challenges with **unstable internet**, unclear online instructions, and staying focused during virtual sessions. Your overall sentiment toward both strengths and challenges is positive, indicating you see clear opportunities for improvement.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | Flexibility to review slides, videos, and resources at your own pace. |
# | **Digital Skills Development** | Gaining competence with online tools while still having face‑to‑face contact. |
# | **Flexibility & Time Management** | Ability to learn when it suits you best. |
# | **Student Engagement** | Appreciating the mix of in‑person and online interaction. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Internet & Technical Issues** | Unstable connection hampers participation. |
# | **Learning Difficulty & Clarity** | Online instructions can be unclear. |
# | **Interaction & Communication** | Harder to stay focused and communicate effectively online. |
# | **Motivation & Self‑Discipline** | Maintaining concentration during remote sessions is tough. |
# | **Learning Resources & Environment** | Need for clearer, better‑organized materials. |
#
# ---
#
# ### 4. Personalized Recommendations
# Based on your strengths, challenges, and the “Moderately Engaged (Passive)” segment, the following actions are most relevant:
#
# | Recommendation | Why it matters for you | Practical suggestion |
# |----------------|------------------------|----------------------|
# | **Strengthen access to learning materials** | You value being able to review content anytime. | Lecturers should upload slides, videos, exercises, and reference links **early** in the week. |
# | **Develop digital learning skills** | You are already building digital competence. | Short tutorials on LMS navigation, digital research tools, and effective online note‑taking. |
# | **Increase learner engagement** | Keeping focus online is a challenge. | Include low‑stakes quizzes, interactive polls, or short practical tasks in each online session. |
# | **Increase interaction and communication** | You find it harder to stay connected remotely. | Schedule brief Q&A slots, peer‑discussion boards, and faster feedback on assignments. |
# | **Improve learning resources and environment** | Clear, well‑organized materials help you stay on track. | Use a consistent folder structure, label files clearly, and provide a “quick‑start” guide for each module. |
# | **Improve clarity and learning support** | Unclear instructions reduce confidence. | Provide step‑by‑step guides, example problems, and recorded walkthroughs for complex tasks. |
# | **Support motivation and self‑discipline** | Maintaining self‑discipline is difficult. | Set up weekly check‑ins (e‑mail or short survey), automated reminders, and a personal progress tracker. |
# | **Support self‑paced learning** | Flexibility is a key strength for you. | Offer recorded lectures and a suggested weekly learning path that you can follow at your own speed. |
# | **Improve technical access and reliability** | Internet instability disrupts learning. | Ensure campus Wi‑Fi hotspots in study areas, provide downloadable offline copies of essential materials, and a dedicated tech‑support helpdesk. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | **1** | **Check material availability** – Verify that all slides and videos for the current module are uploaded early. | Look for a “Course Resources” folder on the LMS; if missing, email the lecturer. |
# | **2** | **Boost digital skills** – Complete a 30‑minute LMS tutorial offered by the university’s e‑learning centre. | Register via the student portal; apply one new tip each study session. |
# | **3** | **Create a personal study schedule** – Use the weekly learning path and set specific times for live sessions, review, and quizzes. | Write the schedule in a planner or digital calendar; set reminders. |
# | **4** | **Test technical backup** – Download offline copies of this week’s videos and practice using the campus Wi‑Fi hotspot. | Save files to a USB drive or laptop; note any connectivity issues and report them to IT support. |
#
# By following these steps, you can leverage the flexibility you already appreciate while reducing the technical and motivational hurdles that make blended learning feel passive. Keep track of what works best for you, and feel free to share feedback with your instructors—they can adjust the course design to support you even more. Good luck!

# %% [markdown]
# ## Student ID: `e20123456`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20123456*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to **Cluster 2 – Highly Engaged (Active) Learners**. This segment is characterised by strong motivation to participate in class activities and a willingness to take advantage of digital resources. Because your open‑ended responses did not provide additional details, the recommendations below are drawn primarily from the typical needs of this segment.
#
# ---
#
# ### 2. Main Strengths
# *Not explicitly reported.*
# (Your segment generally shows high engagement and readiness to use digital tools.)
#
# ---
#
# ### 3. Main Challenges
# *Not explicitly reported.*
# (For highly engaged learners, common challenges can include needing timely access to materials and structured self‑paced options.)
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Tag | What to Focus On | How to Apply It |
# |-----|------------------|-----------------|
# | **content_access** | Strengthen access to learning materials | Upload slides, videos, reference links, exercises, and any other course resources **early** in the semester so you can review them whenever needed. |
# | **digital_skill** | Develop digital learning skills | Get short guides or short video tutorials on using the LMS, online libraries, citation tools, and other educational technologies that support your coursework. |
# | **engagement** | Increase learner engagement | Participate in quizzes, gamified activities, practical tasks, and discussion forums. These interactive elements help deepen understanding and keep motivation high. |
# | **self_paced** | Support self‑paced learning | Use recorded lectures and weekly learning paths that let you study at a rhythm that fits your schedule. Review material before class or after lectures to reinforce learning. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Check the course portal for any uploaded slides or videos. If they are missing, ask the instructor to post them early. |
# | **2** | Complete a 15‑minute tutorial on the LMS’s key features (e.g., submitting assignments, accessing discussion boards). |
# | **3** | Join at least one interactive activity (quiz, poll, or group discussion) and note what you found most helpful. |
# | **4** | Create a personal weekly learning schedule using the recorded lessons and set aside time for review and practice exercises. |
#
# By following these steps, you’ll make the most of the blended‑learning environment, keeping your strong engagement while ensuring you have the resources and digital skills needed for success.

# %% [markdown]
# ## Student ID: `e20230006`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment", "learning_support", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230006*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically makes good use of digital resources, participates actively, and prefers a self‑paced structure. Your own comments show that you appreciate having all study materials in one place, but you experience some navigation and feedback issues.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value that the course content is consolidated in a single location, which helps you stay organized.
#
# ---
#
# ### 3. Main Challenges
# - **Navigation** – You would like the course to appear directly on your homepage rather than being mixed with other universities’ content.
# - **Feedback & Interaction** – Teacher feedback on assignments is often missing, and you feel more interaction (Q&A, peer discussion) would support your learning.
# - **Learning Resources & Environment** – You need clearer instructions, extra practice material, and a more organized study space.
# - **Assessment & Workload** – Balancing assignments and understanding deadlines can be stressful.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Ensure that slides, videos, reference links, exercises and any other course material are uploaded **early** and kept in the same folder so you can keep everything “in one place.” |
# | **Interaction** | Request or set up **regular Q&A sessions**, small‑group discussions, and peer‑collaboration activities. Ask lecturers for **faster, more detailed feedback** on assignments. |
# | **Learning Environment** | Work with the course team to **organize materials clearly** (e.g., weekly folders, consistent naming). Suggest improvements to the virtual study space (navigation shortcuts, homepage links) and, if possible, a comfortable physical study area. |
# | **Learning Support** | Ask for **clearer instructions** and concrete examples for each task. Request **recorded explanations** or step‑by‑step guides that you can revisit when needed. |
# | **Workload Support** | Seek a **balanced schedule**: clear deadlines, a preview of upcoming assignments, and alignment between online tasks and in‑person sessions. This will help you manage the workload more predictably. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the current course portal; note where navigation feels confusing. |
# | **Day 3** | Send a brief email to the lecturer asking for a **single‑page link** to the course on your homepage and requesting earlier posting of materials. |
# | **Day 4–5** | Join or propose a **Q&A slot** on the discussion board; post any pending questions about recent assignments. |
# | **Day 6** | Request a **sample feedback** on a past assignment to understand what detail you need. |
# | **Day 7** | Create a personal folder structure that mirrors the course weeks; move all existing files into it. |
# | **Day 8–10** | Ask the instructor for a **recorded walkthrough** of the next assignment’s instructions. |
# | **Day 11** | Draft a short list of **deadline dates** you have so far; share it with classmates to confirm accuracy. |
# | **Day 12–14** | Participate in a **peer‑review** activity (if available) to practice giving and receiving feedback. |
#
# Follow these steps, and keep a quick log of what works well and what still feels unclear. Adjust the plan as needed, and continue to communicate with your lecturers and peers—you’re already an active learner, and these targeted actions will help you get the most out of the blended format.

# %% [markdown]
# ## Student ID: `e20230172`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "learning_environment", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230172*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the ability to revisit video lessons and conduct research at your own pace. Flexibility and easy access to course materials are important to you, and you are comfortable using digital tools. At times, a busy schedule and occasional technical glitches can interrupt your study routine.
#
# ---
#
# ### 2. Main Strengths
# | Strength theme | What you mentioned |
# |----------------|--------------------|
# | **Access to Learning Materials** | You like re‑watching videos and reviewing lessons whenever you have free time. |
# | **Digital Skills Development** | You are comfortable using the LMS and online resources. |
# | **Flexibility & Time Management** | Blended learning lets you fit study into your schedule. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge theme | What you mentioned |
# |-----------------|--------------------|
# | **Motivation & Self‑Discipline** | When you get very busy, you sometimes forget to follow the course. |
# | **Internet & Technical Issues** | Platform updates (e.g., Moodle) can block access, and you would like clearer communication about technical problems. |
# | **Learning Resources & Environment** | You need reliable, well‑organized materials and a stable study environment. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|------------------|
# | **Strengthen access to learning materials** (content_access) | Ensure slides, videos, references and exercises are uploaded early so you can review them anytime. |
# | **Develop digital learning skills** (digital_skill) | Offer short guides or tutorials on LMS tools, online research methods, and other educational technologies you use. |
# | **Improve learning resources and environment** (learning_environment) | Organise course content clearly, keep resources up‑to‑date, and provide tips for creating a comfortable study space. |
# | **Support motivation and self‑discipline** (motivation) | Set up weekly check‑ins, automated reminders, and simple progress‑tracking dashboards to keep you on track when you’re busy. |
# | **Support self‑paced learning** (self_paced) | Provide recorded lessons and weekly learning paths that you can follow at your own speed. |
# | **Improve technical access and reliability** (tech_issue) | Offer offline copies of key materials, clear instructions for platform updates, and a responsive technical‑support contact point. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Review the course’s “Materials Hub” to confirm all slides and videos are uploaded early. | You can start re‑watching content immediately. |
# | 2 | Attend a 15‑minute LMS tutorial (live or recorded) on using bookmarks, download options, and progress tracking. | Faster navigation and better use of digital tools. |
# | 3 | Set a personal study schedule: 2 × 30‑minute blocks per week, with a reminder set in your calendar. Use the weekly check‑in feature to log progress. | Improved self‑discipline and visibility of your learning streak. |
# | 4 | Download offline copies of the week’s videos and readings; test the platform’s update notification system or ask the support team for a contact email. | Reduced impact of technical outages and smoother study flow. |
#
# Feel free to adapt the plan to fit your own timetable—your active engagement is the key driver of success, and these steps are designed to keep your learning smooth, flexible, and well‑supported. Good luck!

# %% [markdown]
# ## Student ID: `e20240100`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240100*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you shared:** You noted that you value more communication and that managing time can be a challenge.
#
# Because the open‑ended responses are brief, the recommendations below rely primarily on the characteristics of the “Highly Engaged (Active) Learners” segment.
#
# ---
#
# ### 2. Main Strengths
# - Strong **student engagement** – you are already active and motivated in learning activities.
# - Interest in **communication**, which supports collaborative work.
#
# ### 3. Main Challenges
# - **Time management** – fitting study tasks into a busy schedule.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How to apply it in a blended setting |
# |----------------|---------------------------------------|
# | **Increase learner engagement** (core recommendation) | • Use short, interactive quizzes after each lecture to reinforce key points.<br>• Incorporate game‑based elements (e.g., leaderboards, badges) for self‑paced modules.<br>• Participate in discussion forums or live chat sessions to keep communication flowing.<br>• Complete practical tasks or mini‑projects that let you apply concepts immediately. |
#
# These activities are designed to keep you actively involved while allowing flexibility to fit them into limited time slots.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action | Time Needed |
# |------|--------|-------------|
# | 1 | Join a course discussion board and post an introduction. | 15 min |
# | 2 | Complete the first interactive quiz after the lecture. | 10 min |
# | 3 | Try a quick game‑based activity (e.g., flashcard challenge). | 10 min |
# | 4 | Finish a short practical task and share your result in the forum. | 20 min |
#
# Repeat the cycle, adjusting the timing to match your schedule. By embedding these engaging, bite‑sized activities, you’ll maintain high involvement without overwhelming your calendar.
#
# ---
#
# **Keep communicating with your instructors and peers**—your strength in communication will help you stay on track and manage your time more effectively. Good luck!

# %% [markdown]
# ## Student ID: `e20241028`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241028*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate having professor‑recorded videos that you can re‑watch, but you face two main hurdles: unreliable internet connection and limited interaction with classmates, which makes studying feel less enjoyable.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You value the ability to review video recordings and other resources.
# - **Digital Skills Development:** You are comfortable using digital content when it is available.
# - **Student Engagement (via media):** Recorded lectures help you stay on track with the course.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Little peer contact reduces motivation and fun.
# - **Internet & Technical Issues:** Unstable connectivity limits your ability to participate fully.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Keep all slides, videos, references, and exercises available early so you can download them when the connection is good. | Look for a “download” option in the LMS; store files on your device or a USB drive for offline study. |
# | **Develop digital learning skills** | Learn the tools that make online study smoother (e.g., LMS navigation, bookmarking, note‑taking apps). | Attend the short “LMS Basics” tutorial offered by the university or watch the quick guide videos posted by your lecturer. |
# | **Increase learner engagement** | Add active elements (quizzes, short games, practical tasks) to keep you motivated while reviewing videos. | After each video, complete the embedded quiz or a quick practice task; set a timer for 5‑minute “challenge” activities. |
# | **Increase interaction and communication** | Create more chances to talk with peers and get faster feedback from the lecturer. | Join the class’s discussion forum or a WhatsApp/Telegram group; schedule a weekly 15‑minute virtual coffee chat with a study buddy. |
# | **Improve technical access and reliability** | Reduce the impact of poor internet by having offline options and clear technical support. | Download all course materials when you have good Wi‑Fi; use the campus’s free Wi‑Fi hotspots or the university’s loan‑out laptops/tablets if needed; keep the tech‑support contact handy for quick help. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Locate the “download” buttons for this week’s lecture slides and videos; save them to your laptop/tablet. |
# | **Day 3** | Watch the 10‑minute “LMS Basics” tutorial and try one new feature (e.g., bookmarking a video). |
# | **Day 5** | Complete the quiz that follows the latest video; note any topics that need clarification. |
# | **Day 7** | Join the class discussion forum (or create a small study‑group chat) and post one question about the week’s material. |
# | **Day 9** | Contact campus IT to ask about offline access options or loan‑out devices if your home internet is still unstable. |
# | **Day 12** | Schedule a 15‑minute virtual meet‑up with a classmate to review the week’s content together. |
# | **Day 14** | Review the downloaded materials, redo the quiz, and note any improvement in confidence or understanding. |
#
# ---
#
# **Remember:** By securing reliable access to materials, sharpening your digital skills, adding interactive elements, and building peer connections, you can turn a passive learning style into a more active and enjoyable experience—even when internet connectivity is a challenge. Good luck!

# %% [markdown]
# ## Student ID: `e20241144`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241144*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you said works well:** You find the current learning set‑up “good” and appreciate its convenience and effectiveness.
# - **What you’d like to improve:** You would like more guidance in choosing which course or skill to study next.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You are comfortable using online resources and get value from them.
#
# ---
#
# ### 3. Main Challenges
# - **Self‑direction in topic selection** – Deciding which course or skill to focus on next is currently unclear.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it fits you | How to apply it |
# |----------------|----------------|-----------------|
# | **Improve learning effectiveness** (rule‑based) | You already use online material successfully; adding focused face‑to‑face elements will deepen understanding and keep you motivated. | • Use online videos, readings, or quizzes as a **review** before class.<br>• Attend short, in‑person sessions where the instructor explains key concepts, guides practice activities, and gives immediate feedback.<br>• Schedule these blended sessions regularly (e.g., weekly or bi‑weekly) for the topics you choose. |
#
# *Because your open‑ended input was brief, this recommendation is also grounded in the typical needs of highly engaged learners in your segment.*
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Pick one upcoming course/skill you’re interested in. Gather the related online review materials (videos, articles, quizzes). |
# | **2** | Attend an in‑person (or live‑online) session that covers the same topic. Take notes and ask questions. |
# | **3** | Complete a short practice exercise and request feedback from the instructor or a peer. |
# | **4** | Reflect on what helped you learn best. Adjust the mix of online review and face‑to‑face practice for the next topic. |
# | **Ongoing** | Repeat the cycle for each new course or skill you decide to study. |
#
# ---
#
# **Keep it simple:** Use the online resources you already trust, then add a brief, interactive face‑to‑face component for explanation, practice, and feedback. This blended approach will boost your learning effectiveness while you continue to choose new subjects that interest you. Good luck!

# %% [markdown]
# ## Student ID: `e20240232`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240232*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** Learners who appreciate efficient use of time and resources but prefer a more structured, low‑interaction environment.
#
# ### 2. Main Strengths
# - **Time‑ and resource‑efficient:** You value quick access to the materials you need.
# - **Access & Convenience:** You feel the current provision of slides, videos, and references works well for you.
#
# ### 3. Main Challenges
# - **User‑interface:** You would like a clearer, easier way to interact with the learning platform.
# - **Learning environment:** Better organization of resources and a comfortable study space would help you stay focused.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Keep the fast, convenient access you already enjoy. | • Upload all slides, videos, readings, and practice exercises **early** in the semester. <br>• Use a single, well‑named folder for each module so you can find items instantly. |
# | **Improve learning effectiveness** (learning_effectiveness) | Pair the online resources you like with brief, in‑person activities that reinforce the content. | • After reviewing a video or slide, attend a short face‑to‑face session for explanation, guided practice, and quick feedback. <br>• Use the session to ask any lingering questions—no need for long discussions. |
# | **Improve learning resources and environment** (learning_environment) | Make the digital and physical study space clearer and more comfortable. | • Organize digital materials with consistent naming and a simple navigation menu. <br>• Ensure the classroom or study area is tidy, well‑lit, and has minimal distractions. <br>• If possible, request updated or additional resources (e.g., better handouts or ergonomic seating). |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Create a master folder for the current course; upload all existing slides, videos, and reference links. |
# | **Day 3–4** | Review the folder structure with a peer or tutor to confirm it’s easy to navigate. |
# | **Day 5** | Schedule a 30‑minute in‑person review session for the first module; bring a list of questions from the online material. |
# | **Day 6–7** | Attend the session, practice a short exercise, and note any feedback. |
# | **Day 8–10** | Refine the digital layout based on the session’s feedback (clear headings, consistent file names). |
# | **Day 11–12** | Assess your study space: declutter, improve lighting, and arrange seating for comfort. |
# | **Day 13–14** | Reflect on the changes: Are materials quicker to find? Does the brief face‑to‑face session help you understand better? Adjust as needed. |
#
# ---
#
# **Remember:** Your strength lies in efficiently accessing quality materials. By pairing that efficiency with brief, focused in‑person practice and a well‑organized learning environment, you’ll boost both understanding and comfort without needing extensive interaction. Good luck!

# %% [markdown]
# ## Student ID: `e20230616`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** e20230616
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# You are identified as a moderately engaged learner who tends to work quietly and prefers a flexible study routine.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to adjust your study schedule as needed.
#
# ---
#
# ### 3. Main Challenges
# - **External interruptions** – Family members often ask you to do chores while you are studying, assuming you have free time.
#
# ---
#
# ### 4. Personalized Recommendations
# **Support self‑paced learning**
# - Access recorded lectures and video lessons so you can watch them whenever you have an uninterrupted moment.
# - Follow a weekly learning path that outlines what to study each day, but allows you to shift tasks to later in the week if chores arise.
# - Keep all reading materials, slides, and practice exercises in a single online folder for easy review at your own speed.
#
# These suggestions are drawn directly from the rule‑based recommendation for the “self‑paced” tag, which matches your segment’s needs.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How it helps |
# |------|--------|--------------|
# | 1 | Download all recorded lessons for the upcoming module and organize them in a personal folder. | Gives you control over when to watch each lesson. |
# | 2 | Create a simple weekly checklist (e.g., “Mon – watch Lecture 1”, “Tue – complete Quiz 1”). | Provides structure while remaining flexible. |
# | 3 | Set a “quiet study window” (e.g., 30 min after dinner) and inform family you’ll be unavailable during that time. | Reduces interruptions from chores. |
# | 4 | Review any missed content during a weekend “catch‑up” session using the recordings. | Ensures you stay on track even if chores shift your schedule. |
#
# By using self‑paced resources and a light, adaptable schedule, you can maintain progress while accommodating family responsibilities. Keep communicating your study needs with your household, and adjust the weekly plan as needed. Good luck!

# %% [markdown]
# ## Student ID: `e20231111`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20231111*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** Learners who appreciate flexibility and can study independently, but who benefit from more interaction, clearer guidance, and balanced workload.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value being able to study from home, which saves money on travel and allows you to manage your time effectively.
#
# ### 3. Main Challenges
# - **Assessment & Workload:** You would like clearer information about assignments and objectives.
# - **Interaction & Communication:** You prefer that teachers record videos and share them, along with assignment details, in the group chat.
# - **Learning Difficulty & Clarity:** You need more explicit instructions and examples to understand the material.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Increase interaction and communication** | Add short Q&A sessions, group discussions, and peer‑collaboration activities; get faster feedback from lecturers. | Join the scheduled live Q&A each week; participate in the class discussion board; ask for feedback on drafts within 48 hours. |
# | **Improve clarity and learning support** | Receive clearer instructions, concrete examples, and step‑by‑step guides; recorded explanations will be available. | Look for the “Guidelines & Examples” folder in the course LMS; watch the short explainer videos before attempting assignments. |
# | **Support self‑paced learning** | Access recorded lessons and weekly learning paths that you can review at any time. | Download the weekly video bundle and follow the suggested learning path; replay any segment that feels unclear. |
# | **Manage workload and assessment pressure** | Assignments will be balanced, deadlines clearly stated, and online tasks aligned with in‑person sessions. | Check the consolidated schedule posted in the group chat; use the calendar reminder for each deadline; flag any overload to the instructor early. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Open the course group chat and locate the “Weekly Schedule & Assignments” post. |
# | **Day 2‑3** | Watch the recorded lecture for this week and note any unclear points. |
# | **Day 4** | Post a question in the Q&A forum about the unclear points; request a brief clarification video if needed. |
# | **Day 5** | Review the provided step‑by‑step guide and example problems for the upcoming assignment. |
# | **Day 6‑7** | Begin the assignment using the guide; schedule a 15‑minute peer‑review session with a classmate. |
# | **Day 8** | Submit a draft for instructor feedback; aim for feedback within 48 hours. |
# | **Day 9‑10** | Adjust the draft based on feedback; confirm the final deadline in the group chat. |
# | **Day 11‑14** | Complete and submit the final assignment; reflect on what support helped you most and note any remaining gaps for the next week. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset. By adding a bit more interaction, clearer resources, and balanced workload cues, you can turn that flexibility into even more effective learning. If any part of the plan feels overwhelming, reach out in the group chat—your instructors are there to help. Good luck!

# %% [markdown]
# ## Student ID: `e20241379`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20241379
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Highly Engaged (Active) Learners” segment. This group typically makes the most of both digital and face‑to‑face resources, values convenience, and seeks effective ways to deepen knowledge.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You appreciate tools that let you study when it fits your schedule and that help you master material quickly.
# - Your open‑ended comment (“we can challenge them self and make more knowledge”) shows a positive attitude toward self‑challenge and knowledge building.
#
# ---
#
# ### 3. Main Challenges
# - You noted **complexity** as a challenge. While you are motivated, some topics may feel too intricate when studied alone.
#
# ---
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness**
# - **Blend online review with in‑person support:** Use short video or reading modules to revisit key concepts on your own, then attend a classroom or live‑online session where the instructor explains the material, guides practice activities, and gives immediate feedback.
# - This mix lets you keep the convenience you like while reducing the feeling of complexity through direct interaction.
#
# ---
#
# ### 5. Short Action Plan
# | Step | What to Do | When |
# |------|------------|------|
# | 1. Choose a core topic you find complex. | Select a chapter or module. | This week |
# | 2. Review the online material. | Watch the video or read the summary (10‑15 min). | Before the next class |
# | 3. Attend a live session (in‑person or virtual). | Participate in the explanation, ask questions, do the practice exercise. | Scheduled class or tutorial |
# | 4. Get feedback. | Review the instructor’s comments or peer feedback on your practice work. | Immediately after the session |
# | 5. Reflect and adjust. | Note what helped reduce complexity and plan the next topic. | End of week |
#
# By repeatedly pairing self‑paced online review with guided, interactive practice, you’ll maintain the convenience you value while making complex material clearer and more manageable. Keep leveraging your high engagement—ask questions, seek feedback, and challenge yourself regularly. Good luck!

# %% [markdown]
# ## Student ID: `e20240289`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240289*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You value having the ability to study on your own and to locate relevant documents, but you have experienced occasional internet/technical problems that can interrupt your study.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You recognize the importance of being able to obtain slides, videos, and reference documents for self‑study.
# - **Learning Convenience & Effectiveness** – You see value in convenient resources that support your learning.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity sometimes hinders your ability to access online content.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** *(content_access)* | Ensure all course resources are available early so you can study independently. | • Look for a central repository where the instructor uploads slides, videos, readings, and practice exercises before class. <br>• Download needed files when you have a stable connection and keep them for offline review. |
# | **Improve learning effectiveness** *(learning_effectiveness)* | Combine the online resources with face‑to‑face explanations and feedback to deepen understanding. | • Attend scheduled in‑person sessions for clarification and practice. <br>• Use the uploaded materials to review before class, then apply concepts during workshops or labs. |
# | **Improve technical access and reliability** *(tech_issue)* | Reduce the impact of internet problems by having offline options and clear technical support. | • When possible, download videos and PDFs ahead of time. <br>• Keep a list of platform guides and contact information for the IT help desk. <br>• If the campus offers Wi‑Fi hotspots or loaner devices, take advantage of them. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the course’s online resource hub; download all available slides, videos, and readings. |
# | **Day 3‑4** | Review the downloaded materials before the next in‑person class; note any questions. |
# | **Day 5** | Attend the class, ask your questions, and complete any in‑class practice activities. |
# | **Day 6‑7** | Check the campus IT portal for offline‑access tips and save the technical support contact. |
# | **Day 8‑10** | If internet issues arise, use the offline files you saved; contact support if problems persist. |
# | **Day 11‑14** | Reflect on what helped you learn best (e.g., reviewing videos first, then class discussion) and adjust your study schedule accordingly. |
#
# By following these steps, you’ll have reliable access to course content, combine online and face‑to‑face learning for better understanding, and minimize disruptions caused by technical issues. Good luck, and remember that the resources are there to support your self‑directed study!

# %% [markdown]
# ## Student ID: `e20241023`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_effectiveness", "learning_environment", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241023*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You prefer a mix of online video recordings and face‑to‑face sessions with lecturers. You value having the learning materials available early, but you would like clearer explanations and richer resources both online and in the physical classroom.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You already make good use of video recordings and self‑study resources.
# - **Digital Skills Development** – Comfortable navigating online content.
# - **Learning Convenience & Effectiveness** – Appreciate the flexibility that blended formats give you.
# - **Student Engagement** – You are open to engaging with the material when it is well‑structured.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – Need more detailed explanations and step‑by‑step guidance.
# - **Learning Resources & Environment** – Would benefit from better‑organized materials and a more supportive study space (both online and on‑campus).
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on the rule‑based recommendations) |
# |------|------------------------------------------------------|
# | **Content Access** | Ask your instructors to upload slides, videos, reference links, exercises, and any other course files **well before** class starts. |
# | **Digital Skills** | Use short tutorials on the LMS (how to download files, join webinars, use discussion boards) and explore recommended digital research tools. |
# | **Engagement** | Participate in low‑stakes quizzes, quick polls, or short discussion posts that accompany the video material. These activities help keep the material active in your mind. |
# | **Learning Effectiveness** | Combine the recorded videos with the in‑person sessions: review the video first, then use class time for explanations, practice problems, and immediate feedback. |
# | **Learning Environment** | Keep a personal folder (digital or paper) where you store all course assets in a clear order (e.g., week 1 → week 2). If possible, choose a quiet study spot on campus that is comfortable and well‑lit. |
# | **Learning Support** | Look for recorded “walk‑through” videos or step‑by‑step guides that break down complex concepts. When instructions are unclear, ask the lecturer for a brief example or clarification. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s LMS page and download all available slides, videos, and exercise files for the upcoming week. Save them in a folder named “Course – Week X”. |
# | **Day 3** | Watch the video lecture once, taking brief notes. Mark any parts that feel unclear. |
# | **Day 4** | Attend the face‑to‑face session. Use the class time to ask for clarification on the marked points and do a quick practice problem. |
# | **Day 5** | Complete a short quiz or poll (if provided) to test your understanding. |
# | **Day 6** | Review the quiz results; re‑watch the specific video segment that needs more explanation. |
# | **Day 7** | Spend 30 minutes organizing your notes and resources, adding any new links or examples shared in class. |
# | **Week 2** | Repeat the cycle, adding one new digital‑skill tip each week (e.g., how to use a citation manager or a research database). |
#
# ---
#
# **Remember:** Your blended learning experience works best when you combine early access to clear, well‑organized materials with active participation in both online and in‑person activities. Use the steps above to turn the resources into deeper understanding and smoother study sessions. Good luck!

# %% [markdown]
# ## Student ID: `e20240055`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240055*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** You keep a good work‑life balance and prefer clear, step‑by‑step guidance. You benefit from learning resources that are well‑organized and allow you to study at your own pace.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You are able to balance study with other responsibilities, which is a solid foundation for self‑paced learning.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity:** You would like a detailed roadmap for each semester, with suggestions on how to study each lesson.
# - **Learning Resources & Environment:** You prefer slower‑paced online videos that explain concepts thoroughly, along with complete solutions and explanations for practice problems.
#
# ### 4. Personalized Recommendations
#
# | Recommendation Area | What It Means for You | How to Use It |
# |---------------------|-----------------------|---------------|
# | **Learning Environment** | Organize course materials so you can see exactly what to study and in what order. Ensure the study space (both physical and digital) is comfortable and free of distractions. | • Use the course’s syllabus or a semester‑wide checklist provided by the instructor.<br>• Keep a digital folder (e.g., in Google Drive) where each week’s resources are stored in the correct sequence. |
# | **Learning Support** | Receive clearer instructions, more examples, and step‑by‑step guides for each topic. Recorded explanations and detailed solution walkthroughs will help you understand the material without having to “guess” the answer. | • Watch the instructor‑recorded videos that break down concepts slowly.<br>• Refer to the provided solution guides after attempting practice problems.<br>• Ask the teaching assistant for a brief “how‑to‑study” tip sheet for each module. |
# | **Self‑Paced Learning** | Access recorded lessons and weekly learning paths that let you review content as often as needed, fitting study sessions into your existing schedule. | • Follow the weekly learning path (e.g., “Monday: video 1, Wednesday: practice set, Friday: review notes”).<br>• Re‑watch any video segment that feels unclear before moving on.<br>• Use the platform’s pause/rewind features to control the pace. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Locate the semester syllabus or ask the instructor for a “roadmap” that lists topics in order. | Clear view of what to study and when. |
# | 1 | Set up a dedicated digital folder and label sub‑folders by week/module. | Organized resources that are easy to find. |
# | 2 | Watch the first two recorded lessons at a slower speed (1.25×) and take notes on each step. | Better grasp of concepts and a personal reference. |
# | 2 | Complete the associated practice problems, then compare your answers with the provided solution explanations. | Reinforced learning and clarified any misunderstandings. |
# | Ongoing | Follow the weekly learning path, revisiting any video or solution that still feels fuzzy before proceeding. | Consistent progress while maintaining your work‑life balance. |
#
# ---
#
# **Remember:** Your ability to manage time is a strong asset. By using clearly organized materials, detailed video explanations, and self‑paced study paths, you can turn passive engagement into confident, active learning. If you need additional support, reach out to your course’s teaching assistant or learning support centre—they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `e20210000`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_effectiveness", "learning_environment", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210000*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You appreciate the **flexibility** that blended learning offers: online delivery of foundational theory lets you study at your own pace, pause, and review, while face‑to‑face time is saved for active discussion, labs, and collaborative problem‑solving.
# Your main concern is the **risk of a double workload** when online modules feel like an extra burden and when the digital platform is inconsistent across courses.
#
# ---
#
# ### 2. Main Strengths
# - **Access & Flexibility:** You value being able to retrieve slides, videos, and other resources whenever you need them.
# - **Learning Convenience:** The “best‑of‑both‑worlds” mix helps you manage time and stay engaged.
#
# ---
#
# ### 3. Main Challenges
# - **Workload Management:** Online content sometimes feels redundant and adds pressure.
# - **Technical & Platform Issues:** Navigating different digital layouts creates frustration and takes time away from learning.
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation follows the rule‑based tags identified for you.)
#
# | Tag | What to Do | Why It Helps |
# |-----|------------|--------------|
# | **content_access** | Upload slides, videos, references, exercises, and other course materials **early** in the semester. | Gives you the resources you need to study independently and reduces last‑minute searching. |
# | **engagement** | Include short quizzes, interactive games, practical tasks, and discussion prompts within the online modules. | Keeps you actively involved and makes the online portion feel purposeful rather than extra work. |
# | **interaction** | Schedule regular Q&A sessions, small‑group discussions, and peer‑collaboration activities; aim for quicker lecturer feedback. | Improves communication and helps you clarify doubts before the face‑to‑face class. |
# | **learning_effectiveness** | Pair each online review material with an in‑person session that expands on the concepts through practice and feedback. | Reinforces learning and shows the clear link between online and classroom work. |
# | **learning_environment** | Organise all materials in a clear folder structure, keep resources up‑to‑date, and ensure classroom spaces are comfortable for collaborative work. | Reduces the time spent searching for files and creates a smoother transition between online and offline study. |
# | **self_paced** | Provide recorded lectures and a weekly learning path that outlines what to study before each class. | Supports your preferred pace and lets you plan your study schedule efficiently. |
# | **tech_issue** | Offer clear, step‑by‑step platform guides, offline copies of essential content, and a reliable technical‑support contact. | Minimises technical frustrations and keeps your focus on learning. |
# | **workload_support** | Align online tasks directly with upcoming in‑person activities, clarify deadlines, and balance the number of assignments across weeks. | Prevents the feeling of “double workload” and makes the blended format feel integrated. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Review the **weekly learning path** and watch the recorded introductory lecture. | Clear roadmap; start self‑paced study. |
# | 2 | Complete the first **online quiz** and post any questions in the scheduled Q&A forum. | Immediate feedback; identify gaps early. |
# | 3 | Join a **small‑group discussion** on the week’s topic; share a brief summary of what you reviewed online. | Strengthen interaction and deepen understanding. |
# | 4 | Meet with the lecturer (or TA) for a quick **feedback session** on the first assignment; note any workload concerns. | Align online tasks with classroom work; adjust pacing if needed. |
#
# ---
#
# **Remember:** Your strengths in flexibility and access are valuable assets. By using the steps above, you can turn the challenges of workload and technical navigation into smoother, more integrated learning experiences. If you need additional support, reach out to your course’s technical help desk or academic advisor. Good luck!

# %% [markdown]
# ## Student ID: `e20240483`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "learning_support", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240483*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** You make good use of the convenience of online materials, but you prefer more guidance and interaction to turn that convenience into deeper understanding.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate that class resources are easy to reach and useful for review.
# - **Learning Convenience & Effectiveness** – The ability to study at your own pace helps you stay on track.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You need more concrete examples because online class time feels too short for practice.
# - **Interaction & Communication** – Limited opportunities to ask questions or receive quick feedback make it harder to grasp concepts.
# - **Assessment & Workload** – The current workload and assessment timing feel rushed.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload slides, videos, reference links, exercises, and any other course materials **early** in the week so you can review them before class. |
# | **Interaction** | Add short **Q&A or live chat sessions**, small‑group discussions, and peer‑collaboration activities. Request faster feedback from the lecturer after you submit work. |
# | **Learning Effectiveness** | Pair the online review materials with **in‑person explanations** and guided practice. Use the uploaded resources to prepare questions for class. |
# | **Learning Support** | Provide **clearer instructions** and **step‑by‑step guides** for assignments. Include recorded examples that walk through problem‑solving processes. |
# | **Workload Support** | Work with the instructor to **balance assignment volume**, clarify deadlines, and ensure that online tasks directly support what is covered in face‑to‑face sessions. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How to Implement |
# |------|--------|-------------------|
# | 1 | **Check material availability** – Log into the course platform on Monday and verify that slides, videos, and exercises are posted at least 2 days before the first class. | Set a calendar reminder to review them before class. |
# | 1 | **Schedule a Q&A** – Ask the lecturer to hold a 15‑minute live Q&A after the first lecture. | Prepare 2–3 questions from the pre‑reviewed material. |
# | 2 | **Use an example guide** – Follow a recorded step‑by‑step example for the next assignment and note any unclear steps. | Share your notes in the discussion forum for peer feedback. |
# | 2 | **Clarify deadlines** – Request a written list of upcoming deadlines and the expected workload for the next module. | Keep this list in a notebook or digital planner. |
#
# ---
#
# **Remember:** Your strength lies in accessing materials conveniently. By adding more interaction, clearer examples, and balanced workload, you can turn that convenience into deeper, more confident learning. If you need further help, reach out to your lecturer or the student support team. Good luck!

# %% [markdown]
# ## Student ID: `e20230383`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230383*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are part of a group that typically shows strong motivation and takes an active role in learning activities.
#
# ### 2. Main Strengths
# - Your open‑ended response did not specify particular strengths, and the sentiment analysis was slightly negative.
# - Because the information is limited, this report draws mainly on the characteristics of the “Highly Engaged” segment, which usually includes good participation and willingness to interact with course material.
#
# ### 3. Main Challenges
# - You indicated a challenge related to **“record video.”**
# - The theme identified is **Learning Resources & Environment**, suggesting that the current study setting or material organization may be hindering your ability to create video content effectively.
#
# ### 4. Personalized Recommendations
# **Improve Learning Resources and Environment**
# - **Organise materials clearly:** Keep lecture notes, readings, and assignment files in well‑named folders (e.g., by week or topic) on your cloud drive or learning platform.
# - **Update resources:** Use the latest versions of textbooks, articles, or software tools recommended by the instructor.
# - **Enhance your study space:** Choose a quiet, well‑lit area with a comfortable chair and a stable surface for recording. Reduce background noise and visual distractions.
# - **Support classroom comfort:** If you record in a campus room, check that the lighting and acoustics are suitable; consider using a simple external microphone or headset for clearer audio.
#
# These steps align with the rule‑based recommendation for the **learning_environment** tag and will help you produce higher‑quality video assignments and feel more confident in your study setting.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action | Expected Outcome |
# |-----|--------|------------------|
# | 1–2 | Create a dedicated folder structure for the course (e.g., “Week 1 – Lectures,” “Assignments”). | Faster access to needed files. |
# | 3–4 | Review the syllabus and list any outdated resources; replace them with the latest links or editions. | Up‑to‑date study material. |
# | 5–6 | Set up a quiet, well‑lit corner at home or book a campus study room; test lighting and sound. | Comfortable recording environment. |
# | 7   | Record a short test video (1‑2 min) using your chosen space and equipment. | Identify any remaining technical issues. |
# | 8–10| Adjust the space (add a lamp, reposition microphone) based on the test video review. | Improved video and audio quality. |
# | 11–14| Apply the organised resources and improved environment to your next assignment or class activity. | smoother workflow and higher‑quality submissions. |
#
# ---
#
# **Remember:** As a highly engaged learner, you already have the motivation to succeed. By fine‑tuning your learning environment, you’ll be able to translate that engagement into even better performance, especially when creating video work. Good luck!

# %% [markdown]
# ## Student ID: `e20220185`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220185*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Flexibility that helps you manage your commute and time.
#
# ### 2. Main Strengths
# - You appreciate the flexibility that blended formats give you, especially when it eases travel and scheduling.
#
# ### 3. Main Challenges
# - You indicated that the current experience is already great, so no specific challenges were reported.
#
# ### 4. Personalized Recommendations
# Because you are a highly engaged learner who benefits from flexibility, the primary recommendation is to **support self‑paced learning**:
#
# - **Recorded lessons** – Access video or audio recordings of lectures whenever it fits your schedule.
# - **Weekly learning paths** – Follow short, structured outlines that guide you through the week’s content at your own speed.
# - **Reusable materials** – Keep notes, slides, and practice activities that you can review as needed.
#
# These options let you study during commute times or whenever you feel most focused, while still staying connected to the course.
#
# ### 5. Short Action Plan
#
# | Week | Action | How it helps you |
# |------|--------|------------------|
# | 1 | Locate the recorded lectures for your first module in the LMS. | Watch or listen during your commute or free moments. |
# | 2 | Follow the weekly learning path provided by the instructor. | Keeps you on track without fixed class times. |
# | 3 | Save key slides and practice quizzes for later review. | Reinforces learning and lets you revisit tough topics. |
# | Ongoing | Set a personal “study window” (e.g., 30 min after class or during travel). | Consistent, self‑paced study fits your active schedule. |
#
# ---
#
# **Remember:** Your strong engagement and need for flexibility are best met by taking advantage of self‑paced resources. Use the recorded content and weekly guides to keep learning on your terms while staying fully involved in the course.

# %% [markdown]
# ## Student ID: `e20211474`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211474*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You describe your learning experience as **easy and flexible**, and you value a course format that blends theory with hands‑on practice (as you experience on DataCamp). Your comments do not highlight strong negative feelings, but you note occasional **technical or internet issues** and a desire for clearer guidance.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when it suits you.
# - **Learning Convenience & Effectiveness** – You find the current mix of theory and practice helpful.
#
# ---
#
# ### 3. Main Challenges
# - **Technical/Internet Reliability** – Unstable connections can disrupt learning.
# - **Clarity & Support** – You would like more explicit instructions and examples to deepen understanding.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Improve learning effectiveness** | Pair the online review materials you already use with short, in‑person (or live‑online) sessions where concepts are explained, practiced, and you receive feedback. | Attend weekly tutorial labs or virtual office hours that focus on applying the theory you study on DataCamp. |
# | **Improve clarity and learning support** | Get clearer step‑by‑step guides, recorded explanations, and concrete examples that match the tasks you do. | Use the course’s supplemental guides and video walkthroughs; ask the instructor for annotated examples when a concept feels fuzzy. |
# | **Support self‑paced learning** | Keep the flexibility you value while having a structured path you can follow at your own speed. | Follow the weekly learning path provided, and revisit recorded lessons whenever you need a refresher. |
# | **Improve technical access and reliability** | Reduce interruptions caused by internet or platform issues. | Download offline versions of key materials when possible, and contact the technical support team early if you experience connectivity problems. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Review the weekly learning path and download any offline resources you can. |
# | **2** | Attend a live tutorial or office‑hour session to practice a concept you studied online; ask for a concrete example. |
# | **3** | Test the platform’s offline mode and note any technical hiccups; submit a support ticket if needed. |
# | **4** | Reflect on the clarity of the instructions you received; request a step‑by‑step guide for any remaining unclear topics. |
#
# By combining your strong engagement with targeted support and reliable technical access, you can keep learning flexibly while deepening your understanding and performance. Good luck, and keep leveraging both the online and face‑to‑face resources available to you!

# %% [markdown]
# ## Student ID: `e20240269`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["engagement", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240269*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you’ve shared:** You appreciate the **flexibility** of your studies and feel you are generally more engaged when you can manage your time. You also note that you sometimes **lose track of time** and get **distracted by digital media**.
#
# ---
#
# ### 2. Main Strengths
# | Strength theme | Evidence |
# |----------------|----------|
# | **Flexibility & Time Management** | “flexibility and better engagement” |
# | **Student Engagement** | Positive sentiment (strength compound = 0.8074) |
#
# ---
#
# ### 3. Main Challenges
# | Challenge theme | Evidence |
# |-----------------|----------|
# | **Learning Difficulty & Clarity** | “lost track of time and addicted to digital media” (negative sentiment, challenge compound = ‑0.3182) |
# | **Motivation & Self‑Discipline** | Same open‑ended comment reflects difficulty staying focused |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How it helps you | Practical actions you can try |
# |----------------|------------------|--------------------------------|
# | **Increase learner engagement** | Makes study sessions more interactive, helping you stay focused and reduce “digital‑media” drift. | • Use short quizzes or game‑based reviews after each topic.<br>• Join discussion boards or small‑group chats for practical tasks. |
# | **Improve clarity and learning support** | Clear instructions and examples reduce confusion that can cause you to lose track of time. | • Watch recorded explanations before attempting assignments.<br>• Follow step‑by‑step guides provided for each module. |
# | **Support motivation and self‑discipline** | Structured check‑ins and progress tracking keep you accountable. | • Set a weekly study schedule with specific goals.<br>• Use the platform’s reminder feature and log your progress each Friday. |
# | **Support self‑paced learning** | Gives you the freedom to review material when you need it, matching your preference for flexibility. | • Access recorded lessons anytime.<br>• Follow the weekly learning path but pause/review sections as required. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a **weekly study schedule** (2‑hour blocks) and set calendar reminders. |
# | **Tuesday** | Watch the **recorded overview** for the upcoming module; take notes on key steps. |
# | **Wednesday** | Complete a **quick quiz** on Tuesday’s material; discuss one question in the forum. |
# | **Thursday** | Review any unclear concepts using the **step‑by‑step guide**; note questions. |
# | **Friday** | Do a **progress check‑in**: mark completed tasks, adjust next week’s schedule, and set a reminder for next Monday. |
# | **Weekend** | Optional: Play an **educational game** related to the week’s topic for 15‑20 minutes to reinforce learning. |
#
# Repeat the cycle, tweaking the schedule as you discover what timing and activities keep you most engaged.
#
# ---
#
# **Remember:** Your flexibility is a strong asset. By adding a bit of structure, interactive elements, and clear resources, you can turn passive moments into active learning and stay on track with your goals. Good luck!

# %% [markdown]
# ## Student ID: `e20211152`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211152*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits of this segment:** strong motivation, frequent interaction with learning materials, and a preference for flexible, self‑paced study options.
#
# ### 2. Main Strengths
# - Values **learning convenience and effectiveness** – you appreciate being able to spend more time on self‑directed learning experiences.
#
# ### 3. Main Challenges
# - You see a need to **design an interactive and useful curriculum** that keeps your learning active and relevant.
#
# ### 4. Personalized Recommendations
# Based on the “learning_effectiveness” tag that matches both your strengths and the challenge you identified, the following blended‑learning approach is recommended:
#
# - **Combine online review materials with in‑person sessions** that include clear explanations, guided practice, and timely feedback.
#   - *Why it helps:* Online resources let you review concepts at your own pace, while face‑to‑face time reinforces understanding through active practice and personalized feedback, boosting overall learning effectiveness.
#
# ### 5. Short Action Plan
#
# | Week | Action | How it supports you |
# |------|--------|---------------------|
# | 1–2 | Select concise video or reading modules for each upcoming topic. | Gives you the convenience to study when you choose. |
# | 3–4 | Attend a short in‑person workshop or tutorial for the same topics. | Allows you to ask questions, practice skills, and receive feedback. |
# | 5–6 | Use a quick online quiz to self‑check understanding, then meet with a tutor or peer group to discuss any errors. | Reinforces learning and makes the curriculum more interactive. |
# | Ongoing | Keep a brief log of what you reviewed online and what you practiced in person. | Helps you see progress and adjust your study rhythm. |
#
# ---
#
# **Remember:** Your high engagement level makes you well‑suited to a blended model that mixes self‑paced online review with active, feedback‑rich classroom time. Using this mix will strengthen your learning effectiveness and keep the curriculum lively and useful. Good luck!

# %% [markdown]
# ## Student ID: `e20230120`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230120
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Values flexibility and can manage time well, especially when learning resources are conveniently located (e.g., “convenient place and research”).
#
# **Main Challenges**
# - Experiences low connection with peers and feels hesitant to ask questions.
# - Reports internet and technical difficulties that hinder smooth participation.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** | Access recorded lessons, weekly learning paths, and downloadable materials so you can study when it fits your schedule. | • Log into the course portal each week to download the week’s video and notes.<br>• Review the recordings at your own pace before live sessions. |
# | **Improve technical access and reliability** | Ensure you have a stable connection and clear guidance on using the platform, plus offline options when needed. | • Use the campus Wi‑Fi or a reliable hotspot for live activities.<br>• Download lecture videos and PDFs in advance for offline study.<br>• Keep the technical‑support contact info handy for quick help. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Set up a weekly routine** – Every Monday, download that week’s recorded lecture and materials. Schedule 2‑3 hours of review time that fits your other commitments.
# 2. **Test your internet** – Run a speed test before your first live session. If the connection is unstable, arrange to use campus Wi‑Fi or a nearby library hotspot.
# 3. **Create a backup** – Save all videos and PDFs to a cloud folder or USB drive so you can study offline if the connection drops.
# 4. **Reach out for help** – If you encounter any technical issue, contact the provided tech‑support line within 24 hours; keep a note of the ticket number for follow‑up.
#
# By following this plan, you’ll be able to keep learning at a pace that works for you while minimizing technical disruptions. If you need further assistance, your course mentor is available for brief check‑ins. Good luck!

# %% [markdown]
# ## Student ID: `e20240925`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20240925
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You describe yourself as good at **time‑management** and eager for **self‑improvement**. You would also like to be able to **access lessons before a semester starts**. Overall, you are a highly engaged learner who values flexibility and effectiveness in your study routine.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you organise your schedule well and can adapt to different learning formats.
# - **Learning Convenience & Effectiveness** – you seek ways to make study time productive and meaningful.
#
# ---
#
# ### 3. Main Challenges
# - **Early Access to Lessons** – you would benefit from having course materials available ahead of the official semester start.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Improve learning effectiveness** | Pair the online review materials you already use with in‑person explanations, practice activities, and feedback sessions. | Combining digital content with face‑to‑face interaction deepens understanding and lets you apply what you’ve reviewed. |
# | **Support self‑paced learning** | Use recorded lectures, weekly learning paths, and downloadable resources that you can revisit anytime, especially before the semester begins. | This gives you the early access you want and lets you study at the speed that fits your schedule. |
#
# Both suggestions align with the **“learning_effectiveness”** and **“self_paced”** tags identified for you.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1** | Locate any recorded lectures or preview materials for the upcoming course (ask the instructor or check the LMS). |
# | **Week 1** | Create a simple weekly learning path: list topics, allocate 1–2 hours per topic, and schedule short practice sessions. |
# | **Week 2** | Attend the first in‑person class or tutorial; bring specific questions from your online review to get targeted feedback. |
# | **Week 2** | Review the feedback, adjust your learning path, and note any gaps to revisit with the recorded material. |
#
# By blending your strong time‑management skills with these structured, self‑paced resources and in‑person support, you’ll maximize both convenience and learning effectiveness. Keep tracking your progress, and feel free to adjust the plan as you discover what works best for you.

# %% [markdown]
# ## Student ID: `e20241404`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241404
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate the flexibility of blended learning, the ability to study at your own pace, and the wide range of digital resources that make learning more convenient and effective.
#
# **Main Challenges**
# You notice two key issues:
# 1. **Technical & Internet problems** that can interrupt online work.
# 2. **Limited interaction** with lecturers and a need for clearer instructions and more engaging online activities.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** in the semester. | Gives you reliable material to review whenever you need it, supporting your self‑paced study. |
# | **Digital Skills** | Offer short guides or workshops on using the LMS, searching digital libraries, and applying educational tech tools. | Strengthens the digital abilities you already value and reduces frustration with online platforms. |
# | **Interaction** | Add scheduled Q&A sessions, small‑group discussions, and peer‑collaboration tasks; encourage faster lecturer feedback. | Increases the contact you have with instructors and classmates, addressing the interaction gap you mentioned. |
# | **Learning Effectiveness** | Pair online review resources (recorded lessons, quizzes) with in‑person explanations, practice activities, and feedback. | Combines the convenience you like with the hands‑on support that improves understanding. |
# | **Learning Environment** | Organise all materials clearly, keep resources up‑to‑date, and ensure classroom spaces are comfortable and well‑equipped. | Makes it easier to locate what you need and creates a more supportive physical learning setting. |
# | **Learning Support** | Provide clearer written instructions, concrete examples, recorded step‑by‑step guides, and optional tutoring. | Reduces ambiguity and helps you follow tasks without needing constant clarification. |
# | **Self‑Paced Learning** | Supply recorded lectures, weekly learning pathways, and downloadable content that you can access offline. | Lets you study when it fits your schedule and mitigates internet‑related interruptions. |
# | **Technical Issues** | Ensure stable campus Wi‑Fi, offer offline copies of essential files, give clear platform tutorials, and maintain a responsive tech‑support desk. | Directly tackles the connectivity problems you experience. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1 | **Check material availability** – Log into the LMS and verify that slides and videos for the current module are posted early. | If anything is missing, email the lecturer or teaching assistant. |
# | 2 | **Boost digital skills** – Attend a 30‑minute LMS tutorial (often offered by the library or IT services). | Note any features you find useful for note‑taking or bookmarking. |
# | 3 | **Engage in interaction** – Join a scheduled online Q&A or create a study‑group chat for the course. | Prepare one question in advance to make the most of the session. |
# | 4 | **Test technical reliability** – Try downloading key resources for offline use and confirm you have a stable Wi‑Fi spot on campus. | If issues persist, submit a ticket to the tech‑support team. |
#
# By following these steps, you can keep leveraging the flexibility you enjoy while reducing technical hurdles and increasing meaningful interaction with instructors and peers. Good luck, and remember that the university’s support services are there to help you succeed!

# %% [markdown]
# ## Student ID: `e20230393`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230393*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** You benefit from clear, convenient study materials and tend to work well when learning resources are well‑organized.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You appreciate that the current setup saves you time for self‑study, indicating you can manage your learning efficiently when materials are easy to use.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You would like the learning materials to be clearer so more students can understand the lessons.
# - **Learning Resources & Environment** – You hope lectures respond politely to questions and that study spaces and resources are improved.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Pair the online review content you already find convenient with short, in‑person explanations, practice activities, and feedback. | • Before class, watch the recorded review. <br>• During class, ask the instructor to clarify key points and do a quick practice problem. <br>• After class, use the feedback to adjust your self‑study plan. |
# | **Improve learning resources and environment** | Use well‑organized materials and a comfortable study space to reduce confusion. | • Keep a digital folder that groups lecture slides, notes, and practice files by topic. <br>• Choose a quiet, well‑lit spot (library cubicle, study lounge) for reviewing the material. |
# | **Improve clarity and learning support** | Get clearer instructions, examples, and step‑by‑step guides to help you follow the lessons more easily. | • Request recorded explanations or sample problems from the instructor. <br>• Use the provided step‑by‑step guides for each assignment. <br>• If a concept is unclear, post a concise question in the course forum so the lecturer can respond politely and promptly. |
#
# These recommendations are drawn directly from the evidence about your strengths, challenges, and the segment’s typical needs.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Day 1–2** | Create a single folder (e.g., “Course X – Week 1”) and upload all online review PDFs, lecture slides, and any recorded explanations. |
# | **Day 3** | Identify one topic you find unclear. Watch the online review, then attend the next class and ask the lecturer for a brief, concrete example. |
# | **Day 4–5** | Complete a short practice exercise on that topic and request feedback (in‑person or via the LMS). |
# | **Day 6** | Review the feedback, update your notes, and add a step‑by‑step guide you created for future reference. |
# | **Week 2** | Repeat the cycle for a second topic, and experiment with a different study space (e.g., library study room) to see which environment helps you focus best. |
# | **End of Week 2** | Reflect: Which resources, explanations, or environments helped you learn most effectively? Note them for the rest of the term. |
#
# ---
#
# **Keep in mind:** Your ability to save time for self‑study is a strong asset. By pairing that convenience with clearer instructions, organized resources, and brief in‑person support, you’ll turn passive engagement into more active, confident learning. Good luck!

# %% [markdown]
# ## Student ID: `e20221407`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20221407
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You appreciate the **flexibility and time‑saving** aspect of blended learning (e.g., cutting travel time).
#
# **Main Challenges**
# - Occasional **internet or technical problems** sometimes disrupt your study sessions.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** | Access recorded lectures, weekly learning paths, and downloadable materials so you can study whenever it fits your schedule. | • Log into the course portal to download videos and notes.<br>• Follow the weekly learning path at your own speed, pausing or revisiting content as needed. |
# | **Improve technical access and reliability** | Ensure you have stable internet or offline options and clear guidance on using the platform. | • Use the university’s Wi‑Fi hotspots or request a loaner hotspot if needed.<br>• Download course files for offline study.<br>• Keep the technical‑support contact information handy for quick help. |
#
# **Short Action Plan (Next 2 weeks)**
#
# 1. **Set up a weekly learning schedule** – Choose 2‑3 time blocks that suit you and follow the provided weekly path.
# 2. **Download all materials for the first two weeks** – Store them on your laptop or tablet to study offline if the connection drops.
# 3. **Test your internet connection** – Run a speed test; if it’s unstable, contact campus IT for a hotspot or alternative solution.
# 4. **Bookmark technical support resources** – Save the help‑desk email/phone number and the platform’s quick‑start guide for easy reference.
#
# By focusing on self‑paced study and securing reliable technical access, you can make the most of the blended format while minimizing disruptions. Good luck!

# %% [markdown]
# ## Student ID: `e20240407`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20240407
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Highly Engaged (Active) Learners” segment. This group typically makes good use of both online and face‑to‑face activities, enjoys reviewing material before class, and shows strong motivation to participate.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate being able to study course content online before the offline session starts. (Positive sentiment, strength score 0.62)
#
# ### 3. Main Challenges
# - No specific challenges were reported.
#
# ### 4. Personalized Recommendations
# **Strengthen access to learning materials**
# - Ensure that slides, video recordings, reference links, exercises, and any other course resources are uploaded to the learning platform **well in advance of each class**.
# - Use the early‑access materials to preview topics, note questions, and prepare for in‑class activities.
#
# ### 5. Short Action Plan
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1    | Check the course portal daily for new uploads. | Set a reminder for the same time each day. |
# | 2‑3  | Review the pre‑class materials before each offline session. | Highlight key points and write down any questions. |
# | Ongoing | Provide feedback to the instructor if any material is missing or posted late. | Use the platform’s comment or email feature. |
#
# By consistently accessing and reviewing the uploaded content ahead of class, you’ll keep your strong engagement level and make the most of both online and offline learning experiences.

# %% [markdown]
# ## Student ID: `e20210629`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210629*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - Your open‑ended responses did not provide specific strengths or challenges, so the recommendations below are drawn primarily from the characteristics of this segment.
#
# ### 2. Main Strengths
# - Not explicitly reported.
#
# ### 3. Main Challenges
# - Not explicitly reported.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from lecturers. | Increases engagement and helps you stay connected with the course material and classmates. |
# | **Learning Support** | • Look for clearer written instructions and concrete examples.<br>• Use recorded explanations and step‑by‑step guides provided by the instructor. | Improves understanding and reduces uncertainty when working independently. |
# | **Motivation & Self‑Discipline** | • Set up weekly check‑ins (e.g., with a tutor or study buddy).<br>• Use reminders and a simple progress‑tracking tool.<br>• Follow a structured study schedule. | Keeps you on track, builds routine, and boosts confidence in meeting deadlines. |
# | **Self‑Paced Learning** | • Access recorded lessons and review them as needed.<br>• Follow the weekly learning path outlines.<br>• Organise the provided materials for personal review. | Allows you to study at a comfortable speed while still covering all required content. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Time Needed |
# |------|--------|-------------|
# | 1 | Register for the upcoming Q&A session and join a study group on the course platform. | 1 hour |
# | 1 | Download the recorded lecture for this week and read the step‑by‑step guide. | 2 hours |
# | 2 | Set up a weekly check‑in with a peer or tutor (15 min) and create a simple checklist of tasks. | 30 min |
# | 2 | Use the course’s progress tracker to mark completed activities and note any questions for the lecturer. | 15 min |
#
# Follow these steps and adjust as you discover what works best for you. The goal is to make your blended learning experience more interactive, supported, and self‑directed. Good luck!

# %% [markdown]
# ## Student ID: `e20240473`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240473*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Key traits of this segment:** Learners are able to manage their time flexibly but tend to participate less in interactive activities. They benefit from clear structure and opportunities to connect with peers and instructors.
#
# ### 2. Main Strengths
# - **Adaptive study pace** – you are good at adjusting how quickly you work, which supports flexible, self‑paced study.
#
# ### 3. Main Challenges
# - **Interaction & communication** – you would like more timely feedback and greater opportunities to engage with classmates and the lecturer.
#
# ### 4. Personalized Recommendations
#
# | Focus | What the recommendation means for you | Suggested actions |
# |-------|----------------------------------------|-------------------|
# | **Interaction** | Increase opportunities for dialogue and quicker feedback. | • Join scheduled Q&A sessions and small‑group discussions.<br>• Participate in peer‑collaboration activities (e.g., shared documents, study groups).<br>• Request or set up brief feedback windows with the lecturer after assignments. |
# | **Self‑paced learning** | Keep using resources that let you study at your own speed. | • Use recorded lecture videos to review concepts as needed.<br>• Follow the weekly learning path provided in the LMS, which outlines what to study each week.<br>• Keep a personal checklist of materials you can revisit before exams. |
#
# These recommendations come directly from the rule‑based guidance for your segment and the specific strengths and challenges you reported.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Watch the recorded lecture for this week’s topic; note any questions. |
# | **Wednesday** | Attend the live Q&A session; post at least one question in the forum. |
# | **Friday** | Form a small study group (2‑3 peers) to discuss the week’s material; schedule a 30‑minute meeting. |
# | **Next Monday** | Submit any assignment drafts early to receive quicker lecturer feedback. |
# | **Next Wednesday** | Review feedback received; update your personal study checklist. |
# | **Next Friday** | Reflect on how the interaction helped your understanding; adjust the next week’s plan accordingly. |
#
# Stick to this simple cycle: **watch → ask → discuss → get feedback → reflect**. It leverages your strength in self‑paced study while building the interaction you want.
#
# Good luck, and remember that small, regular steps lead to steady progress!

# %% [markdown]
# ## Student ID: `e20240957`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240957*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility of blended learning. You appreciate being able to access materials online at any time, which helps you manage your schedule and develop digital skills. At the same time, you notice occasional technical problems (unstable internet) and occasional unclear online instructions that can affect focus and motivation.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | Ability to review slides, videos, and exercises whenever needed. |
# | **Digital Skills Development** | Gaining independence and competence with online tools. |
# | **Flexibility & Time Management** | Balancing online and face‑to‑face study to fit your timetable. |
# | **Learning Convenience & Effectiveness** | Using online resources to deepen understanding. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you reported |
# |-------|-------------------|
# | **Internet & Technical Issues** | Unstable connection sometimes blocks online class attendance. |
# | **Learning Difficulty & Clarity** | Some online instructions and materials are not clear enough. |
# | **Interaction & Communication** | Less interaction during online sessions, making focus harder. |
# | **Motivation & Self‑Discipline** | Need more structure to stay motivated when studying independently. |
# | **Learning Resources & Environment** | Desire for better‑organized materials and comfortable study spaces. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Lecturers will upload slides, videos, references, and exercises **early** so you can review them before class. |
# | **Develop digital learning skills** (digital_skill) | Short guides on using the LMS, online research tools, and other educational technologies will be provided. |
# | **Increase interaction and communication** (interaction) | Scheduled Q&A sessions, group discussions, and quicker lecturer feedback will give you more opportunities to engage. |
# | **Improve learning effectiveness** (learning_effectiveness) | Online review materials will be paired with in‑person explanations, practice activities, and feedback to deepen understanding. |
# | **Improve learning resources and environment** (learning_environment) | Course pages will be reorganised for clarity, and study‑space recommendations will be shared to create a comfortable learning setting. |
# | **Improve clarity and learning support** (learning_support) | Clearer instructions, step‑by‑step guides, and recorded explanations will be added to each module. |
# | **Support motivation and self‑discipline** (motivation) | Weekly check‑ins, progress trackers, and reminder emails will help you keep a structured study routine. |
# | **Support self‑paced learning** (self_paced) | Recorded lessons and weekly learning paths will let you study at a pace that fits your schedule. |
# | **Improve technical access and reliability** (tech_issue) | The university will offer stable Wi‑Fi hotspots, offline downloadable materials, and a dedicated tech‑support helpdesk. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | What to do |
# |------|--------|------------|
# | **1** | Access early materials | Check the course LMS for uploaded slides and videos before the first lecture. |
# | **2** | Attend a Q&A session | Join the scheduled online Q&A to ask any unclear questions. |
# | **3** | Use the digital‑skill guide | Review the short tutorial on LMS tools and practice using them for assignments. |
# | **4** | Set up a weekly check‑in | Use the provided progress tracker; schedule a 10‑minute self‑review each Friday to note what you’ve mastered and what needs clarification. |
#
# By following these steps, you can keep leveraging your strong engagement while reducing the technical and clarity issues you’ve experienced. Feel free to reach out to your course coordinator or the university’s tech support whenever you need extra help. Good luck, and keep up the great work!

# %% [markdown]
# ## Student ID: `e20220209`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20220209
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - No specific strengths were identified in the open‑ended response.
#
# **Main Challenges**
# - The student highlighted difficulty with internet connectivity and technical access.
#
# **Personalized Recommendations**
# Because the primary challenge reported is a technical one, the recommendation focuses on improving your access to reliable technology:
#
# - **Improve technical access and reliability** – Ensure you have a stable internet connection, use offline learning materials when possible, follow clear platform instructions, and know how to reach technical support quickly.
#
# **Short Action Plan**
#
# | Step | What to Do | How to Do It | When |
# |------|------------|--------------|------|
# | 1 | Check your current internet setup | Test speed, reset router, or contact your ISP | This week |
# | 2 | Arrange backup access | Identify a campus Wi‑Fi spot, library, or a mobile hotspot you can use if home internet fails | This week |
# | 3 | Download offline resources | Before each class, download lecture slides, readings, or videos to your device | Before each session |
# | 4 | Keep support contacts handy | Save the university’s IT help‑desk email/phone and note the steps for common issues | Ongoing |
# | 5 | Review platform guides | Follow any short tutorials the university provides for using the learning platform offline | As needed |
#
# By securing reliable connectivity and having offline options ready, you’ll be able to stay engaged with the blended course material even when internet problems arise. If additional challenges appear, further recommendations can be added later.

# %% [markdown]
# ## Student ID: `e20240514`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240514*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive on flexible, time‑saving learning experiences and are comfortable using digital tools.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate the ability to learn from anywhere in the world and to fit study around your schedule.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable connections and occasional low‑quality video/audio sometimes disrupt your learning.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** | Access recorded lessons, weekly learning paths, and downloadable materials so you can study when your connection is reliable. | • Watch videos at a time that works for you.<br>• Review notes or slides before/after live sessions.<br>• Follow the weekly path to stay on track without pressure. |
# | **Improve technical access and reliability** | Ensure you have stable internet options, offline resources, clear platform guides, and quick tech support. | • Download lecture videos or PDFs when you have good bandwidth.<br>• Use campus Wi‑Fi or a reliable hotspot for live sessions.<br>• Keep the platform’s help desk contact handy for fast assistance. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Identify a reliable internet source (e.g., campus Wi‑Fi, library, or a personal hotspot). |
# | **1‑2** | Download all upcoming lecture recordings and reading materials to your device. |
# | **2‑3** | Follow the weekly learning path: set a personal deadline for each module and check off completed items. |
# | **Ongoing** | If a connection problem occurs, switch to the offline files and contact technical support using the provided help‑desk link. |
# | **End of Month** | Review your progress and note any remaining technical hurdles; adjust your internet solution or reach out for additional support. |
#
# These steps align with your active, highly engaged learning style while addressing the connectivity challenges you reported. Feel free to reach out to your instructor or the support team if you need further assistance. Good luck!

# %% [markdown]
# ## Student ID: `e20231238`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20231238
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Values **flexibility and time‑management** in your study routine.
# - You see blended learning as a way to make studying more convenient and to improve your study skills.
#
# **Main Challenges**
# - You would like lecturers to give **clear, specific announcements** about what to focus on each week.
#
# **Personalized Recommendations**
# Because you belong to the *Moderately Engaged (Passive)* segment and you highlighted the need for flexibility, the primary recommendation is to **support self‑paced learning**:
#
# - **Recorded lessons** – watch them whenever it fits your schedule.
# - **Weekly learning paths** – a short outline of what to study each week, so you know exactly what to focus on.
# - **Reusable materials** – slides, notes, and practice activities that you can revisit as needed.
#
# These resources let you control the pace of your learning while still receiving the clear guidance you asked for from your lecturers.
#
# **Short Action Plan**
#
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1 | Access the recorded lecture for the week and note the key topics. | Gives you a concrete start point without needing to be present live. |
# | 2 | Follow the weekly learning path (provided by the instructor) and mark any unclear points. | Ensures you have the specific announcements you want. |
# | 3 | Review the recorded lecture and accompanying notes before any assessment. | Reinforces material at your own speed, improving study skills. |
# | Ongoing | Use the self‑paced materials to fill gaps or revisit challenging concepts. | Keeps learning flexible and supports continuous improvement. |
#
# By using these self‑paced resources, you can maintain the flexibility you value while receiving the clear, structured guidance you need. Good luck with your studies!

# %% [markdown]
# ## Student ID: `e20241313`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241313*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners who attend classes but tend to be quiet, prefer structured material, and benefit from clear guidance and regular interaction.
#
# *Note:* Your open‑ended responses gave limited detail (“no idea” for strengths and “can’t discuss immediately” for challenges). Therefore, the recommendations below are drawn primarily from the characteristics of your segment.
#
# ---
#
# ### 2. Main Strengths
# - No specific strengths were identified in your response.
#
# ---
#
# ### 3. Main Challenges
# - Difficulty engaging in immediate discussion or asking questions during class.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What the recommendation means for you | Practical actions |
# |-------|----------------------------------------|-------------------|
# | **Interaction** | Increase opportunities to talk, ask questions, and work with peers. | • Join short Q&A or “office‑hour” slots after lectures.<br>• Participate in small‑group discussion boards.<br>• Pair up with a classmate for brief peer‑review sessions. |
# | **Learning Support** | Get clearer instructions and additional examples to reinforce concepts. | • Use the recorded explanations and step‑by‑step guides provided for each topic.<br>• Review the example problems posted by the lecturer before attempting assignments. |
# | **Motivation & Self‑Discipline** | Build routine habits and track progress to stay motivated. | • Set a weekly study schedule (e.g., 2 hours on Monday, 1 hour on Thursday).<br>• Use the course’s progress tracker and set small weekly goals.<br>• Respond to the weekly check‑in email or app reminder. |
# | **Self‑Paced Learning** | Take advantage of materials you can review at your own speed. | • Watch the recorded lessons before class to prepare questions.<br>• Re‑watch any segment that feels unclear, then note down questions for the next Q&A session. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Watch the recorded lecture for this week and write down 2‑3 questions. |
# | **Tuesday** | Post your questions in the course forum; read at least one peer’s comment. |
# | **Wednesday** | Attend the optional Q&A slot (15 min) and ask one of your questions. |
# | **Thursday** | Follow the step‑by‑step guide for the current assignment; complete the first part. |
# | **Friday** | Review your progress in the course tracker; set a goal for next week. |
# | **Weekend** | Spend 30 min revisiting any recorded segment you found difficult. |
#
# Repeat a similar pattern each week, adjusting the schedule as you become more comfortable with the routine.
#
# ---
#
# **You have the tools and support available—using them consistently will help you move from passive participation to more active, confident learning.**

# %% [markdown]
# ## Student ID: `e20221053`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20221053
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You are a strong self‑studier and regularly review course material on your own.
# - You value easy access to learning resources, which helps you study efficiently.
#
# **Main Challenges**
# - Managing your time effectively.
# - Limited internet reliability and occasional technical issues.
# - Difficulty communicating, especially when you have questions or need clarification.
#
# **Personalized Recommendations**
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Content Access** | • Upload slides, videos, reference links, and exercises **early** in the course week. <br>• Make downloadable/offline versions available. | Guarantees you have the materials when you need them, even if internet access is spotty. |
# | **Interaction & Communication** | • Schedule short **Q&A sessions** or virtual office hours. <br>• Use discussion boards or small‑group chats for peer collaboration. <br>• Encourage quicker feedback from lecturers. | Gives you more opportunities to ask questions, reducing the communication gap you experience. |
# | **Learning Effectiveness** | • Pair the online review resources you already use with **in‑person explanations, practice activities, and feedback**. <br>• Use the uploaded materials to prepare before class, then apply concepts during face‑to‑face sessions. | Combines the convenience of self‑study with the depth of guided practice, boosting overall mastery. |
# | **Technical Access** | • Provide clear instructions for the learning platform and how to download offline content. <br>• Offer a **technical support contact** for quick issue resolution. <br>• Where possible, arrange campus Wi‑Fi hotspots or loaner devices. | Reduces interruptions caused by unstable internet and helps you stay on track with your study schedule. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑3:** Check the course portal for any newly uploaded slides or videos; download them for offline use.
# 2. **Day 4‑7:** Join the first scheduled Q&A session; write down at least two questions you have from your self‑study.
# 3. **Day 8‑10:** Attend an in‑person workshop or tutorial that reviews the same topics you studied online; complete the practice exercise and seek feedback.
# 4. **Day 11‑14:** Test the offline materials on a device without internet; note any technical issues and contact the provided support line.
#
# By following these steps, you can keep leveraging your strong self‑study habits while overcoming time, communication, and technical hurdles. Keep up the active engagement—you’re well positioned to succeed!

# %% [markdown]
# ## Student ID: `e20220981`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220981*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can choose how you learn and you value a mix of online and face‑to‑face activities.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You appreciate that blended learning lets you balance online and physical classes to match different preferences.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Managing both online and in‑person sessions on the same day feels hectic.
# - **Learning Difficulty & Clarity:** Switching formats can make it harder to follow instructions and stay clear on what’s expected.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from lecturers. | Increases communication and reduces the feeling of a chaotic schedule. |
# | **Learning Support** | • Look for clearer written instructions and concrete examples.<br>• Use recorded explanations and step‑by‑step guides provided by the course. | Improves clarity when you move between online and physical classes. |
# | **Self‑Paced Learning** | • Access recorded lessons so you can review them when needed.<br>• Follow the weekly learning path and use the downloadable materials at your own speed. | Lets you control the pace, easing the pressure of back‑to‑back class formats. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the challenges you reported.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Watch the recorded lecture for the upcoming topic and note any questions. |
# | **Tuesday** | Attend the live Q&A session; post at least one question in the forum. |
# | **Wednesday** | Join a small‑group discussion (online or in‑person) on the same topic. |
# | **Thursday** | Review the step‑by‑step guide provided for the assignment; compare it with the lecture notes. |
# | **Friday** | Submit any draft work and request feedback from the lecturer within 24 hours. |
# | **Weekend** | Re‑watch any parts of the recorded lesson that were unclear; update your personal weekly learning path. |
#
# Follow this cycle each week, adjusting the timing to fit your class schedule. Consistent use of the interaction opportunities, clear learning resources, and self‑paced materials will help you manage mixed‑mode days more smoothly while keeping your high level of engagement.
#
# ---
#
# *Keep leveraging your flexibility, and use the tools above to turn scheduling challenges into a more organized, supportive learning experience.*

# %% [markdown]
# ## Student ID: `e20240928`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240928*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - The student reports feeling “all good” and “everything is good,” indicating a positive overall experience. Because the open‑ended comments do not highlight specific strengths or challenges, the recommendations below are drawn primarily from the characteristics of the Highly Engaged learner segment.
#
# ### 2. Main Strengths
# - High level of engagement and motivation (typical of this segment).
#
# ### 3. Main Challenges
# - No specific challenges were identified in the student’s own comments.
#
# ### 4. Personalized Recommendations
#
# | Recommendation Tag | What It Means for You | Practical Steps |
# |--------------------|----------------------|-----------------|
# | **content_access** | Make sure you can reach all course materials as soon as they are ready. | • Upload slides, videos, reading lists, and exercises early in the week.<br>• Keep a personal folder (e.g., cloud drive) where you store all downloaded resources for quick reference. |
# | **digital_skill** | Strengthen your ability to use the LMS and other online tools. | • Attend a short tutorial on LMS navigation, discussion boards, and file‑sharing features.<br>• Explore digital research tools (e.g., citation managers, academic databases) and practice using them for assignments. |
# | **engagement** | Keep your active participation high with varied interactive activities. | • Participate in quizzes, polls, or gamified tasks that the instructor posts.<br>• Join discussion threads and share practical examples from your experience.<br>• Volunteer for short group or hands‑on tasks during live sessions. |
# | **self_paced** | Take advantage of the flexibility to review material on your own schedule. | • Use recorded lectures to revisit complex topics.<br>• Follow the weekly learning path provided by the instructor, but feel free to adjust the pace if you need extra review time.<br>• Set personal milestones (e.g., “finish video 3 by Tuesday”) and track them in a planner or digital app. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Goal |
# |------|--------|------|
# | **1** | Check that all lecture slides and videos are uploaded to the LMS by Monday. | Ensure immediate access to content. |
# |      | Complete the LMS “Getting Started” tutorial (15 min). | Boost digital confidence. |
# |      | Join one discussion forum and post a comment related to the current topic. | Maintain high engagement. |
# | **2** | Watch a recorded lesson you missed and take brief notes. | Practice self‑paced review. |
# |      | Use a citation manager to organize sources for your next assignment. | Apply digital‑skill development. |
# |      | Participate in the weekly quiz and aim for at least 80 % correct. | Reinforce engagement through interactive assessment. |
#
# ---
#
# **Remember:** Your strong engagement is a valuable asset. By ensuring timely access to materials, sharpening your digital toolkit, staying actively involved, and using self‑paced resources, you’ll keep building on that momentum and achieve even better results. Good luck!

# %% [markdown]
# ## Student ID: `e20240981`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240981*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key themes:** Strong engagement in class activities; seeks better communication.
# - **Current challenge:** Maintaining motivation and self‑discipline.
#
# ### 2. Main Strengths
# - **Better communication** – you actively participate and connect well with peers and instructors.
# - **High engagement** – you enjoy interactive and practical learning experiences.
#
# ### 3. Main Challenges
# - **Motivation & self‑discipline** – you find it sometimes difficult to stay consistently motivated and manage study time.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | How It Helps |
# |-------|-------------|--------------|
# | **Engagement** | Incorporate quizzes, games, practical tasks, discussions, and other interactive activities into your study routine. | Keeps learning lively and leverages your natural enthusiasm, reinforcing the material you already enjoy. |
# | **Motivation** | Set up weekly check‑ins (with yourself or a study buddy), use reminders, track your progress, and create a structured study schedule. | Provides clear milestones and accountability, helping you sustain motivation and self‑discipline over time. |
#
# ### 5. Short Action Plan
#
# | Week | Action | Tool/Resource |
# |------|--------|----------------|
# | 1 | Choose one interactive activity (e.g., a short quiz or discussion forum) for each lecture you attend. | LMS quiz module, discussion boards |
# | 2 | Create a simple weekly study schedule (30 min‑1 hr blocks) and add calendar reminders. | Google Calendar or university planner |
# | 3 | Start a progress‑tracking sheet (e.g., checklist of completed tasks, quiz scores). | Google Sheets or a habit‑tracking app |
# | 4 | Arrange a 15‑minute check‑in with a peer or tutor to review your schedule and progress. | Virtual meeting or campus study group |
#
# Follow these steps for the next month and adjust as needed. By pairing your natural engagement with structured motivation tools, you’ll be able to sustain high performance throughout your blended courses. Good luck!

# %% [markdown]
# ## Student ID: `e20240103`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240103*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and keep up with lessons even when you miss class time.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You are good at following the lesson when you can obtain the slides, videos, and other resources.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** The cost of internet makes it difficult to stay connected reliably.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | The instructor will upload slides, videos, references, exercises, and any other course content **early** in the week. | Having the materials ahead of time lets you review them offline or at a time when your internet connection is cheaper or more stable. |
# | **Improve technical access and reliability** | The course will provide **offline versions** of key resources, clear step‑by‑step platform guides, and a quick‑response technical‑support channel. Where possible, the university may offer low‑cost Wi‑Fi hotspots or data vouchers. | Reducing the need for constant high‑speed internet ensures you can keep up with the class without extra cost or connectivity worries. |
#
# ### 5. Short Action Plan
#
# | Step | Action | Timeline |
# |------|--------|----------|
# | 1 | Check the course’s online folder each Monday for newly uploaded slides and videos. | Weekly |
# | 2 | Download the week’s materials to your device (or a USB drive) for offline study. | Within 24 h of upload |
# | 3 | Review the “How to use the learning platform” guide before the first live session. | Before the next live class |
# | 4 | If you experience connectivity problems, contact the technical‑support email/phone listed in the syllabus. | As soon as an issue arises |
# | 5 | Explore campus resources (e.g., library Wi‑Fi, student data vouchers) for low‑cost internet options. | This week |
#
# By following these steps, you can keep leveraging your strong engagement while minimizing the impact of internet costs. If you have any questions or need additional support, feel free to reach out to your instructor or the student help desk. Good luck with your studies!

# %% [markdown]
# ## Student ID: `M080215`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "self_paced", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** M080215
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You appreciate how blended learning can **save time and resources** and make study more convenient.
# - Your comments highlight the value of **easy access to learning materials** and the **flexibility** it offers for managing your schedule.
#
# **Main Challenges**
# - Some courses feel **less suited to blended formats** and you would like more up‑to‑date tools (e.g., subtitles, note‑taking, quizzes).
# - You notice a need for better **assessment balance** and more suitable **learning resources and environments** for blended study.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Strengthen access to learning materials** | Get all slides, videos, references, and exercises uploaded **early** so you can review them whenever you need. | Check the course portal at the start of each week; download or bookmark the materials for offline study. |
# | **Improve learning effectiveness** | Pair the online review content with **in‑person explanations, practice activities, and feedback** to deepen understanding. | Attend face‑to‑face sessions prepared with questions from the online material; use office‑hours for clarification. |
# | **Improve learning resources and environment** | Ensure materials are **well‑organized and up‑to‑date**, and that study spaces (both virtual and physical) are comfortable. | Use the provided folder structure; request updated resources if anything feels outdated; choose a quiet study spot with good lighting. |
# | **Support self‑paced learning** | Access **recorded lessons and weekly learning paths** so you can study at a speed that fits your schedule. | Follow the weekly roadmap, pause/replay recordings as needed, and take notes alongside subtitles or captions. |
# | **Manage workload and assessment pressure** | Have a **clear view of deadlines** and a balanced mix of assignments that link online tasks with classroom work. | Use the course calendar to track due dates; break larger tasks into smaller steps and align them with the weekly path. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Review the upcoming week’s folder on the LMS; download all slides, videos, and reference links.
# 2. **Day 3‑4:** Watch the recorded lecture, use subtitles, and take notes in a digital notebook.
# 3. **Day 5:** Attend the in‑person session prepared with at least two questions from your notes; seek feedback on a short practice exercise.
# 4. **Day 6‑7:** Update your personal study calendar with all assignment deadlines and set reminders for each milestone.
# 5. **Repeat** the cycle for the following week, adjusting the pace as needed and reaching out to the instructor if any resources feel outdated.
#
# By following these steps, you’ll make the most of the blended format—saving time, improving understanding, and keeping the workload manageable. Good luck!

# %% [markdown]
# ## Student ID: `e20240622`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240622*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - No specific strengths or challenges were provided in the open‑ended responses, so the recommendations below are drawn from the typical profile of this segment.
#
# ### 2. Main Strengths
# *Not reported.* The suggestions are based on the characteristics of moderately engaged, more passive learners.
#
# ### 3. Main Challenges
# *Not reported.* The guidance focuses on common areas where passive learners often benefit from additional support.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from lecturers. | Increases active involvement and reduces passivity. |
# | **Learning Support** | • Look for clearer written instructions and concrete examples.<br>• Use recorded explanations and step‑by‑step guides provided by the instructor. | Improves understanding and reduces confusion when studying independently. |
# | **Motivation & Self‑Discipline** | • Set up weekly check‑ins (with a tutor or study buddy).<br>• Use reminders and a simple progress‑tracking sheet.<br>• Follow a structured study schedule each week. | Keeps you on track and builds self‑motivation. |
# | **Self‑Paced Learning** | • Access recorded lessons so you can review material at your own speed.<br>• Follow the weekly learning path outlines and use the downloadable resources. | Allows flexibility while ensuring you cover all required content. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Tool/Resource |
# |------|--------|----------------|
# | 1 | Register for the upcoming Q&A session and join a study group on the course forum. | Course platform calendar, discussion board |
# | 1 | Download the step‑by‑step guide for the current module and watch the recorded lecture. | Module resources page |
# | 2 | Set a 30‑minute weekly check‑in with a peer or tutor; record your progress in a simple spreadsheet. | Google Sheet or notebook |
# | 2 | Create a personal study schedule (e.g., Mon/Wed/Fri 2 – 3 pm) and set phone/computer reminders. | Calendar app, reminder app |
#
# Follow these steps and adjust as needed. If you encounter any specific difficulties, let your instructor know so additional support can be arranged. Good luck!

# %% [markdown]
# ## Student ID: `e20240477`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240477*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits of this segment:** strong motivation, frequent interaction with course content, and a preference for having materials readily available for review.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate being able to revisit sessions and work without distractions. (Your open‑ended comment highlighted the value of re‑watching material.)
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You would like clearer explanations, source references for each course, and a way to check whether your answers are correct.
#
# ### 4. Personalized Recommendations
#
# | Tag | Title | What to do |
# |-----|-------|------------|
# | **content_access** | Strengthen access to learning materials | • Ensure that slides, video recordings, reference links, exercises, and any other course resources are uploaded **early** in the module. <br>• Keep a single, organized repository (e.g., a course folder or LMS page) so you can easily re‑watch sessions whenever needed. |
# | **learning_support** | Improve clarity and learning support | • Provide **clear, step‑by‑step instructions** for each activity, accompanied by recorded explanations or short demo videos. <br>• Include example problems with worked‑out solutions so you can compare your answers and confirm correctness. <br>• Offer quick reference sheets that list the source of each concept or formula used in the course. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the course’s central folder and verify that all slides and videos are uploaded. If anything is missing, request it from the instructor. |
# | **2** | Review the first module’s recorded explanations and note any steps that are unclear. Use the provided examples to test your understanding. |
# | **3** | Complete the practice exercises, then compare your answers with the solution guides. Mark any topics that still feel fuzzy. |
# | **4** | Share feedback with the teaching team about which explanations helped most and where additional clarification is needed. |
#
# By focusing on early, organized access to materials and clearer, supported explanations, you can leverage your high engagement to achieve deeper understanding and better performance. Keep using the resources you can re‑watch, and don’t hesitate to ask for the step‑by‑step guidance you need. Good luck!

# %% [markdown]
# ## Student ID: `M070609`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** M070609
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value the ability to review lessons anytime and anywhere, highlighting strong **access to learning materials**.
#
# **Main Challenges**
# - You experience **internet/technical issues** that can interrupt your study flow.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to act |
# |----------------|----------------------|------------|
# | **Strengthen access to learning materials** (content_access) | Keep all course content—slides, videos, readings, and exercises—available early so you can study on your own schedule. | • Check that the instructor has uploaded all materials at the start of the module.<br>• Save copies of PDFs or videos to your device for offline review. |
# | **Improve technical access and reliability** (tech_issue) | Reduce disruptions caused by unstable internet or platform problems. | • Use campus Wi‑Fi or a reliable hotspot when possible.<br>• Download offline versions of lectures and readings in advance.<br>• Keep a quick‑reference guide for the learning platform handy.<br>• Contact the technical support team as soon as an issue arises. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Verify that all current module materials are uploaded; download any that are missing.
# 2. **Day 3‑5:** Test your internet connection; if unstable, arrange an alternative (campus library Wi‑Fi, mobile hotspot).
# 3. **Day 6‑7:** Create a simple folder on your device for offline content (slides, PDFs, videos).
# 4. **Week 2:** Keep a log of any technical problems and the support you received; share this with your instructor or tech support to help improve the system.
#
# By focusing on reliable access to materials and addressing internet challenges, you can keep leveraging your high engagement while minimizing interruptions. Good luck!

# %% [markdown]
# ## Student ID: `e20230462`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230462*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key strengths you reported:** Flexibility for learning (you manage your time well).
# - **Main challenges you reported:** Internet connectivity issues and difficulty staying focused.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You are able to adapt your study schedule and take advantage of different learning formats.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Keeping focus can be hard, especially when internet access is unreliable.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Support motivation and self‑discipline** | Build habits that keep you on track even when connection drops. | • Set a **weekly check‑in** (e.g., a short self‑review or a quick chat with a tutor). <br>• Use **reminders** (calendar alerts or app notifications) for study blocks. <br>• Track progress with a simple checklist or a digital dashboard. <br>• Follow a **structured study schedule** that includes short, focused sessions. |
# | **Support self‑paced learning** | Take advantage of the flexibility you already have. | • Access **recorded lectures** and download them for offline viewing. <br>• Follow the **weekly learning path** provided by the course (outline of what to study each week). <br>• Review materials as often as needed; you control the speed. |
#
# These recommendations align with the tags **motivation** and **self_paced**, which were identified as most relevant for you.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a weekly study schedule (30 min blocks) and set calendar reminders. |
# | **Tuesday** | Download this week’s recorded lessons for offline access. |
# | **Wednesday** | Complete a brief self‑check‑in: note what you’ve finished and any focus issues. |
# | **Thursday** | Review progress on the checklist; adjust the schedule if needed. |
# | **Friday** | Share a short update with a peer or tutor (email or discussion board). |
# | **Weekend** | Use any extra time to revisit challenging topics without internet pressure. |
# | **Repeat** | Follow the same pattern next week, refining reminders and check‑ins based on what works best. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset. By adding a few simple structures—regular check‑ins, reminders, and offline resources—you can keep motivation high and stay on track even when internet access is spotty. Good luck, and keep leveraging your active learning style!

# %% [markdown]
# ## Student ID: `e20240254`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240254*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You show strong enthusiasm for learning and value convenient, effective study tools.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – you appreciate resources that help you study independently and improve your self‑study skills.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – you sometimes find it hard to concentrate, which can affect sustained study sessions.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Blend online review materials (videos, quizzes, summaries) with face‑to‑face explanations, guided practice, and feedback. | • Use the LMS to watch short review clips before class.<br>• Attend in‑person sessions for deeper explanation and hands‑on activities.<br>• Seek immediate feedback on practice tasks from tutors or peers. |
# | **Support motivation and self‑discipline** | Build routine and visibility of progress through weekly check‑ins, reminders, and a structured schedule. | • Set a weekly study plan (e.g., 2 hrs online review + 1 hr in‑person practice each week).<br>• Enable calendar reminders for study blocks and deadlines.<br>• Use the platform’s progress tracker to log completed tasks and review your weekly gains.<br>• Participate in brief weekly check‑ins (online or with a study buddy) to discuss what’s working and adjust the plan. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a simple weekly schedule (online review + in‑person practice). Set calendar reminders. |
# | **Tuesday** | Watch the first online review module for your current topic. |
# | **Wednesday** | Attend the corresponding in‑person session; ask for feedback on a practice exercise. |
# | **Thursday** | Log completed activities in the progress tracker; note any concentration issues. |
# | **Friday** | Quick 10‑minute self‑check: Did you follow the schedule? What helped you stay focused? |
# | **Weekend** | Review your progress summary; adjust the next week’s schedule if needed. |
# | **Repeat** | Follow the same pattern for the second week, adding a brief peer check‑in on Friday. |
#
# ---
#
# **Remember:** Your strong engagement is a valuable asset. By pairing convenient online resources with active, in‑person practice and keeping a regular, tracked study routine, you’ll boost both learning effectiveness and concentration. Good luck!

# %% [markdown]
# ## Student ID: `e20231074`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20231074*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated, enjoy interacting with digital content, and prefer having material you can revisit.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You value being able to re‑watch online lectures (“online I can re‑watch again”).
# - **Digital Skills Development:** You are comfortable using digital tools for learning.
#
# ### 3. Main Challenges
# - You would like **more video content** so you can review lectures before attempting exercises. (No additional challenges were reported.)
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | Why It Helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Ensure that slides, recorded lectures, reference links, and practice exercises are uploaded to the LMS **early** in the week. | Gives you the ability to re‑watch videos and review content at your own pace, matching your preference for revisiting material. |
# | **Develop digital learning skills** | Receive short guides or short video tutorials on how to use LMS features (e.g., bookmarking, downloading, discussion forums) and how to locate reliable online resources. | Enhances your ability to find, organize, and use digital resources efficiently, supporting your active learning style. |
#
# ### 5. Short Action Plan
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | **1** | Check that all lecture videos and slides are posted by Monday. | Ask the instructor or teaching assistant to upload materials within 24 hours of the live session. |
# | **2** | Create a personal “review folder” in the LMS for each module. | Save the videos, slides, and any extra readings you want to revisit. |
# | **3** | Watch the recorded lecture **once** before attempting the first exercise. | Use the “speed” control if needed, then take notes in your folder. |
# | **4** | Complete a short LMS tutorial (5‑10 min) on bookmarking and searching. | Follow the tutorial link provided by the course or ask the support team for a quick guide. |
# | **5** | Reflect on how the extra video access and digital tools helped your study. | Write a brief note (1‑2 sentences) in your folder to track progress. |
#
# By following these steps, you’ll keep the strong access to materials you already value while sharpening the digital skills that make your active learning even more effective. Good luck, and keep leveraging the flexibility of blended learning!

# %% [markdown]
# ## Student ID: `e20241169`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241169*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What we know:** Your open‑ended response did not highlight clear strengths, and the comments about challenges focused on the speed of the internet and the need for more up‑to‑date slides. Because the open‑ended information is limited, the recommendations below draw primarily on the characteristics of your segment together with the specific issues you mentioned.
#
# ---
#
# ### 2. Main Strengths
# - The data did not provide explicit strengths. As a member of the “Highly Engaged” segment, you are generally motivated to participate actively in class and to take advantage of learning opportunities.
#
# ---
#
# ### 3. Main Challenges
# - **Technical access:** Internet connection is not fast enough for smooth online work.
# - **Learning resources & environment:** Course slides and other materials are not refreshed each year, affecting relevance and clarity.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to act |
# |----------------|----------------------|------------|
# | **Improve learning resources and environment** | Organise study materials so they are easy to find, and ensure that slides and other resources are updated regularly. A comfortable, well‑structured study space will help you stay focused. | • Check the course’s learning‑management system for the latest version of each slide.<br>• Create a personal folder structure (e.g., by week or topic) to keep materials tidy.<br>• If a slide looks outdated, ask the instructor or teaching assistant for the newest version. |
# | **Improve technical access and reliability** | Secure a stable internet connection and have backup options for when connectivity is poor. Clear instructions and quick technical support will reduce frustration. | • Use campus Wi‑Fi or a reliable mobile hotspot for critical sessions.<br>• Download lecture videos or PDFs in advance so you can study offline.<br>• Keep a short “tech checklist” (browser, login, headset) before each online class.<br>• Contact the university IT help desk as soon as you experience connectivity problems. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the latest slide decks in the LMS; note any that are missing or outdated. |
# | **Day 3‑4** | Set up a personal folder system on your computer/ cloud storage for each module. |
# | **Day 5** | Test campus Wi‑Fi or a personal hotspot; record the speed and note any dead zones. |
# | **Day 6‑7** | Download at least one week’s worth of lecture videos for offline study. |
# | **Day 8** | Create a simple tech checklist (browser, login, audio, video) and keep it by your workstation. |
# | **Day 9‑10** | If any slides are still outdated, email the instructor or TA requesting the newest version. |
# | **Day 11‑12** | Review the organized materials and practice using them in a short study session. |
# | **Day 13‑14** | Reflect: Did the faster internet or offline files improve your study experience? Note any remaining issues and share them with the IT support team. |
#
# ---
#
# **Keep in mind:** As a highly engaged learner, you already have the drive to succeed. By tidying your learning environment and securing reliable technical access, you’ll be able to focus that energy on the content itself. If you encounter any new obstacles, reach out to your instructors or the university support services—they’re there to help you thrive.

# %% [markdown]
# ## Student ID: `e20230483`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "learning_environment", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230483*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated, participate actively, and value the flexibility that blended learning can give, especially when you live far from campus.
#
# ### 2. Main Strengths
# - **Access & Convenience:** You appreciate being able to obtain slides, videos, and other materials online so you don’t have to travel for every lecture.
# - **Positive Attitude:** Your comments about the benefits of remote access show a constructive outlook toward blended formats.
#
# ### 3. Main Challenges
# - **Scheduling Gaps:** Switching directly from an online class to an in‑person session can feel rushed.
# - **Coordination of Workload & Resources:** You would like clearer alignment between online and face‑to‑face activities, as well as better‑organized study spaces and materials.
#
# ### 4. Personalized Recommendations
#
# | Recommendation Tag | What It Means for You | Suggested Action |
# |--------------------|-----------------------|------------------|
# | **content_access** | Ensure all learning materials are available early. | Upload slides, videos, readings, and practice exercises at least a week before each class. |
# | **interaction** | Boost communication between you, peers, and lecturers. | Add short Q&A slots, online discussion boards, and peer‑collaboration tasks; request quicker feedback on assignments. |
# | **learning_effectiveness** | Combine the strengths of both modes. | Use online review resources to prepare, then attend in‑person sessions for deeper explanation, guided practice, and immediate feedback. |
# | **learning_environment** | Make the study environment clear and comfortable. | Organise course folders logically, keep digital resources up‑to‑date, and work with the university to improve classroom comfort and study‑space availability. |
# | **workload_support** | Balance assignments and clarify deadlines. | Align online tasks with upcoming face‑to‑face classes, provide a unified calendar, and give advance notice of assessment dates. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Goal | Concrete Step |
# |------|------|----------------|
# | 1 | Secure early material access | Request that the instructor post all lecture slides and videos at least 5 days before class. |
# | 2 | Enhance interaction | Join a course‑wide online discussion board; schedule a 10‑minute Q&A after each lecture. |
# | 3 | Align online & in‑person work | Create a personal calendar that links online assignments to the next face‑to‑face session; share any conflicts with the lecturer. |
# | 4 | Optimize study environment | Review the course folder structure; suggest any needed re‑organisation to the teaching team and identify a quiet on‑campus study spot. |
#
# By following these steps, you can keep leveraging your high engagement while smoothing the transition between online and in‑person learning, reducing workload pressure, and making the most of the resources available to you. Good luck!

# %% [markdown]
# ## Student ID: `e20200254`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20200254*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are classified as a **Highly Engaged (Active) Learner**. Your responses show a positive attitude toward learning, especially in using technology and seeking real‑world applications of data‑science concepts.
#
# ### 2. Main Strengths
# - **Digital Skills Development** – You already have solid knowledge of technology and are keen to improve your research abilities.
# - **Learning Convenience & Effectiveness** – You value tools that make studying easier and more efficient.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – You noted that reliable video recording and access can be a barrier, especially when trying to connect theory to real‑world data‑science practice.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Develop digital learning skills** (digital_skill) | Strengthen your use of the LMS, online research tools, and educational technologies. | Attend short workshops or tutorials on the LMS, explore digital libraries, and practice using data‑science software tutorials provided online. |
# | **Improve learning effectiveness** (learning_effectiveness) | Blend online review (e.g., recorded videos) with in‑person explanation, hands‑on practice, and feedback. | Use recorded lectures for revision, then join study groups or lab sessions where you can discuss concepts and receive immediate feedback. |
# | **Improve technical access and reliability** (tech_issue) | Ensure you have stable internet and clear guidance on platform use. | Download offline copies of key materials when possible, keep a list of technical support contacts, and follow any provided “quick‑start” guides for the LMS. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Watch the LMS “Getting Started” video and bookmark the digital research resources page. |
# | **Day 3‑4** | Download the week’s lecture videos for offline review; note any sections that need clarification. |
# | **Day 5‑7** | Join a peer study group (in‑person or via video call) to discuss the downloaded material and practice a data‑science mini‑project. |
# | **Day 8‑10** | Test your internet connection with a short video upload; if problems arise, contact the campus tech‑support desk and request offline alternatives. |
# | **Day 11‑14** | Reflect on what worked best (online review vs. face‑to‑face practice) and adjust your study schedule accordingly. |
#
# ---
#
# **Remember:** Your strong engagement and digital aptitude are valuable assets. By sharpening your digital learning skills, pairing online review with active practice, and securing reliable technical access, you’ll maximize the benefits of blended learning and deepen your understanding of data‑science in real‑world contexts. Good luck!

# %% [markdown]
# ## Student ID: `e20250116`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "learning_effectiveness", "learning_environment", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250116*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when learning is flexible, convenient, and personally relevant. You value the ability to schedule study time that fits your life and notice that personalized content keeps you highly engaged. At the same time, you find it challenging to stay self‑disciplined in self‑paced settings, to manage occasional technology hiccups, and to cope with feelings of isolation when face‑to‑face contact is limited.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you reported |
# |-------|-------------------|
# | **Flexibility & Time Management** | You appreciate the freedom to choose when and where you study. |
# | **Learning Convenience & Effectiveness** | Personalized materials boost your engagement and understanding. |
# | **Student Engagement** | Interactive, tailored content keeps you motivated. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you reported |
# |-------|-------------------|
# | **Learning Resources & Environment** | Technological barriers and less‑optimal study spaces sometimes hinder you. |
# | **Motivation & Self‑Discipline** | Maintaining discipline in self‑paced formats and feeling isolated can be difficult. |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation Tag | Title | Practical Actions for You |
# |--------------------|-------|----------------------------|
# | **engagement** | Increase learner engagement | • Add short quizzes or game‑based checkpoints after each module.<br>• Participate in online discussion boards and practical tasks that apply concepts. |
# | **learning_effectiveness** | Improve learning effectiveness | • Pair the online review videos with brief in‑person (or live‑online) sessions for explanation, practice, and feedback.<br>• Use the feedback to adjust your study focus. |
# | **learning_environment** | Improve learning resources and environment | • Keep your digital files organized (folders by topic, clear naming).<br>• Ensure you have a reliable internet connection and a comfortable, distraction‑free study spot.<br>• Request updated or additional resources from the instructor when needed. |
# | **motivation** | Support motivation and self‑discipline | • Set a weekly check‑in with yourself (or a peer) to review progress.<br>• Use calendar reminders for study blocks and deadlines.<br>• Track completed tasks in a simple spreadsheet or app to see your momentum. |
# | **self_paced** | Support self‑paced learning | • Follow the weekly learning path provided by the course (outline of what to watch/read each week).<br>• Take advantage of recorded lessons so you can revisit difficult sections at your own speed. |
#
# These suggestions are drawn directly from the evidence about your strengths, challenges, and the segment‑based recommendations.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Set Up** | • Create a dedicated study folder and schedule three 1‑hour study blocks (e.g., Mon, Wed, Fri).<br>• Install a reminder app for these blocks.<br>• Test your internet connection and identify a quiet study spot. |
# | **Week 1 – Engage** | • After each study block, complete a short quiz or mini‑game related to the material.<br>• Post one question or comment on the course discussion board. |
# | **Week 2 – Reflect & Adjust** | • Review your progress tracker; note any missed blocks and why.<br>• Schedule a 15‑minute check‑in with a classmate or tutor to discuss challenges.<br>• Request any missing resources or clarification from the instructor. |
# | **Week 2 – Consolidate** | • Re‑watch any recorded lessons that felt unclear.<br>• Apply what you learned in a practical task or short written summary. |
#
# Follow this plan, adjust the timing to fit your personal schedule, and keep using the engagement tools (quizzes, discussions, feedback) to stay motivated. You have the flexibility and drive—these steps will help you turn that potential into consistent progress. Good luck!

# %% [markdown]
# ## Student ID: `e20230668`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230668*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** Learners who attend classes but tend to participate less actively. They value flexibility and convenience, yet may need extra support to stay connected and clear about tasks.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You adapt well to different schedules and can manage your study time effectively.
# - **Learning Convenience & Effectiveness:** You appreciate learning tools that make studying easier and help you understand material quickly.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Limited opportunities for discussion and feedback can make learning feel isolated.
# - **Internet & Technical Issues:** Unstable connectivity and unclear platform instructions hinder smooth participation.
# - **Learning Difficulty & Clarity:** Instructions sometimes lack detail, making it harder to know exactly what is expected.
#
# ### 4. Personalized Recommendations
#
# | Focus Area | What to Do (Based on Rule‑Based Advice) |
# |------------|------------------------------------------|
# | **Interaction** | Join scheduled Q&A sessions, take part in small‑group discussions, and collaborate with peers on assignments. Look for quicker lecturer feedback through discussion boards or office‑hour chats. |
# | **Learning Effectiveness** | Use a mix of online review materials (e.g., short videos, quizzes) together with in‑person explanations and practice activities. Seek feedback on practice tasks to reinforce understanding. |
# | **Learning Support** | Ask for clearer written instructions, concrete examples, and step‑by‑step guides. Recorded explanations of complex topics can be revisited as needed. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths. Review materials at your own speed and use them to fill gaps before live sessions. |
# | **Technical Access** | If possible, secure a more reliable internet connection (e.g., campus Wi‑Fi, hotspot). Download offline copies of essential resources ahead of time and keep the platform’s help guide handy. Reach out to the tech support desk whenever you encounter issues. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the course’s discussion forum and sign up for the next live Q&A session. |
# | **Day 3‑4** | Download all lecture videos and supplemental PDFs for the upcoming module (offline backup). |
# | **Day 5** | Create a personal weekly learning path: list topics, allocate 30‑45 min slots, and set reminders. |
# | **Day 6‑7** | Review the first topic using the recorded lesson, then post one question on the forum for clarification. |
# | **Day 8** | Join a peer‑study group (virtual or on‑campus) for a 30‑min discussion on the same topic. |
# | **Day 9‑10** | Test your internet connection; if unstable, arrange alternative access (library Wi‑Fi, mobile hotspot). |
# | **Day 11‑12** | Request a step‑by‑step guide from the lecturer for any assignment that feels unclear. |
# | **Day 13‑14** | Complete a short practice quiz, review feedback, and note any remaining doubts for the next Q&A. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset—use it to build a routine that mixes self‑paced study with active interaction. If technical problems arise, seek support early so they don’t disrupt your learning flow. Good luck!

# %% [markdown]
# ## Student ID: `e20230300`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230300*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You appreciate the **flexibility** that blended learning offers and are motivated to keep learning actively.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you value being able to study when it fits your schedule.
# - **Learning Convenience & Effectiveness** – you find the mix of online resources helpful for understanding material.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – low‑bandwidth connections sometimes make streaming video difficult, affecting smooth access to online content.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Improve learning effectiveness** | Pair the online review materials you already like with short, in‑person (or live‑online) sessions where you can ask questions, practice, and receive feedback. | Attend weekly tutorial labs or join a study group that reviews the recorded lessons together. |
# | **Support self‑paced learning** | Keep using recorded lectures and weekly learning paths that let you study at your own speed. | Follow the provided weekly roadmap, pause/re‑watch videos as needed, and use the downloadable notes for review. |
# | **Improve technical access and reliability** | Reduce interruptions caused by a weak internet connection. | Download offline versions of videos and readings ahead of time, use campus Wi‑Fi or a reliable hotspot when possible, and contact the tech‑support desk for quick help with platform issues. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Download the next week’s recorded lessons and reading materials for offline use. |
# | **Day 3** | Review the weekly learning path; set specific study times that fit your schedule. |
# | **Day 4–5** | Attend a 1‑hour in‑person (or live‑online) tutorial to clarify any concepts from the recordings. |
# | **Day 6** | Test your internet connection; if it’s still unstable, arrange to use campus Wi‑Fi or a hotspot for the next streaming session. |
# | **Day 7** | Reach out to the technical support team with any platform questions; keep their contact info handy. |
# | **Day 8–14** | Follow the self‑paced schedule, revisiting any difficult sections, and use the tutorial feedback to improve your understanding. |
#
# ---
#
# **Remember:** Your strong engagement and love of flexibility are great assets. By combining self‑paced online resources with targeted face‑to‑face support and ensuring reliable technical access, you can keep learning effectively even when internet quality fluctuates. Good luck, and keep up the active participation!

# %% [markdown]
# ## Student ID: `e20240400`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240400*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** *Cluster 2 – Highly Engaged (Active) Learners*
# - You thrive when you can study independently and value the flexibility to learn anywhere, especially when you have other commitments.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You can organise your study time and learn effectively outside the classroom.
# - **Learning Convenience & Effectiveness:** You are comfortable using online resources to support your learning.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline:** At times you may lose focus or let other tasks take priority over your studies.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | How It Helps |
# |-------|------------|--------------|
# | **Learning Effectiveness** | Combine online review materials with in‑person explanations, practice activities, and feedback. | Reinforces concepts you study independently and ensures you can apply knowledge correctly. |
# | **Motivation & Self‑Discipline** | Set up weekly check‑ins, automated reminders, and a simple progress‑tracking dashboard. Create a structured weekly study schedule. | Keeps you accountable, highlights your progress, and sustains motivation. |
# | **Self‑Paced Learning** | Use recorded lectures and a weekly learning path that outlines what to study each day. Keep all materials accessible online for review whenever you need them. | Lets you maintain the flexibility you value while ensuring you cover all required content. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Tool/Resource |
# |------|--------|---------------|
# | **1** | Choose one core subject and locate its recorded lectures and online review sheets. | University LMS or course portal |
# |      | Create a **weekly study schedule** (e.g., 2 hrs Mon‑Wed, 1 hr Fri). | Google Calendar or planner app |
# |      | Set **reminders** for each study block and a brief end‑of‑week check‑in. | Mobile reminder app |
# | **2** | Attend an **in‑person session** (lecture, tutorial, or lab) for the same subject to get live explanation and feedback. | Campus timetable |
# |      | Log your completed tasks and any questions in a **progress tracker** (simple spreadsheet or LMS tracker). | Google Sheets / LMS |
# |      | Review recorded lessons again if any concepts are unclear, using the **self‑paced** materials. | Recorded videos |
#
# Continue repeating this cycle, adjusting the schedule as needed. The blend of online review, scheduled check‑ins, and face‑to‑face feedback will maximise your learning effectiveness while supporting motivation and the flexibility you prefer.
#
# ---
#
# *You are a highly engaged learner; these steps build on your strengths and address the main challenge identified.*

# %% [markdown]
# ## Student ID: `e20240972`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240972*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are identified as a **Highly Engaged (Active) Learner**. You report that you can assess and learn material easily, which shows strong self‑assessment skills. Your main concerns are **internet/technical problems** and **limited video resources or a changing set of lecturers**.
#
# ### 2. Main Strengths
# - **Quick assessment and learning** – you feel confident in understanding new content.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – unstable connection or lack of reliable access.
# - **Learning Resources & Environment** – insufficient video materials and recent changes in lecturers make it harder to follow the course.
#
# ### 4. Personalized Recommendations
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Learning Environment** | • Organize your study materials in a clear folder structure (e.g., by week or topic).  <br>• Keep a list of the most useful resources and note any gaps (e.g., missing videos).  <br>• Choose a quiet, comfortable study space and, if possible, improve lighting and ergonomics. | A well‑structured environment reduces the friction caused by changing lecturers and missing resources, letting you focus on the content you already learn quickly. |
# | **Technical Access** | • Use a stable internet connection (e.g., campus Wi‑Fi, a wired link, or a reliable mobile hotspot).  <br>• Download lecture videos or PDFs for offline study when they become available.  <br>• Follow any platform guides provided by the university and keep them bookmarked.  <br>• Contact the IT help desk early when you encounter connectivity problems. | Reliable access and offline options prevent interruptions, so your high engagement can be maintained without technical setbacks. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Identify a quiet study spot and set up a folder system for course files. |
# | **Day 3‑4** | Test your internet connection; if unstable, arrange an alternative (campus Wi‑Fi, hotspot). |
# | **Day 5‑7** | Download any available lecture videos or PDFs for offline use. |
# | **Day 8‑10** | Review the platform’s quick‑start guide; bookmark it for reference. |
# | **Day 11‑14** | If you experience any technical issues, submit a ticket to the IT support desk and note the response time. |
#
# By strengthening your learning environment and ensuring reliable technical access, you can keep leveraging your natural ability to assess and learn quickly, while minimizing the disruptions you’ve identified. Keep track of what works and adjust the plan as needed—your active engagement is a strong foundation for success.

# %% [markdown]
# ## Student ID: `e20230493`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230493*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - This segment typically benefits from easy access to content, strong engagement opportunities, good digital skills, and the ability to study at their own pace.
#
# ### 2. Main Strengths
# - The open‑ended response did not provide clear strengths (the student wrote “not sure”).
# - Because the response is weak, the strengths listed are drawn from the typical profile of highly engaged learners (e.g., motivation and willingness to participate).
#
# ### 3. Main Challenges
# - **Learning Resources & Environment** – the student mentioned difficulty with “recording video,” indicating a challenge related to the learning environment and the tools/resources available for creating or using video content.
#
# ### 4. Personalized Recommendations
# - **Improve Learning Resources and Environment**
#   - Organize study materials and digital files so they are easy to locate.
#   - Update any outdated resources (e.g., video‑recording guides, software tutorials).
#   - Enhance the physical or virtual study space: ensure good lighting, a quiet area, and reliable internet/recording equipment.
#   - Make the classroom or online platform comfortable and supportive for video‑based activities.
#
# ### 5. Short Action Plan
#
# | Week | Action | How to Do It | Expected Outcome |
# |------|--------|--------------|------------------|
# | 1 | Audit current video‑recording tools and files | List all software, hardware, and file locations you use for video work | Clear picture of what you have and what’s missing |
# | 2 | Clean and organize digital folders | Create a simple folder structure (e.g., Course → Lectures → Videos) and move files accordingly | Faster retrieval of resources |
# | 3 | Update resources | Find a short tutorial on the recording software you use (YouTube, university help desk) and save it in your organized folder | Better technical skill and confidence |
# | 4 | Optimize study space | Choose a quiet spot, set up good lighting, and test your microphone/webcam | More comfortable and higher‑quality recordings |
# | Ongoing | Use the organized system for every new video assignment | Follow the same folder structure each time | Consistent, stress‑free workflow |
#
# ---
#
# **Remember:** As a highly engaged learner, you already have the motivation to succeed. By improving the learning environment and resources, you’ll be able to channel that energy into smoother, more effective video work and overall study habits. Good luck!

# %% [markdown]
# ## Student ID: `e20210095`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210095
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - Values the convenience of blended learning: saving travel time and having recorded videos that can be revisited later.
# - Appreciates easy access to learning materials that support quick review.
#
# **Main Challenges**
# - Occasional internet‑connection problems that can interrupt online activities.
# - Would like additional study materials in advance to prepare more effectively.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Having all slides, videos, references, and exercises available early lets you review whenever you need. | Ask your instructor to upload the full set of course resources at the start of each module. Keep a personal folder (cloud or offline) for quick retrieval. |
# | **Improve learning effectiveness** (learning_effectiveness) | Combining the recorded content with face‑to‑face explanation, practice, and feedback maximises understanding. | After watching a video, schedule a short in‑person or virtual session to discuss key points, do practice problems, and receive feedback. |
# | **Improve learning resources and environment** (learning_environment) | Clear, well‑organized materials and a comfortable study space help you stay focused. | Use a dedicated study area with minimal distractions. Keep digital files sorted by week/topic; use the course’s learning‑management system to bookmark important items. |
# | **Improve technical access and reliability** (tech_issue) | Reliable internet and offline options reduce interruptions. | Download videos and PDFs when you have good connectivity so you can study offline. Keep a list of technical support contacts and a quick‑start guide for the platform you use. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Locate the course’s shared folder (e.g., Google Drive, LMS) and download all current week’s slides, videos, and readings for offline use.
# 2. **Day 3‑4:** Create a simple folder structure on your computer (Week 1 → Slides, Videos, Exercises) for easy navigation.
# 3. **Day 5‑7:** After each recorded lecture, write down 2‑3 questions and schedule a 15‑minute meeting (in‑person or virtual) with the instructor or a study buddy to clarify them.
# 4. **Week 2:** Test your internet connection in the study space; if instability persists, arrange a backup (e.g., campus Wi‑Fi hotspot or mobile data) and note the technical support contact for quick help.
#
# By following these steps, you’ll keep the convenience you value while ensuring you have reliable access to materials, a supportive learning environment, and the technical stability needed for effective study. Good luck!

# %% [markdown]
# ## Student ID: `e20240005`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_effectiveness"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240005
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You value having learning materials (slides, videos, references, exercises) available early.
# - You recognize the importance of digital skills for accessing and using online resources.
# - You appreciate convenient, effective learning experiences.
#
# **Main Challenges**
# - You find research and self‑study difficult and feel that videos alone do not keep you motivated.
# - The open‑ended response did not provide many specific details, so the recommendations below rely primarily on the characteristics of the “Moderately Engaged (Passive) Learners” segment.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload all slides, video recordings, reference links, and practice exercises **before** class sessions. | Early access lets you review material at your own pace, reducing the need to rely solely on live video. |
# | **Digital Skills** | Offer short guides or mini‑workshops on using the LMS, searching scholarly sources, and applying educational tech tools. | Better digital fluency makes independent research and self‑study more manageable. |
# | **Engagement** | Integrate low‑stakes quizzes, quick polls, or short discussion prompts into each online segment. | Interactive elements keep attention focused and give you immediate feedback, counteracting passive video watching. |
# | **Learning Effectiveness** | Pair online review resources with brief in‑person (or live‑online) explanations, followed by practice tasks and feedback. | Combining multiple formats reinforces understanding and helps you apply concepts rather than just watching. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# 1. **Week 1 – Material Prep**
#    - Check that the course’s slide deck, video, and reading list are uploaded to the LMS at least 48 hours before the first lecture.
#
# 2. **Week 2 – Digital Skills Boost**
#    - Attend a 15‑minute tutorial on effective literature searching and using LMS features (e.g., bookmarking, discussion boards).
#
# 3. **Week 3 – Interactive Check‑In**
#    - Complete a short quiz after each video segment; aim for at least 70 % correct before moving on.
#
# 4. **Week 4 – Practice & Feedback**
#    - Submit one practice exercise per topic and request brief feedback from the lecturer or a peer tutor.
#
# By following these steps, you’ll have clearer access to materials, stronger digital research abilities, more engaging learning moments, and better overall learning outcomes. Keep track of what works best for you and adjust the plan as needed. Good luck!

# %% [markdown]
# ## Student ID: `e20230799`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230799*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Flexibility, time‑saving, and the convenience of studying online.
# - **Current feeling:** You feel motivated by the blended format and see it as helpful for your studies.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when it fits your schedule.
# - **Learning Convenience & Effectiveness** – You find online resources useful for understanding material quickly.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – While you are generally motivated, maintaining consistent self‑discipline can be a hurdle.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How it helps you | Practical steps you can take |
# |----------------|------------------|------------------------------|
# | **Improve learning effectiveness** | Combining the best of both worlds lets you solidify concepts faster. | • After watching a recorded lecture, attend the scheduled in‑person session for explanation, guided practice, and immediate feedback. |
# | **Support motivation and self‑discipline** | Regular check‑ins keep you on track and boost confidence. | • Set a weekly study schedule and use a digital planner. <br>• Join a short (5‑minute) weekly check‑in with your tutor or a study buddy. <br>• Use the course’s progress tracker and enable reminder notifications. |
# | **Support self‑paced learning** | You can review material as often as needed without feeling rushed. | • Access recorded lessons anytime. <br>• Follow the weekly learning path provided by the course, but feel free to spend extra time on topics that need more practice. <br>• Keep a personal “review folder” of key concepts you can revisit before assessments. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the upcoming week’s learning path; note any topics you want extra time on. |
# | **Tuesday** | Watch the recorded lecture for the first topic. Take brief notes. |
# | **Wednesday** | Attend the in‑person session – ask questions, do the practice activity, and get feedback. |
# | **Thursday** | Update your progress tracker; set a reminder for the next check‑in. |
# | **Friday** | Do a 10‑minute self‑reflection: What went well? What needs more review? |
# | **Weekend** | Re‑watch any parts of the recorded lecture that were unclear; add notes to your review folder. |
# | **Next Monday** | Repeat the cycle for the next topic, and schedule a brief check‑in with a peer or tutor. |
#
# ---
#
# **Remember:** Your strong engagement and appreciation for flexible, effective learning are great assets. By pairing online review with active, in‑person practice, keeping a simple weekly schedule, and using recorded lessons to study at your own pace, you’ll strengthen both learning outcomes and motivation. Good luck, and keep leveraging the blended format that works best for you!

# %% [markdown]
# ## Student ID: `e20241074`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241074*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - Your open‑ended responses did not provide specific strengths or challenges, so the recommendations below are drawn from the typical profile of highly engaged, active learners in this segment.
#
# ### 2. Main Strengths
# - (Not specified by your responses)
# - *Based on the segment:* Highly engaged learners usually show strong motivation, participation, and willingness to interact with course content.
#
# ### 3. Main Challenges
# - (Not specified by your responses)
# - *Based on the segment:* Even active learners can benefit from clearer access to materials, refined digital skills, and structured self‑paced options.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Content Access** | Upload slides, videos, reference links, exercises, and any other course materials **early** in the LMS. | Guarantees you can start working right away and keeps your momentum high. |
# | **Digital Skills** | Offer short guides or short videos on how to use LMS tools, locate online resources, conduct digital research, and apply educational technologies. | Strengthens your ability to navigate and exploit the online environment efficiently. |
# | **Engagement** | Integrate interactive elements such as quizzes, gamified tasks, practical assignments, and discussion prompts. | Keeps the learning experience lively and matches your active learning style. |
# | **Self‑Paced Learning** | Provide recorded lectures, weekly learning pathways, and downloadable resources that you can review whenever you need. | Allows you to deepen understanding at your own speed while still staying on track. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Check the course LMS for any missing slides or videos; request the instructor to upload any unavailable items. |
# | **Day 3–4** | Watch a 5‑minute tutorial on LMS navigation and digital research tools (look for “LMS Basics” in the resources section). |
# | **Day 5** | Complete the first interactive quiz or game provided in the module; note any questions you have. |
# | **Day 6–7** | Review the recorded lecture for the current topic; add personal notes and flag sections to revisit. |
# | **Day 8–10** | Follow the weekly learning path (e.g., “Read → Watch → Practice”) and finish the associated practical task. |
# | **Day 11–14** | Participate in a discussion forum or group chat about the week’s content; share one insight you gained from the self‑paced review. |
#
# ---
#
# **Tip:** Keep a simple checklist (like the table above) to track each activity. Your high engagement will make it easy to stay on top of these steps, and the added structure will help you get the most out of blended learning. Good luck!

# %% [markdown]
# ## Student ID: `e20250056`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250056*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to engage with course material at a steady, but not highly interactive, pace. You are comfortable studying from home when you have the necessary resources.
#
# ### 2. Main Strengths
# - You recognize that learning can happen at home even without personal transportation. This shows flexibility and the ability to use remote resources.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** You reported that the internet connection is slow, which can hinder access to online lectures, readings, and interactive tools.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|-----------------------|
# | **Improve technical access and reliability** (tag: *tech_issue*) | • Seek a more stable internet connection (e.g., campus Wi‑Fi hotspots, a data plan upgrade, or a local library’s broadband). <br>• Download lecture videos, PDFs, and other materials when you have a good connection so you can study offline. <br>• Keep a short guide of platform navigation steps handy to reduce confusion. <br>• Use the university’s IT help desk for quick troubleshooting when problems arise. |
#
# *Because your open‑ended responses were brief, this recommendation is primarily based on your segment profile (moderately engaged learners) and the specific technical challenge you identified.*
#
# ### 5. Short Action Plan
#
# | Step | Action | Timeline |
# |------|--------|----------|
# | 1. Identify a reliable internet source | Check campus Wi‑Fi locations, nearby cafés with strong Wi‑Fi, or consider a modest data‑plan upgrade. | **This week** |
# | 2. Download offline materials | Before each class, download the lecture video and reading PDFs to a folder on your laptop or tablet. | **Before each class** |
# | 3. Save a quick‑start guide | Write down the main steps to log in, access modules, and submit assignments; keep it on your desktop. | **Today** |
# | 4. Contact IT support if needed | If connection problems persist, submit a ticket to the university IT help desk. | **As soon as an issue occurs** |
# | 5. Review progress | After two weeks, note whether slower internet still affects your study and adjust the plan accordingly. | **After 2 weeks** |
#
# ---
#
# **Remember:** Improving your technical access will make it easier to stay on track with coursework, even as a moderately engaged learner. If you encounter any other obstacles, reach out to your instructors or the learning support team for additional help. Good luck!

# %% [markdown]
# ## Student ID: `e20231141`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20231141*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a moderately engaged learner who prefers a flexible, self‑directed approach. You are comfortable studying independently and can balance coursework with other life responsibilities. At the same time, you sometimes postpone tasks when studying from home, which can lead to missed deadlines.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You can organise your own study schedule and fit learning around other commitments.
# - **Learning Convenience & Effectiveness** – You are able to use self‑study methods and connect with resources outside the classroom.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Resources & Environment** – A clear, well‑organized set of materials and a comfortable study space would help you stay on track.
# - **Motivation & Self‑Discipline** – When work can be done later, it’s easy to delay and forget tasks.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What to Do | Why it Helps |
# |----------------|------------|--------------|
# | **Improve learning effectiveness** | Combine the online review materials you already use with short, in‑person sessions for explanation, practice, and feedback. | Reinforces concepts you study independently and gives you concrete checkpoints. |
# | **Improve learning resources and environment** | Keep your digital folder structure tidy, use updated resources, and set up a dedicated, comfortable study spot (good lighting, minimal distractions). | A clear environment reduces the temptation to postpone work and makes self‑study more efficient. |
# | **Support motivation and self‑discipline** | Join a weekly check‑in (e.g., a short 10‑minute virtual meeting or a reminder in your calendar), track your progress on a simple checklist, and follow a structured weekly study schedule. | Regular reminders and visible progress keep you accountable and reduce procrastination. |
# | **Support self‑paced learning** | Use recorded lectures and a weekly learning path that outlines what to review each day. You can pause, rewind, and revisit any part at your own speed. | Aligns with your preference for flexibility while ensuring you cover all required material. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a tidy digital folder for the current module; add all lecture recordings and PDFs. |
# | **Tuesday** | Set up a dedicated study space (desk, chair, good lighting). |
# | **Wednesday** | Draft a simple weekly schedule (e.g., 1 h review + 30 min practice each day). |
# | **Thursday** | Schedule a 10‑minute check‑in reminder in your calendar for Friday. |
# | **Friday** | Attend the first in‑person (or live‑online) session for practice and feedback. |
# | **Weekend** | Review recorded lessons according to the weekly path; tick off completed items on your checklist. |
# | **Next Monday** | Update your checklist, note any gaps, and adjust the schedule for the following week. |
#
# Follow this cycle each week, adjusting the study times and resources as needed. By pairing your strong self‑directed habits with clear structure and regular check‑ins, you’ll boost both motivation and learning effectiveness while keeping the flexibility you value.

# %% [markdown]
# ## Student ID: `e20240647`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "learning_effectiveness", "learning_environment", "motivation", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240647*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. Your responses show strong enthusiasm for using technology to improve academic skills, but you also note concerns about motivation, interaction, and technical reliability when learning online.
#
# ---
#
# ### 2. Main Strengths
# - **Digital Skills Development & Learning Convenience** – You recognize that the mix of on‑campus and off‑campus classes gives you ample time to develop digital competencies and learn more efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Limited real‑time dialogue and peer collaboration in online sessions.
# - **Internet & Technical Issues** – Unstable connections can hinder participation.
# - **Learning Resources & Environment** – Need for clearer, better‑organized materials and comfortable study spaces.
# - **Motivation & Self‑Discipline** – Online formats sometimes reduce drive and focus.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Digital Skill** | Attend short workshops on the LMS, digital research tools, and educational apps. Use the university’s “how‑to” guides for navigating online resources. |
# | **Interaction** | Join scheduled Q&A sessions, group discussions, and peer‑collaboration projects. Request quicker feedback from lecturers through the platform’s messaging feature. |
# | **Learning Effectiveness** | Pair online review videos with in‑person tutorials or labs. After each online module, practice the concepts in class and seek immediate feedback. |
# | **Learning Environment** | Use the university’s organized digital libraries and updated study‑space listings. Choose quiet, well‑equipped rooms for both online and offline work. |
# | **Motivation** | Set a weekly check‑in with a tutor or study buddy. Use the LMS to track progress, set micro‑goals, and receive reminder notifications. |
# | **Tech Issue** | Take advantage of campus Wi‑Fi hotspots or loaner devices. Download offline copies of essential materials before class. Keep the technical‑support contact list handy for quick assistance. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Register for a 1‑hour “LMS Basics” workshop; download offline PDFs of this week’s readings. |
# | **2** | Join a study group on the course forum; schedule a 30‑minute Q&A with the lecturer after the next online lecture. |
# | **3** | Create a personal study schedule (2 hrs on‑campus, 2 hrs off‑campus) and set weekly progress reminders in the LMS. |
# | **4** | Test campus Wi‑Fi in a quiet study room; if needed, request a loaner laptop or mobile hotspot from IT services. Review how the combined online/offline approach impacted your understanding and note any further adjustments. |
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By strengthening digital skills, boosting interaction, and ensuring reliable technical support, you can make the blended learning experience both effective and motivating. Good luck!

# %% [markdown]
# ## Student ID: `e20231117`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20231117*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are identified as a **Highly Engaged (Active) Learner**. You value flexibility and practical learning, and you are motivated to make the most of blended‑learning environments.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate the ability to study when and where it fits your schedule.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable Wi‑Fi can disrupt your study flow.
# - **Learning Resources & Environment** – You would like more comfortable rooms and better‑organized study spaces.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Improve learning environment** | Organize course materials clearly, keep digital resources up‑to‑date, and ensure study spaces are comfortable. | Look for a quiet, well‑lit spot on campus or at home; use the LMS’s folder structure to keep files sorted; give feedback to the department if a room feels cramped. |
# | **Support self‑paced learning** | Access recorded lectures and weekly learning paths so you can review content at your own speed. | Download lecture videos after class; follow the weekly roadmap provided in the LMS; pause, rewind, or skip ahead as needed. |
# | **Improve technical access and reliability** | Secure stable internet and have offline options when connectivity drops. | Use the campus Wi‑Fi hotspot or a personal hotspot as a backup; download PDFs or videos for offline study; keep the platform’s help guide handy and contact tech support early if problems arise. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Identify a quiet, comfortable study spot (library room, coffee shop with reliable Wi‑Fi, or a well‑ventilated area at home). |
# | **Day 3‑4** | Download this week’s lecture recordings and any PDFs to your device for offline use. |
# | **Day 5** | Review the LMS’s folder structure; rename or move files so they are easy to find. |
# | **Day 6‑7** | Test the campus Wi‑Fi; if it’s unstable, set up a personal hotspot as a backup. |
# | **Day 8‑10** | Follow the weekly learning path, pausing to revisit any concepts that need extra time. |
# | **Day 11‑12** | Contact technical support with any connectivity issues you encountered; note the solution for future reference. |
# | **Day 13‑14** | Give feedback on the study space and resource organization to your instructor or department. |
#
# ---
#
# **Remember:** Your engagement and desire for flexibility are strong assets. By improving your study environment, using self‑paced resources, and securing reliable technical access, you can keep your learning both active and effective. If you need further help, reach out to your course’s support team—they’re there to assist you.

# %% [markdown]
# ## Student ID: `e20240949`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240949*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are classified as a highly engaged student who typically participates actively in class and shows strong motivation to learn.
#
# *Note:* Because the open‑ended responses did not provide specific strengths or challenges, the recommendations below are drawn primarily from the characteristics of your segment.
#
# ---
#
# ### 2. Main Strengths
# - High level of engagement and willingness to take part in learning activities (inferred from segment).
#
# ---
#
# ### 3. Main Challenges
# - No specific challenges were reported. The suggestions focus on enhancing the resources that best support active learners like you.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation Title | What to Do |
# |-----|----------------------|------------|
# | **content_access** | Strengthen access to learning materials | Upload slides, videos, reference links, exercises, and other course materials **early** in the semester so you can review them whenever needed. |
# | **digital_skill** | Develop digital learning skills | Get brief guidance on using the LMS, online research tools, and educational technologies to make your study time more efficient. |
# | **engagement** | Increase learner engagement | Take part in quizzes, games, practical tasks, discussion boards, and other interactive activities that keep learning lively. |
# | **self_paced** | Support self‑paced learning | Use recorded lessons and weekly learning paths; revisit any material at your own speed to reinforce understanding. |
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Check that all lecture slides and videos are uploaded to the LMS; download them for personal review. |
# | **2** | Attend a short workshop or watch a tutorial on LMS navigation and digital research tools. |
# | **3** | Participate in the first interactive quiz or discussion activity for the course. |
# | **4** | Follow the weekly learning path; re‑watch any recorded lessons that feel unclear. |
# | **5‑8** | Continue using the above resources each week, noting any areas where you need extra support and reaching out to the instructor or tech help desk. |
#
# These steps align with the strengths of a highly engaged learner and give you the tools to stay organized, deepen your digital competence, and make the most of self‑paced study. Good luck, and enjoy the semester!

# %% [markdown]
# ## Student ID: `e20241091`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241091
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You value the **flexibility** that blended learning offers, allowing you to review lessons anytime.
# - You recognize the benefit of having **access to learning materials** both in‑class and online.
#
# **Main Challenges**
# - You would like the university to provide **better internet support** and clearer online materials.
# - You notice room for improvement in **interaction/communication** and the overall **learning environment** (clarity of resources, study spaces).
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to act |
# |----------------|----------------------|------------|
# | **Strengthen access to learning materials** | Get all slides, videos, references and exercises uploaded early so you can study whenever you need. | Check the course LMS regularly for new uploads; download materials for offline review. |
# | **Develop digital learning skills** | Learn how to use the LMS, online research tools and other educational technologies efficiently. | Attend any short “LMS‑tips” workshops or watch the university’s tutorial videos. |
# | **Increase interaction and communication** | More Q&A sessions, group discussions and quicker lecturer feedback will help you stay engaged. | Participate in scheduled online discussion boards; ask questions during live Q&A slots. |
# | **Improve learning resources and environment** | Clear, well‑organized materials and comfortable study spaces make learning smoother. | Use the “Resources” section of the LMS to find organized folders; consider quiet campus study areas or the library. |
# | **Improve clarity and learning support** | Clear instructions, examples and step‑by‑step guides reduce confusion. | Look for recorded explanations or ask the instructor for additional examples when a concept isn’t clear. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you study at your own speed. | Follow the weekly learning path posted by the instructor and revisit recorded lectures as needed. |
# | **Improve technical access and reliability** | Stable internet and offline options prevent technical disruptions. | Download needed files when you have good connectivity; contact the IT help desk for any connectivity issues. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–3:** Review the course LMS; download all available slides, videos and exercises for offline use.
# 2. **Day 4–7:** Watch the university’s “Getting Started with the LMS” tutorial (≈15 min).
# 3. **Day 8:** Join the first scheduled online Q&A session; prepare at least one question about the current topic.
# 4. **Day 9–10:** Locate the weekly learning path and set a personal study schedule that includes time for review.
# 5. **Day 11–12:** Test your internet connection in a campus study space; note any issues and submit a support ticket if needed.
# 6. **Day 13–14:** Reflect on the clarity of the materials you used; write down any unclear points and ask the lecturer for additional examples or recorded explanations.
#
# By following these steps, you’ll make the most of blended learning’s flexibility while strengthening interaction, digital skills, and technical reliability. Good luck!

# %% [markdown]
# ## Student ID: `e20240395`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240395
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Values **flexibility** and can manage time well (you noted that studying “anywhere” works for you).
#
# **Main Challenges**
# - No specific challenges were mentioned, so the advice focuses on what typically helps learners in your segment.
#
# **Personalized Recommendations**
# - **Support self‑paced learning** – Use recorded lectures, weekly learning paths, and downloadable materials so you can study when it best fits your schedule. This matches your preference for flexibility and aligns with the “self‑paced” recommendation for your segment.
#
# **Short Action Plan**
# 1. **Access recorded lessons** for each topic as soon as they are posted.
# 2. **Follow the weekly learning path** provided by the course platform, but feel free to adjust the order to suit your personal timetable.
# 3. **Review materials** (slides, notes, quizzes) at your own speed before moving on to the next week’s content.
# 4. **Set a personal study routine** (e.g., 1–2 hours per day) that fits around any other commitments you have.
#
# By taking advantage of self‑paced resources, you can keep studying in the flexible way that works best for you while staying on track with the course.

# %% [markdown]
# ## Student ID: `e20221709`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221709*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when learning is flexible and you can manage your own time.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value the ability to study when it fits your schedule.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You would like more interactive activities (e.g., games, quizzes, discussions).
# - **Internet & Technical Issues** – Unreliable connectivity sometimes hinders your study.
# - **Learning Resources & Environment** – A clearer, more comfortable study setting would help.
# - **Motivation & Self‑Discipline** – Occasionally you feel a dip in motivation.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | Join scheduled Q&A sessions, group discussions, and peer‑collaboration tasks; look for faster lecturer feedback. | Increases engagement and gives you the interactive activities you’re looking for. |
# | **Learning Environment** | Use organized digital folders, updated course materials, and a dedicated, comfortable study space (e.g., a quiet corner or library). | Clear resources and a good environment reduce distractions and support your flexible study style. |
# | **Motivation & Self‑Discipline** | Set up weekly check‑ins, automated reminders, and a simple progress‑tracking board; follow a structured weekly study schedule. | Regular checkpoints keep motivation high and help you stay on track. |
# | **Self‑Paced Learning** | Access recorded lectures and weekly learning paths that you can review anytime. | Lets you keep the flexibility you value while still covering all content. |
# | **Technical Access** | Use campus Wi‑Fi hotspots or download offline copies of materials; keep a quick‑reference guide for the learning platform and know how to contact tech support. | Reduces the impact of internet problems and ensures you can keep studying even when connectivity is spotty. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# 1. **Day 1‑2:** Create a dedicated study folder on your device and organize current course materials.
# 2. **Day 3‑4:** Download the next week’s lecture recordings for offline use.
# 3. **Day 5:** Join a scheduled Q&A or discussion forum; note any questions you have.
# 4. **Day 6:** Set up a simple weekly schedule (e.g., 2 hrs Mon/Wed/Fri) and add reminder alerts.
# 5. **Day 7:** Test campus Wi‑Fi or a hotspot; download any large files you’ll need for the coming week.
# 6. **Week 2:** Complete a brief self‑check‑in at the end of each study session (what you covered, what’s next, how motivated you feel). Adjust the schedule or seek peer help if motivation drops.
#
# ---
#
# By focusing on interaction, a supportive learning environment, motivation tools, self‑paced resources, and reliable technical access, you can keep leveraging your flexibility while overcoming the challenges you identified. Good luck, and keep up the active engagement!

# %% [markdown]
# ## Student ID: `e20230232`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230232*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a moderately engaged learner who tends to take a more passive role in class. You feel confident about **understanding the course material**, but you experience **wifi and other technical problems in the labs** that make learning harder.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You can obtain the course content when it is made available.
# - **Learning Convenience & Effectiveness:** You feel you grasp the material well when you can study it.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable wifi and technical glitches in the lab disrupt your study flow.
# - **Learning Resources & Environment:** The current setup of study spaces and resource organization does not fully support your learning.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What to Do | Why it Helps you |
# |----------------|------------|------------------|
# | **Strengthen access to learning materials** | • Ask the instructor to upload slides, videos, reference links, and practice exercises **early** in the week.<br>• Save copies for offline use. | Guarantees you have the content ready even when internet access is spotty. |
# | **Improve learning effectiveness** | • Use the uploaded online review materials **before** attending the in‑person session.<br>• During class, focus on the explanations, practice activities, and ask for quick feedback. | Combines the convenience of digital review with the clarity of face‑to‑face guidance, boosting retention. |
# | **Improve learning resources and environment** | • Keep a personal folder (digital or paper) where you organise all course files clearly.<br>• Choose a quiet, comfortable study spot (library, café with reliable wifi, or a designated campus area). | A well‑organised workspace reduces distractions and makes it easier to concentrate despite technical hiccups. |
# | **Improve technical access and reliability** | • Download materials for offline study when you have good connectivity.<br>• Keep a list of quick‑help contacts (IT help desk, teaching assistant).<br>• Follow any platform‑use guides provided by the course. | Having offline copies and clear support channels lessens the impact of lab wifi problems. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Check the course portal; download all available slides and videos for the upcoming topic. |
# | **Tuesday** | Create a simple folder structure (e.g., /Week1/Slides, /Week1/Exercises) on your laptop or cloud drive. |
# | **Wednesday** | Review the downloaded materials for 30 min, note any questions. |
# | **Thursday** | Attend the in‑person session; ask the instructor for clarification on any unclear points and request quick feedback on a practice problem. |
# | **Friday** | Save any new resources posted that day; back‑up the folder to a USB drive or offline location. |
# | **Weekend** | Find a quiet study spot with reliable wifi (library or café) and complete the practice exercises. |
# | **Next Monday** | Contact the IT help desk to report any persistent lab wifi issues and ask about alternative access options. |
#
# Follow these steps and the recommendations above to make your blended learning experience smoother, more reliable, and more effective. You’re already strong in understanding the material—these actions will help you keep that strength while reducing technical and environmental barriers. Good luck!

# %% [markdown]
# ## Student ID: `e20230409`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230409*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Easy access to course information and flexibility that helps you save time and money.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having slides, videos, and references readily available.
# - **Flexibility & Time Management** – You like being able to study when it fits your schedule.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Resources & Environment** – You find it difficult when video recordings are missing or when the study environment is not well‑organized.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it matters for you | What to do |
# |----------------|------------------------|------------|
# | **Strengthen access to learning materials** | You want to reduce costs (e.g., “gas money”) and get plenty of information quickly. | • Upload slides, videos, reference links, and exercises **early** in the course.<br>• Keep a single, searchable folder for each module. |
# | **Improve learning resources and environment** | Missing recordings and a cluttered space hinder your deep learning. | • Organize all materials clearly (e.g., by week or topic).<br>• Ensure study spaces (both physical and virtual) are comfortable and well‑equipped.<br>• Update resources regularly so you always have the latest version. |
# | **Support self‑paced learning** | Your active engagement works best when you can review content at your own speed. | • Provide recorded lessons that you can watch anytime.<br>• Offer weekly learning paths that outline what to study and when.<br>• Allow you to revisit exercises and quizzes as needed. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the themes you highlighted.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action | Expected Benefit |
# |------|--------|-------------------|
# | **1** | Check that all slides and reading lists for the current module are uploaded to the course portal. | Saves time searching for materials; reduces travel costs. |
# | **2** | Locate a quiet, well‑lit study spot (or set up a virtual “focus room”) and arrange your notes there. | Improves concentration for deeper learning. |
# | **3** | Watch the recorded lecture for the week, then follow the suggested learning path and complete the exercises. | Reinforces understanding at your own pace. |
# | **4** | Review the folder structure: rename any unclear files and add brief descriptions. | Makes future navigation faster and less stressful. |
#
# Follow these steps each month and adjust as needed. By strengthening material access, creating a better learning environment, and using self‑paced resources, you’ll keep your high engagement level while overcoming the current challenges.
#
# Good luck, and keep leveraging your active learning style!

# %% [markdown]
# ## Student ID: `e20230160`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "learning_support", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230160*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are classified as a **Highly Engaged (Active) Learner**. Your open response shows confidence in managing your time and preparing for lessons, indicating strong self‑regulation. The main difficulties you reported are unreliable internet access and limited contact with professors.
#
# ---
#
# ### 2. Main Strengths
# - **Time Management & Preparation** – You feel able to organise your study schedule and get ready for class.
# - **Access to Learning Materials** – You value having the resources you need to study effectively.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – It is hard to reach your professor and get timely feedback.
# - **Internet & Technical Issues** – Unstable connectivity hampers your online work.
# - **Learning Clarity** – You need clearer instructions and examples to understand the material fully.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Ensure all slides, videos, readings, and exercises are available early so you can study offline if needed. | Look for a course‑wide repository (e.g., LMS folder) and download materials at the start of each week. |
# | **Increase interaction and communication** | More opportunities for Q&A, group work, and quicker lecturer feedback will reduce the feeling of being “out of touch.” | Participate in scheduled live Q&A sessions, join study‑group chats, and use office‑hour slots (virtual or in‑person) to ask questions. |
# | **Improve learning effectiveness** | Pair online review content with face‑to‑face explanations and practice to deepen understanding. | After watching a lecture video, attend a short in‑person recap or workshop where you can apply concepts with instructor guidance. |
# | **Improve clarity and learning support** | Clearer instructions, examples, and step‑by‑step guides will help you overcome confusion. | Request or look for supplemental guides (e.g., recorded walkthroughs) and use them when a concept feels unclear. |
# | **Improve technical access and reliability** | Stable internet or offline options will keep you connected to the course. | Download materials for offline study, use campus Wi‑Fi or a reliable hotspot, and contact technical support when platform issues arise. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the course’s material folder on the LMS; download all week 1 resources for offline use. |
# | **Day 3** | Join the first scheduled Q&A session; prepare 2‑3 questions in advance. |
# | **Day 4‑5** | Attend an in‑person (or live‑online) recap workshop to practice the week 1 concepts. |
# | **Day 6** | Review the provided step‑by‑step guide or recorded explanation for any topic that felt unclear. |
# | **Day 7** | Test your internet connection; if unstable, arrange a campus hotspot or schedule offline study time. |
# | **Day 8‑10** | Form a small study group (2‑3 peers) for weekly peer‑collaboration and quick feedback. |
# | **Day 11‑14** | Reflect on the week: note which resources helped most, any remaining technical issues, and plan next week’s download and interaction schedule. |
#
# Follow this plan, and adjust as you discover what works best for your learning style. Your active engagement combined with clearer communication and reliable access will help you maintain high performance throughout the blended course.

# %% [markdown]
# ## Student ID: `e20210195`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210195*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You describe yourself as **flexible** in your approach to study.
# - You note that you sometimes feel **less motivated** and that your learning depends on a **good internet connection and a suitable study environment**.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you are able to adapt your schedule and manage your time when needed.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – unreliable connectivity can hinder your access to online content.
# - **Learning Resources & Environment** – you need a quiet, well‑equipped space and up‑to‑date materials to stay focused.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Improve learning resources and environment** | Organise your study materials clearly, keep digital resources up‑to‑date, and create a comfortable study space. | • Set up a dedicated desk with minimal distractions.<br>• Use a folder system (digital or paper) for lecture notes, readings, and assignments.<br>• Check that lighting, seating, and temperature are comfortable. |
# | **Support self‑paced learning** | Take advantage of recorded lectures and weekly learning paths so you can review content whenever your internet is stable. | • Watch recorded lessons at times when your connection is strongest (e.g., evenings).<br>• Follow the weekly learning path provided by the course and mark completed items.<br>• Re‑watch difficult sections until you feel confident. |
# | **Improve technical access and reliability** | Ensure you have a reliable internet link and offline options, plus clear guidance on using the learning platform. | • Identify a location on campus or a public space with stable Wi‑Fi for critical tasks.<br>• Download lecture videos, PDFs, and other resources ahead of time for offline study.<br>• Keep the platform’s help guide bookmarked and contact technical support early if problems arise. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | List all course materials you need; create a folder structure (e.g., Lectures, Readings, Assignments). |
# | **Day 3‑4** | Locate a reliable internet spot (library, café, campus hub) and test download speeds. |
# | **Day 5‑7** | Download the next week’s recorded lectures and PDFs for offline use. |
# | **Day 8** | Set up a quiet study corner with good lighting and a comfortable chair. |
# | **Day 9‑10** | Follow the weekly learning path; mark each completed item in your planner. |
# | **Day 11‑12** | Review any concepts that felt unclear; re‑watch the relevant video sections. |
# | **Day 13‑14** | Check the platform’s help resources; note any technical issues and contact support if needed. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset. By improving your study environment, using self‑paced resources, and securing reliable technical access, you can turn passive engagement into more active, confident learning. Good luck!

# %% [markdown]
# ## Student ID: `e20230135`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230135*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Easy access to materials and the flexibility to manage your own time.
# - **What you find challenging:** Feeling less connected with peers and occasional internet/technical problems.
#
# ---
#
# ### 2. Main Strengths
# - **Accessibility & Flexibility** – you appreciate having course content available whenever you need it, which helps you stay organized and manage your schedule effectively.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – you miss the sense of community that comes from regular peer contact.
# - **Internet & Technical Issues** – unreliable connectivity can interrupt your study flow.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it matters for you | What to do |
# |----------------|------------------------|------------|
# | **Strengthen access to learning materials** | Supports your need for flexibility and quick reference. | Upload slides, videos, readings, and practice exercises **early** in the week so you can download or view them anytime. |
# | **Increase interaction and communication** | Helps rebuild peer connection and keeps you engaged. | Add short **Q&A sessions**, set up **small‑group discussion boards**, and encourage **peer‑review activities**. Request faster feedback from lecturers when possible. |
# | **Support self‑paced learning** | Lets you review content at your own speed, reinforcing understanding. | Provide **recorded lectures** and a **weekly learning path** that outlines what to study each day, with optional checkpoints. |
# | **Improve technical access and reliability** | Reduces interruptions caused by poor internet or platform confusion. | Offer **offline downloadable resources**, clear step‑by‑step platform guides, and a dedicated **technical‑support contact** for quick help. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Check that all upcoming lecture slides and videos are uploaded to the LMS; download them for offline use. |
# | **Day 3** | Join a newly created **peer‑discussion forum** for the course; post an introductory comment. |
# | **Day 4‑5** | Review the **weekly learning path** (provided by the instructor) and schedule 30‑minute study blocks for each topic. |
# | **Day 6** | Attend the first **live Q&A** session; note any technical glitches and report them to support. |
# | **Day 7‑10** | Complete a short **peer‑feedback activity** on a class assignment; request feedback on your own work. |
# | **Day 11‑12** | Test the **offline material download** process; ensure you can access PDFs and videos without internet. |
# | **Day 13‑14** | Reflect on the week: Did interaction feel better? Was any technical issue still a barrier? Share feedback with the course team. |
#
# ---
#
# **Remember:** Your strong engagement and desire for flexible, accessible learning are assets. By adding structured interaction opportunities and ensuring reliable technical support, you can keep the momentum while feeling more connected to your classmates. Feel free to reach out to your lecturer or the support desk if any of these steps need clarification. Good luck!

# %% [markdown]
# ## Student ID: `e20240444`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240444*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically participates actively in class, enjoys using digital resources, and values flexibility in how they study.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials & Convenience** – You appreciate being able to stay indoors, especially in summer, and like that you can re‑watch lecture videos whenever you need them.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – You noted that reliable mobile data is needed for students who don’t have home Wi‑Fi.
# - **Learning Resources & Environment** – The need for a stable, comfortable study setting was mentioned.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Instructors should upload slides, videos, reference links, and exercises **early** in the course. | Gives you everything you need to review at your own pace, reinforcing the convenience you value. |
# | **Improve learning effectiveness** | Combine the online review materials with brief in‑person explanations, practice activities, and feedback sessions. | Helps you apply what you’ve watched, deepening understanding and keeping you actively engaged. |
# | **Improve learning resources and environment** | Course pages should be clearly organized; study spaces (both physical and virtual) should be comfortable and well‑maintained. | A tidy, well‑structured environment reduces distraction and supports your active learning style. |
# | **Improve technical access and reliability** | Provide options for **offline downloads** of videos and readings, clear step‑by‑step platform guides, and quick technical support. | Ensures you can keep studying even when mobile data is limited or internet connectivity is unstable. |
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How to do it |
# |------|--------|--------------|
# | **1** | Check the course portal for any **early‑uploaded** materials (slides, videos, exercises). | Download what you can for offline use. |
# | **2** | Attend a short **in‑person recap** or virtual live Q&A to clarify any confusing points from the videos. | Prepare one question beforehand. |
# | **3** | Review the **organization** of the course site; if anything is unclear, send a quick note to the instructor. | Use the “feedback” feature or email. |
# | **4** | Test the **offline download** option and keep a backup copy of essential files on your device. | Follow the platform’s download guide; contact tech support if needed. |
# | **Ongoing** | Use a **quiet study space** (library corner, study room, or a well‑lit spot at home) and schedule regular review sessions. | Set a weekly calendar reminder. |
#
# ---
#
# **Remember:** Your active engagement is a strong asset. By ensuring you have reliable access to well‑organized materials and a stable technical setup, you can make the most of both online and face‑to‑face learning experiences. If you encounter any technical difficulties, reach out to your university’s support desk promptly. Good luck, and keep up the great work!

# %% [markdown]
# ## Student ID: `M080402`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080402*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you shared:** You describe your learning style as “flexible and fun.”
# - **Current challenge:** Unreliable internet connection.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you like to adapt your study schedule and keep learning enjoyable.
# - **Student Engagement** – you are actively involved in class activities.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – occasional connectivity problems can interrupt online work.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to do (based on the rule‑based advice) |
# |------|---------------------------------------------|
# | **Engagement** | • Add short quizzes, games, or practical tasks to each module.<br>• Join discussion boards or small‑group chats to keep the learning lively. |
# | **Self‑paced learning** | • Use recorded lectures and weekly learning paths so you can study when your connection is stable.<br>• Review materials at your own speed before moving on. |
# | **Technical access** | • Download offline copies of readings, videos, and assignments when you have good connectivity.<br>• Keep a list of quick‑step platform guides and know how to contact technical support if the connection drops. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify which lecture videos and readings can be downloaded for offline use. |
# | **Day 3–5** | Set up a weekly learning path (e.g., “Monday – watch video; Wednesday – quiz; Friday – discussion post”). |
# | **Day 6–7** | Try one interactive activity (quiz or game) and note how it affects your motivation. |
# | **Week 2** | Test the offline materials during a low‑connectivity period; if problems persist, contact tech support using the platform’s help desk. |
# | **End of Week 2** | Reflect on which strategies kept you most engaged and adjust the next week’s plan accordingly. |
#
# ---
#
# **Remember:** Your flexibility and enthusiasm are strong assets. By pairing engaging, self‑paced resources with reliable offline options, you can keep learning fun even when internet access is spotty. If you need help setting up offline files or finding interactive activities, your university’s digital‑learning support team is ready to assist. Good luck!

# %% [markdown]
# ## Student ID: `e20240488`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240488
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value the **flexibility** that blended learning offers, which helps you manage your time effectively.
#
# **Main Challenges**
# - You experience **internet/technical problems** that can disrupt your online study sessions.
#
# **Personalized Recommendations**
#
# | Recommendation | Why it matters for you | What to do |
# |----------------|------------------------|------------|
# | **Support self‑paced learning** | Your strong engagement and appreciation for flexibility mean you benefit from being able to study when it suits you. | • Use recorded lectures and weekly learning paths provided by the university.<br>• Review materials at your own speed and revisit concepts as needed. |
# | **Improve technical access and reliability** | Unstable internet can break your learning flow, especially when you’re actively participating. | • Take advantage of any campus Wi‑Fi hotspots or loaner devices offered.<br>• Download offline versions of readings and videos when you have a good connection.<br>• Keep the platform’s help guide handy and contact technical support promptly when issues arise. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Download offline resources** – Identify one upcoming module, download its videos/ PDFs, and study them without needing a live connection.
# 2. **Set a weekly learning path** – Follow the recorded lessons schedule provided by your course, marking progress each day.
# 3. **Test technical support** – Locate the university’s IT help desk contact info and submit a test ticket to confirm response times.
# 4. **Create a backup plan** – Note nearby locations (library, café) with reliable Wi‑Fi for times when your primary connection fails.
#
# By leveraging self‑paced tools and securing reliable technical access, you can keep your high level of engagement while minimizing disruptions. Good luck!

# %% [markdown]
# ## Student ID: `e20230142`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230142*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are already motivated and make good use of study resources. Your brief feedback indicated a wish for more video recordings of the material.
#
# ### 2. Main Strengths
# - You actively seek out and use studying sources.
#
# ### 3. Main Challenges
# - You would like additional video recordings to support your learning.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps you |
# |------|------------|------------------|
# | **Content Access** | Upload slides, videos, reference links, exercises, and other course materials **early** in the semester. | Gives you the resources you need right away, including the extra video recordings you asked for. |
# | **Digital Skills** | Offer short guides or short live demos on how to use the LMS, locate online resources, and employ digital research tools. | Strengthens your ability to find, organise, and use digital content efficiently. |
# | **Engagement** | Include interactive elements such as quick quizzes, gamified tasks, practical assignments, and discussion prompts. | Keeps your high energy focused and deepens understanding through active participation. |
# | **Self‑Paced Learning** | Provide recorded lessons and a weekly learning path that you can review at any time. | Lets you study at your own speed, revisit complex topics, and fit learning around your schedule. |
#
# *These recommendations are based primarily on the characteristics of the “Highly Engaged (Active) Learners” segment, complemented by your expressed desire for more video material.*
#
# ### 5. Short Action Plan
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Check the course portal for uploaded slides and any available videos. | Immediate access to core materials. |
# | 2 | Attend a 15‑minute LMS tutorial (live or recorded). | Faster navigation of digital resources. |
# | 3 | Complete the first interactive quiz and join a discussion thread. | Reinforce learning and stay engaged. |
# | 4 | Review the recorded lesson for any topics you found challenging. | Consolidate knowledge at your own pace. |
# | Ongoing | Provide feedback on the usefulness of new video recordings and other resources. | Help the instructor keep the material aligned with your needs. |
#
# Stay proactive, make use of the early‑released content, and take advantage of the interactive and self‑paced options to keep your learning both effective and enjoyable. Good luck!

# %% [markdown]
# ## Student ID: `e20240867`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240867*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are identified as a highly engaged student who tends to participate actively in class and online activities. Because your open‑ended responses about strengths and challenges were not provided, the recommendations below are drawn primarily from the typical profile of this segment.
#
# ### 2. Main Strengths
# - (No specific strengths were reported.)
# - *Based on the segment*, highly engaged learners usually show strong motivation and willingness to interact with course content.
#
# ### 3. Main Challenges
# - (No specific challenges were reported.)
# - *Based on the segment*, active learners can benefit from additional structure that lets them control the pace of learning and deepen digital skills.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Having all slides, videos, readings, and exercises available early lets you dive in whenever you’re ready. | Upload or request early access to all course resources; bookmark them in your LMS. |
# | **Develop digital learning skills** | Mastering LMS tools, online research, and educational tech helps you work more efficiently. | Attend a short tutorial on the LMS, explore built‑in help guides, and practice using digital libraries and citation tools. |
# | **Increase learner engagement** | Interactive quizzes, games, practical tasks, and discussion forums keep your high energy focused and deepen understanding. | Participate in weekly polls, join discussion boards, and try out any gamified activities the instructor provides. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you review concepts on your own schedule, reinforcing what you’ve learned. | Save recorded lectures, follow the suggested weekly roadmap, and revisit any material that feels challenging. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s central repository (LMS) and download all available slides, videos, and reading lists. |
# | **Day 3** | Watch the introductory tutorial on LMS navigation and try a practice search in the digital library. |
# | **Day 4–5** | Complete the first set of interactive quizzes or polls; note any topics that need review. |
# | **Day 6–7** | Review the recorded lecture for the week; add personal notes or short summaries. |
# | **Week 2** | Join at least one discussion thread or group activity; share a brief insight or question. |
# | **End of Week 2** | Reflect on which digital tools helped you most and plan to use them for the next module. |
#
# ---
#
# **Remember:** Your high level of engagement is a strong asset. By securing early access to materials, sharpening your digital skills, staying active in interactive tasks, and using self‑paced resources, you’ll maximize both your learning efficiency and enjoyment throughout the course. Good luck!

# %% [markdown]
# ## Student ID: `e20220699`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220699*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated, take initiative, and value flexibility that helps you manage your time efficiently.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You appreciate tools that let you *save time and reduce costs* while studying.
#
# ### 3. Main Challenges
# - **Assessment & Workload:** You note that *there is a time limit for reviewing lessons*, which can create pressure around assignments and exams.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | What to do |
# |----------------|------------------|------------|
# | **Support self‑paced learning** (tag: *self_paced*) | Matches your strength in managing time and wanting flexibility. | • Use recorded lectures and weekly learning paths.<br>• Access all materials online so you can review them whenever it fits your schedule. |
# | **Manage workload and assessment pressure** (tag: *workload_support*) | Addresses the challenge of limited review time and helps keep assignments realistic. | • Look for clear deadlines and balanced assignment loads.<br>• Align online tasks with in‑person sessions so you can prepare efficiently.<br>• Use any provided workload‑planning tools or checklists. |
#
# These recommendations are drawn directly from the evidence for your segment and the specific strengths and challenges you reported.
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Locate the recorded lessons for your current module and add them to your personal study calendar. |
# | **Week 2** | Review the weekly learning path; note any upcoming deadlines and flag any that seem tight. |
# | **Week 3** | Meet with the course tutor or use the online forum to clarify assignment expectations and confirm due dates. |
# | **Week 4** | Use a simple workload tracker (e.g., a spreadsheet or app) to allocate study time for each lesson, ensuring you have buffer time for review before assessments. |
# | **Ongoing** | Keep revisiting recorded lessons as needed and adjust your study plan whenever new deadlines are announced. |
#
# By following this plan, you can keep leveraging your strong time‑management skills while reducing the pressure of tight review windows. Good luck, and keep up the active engagement!

# %% [markdown]
# ## Student ID: `e20240595`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240595*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to **Cluster 2: Highly Engaged (Active) Learners**. This segment is characterised by strong motivation to use both online and face‑to‑face resources and a willingness to take responsibility for your own learning.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You find it easy to study after class by reviewing online slides, videos, and doing extra research.
# - **Learning Convenience & Effectiveness** – The ability to revisit content online helps you understand points that were unclear during class.
#
# ### 3. Main Challenges
# - **Learning Resources & Environment** – You would like new lessons, exercises, and reference materials to be updated regularly and presented in a well‑organized way.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Ensure all course assets (slides, videos, readings, exercises) are available early and in one place. | • Ask your instructor to upload the full set of materials to the LMS before the first class meeting.<br>• Use a personal folder or cloud drive to keep everything organised. |
# | **Improve learning effectiveness** (learning_effectiveness) | Combine the convenience of online review with active in‑class practice and feedback. | • After watching a video, write a brief summary or create a mind‑map.<br>• Bring specific questions to class for the instructor’s explanation and peer discussion.<br>• Complete the provided exercises and seek quick feedback. |
# | **Improve learning resources and environment** (learning_environment) | Keep the learning space (both digital and physical) tidy, up‑to‑date, and comfortable. | • Use the course’s content page to check for the latest updates each week.<br>• Organise digital files by week or topic for quick retrieval.<br>• Choose a quiet study spot with good lighting and minimal distractions; if possible, personalize it with needed supplies. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Verify that the course’s LMS contains all slides, videos, and reading lists for the upcoming week. If anything is missing, request it from the instructor. |
# | **Day 3** | Create a personal “Week 1” folder (PDFs, links, notes) and add a brief summary of each video you watch. |
# | **Day 5** | Complete the first set of practice exercises; submit them for feedback or discuss answers with a study buddy. |
# | **Day 7** | Review the updated resources; note any gaps and ask the instructor to add references or additional exercises. |
# | **Day 10** | Arrange a tidy, well‑lit study space; keep all digital files organized for quick access. |
# | **Day 14** | Reflect on how the combined online review and in‑class practice helped your understanding; adjust your routine as needed. |
#
# ---
#
# By following these focused steps, you’ll make the most of your strong engagement while addressing the need for up‑to‑date, well‑organized resources. Keep leveraging the convenience of online materials and pair them with active classroom participation for the best learning outcomes. Good luck!

# %% [markdown]
# ## Student ID: `e20230118`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230118*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. Your responses show a strong appreciation for the **flexibility and convenience** that blended formats provide, as well as the **higher level of student engagement** they enable. The main difficulty you mentioned is **internet and technical problems**, especially the need for a reliable connection.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you value |
# |-------|----------------|
# | **Flexibility & Time Management** | Ability to study when it fits your schedule. |
# | **Student Engagement** | Interactive, lively learning experiences. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What is difficult |
# |-------|-------------------|
# | **Internet & Technical Issues** | Unstable or slow internet makes online activities hard. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|------------------|
# | **Increase learner engagement** (engagement) | Use quizzes, games, practical tasks, discussions, and other interactive activities to keep the class lively and maintain your high motivation. |
# | **Support self‑paced learning** (self_paced) | Access recorded lectures, weekly learning paths, and downloadable materials so you can study when your connection is stable and review content as needed. |
# | **Improve technical access and reliability** (tech_issue) | Take advantage of offline resources, clear platform guides, and university technical support to minimise disruption from internet problems. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Day 1–2** | Locate the course’s recorded lectures and download the first week’s videos for offline viewing. |
# | **Day 3** | Join a discussion forum or group chat for the module; post a question or comment to start engaging with peers. |
# | **Day 4–5** | Complete a short quiz or interactive activity related to the current topic; note any technical hiccups. |
# | **Day 6** | Test the university’s technical support portal: submit a ticket about your internet reliability and ask about offline material options. |
# | **Week 2** | Follow the weekly learning path at your own pace, using downloaded videos when the connection is weak, and participate in at least one live discussion or game‑based activity. |
#
# By focusing on interactive content, self‑paced resources, and reliable technical support, you can keep your high engagement level while overcoming internet challenges. Good luck, and enjoy the flexibility that blended learning offers!

# %% [markdown]
# ## Student ID: `e20220741`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220741*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically makes good use of digital resources, enjoys flexible study times, and thrives when learning materials are readily available.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate being able to watch videos whenever you want, which shows you are comfortable using on‑demand content.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You feel that online classes can suffer when students are not paying attention.
# - **Motivation & Self‑Discipline** – You notice a lack of teacher‑driven motivation can make it harder to stay focused.
#
# ### 4. Personalized Recommendations
# | Focus | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | **Upload all course slides, videos, reference links, and exercises early in the week.** | Gives you and your peers the flexibility to study when you’re most alert, reinforcing your strength in using on‑demand video. |
# | **Interaction** | **Add regular Q&A sessions, small‑group discussions, and peer‑collaboration tasks. Provide quicker feedback on assignments.** | Increases real‑time engagement, keeping online learners attentive and creating a sense of community. |
# | **Motivation** | **Implement weekly check‑ins, automated reminders, and a simple progress‑tracking dashboard. Encourage students to set a short, structured study schedule each week.** | Supports self‑discipline and maintains motivation even when teacher prompts are less frequent. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Who’s Responsible |
# |------|--------|--------------------|
# | 1 | Upload all lecture slides, video recordings, and supplemental readings **by Monday**. | Lecturer / Course admin |
# | 1 | Schedule a 30‑minute live Q&A **Wednesday** and create a discussion forum for the week. | Lecturer |
# | 1 | Send an automated reminder on **Friday** with a simple study‑schedule template (e.g., “Watch video 1, complete exercise A”). | LMS/TA |
# | 2 | Run a peer‑collaboration activity (e.g., small breakout groups) **Tuesday**. | Lecturer |
# | 2 | Provide quick feedback on the first set of exercises **by Thursday**. | Lecturer / TA |
# | 2 | Share a progress‑tracking snapshot (e.g., % of videos watched, exercises completed) **Friday**. | LMS |
#
# Follow these steps to keep your learning experience flexible, interactive, and motivating. If you encounter any difficulties, reach out to your lecturer or teaching assistant for additional support. Good luck!

# %% [markdown]
# ## Student ID: `e20231279`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20231279*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# - **Strengths you highlighted:** Flexibility and the ability to save time while studying.
# - **Challenges you mentioned:**
#   1. **Interaction & Communication** – feedback from lecturers takes a long time and opportunities for dialogue are limited.
#   2. **Learning Resources & Environment** – the quality of materials is poor and the learning environment lacks adequate resources.
#
# Your overall sentiment shows confidence in your strengths (positive) and frustration with the challenges (negative).
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you make good use of flexible study options to manage your schedule efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Slow feedback and limited interaction** with peers and instructors.
# - **Insufficient or low‑quality learning materials** and a learning environment that does not fully support your needs.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How it helps |
# |----------------|----------------------|--------------|
# | **Increase interaction and communication** | Add regular Q&A sessions, group discussions, peer‑collaboration activities, and ensure faster lecturer feedback. | You’ll receive timely answers, deepen understanding, and stay motivated through active dialogue. |
# | **Improve learning resources and environment** | Organize course materials clearly, update outdated resources, and enhance study spaces (e.g., comfortable seating, good lighting, reliable internet). | Higher‑quality content and a better physical/virtual environment will reduce frustration and support effective study. |
# | **Support self‑paced learning** | Provide recorded lectures, weekly learning paths, and downloadable materials you can review whenever you need. | Keeps the flexibility you value while giving you control over the pace of learning. |
#
# These three recommendations align with the tags **interaction**, **learning_environment**, and **self_paced**, which were identified as most relevant for you.
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Join a study group or forum for your course; schedule a 30‑min Q&A with the lecturer. | Immediate increase in peer interaction and quicker clarification of doubts. |
# | 2 | Request a consolidated list of course materials; suggest a shared folder with organized files. | Easier access to high‑quality resources; reduced time searching for information. |
# | 3 | Start using recorded lectures to review concepts you find difficult; set a personal weekly learning path. | Reinforces self‑paced study and maximizes the flexibility you already enjoy. |
# | 4 | Provide feedback to the instructor about the speed of their responses and the clarity of resources. | Helps improve the overall learning environment for you and future students. |
#
# ---
#
# **Remember:** Your engagement is a strong asset. By enhancing interaction, upgrading resources, and leveraging self‑paced tools, you can turn the current challenges into opportunities for deeper learning and greater satisfaction. If you need further support, your academic advisor or the university’s learning‑technology office can help implement these steps. Good luck!

# %% [markdown]
# ## Student ID: `e20241053`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241053*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to engage with course content by saving and re‑watching videos, which shows a preference for reviewing material at your own pace.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You make good use of video recordings and are able to revisit them whenever needed.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** You noted that the school’s internet service needs improvement, which can limit timely access to online resources.
# - **Learning Resources & Environment:** A more supportive study environment would help you get the most out of the material.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Keep a well‑organized library of all course assets so you can download and review them offline. | • Instructors will upload slides, videos, reference links, and exercises early in the week.<br>• Save these files to your device or a cloud folder for later review. |
# | **Improve learning resources and environment** (learning_environment) | A clearer, more comfortable study setting helps you focus when re‑watching content. | • Use a dedicated study space with minimal distractions.<br>• Ask the department to keep classroom resources (handouts, whiteboards) tidy and up‑to‑date.<br>• Arrange seating or lighting to suit your comfort. |
# | **Improve technical access and reliability** (tech_issue) | Reliable internet and clear platform guidance reduce interruptions while you’re reviewing material. | • Request campus IT support for stronger Wi‑Fi or a wired connection in study areas.<br>• Download videos and PDFs when you have good connectivity so you can study offline.<br>• Keep a short “how‑to” guide for the learning platform handy, and contact tech support promptly if issues arise. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate a quiet study spot on campus; check the Wi‑Fi signal strength. |
# | **Day 3** | Download this week’s lecture videos and slides to your laptop/tablet. |
# | **Day 4** | Review the downloaded material at your own pace; note any unclear points. |
# | **Day 5** | Contact campus IT (or your tutor) to report the internet issue and ask about offline access options. |
# | **Day 6–7** | Organize the downloaded files into clearly labeled folders (e.g., “Week 3 – Marketing”). |
# | **Week 2** | Attend a short session (in‑person or virtual) to confirm that all materials are uploaded early and that the study environment is comfortable. |
#
# By following these steps, you’ll maximize the benefit of the blended‑learning format while minimizing technical and environmental barriers. Keep track of what works best for you and share any further needs with your instructors or support services. Good luck!

# %% [markdown]
# ## Student ID: `e20240912`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_environment", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240912*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can study independently and appreciate clear, calm explanations. You value the convenience of being able to review material on your own, especially when classroom instruction isn’t immediately clear.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You make good use of self‑study opportunities and find calm, easy‑to‑follow explanations helpful.
#
# ### 3. Main Challenges
# - **Assessment & Workload** – You notice that assignment feedback can be slow, which makes it harder to correct misunderstandings quickly.
# - **Interaction & Communication** – More timely interaction with teachers and peers would help you stay on track.
# - **Learning Resources & Environment** – Better‑organized materials and a comfortable study space would support your learning.
#
# ### 4. Personalized Recommendations
# | Focus | What to Do (based on the rule‑based advice) |
# |-------|---------------------------------------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request faster feedback from lecturers after submitting work. |
# | **Learning Effectiveness** | • Pair online review videos with in‑person explanations and practice exercises.<br>• Seek brief feedback loops after each practice session. |
# | **Learning Environment** | • Use a clearly organized digital folder structure for all course materials.<br>• Choose a quiet, comfortable study spot; consider campus study rooms that are well‑lit and ergonomically set up.<br>• Keep resources (e.g., lecture slides, recordings) up‑to‑date by checking the course portal regularly. |
# | **Workload Support** | • Create a personal calendar that marks assignment deadlines and aligns online tasks with upcoming face‑to‑face classes.<br>• Break larger assignments into smaller milestones to avoid last‑minute pressure.<br>• Communicate with the instructor early if workload feels unbalanced. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Set up a dedicated digital folder for the course; label sections (lecture videos, notes, assignments). |
# | **Day 3** | Add the next scheduled Q&A session to your calendar and prepare 2‑3 questions in advance. |
# | **Day 4‑5** | Review a recent online lecture, then meet with a classmate for a 30‑minute discussion to compare notes. |
# | **Day 6** | Submit the upcoming assignment early and request feedback within 48 hours. |
# | **Day 7** | Choose a comfortable study space (library room or quiet café) and test it for a short study block. |
# | **Day 8‑10** | Break the next major assignment into 3 milestones; set mini‑deadlines in your calendar. |
# | **Day 11‑14** | Reflect on the week: note which interaction or resource improvements helped most, and adjust your plan accordingly. |
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By adding structured interaction, clearer resources, and balanced workload strategies, you can turn your self‑study strengths into even more effective learning outcomes. Feel free to reach out to your instructors or the learning support team for any of the steps above. Good luck!

# %% [markdown]
# ## Student ID: `e20230091`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230091
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You value having access to learning materials (e.g., slides, videos, references) so you can review the lesson before the in‑person class.
#
# **Main Challenges**
# - You would like the teaching sessions to be recorded on video, which would give you a more flexible learning environment.
#
# **Personalized Recommendations**
#
# | Recommendation Tag | What It Means for You | Suggested Action |
# |--------------------|-----------------------|------------------|
# | **content_access** | Make sure all course content is available early and in a variety of formats. | • Upload slides, video recordings, reference links, and practice exercises at least a few days before each class. |
# | **learning_environment** | Improve how the materials are organized and ensure the study space is comfortable. | • Use a clear folder structure (e.g., “Week 1 – Slides,” “Week 1 – Videos”). <br>• Keep the classroom or study area tidy, with good lighting and seating. <br>• Provide recorded video of each lecture for later review. |
#
# **Short Action Plan**
#
# 1. **Before each class** – Check the course platform for the uploaded slides, video, and any extra resources. If anything is missing, contact the instructor or teaching assistant.
# 2. **Create a personal folder** – Organize the downloaded materials by week/topic so you can find them quickly.
# 3. **Set up a comfortable study space** – Choose a quiet spot with good lighting and a comfortable chair; keep all materials within reach.
# 4. **Use recordings** – After each lecture, watch the recorded video to reinforce what was covered and fill any gaps.
#
# These steps align with the strengths and challenges identified for your learner profile and should help you engage more actively with the blended course. Good luck!

# %% [markdown]
# ## Student ID: `e20230267`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230267*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated, use the platform frequently, and value the ability to study whenever and wherever you want.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You appreciate that blended learning lets you learn at your own pace and on your own schedule.
# - **Access to Learning Materials:** The rich collection of slides, videos, and references is a clear advantage for you.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity:** You find some modules hard to use because the content feels unorganized.
# - **Learning Resources & Environment:** The interface is not attractive, making it harder to focus and navigate.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to act on it |
# |----------------|----------------------|------------------|
# | **Strengthen access to learning materials** | Keep getting early access to all slides, videos, exercises, and reference links. | Check the course portal each week for newly uploaded resources; download them ahead of class so you can study offline. |
# | **Improve learning resources and environment** | A clearer, better‑organized module will reduce confusion and make study time more comfortable. | Use the “Modules” view to see a logical folder structure; if something feels messy, flag it to the instructor. Look for a quiet study space (library, study rooms) and adjust screen settings for comfort. |
# | **Improve clarity and learning support** | Clear instructions, examples, and step‑by‑step guides will help you work through difficult content. | Watch recorded explanations before attempting assignments; use the provided examples as templates; ask questions in discussion forums or during virtual office hours. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you review material whenever you need. | Follow the weekly learning path checklist; replay recorded lessons if a concept isn’t clear; set personal milestones to stay on track. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course announcement page for any newly uploaded slides or videos. Download all materials for the upcoming module. |
# | **Day 3** | Create a simple folder structure on your computer (e.g., “Week 1 – Slides”, “Week 1 – Videos”) to keep resources organized. |
# | **Day 4–5** | Watch the recorded lesson for the current topic; take notes on any steps that are unclear. |
# | **Day 6** | Post at least one question in the forum about a confusing part of the module; request an example or clarification. |
# | **Day 7** | Draft a personal weekly learning path (what to study each day) and share it with a study buddy for accountability. |
# | **Week 2** | Repeat the cycle: download new materials, organize them, watch recordings, seek support, and adjust your learning path as needed. |
#
# ---
#
# **Keep leveraging your strong engagement and flexibility, while using the above steps to make the learning environment clearer and more organized.** You’re well‑positioned to succeed in a blended setting—just add a bit of structure and targeted support. Good luck!

# %% [markdown]
# ## Student ID: `e20230371`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["engagement", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230371*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You appreciate the **flexibility** of online classes, which let you study at your own pace, while you also value the **focus and immediate feedback** you get from face‑to‑face sessions. Your main concern is reliable internet and a comfortable, clean physical learning space.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You can work comfortably online when you’re not rushed.
# - **Student Engagement** – You notice that in‑person classes help you stay focused and ask questions quickly.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable or slow Wi‑Fi hampers your online work.
# - **Learning Resources & Environment** – Classroom spaces need better cleaning and a more comfortable setup.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Engagement** | • Add short quizzes, quick polls, or mini‑games to both online and face‑to‑face sessions.<br>• Include brief discussion prompts or practical tasks after each topic. | Keeps you actively involved and reinforces learning without feeling passive. |
# | **Learning Environment** | • Ask the department for a dedicated Wi‑Fi hotspot or a “quiet study zone” with reliable connection.<br>• Request regular cleaning of classrooms and consider a small personal comfort item (e.g., a cushion). | Improves focus and reduces distractions caused by technical or physical discomfort. |
# | **Self‑Paced Support** | • Use recorded lectures and weekly learning paths that you can revisit at any time.<br>• Keep a personal checklist of what to review before the next live class. | Lets you blend the convenience of online study with the structure of scheduled sessions. |
# | **Tech Issues** | • Download offline copies of readings and videos when you have good connectivity.<br>• Keep a quick‑reference guide for the learning platform and know how to contact technical support. | Guarantees you can keep studying even when the internet is unreliable. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify a reliable spot on campus (library, lounge) with strong Wi‑Fi; note its hours. |
# | **Day 3–4** | Download this week’s lecture recordings and reading materials for offline use. |
# | **Day 5** | Create a 5‑minute quiz for yourself on the last topic (use a free app like Quizizz). |
# | **Day 6–7** | Attend the next face‑to‑face class, bring a small comfort item (e.g., cushion) and note any environment issues to report. |
# | **Day 8** | Send a brief email to the department requesting a dedicated Wi‑Fi hotspot or cleaner classroom space. |
# | **Day 9–10** | Review the recorded lessons using your weekly learning path; mark any questions to ask in the next live session. |
# | **Day 11–12** | Participate in an online discussion or group chat, using a poll or quick game to test understanding. |
# | **Day 13–14** | Reflect on what worked best (quiz, offline study, environment) and adjust the plan for the following fortnight. |
#
# ---
#
# **Remember:** Your blend of online flexibility and in‑person focus is a strength. By tightening up the technical side and shaping a comfortable study environment, you’ll be able to engage more actively and learn at a pace that fits you best. Good luck!

# %% [markdown]
# ## Student ID: `e20240970`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240970*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** *Cluster 1 – Moderately Engaged (Passive) Learners*
# - **Self‑reported strength:** Discipline
# - **Self‑reported challenge:** Feeling sad (negative affect)
#
# Because the open‑ended responses are brief, the recommendations below rely primarily on the characteristics of the “Moderately Engaged (Passive) Learners” segment.
#
# ---
#
# ### 2. Main Strengths
# - **Discipline:** You are able to follow schedules and keep to a study routine, which is a solid foundation for independent work.
#
# ---
#
# ### 3. Main Challenges
# - **Low mood / sadness:** This can reduce motivation and make it harder to stay engaged with the material.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | Why it Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join short Q&A sessions after each lecture.<br>• Participate in small‑group discussions or peer‑collaboration activities.<br>• Request quicker feedback from the lecturer. | Increases social contact, breaks passive habits, and gives you a sense of community. |
# | **Learning Support** | • Look for clear, step‑by‑step guides and recorded explanations for each topic.<br>• Use example problems provided by the instructor. | Reduces uncertainty and makes the material easier to follow, supporting your disciplined study habits. |
# | **Motivation** | • Set up a weekly check‑in with yourself or a study buddy to review progress.<br>• Use a simple tracker (e.g., checklist or app) to mark completed tasks.<br>• Schedule brief, regular reminders for study blocks. | Keeps momentum visible, helps counter low mood, and leverages your discipline. |
# | **Self‑Paced Learning** | • Access recorded lessons so you can review them when you feel ready.<br>• Follow the weekly learning path but feel free to adjust the pace to match your energy level. | Allows you to study when you feel most motivated, while still maintaining structure. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Watch the recorded lecture for this week and note any unclear points. |
# | **Tuesday** | Post a question in the course forum or attend the Q&A session. |
# | **Wednesday** | Complete the step‑by‑step guide for the current topic; mark it off your tracker. |
# | **Thursday** | Join a 30‑minute peer discussion group (online or in‑person). |
# | **Friday** | Do a brief self‑check‑in: record what you accomplished and how you felt. |
# | **Weekend** | Review any recorded lessons you missed; set a simple goal for next week. |
# | **Repeat** | Follow the same pattern next week, adjusting the pace if you feel more or less motivated. |
#
# ---
#
# **Remember:** Your discipline is a strong asset—use it to build consistent habits, and let the added interaction, clearer support, and motivation tools help lift your mood and engagement. If you find any part of the plan isn’t working, reach out to your lecturer or a peer mentor for quick adjustments. Good luck!

# %% [markdown]
# ## Student ID: `e20240783`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240783*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate the **flexibility** that blended learning offers, but you experience difficulties with **internet reliability**, **limited interaction**, and sometimes find the learning materials unclear.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You value being able to study both online and in‑class, which helps you fit learning into your schedule.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Fewer chances to talk with peers and lecturers.
# - **Internet & Technical Issues:** Unstable connection hampers online work.
# - **Learning Difficulty & Clarity:** Instructions and resources can be hard to follow.
# - **Learning Resources & Environment:** Study spaces and material organization need improvement.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | Join scheduled Q&A sessions, take part in small‑group discussions, and use peer‑collaboration tools. Ask lecturers for quicker feedback on assignments. | Increases engagement and reduces the feeling of isolation. |
# | **Learning Environment** | Use clearly organized folders or a personal digital notebook for course files. Seek out quiet study spots on campus or set up a dedicated home workspace. | Makes it easier to locate materials and creates a more comfortable study setting. |
# | **Learning Support** | Look for recorded explanations, step‑by‑step guides, and concrete examples provided by the instructor. When instructions are vague, request clarification via email or discussion boards. | Improves understanding and reduces confusion. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths. Review videos or notes at your own speed before class meetings. | Lets you reinforce concepts when you need extra time. |
# | **Technical Issues** | When possible, use campus Wi‑Fi or a reliable hotspot. Download offline copies of readings and videos in advance. Keep a short list of technical support contacts handy. | Reduces disruptions caused by unstable internet and ensures you can keep studying offline. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Identify one reliable internet source (campus Wi‑Fi, library, or personal hotspot). Download the next week’s lecture videos and readings for offline use. |
# | **Day 3‑4** | Create a simple folder structure (e.g., Week 1 → Slides, Readings, Assignments). Move all current materials into it. |
# | **Day 5** | Register for an upcoming Q&A or discussion session in your course. Prepare two questions you want answered. |
# | **Day 6‑7** | Watch a recorded lecture at your own pace; take notes and note any unclear points. Email the lecturer or post on the forum for clarification. |
# | **Day 8‑10** | Form a small study group (2‑3 peers) to review the week’s content together, either online or in a quiet campus space. |
# | **Day 11‑14** | Review the feedback you receive on any submitted work; note patterns and ask for specific suggestions to improve. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset—use it to build a routine that includes regular interaction, clear organization, and reliable technical access. Small, consistent steps will turn passive engagement into active learning success. Good luck!

# %% [markdown]
# ## Student ID: `e20241401`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241401
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You indicated that you “know how to use new systems or techniques,” which reflects solid **digital skills**.
#
# **Main Challenges**
# - No specific challenges were reported. Because the open‑ended response was brief, the recommendations rely primarily on the characteristics of your learner segment.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Develop digital learning skills** (digital_skill) | Strengthen your ability to navigate the Learning Management System (LMS), locate and evaluate online resources, and use educational technologies effectively. | • Attend a short LMS tutorial or webinar offered by the university.<br>• Explore the campus library’s digital research guides.<br>• Try one new educational tool (e.g., citation manager, mind‑mapping app) each week and reflect on how it supports your coursework.<br>• Use the university’s e‑learning support centre for quick questions. |
#
# **Short Action Plan (2‑Week Sprint)**
#
# | Day | Action |
# |-----|--------|
# | 1–2 | Watch the university’s LMS “Getting Started” video (15 min). |
# | 3–4 | Locate a digital research guide for your major and bookmark it. |
# | 5–7 | Choose one new tool (e.g., Zotero, Quizlet) and create a small project (e.g., bibliography for an upcoming paper). |
# | 8–10 | Visit the e‑learning support centre (in‑person or online chat) with a specific question about the tool you tried. |
# | 11–14 | Write a brief reflection (150 words) on how these digital resources helped your study routine and plan the next tool to explore. |
#
# By focusing on these targeted digital‑skill activities, you’ll build confidence in the online learning environment and make your study time more efficient. Keep the momentum going, and feel free to reach out to campus support whenever you need a quick tip. Good luck!

# %% [markdown]
# ## Student ID: `e20231105`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20231105*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility and practical approaches to study. You thrive when you can manage your time freely and apply what you learn directly. Your main concerns are having a faster Wi‑Fi connection and a comfortable, distraction‑free study space.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You adapt well to different schedules and make good use of self‑directed study time.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable or slow Wi‑Fi can interrupt your online activities.
# - **Learning Resources & Environment** – A more comfortable and organized study area would help you focus.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | Why It Helps |
# |----------------|----------------------|--------------|
# | **Improve learning environment** | • Keep your digital and paper materials neatly organized.<br>• Choose a quiet, well‑lit spot for studying; add a comfortable chair or desk if possible.<br>• Make sure the room temperature and lighting support concentration. | A tidy, comfortable space reduces distractions and lets your active engagement shine. |
# | **Support self‑paced learning** | • Use recorded lectures and weekly learning paths that you can revisit anytime.<br>• Download key readings or videos for offline study. | Gives you the flexibility you like while letting you work around any brief internet hiccups. |
# | **Improve technical access and reliability** | • Seek campus or library Wi‑Fi hotspots with stronger signals.<br>• Download offline copies of essential materials ahead of time.<br>• Keep a quick‑reference guide for the learning platform and know how to contact tech support. | Stable connectivity ensures you stay on track with assignments and interactive activities. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify a quiet corner in your home or campus library; set up a comfortable chair, good lighting, and keep study supplies organized. |
# | **Day 3** | Test your Wi‑Fi speed. If it’s low, locate the nearest strong‑signal hotspot (e.g., campus library) and note the login details. |
# | **Day 4–5** | Download this week’s lecture recordings and reading PDFs for offline use. |
# | **Day 6** | Create a simple folder structure on your computer/cloud (e.g., “Week 1 – Lectures,” “Week 1 – Assignments”) and move all materials there. |
# | **Day 7** | Write down the tech‑support contact information and bookmark a quick‑start guide for the learning platform. |
# | **Week 2** | Follow the weekly learning path at your own pace, reviewing recorded lessons as needed. Adjust your study spot if you notice any discomfort. |
# | **End of Week 2** | Reflect: Is your Wi‑Fi reliable? Is the study space comfortable? Note any remaining issues and plan next steps (e.g., request a better room or upgrade internet). |
#
# ---
#
# **Keep leveraging your flexibility and active engagement—by fine‑tuning your study environment and ensuring reliable tech access, you’ll maximize the benefits of blended learning.**

# %% [markdown]
# ## Student ID: `e20230095`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "engagement", "learning_support", "motivation", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230095
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Values the human‑centered design of blended learning, seeing technology as a tool that frees teachers to focus on what they do best.
# - Highlights two key themes: **Digital Skills Development** and **Student Engagement** (positive sentiment, strong confidence).
#
# **Main Challenges**
# - Points to confusion, inconsistency, overload, and procrastination in blended courses.
# - Identifies three challenge themes: **Assessment & Workload**, **Learning Difficulty & Clarity**, and **Motivation & Self‑Discipline** (positive sentiment, but low intensity).
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Digital Skill** | Get brief tutorials on the LMS, online research tools, and any educational apps you’ll use. Keep a quick‑reference guide for common functions. |
# | **Engagement** | Participate in low‑stakes quizzes, short games, and discussion boards. Try the practical tasks that accompany each topic to stay active. |
# | **Learning Support** | Look for clear, step‑by‑step instructions and recorded explanations for complex concepts. Ask the instructor for examples when a task feels vague. |
# | **Motivation** | Set a weekly check‑in (self‑or with a peer) to review progress. Use reminders and a simple study schedule to break larger tasks into manageable blocks. |
# | **Workload Support** | Review the syllabus early to note all deadlines. Prioritise tasks so that online work aligns with face‑to‑face sessions, reducing overlap and last‑minute pressure. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Watch the LMS “Getting Started” video and save a cheat‑sheet of key functions.
# 2. **Day 3‑4:** Join a discussion thread for your current module; post one comment or question.
# 3. **Day 5:** Create a one‑page study schedule that blocks 30‑minute slots for reading, quizzes, and assignments.
# 4. **Day 6‑7:** Review the upcoming assignment list; highlight due dates and ask the tutor for clarification on any unclear instructions.
# 5. **Week 2:** Set a 10‑minute weekly check‑in (with yourself or a study buddy) to track progress and adjust the schedule as needed.
#
# By focusing on these concrete steps, you’ll strengthen your digital confidence, stay more engaged, and keep the workload manageable while building self‑discipline. Good luck!

# %% [markdown]
# ## Student ID: `e20240371`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240371
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You find it easy to get to the learning materials you need, which helps you study conveniently and effectively.
#
# **Main Challenges**
# - Unreliable internet (e.g., weak Wi‑Fi around the school grounds) makes it harder to access online resources and creates a less comfortable learning environment.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload slides, videos, reference links, exercises and other course materials **early** in the semester. | Having everything ready in advance lets you download or view them when the connection is good, reducing the impact of spotty Wi‑Fi. |
# | **Learning Effectiveness** | Pair the online review materials with **in‑person explanations, practice sessions, and feedback** from the instructor or peers. | Combining digital and face‑to‑face activities reinforces understanding and keeps you engaged even if you spend time offline. |
# | **Learning Environment** | Keep your digital folders and the classroom’s physical resources **well‑organized and up‑to‑date**; choose a quiet, comfortable spot for study when possible. | A tidy, predictable environment reduces distraction and makes the time you do have online more productive. |
# | **Technical Issues** | Use **offline copies** of key files (PDFs, videos) and follow any short guides the platform provides; contact the university’s tech support when connectivity problems arise. | Offline materials give you a reliable backup, and clear instructions plus support minimise downtime caused by internet glitches. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑3:** Download all current lecture slides and any posted videos to your laptop/tablet.
# 2. **Day 4‑5:** Create a simple folder structure (e.g., Week 1, Week 2…) and place the downloaded files there.
# 3. **Day 6‑8:** Attend a scheduled in‑person review session; ask the instructor for quick feedback on any concepts that feel unclear.
# 4. **Day 9‑10:** Test the campus Wi‑Fi in a few different locations; note where the signal is strongest and plan future study sessions there.
# 5. **Day 11‑12:** If you encounter connectivity problems, submit a ticket to the university’s tech help desk and request offline copies of any missing resources.
# 6. **Day 13‑14:** Review the organized materials and complete one practice exercise, then check your answers with a peer or the instructor.
#
# Following these steps will reinforce your strong access to materials while mitigating the internet and environment challenges you face. Keep the focus on early preparation, blended (online + in‑person) practice, and having reliable offline backups. Good luck!

# %% [markdown]
# ## Student ID: `e20211604`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_effectiveness", "learning_support", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211604*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged IT student who values real‑world exploration and fast adoption of new technologies. You already use blended learning to go beyond the fixed curriculum, especially for topics like system design and open‑source AI. You prefer concise video content (e.g., YouTube) and focus on material that directly supports your career as a full‑stack developer.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You actively seek out slides, videos, and external resources.
# - **Digital Skills Development:** You quickly pick up new tools and technologies.
# - **Learning Convenience & Effectiveness:** You appreciate being able to study independently and apply knowledge right away.
# - **Student Engagement:** Your proactive attitude keeps you motivated to explore beyond lab exercises.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity:** Recorded video lectures feel boring and sometimes lack clear instructions.
# - **Motivation & Self‑Discipline:** Long‑form videos without interactive elements make it harder to stay focused.
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Instructors should upload slides, videos, reference links, and practice exercises **early** in the week so you can preview and plan your study. |
# | **Digital Skill** | Receive short guides on using the LMS, searching scholarly/technical resources, and leveraging educational tech (e.g., code‑sharing platforms). |
# | **Engagement** | Participate in quick quizzes, gamified challenges, and brief discussion prompts that relate to the real‑world projects you enjoy. |
# | **Learning Effectiveness** | Combine the online review material you already use with short, in‑person (or live‑online) explanation sessions and immediate feedback on practical tasks. |
# | **Learning Support** | Ask for clearer step‑by‑step instructions and example walkthroughs that accompany the recorded videos. |
# | **Motivation** | Set up weekly check‑ins (e.g., a 5‑minute sync with a tutor or peer) and use a simple progress tracker to mark completed modules and upcoming goals. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the course’s slide deck and video library; download all materials before the first live session. |
# | **2** | Complete a short “digital tools” tutorial provided by the instructor (e.g., LMS navigation, code‑repo linking). |
# | **3** | Join a weekly 10‑minute quiz or poll related to your current module; review the feedback immediately. |
# | **4** | Schedule a 15‑minute check‑in with a teaching assistant to discuss any unclear video content and set goals for the next module. |
#
# By following these steps, you can keep leveraging your strong engagement and digital aptitude while reducing the boredom and ambiguity you experience with long video lectures. Good luck, and keep building those full‑stack skills!

# %% [markdown]
# ## Student ID: `e20240875`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240875*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. Your open‑ended feedback highlights two main points:
#
# - **Strengths:** You appreciate the **flexibility and convenience** that blended learning offers.
# - **Challenges:** You experience occasional **self‑motivation difficulties** and **technical issues** (e.g., internet stability).
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value being able to study when it fits your schedule.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Keeping momentum can be tough without external prompts.
# - **Internet & Technical Issues** – Unreliable connectivity sometimes disrupts learning.
#
# ---
#
# ### 4. Personalized Recommendations
# | Focus | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Motivation** | • Set up **weekly check‑ins** (with a tutor, study buddy, or via the LMS). <br>• Use **reminders** and a **progress‑tracking dashboard**. <br>• Follow a **structured study schedule** that blocks specific times for each task. | Regular touch‑points and visible progress keep you accountable and boost self‑discipline. |
# | **Self‑Paced Learning** | • Access **recorded lectures** and **downloadable resources**. <br>• Follow the **weekly learning path** provided in the course outline, but feel free to review any material as needed. | You can take advantage of the flexibility you value while still having a clear roadmap. |
# | **Technical Access** | • Use the university’s **stable Wi‑Fi hotspots** or request a **mobile data voucher** if needed. <br>• Download **offline copies** of readings and videos ahead of time. <br>• Keep the **platform guide** handy and know how to contact **technical support** quickly. | Reducing connectivity problems ensures you can study without interruptions. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the weekly learning path and download all lecture videos for the week. |
# | **Day 2** | Set up a recurring **calendar reminder** for a 30‑minute study block each day. |
# | **Day 3** | Schedule a **30‑minute check‑in** with a peer or tutor (virtual or in‑person). |
# | **Day 4** | Test your internet connection; locate the nearest campus Wi‑Fi hotspot or request a data voucher. |
# | **Day 5** | Create a simple **progress tracker** (e.g., checklist or spreadsheet) for the week’s tasks. |
# | **Day 6‑7** | Review any missed material using the offline resources; note any technical issues to report to support. |
# | **Repeat** | Continue the same routine each week, adjusting the study block length as needed. |
#
# ---
#
# **Remember:** Your engagement is a strong asset. By adding a few structured habits and ensuring reliable technical access, you can turn flexibility into consistent progress. If you need help setting up any of the tools above, reach out to your course’s support team—they’re there to assist you. Good luck!

# %% [markdown]
# ## Student ID: `e20230186`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230186
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value the **flexibility** that blended learning gives you, allowing you to save time, energy, and money.
# - You appreciate the **convenient, effective** way you can create a schedule that fits your personal needs.
#
# **Main Challenges**
# - **Internet/technical issues** sometimes make it hard to access online content.
# - You experience **misunderstandings** when announcements or instructions are not clear.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Pair the online review materials you already use with short, in‑person sessions for explanation, practice, and feedback. | Attend scheduled tutorials or office‑hours where you can ask questions and get immediate feedback on the material you reviewed online. |
# | **Improve clarity and learning support** | Get clearer, step‑by‑step guidance and examples to avoid misunderstandings. | Look for recorded explanations and detailed guides that accompany each module; use them as a reference before attempting assignments. |
# | **Support self‑paced learning** | Keep using recorded lessons and weekly learning paths that let you study when it suits you. | Follow the weekly learning roadmap provided by the course, revisiting recorded lectures as needed to reinforce concepts. |
# | **Improve technical access and reliability** | Reduce disruptions caused by poor internet or platform confusion. | Download offline versions of key resources when possible, and use the university’s technical support desk for any connectivity problems. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Download offline copies** of this week’s lecture slides and readings.
# 2. **Schedule one in‑person tutorial** (or virtual office hour) to discuss any unclear points from the online material.
# 3. **Follow the weekly learning path**: watch the recorded lecture, take notes, then complete the practice activity before the next tutorial.
# 4. **Test your internet connection** in a quiet location; if issues persist, contact the campus IT help desk for assistance.
#
# By combining your strong engagement and love of flexibility with clearer instructions, reliable technical access, and targeted face‑to‑face support, you can make the most of blended learning and keep your progress steady and effective.

# %% [markdown]
# ## Student ID: `e20240670`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240670
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You feel that the lessons help you understand the material more clearly.
# - This reflects a positive view of the **access to learning materials** and the **convenience/effectiveness** of the current content.
#
# **Main Challenges**
# - You experience problems with the university’s internet/Wi‑Fi, which makes self‑study difficult.
# - This points to issues with **technical access** and the **learning environment** (stable connectivity and suitable study spaces).
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on the rule‑based recommendations) |
# |------|-------------------------------------------------------|
# | **Content Access** | The university should upload slides, videos, reference links, exercises and other course materials **early** so you can download them before class. |
# | **Learning Effectiveness** | Combine the online review materials you receive with in‑person explanations, practice activities and feedback to deepen understanding. |
# | **Learning Environment** | Organize course resources clearly, keep them up‑to‑date, and improve study spaces (lighting, seating, quiet zones) to make self‑study more comfortable. |
# | **Technical Issues** | Ensure stable campus internet/Wi‑Fi, provide **offline copies** of essential materials, give clear instructions for using the learning platform, and make technical support readily available. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Download Materials** – As soon as the instructor posts slides or videos, download them to your device for offline use.
# 2. **Create a Study Spot** – Identify a quiet area on campus (library, study lounge) with reliable Wi‑Fi; if unavailable, request a reserved space from the student services office.
# 3. **Seek Technical Help** – Contact the IT help desk to report your Wi‑Fi issues and ask about alternative connections (e.g., campus hotspots).
# 4. **Combine Resources** – After each lecture, spend 15‑20 minutes reviewing the uploaded materials and then attend any scheduled in‑person review or practice session for feedback.
#
# By focusing on early access to content, improving the study environment, and securing reliable internet, you can make your self‑study more effective while staying engaged with the course.

# %% [markdown]
# ## Student ID: `e20241019`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "interaction", "learning_effectiveness", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241019*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Flexibility, convenient learning, and high engagement.
# - **Current challenge:** Interaction & communication (neutral sentiment).
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you make good use of flexible study options.
# - **Learning Convenience & Effectiveness** – you find blended formats helpful for understanding material.
# - **Student Engagement** – you are actively involved in your courses.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – you would benefit from more opportunities to talk with peers and instructors.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to try | Why it helps |
# |------|-------------|--------------|
# | **Engagement** | Use short quizzes, games, practical tasks, and discussion prompts in each module. | Keeps the high energy you already bring and deepens learning. |
# | **Interaction** | Join scheduled Q&A sessions, small‑group discussions, and peer‑collaboration projects; request quicker feedback from lecturers. | Improves the communication gap you noted and lets you learn from classmates. |
# | **Learning Effectiveness** | Pair online review videos or readings with in‑person explanations, hands‑on practice, and immediate feedback. | Combines the convenience you like with the clarity of face‑to‑face support. |
# | **Self‑Paced Learning** | Follow weekly learning paths that include recorded lectures and downloadable resources you can revisit anytime. | Lets you keep the flexibility you value while staying on track. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the strengths/challenges you reported.
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Identify one module and add a short quiz or game after each lesson. |
# | **2** | Sign up for a live Q&A or discussion group; schedule a 15‑minute peer review session. |
# | **3** | Pair an online video with an in‑person practice session; ask the lecturer for quick feedback on the activity. |
# | **4** | Create a personal weekly learning path using recorded lessons and set aside 30 min each day for review. |
#
# **Tip:** Keep a brief log of what you tried and how it felt. Adjust the activities that work best for you and share the results with your instructor—they can help fine‑tune the blend for you.
#
# Good luck, and keep leveraging your strong engagement while building richer communication with peers and teachers!

# %% [markdown]
# ## Student ID: `e20241312`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241312*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You already make good use of the resources that are available and value the ability to research topics on‑line and verify understanding with professors.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You appreciate having slides, videos, references, and exercises readily available.
# - **Learning Convenience & Effectiveness:** You use the platform to fill gaps in understanding quickly.
# - **Student Engagement:** You are actively involved in the learning process.
#
# ### 3. Main Challenges
# - No specific challenges were reported.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Keep the course content (slides, videos, readings, exercises) available early in the term so you can study and research whenever needed. | Upload or request early posting of all course resources; create a personal folder for quick reference. |
# | **Increase learner engagement** | Add interactive elements to deepen your active participation. | Use quizzes, short games, practical tasks, and discussion boards built into the LMS; schedule brief peer‑to‑peer or professor‑led Q&A sessions. |
# | **Improve learning effectiveness** | Blend online review with face‑to‑face explanation, practice, and feedback for better mastery. | After reviewing digital materials, attend in‑person sessions for clarification, work on hands‑on activities, and seek timely feedback on assignments. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Check that all upcoming lecture slides and videos are uploaded; if not, ask the instructor to post them early. |
# | **Day 3‑5** | Complete the first set of online quizzes for the current module; note any topics that need clarification. |
# | **Day 6‑7** | Join a discussion forum or study group to talk through quiz questions and share resources. |
# | **Day 8‑10** | Attend the next in‑person class, focus on applying what you reviewed online, and ask for feedback on a short practice task. |
# | **Day 11‑14** | Reflect on what worked best (e.g., quizzes, discussions, face‑to‑face feedback) and adjust your study routine accordingly. |
#
# By following these steps, you’ll keep your strong engagement level while ensuring that the material you need is always at hand and that your learning is as effective as possible. Keep up the active approach—you’re well positioned to succeed!

# %% [markdown]
# ## Student ID: `e20211544`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211544*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive in a blended environment because you value the **flexibility to access materials anytime** and enjoy a mix of online and face‑to‑face activities. Your comments show strong enthusiasm for the convenience and engagement that blended learning provides.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate being able to review slides, videos, and exercises at your own pace.
# - **Flexibility & Time Management** – The balance between online and in‑person work helps you manage your schedule.
# - **Student Engagement** – Interactive activities keep you motivated and involved.
#
# ### 3. Main Challenges
# - **Inconsistent quality** between online and in‑person sessions (unclear instructions, uneven resources).
# - **Technical issues** such as poor internet connectivity.
# - **Motivation & Self‑Discipline** – Staying on track and managing time when learning online can be difficult.
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload all slides, videos, references, and exercises **early** so you can review them whenever you need. |
# | **Engagement** | Participate in quizzes, games, practical tasks, discussions, and other interactive activities to keep the learning lively. |
# | **Learning Effectiveness** | Pair online review materials with **in‑person explanations, practice, and feedback** to deepen understanding. |
# | **Learning Environment** | Use clearly organized folders, keep resources up‑to‑date, and choose comfortable study spaces (both online and on campus). |
# | **Learning Support** | Seek clearer instructions, examples, and step‑by‑step guides; request recorded explanations when a concept isn’t clear. |
# | **Motivation & Self‑Discipline** | Set up **weekly check‑ins**, reminders, and a simple progress tracker; follow a structured study schedule. |
# | **Self‑Paced Learning** | Take advantage of recorded lessons and weekly learning paths that let you study at your own speed. |
# | **Technical Issues** | Ensure you have a stable internet connection; download offline copies of key materials and use the university’s technical support when needed. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the course’s online folder; note any missing slides or videos and request them from the instructor. |
# | **Day 2‑3** | Create a personal study schedule: allocate specific times for online review, in‑person sessions, and quizzes. |
# | **Day 4** | Test your internet speed; if unstable, arrange a backup (e.g., campus Wi‑Fi hotspot) and download offline copies of this week’s materials. |
# | **Day 5‑6** | Join a discussion forum or study group; post a question about a concept that feels unclear to get peer or instructor clarification. |
# | **Day 7** | Complete a short self‑quiz on the week’s content and note any gaps for the next in‑person class. |
# | **Day 8‑10** | Attend the in‑person session, focus on practice tasks and ask for immediate feedback. |
# | **Day 11** | Update your progress tracker; celebrate what you’ve mastered and set a micro‑goal for the next week. |
# | **Day 12‑14** | Reflect on what worked (e.g., recorded lessons, check‑ins) and adjust your schedule or support needs accordingly. |
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By tightening access to materials, clarifying instructions, managing technical hurdles, and using structured motivation tools, you can turn the occasional challenges of blended learning into smooth, effective study experiences. Good luck!

# %% [markdown]
# ## Student ID: `e20240507`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["engagement", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240507*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically shows moderate motivation, prefers some structure, and benefits from clear interaction and support.
#
# ### 2. Main Strengths
# - **Student Engagement** – You noted that fun game‑style quizzes help keep you interested and would like more of them. (Positive sentiment, strength score 0.74)
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable Wi‑Fi makes it hard to study online. (Negative sentiment, challenge score ‑0.40)
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation (based on rule‑based guidance) |
# |-----|-----------------------------------------------|
# | **engagement** | Incorporate more quizzes, games, practical tasks, short discussions, and other interactive activities into your study routine. These formats have been shown to boost interest and retention for learners in your segment. |
# | **tech_issue** | Ensure you have stable internet access or use offline materials when connectivity is poor. Look for clear instructions on how to download resources, and take advantage of any technical support your university offers. |
#
# ### 5. Short Action Plan
#
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1 | Identify a reliable spot on campus (library, study lounge) with strong Wi‑Fi, or arrange a mobile hotspot. | Reduces interruptions caused by weak internet. |
# | 2 | Add at least one game‑based quiz to each study session (many platforms have free quiz generators). | Increases engagement and makes review more enjoyable. |
# | 3 | Download lecture slides and readings for offline use before each class. | Guarantees access even when the connection drops. |
# | 4 | Join a short online discussion or study group (via your course forum or a messaging app). | Adds interaction and reinforces learning without needing long continuous internet time. |
# | Ongoing | Keep a list of technical support contacts (IT help desk, campus Wi‑Fi office) and note any recurring issues. | Quick resolution of future tech problems. |
#
# ---
#
# **Remember:** By mixing more interactive activities with reliable access to materials, you can stay motivated and make the most of blended learning. If you encounter any new obstacles, reach out to your instructors or the campus support services—they’re there to help. Good luck!

# %% [markdown]
# ## Student ID: `e20241176`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241176
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You value having clear, focused learning environments and believe that being able to concentrate on lessons is important.
# - Your comment highlights the importance of easy access to learning materials (slides, videos, references, exercises).
#
# **Main Challenges**
# - No specific challenges were provided, so the recommendations rely mainly on the typical characteristics of the “Moderately Engaged (Passive)” segment.
#
# **Personalized Recommendations**
#
# | Recommendation Tag | What it means for you | How to apply it |
# |--------------------|-----------------------|-----------------|
# | **content_access** | Make sure all course resources are available to you early and in one place, so you can review them whenever you need to focus. | • Ask your instructor to upload lecture slides, video recordings, reading lists, and practice exercises at the start of each week.<br>• Use a cloud folder or the LMS “Resources” section to keep everything organized.<br>• Review the materials before class to reinforce focus during in‑person sessions. |
#
# **Short Action Plan**
#
# 1. **Check the LMS weekly** – Look for a “Week X Materials” folder and download all files by the start of the week.
# 2. **Create a personal study folder** – Organize slides, videos, and notes by topic so you can quickly locate what you need.
# 3. **Set a short review time** – Spend 10‑15 minutes reviewing the uploaded materials before each class to boost concentration.
# 4. **Give feedback** – If any material is missing or posted late, let the instructor know so the process improves for you and your peers.
#
# By ensuring timely and organized access to all learning materials, you’ll be able to maintain focus during in‑person sessions and make the most of your study time.

# %% [markdown]
# ## Student ID: `e20240452`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240452*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits of this segment:** strong motivation, frequent interaction with course content, and a preference for having materials readily available to study at their own pace.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You noted that being able to see the lesson material, even when you hadn’t reviewed it beforehand, is a key strength for you. This shows you value having the resources available early.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You mentioned that teaching and explanations could be slower and clearer. This indicates a need for more explicit guidance and examples to support your understanding.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** *(content_access)* | Ensure that slides, videos, reference links, exercises and any other course resources are uploaded **well before** the class session. | You can preview and review content at your own pace, which matches your active learning style and reduces the feeling of “not knowing” the lesson. |
# | **Improve clarity and learning support** *(learning_support)* | Provide clearer written instructions, concrete examples, short recorded explanations, and step‑by‑step guides for each topic. | More explicit guidance reduces confusion and helps you process information more efficiently, supporting the clarity you’re looking for. |
#
# These recommendations are drawn directly from the rule‑based suggestions for your segment and the themes you identified.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | **1** | Check the course platform for early uploads. | Look for a “Materials” folder; if nothing is there, ask the instructor to post slides/videos at least 2 days before the lecture. |
# | **2** | Use the previewed materials to create a quick outline of key points. | Write 3–5 bullet points per topic; note any terms you don’t understand. |
# | **3** | Seek clarified explanations. | Watch any recorded explanations; if they’re missing, request short video demos or ask the tutor for an example. |
# | **4** | Review step‑by‑step guides while doing practice exercises. | Follow the guide line‑by‑line, pausing the video or reading the notes as needed. |
# | **Ongoing** | Provide feedback to the instructor about material timing and clarity. | Send a brief email after each week summarizing what helped and what could be clearer. |
#
# By following this plan, you’ll keep the strong access to resources you value while gaining the clearer, more supportive instruction that will help you stay fully engaged and successful in your blended courses.

# %% [markdown]
# ## Student ID: `e20240625`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20240625
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Highly Engaged (Active) Learners” segment, which typically benefits from rich content access, strong digital tools, self‑paced options, and high levels of interaction.
#
# Your open‑ended responses indicated the same idea for both strengths and challenges (“study hard”), and the sentiment analysis flagged a negative tone. The only specific challenge theme identified was **Learning Difficulty & Clarity**.
#
# ---
#
# ### 2. Main Strengths
# - **High engagement** – as a member of the active‑learner cluster, you are motivated to participate and put effort into your studies.
#
# ---
#
# ### 3. Main Challenges
# - **Learning difficulty & clarity** – you find some material or instructions unclear, which can hinder your study effectiveness.
#
# ---
#
# ### 4. Personalized Recommendations
# **Learning Support – Improve clarity and learning support**
# - Request or look for **clearer written instructions** for assignments and activities.
# - Use **recorded explanations** (lecture videos, audio walkthroughs) that you can pause and replay.
# - Follow **step‑by‑step learning guides** or checklists that break complex tasks into manageable parts.
#
# These supports align with the “learning_support” tag that the rule‑based system identified for you.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1 | Identify unclear topics | List the concepts you felt vague about in the past week. |
# | 2 | Seek clearer resources | Ask the instructor for written examples or locate recorded explanations in the LMS. |
# | 3 | Use step‑by‑step guides | Follow any provided guides; if none exist, create your own checklist for the task. |
# | 4 | Review and reflect | After using the clearer resources, note any improvement in understanding and adjust your study plan. |
#
# ---
#
# **Remember:** Your strong engagement is a valuable asset. Pair it with clearer learning materials, and you’ll be able to study more efficiently and confidently. If you need additional support, reach out to your course tutor or the learning‑support centre.

# %% [markdown]
# ## Student ID: `e20221013`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20221013
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - Shows strong engagement with course material (the only theme identified).
#
# **Main Challenges**
# - No specific challenges were reported.
#
# **Personalized Recommendations**
# Because you are classified as a **Highly Engaged (Active) Learner**, the primary recommendation focuses on keeping that energy high and channeling it into deeper interaction with the content. The rule‑based suggestion is to **increase learner engagement** through varied, interactive activities.
#
# **Short Action Plan**
#
# | What to Do | How to Do It | When |
# |------------|--------------|------|
# | Add quick quizzes or polls to each study session | Use the LMS quiz tool or a free app (e.g., Kahoot, Quizizz) after reading a chapter | Start this week |
# | Include short games or gamified challenges | Turn key concepts into flash‑card battles or point‑based tasks | Ongoing, 1‑2 times per week |
# | Do practical, hands‑on tasks | Apply theory to a small project, case study, or lab exercise | After each major topic |
# | Participate in discussion forums or small‑group chats | Post a question or comment, respond to peers | At least twice a week |
# | Use interactive simulations or multimedia | Find relevant videos, simulations, or interactive diagrams | When a new concept is introduced |
#
# These activities are designed to match your high engagement level and keep you actively involved in learning, without requiring any new skills beyond what you already have. If you find any activity particularly helpful, keep using it; if something feels less useful, feel free to adjust.

# %% [markdown]
# ## Student ID: `e20220564`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220564*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Flexibility and the ability to manage your time effectively.
# - **Current challenge:** An intermittent or slow internet connection that can disrupt online activities.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when it best fits your schedule and can organise your workload efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity can make it hard to access live sessions or download large files.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | What to do |
# |----------------|------------------|------------|
# | **Support self‑paced learning** | Matches your need for flexibility and lets you review material on your own timetable. | • Use recorded lectures instead of only live sessions.<br>• Follow the weekly learning paths provided by the course.<br>• Keep the downloadable PDFs, slides, and practice files for later review. |
# | **Improve technical access and reliability** | Reduces the impact of a slow connection so you can stay engaged without frustration. | • Download offline versions of videos and readings when you have a good connection.<br>• Follow the short guide on platform navigation to avoid unnecessary loading.<br>• Contact the campus tech‑support desk for assistance with connectivity or device issues.<br>• If possible, use campus Wi‑Fi or a reliable hotspot for critical activities. |
#
# These suggestions are drawn directly from the evidence for your segment and the specific tags identified for you (“self_paced” and “tech_issue”).
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate and download the week 1 recorded lecture and accompanying slides. Test the offline files on your device. |
# | **2** | Follow the weekly learning path; set aside 2‑3 hours on days that suit you best. |
# | **3** | If you experience another connection drop, reach out to the tech‑support team (provide screenshots or error messages). |
# | **4** | Review the “How to use the platform” quick guide; note any steps that still cause delays and report them. |
# | **Ongoing** | Continue using recorded content and offline materials whenever you anticipate a weak connection. Keep a personal schedule that aligns with the weekly learning paths. |
#
# ---
#
# **Keep in mind:** Your strong ability to organise your time combined with reliable, self‑paced resources will let you stay on track even when technical hiccups occur. If you need further assistance, the learning support centre and IT help desk are ready to help. Good luck!

# %% [markdown]
# ## Student ID: `e20230724`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230724*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** You highlighted the flexibility of studying from home and the ability to self‑study and improve your skills.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to choose when and where you learn.
# - **Learning Convenience & Effectiveness** – You see blended learning as a convenient way to deepen your knowledge.
#
# ### 3. Main Challenges
# - You did not report any specific challenges with the current blended format.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it fits you | How to apply it |
# |----------------|----------------|-----------------|
# | **Improve learning effectiveness** | You already engage actively; adding focused in‑person support can boost the impact of your self‑study. | • Attend scheduled face‑to‑face sessions where the instructor explains key concepts, runs practice activities, and gives feedback.<br>• Use these sessions to clarify doubts that arise from your online review. |
# | **Support self‑paced learning** | Your strength is managing your own study time. Providing clear, reusable resources lets you keep that momentum. | • Access recorded lectures and supplemental videos at any time.<br>• Follow weekly learning paths that outline what to study, when, and which resources to use.<br>• Review materials as needed before or after in‑person sessions. |
#
# ### 5. Short Action Plan (Next 2 weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Monday** | Log into the course portal and locate the recorded lessons for this module. |
# | **Week 1 – Tuesday–Thursday** | Follow the weekly learning path: watch the videos, take brief notes, and complete any online quizzes. |
# | **Week 1 – Friday** | Attend the first in‑person (or live‑online) session: ask questions about any unclear points and practice the skills demonstrated. |
# | **Week 2 – Monday–Wednesday** | Review the recorded session again, focusing on parts you found challenging. |
# | **Week 2 – Thursday** | Participate in a peer‑feedback activity or office‑hours meeting to receive targeted feedback. |
# | **Week 2 – Friday** | Reflect on what helped you learn best and adjust your personal study schedule for the next module. |
#
# ---
#
# **Remember:** Your active engagement and love of flexibility are strong assets. By pairing your self‑paced study with concise, interactive face‑to‑face moments, you’ll make the most of blended learning and continue to improve your skills efficiently. Good luck!

# %% [markdown]
# ## Student ID: `M080415`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** M080415
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate how blended learning gives you flexibility, convenient access to materials, and helps you develop digital skills. You also notice that it can increase overall student engagement and make classroom time more effective.
#
# **Main Challenges**
# You experience occasional internet or platform problems, would like clearer learning materials, and want more interactive activities and communication during class.
#
# **Personalized Recommendations**
#
# | Area | What to do (based on the rule‑based advice) |
# |------|---------------------------------------------|
# | **Content Access** | Upload slides, videos, references, exercises and other course resources **early** so you can review them whenever you need. |
# | **Digital Skills** | Offer short guides or workshops on using the LMS, online research tools, and other educational technologies. |
# | **Engagement** | Include low‑stakes quizzes, quick games, practical tasks and brief discussion prompts in each online session. |
# | **Interaction** | Add regular Q&A slots, small‑group discussions, peer‑collaboration tasks, and faster feedback from the lecturer. |
# | **Learning Effectiveness** | Pair online review material (e.g., recorded explanations) with in‑person practice and feedback to reinforce concepts. |
# | **Learning Environment** | Organise all materials in a clear folder structure, keep resources up‑to‑date, and ensure classroom spaces are comfortable for hybrid participation. |
# | **Learning Support** | Provide explicit instructions, concrete examples, and step‑by‑step guides (including recorded walkthroughs) for complex topics. |
# | **Self‑Paced Learning** | Make recorded lessons and weekly learning paths available so you can study at a pace that fits your schedule. |
# | **Technical Issues** | Ensure reliable internet access (e.g., campus Wi‑Fi hotspots), offer offline copies of key materials, and give clear platform tutorials plus a help desk contact. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# | Week | Action |
# |------|--------|
# | 1 | Review the course’s newly uploaded slide deck and video recordings; note any unclear sections. |
# | 2 | Attend a 30‑minute digital‑tools workshop (or watch the recorded guide) to boost LMS confidence. |
# | 3 | Participate in a scheduled online quiz and a 10‑minute peer discussion; give feedback on the experience. |
# | 4 | Meet with the lecturer or teaching assistant for a quick Q&A on any remaining doubts; test the offline material download option. |
#
# By following these steps, you can take full advantage of the flexibility of blended learning while reducing technical hiccups and increasing interaction and clarity. Good luck!

# %% [markdown]
# ## Student ID: `e20220759`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20220759
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Highly Engaged (Active) Learners” segment. This group typically makes the most of digital resources, participates actively in class, and benefits from clear, readily‑available learning materials.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You noted that the course “has video record,” indicating you value having recordings and other resources you can refer back to.
#
# ---
#
# ### 3. Main Challenges
# - You indicated “i have no idea” when asked about challenges, so no specific difficulty was identified. Because the open‑ended response is limited, the recommendation below relies mainly on the typical needs of your segment.
#
# ---
#
# ### 4. Personalized Recommendations
# **Strengthen access to learning materials**
# - **What to do:** Ensure that all course components—slides, lecture videos, reference links, exercises, and any supplemental documents—are uploaded **early** in the module.
# - **Why it helps:** Early access lets you review content before class, revisit complex topics after lectures, and manage your study time more flexibly—perfect for an active, engaged learner like you.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How to Implement |
# |------|--------|------------------|
# | 1    | Check the course platform for any missing resources. | List what’s available (slides, videos, etc.) and note gaps. |
# | 2    | Request early uploads from the instructor or teaching assistant. | Send a brief, polite email asking for the next week’s materials to be posted in advance. |
# | 3‑4  | Create a personal “resource folder.” | Save all downloaded files in a structured folder (e.g., Week 1 – Slides, Videos, Exercises). |
# | Ongoing | Review materials before each class and after lectures. | Spend 15‑20 minutes reviewing the week’s slides/video to reinforce learning. |
#
# By securing early access to all learning materials, you’ll be able to keep your high level of engagement and make the most of your active learning style. If new challenges arise, feel free to update your feedback so the recommendations can be refined.

# %% [markdown]
# ## Student ID: `e20240685`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "learning_environment", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240685
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Values having a variety of learning materials that let you study independently (e.g., slides, videos, research resources).
# - Shows interest in developing digital skills for online research and coursework.
#
# **Main Challenges**
# - Frequent internet and technical problems that limit your ability to access online resources.
# - Need for a clearer, more comfortable learning environment and better‑organized study materials.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Get all course slides, videos, references, and exercises early so you can study at your own pace. | Check the LMS weekly for newly uploaded content; download files when you have a stable connection. |
# | **Develop digital learning skills** | Learn how to use the LMS, online libraries, and research tools more efficiently. | Attend the short “Digital Skills” workshop offered by the university or watch the recorded tutorial series. |
# | **Improve learning resources and environment** | Have well‑organized materials and comfortable study spaces that support self‑directed learning. | Use the “Resources Hub” page that groups materials by topic; choose a quiet campus study area or a reserved library seat. |
# | **Improve technical access and reliability** | Reduce disruptions caused by poor internet or platform issues. | When possible, connect to the campus Wi‑Fi or use the university’s offline download option; keep the tech‑support contact info handy for quick assistance. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–2:** Log into the LMS, locate the “Course Materials” folder, and download all available slides and videos for the upcoming week.
# 2. **Day 3:** Watch the 20‑minute “Getting Started with the LMS” tutorial (available on the university’s help portal).
# 3. **Day 4–5:** Test the campus Wi‑Fi in a nearby study space; note any connectivity issues and report them to IT.
# 4. **Day 6–7:** Organize downloaded files into clearly labeled folders on your device (e.g., “Week 1 Slides,” “Research Articles”).
# 5. **Day 8–10:** Attend the optional “Digital Research Skills” workshop (or view its recording).
# 6. **Day 11–14:** Review the “Resources Hub” page, bookmark the most useful links, and set a weekly reminder to check for updates.
#
# By following these steps, you’ll build a more reliable, self‑paced learning environment that matches your strengths and addresses the technical challenges you’ve identified. Keep track of what works best for you and adjust the plan as needed. Good luck!

# %% [markdown]
# ## Student ID: `e20210963`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210963*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from structured, flexible resources that allow study at their own speed.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You appreciate the ability to arrange class attendance flexibly (“flexible class make‑up”).
#
# ### 3. Main Challenges
# - **Self‑commitment on studying:** You find it difficult to stay consistently motivated to study on your own.
#
# ### 4. Personalized Recommendations
# - **Support self‑paced learning** (the only rule‑based recommendation for your profile).
#   - Access **recorded lessons** so you can review content whenever it fits your schedule.
#   - Follow **weekly learning paths** that outline what to study each week, giving you a clear roadmap without fixed class times.
#   - Use the provided **materials (slides, readings, practice quizzes)** at your own pace, allowing you to reinforce concepts when you feel most ready.
#
# These resources are designed to match your strength in flexibility while helping you build the self‑discipline needed for independent study.
#
# ### 5. Short Action Plan
#
# | Week | Action | How It Helps |
# |------|--------|--------------|
# | 1 | Log into the course platform and locate the recorded lectures for the first module. | Gives you immediate, flexible access to content. |
# | 2 | Follow the weekly learning path: set a specific day and time (e.g., Mon 10 am) to watch the videos and take notes. | Creates a routine that supports self‑commitment. |
# | 3 | Complete the practice quiz after each video and review any incorrect answers using the recorded material. | Reinforces learning and builds confidence. |
# | 4 | Reflect on your study habits: note what time of day you were most focused and adjust the next week’s schedule accordingly. | Improves time‑management and motivation. |
# | Ongoing | Continue the same cycle for each new module, using the recorded lessons and weekly paths as your guide. | Maintains flexibility while fostering consistent study habits. |
#
# ---
#
# **Remember:** The flexibility you value is a strong asset. By pairing it with a clear, self‑paced structure, you can strengthen your study commitment and succeed in the blended learning environment. If you need additional support, reach out to your instructor or learning support services. Good luck!

# %% [markdown]
# ## Student ID: `e20230754`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230754*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** Saving travel time and lower costs (Flexibility & Time Management).
# - **What you find challenging:** Limited interaction with professors and classmates (Interaction & Communication).
#
# ---
#
# ### 2. Main Strengths
# - Appreciates the flexibility of online study, which helps you manage your schedule and reduce expenses.
#
# ---
#
# ### 3. Main Challenges
# - Finds the learning experience less interactive, making it harder to communicate with the instructor and peers.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | How to use it |
# |----------------|------------------|---------------|
# | **Increase interaction and communication** | Addresses the feeling that the course is “less interactive.” | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities (e.g., breakout rooms, shared documents).<br>• Take advantage of faster lecturer feedback channels (e.g., short response polls, office‑hour chat). |
# | **Support self‑paced learning** | Builds on the flexibility you already appreciate, letting you review material when it fits your schedule. | • Use recorded lecture videos for review.<br>• Follow the weekly learning path provided by the course (checklists, suggested milestones).<br>• Keep all reading and resources handy for on‑demand study. |
#
# These two recommendations are drawn directly from the rule‑based tags **interaction** and **self_paced** that match your segment profile.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Day 1** | Locate the course’s Q&A schedule and add the sessions to your calendar. |
# | **Week 1 – Day 2** | Download the first set of recorded lectures and set a 30‑minute review slot each day. |
# | **Week 1 – Day 4** | Join a peer discussion forum or create a small study group (2‑3 classmates). |
# | **Week 2 – Day 1** | Submit a question or comment on the latest lecture and request feedback within 24 hours. |
# | **Week 2 – Day 3** | Follow the weekly learning path checklist; mark completed items and note any topics needing extra review. |
# | **Week 2 – Day 5** | Reflect on the interaction activities: Did you feel more connected? Adjust participation as needed. |
#
# ---
#
# **Keep in mind:** Your segment indicates that boosting interaction while preserving self‑paced flexibility will most improve your learning experience. Use the tools above consistently, and you’ll likely feel more engaged without sacrificing the convenience you value. Good luck!

# %% [markdown]
# ## Student ID: `e20221543`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221543*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate the **flexibility** of e‑learning and the time saved by not having to travel.
# - You notice areas that could be better, such as keeping lecture versions up‑to‑date, having reliable Wi‑Fi, and receiving regular progress check‑ins.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | Easy to reach e‑learning content. |
# | **Flexibility & Time Management** | Ability to study when it fits your schedule. |
# | **Learning Convenience & Effectiveness** | Saves travel time and feels convenient. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Internet & Technical Issues** | Need for better Wi‑Fi and stable connection. |
# | **Learning Resources & Environment** | Want newer lecture versions, clearer resources, and a comfortable study space. |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it matters for you | What to do |
# |----------------|-----------------------|------------|
# | **Strengthen access to learning materials** | You value quick, easy access. | Upload slides, videos, references, and exercises **early** in the semester so you can download or view them whenever you need. |
# | **Improve learning effectiveness** | Combining online review with face‑to‑face help deepens understanding. | Use online review materials **before** class, then attend in‑person sessions for explanations, practice activities, and feedback. |
# | **Improve learning resources and environment** | Updated, well‑organized content and a comfortable space support your passive style. | Keep course files clearly labeled and regularly updated; arrange a quiet study area with good lighting and seating. |
# | **Support self‑paced learning** | Your flexibility works best when you can control the pace. | Provide recorded lessons and a weekly learning path so you can review material at your own speed. |
# | **Improve technical access and reliability** | Reliable internet is essential for you to use e‑learning effectively. | Offer offline copies of key resources, clear instructions for the learning platform, and quick‑response technical support. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | How it helps |
# |------|--------|--------------|
# | 1 | **Check the course portal** for any newly uploaded slides or videos. Download them for offline use. | Guarantees you have the latest material even if Wi‑Fi is spotty. |
# | 2 | **Create a personal weekly schedule** that lists which recorded lessons you’ll watch and when you’ll attend in‑person practice. | Keeps your learning self‑paced and organized. |
# | 3 | **Visit the campus IT desk** (or contact online support) to confirm you have access to a stable Wi‑Fi hotspot or loaner device. | Reduces technical interruptions. |
# | 4 | **Provide feedback** to the instructor about any outdated resources or classroom comfort issues. | Helps improve the learning environment for you and future students. |
#
# ---
#
# **Remember:** Your flexibility and appreciation for easy‑access content are strong assets. By ensuring materials are up‑to‑date, organized, and supported by reliable technology, you can make the most of both online and face‑to‑face learning experiences. If you need any help implementing these steps, reach out to your academic advisor or the university’s learning‑support team.

# %% [markdown]
# ## Student ID: `e20230509`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_support", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230509*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values online formats. You appreciate being able to review lessons through video recordings and feel that digital environments help you focus on the instructor’s explanations.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You like having slides, videos, and other resources available for review.
# - **Digital Skills Development** – You are comfortable using online tools and prefer digital learning.
# - **Student Engagement** – You stay actively involved in class activities.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You would benefit from clearer, more frequent communication with the teacher.
# - **Learning Difficulty & Clarity** – Sometimes explanations are not clear enough.
# - **Motivation & Self‑Discipline** – Maintaining motivation and self‑discipline can be a hurdle.
#
# ### 4. Personalized Recommendations
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload slides, videos, reference links, and exercises **early** in the LMS. | Lets you review material at your own pace and reinforces learning. |
# | **Digital Skills** | Offer short guides or tutorials on LMS tools, online research, and educational tech. | Strengthens the digital competencies you already enjoy using. |
# | **Engagement** | Include quick quizzes, gamified tasks, and practical activities within each module. | Keeps your high energy directed toward the content. |
# | **Interaction** | Schedule regular Q&A slots, small‑group discussions, and peer‑collaboration tasks; aim for faster lecturer feedback. | Improves the communication you find missing and deepens understanding. |
# | **Learning Support** | Provide clearer written instructions, concrete examples, and recorded step‑by‑step explanations. | Reduces confusion and makes complex ideas easier to grasp. |
# | **Motivation** | Set up weekly check‑ins, automated reminders, progress dashboards, and a simple study schedule template. | Helps you stay on track and sustain motivation throughout the term. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | • Access the course’s new “Resources” folder (slides + videos uploaded). <br>• Watch the introductory tutorial on using the LMS’s discussion board. |
# | **1‑2** | • Complete the first interactive quiz; note any unclear points. <br>• Join the scheduled live Q&A (30 min) and post one question in the forum. |
# | **2** | • Review the recorded step‑by‑step explanation for the current topic. <br>• Fill out the weekly self‑check‑in form (focus on motivation and study schedule). |
# | **Ongoing** | • Participate in at least one peer‑collaboration activity per module. <br>• Track your progress on the dashboard and adjust your study plan as needed. |
#
# By following these steps, you’ll leverage your strong engagement and digital comfort while addressing the areas that currently limit your learning experience. Good luck, and keep up the active participation!

# %% [markdown]
# ## Student ID: `e20221198`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20221198
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You feel more comfortable studying at home, especially when the classroom environment is hot.
#
# **Main Challenges**
# - The classroom temperature makes it difficult to focus; you would like the space to be cooler (e.g., by installing air‑conditioners).
#
# **Personalized Recommendations**
# - **Learning Environment:** Improve the physical learning space. Organise study materials clearly, keep resources up‑to‑date, and work with the university to enhance classroom comfort (e.g., better ventilation, fans, or air‑conditioning). A cooler, well‑arranged environment will help you stay focused and make the classroom feel more inviting.
#
# **Short Action Plan**
#
# | Step | What to Do | How to Do It | When |
# |------|------------|--------------|------|
# | 1 | Talk to the course coordinator or facilities office about classroom temperature. | Send a brief email describing the issue and suggesting possible solutions (fans, AC, better ventilation). | This week |
# | 2 | Create a tidy, organized study area at home. | Use folders, digital tools, or a simple desk layout to keep materials easy to find. | Immediately |
# | 3 | Use supplemental online resources when the classroom is uncomfortable. | Access lecture recordings, PDFs, or discussion boards from the learning platform. | As needed |
# | 4 | Monitor your comfort and performance. | Note any changes in focus or grades after the environment improves. | Ongoing |
#
# By improving the learning environment both on‑campus and at home, you’ll be able to study more comfortably and stay engaged with the course material.

# %% [markdown]
# ## Student ID: `e20220446`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220446*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** Learners who attend classes regularly but tend to take a more passive role. They benefit from clear structure, moderate interaction, and support that helps them stay on track.
#
# ---
#
# ### 2. Main Strengths
# - **Learning convenience & effectiveness:** You feel blended learning improves your self‑discipline and supports self‑directed study.
# - **Positive attitude:** Your comments about the current experience are upbeat, indicating you are already making good use of the format.
#
# ---
#
# ### 3. Main Challenges
# - **Assessment & workload:** You would like a smoother balance of assignments and clearer deadlines.
# - **Learning resources & environment:** You mentioned a wish for more interactive quizzes and better study resources.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Pair the online review material you already use with brief in‑person explanations, practice activities, and feedback. | • Before a class, skim the online notes. <br>• During the face‑to‑face session, ask the instructor to clarify key points and work through a short problem together. <br>• After class, use the online platform to submit a quick reflection or answer a short quiz for feedback. |
# | **Improve learning resources and environment** | Organize the digital and physical materials so they are easy to find, and make your study space comfortable. | • Use folders or tags on the LMS to group related resources (lecture slides, readings, practice questions). <br>• Keep a tidy desk, good lighting, and minimize distractions. <br>• Request the instructor to add more interactive quizzes or short polls if they are not already available. |
# | **Manage workload and assessment pressure** | Keep assignments balanced and deadlines clear, linking online tasks to what you do in class. | • Write down all due dates in a single calendar (digital or paper). <br>• Break larger tasks into smaller steps and schedule them alongside the corresponding in‑person session. <br>• If a deadline is unclear, ask the tutor for confirmation early. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Create a folder on the LMS for each course (e.g., “Lectures,” “Readings,” “Quizzes”). |
# | **Day 2** | Add upcoming assignment deadlines to a personal calendar; set reminder 2 days before each due date. |
# | **Day 3‑4** | Before the next class, review the online material and write down 2‑3 questions you want clarified. |
# | **Day 5** | During class, ask those questions, take brief notes, and do any in‑class practice offered. |
# | **Day 6** | Complete a short online quiz (or ask the instructor to add one) to get immediate feedback. |
# | **Day 7** | Review quiz results, note any gaps, and spend 30 min revisiting the relevant online content. |
# | **Day 8‑14** | Repeat the cycle for the next module, adjusting the study‑space setup if needed (e.g., better lighting, comfortable chair). |
#
# ---
#
# **Remember:** You already see blended learning as a tool for self‑discipline. By linking online review with focused in‑person practice, keeping your resources organized, and managing deadlines proactively, you’ll strengthen your learning effectiveness while keeping the workload manageable. Feel free to reach out to your instructors or learning support services if you need additional interactive activities or clarification on assignments. Good luck!

# %% [markdown]
# ## Student ID: `e20221402`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221402*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically makes good use of digital resources, likes to stay involved in class activities, and can manage their time flexibly.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials & Flexibility** – You appreciate being able to review class content when you miss a session, which helps you stay on track.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You find that some videos are not clear enough and would benefit from more detailed explanations.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Strengthen access to learning materials** | Ensure all slides, videos, references, and exercises are available early so you can review them anytime. | Look for a course “Resources” folder; download materials before class and keep them organized for quick reference. |
# | **Improve clarity and learning support** | Get clearer instructions, examples, and step‑by‑step guides to help you understand difficult concepts. | Use supplemental recorded explanations or ask the instructor for annotated examples when a video feels vague. |
# | **Support self‑paced learning** | Take advantage of recorded lessons and weekly learning paths that let you study at your own speed. | Follow the weekly roadmap, pause/replay videos as needed, and complete practice exercises on your schedule. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Locate the course’s “Resources” section and download all slides and videos for the upcoming week. |
# | **Day 2‑3** | Watch the first video; pause to note any unclear points. Search for any recorded explanations or ask the tutor for a short clarification. |
# | **Day 4** | Complete the related exercises using the downloaded materials; compare your answers with any provided solutions. |
# | **Day 5‑7** | Follow the weekly learning path: review slides, re‑watch video sections that were unclear, and add personal notes. |
# | **Day 8‑10** | Participate in a short discussion forum or study group to share your clarified understanding and get peer feedback. |
# | **Day 11‑14** | Reflect on what helped most (e.g., extra examples, step‑by‑step guides) and note any remaining gaps to discuss with the instructor. |
#
# By consistently using the available digital resources, seeking clearer explanations when needed, and pacing your study according to the weekly plan, you’ll reinforce your strengths and overcome the clarity challenges you’ve identified. Keep up the active engagement—you’re well positioned to succeed in a blended learning environment!

# %% [markdown]
# ## Student ID: `e20250137`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250137*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** You see blended learning as a way to gain flexibility, manage time better, and make study more convenient—especially when travel is difficult.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when it fits your schedule.
# - **Learning Convenience & Effectiveness** – You recognize that blended formats can help you learn efficiently.
#
# ### 3. Main Challenges
# - No specific challenges were reported.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it fits you | How to apply it |
# |----------------|----------------|-----------------|
# | **Improve learning effectiveness** | You already value the convenience of blended learning; adding focused in‑person sessions will deepen understanding. | • Attend scheduled face‑to‑face workshops where concepts are explained, practiced, and feedback is given.<br>• Use the online review materials you already access to prepare for these sessions. |
# | **Support self‑paced learning** | Your positive view of flexibility shows you thrive when you can control the pace of study. | • Use recorded lectures and weekly learning paths provided by the course.<br>• Review videos, readings, or quizzes anytime that suits you, especially before or after in‑person meetings. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the recorded lessons for your current module and set a personal weekly learning path (e.g., 2 hours of video + 1 hour of practice). |
# | **2** | Attend the first in‑person session; bring questions from your online review. Ask for immediate feedback on any practice tasks. |
# | **3‑4** | Continue the weekly self‑paced schedule; after each in‑person class, note what concepts were clarified and update your study plan accordingly. |
# | **5** | Review your progress: have the combined online + face‑to‑face approach improved your grasp of the material? Adjust the amount of self‑study time if needed. |
#
# By pairing your strong self‑direction with targeted face‑to‑face interaction, you can maximize both flexibility and learning effectiveness. Keep tracking what works best for you, and feel free to reach out to your instructors for additional support.

# %% [markdown]
# ## Student ID: `e20240274`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240274
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - Values the **flexibility** of blended learning and the **easy access to online resources** (e.g., slides, videos, references).
#
# **Main Challenges**
# - Unstable internet connection.
# - Difficulty staying focused during online sessions.
# - Wants clearer instructions and more interaction with peers and instructors.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Keep all course content (slides, videos, exercises, references) available early so you can study whenever you have a good connection. | Check the course portal at the start of each week; download needed files for offline use. |
# | **Increase interaction and communication** | More Q&A, group discussions, and quick lecturer feedback will help you stay focused and feel connected. | Join scheduled live discussion groups; use the forum to ask questions; request brief feedback on assignments. |
# | **Improve clarity and learning support** | Clear step‑by‑step guides, examples, and recorded explanations will reduce confusion. | Look for “how‑to” videos or guide documents attached to each module; use them before attempting exercises. |
# | **Support motivation and self‑discipline** | Weekly check‑ins, reminders, and progress tracking keep you on track. | Set a weekly study schedule; use the platform’s progress tracker; respond to any reminder emails or notifications. |
# | **Support self‑paced learning** | Recorded lessons let you review material at your own speed, which is useful when internet is spotty. | After each live session, watch the recorded version; pause and replay sections as needed. |
# | **Improve technical access and reliability** | Access to stable internet or offline materials will minimise disruptions. | Download all weekly resources when you have a good connection; contact the tech support desk if you experience outages; explore campus Wi‑Fi hotspots or loaner devices if needed. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–2:** Review the syllabus and locate where all weekly materials are posted. Download the first week’s slides, videos, and exercises for offline use.
# 2. **Day 3:** Join the first live Q&A session; write down any questions that arise.
# 3. **Day 4–5:** Create a simple study schedule (e.g., Mon‑Wed‑Fri 2 hrs) and set calendar reminders.
# 4. **Day 6:** Test the platform’s progress tracker; mark completed tasks each day.
# 5. **Day 7:** Contact technical support to confirm you have access to offline downloads and ask about campus Wi‑Fi options.
# 6. **Week 2:** Repeat steps 1‑5 for the second week’s content, adding a brief peer‑collaboration activity (e.g., a 15‑minute group chat) to boost interaction.
#
# By following these steps, you can keep leveraging your strong engagement while minimizing technical and focus‑related obstacles. Good luck!

# %% [markdown]
# ## Student ID: `e20240328`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20240328
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You describe your studies as “helpful for easy self‑study,” indicating you value convenience and effectiveness when you learn on your own. You also note that you tend to “study only one shift,” suggesting you usually focus on a single study period each day.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You appreciate tools that let you study independently and efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Limited Study Sessions** – Working in only one shift may restrict the amount of practice and feedback you receive.
#
# ---
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness** – Combine the online review materials you already find convenient with short, in‑person sessions that provide explanation, guided practice, and immediate feedback. This blend keeps your self‑paced convenience while adding the interactive support that can deepen understanding.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1‑2 | Identify a core topic you’ll review online. | Use the course’s digital resources to study the concept on your own. |
# | 1‑2 | Schedule a 30‑minute face‑to‑face (or live‑video) session. | Meet with a tutor, teaching assistant, or study group to discuss the topic, ask questions, and do a quick practice activity. |
# | 3‑4 | Add a second short in‑person session on a different day. | Rotate the timing of your live session to create a second study “shift.” |
# | Ongoing | Reflect after each blended cycle. | Note what you understood better after the live feedback and adjust the balance of online vs. in‑person time as needed. |
#
# By pairing your preferred self‑study approach with targeted in‑person explanation and feedback, you can boost retention and performance while still enjoying the flexibility you value.

# %% [markdown]
# ## Student ID: `e2024502NKH`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e2024502NKH*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility and can easily access learning materials from home. You are comfortable replying to recorded videos and appreciate the ability to study remotely.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You can join classes from home and respond to recorded content.
# - **Flexibility & Time Management** – Your schedule allows you to make use of digital resources whenever needed.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You would like higher‑quality video standards and quicker, more detailed feedback from lecturers.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to use it |
# |----------------|-----------------------|---------------|
# | **Strengthen access to learning materials** | Ensure all slides, videos, references, and exercises are uploaded early so you can review them at any time. | Check the course portal each week for new uploads; download materials you want to study offline. |
# | **Increase interaction and communication** | Add more Q&A sessions, group discussions, and peer collaboration, plus faster lecturer feedback. | Participate in scheduled live Q&A or discussion boards; ask for clarification promptly; use peer‑review groups for assignments. |
# | **Support self‑paced learning** | Provide recorded lessons and weekly learning paths that let you study at your own speed. | Follow the weekly learning path outline; re‑watch recorded lessons before completing exercises; set personal milestones. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Log into the course platform and download all newly uploaded slides and videos for the upcoming topic. |
# | **Wednesday** | Join the live Q&A session (or post questions on the discussion board) to clarify any doubts from the recorded lesson. |
# | **Friday** | Review the weekly learning path; set two specific goals (e.g., finish exercise #3 and draft a peer‑review comment). |
# | **Next Monday** | Submit any pending work and request feedback; note the response time and quality. |
# | **Next Wednesday** | Participate in a small group discussion or peer‑collaboration activity. |
# | **Next Friday** | Reflect on the week: Did the early material access help? Was the feedback quicker? Adjust your plan accordingly. |
#
# By following these steps, you’ll keep leveraging your strong engagement while improving interaction and feedback quality—key factors for success in a blended learning environment. Good luck!

# %% [markdown]
# ## Student ID: `e20240247`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240247*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** You appreciate the flexibility of blended learning and the easy access to course materials.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You find it helpful that slides, videos, and other resources are readily available.
# - **Flexibility & Time Management** – The ability to study when it fits your schedule works well for you.
#
# ### 3. Main Challenges
# - No specific challenges were reported. Because the open‑ended response was brief, the recommendations rely mainly on the typical needs of your segment.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it matters for you | What to do |
# |----------------|------------------------|------------|
# | **Strengthen access to learning materials** | You already see easy access as a strength; ensuring all content is uploaded early will keep the experience smooth. | • Upload slides, videos, reference links, and exercises **before** each class session.<br>• Keep a single, organized folder or LMS page where everything is easy to find. |
# | **Support self‑paced learning** | Your preference for flexibility means you benefit from being able to review material on your own schedule. | • Record all live lessons and make them available for later viewing.<br>• Provide a weekly learning path that outlines what to study and when.<br>• Offer optional practice exercises that students can complete at their own speed. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Verify that the LMS contains all slides, videos, and reading links for the upcoming module. |
# | **Week 2** | Publish a recorded version of the first live lecture and share a simple weekly roadmap (e.g., “Monday: watch video; Wednesday: complete exercise”). |
# | **Week 3** | Collect brief feedback on the accessibility of the materials and adjust the folder structure if needed. |
# | **Ongoing** | Continue uploading new content early and keep the weekly learning path updated so you can study whenever it suits you. |
#
# ---
#
# **Remember:** Your success in a blended environment grows when you can easily reach the materials you need and move through them at your own pace. Use the steps above to keep your learning experience both flexible and well‑organized. Good luck!

# %% [markdown]
# ## Student ID: `e20240053`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240053*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. Your responses show a strong appreciation for the flexibility and personalized pacing that blended learning offers, and you are motivated to make the most of digital resources.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You value being able to study at your own pace and appreciate the ability to fit learning around other commitments.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Want more opportunities for Q&A, discussion, and quick feedback from lecturers.
# - **Internet & Technical Issues:** Need reliable campus Wi‑Fi, device support, and offline options.
# - **Learning Resources & Environment:** Desire clearer organization of materials and better study spaces.
# - **Motivation & Self‑Discipline:** Looking for structures that help you stay motivated and manage self‑discipline.
#
# ### 4. Personalized Recommendations
# | Focus Area | What the university can do for you |
# |------------|-------------------------------------|
# | **Interaction** | Add regular live Q&A sessions, group discussions, and peer‑collaboration activities. Ensure lecturers provide prompt feedback on assignments. |
# | **Learning Environment** | Organize course materials in a clear, searchable format; keep digital resources up‑to‑date; improve physical study spaces and classroom comfort. |
# | **Motivation** | Implement weekly check‑ins or progress reminders, and offer tools for tracking your learning milestones and creating a structured study schedule. |
# | **Self‑Paced Learning** | Provide recorded lectures and weekly learning paths so you can review content whenever needed. |
# | **Technical Access** | Ensure stable campus Wi‑Fi, offer offline downloadable materials, give clear platform guides, and make technical support readily available. |
#
# ### 5. Short Action Plan
# | Week | Action |
# |------|--------|
# | **1** | Join any existing online forum or chat group for your courses to start building peer connections. |
# | **2** | Download the week’s recorded lectures and set a personal study schedule using the provided weekly learning path. |
# | **3** | Attend the first live Q&A or discussion session; note any feedback delays and report them to the lecturer. |
# | **4** | Use the university’s technical support portal to test offline access to materials and confirm Wi‑Fi reliability in your preferred study spot. |
# | **5** | Complete a self‑assessment checklist (motivation, progress tracking) and schedule a brief check‑in with your tutor or mentor. |
#
# By following these steps, you can capitalize on your strengths while addressing the challenges you identified, making your blended‑learning experience more effective and enjoyable.

# %% [markdown]
# ## Student ID: `e20240133`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "motivation"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240133
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You see value in having a way to fill in gaps for missed lessons, highlighting the importance of easy access to learning materials.
#
# **Main Challenges**
# - Keeping sources and files up‑to‑date and staying focused.
# - Managing the learning environment and maintaining motivation/self‑discipline.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload slides, videos, reference links, exercises and any other course materials **early** in the semester (e.g., the week before a lecture). | Gives you a reliable place to catch up on missed lessons and reduces the need to scramble for resources. |
# | **Learning Environment** | • Organise all digital files in clearly labelled folders (e.g., “Week 1 – Slides”, “Assignments”). <br>• Set aside a tidy, comfortable study space and keep it free of distractions. <br>• Regularly check that any shared resources are current and replace outdated files promptly. | A clean, well‑structured environment makes it easier to locate what you need and helps you stay focused. |
# | **Motivation & Self‑Discipline** | • Schedule a short **weekly check‑in** (e.g., Friday 15 min) to review what you’ve completed and plan the next week. <br>• Use simple reminders or a digital planner to mark study blocks. <br>• Track progress visually (check‑lists, progress bars). | Structured check‑ins and visible progress keep you accountable and boost motivation to stay on track. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–2:** Create a master folder for the course and set up sub‑folders for each week’s materials.
# 2. **Day 3–4:** Upload all currently available slides, videos and reading links to the appropriate folders.
# 3. **Day 5:** Choose a quiet study spot; arrange it with only the tools you need (laptop, notebook, headphones).
# 4. **Day 6:** Set a recurring weekly reminder (e.g., every Friday at 4 pm) for a 15‑minute progress check‑in.
# 5. **Week 2:** Review the folder structure, add any new resources that appear, and update any outdated files.
# 6. **End of Week 2:** Reflect on your focus and motivation levels; adjust study blocks or reminder times if needed.
#
# Following these steps will strengthen your access to materials, create a more supportive learning environment, and build habits that keep motivation high. You’re already aware of the gaps you want to fill—these actions make it easier to do so. Good luck!

# %% [markdown]
# ## Student ID: `e20231067`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20231067
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values having the right materials to understand lessons, especially when classroom explanations are unclear. You appreciate convenient, effective ways to review content and would like clearer guidance and more research‑oriented material.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You recognize that having slides, videos, and references available helps you grasp the lesson.
# - **Learning Convenience & Effectiveness** – You prefer resources that let you study the material at your own pace and reinforce classroom learning.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You find some lessons unclear and would like more detailed explanations, examples, and research‑focused content.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What It Means for You | How to Use It |
# |----------------|----------------------|---------------|
# | **Strengthen access to learning materials** | Ensure all course slides, videos, reference links, and practice exercises are uploaded early in the week. | Check the course portal regularly; download materials before class so you can review them when needed. |
# | **Improve learning effectiveness** | Pair the online review resources with in‑person explanations, practice activities, and feedback sessions. | After watching a video or reading a slide, attend the related tutorial or lab to apply the concepts and ask questions. |
# | **Improve clarity and learning support** | Receive clearer instructions, step‑by‑step guides, and recorded explanations for complex topics. | Look for short “how‑to” videos or written guides posted by the instructor; use them as a reference when a lesson feels confusing. |
#
# These suggestions are drawn directly from the evidence about your strengths, challenges, and the “content_access,” “learning_effectiveness,” and “learning_support” tags identified for your segment.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Monday** | Log into the course platform and download all posted slides and videos for the upcoming module. |
# | **Week 1 – Tuesday** | Watch the introductory video, then write down any unclear points. |
# | **Week 1 – Wednesday** | Attend the in‑person session; ask the instructor to clarify the points you noted. |
# | **Week 1 – Thursday** | Complete the practice exercises provided with the module. |
# | **Week 1 – Friday** | Review the recorded explanations or step‑by‑step guides posted after class. |
# | **Week 2 – Monday** | Start the research‑oriented reading list (if provided) and summarize one key idea. |
# | **Week 2 – Wednesday** | Participate in a peer‑study group to discuss the module and share resources. |
# | **Week 2 – Friday** | Reflect on what helped most (e.g., videos, guides, group work) and note any remaining gaps for the instructor. |
#
# Follow this cycle each module to keep materials accessible, reinforce learning with active practice, and ensure you receive the clear support you need. Good luck, and keep leveraging your strong engagement!

# %% [markdown]
# ## Student ID: `e20220472`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220472*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits of this segment:** strong motivation, frequent self‑study, and a preference for interactive, mixed‑mode learning.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You already spend a good amount of time on self‑study, which helps you grasp material quickly.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable connectivity can interrupt online activities.
# - **Learning Resources & Environment:** Limited or uncomfortable study spaces affect focus.
#
# *(Your open‑ended responses were brief, so the recommendations below rely mainly on the characteristics of the “Highly Engaged (Active) Learners” segment together with the challenges you reported.)*
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Learning Effectiveness** | Combine the online review materials you already use with in‑person explanations, guided practice, and timely feedback. | Blending the two modes reinforces concepts and lets you apply what you study on your own. |
# | **Learning Environment** | • Keep your study materials organized and up‑to‑date.<br>• Improve your study space (e.g., a quiet corner, good lighting, ergonomic seating).<br>• Use campus facilities or libraries when home conditions are poor. | A tidy, comfortable environment reduces distractions and supports deeper concentration. |
# | **Technical Access** | • Secure a stable internet connection (e.g., campus Wi‑Fi, a reliable mobile hotspot, or a wired line).<br>• Download offline versions of essential readings and videos ahead of time.<br>• Follow the platform’s quick‑start guide and note the technical support contact. | Reliable access and offline options keep your learning flow uninterrupted, even when connectivity falters. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify a quiet study spot on campus or in a library; bring a small organizer for your notes and materials. |
# | **Day 3–4** | Test your internet speed at home. If unstable, arrange a backup (e.g., campus Wi‑Fi hotspot or mobile data plan). |
# | **Day 5** | Download the next week’s lecture videos and reading PDFs for offline use. |
# | **Day 6–7** | Schedule a 30‑minute in‑person session (office hours, study group, or tutorial) to discuss the material you reviewed online. |
# | **Day 8–10** | Apply what you learned by completing a short practice exercise and ask for feedback from a tutor or peer. |
# | **Day 11–14** | Review how the new study space and tech setup worked; adjust any remaining issues (lighting, chair, connectivity). |
#
# Follow these steps, and you’ll strengthen both the effectiveness of your learning and the reliability of the environment in which you study. Keep leveraging your strong self‑study habit, and the blended approach will become even more powerful. Good luck!

# %% [markdown]
# ## Student ID: `e20211364`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211364*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You value having more time for self‑study and are comfortable using digital resources.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You appreciate the flexibility that self‑study provides.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You find it difficult to understand material when you don’t have direct instructor support.
# - **Learning Difficulty & Clarity:** Content can feel unclear without immediate guidance.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request faster feedback from the lecturer after submissions. | Increases real‑time communication and lets you clarify doubts quickly. |
# | **Learning Effectiveness** | • Use the online review materials **before** attending in‑person classes.<br>• During class, focus on the lecturer’s explanations, practice exercises, and receive feedback. | Blends self‑study with guided practice, reinforcing understanding. |
# | **Learning Support** | • Look for clearer written instructions and step‑by‑step guides provided by the course.<br>• Watch recorded explanations and example walkthroughs when concepts are unclear. | Provides the extra scaffolding you need when instructor support is not immediately available. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Review the upcoming module’s online summary material (30 min). |
# | **Tue** | Post any questions on the course forum; schedule a 15‑min virtual Q&A with the lecturer. |
# | **Wed** | Attend the live group discussion; take notes on key points. |
# | **Thu** | Complete the practice exercise; submit for feedback. |
# | **Fri** | Watch the recorded explanation for any topics you found difficult. |
# | **Weekend** | Reflect on what helped most and plan which peer‑collaboration activity to join next week. |
#
# By combining your strong self‑study habits with more structured interaction, clearer resources, and timely feedback, you’ll be able to maintain high engagement while overcoming the challenges of understanding content without direct instructor support. Good luck!

# %% [markdown]
# ## Student ID: `e20220258`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20220258
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - Values the **flexibility** of blended learning, appreciating the ability to study at his own pace and to research freely online.
#
# **Main Challenges**
# - Finds it time‑consuming to locate specific courses in Moodle, especially when older‑year materials are not easy to search or archive.
# - This points to **technical/access issues** that can interrupt smooth learning.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** (tag: *self_paced*) | Keep using recorded lectures and weekly learning paths so you can review material whenever it fits your schedule. | • Save the weekly learning path PDFs in a personal folder. <br>• Re‑watch recorded lessons before exams or when you need a refresher. |
# | **Improve technical access and reliability** (tag: *tech_issue*) | Reduce the time spent searching for courses and avoid interruptions caused by platform navigation. | • Use the platform’s “search” function (if available) or request a shortcut list from the course admin. <br>• Download key resources for offline study when internet stability is a concern. <br>• Contact technical support for help with archiving older courses or improving navigation. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Create a personal course index** – List the current semester’s Moodle links in a spreadsheet or note‑taking app for quick access.
# 2. **Download weekly learning path materials** – Save them locally so you can study without relying on constant internet connectivity.
# 3. **Set a weekly review slot** – Allocate 30 minutes each week to watch recorded lessons you missed or want to revisit.
# 4. **Reach out for technical help** – Submit a ticket to the university’s IT support asking for guidance on searching/archiving older courses.
#
# By leveraging your strong self‑direction and addressing the navigation challenges, you can keep your learning both flexible and efficient. Good luck!

# %% [markdown]
# ## Student ID: `e20240089`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240089*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Learning that is convenient and effective (you mentioned “personalized learning”).
# - **Current challenge:** Maintaining motivation and self‑discipline (you noted “reduced student motivation”).
#
# ---
#
# ### 2. Main Strengths
# - Strong engagement with learning resources.
# - Preference for personalized, convenient study options that boost effectiveness.
#
# ---
#
# ### 3. Main Challenges
# - Keeping motivation high over time.
# - Staying disciplined without external prompts.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How to apply it in a blended setting |
# |----------------|---------------------------------------|
# | **Improve learning effectiveness** | • Use online review materials (videos, quizzes, flashcards) **before** attending face‑to‑face sessions. <br>• In class, focus on explanations, guided practice, and immediate feedback to deepen understanding. |
# | **Support motivation and self‑discipline** | • Set up a **weekly check‑in** (e.g., a short meeting or digital survey) to review goals. <br>• Enable **reminders** and a simple **progress tracker** in your learning platform. <br>• Create a **structured study schedule** that blends online review time with fixed in‑person study blocks. |
#
# These suggestions are drawn directly from the rule‑based recommendations for your segment and the specific tags identified for you (*learning_effectiveness* and *motivation*).
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Choose one online review module for your current topic. |
# | **Tuesday** | Attend the corresponding in‑person session; focus on practice and ask for feedback. |
# | **Wednesday** | Update your progress tracker with what you’ve mastered. |
# | **Thursday** | Set a reminder for a 10‑minute self‑reflection on motivation (what’s working, what isn’t). |
# | **Friday** | Schedule a 15‑minute check‑in with a peer or tutor to discuss progress. |
# | **Weekend** | Review the online material again briefly; adjust your study schedule for next week based on what felt most motivating. |
#
# Repeat this cycle, tweaking the timing and tools as you discover what keeps you most engaged and disciplined.
#
# ---
#
# **Remember:** Your strong engagement is a great foundation. By pairing convenient online review with focused in‑person practice and adding regular motivation supports, you can sustain high performance throughout the semester. Good luck!

# %% [markdown]
# ## Student ID: `e20241025`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241025*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What this means:** You tend to participate less actively in class activities and may rely more on the material being presented to you rather than seeking out interaction or extra support.
#
# ---
#
# ### 2. Main Strengths
# *No specific strengths were reported, so this overview is based on the typical profile of moderately engaged learners.*
#
# ---
#
# ### 3. Main Challenges
# *No specific challenges were reported, so the following are common areas where learners in this segment often need help.*
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | Why it Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join short Q&A sessions after lectures<br>• Participate in small‑group discussions or peer‑collaboration activities<br>• Request quicker feedback from the lecturer | Increases engagement and gives you more opportunities to clarify doubts. |
# | **Learning Support** | • Look for clear, step‑by‑step guides and recorded explanations for complex topics<br>• Use example problems provided by the instructor | Improves understanding when you study independently. |
# | **Motivation & Self‑Discipline** | • Set a weekly check‑in with yourself (or a study buddy) to review progress<br>• Use reminders or a simple progress tracker<br>• Follow a structured study schedule | Keeps you on track and builds a habit of regular study. |
# | **Self‑Paced Learning** | • Access recorded lessons so you can review them at any time<br>• Follow the weekly learning path outlined by the course<br>• Keep all materials organized for easy reference | Lets you learn at a comfortable speed while still meeting course deadlines. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | **1** | **Join a Q&A session** | Register for the next live Q&A or post a question in the forum. |
# |      | **Create a simple study schedule** | Block 30‑45 min each day for the course; add reminders on your phone. |
# | **2** | **Use a recorded lesson** | Watch one recorded lecture and take notes; compare notes with the provided step‑by‑step guide. |
# |      | **Track progress** | Mark completed topics in a checklist; note any questions to bring to the next discussion. |
#
# Stick to these steps, and adjust as you discover what works best for you. Small, consistent actions will help turn passive participation into active learning. Good luck!

# %% [markdown]
# ## Student ID: `e20230857`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230857
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate the flexibility of blended learning. It lets you:
# - Access course materials anytime, which helps you manage your time and develop digital skills.
# - Review slides, videos, and other resources at your own pace.
#
# **Main Challenges**
# You experience several hurdles that can affect your learning:
# - Unstable internet and limited devices make online sessions difficult.
# - Online classes can feel less interactive, which reduces focus and motivation.
# - Some course materials are not always clear or well‑organized.
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on the rule‑based recommendations) |
# |------|--------------------------------------------------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** so you can review them whenever you need. |
# | **Digital Skills** | Get short guides on using the LMS, online research tools, and other educational technologies to boost confidence with digital tasks. |
# | **Interaction** | Participate in scheduled Q&A sessions, group discussions, and peer‑collaboration activities; look for faster feedback from lecturers. |
# | **Learning Environment** | Use clearly organized folders and updated resources; take advantage of quiet study spaces on campus or at home, and let the university know if classroom comfort is an issue. |
# | **Learning Support** | Seek out recorded explanations, step‑by‑step guides, and concrete examples that clarify complex topics. |
# | **Motivation & Self‑Discipline** | Set a weekly check‑in with yourself (or a study buddy) to track progress, use reminders, and follow a structured study schedule. |
# | **Self‑Paced Learning** | Make use of recorded lessons and weekly learning paths so you can revisit content at a speed that suits you. |
# | **Technical Issues** | Request stable campus Wi‑Fi or offline copies of materials; keep a list of technical support contacts and follow clear platform instructions. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Download all currently available lecture slides and videos; save them for offline use.
# 2. **Day 3‑4:** Watch a short tutorial on the LMS (look for a “Getting Started” video from the university).
# 3. **Day 5:** Join a peer‑study group or schedule a 30‑minute Q&A session with the lecturer.
# 4. **Day 6‑7:** Create a simple weekly study schedule with specific times for reviewing recorded lessons and completing exercises.
# 5. **Day 8‑10:** Test the campus Wi‑Fi in a quiet study area; if problems persist, request a hotspot or offline material package from the IT help desk.
# 6. **Day 11‑14:** Review one module using the recorded lessons and step‑by‑step guides; note any unclear points and ask the lecturer for clarification.
#
# Following these steps will help you make the most of blended learning’s flexibility while addressing the technical and interaction challenges you’ve identified. Keep track of what works best for you, and adjust the plan as needed. Good luck!

# %% [markdown]
# ## Student ID: `e20240242`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240242*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You actively use Moodle, appreciate extra lessons, and like contacting lecturers for questions.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value being able to reach slides, videos, and other resources on Moodle.
# - **Student Engagement** – You enjoy interactive opportunities that keep you involved in the course.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Mobile data does not work well inside the school, especially in the library.
# - **Learning Resources & Environment** – You would like a more reliable Wi‑Fi connection and better study spaces.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Practical steps you can take |
# |----------------|----------------------|------------------------------|
# | **Strengthen access to learning materials** *(content_access)* | Keep all course content (slides, videos, references, exercises) available early so you can study anytime, even offline. | • Download lecture files from Moodle after each class.<br>• Request that lecturers upload materials ahead of time if they haven’t already. |
# | **Increase learner engagement** *(engagement)* | Use interactive tools that match your active style. | • Participate in quizzes, games, and discussion boards on Moodle.<br>• Join study groups or virtual labs that involve practical tasks. |
# | **Improve learning resources and environment** *(learning_environment)* | A well‑organized, comfortable study space helps you stay focused. | • Suggest to the school that study areas be better arranged and equipped.<br>• Use campus spaces with good lighting and seating when possible. |
# | **Improve technical access and reliability** *(tech_issue)* | Reliable internet lets you use Moodle without interruptions. | • Ask the IT department for stronger Wi‑Fi coverage in the library.<br>• Download offline copies of essential materials for use when connectivity is poor.<br>• Keep a list of technical support contacts handy. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Download all current lecture slides and videos from Moodle to a local folder. |
# | **Day 3‑4** | Join a Moodle quiz or discussion related to your current module. |
# | **Day 5** | Visit the library and note any Wi‑Fi dead zones; report them to campus IT. |
# | **Day 6‑7** | Create a tidy study spot in a quiet campus area; keep your downloaded materials there. |
# | **Day 8‑10** | Ask your lecturer to upload next week’s materials early (or confirm the schedule). |
# | **Day 11‑14** | Test offline study: work on an exercise without internet, then sync your work when back online. |
#
# By following these steps, you can keep leveraging your high engagement while reducing technical frustrations and improving your study environment. Keep communicating with lecturers and campus support—they’re key partners in making blended learning work best for you.

# %% [markdown]
# ## Student ID: `e20221466`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221466*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you shared:**
#   - **Strength:** “we can research more and more” – you enjoy digging deeper into topics.
#   - **Challenge:** “please make to ask more information when have questions” – you would like clearer ways to seek help when something isn’t clear.
#
# Because the open‑ended responses are brief, the recommendations below rely primarily on the characteristics of the “Highly Engaged (Active) Learners” segment.
#
# ---
#
# ### 2. Main Strengths
# - Strong motivation to explore and research content.
# - Naturally active in learning activities.
#
# ### 3. Main Challenges
# - Need for more structured opportunities to ask questions and obtain additional information.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps you |
# |------|------------|------------------|
# | **Content Access** | Upload or request early access to slides, videos, reference links, and practice exercises. | Having all materials ready lets you start researching right away and keep your momentum. |
# | **Digital Skills** | Get a short guide or tutorial on using the LMS, online libraries, and research tools. | Strong digital skills make it easier to locate information and ask precise questions when you need help. |
# | **Engagement** | Participate in quizzes, quick games, practical tasks, and discussion forums. | Interactive activities keep your high energy focused and give natural moments to raise questions. |
# | **Self‑Paced Learning** | Use recorded lectures and weekly learning paths that you can review anytime. | You can dive deeper into topics at your own speed and revisit any part that isn’t clear. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s central folder (LMS) and download all available slides, videos, and reference links. |
# | **Day 3** | Watch a 10‑minute tutorial on LMS navigation and digital research tools (e.g., library databases, citation managers). |
# | **Day 4–5** | Complete the first interactive quiz or game; note any concepts you want to explore further. |
# | **Day 6** | Post one question in the discussion forum about a topic you’re researching; use the digital‑skill guide to reference sources. |
# | **Day 7** | Review the recorded lecture for the week; add personal notes or extra resources you discover. |
# | **Day 8–10** | Repeat the cycle for the next module, focusing on using the weekly learning path to stay on schedule. |
# | **Day 11–14** | Reflect: Which digital tools helped you ask better questions? Share a brief tip with classmates to reinforce engagement. |
#
# ---
#
# **Keep it simple:** Use the materials and tools already provided, ask clear questions in forums or during live sessions, and take advantage of recorded content to study at your own pace. Your active approach to research will thrive with these small, structured supports. Good luck!

# %% [markdown]
# ## Student ID: `e20240196`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support", "motivation", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240196*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You appreciate the ability to **rewatch lessons** and study **anytime, anywhere**. This flexibility helps you keep up with the course when you can fit it into your schedule. At the same time, you find it hard to **manage your schedule, stay disciplined, and avoid procrastination**. You also would like **clearer explanations** because you cannot ask questions instantly during online sessions.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You make good use of recorded content and can study when it suits you.
# - **Flexibility & Time Management** – The ability to learn at your own pace is a clear advantage for you.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Procrastination and difficulty sticking to a study plan.
# - **Learning Difficulty & Clarity** – Need for clearer instructions and examples when concepts are confusing.
# - **Assessment & Workload** – Uncertainty about deadlines and the amount of work expected.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What It Means for You |
# |----------------|-----------------------|
# | **Strengthen access to learning materials** (content_access) | Course staff will upload slides, videos, reference links, and exercises **early** so you can review them whenever you need. |
# | **Improve clarity and learning support** (learning_support) | Expect **clearer instructions, step‑by‑step guides, and recorded explanations** that you can pause and replay, reducing the need for immediate live answers. |
# | **Support motivation and self‑discipline** (motivation) | Weekly check‑ins, reminder emails, and a simple progress tracker will help you build a regular study routine and stay on top of tasks. |
# | **Support self‑paced learning** (self_paced) | Recorded lessons and a weekly learning path will let you decide the order and speed of your study while still following a structured schedule. |
# | **Manage workload and assessment pressure** (workload_support) | Assignments will be balanced, deadlines clearly highlighted, and online tasks aligned with any in‑person sessions to avoid overload. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the course’s **uploaded slide deck and video** for the upcoming module. |
# | **Day 3** | Set a **personal study schedule** (e.g., 1 hour on Mon/Wed/Fri) and add the deadlines to your calendar. |
# | **Day 5** | Watch the **recorded explanation** for any concept you found unclear; take notes on the step‑by‑step guide. |
# | **Day 7** | Complete the first **short practice exercise** and mark it as done in the progress tracker. |
# | **Day 9** | Attend the **weekly check‑in** (online form or brief chat) to confirm you’re on track. |
# | **Day 12** | Review the **assignment brief** and confirm you understand the workload and due dates. |
# | **Day 14** | Reflect on what helped you stay disciplined (reminders, schedule) and adjust the plan for the next two weeks. |
#
# Follow this plan, use the newly available resources, and keep the weekly check‑ins as a habit. Over time, the clearer materials and structured support should reduce procrastination and make your learning experience smoother and more rewarding. Good luck!

# %% [markdown]
# ## Student ID: `e20240856`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240856*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate a balanced mix of face‑to‑face classes and online media, describing it as a “well‑made fusion dish.”
# - You do not experience major Wi‑Fi or Zoom fatigue, but you notice occasional friction in how blended learning works.
#
# ### 2. Main Strengths
# - **Digital Skills Development** – You recognize the value of digital tools and are open to using them effectively.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Even though connectivity is generally okay, you see points where technical reliability can hinder learning.
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation Title | What to Do |
# |-----|----------------------|------------|
# | **digital_skill** | Develop digital learning skills | • Get short guides or short videos on how to navigate the LMS, locate online resources, and use research tools.<br>• Practice using the educational technologies that your courses provide (e.g., discussion boards, quiz apps). |
# | **tech_issue** | Improve technical access and reliability | • Keep a backup plan: download lecture slides or readings in advance so you can study offline if the connection drops.<br>• Follow the clear step‑by‑step instructions for each platform (login, submission, video playback).<br>• Use the university’s technical‑support help desk for quick assistance when problems arise. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Review the LMS quick‑start guide sent by your instructor (5‑10 min). |
# | **Day 3‑4** | Download all required readings for the upcoming week and store them on your device. |
# | **Day 5** | Try a short practice activity (e.g., a quiz) using the online tool; note any technical hiccups. |
# | **Day 6‑7** | If you encounter an issue, contact the campus tech‑support desk and record the solution. |
# | **Week 2** | Schedule 15 minutes each week to explore one new digital feature (e.g., annotation tool, discussion forum). |
#
# By strengthening your digital competencies and having reliable backup options, you’ll reduce the friction you’ve noticed and get more out of the blended format. Keep the plan simple, and reach out for support whenever a technical snag appears. Good luck!

# %% [markdown]
# ## Student ID: `e20240818`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240818*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Flexibility, time‑management, and high levels of engagement in learning activities.
#
# ---
#
# ### 2. Main Strengths
# - You thrive when learning is **flexible and personalized**.
# - You are **highly engaged**, enjoying active‑learning formats such as discussions, games, and practical tasks.
#
# ---
#
# ### 3. Main Challenges
# - Managing **assessment workload** and ensuring a smooth **technology adoption** experience for both you and faculty.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How it helps you | Practical actions you can take |
# |----------------|------------------|--------------------------------|
# | **Increase learner engagement** *(tag: engagement)* | Keeps your motivation high and builds on your active‑learning style. | • Participate in quizzes, games, and interactive discussions.<br>• Seek out practical tasks or case studies in each module. |
# | **Support self‑paced learning** *(tag: self_paced)* | Lets you control the pace that fits your schedule, reinforcing flexibility. | • Use recorded lectures and weekly learning paths.<br>• Review materials whenever needed to solidify understanding. |
# | **Manage workload and assessment pressure** *(tag: workload_support)* | Reduces stress from heavy assignment loads and aligns online work with face‑to‑face sessions. | • Keep a personal deadline tracker that mirrors course deadlines.<br>• Ask the instructor to clarify assignment expectations and how online tasks connect to in‑person activities. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the course’s weekly learning path and download any recorded lessons. |
# | **Tuesday** | Add all assignment due dates to a digital calendar; set reminders 3 days before each deadline. |
# | **Wednesday** | Join a discussion forum or study group for the current topic; contribute at least one comment or question. |
# | **Thursday** | Complete a short quiz or game related to the week’s material to reinforce learning. |
# | **Friday** | Spend 30 minutes revisiting any recorded lecture you found challenging. |
# | **Weekend** | Reflect on workload balance: note any tasks that felt overwhelming and plan how to adjust next week (e.g., break large assignments into smaller steps). |
#
# ---
#
# **Remember:** Your strong engagement and desire for flexibility are assets. By using interactive activities, self‑paced resources, and clear workload management, you can keep your learning experience both effective and enjoyable. If you encounter any technical or workload issues, reach out early to your instructor or a learning support advisor. Good luck!

# %% [markdown]
# ## Student ID: `e20240165`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240165*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can control your schedule, revisit past lessons, and prepare efficiently for exams. You value easy access to slides, videos, and other resources that let you study independently.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having slides, videos, and references available early.
# - **Flexibility & Time Management** – Being able to set your own pace and review content when needed works well for you.
# - **Learning Convenience & Effectiveness** – You find that organized, review‑friendly materials help you perform better on upcoming exams.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – It is hard to ask quick questions about specific points, and feedback can be slow.
# - **Learning Difficulty & Clarity** – Some video explanations lack depth, making concepts harder to grasp.
# - **Learning Resources & Environment** – The platform’s website feels slow and outdated, which disrupts study flow.
# - **Motivation & Self‑Discipline** – Periods of low motivation lead to procrastination.
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload all slides, videos, reference links, and exercises **early** in the week so you can start reviewing right away. |
# | **Interaction** | Introduce short **Q&A sessions** and **peer‑discussion groups**; ask lecturers for quicker feedback on specific questions. |
# | **Learning Effectiveness** | Pair the online review materials with **in‑person explanations or live demos**, followed by practice tasks and feedback. |
# | **Learning Environment** | Keep the digital folder **well‑organized** (clear headings, consistent naming). Request updates to the platform UI or use a faster browser/device if possible. |
# | **Learning Support** | Provide **step‑by‑step guides**, extra examples, and short recorded explanations for complex topics. |
# | **Motivation** | Set up **weekly check‑ins** (with yourself or a study buddy), use a simple progress tracker, and schedule short study blocks with reminders. |
# | **Self‑Paced Learning** | Follow a **weekly learning path** that lists which recorded lessons to watch and which exercises to complete, allowing you to move forward at your own speed. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How to Implement |
# |------|--------|-------------------|
# | **1** | **Access & Organization** – Ask the instructor to upload all week‑1 materials by Monday. Create a folder with sub‑folders for slides, videos, and exercises. | Use the course LMS or a cloud drive; label files clearly (e.g., “Week1_Slides.pdf”). |
# | **1** | **Interaction Boost** – Join a study‑group chat or schedule a 15‑minute live Q&A with the lecturer. | Send a quick email to the lecturer proposing a short Q&A slot. |
# | **1‑2** | **Motivation Check‑In** – Set a recurring calendar reminder for a 10‑minute progress review every Friday. | Mark completed tasks in a simple checklist (e.g., “Reviewed video 3”, “Submitted exercise 2”). |
# | **2** | **Learning Support** – Request a short recorded walkthrough for the most confusing topic identified in week 1. | Post a request in the course forum or ask during the Q&A. |
# | **2** | **Self‑Paced Path** – Draft a personal learning schedule for weeks 2‑3, listing which recordings to watch each day. | Use a spreadsheet or a planner app; stick to the schedule and adjust as needed. |
#
# ---
#
# **Remember:** Your strong ability to manage time and review materials is a great foundation. By adding structured interaction, clearer resources, and regular motivation checks, you can turn those challenges into new strengths and keep your learning both active and effective. Good luck!

# %% [markdown]
# ## Student ID: `e20240862`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240862*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You actively participate in both online and face‑to‑face activities and value the flexibility that blended learning provides.
#
# ### 2. Main Strengths
# - **Access to Learning Materials & Flexibility:** You appreciate being able to review lessons anytime.
# - **Digital Skills Development:** You see blended learning as a way to improve your digital abilities.
# - **Student Engagement:** You enjoy the mix of classroom interaction and online resources.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unstable connection sometimes hinders your online work.
# - **Learning Difficulty & Clarity:** Some online lessons are hard to understand without additional support.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Instructors will upload slides, videos, references, and exercises early in the week. | You can review content whenever your connection is stable and stay ahead of class. |
# | **Develop digital learning skills** | Short guides and short videos on how to use the LMS, search academic sources, and use collaboration tools. | Boosts the digital skills you already value and makes navigation smoother. |
# | **Increase learner engagement** | Interactive quizzes, quick games, discussion prompts, and practical tasks will be embedded in each module. | Keeps your high engagement level high and reinforces understanding of tough concepts. |
# | **Improve clarity and learning support** | Lessons will include clear step‑by‑step instructions, example problems, and recorded explanations you can replay. | Helps you overcome the difficulty you experience with some online topics. |
# | **Support self‑paced learning** | Recorded lectures and weekly learning paths will be available so you can study at your own speed. | Gives you control over timing, especially when internet access is intermittent. |
# | **Improve technical access and reliability** | The course will provide offline downloadable resources, clear platform guides, and a help desk for connectivity issues. | Reduces the impact of unstable internet and ensures you can keep learning uninterrupted. |
#
# ### 5. Short Action Plan
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | **1** | Check the course portal for the **early‑uploaded materials** (slides, videos). | Download any files you might need for offline study. |
# | **2** | Watch the **digital‑skills mini‑guide** (5‑min video) on using the LMS. | Practice the shown tools in a low‑stakes activity. |
# | **3** | Complete the first **interactive quiz** and join the discussion forum. | Use the quiz feedback to identify any unclear topics. |
# | **4** | Review the **recorded explanations** for any lesson you found difficult. | Note questions and post them in the forum or ask the tutor. |
# | **5** | Follow the **weekly learning path** and set a personal study schedule that fits your internet availability. | Use a planner or digital calendar to block study times. |
# | **Ongoing** | If you experience connectivity problems, **download offline resources** and contact the technical support desk. | Keep the support contact info handy for quick assistance. |
#
# ---
#
# **Remember:** Your strong engagement and desire for flexibility are great assets. By using the resources and support outlined above, you can turn technical hiccups into manageable steps and deepen your understanding of the course material. Good luck, and keep leveraging both the online and classroom worlds!

# %% [markdown]
# ## Student ID: `e20230259`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20230259
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Recognises that blended learning provides **flexibility** and can boost **engagement** when used well.
# - Values **access to learning materials** and sees the potential for developing **digital skills**.
#
# **Main Challenges**
# - Experiences **network/Internet problems** and would like the school to improve Wi‑Fi coverage.
# - Notes that the **learning environment** (technical reliability and resource availability) can limit the blended experience.
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload slides, videos, reference links, exercises and other course materials **early** so you can download them before class. |
# | **Digital Skills** | Take short guides or micro‑tutorials on using the LMS, searching scholarly sources online, and handling common educational tools. |
# | **Engagement** | Participate in quizzes, quick games, practical tasks, and discussion boards that the instructor adds to the course. |
# | **Learning Environment** | Keep your study space organized; use the provided folders and clear naming conventions. If possible, choose a quiet spot with good lighting. |
# | **Self‑Paced Learning** | Review recorded lessons and weekly learning paths at times that suit you. Re‑watch any segment you find difficult. |
# | **Technical Issues** | Download offline copies of essential materials when the connection is good. Keep a list of quick‑step instructions for the platform and know how to contact technical support. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–2:** Locate the course’s shared folder and download all current slides and videos for offline use.
# 2. **Day 3–4:** Complete a 15‑minute tutorial on the LMS’s key features (uploading files, posting in forums, accessing quizzes).
# 3. **Day 5:** Join a discussion thread or small‑group chat; post one comment or question about the current topic.
# 4. **Day 6–7:** Set up a personal study schedule that includes 30 minutes of self‑paced review of the recorded lesson.
# 5. **Day 8:** Test the campus Wi‑Fi in a few locations; note the strongest spot and plan to use it for live sessions.
# 6. **Day 9–10:** If a connection drops, switch to the offline materials you saved and note any gaps to ask the instructor about.
# 7. **Day 11–14:** Complete the first interactive quiz or game offered in the module and reflect on what helped you stay engaged.
#
# By following these steps, you’ll make the most of blended learning’s flexibility while reducing technical frustrations and strengthening both your digital competence and course engagement. Good luck!

# %% [markdown]
# ## Student ID: `e20221004`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221004*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits of this segment:** strong motivation, frequent interaction with course content, and a preference for flexible, self‑paced study.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You are able to retrieve lessons you missed and can study at any time, which supports continuous learning.
#
# ### 3. Main Challenges
# - No specific challenges were reported. The recommendation below is therefore based primarily on the strengths identified and the typical needs of highly engaged learners.
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation |
# |-----|----------------|
# | **content_access** | **Strengthen access to learning materials** – Upload slides, videos, reference documents, exercises, and any other course resources **early** in the semester. This ensures you (and fellow students) can review content whenever needed, reinforcing your ability to learn on your own schedule. |
#
# ### 5. Short Action Plan
#
# | Step | What to Do | When |
# |------|------------|------|
# | 1. **Check the course platform** for any missing materials (slides, videos, readings). | Today |
# | 2. **Request early uploads** from the instructor or teaching assistant if anything is not yet available. | Within the next 2 days |
# | 3. **Create a personal folder** (e.g., on cloud storage) to organize all downloaded resources by week/topic. | This week |
# | 4. **Set a weekly review time** (e.g., 30 min on Sunday) to go through the uploaded materials before the next class. | Ongoing |
# | 5. **Give feedback** to the instructor about the usefulness of early material availability. | End of each month |
#
# By ensuring that all learning materials are uploaded promptly and organized for easy access, you can continue to leverage your strong self‑paced study habits and stay fully engaged throughout the course.

# %% [markdown]
# ## Student ID: `e20241226`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241226
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - The segment profile indicates you are a highly engaged and active learner who readily participates in class activities.
#
# **Main Challenges**
# - No specific challenges were reported, so the suggestions below are drawn primarily from the characteristics of your learner segment.
#
# **Personalized Recommendations**
#
# | Tag | What it means for you | Suggested actions |
# |-----|----------------------|-------------------|
# | **content_access** | Make sure you can get to all learning materials as early as possible. | • Ask your instructor to upload slides, videos, readings, and exercises at the start of each week.<br>• Keep a personal folder (e.g., on the cloud) where you store these resources for quick reference. |
# | **digital_skill** | Strengthen the ways you use the LMS and other online tools. | • Review any short guides or tutorials the university provides for the LMS, citation managers, and research databases.<br>• Experiment with features such as discussion boards, quizzes, and file‑sharing to become more comfortable. |
# | **engagement** | Keep your high energy directed toward interactive learning. | • Participate in live polls, quizzes, or game‑based activities.<br>• Join study groups or discussion forums where you can apply concepts to real‑world problems. |
# | **self_paced** | Take advantage of the ability to review material on your own schedule. | • Use recorded lectures to revisit complex topics.<br>• Follow a weekly learning path (e.g., “Monday – reading, Wednesday – practice quiz, Friday – reflection”) that you can adjust as needed. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Week 1** – Locate the course’s shared folder or LMS module and download all available slides, videos, and readings.
# 2. **Week 1** – Spend 30 minutes exploring the LMS tutorial videos (focus on discussion boards and quiz tools).
# 3. **Week 2** – Join a peer discussion group or create a short study‑session using a collaborative tool (e.g., Google Docs, Padlet).
# 4. **Week 2** – Set a personal “review day” to watch any recorded lessons you missed and take a quick self‑quiz.
#
# By following these steps, you’ll capitalize on your natural engagement while ensuring you have reliable access to content, strong digital skills, and the flexibility to learn at your own pace. Good luck!

# %% [markdown]
# ## Student ID: `e20240097`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240097*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you enjoy:** Learning more about technology and having flexible schedules.
# - **What you find challenging:** Staying focused, avoiding distractions, and feeling comfortable asking questions.
#
# ---
#
# ### 2. Main Strengths
# - **Digital Skills Development** – you are motivated to expand your tech abilities.
# - **Flexibility & Time Management** – you appreciate and can make use of flexible learning options.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – instructions can feel unclear, making it hard to stay on track.
# - **Motivation & Self‑Discipline** – staying focused and self‑motivated is a struggle, especially when distractions arise.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How it helps you | Practical steps you can take |
# |----------------|------------------|------------------------------|
# | **Develop digital learning skills** *(digital_skill)* | Strengthens the tech tools you already like to use. | • Explore short tutorials on the LMS and research tools.<br>• Join a campus “digital‑tools” peer group or forum. |
# | **Improve clarity and learning support** *(learning_support)* | Gives you clearer guidance so you can focus more easily. | • Look for recorded explanations and step‑by‑step guides for each module.<br>• Use the “ask‑a‑tutor” feature or discussion boards to get answers without feeling pressured. |
# | **Support motivation and self‑discipline** *(motivation)* | Keeps you on track and reduces distraction. | • Set a weekly check‑in with yourself or a study buddy.<br>• Use the LMS calendar for reminders and mark progress after each task. |
# | **Support self‑paced learning** *(self_paced)* | Lets you study when you’re most attentive. | • Watch recorded lessons before live sessions.<br>• Follow the weekly learning path but adjust the pace to match your focus levels. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the LMS tutorial videos on navigation and digital research tools. |
# | **Day 2‑3** | Choose one module and locate its recorded lecture and step‑by‑step guide; watch the video, then take notes. |
# | **Day 4** | Set up a weekly reminder (e.g., every Monday 10 am) to check your progress and update your study schedule. |
# | **Day 5‑7** | Join a short online discussion or “office hour” session to practice asking a question in a low‑pressure setting. |
# | **Week 2** | Follow the weekly learning path at your own speed, using the recorded lessons when you feel distracted. Review your progress at the end of the week and adjust the schedule if needed. |
#
# ---
#
# **Remember:** Your enthusiasm for technology and flexible learning is a strong foundation. By adding clearer resources, regular check‑ins, and self‑paced materials, you’ll be able to stay focused, ask questions confidently, and make the most of your active learning style. Good luck!

# %% [markdown]
# ## Student ID: `e20241370`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241370*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are classified as a **Highly Engaged (Active) Learner**. Your responses show that you value easy access to online resources and the possibility to ask lecturers questions in person. You also note that motivation can drop in fully online sessions, and you would like lecturers to provide advance PDFs of books for deeper reading.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having resources available online.
# - **Digital Skills Development** – You are comfortable using digital tools for learning.
# - **Student Engagement** – You actively participate when material is readily accessible.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You feel less motivated when online interaction is limited.
# - **Motivation & Self‑Discipline** – Maintaining drive in online classes can be difficult without clear guidance or pre‑sent material.
#
# ---
#
# ### 4. Personalized Recommendations
# | Focus | What to Do (based on rule‑based advice) |
# |-------|------------------------------------------|
# | **Content Access** | Lecturers should **upload slides, videos, reference PDFs and exercises early** in the LMS so you can review them before class. |
# | **Digital Skill** | Receive **short guides or short videos on using LMS tools, online research databases, and educational apps** to boost efficiency. |
# | **Engagement** | Incorporate **quick quizzes, interactive games, practical tasks, and discussion prompts** within each module to keep you actively involved. |
# | **Interaction** | Schedule **regular Q&A slots, small‑group discussions, and peer‑collaboration activities**; aim for faster feedback from lecturers. |
# | **Motivation** | Set up **weekly check‑ins, automated reminders, and a personal progress tracker**; create a simple study schedule that aligns with the pre‑sent PDFs you request. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Access the course LMS; download all available slides, videos and any PDF reading material posted early. |
# | **2** | Attend the first live Q&A session; note any questions for follow‑up. |
# | **3** | Complete the first interactive quiz and use the progress tracker to record your results. |
# | **4** | Join a peer‑study group for a short discussion on the week’s reading; schedule a 10‑minute check‑in with the lecturer to discuss any difficulties. |
#
# Follow this plan and adjust the schedule as needed. By strengthening material access, sharpening digital skills, and adding regular interaction and motivation checkpoints, you’ll be able to keep your high engagement level even in fully online components.
#
# ---
#
# *If any part of this report feels unclear, feel free to reach out to your course coordinator for further clarification.*

# %% [markdown]
# ## Student ID: `e20240673`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240673*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You are comfortable studying material on your own when the professor provides a brief guide. You prefer concise video content and feel that most interaction can happen during in‑person sessions.
#
# ### 2. Main Strengths
# - **Self‑study ability:** You can work through lessons independently with minimal prompts.
# - **Access to materials:** You value having slides, videos, and references available to support your learning.
# - **Positive engagement:** You are motivated to think through problems and seek clarification from teachers when needed.
#
# ### 3. Main Challenges
# - **Length & interactivity of videos:** You find current videos too long and would like fewer built‑in interactive elements, preferring to ask questions face‑to‑face.
# - **Limited real‑time interaction:** You would like more opportunities for quick communication with the lecturer and peers outside of class.
#
# ### 4. Personalized Recommendations
#
# | Recommendation Tag | What It Means for You | Suggested Actions |
# |--------------------|-----------------------|-------------------|
# | **content_access** | Make sure all learning resources are ready early so you can review them before class. | • Upload slides, video recordings, reference links, and practice exercises at least a week in advance. |
# | **engagement** | Keep you actively involved without overwhelming you with long videos. | • Insert short, low‑stakes quizzes or quick polls after each video segment (2‑3 min). <br>• Use brief practical tasks that reinforce the concept you just watched. |
# | **interaction** | Give you more chances to ask questions and collaborate with classmates. | • Schedule short live Q&A slots after video releases. <br>• Set up a discussion board or chat channel for peer questions, with the lecturer responding within 24 h. |
# | **learning_effectiveness** | Blend online review with the in‑person explanations you prefer. | • Provide concise video summaries (5‑7 min) that you can watch before class. <br>• Use class time for deeper explanation, problem‑solving, and immediate feedback. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Who’s Responsible |
# |------|--------|--------------------|
# | 1 | Upload all lecture slides, short video summaries, and reference links for the upcoming module. | Lecturer / Course team |
# | 1 | Create a brief (3‑question) quiz at the end of each video. | Instructional designer |
# | 2 | Open a discussion board for the module; post a prompt inviting questions on the video content. | Lecturer |
# | 2 | Hold a 15‑minute live Q&A session (online) to address the most common questions before the next face‑to‑face class. | Lecturer |
# | Ongoing | Use class time for hands‑on practice and immediate feedback on the quiz topics. | Lecturer & peers |
#
# These steps align with your strengths in self‑study and your desire for concise, well‑structured content while adding the interaction and feedback you find helpful. Feel free to share any further preferences so the blended format can be refined even more. Good luck with your studies!

# %% [markdown]
# ## Student ID: `e20210535`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support", "motivation"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210535
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You find it easy to locate and review research‑related materials for lessons (strength theme: **Access to Learning Materials**).
#
# **Main Challenges**
# - Lessons sometimes feel unclear or too theoretical, making it hard to stay focused (challenge themes: **Learning Difficulty & Clarity**, **Motivation & Self‑Discipline**).
#
# **Personalized Recommendations**
#
# | Tag | Recommendation Title | What to Do |
# |-----|----------------------|------------|
# | **content_access** | Strengthen access to learning materials | Upload slides, videos, reference links, exercises, and any other course resources **early** in the module so you can review them whenever needed. |
# | **learning_support** | Improve clarity and learning support | Provide clearer instructions, concrete examples, and short recorded explanations. Offer step‑by‑step guides that walk you through key concepts and tasks. |
# | **motivation** | Support motivation and self‑discipline | Set up weekly check‑ins or brief reminders, use a progress‑tracking tool, and create a structured study schedule to keep you on track. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–3:** Review the course’s uploaded materials (slides, videos, references). Note any gaps and request missing resources from the instructor.
# 2. **Day 4–7:** Follow a step‑by‑step guide for the upcoming assignment; pause the recorded explanations to replicate each step.
# 3. **Week 2 – Monday:** Attend a brief weekly check‑in (virtual or in‑person) to discuss any unclear points and set goals for the week.
# 4. **Week 2 – Midweek:** Update your progress tracker (e.g., checklist or simple spreadsheet) and adjust your study schedule if needed.
#
# By ensuring early access to clear, well‑organized materials and using regular check‑ins and tracking, you can maintain your high engagement while reducing confusion and staying motivated. Good luck!

# %% [markdown]
# ## Student ID: `e20240320`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240320*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You actively seek rich knowledge and enjoy deepening your critical thinking. Your engagement level is high, and you value learning that is convenient and effective.
#
# ### 2. Main Strengths
# - Strong interest in **digital skills development**.
# - Preference for **learning convenience and effectiveness**.
#
# ### 3. Main Challenges
# - You noted that “excessive information seeks to be adjusted for sending files to each section,” indicating a need to streamline how you manage and share digital resources.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Develop digital learning skills** (digital_skill) | Gain confidence using the LMS, online research tools, and other educational technologies. | • Attend a short workshop or tutorial on the LMS features you use most.<br>• Explore curated guides on digital research and file‑sharing best practices.<br>• Practice organizing course materials in a consistent folder structure. |
# | **Improve learning effectiveness** (learning_effectiveness) | Blend online review with face‑to‑face activities to reinforce understanding. | • Use online videos or readings for initial exposure to a topic.<br>• Schedule in‑person or live‑online sessions for discussion, practice problems, and immediate feedback.<br>• After each session, reflect on what worked and adjust your study plan. |
#
# These recommendations are drawn directly from the rule‑based guidance for your segment and the strengths you reported.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Day 1–2** | Watch a 15‑minute LMS tutorial (focus on file upload/download and organization). |
# | **Day 3–4** | Create a personal folder system for each course section; practice uploading a sample file. |
# | **Day 5** | Choose one upcoming topic, review the online material, then attend a live discussion or study group. |
# | **Week 2** | Complete a short self‑assessment: Did the blended approach help you understand the topic better? Note any adjustments needed. |
# | **End of Week 2** | Meet with a peer or tutor to get feedback on your digital workflow and learning strategy. |
#
# ---
#
# **Keep in mind:** Your high engagement is a strong asset. By sharpening your digital skills and pairing online review with interactive practice, you’ll turn the abundance of information into a more manageable, effective learning experience. Good luck!

# %% [markdown]
# ## Student ID: `e20250070`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20250070
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value clear and well‑organized learning materials that help you understand the course content more easily.
# - You appreciate having convenient access to slides, videos, and other resources that support effective study.
#
# **Main Challenges**
# - You experience occasional internet and Wi‑Fi problems that make it harder to use online resources.
# - You would like more reliable technology tools to support your learning.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Having slides, videos, references, and exercises available early will keep your study flow smooth. | • Look for a course folder where the instructor uploads all materials before each class.<br>• Download the files to your device when you have a good connection so you can study offline. |
# | **Improve learning effectiveness** (learning_effectiveness) | Combining online review with face‑to‑face explanation, practice, and feedback maximises your active learning style. | • Before class, review the uploaded videos or slides.<br>• During class, focus on asking questions and doing the in‑person activities.<br>• After class, use any provided practice exercises and seek quick feedback from the tutor or peers. |
# | **Improve technical access and reliability** (tech_issue) | Stable internet and clear platform instructions reduce interruptions and keep you engaged. | • Use campus Wi‑Fi or a reliable hotspot when possible.<br>• Download offline copies of essential materials (as suggested above).<br>• Keep a short guide of platform steps handy and contact the tech support desk whenever you encounter issues. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Check the course’s online portal for a “Materials” folder. Download all slides, videos, and reading PDFs for the upcoming week.
# 2. **Day 3‑4:** Test your internet connection; if it’s unstable, arrange access to campus Wi‑Fi or a reliable hotspot.
# 3. **Day 5‑7:** Before each class, spend 15 minutes reviewing the downloaded materials. Bring any questions to the in‑person session.
# 4. **Day 8‑10:** Complete the practice exercises provided after class and request quick feedback from the tutor or a study group.
# 5. **Day 11‑14:** If technical problems persist, contact the university’s technical support with a brief description of the issue and ask for troubleshooting steps or alternative access options.
#
# By following these steps, you’ll keep your strong engagement level, improve how effectively you learn, and reduce the impact of technical hurdles. Good luck!

# %% [markdown]
# ## Student ID: `e20220963`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220963*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you shared:** You find the course material easy to learn when it is fully interactive, but you feel that a lack of personal discipline sometimes hinders your interaction with lecturers and the learning environment.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You appreciate having complete, interactive materials that make learning straightforward.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You experience difficulty staying connected with lecturers and peers.
# - **Learning Resources & Environment** – You notice that the study setting and resource organization could be better, and you attribute some of the issue to personal discipline.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus Area | What to Do (based on rule‑based advice) |
# |------------|------------------------------------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from lecturers when possible. |
# | **Learning Effectiveness** | • Pair the online review materials you already enjoy with brief in‑person explanations or practice sessions.<br>• Seek regular feedback on your work to reinforce understanding. |
# | **Learning Environment** | • Keep your digital and physical study materials well‑organized (e.g., folders, bookmarks).<br>• Choose a comfortable, distraction‑free study space and, if needed, suggest improvements to classroom comfort to your department. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the challenges you identified.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Day 1** | Locate the next live Q&A or discussion slot and add it to your calendar. |
# | **Week 1 – Day 2** | Create a simple folder system (digital or paper) for all course materials. |
# | **Week 1 – Day 4** | Schedule a 15‑minute meeting (or email) with a lecturer to ask for quick feedback on a recent assignment. |
# | **Week 2 – Day 1** | Form a small study group (2‑3 peers) for a 30‑minute peer‑review session. |
# | **Week 2 – Day 3** | Evaluate your study space: adjust lighting, seating, or noise level to improve comfort. |
# | **Week 2 – Day 5** | Review the online materials, then write a short summary or explain the key points to a peer (in‑person or via video). |
#
# Follow these steps, reflect on what works best for you, and adjust as needed. Consistent interaction, combined with organized resources and targeted practice, will help you turn your strong engagement into even higher academic performance.
#
# ---
#
# *You are a highly engaged learner—leveraging interaction, effective practice, and a well‑structured environment will let you make the most of your strengths.*

# %% [markdown]
# ## Student ID: `e20240215`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240215*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits of this segment:** strong interest in learning, comfortable using digital tools, prefers a mix of self‑paced study and interactive activities.
#
# ### 2. Main Strengths
# - **Independent and self‑directed:** You have shown the ability to develop your own learning path and make use of convenient, effective resources.
#
# ### 3. Main Challenges
# - **Maintaining focus on collaborative aspects:** You noted a need to “pay attention to the students,” indicating that staying motivated and disciplined in group‑oriented or structured settings can be difficult.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What to Do | Why it Helps |
# |----------------|------------|--------------|
# | **Improve learning effectiveness** | • Use online review materials (videos, quizzes, summaries) **before** attending in‑person sessions. <br>• During class, seek explanations, practice activities, and immediate feedback from the instructor or peers. | Combining digital review with face‑to‑face interaction reinforces concepts and makes your independent study more powerful. |
# | **Support motivation and self‑discipline** | • Set a **weekly check‑in** (e.g., a 10‑minute self‑review or a brief chat with a tutor). <br>• Enable **reminders** in your calendar or learning platform for deadlines and study blocks. <br>• Track progress with a simple log (completed topics, practice scores). <br>• Follow a **structured study schedule** that balances solo work and group tasks. | Regular check‑ins, reminders, and visible progress keep motivation high and help you stay on track with both independent and collaborative work. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Choose one upcoming topic. Watch a short online overview (10‑15 min). |
# | **Tuesday** | Attend the related in‑person session; ask at least one question and do the practice exercise. |
# | **Wednesday** | Log what you learned and rate your confidence (1‑5). Set a reminder for the next review. |
# | **Thursday** | Schedule a 15‑minute check‑in with a study buddy or tutor to discuss progress. |
# | **Friday** | Update your progress tracker; adjust the study schedule for next week if needed. |
# | **Weekend** | Review notes briefly; plan the next week’s topics and set reminders. |
#
# Repeat this cycle, gradually adding more detailed check‑ins or group study sessions as you become comfortable.
#
# ---
#
# **Remember:** Your independence is a strong asset. By pairing it with structured review, feedback, and regular motivation checks, you’ll boost both effectiveness and self‑discipline while staying engaged with fellow students. Good luck!

# %% [markdown]
# ## Student ID: `e20220544`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220544*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can control when and how you study, and you are motivated to keep learning actively.
#
# ### 2. Main Strengths
# - **Access to Learning Materials & Flexibility:** You value being able to revisit slides, videos, and other resources whenever you have free time. This flexibility helps you manage your schedule and stay engaged.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable internet connections and occasional electricity problems can interrupt your study flow.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | Why It Helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Instructors should upload all slides, videos, reference documents, and exercises **early** in the week. | You can download or stream them when you have a stable connection, reducing the impact of technical hiccups. |
# | **Support self‑paced learning** | Recorded lessons and a clear weekly learning path will be provided so you can review content at your own speed. | Keeps the flexibility you like while giving you a structured roadmap to follow. |
# | **Improve technical access and reliability** | The platform will offer options for **offline downloads**, clear step‑by‑step usage guides, and a help desk for quick tech support. | Helps you continue studying even when internet or power is unstable. |
#
# ### 5. Short Action Plan
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | **1** | Download all course materials for the week (slides, videos, exercises). | Look for the “Download All” button on the course page; save files to your device or a USB drive. |
# | **2** | Follow the weekly learning path and watch recorded lessons at a time that fits your schedule. | Use the weekly schedule posted in the LMS; mark completed items in your personal planner. |
# | **3** | Test offline access and note any technical problems. | Try opening a downloaded video without internet; if you encounter issues, contact the technical support desk (email/phone provided in the LMS). |
# | **4** | Review and adjust your study routine based on what worked best. | Reflect on which times and devices gave you the smoothest experience; plan future study sessions accordingly. |
#
# ---
#
# **Remember:** Your strong engagement and desire for flexibility are key assets. By ensuring reliable access to materials, using self‑paced resources, and having backup options for technical problems, you can keep your learning momentum high throughout the semester. If you need further assistance, reach out to your course’s technical support team—they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `e20220800`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220800*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can prepare quickly for class and revisit video material as often as you need. You value having learning resources ready in advance and feel confident using them to support your in‑person sessions. Your main difficulty is timing – if a teacher’s schedule changes or notifications are late, you may miss the start of a class.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You can prepare without extra time because you have slides, videos, and other resources ready.
# - **Learning Convenience & Effectiveness** – You make good use of video reviews to reinforce what is taught in class.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Late or unclear schedule information can disrupt your attendance.
# - **Assessment & Workload** – Uncertain deadlines can add pressure when you try to balance online and face‑to‑face tasks.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|-----------------------|
# | **Strengthen access to learning materials** | Instructors should upload slides, videos, reference links, and practice exercises **well before** the class meeting. This lets you keep your fast‑prep routine and review content repeatedly. |
# | **Increase interaction and communication** | Request or suggest short Q&A slots, online discussion boards, or peer‑collaboration activities. Faster lecturer feedback and clear schedule notices will help you arrive on time and stay engaged. |
# | **Improve learning effectiveness** | Combine the pre‑uploaded videos with in‑person explanations and guided practice. Use the online material for review, then apply what you learned during class activities and receive immediate feedback. |
# | **Manage workload and assessment pressure** | Ask for a clear overview of assignment deadlines and how online tasks align with classroom work. Balanced workloads will let you focus on both review videos and hands‑on practice without feeling rushed. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Check the course’s online platform for any newly uploaded slides or videos. Download them to your device for quick review. |
# | **Day 3** | Send a brief email to the lecturer asking for the schedule of the next week and any upcoming deadlines. |
# | **Day 5** | Join a scheduled Q&A or discussion forum (or propose one) to clarify any unclear topics before the next class. |
# | **Day 7** | Review the week’s video material, then write down at least two questions to bring to the in‑person session. |
# | **Day 10** | After class, spend 15 minutes summarising what you learned and note any feedback from the lecturer. |
# | **Day 14** | Review the assignment timeline you received, break the work into small tasks, and schedule them alongside your video reviews. |
#
# Follow these steps, and you’ll keep leveraging your strong preparation habits while reducing schedule‑related stress and workload uncertainty. Keep communicating with your instructors—your active engagement makes a big difference!

# %% [markdown]
# ## Student ID: `e20241406`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241406*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you shared:** You value a good balance between study and other life commitments.
# - **What you’re facing:** Occasional connection or technical problems that interrupt your online work.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You are able to organise your schedule and keep a healthy life‑study balance.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity or platform glitches can disrupt learning.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | How to use it |
# |----------------|------------------|---------------|
# | **Support self‑paced learning** | Your strong time‑management skills let you get the most from material you can review when it suits you. | • Use recorded lectures and weekly learning paths that are always available.<br>• Download PDFs, slides, or audio files so you can study offline when the connection is weak. |
# | **Improve technical access and reliability** | Reducing connection problems will let your active engagement stay uninterrupted. | • Take advantage of any university‑provided stable Wi‑Fi hotspots or loaner devices.<br>• Keep offline copies of essential resources.<br>• Follow the platform’s quick‑start guide and contact technical support as soon as an issue arises. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate where you can download lecture recordings and course PDFs. Save the first week’s materials to your device. |
# | **Day 3** | Test the university’s Wi‑Fi hotspot or request a loaner hotspot if you often study off‑campus. |
# | **Day 4–5** | Create a simple weekly learning path: list the recorded lessons you’ll watch and the readings you’ll complete each day. |
# | **Day 6–7** | Review the platform’s technical support page; note the contact method for quick help. |
# | **Week 2** | Follow your learning path, using offline files when the internet is unstable. If a technical problem occurs, reach out to support immediately. |
#
# ---
#
# **Remember:** Your ability to manage time flexibly is a key asset. By pairing self‑paced resources with reliable technical access, you can keep your learning both active and uninterrupted. If you need further help, your academic advisor and the campus IT help desk are ready to assist.

# %% [markdown]
# ## Student ID: `e20240331`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "learning_effectiveness", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240331*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate that blended learning reduces teaching effort and frees up time while keeping the same amount of knowledge as a traditional face‑to‑face course.
# - The main difficulty you experience is a lack of motivation to study.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You value the easy availability of slides, videos, and other resources.
# - **Digital Skills Development:** You see blended learning as a chance to improve your use of digital tools.
# - **Learning Convenience & Effectiveness:** You recognize that the approach can be time‑saving and still effective.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline:** Staying motivated and managing study time independently is challenging for you.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What to Do | Why it Helps |
# |----------------|------------|--------------|
# | **Strengthen access to learning materials** | Upload all slides, videos, references, exercises, and other course content **early** in the LMS. | Having everything ready lets you study when you feel most motivated and reduces the effort of searching for resources. |
# | **Develop digital learning skills** | Offer short guides or short “how‑to” videos on using the LMS, online libraries, citation tools, and other educational technologies. | Better digital skills make it easier to navigate the course and keep you engaged with the material. |
# | **Improve learning effectiveness** | Pair the online review materials with brief in‑person sessions for explanation, practice, and feedback. | Combining both modes reinforces understanding and makes study time more productive. |
# | **Support motivation and self‑discipline** | Set up **weekly check‑ins** (e.g., a short online poll or a quick meeting), automated **reminders**, a personal **progress tracker**, and a **structured study schedule** with clear milestones. | Regular prompts and visible progress help sustain motivation and keep you on track. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Review the course page and note when all slides, videos, and exercises will be uploaded. Add them to your personal folder. |
# | **2** | Watch the short “LMS basics” tutorial provided by the instructor. Practice uploading a file and posting a question. |
# | **3** | Attend the first in‑person session that reviews the online material. Complete the associated practice exercise and ask at least one question. |
# | **4** | Set up a weekly reminder (e.g., on your phone or calendar) for a 30‑minute study block. Use the progress tracker to mark completed readings and exercises. |
#
# ---
#
# **Remember:** You already see the value of blended learning. By securing easy access to materials, sharpening your digital skills, combining online and face‑to‑face activities, and using regular motivation supports, you can turn passive engagement into active, successful learning. Good luck!

# %% [markdown]
# ## Student ID: `M080411`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** M080411
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You value **saving time and flexibility** in your studies. Your main concern is the **quality of the material or video lectures** and the desire to **improve your learning speed** (e.g., “need to 10x time improve”).
#
# Because your open‑ended responses are brief, the recommendations below rely primarily on the characteristics of your segment (moderately engaged, passive) and the strengths you identified.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate learning options that fit your schedule and help you use time efficiently.
#
# ### 3. Main Challenges
# - **Material Quality & Speed of Learning** – You want higher‑quality resources and faster ways to master the content.
#
# ---
#
# ### 4. Personalized Recommendations
# **Support self‑paced learning**
# - **Recorded lessons** that you can watch whenever it suits you.
# - **Weekly learning paths** that outline what to study each week, giving you a clear roadmap while letting you control the pace.
# - **Supplementary materials** (slides, notes, practice quizzes) that you can review as often as needed to reinforce understanding and speed up mastery.
#
# These elements match your need for flexibility and address the desire for higher‑quality, reviewable content.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1 | Access the recorded lecture for the upcoming topic and download the accompanying slides. | Gives you control over when and how you study. |
# | 2 | Follow the weekly learning path, completing the short practice quiz after each video. | Keeps you on track while allowing review at your own speed. |
# | 3 | Identify any video sections that feel unclear; re‑watch those parts and use the notes to clarify. | Improves material quality perception and speeds up learning. |
# | 4 | Reflect on your time spent versus understanding gained; adjust the pace for the next module accordingly. | Helps you fine‑tune the “10x time improve” goal. |
#
# Stick to the schedule, use the recordings repeatedly if needed, and you’ll benefit from a flexible, self‑paced approach that fits your learning style. Good luck!

# %% [markdown]
# ## Student ID: `e20230392`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "learning_effectiveness", "learning_support", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230392*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the mix of face‑to‑face and online instruction. You see blended learning as a way to use more technology, access a wider range of resources, improve outcomes, and reduce costs. Your main concerns are unreliable internet and occasional difficulty understanding lesson content.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having slides, videos, and other resources available.
# - **Digital Skills Development** – You are eager to use technology and online tools for learning.
# - **Learning Convenience & Effectiveness** – You recognize that blended formats can make studying more efficient.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Poor connectivity sometimes blocks your participation.
# - **Learning Difficulty & Clarity** – At times the lesson explanations are not clear enough for you.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Ensure you have all course content (slides, videos, exercises, references) well before class. | Check the LMS weekly; download files when you have good internet; keep a personal folder for each course. |
# | **Develop digital learning skills** | Build confidence with the LMS, online research tools, and educational tech. | Attend any short “LMS‑tips” workshops; explore tutorials on citation managers, discussion boards, and video‑annotation tools. |
# | **Improve learning effectiveness** | Blend online review with in‑person practice and feedback. | Before a face‑to‑face session, watch the recorded lecture and do the suggested exercises; use class time for questions and hands‑on activities. |
# | **Improve clarity and learning support** | Get clearer instructions and step‑by‑step guides. | Request recorded explanations or example problems from the instructor; use the course’s FAQ or a study‑group chat for additional help. |
# | **Improve technical access and reliability** | Reduce the impact of internet problems. | When possible, download offline copies of videos and readings; locate campus Wi‑Fi hotspots or use the university’s loan‑er laptops/tablets with built‑in data plans; contact the IT help desk early if you encounter issues. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course syllabus and note all upcoming material uploads. |
# | **Day 3** | Download the next week’s slides and videos to a device you can use offline. |
# | **Day 4** | Watch the first video and complete the associated exercise; note any unclear points. |
# | **Day 5** | Post your questions in the course forum or ask the instructor for a short recorded clarification. |
# | **Day 6–7** | Attend the in‑person session, focusing on the areas you flagged; ask for immediate feedback. |
# | **Day 8** | Locate a reliable campus Wi‑Fi spot or arrange a loan‑er device for the next week. |
# | **Day 9–10** | Complete a quick “LMS‑tips” tutorial (often 10‑15 min) to sharpen navigation skills. |
# | **Day 11–12** | Review the week’s material again using the offline copies; test yourself with practice questions. |
# | **Day 13** | Summarize what you learned in a one‑page note; share it with a study partner for peer feedback. |
# | **Day 14** | Reflect on any remaining technical or clarity issues and contact the IT support or instructor as needed. |
#
# Follow this plan, and you’ll keep leveraging your strong engagement while minimizing the internet and clarity hurdles that currently affect your learning. Good luck!

# %% [markdown]
# ## Student ID: `e20211284`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20211284
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Values the **convenience** that comes with being a 5th‑year student.
# - Appreciates **flexibility and time‑management** opportunities in the learning design.
#
# **Main Challenges**
# - Finds the **learning site and materials uninteresting** and feels there is a lack of sufficient resources.
# - Experiences difficulties with the overall **learning resources & environment**.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Improve learning resources and environment** | Organize course materials so they are easy to find, update content to keep it relevant, and make study spaces (both physical and virtual) more comfortable. | • Check the course portal for any newly uploaded or reorganized files.<br>• Use the university’s library or online databases to supplement missing resources.<br>• Arrange a quiet, well‑lit study area or use virtual breakout rooms for focused work. |
# | **Support self‑paced learning** | Access recorded lectures, follow a weekly learning path, and review materials whenever it fits your schedule. | • Watch recorded lessons before or after class to reinforce concepts.<br>• Follow the suggested weekly roadmap provided by the instructor.<br>• Keep a personal folder of notes and recordings for quick review before exams. |
#
# **Short Action Plan**
#
# 1. **Week 1:** Locate the updated course folder on the learning platform; bookmark key sections (syllabus, lecture recordings, reading lists).
# 2. **Week 2:** Set a personal weekly schedule that includes 2–3 hours for reviewing recorded lessons and completing the weekly learning path.
# 3. **Week 3:** Identify a comfortable study spot (library cubicle, coffee shop, or a quiet room at home) and commit to using it for each study session.
# 4. **Week 4:** Evaluate the usefulness of the materials you’ve gathered; if anything is still missing, request additional resources from the instructor or teaching assistant.
#
# By focusing on a clearer learning environment and taking advantage of self‑paced resources, you can turn the convenience you already appreciate into more effective, engaging study habits. Good luck!

# %% [markdown]
# ## Student ID: `e20220455`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "motivation", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220455*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are identified as a **Highly Engaged (Active) Learner**. You enjoy interacting with digital tools and like the option to revisit recorded videos. Your main challenges are occasional internet problems and maintaining self‑discipline.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – you make good use of digital resources and like having videos you can watch later.
# - **Digital Skills Development** – comfortable using online tools.
# - **Student Engagement** – actively participate when the content is interactive.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – unreliable connectivity can interrupt study.
# - **Motivation & Self‑Discipline** – staying on schedule can be difficult without external structure.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Instructors will upload slides, videos, references, exercises and other course materials **early** so you can download them before class. |
# | **Digital Skills** | Short guides and quick‑tips will be provided on how to use the LMS, locate online resources, and apply educational technologies effectively. |
# | **Engagement** | Lessons will include quizzes, games, practical tasks, discussion boards and other interactive activities to keep you actively involved. |
# | **Motivation & Self‑Discipline** | Weekly check‑ins, automated reminders, progress‑tracking dashboards and a suggested study schedule will help you stay on track. |
# | **Technical Access** | Options for **offline** copies of videos/materials, clear instructions for the platform, and a dedicated tech‑support channel will be made available to reduce the impact of internet issues. |
#
# *Because your open‑ended responses were brief, these recommendations rely primarily on the characteristics of your learner segment.*
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action |
# |------|--------|
# | **1** | Download all available course materials (slides, videos) to a personal device for offline use. |
# | **2** | Review the LMS quick‑tip guide; practice using at least one new digital tool. |
# | **3** | Participate in a quiz or interactive activity each class; note what helps you stay focused. |
# | **4** | Set a weekly study schedule; use the progress tracker and attend the first check‑in meeting. |
# | **5+** | If internet problems persist, contact tech support and request additional offline resources. Continue using reminders and check‑ins to build self‑discipline. |
#
# Stay proactive, use the resources provided, and reach out for support whenever technical or motivational hurdles arise. You have the engagement and digital skills— these steps will help you translate them into consistent, successful learning.

# %% [markdown]
# ## Student ID: `e20240694`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240694
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You are skilled at helping peers improve their use of digital tools for studying.
# - Your comments show a positive attitude toward digital skills development.
#
# **Main Challenges**
# - No specific challenges were reported.
#
# **Personalized Recommendations**
# Because you belong to the “Highly Engaged (Active) Learners” segment and have highlighted digital‑tool expertise, the recommendation focuses on further developing your digital learning skills:
#
# - **Develop digital learning skills** – Seek guidance on using the university’s Learning Management System (LMS), exploring online research resources, and mastering educational technologies that can enhance both your own study habits and the support you give to classmates.
#
# **Short Action Plan**
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1 | Review LMS tutorials | Watch the official LMS walkthrough videos on the university portal. |
# | 2 | Explore digital research tools | Attend the library’s “Effective Online Research” webinar. |
# | 3 | Try a new ed‑tech app | Choose one tool (e.g., citation manager, mind‑mapping app) and use it for an upcoming assignment. |
# | 4 | Share a tip sheet | Create a one‑page guide of your favorite digital tools and post it in your study group or class forum. |
#
# By following these steps, you’ll deepen your own digital competence while continuing to support fellow students. Keep leveraging your high engagement level—your proactive approach will make these activities both effective and enjoyable.

# %% [markdown]
# ## Student ID: `e20221592`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20221592
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You find learning “easy everywhere,” which shows you value the convenience of accessing material from any location. At the same time, you experience inconsistent technology and internet access, which can interrupt your study flow.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You are comfortable learning in different settings and can make good use of flexible resources.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity and occasional tech problems limit your ability to engage consistently with online content.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Pair the online review materials you already use with short, in‑person (or live‑online) sessions where concepts are explained, practiced, and you receive feedback. | • Schedule brief tutoring or study‑group meetings after reviewing each topic.<br>• Use campus labs or library spaces for these sessions if they offer stable Wi‑Fi. |
# | **Improve technical access and reliability** | Ensure you have stable internet and clear guidance on using the learning platform, plus a fallback when connectivity fails. | • Take advantage of university Wi‑Fi hotspots or campus computer labs.<br>• Download lecture videos, readings, and practice files for offline study.<br>• Keep the platform’s help guide handy and know how to contact technical support quickly. |
#
# These suggestions are drawn directly from the evidence‑based tags **learning_effectiveness** and **tech_issue**, and they align with the typical needs of Moderately Engaged (Passive) learners.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify one course module to review online. Download all related videos and PDFs for offline use. |
# | **Day 3** | Book a 30‑minute in‑person (or live‑online) session with a tutor or peer to discuss the module and practice key problems. |
# | **Day 4–5** | Test the university Wi‑Fi or a campus computer lab to confirm stable access for future sessions. |
# | **Day 6** | Save the platform’s quick‑start guide on your phone or laptop for easy reference. |
# | **Day 7** | If any technical issue arises, contact the university’s tech support using the provided help‑desk number/email. |
# | **Day 8–14** | Repeat the cycle for the next module, adjusting the timing based on what worked best for you. |
#
# Following this plan will help you keep learning convenient while reducing the impact of technical interruptions. Good luck, and remember that combining online resources with focused, interactive practice is a proven way to boost your learning effectiveness!

# %% [markdown]
# ## Student ID: `e20240108`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240108*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - Your open‑ended responses did not provide specific strengths or challenges, so the recommendations below are drawn primarily from the characteristics of this segment.
#
# ### 2. Main Strengths
# - Not explicitly reported.
#
# ### 3. Main Challenges
# - Not explicitly reported.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from the lecturer. | Increases engagement and helps you stay connected with the material and classmates. |
# | **Learning Support** | • Look for clear, step‑by‑step guides and recorded explanations.<br>• Use provided examples to clarify concepts. | Improves understanding when you study independently. |
# | **Motivation & Self‑Discipline** | • Set up weekly check‑ins (e.g., with a study buddy or tutor).<br>• Use reminders and a simple progress tracker.<br>• Follow a structured study schedule. | Keeps you on track and builds consistent study habits. |
# | **Self‑Paced Learning** | • Access recorded lessons and review them as needed.<br>• Follow the weekly learning path outlines.<br>• Organize the provided materials for personal review. | Allows you to learn at a comfortable speed while still meeting course deadlines. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the course’s weekly learning path and note any recorded lessons you need to watch. |
# | **Day 2‑3** | Schedule a 15‑minute weekly check‑in with a peer or tutor; set a reminder in your calendar. |
# | **Day 4** | Attend the first Q&A or discussion session; prepare one question in advance. |
# | **Day 5‑7** | Watch the recorded lessons for this week; take brief notes using the step‑by‑step guides. |
# | **Day 8** | Submit any pending assignments and request feedback within 24 hours. |
# | **Day 9‑10** | Review feedback, update your progress tracker, and adjust your study schedule if needed. |
# | **Day 11‑12** | Join a peer‑collaboration activity or study group online. |
# | **Day 13‑14** | Reflect on what helped you stay motivated; plan any adjustments for the next week. |
#
# ---
#
# By following these focused steps, you’ll strengthen interaction, receive clearer support, stay motivated, and make the most of self‑paced resources—key factors for success as a Moderately Engaged (Passive) learner. Good luck!

# %% [markdown]
# ## Student ID: `e20241119`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["engagement", "learning_effectiveness", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241119*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You value face‑to‑face time with the teacher because it gives clear explanations and helps you get to know classmates.
# - You experience occasional misunderstandings that affect clarity.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You appreciate the blended format when it includes direct teacher guidance.
# - **Student Engagement:** In‑person interaction makes the material feel more understandable.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity:** Misunderstandings arise, indicating a need for clearer instructions and additional support.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Engagement** | Add short quizzes, quick games, or brief discussion prompts during class and in the online component. | Keeps you actively involved and reinforces what the teacher explains. |
# | **Learning Effectiveness** | Use online review resources (e.g., short videos or summary sheets) *before* the in‑person session, then practice the concepts with teacher feedback during class. | Combines the convenience of online review with the clarity of face‑to‑face explanation. |
# | **Learning Support** | Ask the instructor for recorded explanations or step‑by‑step guides, and look for examples that illustrate each new idea. | Provides clearer instructions and reference material to reduce misunderstandings. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Watch a 5‑minute video preview of the upcoming topic (provided on the LMS). |
# | **Tue** | Bring one question from the video to the in‑person class; participate in a brief discussion. |
# | **Wed** | Complete a short online quiz (5‑10 questions) on the same topic. |
# | **Thu** | Review the quiz feedback with the teacher; ask for a recorded explanation of any unclear point. |
# | **Fri** | Summarize the lesson in a one‑page step‑by‑step guide for yourself. |
# | **Next Mon** | Repeat the cycle with the next topic, adding a quick group game or poll during class to keep engagement high. |
#
# By following these steps, you’ll strengthen engagement, improve the effectiveness of your study time, and gain clearer support whenever misunderstandings arise. Keep communicating with your instructor about what works best for you. Good luck!

# %% [markdown]
# ## Student ID: `e20221650`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "interaction", "learning_effectiveness", "learning_environment", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221650*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. Your responses show a positive view of blended learning, highlighting its flexibility, convenience, and the way it keeps you engaged. At the same time, you note challenges around technology‑driven engagement, workload, and the need for clearer interaction and resources.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you value |
# |-------|----------------|
# | **Flexibility & Time Management** | Ability to study when it fits your schedule. |
# | **Learning Convenience & Effectiveness** | Access to materials that help you meet academic goals. |
# | **Student Engagement** | Enjoyment of interactive, collaborative activities. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you find difficult |
# |-------|--------------------------|
# | **Assessment & Workload** | Managing the amount and timing of assignments. |
# | **Interaction & Communication** | Wanting more structured, real‑time contact with peers and lecturers. |
# | **Learning Resources & Environment** | Need for clearer, better‑organized materials and study spaces. |
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation follows the rule‑based tags that match your strengths and challenges.)
#
# | Recommendation | How to apply it |
# |----------------|-----------------|
# | **Increase learner engagement** | Incorporate short quizzes, game‑based elements, practical tasks, and discussion prompts into each module. |
# | **Increase interaction and communication** | Schedule regular Q&A sessions, set up small‑group discussions, encourage peer‑collaboration projects, and request quicker feedback from lecturers. |
# | **Improve learning effectiveness** | Pair online review videos with in‑person explanations, hands‑on practice, and timely feedback to reinforce concepts. |
# | **Improve learning resources and environment** | Use a clear folder structure for course files, keep resources up‑to‑date, and ensure study spaces (both virtual and physical) are comfortable and well‑equipped. |
# | **Support self‑paced learning** | Provide recorded lectures and a weekly learning path so you can review material at your own speed. |
# | **Manage workload and assessment pressure** | Align online tasks with face‑to‑face sessions, balance the number of assignments, and give clear deadlines well in advance. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|------------------|
# | 1 | Review the course’s weekly learning path and locate recorded lessons. | Gives you control over pacing and reduces last‑minute cramming. |
# | 2 | Join a peer‑study group that meets for a 30‑minute Q&A each week. | Boosts interaction and clarifies doubts quickly. |
# | 3 | Complete one quiz or game‑based activity per topic before the next lecture. | Reinforces learning and keeps engagement high. |
# | 4 | Meet with the lecturer (or TA) to discuss upcoming assessments and confirm deadlines. | Helps balance workload and plan study time effectively. |
#
# Follow these steps, and you’ll keep the high level of engagement you already enjoy while addressing the workload and interaction challenges you identified. Good luck!

# %% [markdown]
# ## Student ID: `e20230058`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230058*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits:** Actively seeks material, prefers to review what is unclear, and thrives when resources are readily available.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You like to “skip what I know and replay what I don’t understand,” showing a strong ability to target gaps quickly.
# - **Learning Convenience & Effectiveness** – Your active approach works best when you can get the right content at the right time.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – You noted “notification” as a difficulty, indicating that reminders and prompts are not always effective for you.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** *(content_access)* | Having slides, videos, references, and exercises available early lets you focus on the parts you find confusing. | Ask your instructor to upload all course assets at the start of each module. Keep a personal folder (e.g., on Google Drive) where you store these files for quick review. |
# | **Improve learning effectiveness** *(learning_effectiveness)* | Pairing online review with in‑person explanation, practice, and feedback helps you solidify understanding. | After watching a video or reading a slide, schedule a short 15‑minute face‑to‑face (or virtual) session with a tutor or study group to discuss key points and get feedback. |
# | **Support motivation and self‑discipline** *(motivation)* | Structured check‑ins, reminders, and progress tracking keep you on track when notifications alone aren’t enough. | Set a weekly study plan (e.g., Monday & Thursday 10 am). Use a planner or app that requires you to mark completed tasks. Arrange a brief weekly check‑in with a peer or mentor to review progress. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Create a digital folder for the current course and download all available slides, videos, and readings. |
# | **Day 2** | Draft a simple weekly schedule (2‑3 study blocks) and add it to your calendar. |
# | **Day 3** | Set up a reminder in your phone or app that prompts you **15 minutes before** each study block. |
# | **Day 4** | Choose one topic you find difficult, watch the related video, then meet a classmate for a 15‑minute discussion. |
# | **Day 7** | Review your progress: mark completed items in the folder and note any gaps. |
# | **Day 10** | Repeat the “watch + discuss” cycle for a second topic. |
# | **Day 14** | Have a brief check‑in (email or chat) with your tutor/peer to share what you’ve mastered and where you still need help. Adjust next week’s schedule accordingly. |
#
# ---
#
# **Remember:** Your active learning style works best when you have quick, organized access to materials, combine online review with live interaction, and use structured, self‑monitored study routines. Implement the steps above, and you’ll keep your momentum strong throughout the semester. Good luck!

# %% [markdown]
# ## Student ID: `e20220184`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_support", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220184*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values being able to revisit video material and appreciates clear, well‑structured content. You actively seek additional explanations when a video is unclear and are comfortable using AI or asking the instructor for help.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You like having video recordings that you can pause, rewind, and review.
# - **Student Engagement** – You are motivated to stay involved and take advantage of digital resources.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – When videos lack clear explanations or examples, you feel confused and need extra support.
# - **Interaction & Communication** – You would benefit from quicker feedback and more opportunities to ask questions.
# - **Assessment & Workload** – Managing assignments and understanding deadlines can be stressful.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on the rule‑based recommendations) |
# |------|------------------------------------------------------|
# | **Content Access** | Ensure that slides, videos, reference links, exercises and any other course materials are uploaded **early** in the week so you can review them before class. |
# | **Engagement** | Participate in short quizzes, interactive games, practical tasks, and discussion prompts that are embedded in the online modules. |
# | **Interaction** | Join scheduled **Q&A sessions** and group‑discussion boards; use peer‑collaboration tools and request faster feedback from the lecturer when you post a question. |
# | **Learning Support** | Look for recorded explanations that include step‑by‑step guides and concrete examples. When a video is unclear, use the provided supplemental notes or ask the instructor for a brief clarification video. |
# | **Workload Support** | Check the course calendar for clear deadlines, and use the online task list to see how assignments align with in‑person sessions. If the workload feels heavy, contact the tutor early to discuss possible pacing. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | • Download all posted slides and videos for the upcoming module (content access). <br>• Complete the introductory quiz to activate engagement. |
# | **1‑2** | • Post any unclear points from the videos in the Q&A forum (interaction). <br>• Review the supplemental step‑by‑step guide for the first practical task (learning support). |
# | **2** | • Attend the live Q&A session and share one example you created from the video (interaction & engagement). <br>• Review the assignment calendar; note all deadlines and plan study blocks (workload support). |
#
# Follow these steps and keep using the digital resources that work best for you. Your active approach combined with clearer, well‑structured materials and timely interaction will help you stay confident and successful in both online and face‑to‑face parts of the course.

# %% [markdown]
# ## Student ID: `e20240966`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240966*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** Gaining new knowledge and the convenience of digital learning.
# - **Current challenge:** Unreliable internet access.
#
# ---
#
# ### 2. Main Strengths
# - Strong interest in **digital skills development** and **learning convenience & effectiveness** (you noted “gain new knowledge”).
#
# ---
#
# ### 3. Main Challenges
# - **Technical issue:** Intermittent or slow internet connections that can disrupt online activities.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | What to do |
# |----------------|------------------|------------|
# | **Develop digital learning skills** (digital_skill) | Improves confidence with the LMS, online resources, and research tools, making your study time more productive. | • Attend a short LMS‑tool tutorial (often offered by the university). <br>• Explore curated lists of reliable digital research databases. |
# | **Improve learning effectiveness** (learning_effectiveness) | Combining brief online reviews with face‑to‑face explanations and practice boosts understanding, especially when you prefer a more passive style. | • Use short video or slide reviews before class. <br>• Participate in in‑person discussion or lab sessions for clarification and feedback. |
# | **Improve technical access and reliability** (tech_issue) | Stable connectivity lets you use the online materials without interruption. | • Locate campus Wi‑Fi hotspots or library computers for critical sessions. <br>• Download lecture slides or readings in advance for offline study. <br>• Keep the university’s tech‑support contact handy for quick help. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Watch the LMS quick‑start video (10 min) and bookmark the university’s digital‑research guide. |
# | **Day 3‑4** | Identify a reliable campus location (library, study lounge) with strong Wi‑Fi; plan to attend at least one in‑person class there. |
# | **Day 5** | Download this week’s lecture slides and any supplemental PDFs for offline review. |
# | **Day 6‑7** | Attend the scheduled in‑person session; ask at least one question to get feedback on the material. |
# | **Day 8‑10** | If internet problems persist, contact tech support and request a temporary hotspot loan or alternative access solution. |
# | **Day 11‑14** | Reflect: note which digital tools helped most and any remaining technical hurdles; adjust your study routine accordingly. |
#
# ---
#
# **Remember:** You already have a positive attitude toward gaining new knowledge. By strengthening your digital skills, pairing online review with face‑to‑face practice, and securing reliable internet access, you’ll make your blended learning experience smoother and more effective. Good luck!

# %% [markdown]
# ## Student ID: `e20220908`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220908*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated, regularly attend class, and make good use of recorded lectures.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value being able to watch lecture recordings whenever you need them and to review them at your own pace.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You find some new technology tools hard to use, which can affect how clearly you understand the material.
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation (title) | What to do |
# |-----|------------------------|------------|
# | **content_access** | **Strengthen access to learning materials** | • Ensure that slides, videos, reference links, exercises and any other course resources are uploaded **early** in the learning platform. <br>• Keep a single, well‑organized folder for each module so you can locate recordings and supplemental files quickly. |
# | **learning_support** | **Improve clarity and learning support** | • Ask the instructor for **clearer step‑by‑step guides** and examples for any new tools you must use. <br>• Use recorded explanations or short tutorial videos that walk through the technology before you start the activity. <br>• When instructions feel vague, request a brief clarification in the discussion forum or during office hours. |
#
# These actions match the two recommendation tags that emerged from your profile: **content_access** and **learning_support**.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Check the course’s online portal for a “Resources” folder. If it’s missing, send a quick note to the instructor asking for early uploads of slides and videos. |
# | **Day 3–5** | Locate a tutorial video on the new technology tool you find difficult. Watch it, pause, and try the steps yourself. |
# | **Day 6** | Write down any unclear steps and post a question in the class forum or schedule a 10‑minute virtual office‑hour meeting. |
# | **Day 7–10** | Create a personal “study folder” on your device where you store the recordings you watch, along with the instructor’s step‑by‑step guides. |
# | **Day 11–14** | Review one lecture recording and the associated exercise using the new guide. Note what helped you understand better and share that feedback with the instructor. |
#
# Following this plan will keep your strong habit of using recordings while giving you clearer support for the technology tools you find challenging. Keep leveraging your high engagement—your proactive steps will make blended learning smoother and more effective.

# %% [markdown]
# ## Student ID: `e20221701`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221701*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You tend to work best when you can **re‑watch recorded videos and study on your own**. You also mentioned that you often miss class notifications unless the teacher tells you directly, which can make staying on top of tasks harder.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You make good use of recorded videos and self‑study resources.
# - **Learning Convenience & Effectiveness:** Being able to review content at your own pace helps you understand the material.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Limited real‑time contact with the instructor and peers.
# - **Motivation & Self‑Discipline:** Relying on teacher reminders can affect your ability to keep a steady study rhythm.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on evidence) |
# |------|--------------------------------|
# | **Content Access** | **Upload all course assets early** – slides, videos, reference links, and practice exercises should be available on the learning platform before each class. This lets you continue your effective self‑study without waiting. |
# | **Interaction** | **Add structured interaction opportunities** – short Q&A slots after videos, small‑group discussion boards, and peer‑collaboration tasks. Request quicker feedback from the lecturer on assignments. |
# | **Learning Effectiveness** | **Blend review with live explanation** – use the recorded material you already like, then attend brief in‑person (or live‑online) sessions where the instructor clarifies key points and you can practice with immediate feedback. |
# | **Motivation & Self‑Discipline** | **Set up weekly check‑ins** – a short meeting or digital form where you report progress, receive reminders, and adjust your study schedule. Use a simple tracker (e.g., a checklist or app) to see completed tasks and stay motivated. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | • Ensure the instructor uploads all slides, videos, and exercises at least 2 days before class.<br>• Join a discussion forum for the course and post one question about the current topic. |
# | **2** | • Attend a 15‑minute live Q&A session (or schedule one) to clarify any confusing points from the videos.<br>• Complete a personal progress checklist and set a reminder for the next week’s study goals. |
#
# Follow these steps, and you’ll keep the advantages of self‑paced study while adding the interaction and structure that help maintain motivation. If you need further support, reach out to your lecturer or academic advisor. Good luck!

# %% [markdown]
# ## Student ID: `e20210184`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_support", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210184*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to work steadily but prefer a more passive role in class. You are good at locating resources when you study on your own, yet you feel the current weekly assignment load fragments your study time and limits deep understanding.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You find it relatively easy to locate resources for self‑study.
# - **Learning Convenience & Effectiveness:** You can make good use of the materials you find, which supports your learning when you study independently.
#
# ### 3. Main Challenges
# - **Assessment & Workload:** Weekly assignments for each subject divide your study time and make it hard to achieve deeper comprehension.
# - **Learning Difficulty & Clarity:** The pace and amount of work sometimes reduce the clarity of what you need to learn.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** *(content_access)* | Having all slides, videos, references, and practice exercises available early lets you continue the self‑study approach you already use. | • Instructors should upload all course assets at the start of each week.<br>• Use the university’s LMS to bookmark and organize these resources for quick reference. |
# | **Improve learning effectiveness** *(learning_effectiveness)* | Pairing the online content you already access with in‑person explanations and feedback will deepen your understanding. | • Review the uploaded materials before class.<br>• Attend the face‑to‑face session to ask questions and practice the concepts with the instructor’s guidance. |
# | **Improve clarity and learning support** *(learning_support)* | Clearer instructions and step‑by‑step guides will reduce confusion and help you focus on the key ideas. | • Look for recorded explanations and example problems posted by the teacher.<br>• Use any provided learning guides as a checklist when completing tasks. |
# | **Manage workload and assessment pressure** *(workload_support)* | A more balanced assignment schedule will give you longer, uninterrupted study periods for each subject. | • Request that the instructor groups related online tasks with the corresponding in‑person session.<br>• When possible, negotiate extended deadlines for larger assignments or combine smaller weekly tasks into a single, more manageable deadline. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Monday** | Check the LMS for all uploaded slides, videos, and practice files for your courses. Save them in a dedicated folder. |
# | **Week 1 – Tuesday** | Watch the introductory videos **before** the first face‑to‑face class. Note any questions. |
# | **Week 1 – Wednesday** | Attend the in‑person session, ask your prepared questions, and complete a short practice activity with the instructor’s feedback. |
# | **Week 1 – Thursday** | Review the recorded explanations and step‑by‑step guides posted after class. |
# | **Week 1 – Friday** | Draft a personal study schedule that groups related topics together, allowing at least 2–3 hours of focused study per subject. |
# | **Week 2 – Monday** | Communicate with the course coordinator (email or office hours) about the possibility of longer deadlines or combined assignments for the upcoming weeks. |
# | **Week 2 – Rest of the week** | Follow the schedule, using the organized materials and the clarified instructions to complete assignments. Adjust the plan if you notice any overload and discuss further with the instructor. |
#
# ---
#
# **Remember:** By taking advantage of early‑released materials, combining them with active in‑person learning, and working with your instructors to balance the workload, you can turn your strong self‑study skills into deeper, more confident understanding of each subject. Good luck!

# %% [markdown]
# ## Student ID: `e20211096`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment", "motivation", "tech_issue", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20211096
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You appreciate having learning resources (slides, videos, recordings) available online, finding them easier to follow than in‑person sessions.
#
# **Main Challenges**
# - You would like quicker notifications about new tasks, quizzes, and deadlines.
# - You need clearer communication from lecturers (e.g., louder audio).
# - You experience occasional technical or internet issues that affect access to materials.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload all slides, videos, references, exercises, and other course materials early in the week. | Gives you reliable, early access to the resources you already value. |
# | **Interaction** | Add regular Q&A slots, short group discussions, and peer‑collaboration activities; ensure lecturers give prompt feedback. | Increases the communication you want and keeps you connected with the class. |
# | **Learning Environment** | Organise the online folder structure clearly, keep resources up‑to‑date, and provide guidance on creating a comfortable study space (e.g., headphones, proper lighting). | Makes it easier to locate what you need and improves the overall study experience. |
# | **Motivation & Self‑Discipline** | Set up weekly check‑ins, automated reminders for upcoming quizzes and assignments, and a simple progress‑tracking dashboard. | Supports your need for timely notifications and helps you stay on schedule. |
# | **Technical Issues** | Offer a reliable internet backup (e.g., campus Wi‑Fi vouchers), provide offline downloadable versions of key materials, and give clear step‑by‑step platform guides plus a help‑desk contact. | Reduces the disruptions you face when connectivity or platform problems arise. |
# | **Workload Support** | Balance the number of online tasks with in‑person work, clearly list all deadlines in one place, and synchronize quiz dates with class schedules. | Lessens the pressure of tight deadlines and aligns assessments across delivery modes. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Review the course’s online folder; request that the instructor upload all week‑1 materials (slides, videos, exercises) by Monday.
# 2. **Day 3:** Subscribe to the course’s notification channel (e.g., LMS alerts or a messaging group) and set personal reminders for upcoming quizzes.
# 3. **Day 4‑5:** Join a peer‑study group or schedule a short virtual Q&A with the lecturer to clarify any unclear points.
# 4. **Day 6‑7:** Test the offline download option for the week’s videos; if needed, request technical support for any connectivity problems.
# 5. **Week 2:** Complete a quick self‑check (using the progress dashboard) and note any missed deadlines; share feedback with the instructor about audio volume or other communication issues.
#
# By following these steps, you can keep leveraging your strong engagement while addressing the notification, technical, and workload concerns you highlighted. Good luck, and keep up the active participation!

# %% [markdown]
# ## Student ID: `M080405`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080405*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What we know:** You indicated that the internet is a strength for you, while the teaching style of courses can be a challenge. No additional themes were identified, so the recommendations below are drawn primarily from the characteristics of the “Highly Engaged” segment.
#
# ---
#
# ### 2. Main Strengths
# - Comfortable using the internet for learning.
#
# ---
#
# ### 3. Main Challenges
# - The current teaching style does not always match your preferred way of learning.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps you |
# |------|------------|------------------|
# | **Content Access** | Upload or request early access to slides, videos, reference links, exercises, and any other course materials. | Having the materials ahead of time lets you explore content at your own speed and prepares you for class activities. |
# | **Digital Skills** | Take short tutorials on the LMS, online research tools, and any educational tech used in the course. | Strengthening these skills lets you make the most of digital resources and reduces friction with teaching styles that rely on technology. |
# | **Engagement** | Participate in quizzes, games, practical tasks, discussion boards, and other interactive activities. | Active, varied tasks keep you motivated and help you apply what you learn, offsetting any mismatch in teaching style. |
# | **Self‑Paced Learning** | Use recorded lectures and weekly learning paths; review materials whenever needed. | This gives you control over timing, so you can revisit concepts that the teaching style may not have clarified the first time. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the course’s LMS and download any available slides or video recordings. |
# | **Day 3‑4** | Complete a brief LMS tutorial (many platforms have a “Help” or “Getting Started” video). |
# | **Day 5‑7** | Set up a personal weekly learning path: list the topics, allocate 1‑2 h per topic, and schedule review sessions. |
# | **Day 8‑10** | Join at least one discussion forum or group chat for the course; post a question or comment. |
# | **Day 11‑12** | Attempt a low‑stakes quiz or interactive activity related to the current topic. |
# | **Day 13‑14** | Review any material that felt unclear; use the internet to find supplementary resources (e.g., short YouTube explainer, open‑access article). |
#
# Follow this plan and adjust the timing to fit your schedule. By strengthening access, digital competence, engagement, and self‑paced options, you’ll be able to turn the teaching‑style challenge into an opportunity for deeper, more active learning.
#
# ---
#
# *Keep leveraging your comfort with the internet, and feel free to reach out to your instructor or learning support services if you need additional resources.*

# %% [markdown]
# ## Student ID: `e20230757`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230757*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key Strength:** Flexibility & good time‑management skills.
# - **Main Challenge:** Difficulty listening and understanding material clearly.
#
# ### 2. Main Strengths
# - **Flexibility:** You adapt well to different schedules and can manage your study time effectively. This makes you well‑suited to self‑directed activities.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity:** You find it hard to follow spoken explanations, which can affect comprehension of new concepts.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Learning Support** (clarity & support) | Get clearer instructions, concrete examples, and step‑by‑step guides. Recorded explanations can be replayed as needed. | Look for supplemental videos or audio recordings that break down complex ideas. Use any provided walkthroughs before tackling assignments. |
# | **Self‑Paced Learning** | Take advantage of recorded lessons and weekly learning paths that let you study at your own speed. | Review lecture recordings before class, pause and replay sections that are unclear, and follow the weekly roadmap to stay on track. |
#
# These recommendations are drawn from the *Highly Engaged* segment profile and the specific strengths/challenges you reported.
#
# ### 5. Short Action Plan
#
# | Week | Action | Goal |
# |------|--------|------|
# | **1** | Locate all recorded lectures and step‑by‑step guides for your current module. | Build a personal “clarity toolkit.” |
# | **2** | Create a weekly learning path (e.g., 2 hrs video, 1 hr practice, 30 min review). | Structure your flexible schedule around clear milestones. |
# | **3** | After each lecture, write down any unclear points and re‑watch the relevant video segment. | Improve comprehension and reduce listening difficulty. |
# | **4** | Share one useful example or guide with a classmate and discuss it briefly. | Reinforce learning and maintain engagement. |
#
# Follow this plan for the next month, adjusting the pace as needed. Your flexibility will help you stay on track, and the added learning support will make the material clearer and easier to master. Good luck!

# %% [markdown]
# ## Student ID: `e20220468`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220468*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can manage your own schedule and appreciate the flexibility that digital tools give you. At the same time, you value face‑to‑face interaction, feeling that in‑person classes add extra value to your learning experience.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You find the ability to study when it fits your personal timetable convenient.
# - **Digital Skills Development** – You are comfortable using digital resources and are ready to deepen those abilities.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You feel that in‑person sessions provide richer interaction than online formats and would like more meaningful communication in blended courses.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Develop digital learning skills** *(digital_skill)* | Strengthen your use of the LMS, online libraries, and educational tech tools. | Attend short tutorials on the LMS, explore digital research guides, and try out new ed‑tech apps suggested by your lecturer. |
# | **Increase interaction and communication** *(interaction)* | Add more opportunities for live dialogue and peer collaboration. | Participate in scheduled Q&A sessions, join small‑group discussion boards, and request quicker feedback on assignments. |
# | **Support self‑paced learning** *(self_paced)* | Keep the flexibility you like while ensuring you don’t miss key content. | Use recorded lectures and weekly learning paths; review materials at your own speed and set personal milestones each week. |
#
# These three recommendations align directly with the tags identified for you and the strengths/challenges you reported.
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|------------------|
# | 1 | Watch the LMS “Getting Started” video and bookmark the digital research guide. | Faster navigation of course resources. |
# | 2 | Join a peer‑study group on the discussion board; schedule a 30‑min live Q&A with the lecturer. | More interaction and immediate clarification of doubts. |
# | 3 | Download the week’s recorded lectures; create a personal study checklist based on the weekly learning path. | Maintain flexibility while staying on track. |
# | 4 | Reflect on the new tools and interaction opportunities: note any improvements in understanding or time management. | Consolidate digital skills and decide which practices to keep. |
#
# ---
#
# **Remember:** Your active engagement and ability to manage time are strong assets. By sharpening your digital skills, adding structured interaction, and using self‑paced resources, you can get the best of both online flexibility and the richness of in‑person learning. Good luck!

# %% [markdown]
# ## Student ID: `e20220368`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220368*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically makes good use of digital tools, enjoys self‑paced study, and stays motivated when content is readily accessible.
#
# ### 2. Main Strengths
# - **Appreciation of blended learning:** You recognize that the blended format saves travel time and gives you more time to study.
#
# ### 3. Main Challenges
# - You would like lecturers to **explain material more slowly** and to provide **clear outlines and learning materials** in advance.
# - These concerns fall under the themes of **Interaction & Communication**, **Learning Difficulty & Clarity**, and **Learning Resources & Environment**.
#
# ### 4. Personalized Recommendations
# | Area | What the recommendation suggests | Why it helps you |
# |------|----------------------------------|------------------|
# | **Interaction** | Add short Q&A slots, group discussions, peer‑collaboration activities, and quicker feedback from lecturers. | Gives you more chances to ask for clarification and engage actively with the material. |
# | **Learning Environment** | Organize course resources in a clear, searchable folder; keep digital and physical study spaces tidy; update any outdated content. | Makes it easier to locate outlines and materials before class, reducing uncertainty. |
# | **Learning Support** | Provide step‑by‑step guides, recorded explanations, and concrete examples for each topic. | Supports slower, clearer explanations and lets you review at your own pace. |
#
# These three recommendations align directly with the tags identified for you: **interaction, learning_environment, learning_support**.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action | Expected Benefit |
# |-----|--------|------------------|
# | **Day 1–2** | Review the course’s online portal and note where outlines or resources are missing. | Identify gaps to discuss with the lecturer. |
# | **Day 3** | Send a brief, polite request to the lecturer for a short outline of the upcoming week’s topics. | Improves your preview of material. |
# | **Day 4–5** | Join a peer‑study group (or start one) for a 30‑minute Q&A session on the current module. | Increases interaction and clarifies doubts. |
# | **Day 6–7** | Create a personal “study folder” where you store all downloaded slides, recordings, and your own notes in a consistent order. | Enhances the learning environment for quick reference. |
# | **Day 8–10** | Watch any recorded lecture segments at a slower playback speed; pause to write step‑by‑step notes. | Reinforces clearer explanations. |
# | **Day 11–12** | Provide feedback to the lecturer (via email or course forum) about which explanations helped you most and where you still need slower pacing. | Encourages the lecturer to adjust future sessions. |
# | **Day 13–14** | Reflect on the week: note any improvements in understanding and any remaining gaps. Plan the next week’s actions accordingly. | Closes the feedback loop and sustains engagement. |
#
# ---
#
# **Keep in mind:** Your active engagement is a strong asset. By shaping the interaction, environment, and support you receive, you can turn your enthusiasm into even deeper learning outcomes. If you need further assistance, reach out to your academic advisor or the course’s learning‑support team. Good luck!

# %% [markdown]
# ## Student ID: `e20210573`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210573*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. You value the **flexibility, speed, time‑saving, and convenience** that blended formats can offer, and you appreciate easy **access to learning materials**. At the same time, you find it **hard to understand content online when you don’t have direct instructor support**, indicating a need for clearer interaction and guidance.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You like having slides, videos, and resources available quickly.
# - **Flexibility & Time Management** – You benefit from being able to study when it fits your schedule.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You miss real‑time help and feel isolated without direct instructor contact.
# - **Learning Difficulty & Clarity** – Online explanations sometimes feel unclear, making it harder to grasp the material.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Keep the fast, convenient flow of resources you value. | Instructors should **upload slides, videos, references, exercises, and other course materials early** in the week so you can review them whenever you need. |
# | **Increase interaction and communication** | Reduce the feeling of isolation and get quicker help. | Include **regular Q&A sessions, small‑group discussions, peer‑collaboration activities, and faster lecturer feedback** (e.g., short response windows on discussion boards). |
# | **Improve clarity and learning support** | Make online content easier to understand without needing a live instructor. | Provide **clearer instructions, concrete examples, recorded step‑by‑step explanations, and short learning guides** that you can replay as often as needed. |
# | **Support self‑paced learning** | Align with your preference for flexibility. | Offer **recorded lessons and a weekly learning path** that outline what to study each day, allowing you to **review material at your own pace**. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Who’s responsible |
# |------|--------|-------------------|
# | 1 | Check the course portal for **early‑uploaded slides and videos** for this week’s topics. | Instructor / LMS admin |
# | 1 | Join a **live Q&A** (or schedule a short office‑hour slot) to clarify any confusing points. | Instructor |
# | 1‑2 | Form a **peer study group** (2‑4 students) to discuss weekly readings and solve practice problems together. | You & classmates |
# | 2 | Review the **recorded explanations** and **step‑by‑step guides** for any concepts that were unclear in the live session. | You |
# | 2 | Follow the **weekly learning path**: set 30‑minute blocks each day to watch a video, do an exercise, and post a question if needed. | You |
#
# By focusing on these four areas—material access, interaction, clear support, and self‑paced structure—you can keep leveraging your strong engagement while overcoming the challenges you’ve identified. Good luck, and enjoy the flexibility that blended learning can give you!

# %% [markdown]
# ## Student ID: `e20220888`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment", "learning_support", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220888*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Overall tone:** Positive about both strengths and challenges.
#
# You value easy access to course materials and prefer clear, well‑structured content. You also note that you need strong guidance from instructors because you rarely ask questions during class.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having the material readily available, which helps you stay focused.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Limited opportunities to ask questions or engage with the lecturer.
# - **Learning Difficulty & Clarity** – Need for precise explanations, step‑by‑step guidance, and anticipated questions with answers.
# - **Learning Resources & Environment** – High expectations for audio‑visual quality and well‑organized content.
# - **Motivation & Self‑Discipline** – Preference for external structure to keep you on track.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | **Upload all course assets early** – slides, video recordings, reference links, and practice exercises should be available at the start of the week. |
# | **Interaction** | **Add interactive elements** – schedule short Q&A slots, create small‑group discussion boards, and encourage peer collaboration. Request quicker feedback from the lecturer on submitted work. |
# | **Learning Environment** | **Organize and polish resources** – use clear folder structures, keep visual and audio quality high, and eliminate background noise in videos. Provide a tidy online “study space” (e.g., a dedicated module page). |
# | **Learning Support** | **Provide explicit guidance** – include step‑by‑step instructions, worked examples, and recorded explanations that anticipate common questions. |
# | **Motivation** | **Build routine support** – set up weekly check‑ins (automated reminders or brief surveys), use a progress‑tracking dashboard, and follow a structured study schedule (e.g., “Monday: watch video, Tuesday: complete exercises”). |
#
# These actions directly address the challenges you highlighted while leveraging your strength in accessing materials.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How You’ll Do It |
# |------|--------|------------------|
# | **1** | **Get materials early** – check the course portal every Monday for new slides, videos, and readings. | Set a calendar reminder for “Course upload check – Monday 9 am”. |
# | **1** | **Join a discussion group** – sign up for the class’s online forum or a study‑buddy pair. | Post an introductory message and schedule a 15‑minute chat. |
# | **1‑2** | **Use the provided step‑by‑step guides** – follow any “how‑to” videos before attempting exercises. | Pause the video, take notes, then try the practice problem. |
# | **2** | **Weekly check‑in** – complete the short progress survey sent by the instructor and note any questions. | Allocate 10 minutes on Friday evening for the survey. |
# | **2** | **Track your progress** – mark completed modules on the course dashboard. | Update the dashboard after each study session. |
#
# By following this simple plan, you’ll benefit from early material access, clearer explanations, more interaction, and a structured routine that supports motivation.
#
# Good luck, and remember that the university’s support services are here to help you succeed!

# %% [markdown]
# ## Student ID: `e20220554`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220554*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** Flexibility and enough time to catch up when you miss a class.
# - **What you find difficult:** Unreliable internet, and participating in online team discussions.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when it fits your schedule and like having the option to review material later.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Online group work feels hard.
# - **Internet & Technical Issues** – Spotty connection disrupts learning.
# - **Learning Difficulty & Clarity** – When instructions are unclear, it adds to the struggle.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and short live polls.<br>• Take part in small‑group discussion boards or breakout rooms.<br>• Use peer‑collaboration tools (e.g., shared docs) and ask the lecturer for quicker feedback on drafts. | Increases real‑time communication and makes team work feel more manageable. |
# | **Learning Support** | • Look for recorded explanations and step‑by‑step guides that accompany each topic.<br>• Request examples or additional clarification when a concept isn’t clear. | Clearer instructions reduce confusion and give you concrete reference material to review. |
# | **Self‑Paced Learning** | • Access the recorded lectures and weekly learning paths that outline what to study each week.<br>• Keep a personal checklist of the modules you need to complete, revisiting any you missed. | Lets you use your preferred flexibility while staying on track. |
# | **Technical Access** | • Download offline versions of videos, slides, and readings when you have good connectivity.<br>• Use the campus Wi‑Fi hotspots or the university’s loan‑er laptop/portable router program.<br>• Follow the short “how‑to” guide for the learning platform and contact tech support for persistent issues. | Reduces the impact of bad internet and ensures you can keep studying even offline. |
#
# *These suggestions are drawn directly from the recommendations matched to your segment and the challenges you reported.*
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the “download offline materials” option in the course portal; download the next two lecture videos. |
# | **Day 3** | Join the upcoming live Q&A session (check the schedule in the LMS). Prepare one question you’ve had about the recent topic. |
# | **Day 4–5** | Form a small study group (2‑3 peers) on the discussion board; schedule a 30‑minute breakout chat to review the recorded lecture together. |
# | **Day 6** | Review the step‑by‑step guide for the current assignment; note any unclear steps and email the lecturer for clarification. |
# | **Day 7** | Set up a weekly learning path checklist in a notebook or digital app; mark completed items each day. |
# | **Day 8–9** | Test the campus Wi‑Fi hotspot or request a loan‑er device if your home connection remains unstable. |
# | **Day 10** | Submit a short reflection (1‑2 sentences) on what interaction method helped you most this week; share it with the instructor for faster feedback. |
# | **Day 11–14** | Repeat the cycle, adjusting the study‑group time and the resources you download based on what worked best. |
#
# ---
#
# **Keep in mind:** Your flexibility is a strong asset—use the recorded and offline resources to stay ahead, and lean on the interaction tools and tech support whenever connectivity or communication feels limiting. You’re on a good path to a more engaging and reliable blended learning experience!

# %% [markdown]
# ## Student ID: `e20241155`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241155*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What the data shows:** You expressed a positive view of your learning experience, especially appreciating the convenience and effectiveness of the resources you use. No specific challenges were reported.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You feel that the current tools help you study efficiently and fit well with your schedule.
#
# ### 3. Main Challenges
# - No challenges were identified in your responses.
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness** – To build on your strong engagement, combine the online review materials you already find convenient with brief, in‑person sessions that provide explanation, guided practice, and immediate feedback. This blended approach helps solidify understanding and boosts long‑term retention.
#
# ### 5. Short Action Plan
#
# | Step | What to Do | How It Helps |
# |------|------------|--------------|
# | 1. **Select key topics** | Identify 1–2 concepts each week that need deeper practice. | Focuses your effort where it matters most. |
# | 2. **Use online review** | Before class, watch short video summaries or read concise notes. | Keeps the convenience you value. |
# | 3. **Attend a short in‑person session** | Join a 30‑minute workshop, tutorial, or study group for those topics. | Gives you direct explanation and practice. |
# | 4. **Get feedback** | Ask the instructor or peers for quick feedback on a practice problem or a short write‑up. | Clarifies misunderstandings right away. |
# | 5. **Reflect & adjust** | After each week, note what helped you learn best and tweak the mix of online and face‑to‑face time. | Continues to improve your effectiveness. |
#
# By pairing the flexible online resources you already enjoy with targeted, interactive face‑to‑face activities, you’ll maintain your high engagement while deepening your mastery of the material.

# %% [markdown]
# ## Student ID: `e20221070`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221070*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - This segment is characterised by strong motivation to interact with course content and a preference for flexible, technology‑rich learning environments.
#
# ### 2. Main Strengths
# - **Interest in modern education** – you value up‑to‑date teaching methods and resources.
#
# ### 3. Main Challenges
# - **Reluctance to ask questions in class** – you mentioned that you rarely pose questions to the professor during face‑to‑face sessions.
#
# ### 4. Personalized Recommendations
# Because your open‑ended responses are brief, the suggestions below draw primarily on the typical needs of highly engaged learners in your segment, combined with the strengths and challenge you shared.
#
# | Recommendation Area | What it means for you | Suggested actions |
# |---------------------|-----------------------|-------------------|
# | **Content Access** | Having all learning materials early lets you explore topics at your own pace and come to class prepared to ask deeper questions. | • Upload lecture slides, videos, reading lists, and practice exercises to the LMS **before** each class.<br>• Keep a personal folder of these resources for quick reference. |
# | **Digital Skill** | Mastering the LMS and online research tools will boost your confidence when seeking information or clarifying doubts. | • Attend a short workshop on LMS navigation, citation tools, and effective online searching.<br>• Use built‑in discussion boards or chat to pose questions digitally before or after class. |
# | **Engagement** | Interactive activities (quizzes, games, discussions) make the material more memorable and give you low‑stakes ways to participate. | • Join in‑class polls or quick quizzes.<br>• Participate in small‑group discussions or online forums where you can type questions first. |
# | **Self‑Paced Learning** | Recorded lessons and weekly learning paths let you review complex topics as many times as needed, supporting your habit of preparing before class. | • Watch recorded lectures ahead of time and note any uncertainties.<br>• Follow a weekly checklist of readings, videos, and practice tasks that you can complete at your own speed. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s LMS and bookmark the folder where slides and videos will be posted. |
# | **Day 3** | Watch the first recorded lecture; write down 2–3 questions you have. |
# | **Day 4** | Post those questions in the LMS discussion board or send them to the professor via email. |
# | **Day 5** | Complete the first short quiz or interactive activity provided online. |
# | **Day 6–7** | Review any feedback, revisit the relevant video segment, and note any remaining doubts. |
# | **Week 2** | Attend the live class, using the prepared questions to feel more comfortable speaking up. Reflect on how the digital tools helped you engage. |
#
# ---
#
# **Remember:** Leveraging early access to materials, sharpening your digital skills, and using interactive, self‑paced resources will make it easier to voice your questions and deepen your learning. You’re already highly motivated—these steps will help turn that motivation into even stronger academic performance. Good luck!

# %% [markdown]
# ## Student ID: `e20220547`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220547*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits of this segment:** strong motivation, good self‑discipline, and a preference for active, self‑paced study.
#
# ### 2. Main Strengths
# - **Self‑discipline** – you keep to schedules and manage your workload well.
# - **Motivation** – you are eager to learn and stay engaged with course material.
#
# ### 3. Main Challenges
# - **Technical/Internet issues** – occasional problems with connectivity or platform reliability that can interrupt study.
#
# ### 4. Personalized Recommendations
# Because your strengths already align with the “Highly Engaged” profile, the key area to support you is ensuring smooth technical access:
#
# - **Stable internet access** – seek campus Wi‑Fi hotspots, a reliable home broadband plan, or a mobile data backup.
# - **Offline materials** – download lecture videos, readings, and assignments when you have a good connection so you can study without interruption.
# - **Clear platform guidance** – keep a quick‑reference sheet of how to log in, submit work, and troubleshoot common errors.
# - **Technical support** – use your university’s IT help desk or chat support for prompt assistance when issues arise.
#
# ### 5. Short Action Plan
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | 1 | Test your current internet speed and identify a reliable backup (e.g., campus library Wi‑Fi). | Use a free speed‑test website; note locations with strong signal. |
# | 2 | Download all upcoming week’s materials (videos, PDFs) for offline use. | Click the “download” button on the LMS or ask the instructor for copies. |
# | 3 | Create a one‑page cheat sheet with login steps and common error fixes. | Write down the steps and keep the sheet near your study space. |
# | 4 | Add the university IT help desk contact to your phone and bookmark the support portal. | Save the phone number/email and set a reminder to use it when needed. |
# | Ongoing | Monitor any technical glitches and report them promptly. | Log the issue (date, time, description) and contact support right away. |
#
# ---
#
# **Remember:** Your self‑discipline and motivation are strong foundations for success. By securing reliable technical access, you’ll be able to fully leverage your active learning style and stay on track with your courses. If new challenges arise, feel free to revisit this plan or reach out for additional support.

# %% [markdown]
# ## Student ID: `e20221213`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221213*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are proactive about your studies and like to have course materials in advance.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You already make good use of the ability to obtain slides, videos, and other resources before class.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable internet connectivity can limit your participation in online activities.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Continue to **upload or request slides, videos, references, and exercises early** in the semester. | Having everything ready lets you study at your own pace and stay ahead, matching your active learning style. |
# | **Improve technical access and reliability** | Seek **stable internet options** (e.g., campus Wi‑Fi, a mobile hotspot, or a quiet library space). Ask the instructor for **offline copies** of key resources and keep a list of **technical support contacts** and clear platform guides. | Reliable connectivity ensures you can join live sessions, submit work on time, and fully benefit from the blended format. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Verify that all upcoming lecture slides and videos are posted at least 2 days before class. |
# | **2** | Locate a reliable internet spot on campus or arrange a personal hotspot for backup. |
# | **3** | Download offline versions of the week’s materials (PDFs, video files) to your device. |
# | **4** | Save the contact info for the university’s IT help desk and test the platform with a short practice activity. |
# | **Ongoing** | Review the uploaded materials before each class and note any technical problems to report promptly. |
#
# By focusing on early material access and securing a stable internet connection, you’ll be able to keep up with the course content and make the most of your highly engaged learning style. Good luck!

# %% [markdown]
# ## Student ID: `e20231232`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20231232
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - Recognises that blended learning provides a good balance of in‑person and online instruction, supporting flexibility, time‑management and overall learning convenience.
#
# **Main Challenges**
# - Indicates a neutral concern about “technology use.” No specific challenge was detailed, so the recommendations rely mainly on the characteristics of the Highly Engaged learner segment.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Pair the online review resources you already value with face‑to‑face explanation, practice activities, and timely feedback. | • Use online videos or readings to preview a topic.<br>• Attend the scheduled class session for a concise explanation and guided practice.<br>• Seek feedback on assignments or quizzes right after class. |
# | **Support self‑paced learning** | Take advantage of recorded lessons and weekly learning paths so you can revisit material whenever it fits your schedule. | • Access recorded lectures on the learning platform.<br>• Follow the weekly learning path that outlines what to study each day.<br>• Review notes or redo exercises at your own pace before moving on. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Identify a core topic** you will study this week.
# 2. **Watch the recorded lesson** for that topic before the next in‑person session.
# 3. **Attend the class** to get the instructor’s explanation, do the practice activity, and ask for feedback.
# 4. **Use the weekly learning path** to schedule a 30‑minute review session each day, revisiting the recorded material and completing any extra exercises.
# 5. **Reflect** at the end of the week: note what helped your understanding and any technology issues you encountered, then adjust your plan for the following week.
#
# By combining online review with active classroom work and using self‑paced resources, you can keep your high engagement level while maximizing learning effectiveness.

# %% [markdown]
# ## Student ID: `M080404`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080404*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility of online study and the deeper understanding that comes from in‑person classes. You appreciate having learning materials available early and enjoy interactive activities that keep you motivated. You also notice occasional hurdles such as internet reliability and limited interaction during online sessions.
#
# ---
#
# ### 2. Main Strengths
# | Strength theme | What you expressed |
# |----------------|-------------------|
# | **Access to Learning Materials** | You like that blended learning gives you both online and face‑to‑face resources. |
# | **Flexibility & Time Management** | Online study lets you learn whenever it fits your schedule. |
# | **Student Engagement** | Combining formats helps you stay interested and ask questions. |
# | **Digital Skills Development** | You see value in using digital tools for learning. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge theme | What you mentioned |
# |-----------------|--------------------|
# | **Interaction & Communication** | Online sessions sometimes feel less interactive. |
# | **Internet & Technical Issues** | Connectivity problems can disrupt learning. |
# | **Learning Difficulty & Clarity** | You would like clearer materials and more recorded explanations. |
# | **Learning Resources & Environment** | Better‑organized resources and comfortable study spaces would help. |
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation follows the rule‑based tags that match your strengths and challenges.)
#
# | Recommendation | How it helps you |
# |----------------|-----------------|
# | **Strengthen access to learning materials** – upload slides, videos, references, and exercises early. | Lets you review content before class and reduces last‑minute scrambling. |
# | **Develop digital learning skills** – short guides on LMS tools, online research, and educational tech. | Boosts confidence using the platform and makes troubleshooting easier. |
# | **Increase learner engagement** – embed quizzes, games, practical tasks, and discussion prompts. | Keeps the online part lively and reinforces what you learn in‑person. |
# | **Increase interaction and communication** – schedule regular Q&A, peer‑collaboration groups, and faster lecturer feedback. | Improves the sense of community and clears up doubts quickly. |
# | **Improve learning effectiveness** – pair online review materials with in‑person explanations, practice, and feedback. | Combines the best of both modes for deeper understanding. |
# | **Improve learning resources and environment** – organize materials clearly, update resources, and enhance study spaces. | Makes it easier to find what you need and creates a comfortable learning setting. |
# | **Improve clarity and learning support** – provide clearer instructions, examples, recorded explanations, and step‑by‑step guides. | Reduces confusion and supports self‑study. |
# | **Support self‑paced learning** – offer recorded lessons and weekly learning paths you can follow at your own speed. | Gives you control over timing while still meeting course deadlines. |
# | **Improve technical access and reliability** – ensure stable internet options, offline copies of key content, clear platform instructions, and prompt tech support. | Minimises disruptions caused by connectivity problems. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|------------------|
# | 1 | Check that all course slides and videos are uploaded to the LMS; download any needed files for offline use. | Immediate access to materials; reduces reliance on unstable internet. |
# | 2 | Attend a short “LMS Tips” workshop (or watch the recorded guide). | Improves digital skill and confidence navigating the platform. |
# | 3 | Join a peer‑study group that meets once a week for Q&A and discussion. | Increases interaction and clarifies difficult concepts. |
# | 4 | Use the weekly learning path (recorded lessons + quiz) to review the week’s topic at your own pace. | Reinforces learning, boosts engagement, and tracks progress. |
#
# Feel free to adapt the timeline to fit your personal schedule. By focusing on these targeted actions, you can make the most of blended learning—leveraging its flexibility while minimizing technical and interaction challenges. Good luck, and keep up the active engagement!

# %% [markdown]
# ## Student ID: `e20241351`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241351
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You feel confident with technology and are eager to learn more software tools. (Digital Skills Development)
#
# **Main Challenges**
# - Unreliable internet connectivity makes blended learning difficult. (Internet & Technical Issues)
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Develop digital learning skills** | Build on your comfort with technology by mastering the learning‑management system (LMS), online research tools, and other educational apps. | • Follow short tutorials on the LMS dashboard.<br>• Explore campus‑provided webinars on digital research.<br>• Practice using collaborative tools (e.g., shared docs, discussion boards) for class projects. |
# | **Improve technical access and reliability** | Reduce the impact of internet problems so you can stay engaged with course material. | • Download lecture videos and readings for offline study when you have a good connection.<br>• Keep a list of campus locations (library, computer labs) that offer stable Wi‑Fi.<br>• Use the university’s tech‑support help desk for quick troubleshooting.<br>• Save important deadlines and instructions in a printed or offline note‑taking app. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑3:** Watch the LMS “Getting Started” video (10 min) and bookmark the tutorial page.
# 2. **Day 4‑7:** Download all upcoming week’s lecture videos and PDFs to your laptop/tablet for offline access.
# 3. **Day 8‑10:** Attend a 30‑minute campus tech‑support workshop (or join the online session) to learn quick fixes for connectivity issues.
# 4. **Day 11‑14:** Apply a new digital tool (e.g., a citation manager or collaborative board) in one assignment and note any time saved.
#
# By focusing on sharpening your digital skills and securing reliable access to course materials, you can keep the momentum of your active learning style while minimizing technical disruptions. Good luck!

# %% [markdown]
# ## Student ID: `e20241399`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241399*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically participates actively in class, seeks deeper understanding, and values both online and face‑to‑face learning experiences.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You appreciate tools that help you acquire more knowledge efficiently.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You would like lecturers to improve how they interact with students, especially when internet access is limited.
# - **Internet & Technical Issues** – Unreliable connectivity makes it hard to engage fully with blended courses.
#
# *(Your open‑ended comments were brief, so the recommendations below draw heavily on the characteristics of your segment.)*
#
# ### 4. Personalized Recommendations
# | Focus | What the recommendation suggests | Why it helps you |
# |-------|----------------------------------|------------------|
# | **Interaction** | Add regular Q&A sessions, small‑group discussions, peer‑collaboration activities, and faster lecturer feedback. | Increases the communication you’re looking for and keeps you actively involved even when you’re online or offline. |
# | **Learning Effectiveness** | Pair online review materials with in‑person explanations, guided practice, and timely feedback. | Combines the convenience you value with the deeper understanding you seek. |
# | **Technical Access** | Provide stable internet options, downloadable/offline resources, clear platform guides, and a dedicated tech‑support channel. | Reduces the disruption caused by connectivity problems, letting you stay engaged wherever you study. |
#
# ### 5. Short Action Plan (Next 4 weeks)
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | 1 | **Join a study‑group chat** (e.g., on Teams or Discord) for your course. | Ask the lecturer or classmates for the link; schedule a 30‑min weekly meetup. |
# | 2 | **Download offline materials** for the upcoming module. | Look for “download” buttons on the LMS or request PDFs from the lecturer. |
# | 3 | **Participate in a Q&A session** (live or recorded). | Mark the session in your calendar; prepare 1‑2 questions in advance. |
# | 4 | **Contact tech support** if you experience connectivity issues. | Use the university’s help‑desk portal; note the problem and ask for a temporary hotspot or loaner device. |
#
# ---
#
# By focusing on richer interaction, combining online and face‑to‑face learning, and securing reliable technical access, you can maintain your high level of engagement while overcoming the current challenges. Keep using the resources above, and feel free to reach out to your lecturers or support services whenever you need extra help. Good luck!

# %% [markdown]
# ## Student ID: `e20240212`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240212*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility of self‑study. You appreciate being able to watch course videos whenever you need and to revisit them until the material is clear. Your main difficulty is unreliable internet access, which sometimes limits your ability to use online resources.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You recognize that having slides, videos, and other resources available supports independent study.
# - **Learning Convenience & Effectiveness:** The ability to re‑watch content helps you understand concepts better.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Spotty connectivity can interrupt your study flow and limit access to online content.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to act |
# |----------------|----------------------|------------|
# | **Strengthen access to learning materials** (content_access) | Get all course assets (slides, videos, readings, exercises) as early as possible so you can download them for offline use. | Look for a “download” button on the LMS, or ask the instructor to share a zip folder of the week’s materials. |
# | **Improve learning effectiveness** (learning_effectiveness) | Pair the online videos with in‑person or live‑online sessions where you can ask questions, practice, and receive feedback. | Attend scheduled tutorials or office‑hours, and use the videos as a pre‑study tool. |
# | **Improve technical access and reliability** (tech_issue) | Ensure you have a stable connection or offline alternatives, plus clear guidance on using the platform. | • Use campus Wi‑Fi or a reliable hotspot when possible.<br>• Download videos and PDFs ahead of time.<br>• Keep the platform’s help guide bookmarked and contact tech support early if problems arise. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the “download all resources” option for your current module and save the files to your laptop/tablet. |
# | **Day 3** | Test the downloaded videos offline to confirm they play without internet. |
# | **Day 4–5** | Schedule a 30‑minute session with the course tutor or join a live tutorial to discuss any unclear points from the videos. |
# | **Day 6** | Verify campus Wi‑Fi or arrange a reliable hotspot for the upcoming week. |
# | **Day 7–10** | Follow the same download‑review‑live‑feedback cycle for the next set of materials. |
# | **Day 11–14** | If connectivity issues persist, contact the university’s technical support and note the problem for future reference. |
#
# By securing materials early, combining them with interactive practice, and addressing connectivity gaps, you can keep your high level of engagement while making your blended learning experience smoother and more effective. Good luck, and keep up the active approach to your studies!

# %% [markdown]
# ## Student ID: `e20250062`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250062*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive in flexible, time‑saving learning environments. You appreciate being able to avoid commuting and having extra time to prepare for class. At the same time, you find the lack of real‑time interaction, occasional internet problems, and difficulty asking questions in an online setting challenging.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you said |
# |-------|---------------|
# | **Flexibility & Time Management** | Online classes let you skip traffic and give you more preparation time. |
# | **Learning Convenience & Effectiveness** | You feel the format is manageable and convenient. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you said |
# |-------|---------------|
# | **Interaction & Communication** | Limited chance to interact, ask questions, or discuss with peers. |
# | **Internet & Technical Issues** | Connectivity problems sometimes disrupt learning. |
# | **Learning Difficulty & Clarity** | Online material can be harder to understand without immediate help. |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How it helps you | Practical steps you can take |
# |----------------|------------------|------------------------------|
# | **Increase interaction and communication** | Gives you more chances to ask questions and collaborate. | • Join scheduled live Q&A or discussion sessions.<br>• Form small study groups for peer collaboration.<br>• Use the course forum for quick lecturer feedback. |
# | **Improve learning effectiveness** | Combines the convenience you like with the clarity of face‑to‑face support. | • Attend in‑person workshops that review online material.<br>• Participate in guided practice labs and receive immediate feedback. |
# | **Improve clarity and learning support** | Provides clearer instructions and examples, reducing confusion. | • Look for recorded step‑by‑step tutorials.<br>• Request additional examples or rubrics from the instructor.<br>• Use the provided learning guides for each topic. |
# | **Support self‑paced learning** | Keeps the flexibility you value while ensuring you stay on track. | • Follow the weekly learning path posted on the LMS.<br>• Review recorded lessons at any time.<br>• Set personal milestones and check them against the course schedule. |
# | **Improve technical access and reliability** | Minimises disruptions caused by internet or platform issues. | • Download offline copies of readings and videos when possible.<br>• Keep a list of technical support contacts handy.<br>• Test your connection before live sessions and use campus Wi‑Fi if needed. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the weekly learning path and download any offline materials. |
# | **Day 3** | Join the first live Q&A session; write down any questions you have. |
# | **Day 4** | Form a small study group (2‑3 peers) for a 30‑minute discussion on the current topic. |
# | **Day 5** | Watch a recorded step‑by‑step tutorial and complete the accompanying practice exercise. |
# | **Day 6** | Test your internet connection; note any issues and contact technical support if needed. |
# | **Day 7** | Attend an in‑person workshop or lab that reviews the week’s online content. |
# | **Day 8–14** | Follow the weekly path, revisiting recorded lessons as needed; keep a brief log of what you’ve mastered and any remaining questions for the next Q&A. |
#
# ---
#
# **Keep leveraging the flexibility you enjoy while adding structured interaction, clearer resources, and reliable technical support.** This blended approach will help you stay engaged, understand the material deeply, and succeed in both online and face‑to‑face components of your courses.

# %% [markdown]
# ## Student ID: `e20230360`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230360*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values **flexibility, time‑saving, and cost‑effective study options**. You appreciate being able to study when it suits you and see blended learning as a way to make learning more convenient.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You like that blended formats let you fit study around other commitments.
# - **Learning Convenience & Effectiveness** – You recognize that online resources can make learning more efficient and affordable.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity sometimes blocks your access to online content.
# - **Learning Difficulty & Clarity** – At times you find the lesson content hard to understand without additional explanation.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Improve learning effectiveness** | Pair the online review materials you already use with short, in‑person (or live‑online) sessions where concepts are explained, practiced, and you receive feedback. | Attend scheduled tutorial labs or virtual office hours that follow the online modules. |
# | **Improve clarity and learning support** | Get clearer instructions, concrete examples, and step‑by‑step guides that you can refer to whenever a topic feels confusing. | Use recorded explanations and detailed guides posted on the course platform; ask the instructor for additional examples if needed. |
# | **Support self‑paced learning** | Keep using recorded lessons and weekly learning paths so you can review material at your own speed, especially when internet access is spotty. | Download lecture videos and PDFs in advance; follow the weekly roadmap to stay on track. |
# | **Improve technical access and reliability** | Ensure you have stable internet or offline alternatives, and know how to get quick technical help. | Use campus Wi‑Fi or a mobile hotspot when possible; download offline copies of readings and videos; keep the platform’s help desk contact handy. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify a reliable internet source (campus Wi‑Fi, library, or hotspot). Download the next week’s lecture videos and reading materials for offline use. |
# | **Day 3** | Review the weekly learning path; note any topics you feel unclear about. |
# | **Day 4–5** | Attend a live tutorial or schedule a short meeting with the instructor to go over those topics; ask for additional examples or step‑by‑step guides. |
# | **Day 6** | Practice the concepts using the provided exercises; submit any questions to the teaching assistant for feedback. |
# | **Day 7** | Reflect on what helped most (e.g., recorded explanations, live feedback) and adjust your study schedule for the following week accordingly. |
# | **Repeat** | Follow the same cycle each week, using offline materials when connectivity is poor and seeking clarification promptly. |
#
# By combining flexible online resources with targeted in‑person support and ensuring you have reliable technical access, you can keep leveraging your strong engagement while overcoming the current challenges. Good luck, and keep up the active learning!

# %% [markdown]
# ## Student ID: `e20220573`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220573*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility of blended learning. You see it as a way to take responsibility for your own study, manage time, and deepen research on course topics. At the same time, you notice that long online sessions can make it hard to stay focused, and occasional internet problems disrupt your learning.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You appreciate being able to study when and where it suits you, which helps you stay motivated and develop skills useful for your future career.
# - **Self‑Discipline** – You take ownership of your study schedule and use blended formats to set and achieve personal goals.
#
# ---
#
# ### 3. Main Challenges
# - **Maintaining Focus & Motivation** during extended online periods.
# - **Internet/Technical Issues** that interrupt live lessons.
# - **Clarity & Interaction** – Wanting more engaging, interactive activities and clearer instructions to keep concentration high.
# - **Workload Management** – Balancing online tasks with in‑person work and assessments.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try (Based on Rule‑Based Advice) |
# |------|-------------------------------------------|
# | **Interaction** | Join scheduled Q&A sessions, take part in small‑group discussions, and collaborate with peers on short projects. Ask your lecturer for quicker feedback on drafts. |
# | **Learning Effectiveness** | Use the combination of recorded lecture material and face‑to‑face explanations. After each online segment, spend time practicing the concepts and seek feedback. |
# | **Learning Environment** | Keep your study materials organized in a single folder or LMS section. Choose a quiet, comfortable spot for online work and let the university know if classroom conditions need improvement. |
# | **Learning Support** | Look for step‑by‑step guides, example problems, and recorded explanations that the lecturer provides. When instructions are unclear, request concrete examples. |
# | **Motivation & Self‑Discipline** | Set a weekly check‑in with yourself (or a study buddy) to review progress. Use a simple tracker or calendar to mark completed tasks and celebrate small milestones. |
# | **Technical Issues** | Download lecture videos or slides in advance so you can study offline if the connection drops. Familiarize yourself with the platform’s help resources and contact tech support early when problems arise. |
# | **Workload Support** | Keep a master list of all deadlines; ask the lecturer to confirm due dates at the start of each week. Break larger assignments into smaller, manageable steps that align with both online and face‑to‑face sessions. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Create a dedicated digital folder for each course (lecture slides, recordings, notes). |
# | **Tue** | Schedule a 15‑minute weekly self‑check‑in (e.g., every Friday afternoon). |
# | **Wed** | Download this week’s lecture videos to study offline if needed. |
# | **Thu** | Join a peer‑study group or set up a short discussion forum for a current topic. |
# | **Fri** | Review upcoming deadlines; break any pending assignment into 2‑3 tasks and add them to your calendar. |
# | **Sat** | Spend 30 min practicing a concept from the week’s online material and request feedback from the lecturer or a peer. |
# | **Sun** | Reflect on what helped you stay focused and note any technical issues to report to support. |
#
# Repeat the cycle each week, adjusting the tasks as you discover what works best for you.
#
# ---
#
# **Remember:** Your strong engagement is a valuable asset. By adding a few structured interaction points, clearer resources, and reliable technical backups, you can turn the challenges of blended learning into opportunities for even greater success. Good luck!

# %% [markdown]
# ## Student ID: `e20240486`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240486*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Strengths (self‑reported):** You noted that your learning “makes the brain more stronger,” and you are interested in developing digital skills.
# - **Challenges (self‑reported):** Managing time effectively.
#
# *Because the open‑ended responses are brief, the recommendations below rely primarily on the characteristics of the “Highly Engaged (Active) Learners” segment together with the digital‑skill focus identified in your profile.*
#
# ---
#
# ### 2. Main Strengths
# - Strong motivation and active engagement with course material.
# - Positive attitude toward building **digital learning skills**.
#
# ### 3. Main Challenges
# - **Time‑management** – balancing study tasks with other commitments.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Develop digital learning skills** (tag: *digital_skill*) | Gain confidence using the LMS, online libraries, research tools, and other educational technologies. | • Attend the university’s short “LMS Essentials” workshop (often 1 hour, self‑paced). <br>• Follow the curated list of digital‑resource tutorials provided in the course portal. <br>• Use a digital note‑taking app (e.g., OneNote, Notion) to organize lecture notes and sources. |
# | **Self‑paced content access** (segment default) | Take advantage of recordings, slides, and supplemental videos whenever you have free time. | • Schedule 30‑minute “catch‑up” blocks each day to review recorded lectures. <br>• Bookmark key resources for quick retrieval during study sessions. |
# | **Engagement strategies** (segment default) | Keep your high energy directed toward interactive activities. | • Participate in discussion forums and peer‑review tasks. <br>• Set micro‑goals (e.g., “post one comment per forum thread”) to stay active. |
# | **Time‑management support** (challenge) | Use simple planning tools to protect study time. | • Create a weekly planner (digital or paper) with fixed study slots. <br>• Apply the Pomodoro technique (25 min focus + 5 min break) during digital‑skill practice. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Register for the “LMS Essentials” workshop (or watch the recorded version). |
# | **Day 2‑3** | Choose one digital‑note‑taking app; set it up for the current course. |
# | **Day 4‑5** | Draft a weekly study schedule that includes 2 × 30‑min digital‑skill practice slots. |
# | **Day 6‑7** | Watch one supplemental video on online research tools; take notes in your new app. |
# | **Week 2** | Apply the Pomodoro technique during at least one study session; reflect on time use in a brief journal entry. |
# | **End of Week 2** | Review progress: have you accessed content more flexibly? Do you feel more comfortable with LMS tools? Adjust the schedule as needed. |
#
# ---
#
# **Keep in mind:** Your high engagement gives you a strong foundation for mastering digital learning tools. By pairing that enthusiasm with a simple time‑management routine, you’ll be able to make the most of blended learning resources and keep your “brain stronger” throughout the semester. Good luck!

# %% [markdown]
# ## Student ID: `e20241292`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241292
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value saving time for students who live far from campus, showing an awareness of efficiency and accessibility.
#
# **Main Challenges**
# - Unreliable internet connectivity in university areas.
# - Issues with the learning environment and resources (e.g., study spaces, material organization).
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | Why it matters |
# |----------------|----------------------|----------------|
# | **Improve learning environment** | • Keep your digital and physical study materials well‑organized.<br>• Use updated resources and choose comfortable, quiet study spots (library rooms, study lounges, or a well‑set‑up home workspace). | A clear, comfortable environment reduces distractions and helps you stay focused, especially when you’re actively engaged in class activities. |
# | **Improve technical access and reliability** | • Ensure you have a stable internet connection (e.g., campus Wi‑Fi hotspots, personal data plan, or a portable router).<br>• Download offline copies of lecture videos, readings, and assignments when possible.<br>• Follow the university’s platform guides and know how to contact tech support quickly. | Reliable connectivity lets you participate fully in blended activities and prevents interruptions that can break your momentum. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Map reliable internet spots** – Identify at least two places on or near campus with strong Wi‑Fi (library, student center) and test connection speed.
# 2. **Create an offline resource folder** – Download this week’s lecture videos and readings to a cloud folder or USB drive for backup use.
# 3. **Organize your study space** – Spend 15 minutes each day tidying your desk or chosen study area; label folders/files consistently.
# 4. **Save tech‑support contacts** – Add the university IT help‑desk phone/email to your phone and bookmark the troubleshooting guide.
#
# By tightening your learning environment and securing stable technical access, you can keep leveraging your high engagement while minimizing the disruptions you’ve identified. Good luck!

# %% [markdown]
# ## Student ID: `e20220240`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220240*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can control your schedule, revisit material at your own pace, and blend online and face‑to‑face activities. You value flexibility, time‑management, and the chance to “re‑learn” anything you missed.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you can design your own study timetable and allocate time to personal interests.
# - **Learning Convenience & Effectiveness** – you see blended learning as a way to take responsibility for what you learn and to deepen understanding.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – unreliable connectivity can interrupt study sessions.
# - **Learning Resources & Environment** – staying focused at home is difficult; you often need quiet cafés or offices.
# - **Motivation & Self‑Discipline** – maintaining concentration without a structured setting can be a hurdle.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Learning Effectiveness** | Pair the online review videos or readings you use with short, in‑person (or live‑online) sessions where you can ask questions, practice, and receive feedback. |
# | **Learning Environment** | Keep your digital files and notes well‑organized; update any outdated resources. Create a dedicated study nook—whether at a café, library, or a quiet corner at home—and make sure the space is comfortable (good lighting, ergonomic chair). |
# | **Motivation & Self‑Discipline** | Set a weekly check‑in with yourself (or a peer/mentor). Use a simple tracker (e.g., a spreadsheet or app) to mark completed tasks, and schedule brief reminders for each study block. A consistent, structured timetable will help sustain focus. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths provided by the course. Review the recordings before class, then use class time for active practice and clarification. |
# | **Technical Access** | Download key materials for offline use when you anticipate poor internet. Familiarize yourself with the platform’s help guides, and note the contact details for technical support so you can resolve issues quickly. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Review the week’s syllabus; download all lecture videos and readings for offline access. |
# | **Tue** | Set up a dedicated study spot (e.g., a quiet café). Create a simple study schedule (2 h online review, 1 h in‑person practice). |
# | **Wed** | Attend the live session or office‑hour for the topics you reviewed; ask at least one clarification question. |
# | **Thu** | Update your notes folder; label files by week and topic for easy retrieval. |
# | **Fri** | Do a 10‑minute progress check: mark completed tasks, note any technical problems, and adjust next week’s schedule if needed. |
# | **Weekend** | Spend 1 h reviewing any missed concepts; use offline PDFs if internet is unreliable. |
#
# Repeat the cycle, tweaking the study environment and schedule as you discover what works best for you.
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By pairing flexible online resources with focused, in‑person practice, and by securing a reliable study environment, you’ll maximize both learning effectiveness and enjoyment of blended courses. Good luck!

# %% [markdown]
# ## Student ID: `e20240202`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240202
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# You are an active participant who values the flexibility of blended learning, enjoys reviewing recorded lectures, and likes interactive, digital tools. You also notice that unstable internet and slower online communication sometimes hinder your experience.
#
# ---
#
# ### Main Strengths
# 1. **Access to Learning Materials** – You appreciate being able to review slides, videos, and resources at any time.
# 2. **Digital Skills Development** – You are comfortable using digital tools that make lessons interactive.
# 3. **Flexibility & Time Management** – The blended format lets you learn at your own pace.
# 4. **Student Engagement** – You enjoy quizzes, games, and collaborative activities.
#
# ### Main Challenges
# 1. **Internet & Technical Issues** – Unstable connections can disrupt online participation.
# 2. **Interaction & Communication** – Online replies from lecturers can be slower, making it harder to stay motivated.
# 3. **Motivation & Self‑Discipline** – Maintaining focus without constant structure can be difficult.
#
# ---
#
# ## Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Lecturers should upload slides, videos, references, exercises, and other materials **early** so you can plan your study. |
# | **Digital Skills** | Get short guides on using the LMS, online research tools, and any educational tech your courses employ. |
# | **Engagement** | Participate in quizzes, games, practical tasks, and discussion boards that are built into the course. |
# | **Interaction** | Join scheduled Q&A sessions, group discussions, and peer‑collaboration activities; ask for quicker feedback from lecturers when needed. |
# | **Learning Effectiveness** | Combine your review of online materials with the in‑person sessions that focus on explanation, practice, and feedback. |
# | **Learning Environment** | Keep your digital workspace organized (clear folders, labeled files) and make sure your physical study area is comfortable and free from distractions. |
# | **Learning Support** | Look for clear instructions, step‑by‑step guides, and recorded explanations that clarify complex topics. |
# | **Motivation & Self‑Discipline** | Use weekly check‑ins, set personal reminders, track your progress, and follow a structured study schedule. |
# | **Self‑Paced Learning** | Take advantage of recorded lessons and weekly learning paths to review content whenever it fits your schedule. |
# | **Technical Issues** | When possible, secure a reliable internet connection (e.g., campus Wi‑Fi, hotspot). Download offline copies of materials in advance and keep a list of technical support contacts handy. |
#
# ---
#
# ## Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Locate the course’s LMS and download the week’s slides, videos, and exercise files for offline use. |
# | **Day 2** | Watch the recorded lecture at your own pace; take brief notes. |
# | **Day 3** | Join the scheduled Q&A session; prepare 2‑3 questions in advance. |
# | **Day 4** | Complete the interactive quiz or game linked to the lecture. |
# | **Day 5** | Review the quiz feedback and note any concepts that need clarification. |
# | **Day 6** | Meet (in‑person or virtually) with a study group for a 30‑minute discussion of the week’s topic. |
# | **Day 7** | Set a personal study schedule for the next week and add reminders to your calendar. |
# | **Day 8‑14** | Repeat the cycle, adding a quick check‑in with your lecturer (email or LMS message) to confirm you’re on track. |
#
# By following these steps, you’ll reinforce your strengths, reduce the impact of technical and communication challenges, and keep your motivation high throughout the blended course. Good luck!

# %% [markdown]
# ## Student ID: `e20240244`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "tech_issue", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240244
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You appreciate having easy, ubiquitous access to the course syllabus and other materials, which helps you self‑direct your learning.
#
# **Main Challenges**
# - Unreliable internet and occasional isolation make it hard to stay connected.
# - Instructions for assignments or projects are sometimes unclear, which reduces motivation and self‑discipline.
# - You would like more interaction (questions, quizzes) during both online and face‑to‑face sessions, and you prefer receiving lesson materials a few days before class so you can study in advance.
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload slides, videos, reference links, exercises and any other course resources **early** (ideally a few days before the term starts). |
# | **Interaction** | Add regular Q&A slots, short quizzes, and small‑group discussions; encourage peer collaboration and provide faster lecturer feedback. |
# | **Learning Effectiveness** | Pair the online review materials with in‑person explanations, guided practice and timely feedback to reinforce concepts. |
# | **Learning Environment** | Organise all materials clearly on the learning platform, keep resources up‑to‑date, and ensure classroom spaces are comfortable for study. |
# | **Learning Support** | Provide clearer, step‑by‑step assignment instructions, example solutions and short recorded explanations. |
# | **Motivation & Self‑Discipline** | Implement weekly check‑ins or reminders, let you track progress, and suggest a structured study schedule. |
# | **Technical Issues** | Offer options for offline downloads, clear guidance on using the platform, and a help desk for internet or device problems. |
# | **Workload Support** | Balance the number of assignments, clarify deadlines well in advance, and align online tasks with what is covered in class. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Access the course portal and download any available slides or videos for the upcoming week (offline copy if internet is unstable).
# 2. **Day 3:** Join a short Q&A session or post a question in the discussion forum about any unclear assignment instructions.
# 3. **Day 4‑5:** Follow a simple study schedule (e.g., 1 hour review of slides, 30 min practice exercises). Mark progress in a personal tracker.
# 4. **Day 6:** Attend the in‑person class where the instructor will explain the material and give immediate feedback on practice tasks.
# 5. **Day 7:** Review the feedback, note any remaining doubts, and schedule a brief check‑in with the lecturer or a peer tutor.
#
# By following these steps you’ll make the most of the early material access you value, stay connected despite connectivity issues, and keep your motivation high throughout the course. Good luck!

# %% [markdown]
# ## Student ID: `e20230586`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230586*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You value gaining new experiences and knowledge and are comfortable using digital tools for learning.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – you appreciate resources that let you learn efficiently and at your own pace.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – working in teams can feel difficult.
# - **Learning Difficulty & Clarity** – some instructions or concepts are not clear enough.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from lecturers. | Improves teamwork skills and reduces the feeling of isolation when working with others. |
# | **Learning Effectiveness** | • Use a blend of online review materials (videos, quizzes) together with in‑person explanations and practice tasks.<br>• Seek immediate feedback on practice work. | Reinforces understanding and lets you apply new knowledge more confidently. |
# | **Learning Support** | • Look for clear, step‑by‑step guides and examples provided by the instructor.<br>• Access recorded explanations for complex topics.<br>• Ask for clarified instructions when needed. | Makes difficult concepts easier to grasp and reduces confusion. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the challenges you reported.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the upcoming Q&A session schedule in the LMS and add it to your calendar. |
# | **Day 3‑4** | Choose one online review module and pair it with the related in‑person lecture; complete the practice exercise and request feedback. |
# | **Day 5** | Join a peer‑collaboration group (e.g., a study‑buddy or discussion forum) and share a brief summary of what you learned. |
# | **Day 6‑7** | Review any recorded explanations for topics you found unclear; note down questions for the next Q&A. |
# | **Day 8‑10** | Ask the lecturer for a clarified version of any ambiguous instructions; keep a personal step‑by‑step guide for future reference. |
# | **Day 11‑14** | Reflect on how the added interaction and clearer resources affected your understanding; adjust the plan as needed for the next month. |
#
# Stay proactive and use the blended format to combine the flexibility you like with the support you need. You’re already highly engaged—these steps will help turn that energy into clearer, more collaborative learning outcomes. Good luck!

# %% [markdown]
# ## Student ID: `e20240234`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240234*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and like to take an active role in your studies.
#
# ### 2. Main Strengths
# - You noted that you “can research more about the topic,” indicating good initiative in seeking information.
#
# ### 3. Main Challenges
# - You wrote that you have “no suggestion,” which suggests you did not identify a specific difficulty at this time.
#
# *Because the open‑ended responses are brief, the recommendations below are drawn primarily from the characteristics of your learner segment.*
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Having slides, videos, references, and exercises available early lets you dive deeper into topics you want to research. | Look for a course portal where instructors upload all resources at the start of the week. Download or bookmark them for quick reference. |
# | **Develop digital learning skills** | Mastering the LMS, online databases, and digital tools will make your research faster and more effective. | Attend any short tutorials on the LMS, explore the library’s e‑resources, and try using citation managers or note‑taking apps. |
# | **Increase learner engagement** | Quizzes, games, practical tasks, and discussions keep active learners like you motivated and help you apply what you research. | Participate in live polls, join discussion boards, and complete optional interactive activities that accompany the lectures. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you review material whenever you need, fitting your active style and research habits. | Watch recorded sessions before class to preview topics, then revisit them after class to reinforce understanding. Follow the weekly learning path provided by the instructor. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s central LMS page and download all available slides, videos, and reading lists for the upcoming week. |
# | **Day 3** | Spend 30 minutes on a short tutorial about the LMS’s search and bookmarking features. |
# | **Day 4–5** | Choose one research topic from the week’s material and use the library’s e‑resources to gather at least three scholarly sources. |
# | **Day 6** | Complete any interactive quiz or game linked to the week’s content; note any concepts that need clarification. |
# | **Day 7** | Review the recorded lecture for the next topic and add personal notes or questions to the discussion forum. |
# | **Week 2** | Repeat the cycle, adding a new digital tool (e.g., citation manager) to organize your research findings. |
#
# ---
#
# **Keep leveraging your enthusiasm for research, and use the resources and tools outlined above to make your learning even more effective and flexible.**

# %% [markdown]
# ## Student ID: `e20240568`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "learning_support", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240568
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You appreciate the **flexibility** that blended learning gives you, especially the time saved on travel and the extra preparation time it provides.
# - You see blended learning as a convenient way to study and feel it can be effective when used well.
#
# **Main Challenges**
# - Managing your study time is difficult.
# - You would like the course to be clearer and easier to understand, with better resources and a more supportive learning environment.
#
# **Personalized Recommendations**
#
# | Focus | What the recommendation means for you | Practical steps you can take |
# |-------|----------------------------------------|------------------------------|
# | **Learning Effectiveness** | Combine the online review materials you already have with in‑person explanations, practice activities, and feedback. | • Before class, watch the recorded lessons and note questions.<br>• During face‑to‑face sessions, ask for examples and practice problems.<br>• Use office‑hours or peer‑review sessions for feedback. |
# | **Learning Environment** | Make sure study materials are well‑organized and that your study space (both online and physical) supports concentration. | • Use a folder or digital notebook to keep resources sorted by week.<br>• Choose a quiet spot for online study; keep it tidy and free of distractions.<br>• If possible, suggest to the school that classroom seating and lighting be reviewed for comfort. |
# | **Learning Support** | Get clearer instructions and step‑by‑step guides, plus recorded explanations you can revisit. | • Look for any “how‑to” videos or guides posted by the instructor.<br>• When an assignment is unclear, request a short example or a written checklist.<br>• Save recorded explanations for later review when you need a refresher. |
# | **Self‑Paced Learning** | Use recorded lessons and weekly learning paths to control the speed of your study. | • Follow the weekly learning path provided by the course (e.g., “Monday: video; Wednesday: quiz; Friday: discussion”).<br>• Pause and replay recordings as needed to fit your schedule.<br>• Set personal mini‑deadlines for each module to keep on track. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Create a weekly schedule** that blocks specific times for:
#    - Watching recorded lessons (self‑paced)
#    - Reviewing notes and practice questions (learning effectiveness)
#    - Attending face‑to‑face sessions with prepared questions (learning support)
#
# 2. **Organize your resources:**
#    - Set up a digital folder with sub‑folders for each week’s materials.
#    - Add a “quick‑reference” file with step‑by‑step instructions for common tasks.
#
# 3. **Engage with support:**
#    - Post at least one clarification question on the course forum each week.
#    - Schedule a 15‑minute meeting with a tutor or peer mentor to review a challenging concept.
#
# 4. **Reflect on time use:**
#    - At the end of each study session, note how long you spent and what was most effective.
#    - Adjust the next day’s schedule based on this reflection to improve time management.
#
# By following these focused steps, you can turn the flexibility you value into a more structured, clear, and effective blended‑learning experience. Good luck!

# %% [markdown]
# ## Student ID: `e20241131`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20241131
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can **learn online with recorded videos** and you are highly motivated to engage with course content. Your main challenge is trying to **understand all subjects within your skill set**, which suggests you need clearer guidance and support across topics.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value having slides, videos, and other resources available for review.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – You find it challenging to grasp every subject fully and would benefit from clearer explanations and step‑by‑step guidance.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** (content_access) | Instructors should upload slides, video recordings, reference links, and practice exercises **early** in the module. | You can revisit the material at your own pace, reinforcing understanding of each subject. |
# | **Improve clarity and learning support** (learning_support) | Courses should include **clear instructions, concrete examples, recorded explanations, and step‑by‑step guides** for key concepts. | More explicit guidance reduces confusion and helps you master the full range of topics in your skill set. |
#
# These recommendations are drawn directly from the evidence about your strengths, challenges, and the “Highly Engaged (Active) Learners” segment.
#
# ---
#
# ### 5. Short Action Plan
# 1. **Check the course portal weekly** for newly uploaded slides, videos, and practice files. Bookmark them for quick reference.
# 2. **Create a personal “clarity folder”** where you save recorded explanations and step‑by‑step guides provided by the instructor.
# 3. **Schedule short review sessions** (15‑20 min) after each lecture to go over the uploaded materials and note any points that remain unclear.
# 4. **Use the provided examples and exercises** to test your understanding before moving on to the next topic.
# 5. **Reach out early** (via discussion board or office hours) if a concept still feels fuzzy after reviewing the resources.
#
# Following these steps will leverage your strong engagement with digital content while giving you the clear, supportive structure you need to master all subjects in your program. Good luck, and keep up the active learning!

# %% [markdown]
# ## Student ID: `e20240385`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240385*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can study from anywhere and stay actively involved in class activities.
#
# ### 2. Main Strengths
# - **Flexibility of access:** You value being able to learn remotely and “anywhere.”
# - (Your comment shows a positive attitude toward blended learning overall.)
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You experience difficulty getting timely feedback and communicating with the lecturer and classmates.
# - **Internet & Technical Issues:** Unstable connections and limited technical support hinder your learning.
#
# ### 4. Personalized Recommendations
#
# | Focus Area | What to Do (based on rule‑based advice) |
# |------------|------------------------------------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities (e.g., breakout rooms, shared documents).<br>• Request quicker feedback from the lecturer when possible. |
# | **Technical Access** | • Use any university‑provided stable‑internet options (e.g., campus Wi‑Fi hotspots, loaner routers).<br>• Download offline versions of lectures and readings ahead of time.<br>• Follow the platform’s quick‑start guide and keep the technical‑support contact handy for troubleshooting. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the university’s internet‑access resources (e.g., hotspot loan, campus Wi‑Fi) and download the week’s lecture videos for offline use. |
# | **Day 3‑4** | Sign up for at least one live Q&A or discussion session; prepare one question or comment to share. |
# | **Day 5‑7** | Form a small study group (2‑3 peers) for a short collaborative task; set a shared online workspace (e.g., Google Docs). |
# | **Day 8‑10** | Test the platform’s help desk: note the response time and any common fixes for connectivity problems. |
# | **Day 11‑14** | Review how the added interaction and offline materials affected your learning; note any remaining issues and plan next steps. |
#
# ---
#
# **Remember:** Your strong engagement is a great asset. By boosting communication with peers/lecturers and securing reliable technical access, you’ll make the most of blended learning’s flexibility. Good luck!

# %% [markdown]
# ## Student ID: `e20241269`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_effectiveness", "learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241269*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values quick access to course materials and enjoys interacting with teachers and classmates when you need clarification. You feel confident that your school can provide good solutions, and you see blended learning as a positive way to support your studies.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having slides, videos, and other resources available early.
# - **Digital Skills Development** – You are open to using LMS tools and online resources.
# - **Learning Convenience & Effectiveness** – You like being able to review content online and then discuss it in‑person.
# - **Student Engagement** – You enjoy quizzes, games, discussions, and practical tasks that keep you active in learning.
#
# ---
#
# ### 3. Main Challenges
# - **Learning Resources & Environment** – You noted that the overall learning environment (e.g., how materials are organized and the comfort of study spaces) could be improved.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to act on it |
# |----------------|----------------------|------------------|
# | **Strengthen access to learning materials** | Get slides, videos, references, and exercises uploaded **before** class so you can review them anytime. | Ask the instructor to share a weekly “resource pack” on the LMS; set a reminder to download it each Monday. |
# | **Develop digital learning skills** | Learn to use the LMS, online research tools, and educational apps efficiently. | Attend a short workshop or watch a tutorial on the LMS dashboard; practice using the search and annotation features. |
# | **Increase learner engagement** | Use interactive elements such as quizzes, games, and discussion boards to stay motivated. | Participate in weekly online quizzes; join a study group chat where you can post questions and share ideas. |
# | **Improve learning effectiveness** | Combine online review with face‑to‑face explanation, practice, and feedback. | After watching a video, schedule a 10‑minute meeting with the teacher or a peer to clarify doubts and practice problems. |
# | **Improve learning resources and environment** | Ensure materials are well‑organized and study spaces are comfortable. | Provide feedback to the course coordinator about the layout of the LMS folders; suggest quiet study corners or better seating in the classroom. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Check the LMS for the upcoming week’s resource pack; download all slides and videos. |
# | **Tuesday** | Watch the first video, then post one question in the discussion board. |
# | **Wednesday** | Attend a 15‑minute virtual tutorial on LMS navigation (recorded or live). |
# | **Thursday** | Complete the online quiz linked to the week’s topic; review your score and note any errors. |
# | **Friday** | Meet with a classmate or the instructor for a quick in‑person review of the quiz topics. |
# | **Weekend** | Write brief feedback on how the materials were organized and suggest any improvements for the study space. |
#
# Follow this plan, and you’ll reinforce your strengths while addressing the only challenge identified—optimizing the learning environment. Keep leveraging your high engagement, and the blended format will become an even more powerful tool for your success.

# %% [markdown]
# ## Student ID: `e20221205`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221205*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values easy access to lecture files and reference books. This convenience lets you conduct independent research across courses. At the same time, you experience occasional setbacks from slow or unreliable internet and from some lecturers who do not keep course files up‑to‑date.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You can quickly retrieve slides, videos, and reference texts, which supports self‑directed study.
# - **Learning Convenience & Effectiveness** – The ability to gather resources easily helps you learn efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable connections cause errors and disrupt access.
# - **Interaction & Communication** – Limited lecturer updates and slower feedback reduce timely interaction.
# - **Learning Resources & Environment** – Some course files are outdated, and study spaces could be better organized.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Instructors should **upload slides, videos, references, exercises, and other course materials early** in the semester so you always have the latest resources. |
# | **Interaction** | Add **regular Q&A sessions, group discussions, and peer‑collaboration activities**. Request quicker feedback from lecturers to keep the dialogue flowing. |
# | **Learning Effectiveness** | Pair the online review materials you already use with **in‑person explanations, practice tasks, and timely feedback** to deepen understanding. |
# | **Learning Environment** | Encourage the department to **organise digital folders clearly, keep resources up‑to‑date, and improve physical study spaces** (lighting, seating, quiet zones). |
# | **Technical Issues** | Seek **stable campus Wi‑Fi or offline copies of essential files**, and make use of the university’s technical support and clear platform guides. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Download all current lecture slides and reference PDFs for your courses; store them on a personal device for offline use. |
# | **2** | Join a study group or set up a peer‑chat channel to discuss weekly topics and share notes. |
# | **3** | Attend at least one scheduled Q&A or discussion session; ask the lecturer for any missing or outdated files. |
# | **4** | Contact the IT help desk to test your internet connection on campus; request a stable hotspot or alternative access if needed. |
#
# By following these steps, you can capitalize on your strong ability to access materials while reducing the impact of technical and communication hurdles. Keep leveraging your active engagement, and you’ll continue to thrive in a blended learning environment.

# %% [markdown]
# ## Student ID: `M080311`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** M080311
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Highly Engaged (Active) Learners” segment. This group typically participates actively in class, seeks interaction, and values clear, readily‑available learning resources. Your open‑ended comments were brief, so the recommendations below rely primarily on the characteristics of this segment together with the strengths and challenges identified in the data.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You recognize the importance of having course content (slides, videos, references) available for both students and lecturers.
# - **Student Engagement** – You value an active learning environment where participants are involved.
#
# ### 3. Main Challenges
# - **Learning Resources & Environment** – You noted concerns about the overall quality of the school’s learning environment, suggesting room for improvement in how resources are organized and presented.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Make sure all course assets are uploaded early so everyone can prepare and review at their own pace. | • Upload slides, video recordings, reading lists, and practice exercises at the start of each module.<br>• Use a central LMS folder with clear naming conventions. |
# | **Increase learner engagement** | Keep the high energy you already bring by adding interactive elements that sustain interest. | • Insert short quizzes or polls after key topics.<br>• Use brief games, case‑studies, or practical tasks that require collaboration.<br>• Facilitate discussion boards or live chat sessions. |
# | **Improve learning resources and environment** | Enhance the physical and digital study space so it supports active learning. | • Organise digital files logically (e.g., by week or topic).<br>• Regularly update outdated resources.<br>• Ensure classroom seating, lighting, and Wi‑Fi are comfortable for group work.<br>• Provide quick guides on how to use the LMS tools. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Upload all current module materials (slides, videos, readings) to the LMS before the first live session. | Students can preview content and come prepared. |
# | 2 | Add a 5‑minute quiz at the end of each lecture and post the results on the discussion board. | Immediate feedback and higher participation. |
# | 3 | Review the digital folder structure; rename files for clarity and remove any obsolete files. | Easier navigation for all learners. |
# | 4 | Survey classmates about the classroom setup (seating, lighting, noise) and propose one small improvement (e.g., rearrange seats or add a whiteboard). | A more comfortable environment that supports active collaboration. |
#
# By following these steps, you’ll reinforce the strengths you already demonstrate and address the key challenge of the learning environment, making your blended courses more effective for yourself and your peers. Keep leveraging your active engagement—your involvement is a major driver of success!

# %% [markdown]
# ## Student ID: `e20240157`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240157*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Overall attitude:** Positive about developing digital skills; concerned about understanding material without direct instructor help.
#
# ### 2. Main Strengths
# - **Digital Skills Development** – You see value in improving your digital abilities and are motivated to use online tools for learning.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You may feel isolated when learning remotely and prefer more direct contact with instructors or peers.
# - **Learning Difficulty & Clarity** – Understanding lessons without immediate instructor support can be hard, leading to confusion.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Digital Skill** | • Attend short tutorials on the LMS, online research tools, and educational apps. <br>• Use guided practice sessions to become comfortable with digital resources. |
# | **Interaction** | • Join scheduled Q&A or live chat sessions with the lecturer. <br>• Participate in small‑group discussion boards or peer‑collaboration projects. <br>• Request quicker feedback on assignments when possible. |
# | **Learning Support** | • Look for recorded video explanations and step‑by‑step guides that accompany each topic. <br>• Use clear, written instructions and example problems provided by the instructor. <br>• Keep a personal checklist of key concepts to review after each lesson. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Goal | Concrete Steps |
# |------|------|----------------|
# | 1 | Get comfortable with the LMS | Watch the LMS orientation video; complete a practice activity. |
# | 2 | Boost interaction | Join the first live Q&A session; post one question on the discussion board. |
# | 3 | Clarify learning material | Download the recorded lecture for a topic you found difficult; follow the step‑by‑step guide and complete the accompanying practice quiz. |
# | 4 | Review & reflect | Summarize what you’ve learned about digital tools, interaction, and support resources; set a personal goal for the next month (e.g., “Ask for feedback within 48 h of submission”). |
#
# ---
#
# **Remember:** These suggestions are tailored to your segment and the strengths and challenges you shared. Engaging with the recommended activities will help you build digital confidence, stay connected with peers and instructors, and gain clearer guidance throughout your courses. Good luck!

# %% [markdown]
# ## Student ID: `e20240652`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240652*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and actively participate in class, showing a strong willingness to use both online and face‑to‑face formats.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You already recognize the benefit of studying online in the morning to avoid traffic and save energy, which helps you stay organized and punctual.
#
# ### 3. Main Challenges
# - **Learning Resources & Environment** – You would like a more convenient and comfortable learning setting, especially for morning virtual sessions, to keep the experience fresh and effective.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | Why It Helps |
# |----------------|----------------------|--------------|
# | **Improve learning resources and environment** | • Keep your digital files, notes, and lecture slides well‑organized in one folder or learning platform.<br>• Choose a quiet, well‑lit study spot at home for morning online classes.<br>• If possible, adjust your chair, desk, or lighting to make the space comfortable. | A tidy, comfortable environment reduces distractions and makes the morning online sessions more productive. |
# | **Support self‑paced learning** | • Use recorded lectures and make a weekly learning plan that fits your morning‑online / afternoon‑in‑person schedule.<br>• Review key concepts at your own speed before the next class.<br>• Take advantage of any downloadable resources the university provides. | Having access to recordings and clear weekly paths lets you reinforce material when you’re most alert, reinforcing your strong time‑management habit. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Set up a dedicated “Morning Study” folder on the university LMS; upload today’s lecture slides and any recordings. |
# | **Tuesday** | Arrange a quiet corner at home (desk, lamp, headphones); test internet speed to ensure smooth streaming. |
# | **Wednesday** | Create a simple weekly learning path: list topics, allocate 30 min review slots after each morning session. |
# | **Thursday** | Record a short summary of today’s in‑person class; upload it to your folder for later review. |
# | **Friday** | Reflect on the week: note any distractions or comfort issues and adjust your study space accordingly. |
# | **Weekend** | Review recorded lessons at a relaxed pace; prepare any questions for the upcoming afternoon class. |
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By fine‑tuning your learning environment and using self‑paced resources, you’ll make the most of both online mornings and in‑person afternoons. Keep experimenting with what works best for you, and adjust the plan as needed. Good luck!

# %% [markdown]
# ## Student ID: `e20241315`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241315*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Moderately Engaged (Passive) Learners” segment. Your open‑ended response highlights two points:
#
# * **Strength:** You appreciate having flexible time to study from home.
# * **Challenge:** You sometimes experience internet or connectivity problems that affect your learning.
#
# Because the open‑ended input is brief, the recommendations below are primarily based on the characteristics of your segment together with the themes you identified (flexibility, convenience, technical issues, and learning environment).
#
# ---
#
# ### 2. Main Strengths
# | Theme | What it means for you |
# |-------|-----------------------|
# | **Flexibility & Time Management** | You value the ability to study when it fits your schedule, especially from home. |
# | **Learning Convenience & Effectiveness** | You recognize that studying in a comfortable setting can help you learn well. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What it means for you |
# |-------|-----------------------|
# | **Internet & Technical Issues** | Unreliable connectivity can interrupt online activities. |
# | **Learning Resources & Environment** | The quality of study spaces and materials may need improvement. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|-----------------|
# | **Improve learning effectiveness** – Combine online review materials with in‑person explanations, practice, and feedback. | Gives you the best of both worlds: the convenience of online content plus the clarity of face‑to‑face guidance. |
# | **Improve learning resources and environment** – Organize materials clearly, keep resources up‑to‑date, and create comfortable study spaces. | Makes the time you spend studying at home more productive and less stressful. |
# | **Support self‑paced learning** – Access recorded lessons, follow weekly learning paths, and review materials whenever you need. | Aligns with your preference for flexible, at‑your‑own‑pace study. |
# | **Improve technical access and reliability** – Ensure stable internet (e.g., campus Wi‑Fi hotspots or offline downloads), provide clear platform instructions, and offer quick technical support. | Reduces interruptions caused by connectivity problems. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action | Expected Benefit |
# |----------|--------|------------------|
# | **Day 1–2** | Check if the university offers offline download options for lecture videos and reading materials. | You can study even when the internet is spotty. |
# | **Day 3–5** | Locate a quiet, well‑lit study spot at home or on campus; set up a comfortable chair and minimal distractions. | Improves focus and learning effectiveness. |
# | **Week 1** | Watch a recorded lecture, then attend the related in‑person session for explanation and feedback. | Combines online convenience with face‑to‑face clarity. |
# | **Week 2** | Follow the weekly learning path provided by the instructor; note any technical issues and contact the help desk promptly. | Keeps you on track and ensures technical problems are resolved quickly. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset. By pairing it with reliable technical support and well‑organized resources, you can boost both the quality and efficiency of your learning. If you encounter any difficulties, reach out to your course’s technical support team or academic advisor for assistance. Good luck!

# %% [markdown]
# ## Student ID: `e20220867`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220867*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners who attend classes but tend to stay passive, benefit from more interaction, clearer guidance, and reliable technical access.
#
# *Because the open‑ended strengths response was “i have no idea,” the profile and recommendations rely mainly on the characteristics of your segment.*
#
# ---
#
# ### 2. Main Strengths
# - No specific strengths were reported.
# - As a moderately engaged learner, you already show enough baseline participation to build on with targeted support.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You would like more timely and clear communication from the teacher.
# - **Internet & Technical Issues:** Reliable Wi‑Fi and smooth platform use are important for you.
# - **Learning Difficulty & Clarity:** You need clearer instructions and course materials before class.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | • Join short Q&A or “office‑hour” chats after each lecture.<br>• Participate in small‑group discussion boards or peer‑collaboration tasks.<br>• Request quicker feedback on assignments. | Increases engagement and gives you the chance to ask questions when you need clarification. |
# | **Learning Support** | • Ask the instructor for step‑by‑step guides or recorded walkthroughs of key concepts.<br>• Use any provided examples or sample problems before the live session.<br>• Keep a personal checklist of what you need to understand for each topic. | Clearer instructions and examples reduce confusion and make self‑study more effective. |
# | **Technical Access** | • Test your internet connection before class; if it’s unstable, consider campus Wi‑Fi hotspots or a mobile data backup.<br>• Download lecture slides or videos in advance so you can study offline.<br>• Keep the platform’s help page bookmarked and contact technical support early if problems arise. | Reliable access prevents missed content and reduces stress during live sessions. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Identify a reliable Wi‑Fi spot on campus or arrange a mobile hotspot. |
# | **Day 2** | Download this week’s lecture materials (slides, videos) for offline review. |
# | **Day 3** | Post one question on the course discussion board about a concept you find unclear. |
# | **Day 5** | Attend a 15‑minute Q&A session (or schedule a quick chat with the lecturer). |
# | **Day 7** | Review the recorded explanation provided by the instructor; note any remaining doubts. |
# | **Day 10** | Join a peer‑study group for a short collaborative exercise. |
# | **Day 12** | Request feedback on your latest assignment and note any suggestions. |
# | **Day 14** | Reflect: Did the extra interaction and clearer resources help you understand the material better? Adjust the plan as needed. |
#
# ---
#
# **Keep in mind:** Small, consistent steps—asking questions, using clear resources, and ensuring stable internet—will gradually shift your learning from passive to more active and confident. If you encounter any new obstacles, reach out to your lecturer or the technical support team; they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `e20240521`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240521*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive in a blended environment because it gives you **flexibility**, **easy access to materials**, and the chance to manage your own time. You value being able to study both online and in‑class, and you appreciate having recorded lectures and resources available whenever you need them.
#
# You also notice a few hurdles: occasional **technical problems** (unstable internet, platform difficulties) and moments when it’s hard to stay focused online. You would like clearer instructions, more interactive activities, and stronger technical support.
#
# ---
#
# ### 2. Main Strengths
# | Strength theme | What you said |
# |----------------|---------------|
# | Access to Learning Materials | You like that blended learning lets you reach slides, videos, and other resources anytime. |
# | Flexibility & Time Management | The mix of online and face‑to‑face classes helps you become more independent and manage your schedule. |
# | Learning Convenience & Effectiveness | Having both formats makes learning feel more effective for you. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge theme | What you said |
# |-----------------|---------------|
# | Interaction & Communication | Want more interaction and quicker feedback. |
# | Internet & Technical Issues | Unstable connection and platform difficulties. |
# | Learning Difficulty & Clarity | Need clearer instructions and examples. |
# | Motivation & Self‑Discipline | Staying focused online can be tough. |
#
# ---
#
# ### 4. Personalized Recommendations
# (These are drawn directly from the rule‑based suggestions for your segment.)
#
# | Area | How to improve it |
# |------|-------------------|
# | **Content Access** | Instructors should **upload slides, videos, references, exercises, and other course materials early** so you can plan ahead. |
# | **Interaction** | Add **Q&A sessions, group discussions, peer collaboration, and faster lecturer feedback** to keep you engaged. |
# | **Learning Effectiveness** | Combine **online review materials with in‑person explanations, practice, and feedback** to reinforce concepts. |
# | **Learning Environment** | Organise resources clearly, keep them up‑to‑date, and improve study spaces and classroom comfort. |
# | **Learning Support** | Provide **clearer instructions, concrete examples, recorded explanations, and step‑by‑step guides**. |
# | **Motivation** | Use **weekly check‑ins, reminders, progress tracking, and structured study schedules** to sustain focus. |
# | **Self‑Paced Learning** | Offer **recorded lessons, weekly learning paths, and materials you can review at your own speed**. |
# | **Technical Issues** | Ensure **stable internet access, offline material options, clear platform guides, and responsive technical support**. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Who’s responsible |
# |------|--------|-------------------|
# | 1 | Check that all lecture slides and videos are uploaded to the LMS at least 2 days before class. | Lecturer / Course team |
# | 2 | Join a weekly online Q&A session and a small‑group discussion forum. | You (participate) |
# | 3 | Set a personal study schedule: 30 min review of recorded lessons + 1 hr in‑class practice each week. Track progress in a simple spreadsheet. | You |
# | 4 | Test the campus Wi‑Fi or arrange a reliable hotspot; note any platform issues and contact tech support promptly. | You + IT support |
#
# Follow these steps, and you’ll keep leveraging the flexibility you enjoy while reducing the technical and motivational bumps you’ve identified. Good luck, and keep staying actively engaged!

# %% [markdown]
# ## Student ID: `M080312`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080312*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** Flexibility and the ability to manage your time efficiently.
# - **Current challenge:** Unreliable internet connection that disrupts engagement, especially in longer courses.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate learning formats that let you fit study around other commitments and review material when it suits you.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Loss of connection reduces your ability to stay engaged, particularly for extended online sessions.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | How to use it |
# |----------------|------------------|---------------|
# | **Support self‑paced learning** | Matches your need for flexibility and lets you control the speed of study. | • Use recorded lectures and weekly learning paths.<br>• Review notes and videos at any time that fits your schedule. |
# | **Improve technical access and reliability** | Reduces the disruption caused by connectivity problems, keeping you engaged. | • Download offline versions of readings and videos when you have a stable connection.<br>• Follow the platform’s clear setup guide and contact technical support early if issues arise.<br>• If possible, use campus Wi‑Fi or a reliable hotspot for longer sessions. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the “Download for offline use” option for your current course materials. |
# | **Day 3–5** | Create a personal weekly learning path: list which recorded lessons you will watch each day. |
# | **Day 6** | Test your internet connection during a live session; note any drop‑outs. |
# | **Day 7** | If problems persist, contact the university’s technical support (provide screenshots of the issue). |
# | **Day 8–10** | Use offline videos to complete at least one full module without needing a live connection. |
# | **Day 11–14** | Review your progress and adjust the weekly path if needed; keep a brief log of any technical hiccups and how they were resolved. |
#
# By following this plan, you’ll keep the flexibility you value while minimizing the impact of internet interruptions. Feel free to reach out to your course coordinator or the tech help desk for any additional support. Good luck!

# %% [markdown]
# ## Student ID: `e20241255`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "motivation", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241255*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can mix online convenience with face‑to‑face interaction. You are motivated, but you notice that online notifications can pull your focus and that unreliable internet makes studying stressful.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You appreciate being able to attend classes online instead of traveling long distances, which saves time and makes learning feel easier.
#
# ---
#
# ### 3. Main Challenges
# 1. **Internet & Technical Issues** – Slow or unstable Wi‑Fi disrupts your focus and reduces motivation.
# 2. **Learning Resources & Environment** – You need a smooth, comfortable study space and clear, up‑to‑date materials.
# 3. **Motivation & Self‑Discipline** – Online notifications and connectivity problems sometimes cause you to lose focus.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Learning Effectiveness** | Pair the online review videos or slides you use with brief in‑person (or live‑online) sessions where you can ask questions, practice, and receive feedback. |
# | **Learning Environment** | Keep your study materials organized (e.g., a single folder for each course). Choose a quiet, comfortable spot, and make sure your desk is set up for both screen work and handwritten notes. |
# | **Motivation & Self‑Discipline** | Set a weekly schedule with specific study blocks. Use a simple tracker (e.g., a checklist or app) and schedule a short check‑in with yourself or a peer each week to review progress and adjust goals. |
# | **Technical Access** | Request high‑speed campus Wi‑Fi or a reliable hotspot for home use. Download lecture recordings or PDFs in advance so you can study offline if the connection drops. Keep a quick‑reference guide for the learning platform and know how to contact tech support. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify a quiet study space and arrange your materials (folders, digital files). |
# | **Day 3** | Test your internet speed; if it’s low, apply for campus Wi‑Fi access or arrange a hotspot. |
# | **Day 4** | Download this week’s lecture recordings for offline use. |
# | **Day 5** | Create a simple weekly schedule (e.g., Mon 9‑11 am review, Wed 2‑4 pm practice). |
# | **Day 6** | Set up a progress tracker (paper checklist or free app). |
# | **Day 7** | Schedule a 10‑minute self‑check‑in to review what you completed and plan the next week. |
# | **Day 8–14** | Follow the schedule, use the offline materials when needed, and note any technical issues to report to support. |
#
# Stay proactive with the schedule and keep your environment and tech ready—this will let your high engagement turn into even stronger results. Good luck!

# %% [markdown]
# ## Student ID: `e20240533`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240533*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Highly Engaged (Active) Learners” segment. This group typically participates actively in class, seeks out resources, and values flexible ways to study material.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You already make good use of recordings to review lessons you missed or want to revisit.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – You noted that reliable Wi‑Fi is essential for completing coursework.
# - **Learning Resources & Environment** – You would like the university to improve the overall study environment and resource availability.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|-----------------------|
# | **Strengthen access to learning materials** (content_access) | Instructors will upload slides, videos, reference links, and exercises **early** in the week so you can download or stream them whenever you need. |
# | **Improve learning resources and environment** (learning_environment) | Course pages will be organized clearly, with up‑to‑date resources. Study spaces (both physical and virtual) will be reviewed to ensure they are comfortable and conducive to focused work. |
# | **Improve technical access and reliability** (tech_issue) | The university will provide more stable Wi‑Fi options, offer offline versions of key materials, give clear instructions for using the learning platform, and make technical support readily available. |
#
# These suggestions are drawn directly from the evidence you provided and from the typical needs of your learner segment.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action |
# |------|--------|
# | **1** | Check the course portal for newly uploaded slides and videos; download any files you may need offline. |
# | **2** | Locate the designated study area on campus (or a quiet spot at home) and test the Wi‑Fi connection. Report any connectivity problems to the IT help desk. |
# | **3** | Use the recorded lessons to review a topic you found challenging; note any gaps in the provided resources and share feedback with the instructor. |
# | **4** | Attend a short workshop (or watch a tutorial) on how to access offline materials and troubleshoot common platform issues. |
# | **Ongoing** | Keep a list of resources you find most helpful and share it with classmates to build a supportive learning community. |
#
# By following these steps, you can make the most of the blended‑learning environment while addressing the technical and resource challenges you highlighted. Keep leveraging recordings and the upcoming improved access—your active engagement will continue to drive success.

# %% [markdown]
# ## Student ID: `e20220283`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20220283
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You appreciate the **flexibility** of blended courses and find it easy to access learning resources.
# - These strengths align with the themes of *Access to Learning Materials*, *Flexibility & Time Management*, and *Learning Convenience & Effectiveness*.
#
# **Main Challenges**
# - You note that the university’s **Wi‑Fi reliability** and **classroom comfort (air‑conditioning)** could be better.
# - These concerns fall under the themes of *Internet & Technical Issues* and *Learning Resources & Environment*.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps you |
# |------|------------|------------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** in the semester. | Gives you the resources you value most, so you can study when it fits your schedule. |
# | **Learning Effectiveness** | Pair online review materials with **in‑person explanations, practice activities, and timely feedback**. | Reinforces concepts you review on your own and makes classroom time more purposeful. |
# | **Learning Environment** | Keep materials **well‑organized**, update resources regularly, and improve study spaces (e.g., comfortable, air‑conditioned rooms). | A tidy, comfortable environment supports the passive learning style you prefer. |
# | **Self‑Paced Learning** | Provide **recorded lessons**, a **weekly learning path**, and downloadable materials you can revisit at any time. | Lets you control the pace of study, matching your need for flexibility. |
# | **Technical Issues** | Ensure **stable internet access**, offer **offline versions** of key content, give clear platform instructions, and provide quick **technical support**. | Reduces the frustration caused by connectivity problems and keeps you focused on learning. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# | Week | Action | How to Implement |
# |------|--------|-------------------|
# | 1 | Check the course portal for any **early‑uploaded** slides or videos. If missing, request them from the instructor. | Send a brief email or post in the forum asking for the materials. |
# | 2 | Download all available resources for **offline** use (PDFs, videos). | Use the “download” button or ask the tech support team for help. |
# | 3 | Follow the **weekly learning path** provided by the instructor; watch recorded lessons before attending the live session. | Allocate a regular 30‑minute slot each day for review. |
# | 4 | Attend the next in‑person class prepared with questions; use the **feedback** time to clarify doubts. | Bring a list of 2–3 specific questions based on your review. |
# | Ongoing | Report any **Wi‑Fi or classroom comfort** issues to the campus facilities office and request technical assistance when needed. | Use the campus service portal or contact the help desk. |
#
# These steps are tailored to your strengths in flexibility and resource access while addressing the technical and environmental challenges you highlighted. By following the plan, you can make the most of blended learning and improve your overall study experience.

# %% [markdown]
# ## Student ID: `e20211534`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20211534
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - **Flexibility & Time Management:** You appreciate how blended learning lets you balance personal and academic life, study independently, and research topics at your own pace.
#
# **Main Challenges**
# - **Interaction & Communication:** You feel there is limited encouragement and social involvement with peers.
# - **Internet & Technical Issues:** Unstable or slow internet connections hinder your study experience.
# - **Learning Resources & Environment:** You would like clearer organization of materials and more comfortable study spaces.
#
# **Personalized Recommendations**
#
# | Area | What the university can do for you | How you can take advantage |
# |------|------------------------------------|----------------------------|
# | **Interaction** | Add regular Q&A sessions, group discussions, and peer‑collaboration activities; ensure lecturers give quicker feedback. | Join the scheduled discussion groups, ask questions during Q&A, and partner with classmates for mini‑projects. |
# | **Learning Environment** | Organize course materials clearly, keep resources up‑to‑date, improve physical study spaces, and enhance classroom comfort. | Use the well‑structured material folders, give feedback on resource usefulness, and choose the upgraded study areas for focused work. |
# | **Self‑Paced Learning** | Provide recorded lectures, weekly learning paths, and reusable materials you can review anytime. | Create a personal weekly schedule using the provided learning paths and revisit recorded lessons when you need a refresher. |
# | **Technical Access** | Offer stable campus Wi‑Fi hotspots, offline downloadable content, clear platform guides, and responsive tech support. | Download offline copies of essential readings before a weak‑connection day, and contact tech support early if you encounter issues. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# 1. **Week 1:**
#    - Register for the upcoming Q&A session in your main course.
#    - Download the first week’s recorded lectures for offline use.
#
# 2. **Week 2:**
#    - Join a peer‑study group announced in the course forum.
#    - Test the campus Wi‑Fi hotspot location and note the strongest signal spot.
#
# 3. **Week 3:**
#    - Review the newly organized material folder; mark any resources that need clarification for the instructor.
#    - Follow the weekly learning path and set 30‑minute self‑study blocks each day.
#
# 4. **Week 4:**
#    - Provide brief feedback on the discussion format and resource layout via the course survey.
#    - Contact technical support if any connectivity problems persist, and request offline copies of any missing content.
#
# By focusing on increased interaction, a clearer learning environment, self‑paced resources, and reliable technical access, you can turn your strong engagement into an even more rewarding blended‑learning experience. Keep leveraging your flexibility, and use the support options above to stay connected and productive.

# %% [markdown]
# ## Student ID: `e20220912`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "interaction", "learning_effectiveness", "learning_environment", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220912*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can control the pace of study and enjoy interactive, hands‑on activities. You value flexibility and find learning more effective when it is convenient and engaging. At the same time, you notice that self‑discipline can slip and that you sometimes miss richer interaction with peers and instructors. You also mentioned occasional technical hiccups and a desire for high‑quality online materials.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you said |
# |-------|---------------|
# | **Flexibility & Time Management** | “I can learn at my own pace…” |
# | **Learning Convenience & Effectiveness** | “…better understanding and more interactive learning.” |
# | **Student Engagement** | Positive attitude toward active learning. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you said |
# |-------|---------------|
# | **Interaction & Communication** | Limited interaction with others. |
# | **Motivation & Self‑Discipline** | “Lack of self‑discipline.” |
# | **Internet & Technical Issues** | Need for reliable technical support. |
# | **Learning Resources & Environment** | Desire for high‑quality online materials and a balanced mix of online/classroom activities. |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How to apply it (practical steps) |
# |----------------|------------------------------------|
# | **Increase learner engagement** | • Use short quizzes or game‑based checkpoints after each module.<br>• Participate in practical tasks and class‑based discussions. |
# | **Increase interaction and communication** | • Join scheduled Q&A sessions and small‑group discussions.<br>• Collaborate on short peer projects; ask the lecturer for quicker feedback. |
# | **Improve learning effectiveness** | • Review recorded lectures before coming to class, then use face‑to‑face time for explanations, practice, and feedback. |
# | **Improve learning resources and environment** | • Access clearly organized folders on the LMS; use the updated study‑space guidelines provided by the university.<br>• Choose a quiet, comfortable spot for online work. |
# | **Support motivation and self‑discipline** | • Set a weekly study schedule and check‑in with a study buddy or tutor.<br>• Use the platform’s progress tracker and enable reminder notifications. |
# | **Support self‑paced learning** | • Watch recorded lessons at your own speed and revisit them as needed.<br>• Follow the weekly learning path outlines posted by the course team. |
# | **Improve technical access and reliability** | • Test your internet connection before live sessions; keep offline copies of essential PDFs.<br>• Use the university’s tech‑support helpdesk for any platform issues. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Review the week’s learning path; download any required PDFs for offline use. |
# | **Tue** | Attend the live Q&A session; ask at least one question. |
# | **Wed** | Complete a short quiz on the topic covered; note any gaps. |
# | **Thu** | Meet (in‑person or virtually) with a peer for a 30‑min discussion of the material. |
# | **Fri** | Set a 10‑minute reminder to log progress in the LMS tracker. |
# | **Sat** | Test internet speed; contact tech support if needed. |
# | **Sun** | Reflect on what worked, adjust the study schedule for next week. |
#
# Follow this plan, tweak it as you learn what works best for you, and you’ll keep leveraging your strong engagement while strengthening discipline, interaction, and technical reliability. Good luck!

# %% [markdown]
# ## Student ID: `e20241344`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241344*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive on flexibility and like to personalize your study routine. You value learning that fits your schedule and helps you stay effective. You have identified **time‑management for online work** and the need for **clearer weekly tasks and more check‑ins** as areas to improve.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you appreciate being able to choose when and where you study.
# - **Learning Convenience & Effectiveness** – you seek methods that make learning easy and productive.
#
# ---
#
# ### 3. Main Challenges
# - **Assessment & Workload** – managing deadlines and the amount of online work can feel unclear.
# - **Learning Difficulty & Clarity** – you would benefit from more explicit instructions and regular feedback.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Pair the online review materials you already use with short, in‑person explanation sessions, practice activities, and feedback. | Attend the scheduled tutorial labs or office‑hour mini‑sessions that follow each online module. |
# | **Improve clarity and learning support** | Get clearer instructions, concrete examples, and step‑by‑step guides for each task. | Use the recorded explanations and detailed guides posted on the LMS; refer to them before starting an assignment. |
# | **Support self‑paced learning** | Keep the freedom to study when it suits you while having a structured path. | Follow the weekly learning path provided by the course, and revisit recorded lessons as needed. |
# | **Manage workload and assessment pressure** | Reduce uncertainty about deadlines and balance online tasks with face‑to‑face work. | Check the consolidated weekly schedule (online + in‑person) posted each Monday; use the checklist to track completed items and ask for quick check‑ins during class. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the weekly learning path and note all deadlines in your calendar. |
# | **Tuesday** | Watch the recorded lesson for the upcoming topic; take notes on key steps. |
# | **Wednesday** | Attend the in‑person explanation session; ask at least one clarification question. |
# | **Thursday** | Complete the first practice activity; submit for feedback. |
# | **Friday** | Use the step‑by‑step guide to start the assignment; mark any unclear points for a quick check‑in. |
# | **Weekend** | Review recorded explanations again if needed; update your progress checklist. |
# | **Next Monday** | Attend a brief check‑in (office hour or study‑group) to confirm you’re on track and adjust the plan if necessary. |
#
# Follow this cycle each week, adapting the timing to fit your personal schedule. By combining flexible online resources with targeted in‑person support and clear workload planning, you’ll strengthen both your learning effectiveness and your confidence in managing assignments.

# %% [markdown]
# ## Student ID: `e20220229`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220229*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key traits:** enjoys studying anywhere and anytime (flexibility & time‑management).
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You can study in any location and at any time, which lets you fit learning into a busy schedule.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline:** You sometimes get distracted by social media (e.g., Facebook, TikTok, games) while studying.
#
# ### 4. Personalized Recommendations
#
# | Focus | What the recommendation suggests | How it helps you |
# |-------|----------------------------------|------------------|
# | **Motivation & Self‑Discipline** | • Weekly check‑ins (e.g., a short 5‑minute reflection or a quick chat with a tutor). <br>• Automated reminders for upcoming tasks. <br>• Simple progress‑tracking dashboard. <br>• A structured study schedule that blocks dedicated “focus windows.” | Keeps you accountable, reduces the urge to switch to social media, and makes progress visible. |
# | **Self‑Paced Learning** | • Access to recorded lectures and tutorials you can replay. <br>• Weekly learning paths that outline what to cover each week. <br>• Downloadable resources (slides, notes) for offline review. | Lets you use your flexibility to study when you’re most alert, while still following a clear roadmap. |
#
# These suggestions are drawn directly from the rule‑based recommendations for the tags **motivation** and **self_paced**.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Set up** | • Choose a digital tool (e.g., Google Calendar, Trello) for a weekly study schedule. <br>• Subscribe to the course’s recorded lesson library. |
# | **Week 1 – Motivation boost** | • Set a daily 5‑minute check‑in reminder (e.g., “Did I stay on task today?”). <br>• Create a simple progress tracker (check off completed modules). |
# | **Week 2 – Review & Adjust** | • Review your progress dashboard; note any moments of distraction. <br>• Adjust your schedule: add short “focus blocks” (25 min) followed by a 5‑min break (no social media). |
# | **Ongoing** | • Keep weekly check‑ins with a peer or tutor. <br>• Continue using recorded lessons to reinforce concepts at your own pace. |
#
# ---
#
# **Remember:** Your ability to study anywhere is a strong asset. By pairing that flexibility with brief, regular check‑ins and a clear, self‑paced roadmap, you’ll stay motivated and make steady progress toward your goals. Good luck!

# %% [markdown]
# ## Student ID: `e20210434`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "learning_effectiveness", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210434*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the ability to study independently, at your own speed, and to explore concepts deeply. You appreciate having easy access to course materials and recognize that self‑discipline is key to making the most of blended learning.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You see early availability of slides, videos, and exercises as essential for self‑study.
# - **Flexibility & Time Management** – You like being able to learn at your own pace and to pause for reflection.
# - **Learning Convenience & Effectiveness** – You believe blended formats help you grasp material better than fast‑paced lectures.
# - **Student Engagement** – You are motivated to stay active and participate when the content is interactive.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – You note that staying disciplined is a personal responsibility and can be a hurdle without structure.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Get all slides, videos, references, and exercises early so you can study whenever you’re ready. | Instructors should upload the full set of resources at the start of each module. |
# | **Increase learner engagement** | Keep your active participation high with interactive elements. | Use quizzes, short games, practical tasks, and discussion forums built into the course platform. |
# | **Improve learning effectiveness** | Blend online review with face‑to‑face explanation and feedback for deeper understanding. | Attend scheduled in‑person sessions that focus on applying concepts you’ve reviewed online. |
# | **Support motivation and self‑discipline** | Build routine and track progress to stay on course. | Set up weekly check‑ins, automated reminders, and a personal progress dashboard; follow a structured study schedule. |
# | **Support self‑paced learning** | Continue to learn when it suits you best, revisiting material as needed. | Access recorded lectures and weekly learning paths that let you review content at any time. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Review the course syllabus and locate all uploaded materials (slides, videos, exercises). Create a personal folder for easy access. |
# | **2** | Set a weekly study schedule (e.g., 2 hrs Mon/Wed, 3 hrs Fri). Add reminders to your calendar and mark progress in the course dashboard. |
# | **3** | Complete the first set of interactive quizzes and join a discussion thread on a topic you found challenging. |
# | **4** | Attend the first in‑person session, bring questions from your online review, and ask for feedback on your practice tasks. Reflect on what worked and adjust your schedule if needed. |
#
# By following these steps, you’ll leverage your strong engagement while adding the structure needed to keep motivation high. Happy learning!

# %% [markdown]
# ## Student ID: `e20240499`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240499*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from clear structure, regular updates, and a mix of self‑paced and guided activities.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You are good at self‑learning and can quickly relearn or catch up on material you missed.
#
# ### 3. Main Challenges
# - **Learning Resources & Environment:** You would like course materials to be updated more frequently and made available as early as possible, and you value a well‑organized study space.
#
# ### 4. Personalized Recommendations
#
# | Focus | Recommendation (based on rule‑based guidance) |
# |-------|-----------------------------------------------|
# | **Learning Effectiveness** | Combine the online review materials you already use with short, in‑person sessions that provide explanations, guided practice, and immediate feedback. This blend reinforces what you study on your own and helps you apply concepts more confidently. |
# | **Learning Environment** | Ensure that all course resources are clearly organized and updated promptly. Create a dedicated, comfortable study area (e.g., a quiet desk with good lighting) and use the latest versions of lecture slides, notes, and practice problems. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Identify the online review modules for your current course. Schedule two 30‑minute face‑to‑face (or live‑online) sessions with a tutor or study group to discuss key concepts and get feedback. |
# | **2** | Review the course’s material repository. Flag any outdated files and request updates from the instructor or teaching assistant. |
# | **3** | Set up a consistent study space: tidy desk, good lighting, minimal distractions. Keep all updated resources in one folder (digital or physical). |
# | **4** | Repeat the blend of self‑study + short guided sessions for the next topic. Reflect on whether the updated resources helped you stay on track. |
#
# By following this plan, you’ll strengthen your self‑learning habits while ensuring the learning environment supports timely, effective study. Good luck!

# %% [markdown]
# ## Student ID: `M080210`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080210*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are classified as a **Highly Engaged (Active) Learner**. You enjoy a flexible learning mood and appreciate having materials provided early, which helps you stay motivated and manage your time effectively.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value having slides, videos, and other resources available early in the course.
# - **Flexibility & Time Management** – Your flexible approach keeps the learning experience lively and prevents boredom.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Slow university internet can hinder your study flow.
# - **Learning Resources & Environment** – Some courses lack sufficient material, and the study environment could be better organized.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Instructors should upload slides, videos, references, and exercises **well before class**. | Gives you the early resources you like and supports your active engagement. |
# | **Improve learning resources and environment** | Course pages should be clearly organized; study spaces should be comfortable and equipped with needed tools. | Reduces the feeling of missing material and creates a smoother, more productive study setting. |
# | **Support self‑paced learning** | Provide **recorded lessons** and a **weekly learning path** that you can review at any time. | Lets you use your flexibility to revisit concepts when the internet is slow or you need extra practice. |
# | **Improve technical access and reliability** | Offer **offline downloadable files**, clear instructions for the learning platform, and quick technical support. | Mitigates the impact of slow campus Wi‑Fi and ensures you can keep learning without interruption. |
#
# ### 5. Short Action Plan
# | Week | Action | How to do it |
# |------|--------|--------------|
# | **1** | Check the course portal for any **pre‑uploaded materials** (slides, videos). | If missing, request them from the instructor or teaching assistant. |
# | **2** | Download all available resources for offline use. | Use the university’s VPN or library computers if campus Wi‑Fi is slow. |
# | **3** | Follow the **weekly learning path** (if provided) or create your own schedule using the downloaded content. | Allocate specific times for review and practice. |
# | **4** | Evaluate your study environment – ensure it is quiet, organized, and has necessary tools. | If needed, book a study room or adjust your workspace. |
# | **Ongoing** | Report any persistent **technical issues** to the IT helpdesk and ask for alternative access options. | Keep a log of problems to share with support staff. |
#
# ---
#
# **Keep leveraging your high engagement and flexibility**—by securing reliable access to materials and a stable technical environment, you’ll be able to maintain your active learning style and succeed in all your courses. If you need further assistance, your academic advisor and the university’s IT support are ready to help.

# %% [markdown]
# ## Student ID: `e20240484`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20240484
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You appreciate how blended learning gives you new digital experiences and lets you study flexibly without spending time traveling.
# - Your comments highlight strong **digital‑skill development**, **flexibility & time‑management**, and overall **learning convenience & effectiveness**.
#
# **Main Challenges**
# - You note that unreliable internet can make it hard to ask teachers questions when you need help.
# - This points to difficulties with **interaction & communication**, **technical/internet issues**, and occasional **learning clarity**.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Develop digital learning skills** | Use short guides or short videos that walk you through the LMS, online research tools, and any educational apps you use. | Strengthens the digital skills you already value and makes navigation smoother. |
# | **Increase interaction and communication** | Join scheduled live Q&A sessions, participate in small‑group discussion boards, and request quicker feedback from lecturers. | Gives you reliable ways to ask questions when internet is spotty and keeps you actively engaged. |
# | **Improve learning effectiveness** | Pair the online review materials you already use with brief in‑person or live‑online explanations, followed by practice exercises and feedback. | Combines the convenience you like with deeper understanding. |
# | **Improve clarity and learning support** | Look for recorded step‑by‑step explanations, clear examples, and concise written instructions for each topic. | Provides a reference you can revisit when connectivity problems limit real‑time help. |
# | **Support self‑paced learning** | Follow weekly learning paths that include recorded lectures you can watch anytime, plus optional quizzes to check your progress. | Lets you keep the flexibility you enjoy while ensuring you stay on track. |
# | **Improve technical access and reliability** | Check if the university offers offline downloadable resources, a campus Wi‑Fi hotspot, or a tech‑support help desk. Keep a backup device or mobile data plan for critical sessions. | Reduces the impact of internet interruptions on your ability to ask questions and stay connected. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# | Week | Action |
# |------|--------|
# | 1 | Watch a 10‑minute tutorial on your LMS and bookmark the digital‑tool guide. |
# | 2 | Sign up for a live Q&A session in one of your courses; prepare 2‑3 questions in advance. |
# | 3 | Download the week’s lecture videos and any PDFs for offline study; set a personal deadline to complete the self‑paced path. |
# | 4 | Test the campus Wi‑Fi hotspot or arrange a backup data plan; contact the tech‑support desk to confirm offline material access. |
#
# By building on your strong engagement and addressing the internet‑related hurdles, these steps will help you keep learning flexibly, stay connected with instructors, and make the most of blended learning. Good luck!

# %% [markdown]
# ## Student ID: `e20220969`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220969*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** Learners who prepare by reviewing materials in advance but tend to participate passively in class. They benefit from clear, reliable access to content and a supportive learning environment.
#
# ### 2. Main Strengths
# - **Proactive material preparation** – You like to obtain slides, videos, and references before class so you can do background research ahead of time.
#
# ### 3. Main Challenges
# - **Unreliable internet/technology** – Inconsistent connection quality at your university hampers online activities.
# - **Learning environment issues** – The current study spaces and resource organization do not always support effective learning.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Ensure that all slides, videos, readings, and exercises are uploaded **well before** each class session. | Gives you the time you already like to use for pre‑class research and reduces last‑minute scrambling. |
# | **Improve learning resources and environment** | Materials should be clearly organized (e.g., weekly folders, consistent naming). Study spaces (both physical and virtual) should be comfortable, with good lighting and minimal distractions. | A tidy, predictable environment lets you focus on the content you’ve prepared and supports more active engagement. |
# | **Improve technical access and reliability** | Provide options for **offline access** (downloadable PDFs, videos). Offer clear instructions for the learning platform and a quick‑response technical support channel. Where possible, arrange for campus Wi‑Fi hotspots or loaner devices. | Reduces interruptions caused by unstable connections, allowing you to continue your pre‑class preparation without technical setbacks. |
#
# ### 5. Short Action Plan
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | **1** | Check the course portal for upcoming material uploads. | Set a calendar reminder to review new files **2–3 days before** each class. |
# | **2** | Create a personal folder structure (e.g., “Week 1 – Slides, Videos, Articles”). | Use cloud storage (Google Drive, OneDrive) so you can access files from any device. |
# | **3** | Download all available resources for offline use. | Look for “Download” buttons or ask the instructor for PDF copies. |
# | **4** | Test campus Wi‑Fi or locate a reliable hotspot. | If connection is still spotty, request a loaner laptop/tablet from the university’s IT service. |
# | **5** | Reach out to technical support with any recurring issues. | Use the help‑desk email or chat; keep a log of problems to share with them. |
# | **Ongoing** | Review and reorganize your study space weekly. | Keep the area tidy, ensure good lighting, and have all needed tools (notebook, charger) within reach. |
#
# ---
#
# **Remember:** Your habit of preparing ahead is a strong asset. By securing reliable access to materials, improving your study environment, and addressing technical hurdles, you’ll be able to make the most of that preparation and move toward more active participation in class. If you need further assistance, your university’s learning support and IT services are ready to help. Good luck!

# %% [markdown]
# ## Student ID: `e20210874`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "learning_support", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210874
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You feel “good for course and well focus,” indicating a solid ability to stay on task when materials are clear and available.
# - Your strengths align with **Access to Learning Materials** and **Learning Convenience & Effectiveness**.
#
# **Main Challenges**
# - You find it “hard to follow university schedule,” reflecting difficulty with **Assessment & Workload**, **Learning Difficulty & Clarity**, and the **Learning Resources & Environment**.
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on your segment & responses) |
# |------|-----------------------------------------------|
# | **Content Access** | Ensure that slides, videos, references, exercises and other course materials are uploaded **early** so you can review them at your own pace. |
# | **Learning Effectiveness** | Pair the online review materials with **in‑person explanations, practice activities, and timely feedback** to reinforce understanding. |
# | **Learning Environment** | Keep study resources **well‑organized** and up‑to‑date; seek out quiet, comfortable study spaces on campus or online to improve focus. |
# | **Learning Support** | Ask for **clearer instructions, concrete examples, and step‑by‑step guides** (including recorded explanations) when a concept feels unclear. |
# | **Workload Support** | Work with the instructor to **balance assignments, clarify deadlines**, and make sure online tasks line up with what is covered in class, reducing schedule pressure. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Check the course portal** each morning for newly uploaded slides or videos; download them for offline review.
# 2. **Create a weekly schedule** that blocks specific times for:
#    - Reviewing online materials (30 min)
#    - Attending in‑person sessions (as scheduled)
#    - Completing practice exercises (45 min)
# 3. **Ask the lecturer** for a concise written guide or recorded walkthrough for any topic you find confusing.
# 4. **Set up a tidy study space** (library desk, quiet room, or a dedicated corner at home) with all needed resources within reach.
# 5. **Write down all assignment deadlines** in a digital calendar; set reminders 2 days before each due date to avoid last‑minute pressure.
#
# These steps are designed to build on your existing focus and make the university schedule more manageable. Feel free to adjust the plan as you discover what works best for you. Good luck!

# %% [markdown]
# ## Student ID: `M080108`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** M080108
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value **flexibility, easy access to materials, and improving digital skills**.
# - These strengths align with the themes *Access to Learning Materials*, *Digital Skills Development*, and *Flexibility & Time Management*.
#
# **Main Challenges**
# - You experience **low motivation and a high need for self‑discipline**, and you note that **technical proficiency of lecturers and reliable internet are important**.
# - These challenges match the themes *Interaction & Communication*, *Internet & Technical Issues*, and *Motivation & Self‑Discipline*.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** in the semester. | Gives you the flexibility you need and ensures you can study whenever you have time. |
# | **Digital Skills** | Offer short guides or short videos on how to use the LMS, online research tools, and other educational technologies. | Strengthens the digital skills you already enjoy developing and makes navigation smoother. |
# | **Interaction** | Add regular Q&A sessions, small‑group discussions, and peer‑collaboration tasks; provide quicker feedback from lecturers. | Increases the communication you find lacking and keeps you more connected to classmates and instructors. |
# | **Motivation & Self‑Discipline** | Implement weekly check‑ins, automated reminders, progress‑tracking dashboards, and a suggested study schedule. | Gives you external structure to boost motivation and help you stay on track. |
# | **Self‑Paced Learning** | Record all live lessons and publish a weekly learning path with clear milestones that you can review at your own speed. | Supports your preference for flexibility while still covering all required content. |
# | **Technical Issues** | Ensure stable internet options (e.g., campus Wi‑Fi hotspots), provide offline downloadable resources, clear platform instructions, and a help desk for quick technical support. | Reduces interruptions caused by connectivity problems and makes the online environment more reliable. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Check that all course slides and videos are uploaded to the LMS at least **48 hours before** each class. | Immediate access to materials; easier planning. |
# | 2 | Attend the first **live Q&A** and join a peer discussion group. | More interaction and quicker clarification of doubts. |
# | 3 | Set up a personal **weekly study schedule** using the provided progress‑tracking tool; enable reminder notifications. | Better self‑discipline and visible progress. |
# | 4 | Download the week’s recorded lessons and any offline resources; test the campus Wi‑Fi or a backup connection. | Fewer technical disruptions and confidence in self‑paced study. |
#
# These steps are drawn directly from the evidence about your strengths, challenges, and the rule‑based recommendations for your learner segment. Implementing them should help you keep the high engagement you already show while addressing the areas that currently limit your learning experience. Good luck!

# %% [markdown]
# ## Student ID: `M080417`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "motivation"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** M080417
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You feel you learn best when you can focus in an in‑person classroom setting.
#
# **Main Challenges**
# - You would like more opportunities for interaction and communication, and you want support to stay motivated and disciplined while studying.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Increase interaction and communication** | Add more chances to ask questions, discuss ideas with peers, and receive quick feedback from the lecturer. | • Join scheduled Q&A sessions or virtual office hours.<br>• Participate in small‑group discussions or study circles.<br>• Use collaborative tools (e.g., shared docs, discussion boards) for peer work. |
# | **Support motivation and self‑discipline** | Keep your study routine on track with regular check‑ins and clear progress markers. | • Set a weekly study schedule and stick to it.<br>• Use reminders or a planner to note upcoming deadlines.<br>• Track your progress (e.g., checklist, simple dashboard) and review it each week.<br>• Attend brief weekly check‑in meetings (in‑person or online) with a tutor or study buddy. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Schedule interaction:** Sign up for the next Q&A session and join a study group for your current module.
# 2. **Create a study timetable:** Draft a 5‑day weekly plan with specific blocks for reading, assignments, and review.
# 3. **Set up progress tracking:** Use a simple spreadsheet or app to mark completed tasks each day.
# 4. **Weekly check‑in:** Arrange a 15‑minute meeting (in‑person or virtual) with a peer or tutor to discuss what you’ve accomplished and any obstacles.
#
# By focusing on more active interaction and a structured, self‑monitoring routine, you can turn your strong engagement into even better learning outcomes. Good luck!

# %% [markdown]
# ## Student ID: `e20221464`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_support", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221464*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners who attend classes but often take a passive role, may need extra prompts to stay focused and motivated.
#
# ### 2. Main Strengths
# - You describe yourself as **“more focused.”** This positive self‑view shows you have the capacity to concentrate when conditions are right.
#
# ### 3. Main Challenges
# - You note that **“sometime it is hard to focus.”**
# - The challenge themes identified are **Learning Difficulty & Clarity** and **Motivation & Self‑Discipline**.
#
# ### 4. Personalized Recommendations
#
# | Area | What to try | Why it helps |
# |------|-------------|--------------|
# | **Learning Support** | • Use course materials that include **clear, step‑by‑step guides** and **recorded explanations**.<br>• Look for **examples** that illustrate each concept before trying exercises. | Clear instructions reduce confusion and make it easier to maintain focus. |
# | **Motivation & Self‑Discipline** | • Set up a **weekly check‑in** (e.g., a short meeting with a tutor or a self‑review).<br>• Activate **reminders** in your calendar for study blocks.<br>• Track progress with a simple checklist or a digital tracker.<br>• Follow a **structured study schedule** that breaks tasks into short, manageable chunks. | Regular check‑ins and visible progress keep motivation high and help you stay on task. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the syllabus and locate any **step‑by‑step guides** or recorded videos for the upcoming topic. |
# | **Day 2‑3** | Create a **study schedule**: 45‑minute focus blocks with 10‑minute breaks; add these blocks to your calendar with reminders. |
# | **Day 4** | Start a **progress tracker** (paper or app) and mark each completed block. |
# | **Day 5** | Schedule a **30‑minute check‑in** with a peer or tutor to discuss what you’ve learned and any unclear points. |
# | **Day 6‑7** | Follow the schedule, using the guides and examples before attempting practice problems. |
# | **Day 8** | Review your tracker: note any patterns (e.g., times of day when focus is strongest) and adjust the schedule if needed. |
# | **Day 9‑10** | Repeat the study blocks, adding a **quick recap video** after each block to reinforce learning. |
# | **Day 11** | Conduct a second **check‑in** to reflect on progress and set goals for the next week. |
# | **Day 12‑14** | Continue the cycle, refining the schedule and using the support resources as needed. |
#
# ---
#
# **Remember:** Your ability to focus is a strength you can build on. By using clearer learning materials and a simple, regular routine, you’ll find it easier to stay engaged and achieve your study goals. Good luck!

# %% [markdown]
# ## Student ID: `e20220686`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220686*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key themes you mentioned:**
#   - **Strength:** Access to learning materials
#   - **Challenge:** Interaction & communication
#
# Your open‑ended comments were brief, so the recommendations below rely primarily on the characteristics of the “Highly Engaged (Active) Learners” segment together with the themes you identified.
#
# ---
#
# ### 2. Main Strengths
# - You value having learning materials (slides, videos, references, exercises) readily available, which helps you work efficiently and finish lessons quickly.
#
# ---
#
# ### 3. Main Challenges
# - You would like more interaction during online sessions, such as the teacher asking questions and providing quicker feedback.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Ensure that all course slides, video recordings, reference links, and practice exercises are uploaded **early** in the module (e.g., at the start of each week). | You can review content at your own pace, prepare questions in advance, and finish lessons faster. |
# | **Increase interaction and communication** | Add regular **Q&A slots**, short **polls or quizzes**, small‑group discussions, and prompt feedback from the lecturer after each activity. | More frequent interaction keeps you actively engaged, lets you clarify doubts quickly, and supports the collaborative style you prefer. |
#
# These two actions align directly with the tags **content_access** and **interaction** that were identified for you.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | 1 | Check the course portal for uploaded materials. | If anything is missing, request the instructor to post it early. |
# | 2 | Participate in a live Q&A or poll during the next online class. | Prepare one question in advance based on the week’s reading. |
# | 3 | Join a peer‑collaboration group (e.g., a study‑chat or breakout room). | Share a brief summary of what you learned and ask a teammate for feedback. |
# | 4 | Request faster feedback on an assignment or exercise. | Submit the work early and ask the lecturer for a quick turnaround. |
# | Ongoing | Keep a personal folder of all slides, videos, and exercises for quick reference. | Update it each week as new resources become available. |
#
# ---
#
# **Keep leveraging your strong access to materials while seeking more interactive moments—this combination will help you stay efficient and deeply engaged in your blended courses.**

# %% [markdown]
# ## Student ID: `e20230076`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230076*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from clearer structure, more interaction opportunities, and stronger learning support.
#
# ### 2. Main Strengths
# - You feel confident that external conditions (e.g., school attendance) will not prevent you from learning.
#
# ### 3. Main Challenges
# - You do not have a comfortable place to study while living alone.
# - (The challenge was identified as related to **Learning Resources & Environment**.)
#
# ### 4. Personalized Recommendations
# **Improve your learning environment**
# - **Organise study materials** – keep notes, PDFs, and assignments in clearly labelled folders (digital or paper).
# - **Update resources** – use the university’s library portal or open‑access repositories to ensure you have the latest readings.
# - **Create a dedicated study space** – even a small corner of your room can become a “study zone” by adding a comfortable chair, good lighting, and minimizing distractions.
# - **Enhance comfort** – consider inexpensive accessories (e.g., a desk lamp, a cushion) and keep the area tidy to reduce stress.
#
# These suggestions follow the rule‑based recommendation for the “learning_environment” tag and align with the needs of your segment.
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action | How to Do It |
# |-----|--------|--------------|
# | 1‑2 | List all current study materials | Write a quick inventory on paper or in a note‑taking app. |
# | 3‑4 | Sort and label the list | Create folders (e.g., “Lectures,” “Assignments,” “Readings”). |
# | 5‑6 | Find a quiet corner | Choose a spot, clear clutter, add a lamp and a comfortable chair. |
# | 7‑9 | Update resources | Search the university library for the latest versions of your course texts. |
# | 10‑12 | Test the space | Study there for 30 minutes each day; note what works and what needs tweaking. |
# | 13‑14 | Adjust as needed | Add any missing items (e.g., headphones, notebook) and finalize your study zone. |
#
# Stick to this simple plan and you’ll create a more supportive environment for your studies, helping you stay engaged and succeed in a blended‑learning setting. Good luck!

# %% [markdown]
# ## Student ID: `e20230312`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230312*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You indicated “I have no idea” for both strengths and challenges, so this report relies primarily on the typical characteristics of your segment.
#
# ### 2. Main Strengths
# - No specific strengths were reported.
# - **Based on your segment:** Highly engaged learners usually show strong motivation and active participation when resources are readily available.
#
# ### 3. Main Challenges
# - No specific challenges were reported.
# - **Based on your segment:** Even active learners can benefit from clear digital guidance and flexible pacing to keep momentum high.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | Why It Helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Upload or request slides, videos, readings, and exercises early in the course. | Quick access lets you dive into content right away, matching your active learning style. |
# | **Develop digital learning skills** | Get short tutorials on using the LMS, online research tools, and any educational apps your program offers. | Strong digital skills reduce friction and let you focus on learning rather than figuring out the platform. |
# | **Increase learner engagement** | Participate in quizzes, games, practical tasks, discussion boards, and other interactive activities. | Interactive elements keep your high energy directed toward deeper understanding. |
# | **Support self‑paced learning** | Use recorded lectures, weekly learning paths, and downloadable resources so you can review material whenever you need. | Flexibility lets you consolidate knowledge at your own speed while staying on track. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the course’s central repository (e.g., LMS folder) and download all available slides, videos, and readings. |
# | **2** | Complete a brief “LMS basics” tutorial (often 10‑15 min) offered by the university’s digital learning centre. |
# | **3** | Join a discussion forum or study group; contribute at least one comment or question. |
# | **4** | Set a personal weekly learning path: schedule 2‑3 hours for recorded lessons and 1 hour for practice quizzes. |
# | **5+** | Review any material you missed, use the self‑paced resources, and keep engaging with interactive activities each week. |
#
# ---
#
# **Remember:** Your high engagement is a strong asset. By ensuring you have easy access to materials, sharpening your digital skills, staying actively involved, and using self‑paced resources, you’ll maximize the benefits of blended learning and keep your momentum strong throughout the semester. Good luck!

# %% [markdown]
# ## Student ID: `e20210320`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210320*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility and the mix of digital and face‑to‑face interaction that blended learning provides. You appreciate being able to review materials online at any time and see a strong link between digital resources and your learning success.
#
# A key challenge you noted is unstable internet connectivity, which can hinder your ability to fully benefit from online components.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You recognize the advantage of having slides, videos, and other resources available online.
# - **Digital Skills Development** – You are comfortable using digital tools and see them as a way to enhance learning.
# - **Flexibility & Time Management** – You value the ability to study when it fits your schedule.
# - **Student Engagement** – You are active in class and enjoy interactive activities.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable campus internet makes it harder to access online content smoothly.
# - **Interaction & Communication** – While you are engaged, you would benefit from more structured opportunities for Q&A and peer collaboration.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** in the LMS. | Guarantees you can download or view resources before class, reducing the impact of spotty internet. |
# | **Digital Skills** | Offer short guides or workshops on LMS navigation, online research, and educational tech tools. | Strengthens your ability to use digital resources efficiently. |
# | **Engagement** | Include quizzes, games, practical tasks, and discussion prompts within each module. | Keeps you actively involved and leverages your high motivation. |
# | **Interaction** | Schedule regular Q&A sessions, small‑group discussions, and peer‑collaboration activities; aim for quicker lecturer feedback. | Improves communication flow and deepens understanding. |
# | **Self‑Paced Learning** | Provide recorded lectures and a weekly learning path that you can follow at your own speed. | Supports your preference for flexibility and allows review when internet is stable. |
# | **Tech Issues** | Ensure campus Wi‑Fi is reliable; where possible, make key materials downloadable for offline use and offer clear technical support contacts. | Directly addresses the connectivity problem you highlighted. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Check that all upcoming lecture slides and videos are uploaded to the LMS **at least 48 h before class**. | You can download materials early, mitigating internet lapses. |
# | 2 | Attend a 30‑minute LMS tutorial (or watch the recorded guide) covering navigation, bookmarking, and offline download options. | Faster, more confident use of digital tools. |
# | 3 | Participate in the first scheduled **online Q&A** and a small‑group discussion forum. | Experience improved interaction and quicker feedback. |
# | 4 | Review the recorded lecture for a topic you found challenging and complete the associated quiz. | Reinforce learning at your own pace and boost engagement. |
#
# Keep track of any remaining technical hurdles and let your instructor know promptly so additional support can be arranged. Your active approach combined with these targeted strategies will help you make the most of blended learning.

# %% [markdown]
# ## Student ID: `e20241402`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241402*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You see blended learning as useful for future jobs and appreciate its convenience and effectiveness.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You recognize that the blended approach helps you study efficiently and prepares you for the workplace.
#
# ### 3. Main Challenges
# - You would like to improve your skills and take on more challenging study tasks. (Your open‑ended comment was brief, so the following recommendation leans heavily on the typical profile of your segment.)
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness** – Combine the online materials you can review at your own pace with focused, in‑person sessions where the instructor explains concepts, you practice activities, and receive immediate feedback. This mix helps turn passive study time into active learning and strengthens the skills you want to develop.
#
# ### 5. Short Action Plan
#
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1‑2 | Identify 1‑2 key topics you find challenging. Use the online videos/notes to review them before class. | Builds a solid base before face‑to‑face work. |
# | 3‑4 | Attend the scheduled in‑person session for those topics. Participate in any practice exercises and ask for feedback. | Turns passive review into active practice and clarifies doubts. |
# | 5‑6 | After class, revisit the same online resources to reinforce what you practiced. Note any remaining questions and bring them to the next session. | Consolidates learning and keeps you motivated. |
# | Ongoing | Set a weekly 30‑minute “reflection” slot to record what you learned, what you still find tough, and plan the next online‑in‑person cycle. | Supports self‑paced progress and continuous improvement. |
#
# By repeatedly pairing your online review with targeted, interactive classroom work, you’ll make your study time more effective and start tackling the more challenging tasks you’re eager to try. Good luck!

# %% [markdown]
# ## Student ID: `e20230030`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230030*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to work well when you can capture the key points of a lecture and later verify or improve on them yourself.
# - You prefer concise, well‑organized recordings (about 5 minutes) and like to annotate texts (underline, highlight, add footnotes).
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You are good at collecting the main ideas from lectures and using them for self‑study.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You feel there is not enough chance to ask questions or interact with the teacher, and you sometimes worry about interrupting.
# - **Learning Difficulty & Clarity:** Recorded lectures give you the key points but not always the deeper understanding, leading you to spend extra time researching and occasionally getting confused.
#
# ### 4. Personalized Recommendations
#
# | Recommendation Area | What to Do (based on rule‑based advice) |
# |---------------------|------------------------------------------|
# | **Content Access** | • Ensure that slides, short video clips, reference links, and practice exercises are uploaded **early** in the course platform. <br>• Keep recordings short (≈5 min) and well‑structured so you can review key points quickly. |
# | **Interaction** | • Participate in scheduled **live Q&A sessions** or brief “office‑hour” chats where you can ask questions without feeling you’re interrupting. <br>• Join small **peer‑discussion groups** or online forums for quick clarification and collaborative problem‑solving. <br>• Look for faster lecturer feedback on submitted questions or short reflections. |
# | **Learning Support** | • Use **step‑by‑step guides** or annotated examples that accompany the recordings. <br>• Access **recorded explanations** that expand on the lecture’s key points, showing how to apply them. <br>• Take advantage of built‑in annotation tools (highlight, underline, add footnotes) to organise the material as you study. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Check the course portal for uploaded slides, short videos, and exercise files. Download them for offline review. |
# | **Day 3‑4** | Join the first live Q&A session (or schedule a 10‑minute virtual office hour). Prepare 2‑3 specific questions from the recent lecture. |
# | **Day 5‑7** | Form or join a small study group (2‑4 peers) on the platform’s discussion board. Share your annotated notes and ask for clarifications. |
# | **Day 8‑10** | Use the provided step‑by‑step guides to work through one practice exercise. Highlight any remaining doubts. |
# | **Day 11‑14** | Review the short recorded explanations that expand on the lecture’s key points. Add footnote references to your notes for any concepts that were unclear. |
#
# By following these steps, you’ll keep strong access to materials while gaining the interaction and clearer guidance that help turn key points into solid understanding. Good luck, and feel free to reach out to your instructor or peers whenever you need a quick clarification!

# %% [markdown]
# ## Student ID: `e20240084`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240084*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to use learning resources when they are convenient, but you feel that the current mix of materials sometimes makes it hard to keep up with course goals.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You appreciate tools that let you study flexibly and see the benefits of new material.
#
# ### 3. Main Challenges
# - The current setup can feel overwhelming, making it difficult to stay on track and reach the outcomes you want.
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness** – Blend your online review materials with regular, short in‑person sessions where the instructor can explain key concepts, give you guided practice, and provide immediate feedback. This combination helps turn convenient study time into deeper understanding.
#
# ### 5. Short Action Plan
#
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1‑2 | Identify 1‑2 online review modules per topic. | Keeps study convenient. |
# | 3‑4 | Attend a 30‑minute face‑to‑face (or live‑online) session focused on the same topics. | Adds clear explanations and real‑time feedback. |
# | 5‑6 | Complete a short practice exercise after the session and discuss any errors with the instructor. | Reinforces learning and fixes gaps quickly. |
# | Ongoing | Repeat the cycle for each new unit, noting which explanations helped you most. | Builds a habit of effective, blended study. |
#
# By pairing the flexibility you value with targeted, interactive support, you’ll be able to keep pace with the course and achieve your learning goals.

# %% [markdown]
# ## Student ID: `e20220580`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220580*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You are able to catch up with lessons and take time to explore the material more deeply.
# - Managing time for study is a current difficulty.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You can obtain the resources you need and use extra time to deepen your understanding.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity:** You find it hard to manage your study time, which can affect how clearly you grasp new concepts.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Having all slides, videos, readings, and practice exercises available early lets you study at your own pace and review whenever needed. | • Look for a course portal where the instructor uploads all content **before** the class session.<br>• Download or bookmark the materials as soon as they are posted so you can plan your study time. |
# | **Improve clarity and learning support** (learning_support) | Clear instructions, examples, and step‑by‑step guides reduce confusion and help you use your study time more efficiently. | • Use recorded explanations or tutorial videos that break down complex topics.<br>• Keep a personal “quick‑start guide” for each new concept (e.g., key steps, sample problems).<br>• If instructions are vague, ask the instructor or peers for a concrete example. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Verify that the course’s online platform has a “Materials” section. Subscribe to notifications for new uploads. |
# | **Day 3–5** | Download the upcoming week’s slides and videos. Create a simple folder structure (e.g., Week 1 → Slides, Videos, Exercises). |
# | **Day 6–7** | Watch the first video lecture and write down 2–3 key steps or examples. Compare them with the slide notes. |
# | **Day 8–10** | Set a 30‑minute “review block” each day to go through the downloaded materials. Use a timer to practice time‑management. |
# | **Day 11–12** | Identify any unclear instructions. Post a question in the class forum or email the instructor requesting a concrete example. |
# | **Day 13–14** | Reflect: Did the early access and clearer guides help you stay on schedule? Adjust your study blocks for the next week accordingly. |
#
# ---
#
# **Remember:** By securing all learning resources early and seeking clearer explanations, you can turn your ability to dive deeper into material into a more efficient, time‑managed study routine. You’re on the right track—keep building these habits each week.

# %% [markdown]
# ## Student ID: `e20220850`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220850*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values a good balance between personal life and academic work. You appreciate having more time to explore additional resources and generate new ideas. Your main difficulty is feeling overloaded by the amount of information you need to process.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You like having a variety of resources (slides, videos, references) that you can use to deepen your understanding.
# - **Flexibility & Time Management** – You manage your schedule well enough to fit study around other commitments.
# - **Learning Convenience & Effectiveness** – You seek ways to make study efficient and meaningful.
#
# ---
#
# ### 3. Main Challenges
# - **Assessment & Workload** – The volume of information and assignments can feel overwhelming.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Having all course content early lets you plan your study and explore extra material without last‑minute pressure. | Ask your instructors to upload slides, videos, readings, and practice exercises at the start of each module. |
# | **Improve learning effectiveness** | Combining online review with face‑to‑face explanation helps you solidify concepts and get quick feedback. | Use online summaries before class, then engage in in‑person discussions, practice activities, and ask for feedback on your work. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you review at a speed that suits you, reducing the feeling of overload. | Follow a weekly roadmap, watch the recorded lectures when convenient, and revisit any part that feels unclear. |
# | **Manage workload and assessment pressure** | Clear deadlines and balanced assignments prevent information overload. | Request a clear schedule of due dates, and look for alignment between online tasks and in‑person sessions so you can tackle related work together. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the course’s shared folder (e.g., LMS) and verify that all slides, videos, and reference links for the current module are uploaded. If not, email the instructor requesting early access. |
# | **Day 3‑4** | Create a simple weekly learning path: list the recorded lecture(s) to watch, the reading material, and the practice exercise for each topic. |
# | **Day 5‑7** | Attend the first in‑person session, use the online review material beforehand, and ask the instructor for quick feedback on any questions. |
# | **Day 8‑10** | Review the feedback, note any concepts that need more practice, and re‑watch the relevant video segment. |
# | **Day 11‑12** | Check the assignment calendar; mark all deadlines and discuss any unclear dates with the teaching team. |
# | **Day 13‑14** | Reflect on the workload: adjust your weekly plan if any week feels too heavy, and use the recorded lessons to spread study time more evenly. |
#
# Follow this plan, keep the communication channel open with your instructors, and adjust the pace as needed. With stronger material access, blended review, and clearer workload management, you’ll be able to maintain your high engagement while reducing information overload. Good luck!

# %% [markdown]
# ## Student ID: `e20220725`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20220725
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values **learning convenience and effectiveness**. You enjoy gaining new knowledge and having opportunities to expand ideas. At the same time, you find that the amount of blended‑learning material can feel overwhelming, making it hard to remember everything, set clear objectives, and manage the workload.
#
# ---
#
# ### 2. Main Strengths
# - **Motivation for new knowledge** – you actively seek additional resources and like to explore ideas.
# - **Positive attitude toward learning** – you view the blended format as convenient and effective when it works well.
#
# ---
#
# ### 3. Main Challenges
# - **Information overload** – difficulty retaining all the blended‑learning content.
# - **Unclear objectives & instructions** – sometimes you are unsure what is expected.
# - **Workload pressure** – balancing online tasks with in‑person sessions can feel stressful.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What to Do | Why it Helps |
# |----------------|------------|--------------|
# | **Improve learning effectiveness** | Pair the online review materials you already use with brief in‑person explanations, practice activities, and immediate feedback. | Combines the convenience you like with the clarity you need, reinforcing memory and understanding. |
# | **Improve clarity and learning support** | Ask instructors for clearer written instructions, concrete examples, and short recorded explanations. Use step‑by‑step guides or checklists for each assignment. | Reduces ambiguity, making it easier to set objectives and remember key points. |
# | **Manage workload and assessment pressure** | Create a simple schedule that aligns online tasks with upcoming face‑to‑face sessions. Mark clear deadlines and request that assignments be balanced across weeks. | Helps you see the big picture, prevents overload, and lets you allocate study time more efficiently. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the syllabus and list all upcoming online and in‑person tasks. Highlight any unclear instructions. |
# | **Day 2‑3** | Contact the course instructor or teaching assistant to ask for a brief recorded walkthrough of the most confusing assignment. |
# | **Day 4** | Set up a weekly planner (digital or paper) that groups online review with the corresponding in‑person session. Mark deadlines clearly. |
# | **Day 5‑7** | After each online review, spend 10‑15 minutes practicing the concept with a peer or using a quick quiz; note any questions for the next class. |
# | **Day 8‑10** | Use the step‑by‑step guide (create one if none exists) for the next assignment; check off each step as you complete it. |
# | **Day 11‑14** | Reflect on how the combined review‑practice‑feedback cycle affected your recall and confidence. Adjust the planner if needed. |
#
# By following these steps, you can keep leveraging your strong engagement while reducing overload and gaining clearer direction in your blended courses. Good luck!

# %% [markdown]
# ## Student ID: `M080421`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080421*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility that blended learning provides. You appreciate easy access to course materials and find that online components help you balance work and study. Your comments show a positive attitude toward both the strengths and the challenges of your current blended courses.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You notice that having slides, videos, and references available online gives you more flexibility and better time‑management.
# - **Flexibility & Time Management** – The ability to study online while working is a key benefit for you.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You would like clearer, more frequent communication and opportunities to interact with lecturers and peers.
# - **Learning Difficulty & Clarity** – Some instructions and explanations could be clearer; recorded lectures would help you review.
# - **Learning Resources & Environment** – Better organization of materials and a comfortable study environment would improve your experience.
# - **Technical Access** – Although you do not have major internet problems, reliable access and clear platform guidance remain important.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|----------------------|
# | **Strengthen access to learning materials** | Lecturers should upload slides, videos, references, and exercises **early** in the week so you can plan your study time. |
# | **Increase interaction and communication** | Add regular Q&A sessions, small‑group discussions, and quicker feedback from instructors to boost peer collaboration. |
# | **Improve learning resources and environment** | Materials should be clearly organized (e.g., folders by week/topic). The learning platform could suggest optimal study spaces or provide tips for a comfortable home‑study setup. |
# | **Improve clarity and learning support** | Provide step‑by‑step guides, concrete examples, and recorded explanations so you can revisit difficult concepts at your own pace. |
# | **Support self‑paced learning** | Offer weekly learning paths and make all recorded lessons available for review whenever you need them. |
# | **Improve technical access and reliability** | Ensure the platform works smoothly, give clear instructions for offline downloads, and maintain a responsive tech‑support channel. |
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How it helps you |
# |------|--------|------------------|
# | **1** | Check that all course slides and videos are uploaded at the start of the week. | Lets you schedule study sessions around work. |
# | **2** | Join a weekly online Q&A or discussion group. | Increases interaction and clears up doubts quickly. |
# | **3** | Use the recorded lectures to review any topic you found unclear. | Supports self‑paced learning and improves understanding. |
# | **4** | Download any needed materials for offline use and test the platform’s stability. | Reduces any technical hiccups and ensures continuous access. |
# | **Ongoing** | Keep a personal folder that mirrors the course’s organized structure. | Makes it easier to locate resources and maintain a tidy study environment. |
#
# By following these steps, you can keep leveraging the flexibility you value while strengthening interaction, clarity, and technical reliability in your blended courses. Keep up the active engagement—you’re well positioned to succeed!

# %% [markdown]
# ## Student ID: `e20240071`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240071*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically enjoys flexible study options, is comfortable with digital tools, and likes to stay actively involved in class activities.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You find it easy to study “wherever and whenever,” which shows strong self‑direction and digital confidence.
#
# ---
#
# ### 3. Main Challenges
# - You noted that **recorded lecture videos would help** when you miss a class or need extra clarification. This points to a need for reliable, on‑demand content to support your active learning style.
#
# ---
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness**
# - **Blend online review materials with in‑person sessions.** Use recorded lectures or short video summaries to revisit key concepts before or after class.
# - **Attend face‑to‑face explanations, practice activities, and receive feedback** from the instructor or peers. This combination reinforces understanding and lets you apply what you’ve reviewed online.
#
# These steps align with the recommendation tag **learning_effectiveness** and leverage your strengths in digital access and self‑paced study.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1 | Locate any recorded lecture videos for the current module (ask the instructor or check the LMS). | Gives you a quick reference when you miss a class. |
# | 2 | Before the next in‑person session, watch the relevant video and note questions. | Pre‑pares you to engage actively during class. |
# | 3 | Participate in the face‑to‑face lecture, focusing on practice exercises and asking for feedback. | Reinforces concepts and clears misunderstandings. |
# | 4 | Review the same video again after class to consolidate learning. | Strengthens retention through spaced repetition. |
# | Ongoing | Keep a personal folder of key videos and notes for each topic. | Builds a reusable resource library for future study. |
#
# By pairing the flexibility you already enjoy with structured in‑person practice and feedback, you’ll boost both understanding and performance in your courses. Keep communicating with your instructors about the availability of recorded content—they’re often happy to support active learners like you.

# %% [markdown]
# ## Student ID: `e20241327`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20241327*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This group tends to study independently but benefits from more structured, face‑to‑face interaction.
#
# ### 2. Main Strengths
# - You appreciate having time for self‑study and value learning convenience.
#
# ### 3. Main Challenges
# - You would like lectures to be paced more slowly so you can follow the material comfortably.
#
# *(Your open‑ended responses were brief, so the recommendations below rely mainly on the characteristics of your learner segment.)*
#
# ### 4. Personalized Recommendations
# **Improve learning effectiveness** – Combine online review materials with in‑person explanation, practice, and feedback.
# - **Online:** Use short video summaries or slide decks before class to preview the topic at your own speed.
# - **In‑person:** Attend scheduled sessions where the instructor expands on the material, demonstrates examples, and answers questions.
# - **Practice & Feedback:** Participate in small‑group activities or quick quizzes during class and receive immediate feedback to reinforce understanding.
#
# ### 5. Short Action Plan
#
# | Week | Online Activity | In‑Person Session | Practice / Feedback |
# |------|----------------|-------------------|----------------------|
# | 1 | Watch 5‑minute preview video of the upcoming topic | Attend 30‑minute lecture (ask the instructor to pause for clarification) | Complete a 5‑question quiz; review answers with the tutor |
# | 2 | Read a concise summary PDF and note any unclear points | Join a 20‑minute discussion group to clarify those points | Do a short problem set; get feedback from peers or the instructor |
# | 3 | Re‑watch any video sections that were still unclear | Participate in a hands‑on workshop or lab | Submit a brief reflection on what helped you understand better |
#
# Repeat the cycle, adjusting the pace of the online review to match your comfort level. This blended approach leverages your preference for self‑study while giving you the slower, interactive support you need to deepen learning.

# %% [markdown]
# ## Student ID: `e20210537`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210537*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and actively participate in your courses.
#
# ### 2. Main Strengths
# - **Learning convenience & effectiveness** – you value being able to study efficiently and get results quickly.
#
# ### 3. Main Challenges
# - **Cost** – financial considerations are a concern for you. (No additional challenges were identified.)
#
# ### 4. Personalized Recommendations
# Because you are a highly engaged learner who prioritises effective, convenient study, the following evidence‑based suggestion is most relevant:
#
# - **Improve learning effectiveness** – *Combine online review materials with in‑person explanation, practice, and feedback.*
#
# This blended approach lets you use quick‑access digital resources while still benefiting from face‑to‑face clarification and hands‑on practice, maximizing both speed and depth of learning.
#
# ### 5. Short Action Plan
#
# | Step | What to Do | How It Helps |
# |------|------------|--------------|
# | 1 | Identify concise online review videos or quizzes for each topic. | Saves time and gives you immediate access to key concepts. |
# | 2 | Schedule short in‑person sessions (office hours, labs, study groups) to ask questions and practice. | Provides direct feedback and deeper understanding. |
# | 3 | After each in‑person session, revisit the online material to reinforce what you learned. | Strengthens retention and links theory with practice. |
# | 4 | Track your time spent and grades to see the efficiency gains. | Lets you confirm that the blended mix is cost‑effective for you. |
#
# *Note:* Your open‑ended responses were brief, so this recommendation draws primarily on the characteristics of the “Highly Engaged (Active) Learners” segment and the specific tag **learning_effectiveness** identified for you.
#
# Good luck, and enjoy the flexibility of blended learning!

# %% [markdown]
# ## Student ID: `e20210739`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210739
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - **Flexibility & Time Management** – you describe yourself as “flexible,” which helps you adapt to different study schedules.
#
# **Main Challenges**
# - **Internet & Technical Issues** – unreliable internet and limited video recordings make it hard to review material.
# - **Learning Difficulty & Clarity** – you find it difficult to study again when recordings are missing.
# - **Learning Resources & Environment** – the current study space and resource organization are not supporting your learning effectively.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Learning Environment** | • Organize course materials in a clear folder structure.<br>• Keep your study space tidy and comfortable (good lighting, minimal distractions). | A well‑structured environment reduces the time spent searching for resources and improves focus. |
# | **Learning Support** | • Ask instructors for clearer written instructions and concrete examples.<br>• Request step‑by‑step guides or short recorded explanations for complex topics. | Clearer guidance reduces confusion and makes self‑study more productive. |
# | **Self‑Paced Learning** | • Use any available recorded lessons and create a personal weekly learning plan.<br>• Review recordings and notes at your own pace, especially when internet is unstable. | Having control over timing lets you compensate for connectivity gaps and reinforces understanding. |
# | **Technical Issues** | • Download lecture videos when you have a good connection and keep them for offline review.<br>• Explore campus Wi‑Fi hotspots or library computers for more reliable access.<br>• Keep a quick‑reference guide for the learning platform and know how to contact tech support. | Stable access and offline options ensure you can continue studying even when the connection drops. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Create a dedicated folder on your device/cloud for each course; label sub‑folders (lectures, notes, assignments).
# 2. **Day 3‑5:** Identify one lecture per subject, download the video, and add brief written notes.
# 3. **Day 6‑8:** Meet (in‑person or virtually) with a tutor/TA to ask for clearer examples on a topic you find difficult.
# 4. **Day 9‑11:** Set up a weekly learning path (e.g., “Monday – watch video; Tuesday – review notes; Wednesday – practice problems”).
# 5. **Day 12‑14:** Locate the nearest campus Wi‑Fi hotspot or library computer and test downloading a full lecture for offline study.
#
# By organizing your resources, securing reliable access, and using self‑paced tools, you can turn your flexibility into consistent progress despite technical challenges. Good luck!

# %% [markdown]
# ## Student ID: `e20220296`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20220296
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who finds blended learning “easier to understand.” Your main difficulty is **time‑management**, especially when a single day mixes online and face‑to‑face classes. You also notice pressure from workload and assessment timing, and you would like smoother interaction with peers and instructors.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You feel that blended formats help you grasp material quickly.
# - **High Engagement:** Your active participation makes you well‑suited to interactive activities.
#
# ---
#
# ### 3. Main Challenges
# - **Time‑Management & Workload:** Coordinating online and in‑person sessions in the same day feels stressful.
# - **Interaction & Communication:** You would benefit from clearer, faster feedback and more peer collaboration.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do (based on rule‑based advice) |
# |-------|------------------------------------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration tasks.<br>• Request quicker feedback from lecturers after submissions. |
# | **Learning Effectiveness** | • Use online review materials **before** in‑person classes.<br>• Apply what you study online during face‑to‑face practice and receive immediate feedback. |
# | **Workload Support** | • Work with your instructors to balance assignment loads and clarify deadlines.<br>• Align online tasks with the topics covered in the same week’s classroom session to avoid overlapping work. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the week’s online lecture notes (30 min). |
# | **Tuesday** | Attend a live Q&A or discussion forum for that topic (45 min). |
# | **Wednesday** | Complete the related in‑person activity; ask the lecturer for quick feedback. |
# | **Thursday** | Consolidate notes; create a brief study checklist with due dates. |
# | **Friday** | Meet a study buddy or small group to compare understanding and share tips for managing the schedule. |
# | **Weekend** | Reflect on what worked, adjust your personal timetable for the next week, and note any remaining questions for the upcoming Q&A. |
#
# Follow this cycle each week, tweaking the timing to fit your personal schedule. By increasing structured interaction, pairing online review with face‑to‑face practice, and clarifying workload expectations, you’ll reduce time‑management stress and make the most of your highly engaged learning style.

# %% [markdown]
# ## Student ID: `M080419`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** M080419
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# You appreciate how blended learning is **flexible**, lets you **review lessons anytime**, and helps you build **digital skills**. You value easy **access to learning materials** and feel confident managing your time.
#
# **Main Challenges**
# You experience **unstable internet** and find some online lessons hard to understand. You would like clearer instructions, recorded lectures, and better **interaction/communication** with lecturers.
#
# **Personalized Recommendations**
#
# | Area | What to do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** so you can download them before class. |
# | **Digital Skills** | Offer short guides or workshops on using the LMS, online research tools, and other educational technologies. |
# | **Interaction** | Add regular Q&A sessions, small‑group discussions, and quicker lecturer feedback to improve communication. |
# | **Learning Environment** | Organise all materials clearly, keep resources up‑to‑date, and ensure study spaces (both online and on‑campus) are comfortable and well‑equipped. |
# | **Learning Support** | Provide clearer step‑by‑step instructions, concrete examples, and recorded explanations for complex topics. |
# | **Self‑Paced Learning** | Make recorded lessons and weekly learning paths available so you can review content at your own speed. |
# | **Technical Issues** | Ensure stable campus Wi‑Fi, offer offline copies of key resources, and provide a help desk for platform problems. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# 1. **Week 1:** Download all currently available lecture slides and videos; note any missing items to request from the lecturer.
# 2. **Week 2:** Attend a short LMS‑skills workshop (or watch the provided tutorial) to boost confidence with digital tools.
# 3. **Week 3:** Join a peer‑study group that meets online for a Q&A session on the most difficult topics.
# 4. **Week 4:** Test the campus Wi‑Fi in a quiet study area; if problems persist, contact technical support and request offline copies of upcoming materials.
#
# By following these steps, you can keep leveraging your high engagement while reducing the technical and clarity barriers you’ve identified. Good luck!

# %% [markdown]
# ## Student ID: `e20210586`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210586
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate how blended learning is **flexible**, helps you **develop digital skills**, gives **easy access to diverse resources**, and supports **collaboration** and **personalised learning**.
#
# **Main Challenges**
# - Slow Wi‑Fi on campus and limited access to digital tutorials.
# - Need for more **interactive activities**, clearer **online‑tool tutorials**, and **timely feedback** from lecturers.
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on the rule‑based recommendations) |
# |------|--------------------------------------------------------|
# | **Content Access** | Instructors should **upload slides, videos, references, exercises, and other course materials early** so you can download them before class. |
# | **Digital Skills** | Seek **guidance on using the LMS, online research tools, and educational technologies** (e.g., short how‑to videos or quick‑start guides). |
# | **Engagement** | Participate in **quizzes, games, practical tasks, and discussion prompts** that are built into the online modules. |
# | **Interaction** | Join scheduled **Q&A sessions, group discussions, and peer‑collaboration activities**; ask lecturers for quicker feedback on assignments. |
# | **Learning Effectiveness** | Combine the online review materials with **in‑person explanations, practice exercises, and feedback** to reinforce concepts. |
# | **Learning Environment** | Use clearly organized **online folders** and take advantage of any **improved study spaces** the university offers; let the teaching team know if classroom comfort is an issue. |
# | **Self‑Paced Learning** | Take advantage of **recorded lessons and weekly learning paths** that let you review content at your own speed. |
# | **Technical Issues** | Request **stable campus Wi‑Fi or offline copies of materials**, and make use of the university’s **technical support** for platform problems. |
#
# **Short Action Plan (Next 4 Weeks)**
#
# | Week | Action |
# |------|--------|
# | 1 | Download all available lecture slides and videos; note any missing items and ask the instructor to upload them. |
# | 2 | Complete a short LMS tutorial (look for a “how‑to” video or ask the support desk). |
# | 3 | Join a live Q&A or discussion session; ask for feedback on one recent assignment. |
# | 4 | Review the recorded lessons for a topic you found difficult, then attempt the associated quiz or practical task. |
#
# By following these steps, you can make the most of blended learning’s flexibility while overcoming the technical and interaction challenges you’ve identified. Good luck!

# %% [markdown]
# ## Student ID: `e20241021`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20241021
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - Values **flexibility and time‑management** – you appreciate the convenience that online resources can provide.
#
# **Main Challenges**
# - You feel that **online learning can be more limited than in‑person classes**, which may affect how fully you can engage with the material.
#
# **Personalized Recommendations**
# Because you belong to the *Highly Engaged (Active) Learners* segment and you highlighted flexibility as a strength, the primary recommendation is to **support self‑paced learning**. This aligns with the rule‑based suggestion for your segment:
#
# - **Provide recorded lessons** so you can revisit content whenever it fits your schedule.
# - **Offer weekly learning paths** that outline what to study each week, giving you a clear roadmap while still letting you move at your own speed.
# - **Make all course materials (slides, readings, quizzes) easily downloadable** so you can review them offline or on any device.
#
# These options help you keep the convenience you value while reducing the sense that online learning is “limited” compared with face‑to‑face classes.
#
# **Short Action Plan**
#
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1 | Access the recorded lectures for your current module and note any sections you want to re‑watch. | Reinforces understanding on your own timetable. |
# | 2 | Follow the weekly learning path provided by the instructor; adjust the pace if needed. | Gives structure without forcing a fixed class time. |
# | 3 | Download all supplemental materials (readings, practice quizzes) and set a personal review schedule. | Ensures you have all resources available, even offline. |
# | Ongoing | Track your progress in a simple planner or digital app; flag any topics that feel “limited” and seek additional resources (e.g., discussion forums, virtual office hours). | Keeps you engaged and lets you address gaps quickly. |
#
# By using self‑paced resources, you can maintain the high level of engagement you already demonstrate while overcoming the limitations you perceive in online learning. Feel free to reach out to your instructor or learning support team if you need help locating recordings or setting up a personalized learning path.

# %% [markdown]
# ## Student ID: `M080422`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080422*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You already make good use of the variety of materials that are available to you, which helps you stay motivated and learn efficiently.
#
# ### 2. Main Strengths
# - **Easy access to diverse materials** – you value having slides, videos, references, and exercises readily available, which supports convenient and effective study sessions.
#
# ### 3. Main Challenges
# - No specific challenges were reported.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content access) | Keep the flow of resources steady so you can continue studying without gaps. | • Upload or share slides, videos, reading lists, and practice exercises **early** in the module (e.g., at the start of each week). <br>• Use a central folder or LMS page that all classmates can access. |
# | **Improve learning effectiveness** (learning effectiveness) | Blend the online content you already enjoy with face‑to‑face activities that deepen understanding. | • Before class, review the uploaded materials. <br>• During in‑person sessions, focus on explanations, guided practice, and getting feedback from the instructor or peers. <br>• After class, use the same resources to reinforce what was covered. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|------------------|
# | 1 | Upload all lecture slides and any reference links **by Monday** of the week. | Guarantees everyone, including you, can start reviewing early. |
# | 1 | Schedule a 15‑minute “clarify‑questions” slot after the first lecture. | Turns passive review into active understanding. |
# | 2 | Create a short practice quiz using the uploaded exercises and share it before the next class. | Gives you immediate feedback and highlights areas to focus on during face‑to‑face time. |
# | 2 | Reflect on how the combined online review + in‑person practice helped your grasp of the topic; note any adjustments for the following weeks. | Reinforces the habit of integrating both modes for maximum learning effectiveness. |
#
# ---
#
# **Keep leveraging your strength of accessing diverse materials, and pair it with purposeful in‑person practice.** This blended approach will help you stay highly engaged while deepening your mastery of each subject. Good luck!

# %% [markdown]
# ## Student ID: `M080105`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment", "learning_support", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M080105*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility and the ability to dive deeper into topics that interest you. You appreciate having plenty of support materials and like to manage your own study schedule.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You notice that having slides, videos, references and other resources early helps you research what you love and stay on track.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity when you are away from campus can delay feedback and make it hard to submit work.
# - **Interaction & Communication** – You would like faster feedback from lecturers and more ways to discuss material with peers.
# - **Assessment & Workload** – Unclear deadlines and the need for offline options for assignments are concerns.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on the rule‑based advice) |
# |------|---------------------------------------------|
# | **Content Access** | Upload all slides, videos, reference links and practice exercises **well before** the class session so you can download them for offline study. |
# | **Interaction** | Add regular Q&A slots, short group‑discussion forums, and peer‑collaboration tasks. Request quicker lecturer feedback on drafts. |
# | **Learning Environment** | Keep the online repository organized (folders by week/topic) and ensure any study‑space resources (e.g., recorded explanations) are easy to find. |
# | **Learning Support** | Provide clear, step‑by‑step instructions and example problems for each assignment; include short recorded walkthroughs. |
# | **Technical Issues** | Offer downloadable PDFs or zip files of all materials so you can work offline. Provide a simple guide on how to save assignments locally and upload them when you regain internet. Ensure a help‑desk contact for connectivity problems. |
# | **Workload Support** | Align online tasks with face‑to‑face sessions, balance the number of assignments, and publish all deadlines at the start of the term. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Check the course platform for a “Download All Materials” button; if missing, ask the lecturer to enable it. |
# | **Day 3‑4** | Join a peer‑study group on the course forum; schedule a 30‑minute weekly Q&A session with the instructor. |
# | **Day 5‑7** | Download the week’s slides, videos and any PDFs; store them on a cloud folder you can access offline. |
# | **Day 8‑10** | Review the assignment brief; note any unclear steps and post a clarification question in the forum. |
# | **Day 11‑12** | Draft your assignment offline; save it in the designated folder and set a reminder to upload it once you have stable internet. |
# | **Day 13‑14** | Submit the draft, request feedback, and note the turnaround time; use this information to plan future work. |
#
# By following these steps, you can keep the flexibility you enjoy while minimizing connectivity problems, improving communication, and managing your workload more smoothly. Keep leveraging your strong engagement—your proactive approach will make the blended format work even better for you.

# %% [markdown]
# ## Student ID: `e20221395`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20221395*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to use the flexibility of blended courses but prefer a more structured, supportive environment.
#
# ### 2. Main Strengths
# - **Access & Flexibility:** You appreciate being able to review video lectures at any time and value having all course materials (slides, videos, references) readily available.
#
# ### 3. Main Challenges
# - **Assessment & Resources:** You have noticed occasional errors in quiz questions or video content, which can cause confusion.
# - **Interaction & Communication:** Faster feedback and clearer communication would help you stay on track.
# - **Learning Environment:** Better organization of materials and a comfortable study space would improve your experience.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Ensure slides, videos, references, and exercises are uploaded early in the semester. | Gives you reliable, error‑free resources to review whenever you need them. |
# | **Increase interaction and communication** | Add regular Q&A sessions, small‑group discussions, and quicker lecturer feedback on assignments. | Reduces confusion from mistaken quiz items and keeps you engaged. |
# | **Improve learning resources and environment** | Organise all course files in a clear folder structure, keep resources up‑to‑date, and provide guidance on optimal study spaces (e.g., quiet zones, ergonomic tips). | Makes it easier to find what you need and creates a comfortable setting for self‑study. |
# | **Support self‑paced learning** | Provide recorded lessons and a weekly learning path that outlines what to study each day. | Lets you use the flexibility you value while staying on schedule. |
# | **Manage workload and assessment pressure** | Balance the number of assignments, clearly state deadlines, and align online tasks with face‑to‑face sessions. | Helps you avoid overload and understand how each activity fits into the overall course. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | 1 | **Check material availability** – Log into the LMS and verify that all slides and videos for the upcoming topic are posted. | If anything is missing, email the lecturer or post a question in the forum. |
# | 2 | **Join a Q&A session** – Attend the scheduled live Q&A or set up a short meeting with the tutor. | Prepare 2‑3 questions about any confusing quiz items. |
# | 3 | **Create a study space** – Arrange a quiet, well‑lit area with needed supplies; use the university’s study‑room booking if needed. | Follow the campus guide on ergonomic study tips (available on the LMS). |
# | 4 | **Review workload** – List all upcoming assignments, note their deadlines, and compare them with the weekly learning path. | If you see clustering of due dates, discuss possible extensions with the instructor. |
#
# ---
#
# By following these steps, you can keep benefiting from the flexibility of blended learning while gaining clearer guidance, more reliable resources, and a balanced workload. Feel free to reach out to your academic advisor if you need additional support.

# %% [markdown]
# ## Student ID: `e20210675`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20210675
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Learning Profile
# You describe yourself as good at **saving time and managing assignment schedules** (Flexibility & Time Management). The main difficulty you mention is **slow internet** (Internet & Technical Issues).
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you can organise your workload and make efficient use of study time.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – unreliable connectivity can disrupt online activities.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Support self‑paced learning** | Use recorded lectures, weekly learning paths, and downloadable resources that you can review whenever you have a stable connection. | Lets you keep your strong time‑management habits while avoiding missed content when the internet is slow. |
# | **Improve technical access and reliability** | Access offline copies of readings/video, clear step‑by‑step platform guides, and a quick‑response tech‑support channel. | Reduces the impact of connectivity problems and ensures you can continue studying without interruption. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s recorded lectures and download the first week’s videos to your device. |
# | **Day 3** | Create a personal weekly learning path (e.g., “Mon – watch video; Tue – read notes; Wed – complete quiz”). |
# | **Day 4–5** | Test the offline materials to confirm they work without internet. |
# | **Day 6** | Save the platform’s technical‑support contact info in a quick‑access folder. |
# | **Day 7–14** | Follow your learning path, using offline resources when the connection is slow; reach out to tech support if any issue persists. |
#
# Stick to the schedule you set, and you’ll keep leveraging your time‑management strength while minimizing the disruption caused by internet problems. If you need further help, your university’s learning support team is ready to assist.

# %% [markdown]
# ## Student ID: `e20211548`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211548*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you’ve shared:** You value flexibility and feel confident using digital tools. You also notice challenges around workload balance and occasional internet/technical issues.
#
# ---
#
# ### 2. Main Strengths
# | Strength theme | Evidence from you |
# |----------------|-------------------|
# | **Digital Skills Development** | “flexibility digital independence” – you are comfortable navigating online platforms and like the freedom digital learning gives you. |
# | **Flexibility & Time Management** | Your ability to adapt your schedule supports self‑directed study. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge theme | Evidence from you |
# |-----------------|-------------------|
# | **Assessment & Workload** | “workload balance” – you feel the amount of work and deadlines can be hard to juggle. |
# | **Internet & Technical Issues** | “access to internet and inconsistency” – occasional connectivity problems disrupt learning. |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it matters for you | What to do |
# |----------------|------------------------|------------|
# | **Develop digital learning skills** | You already enjoy digital independence, so deepening those skills will make your study smoother. | • Short guides on using the LMS, research databases, and collaboration tools.<br>• Quick‑tip videos on advanced features (e.g., annotating PDFs, creating multimedia posts). |
# | **Support self‑paced learning** | Your flexibility works best when you can review material on your own schedule. | • Access recorded lectures and weekly learning paths.<br>• Use the “download for offline” option so you can study without internet. |
# | **Improve technical access and reliability** | Inconsistent internet can break your flow. | • Downloadable offline resources and low‑bandwidth versions of videos.<br>• Clear step‑by‑step platform instructions.<br>• Contact the campus IT help desk for a stable connection or loaner hotspot. |
# | **Manage workload and assessment pressure** | Balancing assignments is a current challenge. | • Look for a consolidated assignment calendar that shows all deadlines.<br>• Break large tasks into smaller, weekly goals (the weekly learning path can help).<br>• Discuss with your instructor any overlapping deadlines; ask for clarification when needed. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Watch the 5‑minute “LMS Basics” video and bookmark the digital‑skill tip sheet. |
# | **Day 3** | Download this week’s recorded lectures and the offline PDF handouts. |
# | **Day 4** | Open the course calendar; add all upcoming deadlines to your personal planner. |
# | **Day 5** | Identify one large assignment and split it into 3‑4 smaller tasks; schedule them on the weekly learning path. |
# | **Day 6–7** | Test the offline materials (watch a video without internet) and note any technical hiccups; contact IT if needed. |
# | **Week 2** | Review progress each Friday: adjust your pacing, confirm you have internet access for next week’s live session, and note any workload concerns to discuss with the instructor. |
#
# ---
#
# **You’re already a proactive, digitally‑savvy learner.** By sharpening your tech skills, using self‑paced resources, securing reliable internet access, and organizing your workload, you can keep your high engagement level while reducing stress. Good luck, and remember the university support services are here to help you succeed!

# %% [markdown]
# ## Student ID: `e20230638`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20230638*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values easy access to course materials and the ability to replay lessons for self‑study. Your main obstacles are unreliable internet and limited physical space for studying.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having slides, videos, and references readily available.
# - **Learning Convenience & Effectiveness** – You use playback features to reinforce understanding on your own schedule.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Slow or unstable connections hinder your ability to stream or download content.
# - **Learning Resources & Environment** – Lack of a quiet, well‑equipped study space makes focused work difficult.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload all slides, videos, reference links, and exercises **early** in the course platform. | Gives you the material you need to review anytime, even if you later face connectivity problems. |
# | **Learning Effectiveness** | Pair the online review resources with **in‑person explanations, guided practice, and timely feedback** (e.g., short lab sessions or tutorial groups). | Reinforces concepts you study on your own and lets you apply knowledge with expert support. |
# | **Learning Environment** | Organize digital folders clearly, keep resources up‑to‑date, and provide tips for creating a compact, distraction‑free study nook (e.g., using headphones, portable desk). | Makes it easier to locate what you need and improves focus despite limited physical space. |
# | **Tech Issue** | Offer **offline download options** for videos and PDFs, supply clear step‑by‑step platform guides, and ensure a help desk is available for connectivity problems. | Reduces reliance on high‑speed internet and gives you quick assistance when technical glitches arise. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course portal and download all available slides and videos for the upcoming module. |
# | **Day 3** | Set up a dedicated study corner (even a small desk with headphones) and label digital folders by topic. |
# | **Day 4–5** | Attend the scheduled in‑person tutorial; ask for clarification on any concepts you reviewed online. |
# | **Day 6** | Test the offline download feature; if you encounter issues, contact technical support. |
# | **Day 7** | Complete a short practice exercise and submit it for feedback. |
# | **Day 8–10** | Use the downloaded materials to review the lesson while offline; note any gaps and bring questions to the next class. |
# | **Day 11–14** | Reflect on what study environment works best; adjust lighting, seating, or noise‑cancelling options as needed. |
#
# ---
#
# **Keep leveraging your strong habit of accessing and replaying materials, and use the steps above to overcome internet and space constraints.** If you need further assistance, your course’s technical support and learning advisors are ready to help. Good luck!

# %% [markdown]
# ## Student ID: `p20250013`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250013*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically values flexible, convenient study options and is motivated to make the most of both online and face‑to‑face resources.
#
# **What you shared:**
# - **Strengths:** You appreciate saving on expenses and having time for self‑study.
# - **Challenges:** You experience internet connectivity problems and notice that some classmates find it hard to keep up with the material.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You like the ability to study independently and manage costs.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable connectivity can disrupt online activities.
# - **Learning Difficulty & Clarity:** Some peers (and possibly you) struggle to catch up when instructions are unclear.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | Why it helps you | What to do |
# |----------------|------------------|------------|
# | **Improve learning effectiveness** | Combines the convenience you value with the depth of in‑person guidance. | Use online review materials **before** attending face‑to‑face sessions where the instructor can explain concepts, give practice tasks, and provide immediate feedback. |
# | **Improve clarity and learning support** | Clearer directions reduce the need to “catch up” and make self‑study more productive. | Look for recorded explanations, step‑by‑step guides, and concrete examples. When instructions feel vague, request additional examples or a short walkthrough from the tutor. |
# | **Improve technical access and reliability** | Stable internet ensures you can use online resources without interruption. | Take advantage of any campus Wi‑Fi hotspots, download offline copies of readings/video clips when you have a good connection, and keep the platform’s help desk contact handy for quick troubleshooting. |
#
# These three actions align directly with the tags **learning_effectiveness**, **learning_support**, and **tech_issue** that were identified for you.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify one upcoming module. Download all lecture videos/reading PDFs while on campus Wi‑Fi. |
# | **Day 3–4** | Watch the downloaded videos and take brief notes. Mark any points that are unclear. |
# | **Day 5** | Attend the in‑person session for that module. Use the time to ask the instructor to clarify the marked points and to practice the exercises. |
# | **Day 6–7** | Review the instructor’s feedback, complete any practice tasks, and upload any questions to the technical support portal if you encounter connectivity problems. |
# | **Day 8–10** | Repeat the cycle for a second module, focusing on using recorded explanations and step‑by‑step guides. |
# | **Day 11–14** | Evaluate: Did the offline materials reduce internet interruptions? Did clearer instructions help you stay on track? Adjust the routine as needed. |
#
# ---
#
# **Keep in mind:** Your active engagement is a strong asset. By pairing reliable offline resources with clear, instructor‑led support, you can maintain the convenience you value while minimizing technical hiccups and learning gaps. If you need further help, reach out to your course’s technical support team or academic advisor. Good luck!

# %% [markdown]
# ## Student ID: `p20230011`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** p20230011
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You appreciate the **flexibility** of studying both at home and on campus, which helps you manage your time effectively.
#
# **Main Challenges**
# - **Internet connectivity** problems, especially when you need to submit assignments.
# - You feel the current **assessment workload** can be difficult to balance.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** | You can study when it suits you best. | Access recorded lectures, follow the weekly learning path, and review any material as often as needed. |
# | **Improve technical access and reliability** | Reduce the impact of internet issues. | Use any offline versions of readings or videos that the university provides, keep a copy of assignment files locally, and contact the tech‑support desk for help with connectivity. |
# | **Manage workload and assessment pressure** | Make assignments clearer and more manageable. | Look for a consolidated list of deadlines, break larger tasks into smaller steps, and discuss any timing concerns with your instructor or tutor. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Download offline materials** – Log into the learning platform, locate the “download for offline use” option, and save the next week’s lecture videos and readings to your device.
# 2. **Create a personal weekly schedule** – Use a simple planner (paper or digital) to block time for watching recorded lessons, completing readings, and working on assignments.
# 3. **Check internet options** – If campus Wi‑Fi is unreliable, explore university‑provided hotspot loans or a nearby co‑working space with stable connection.
# 4. **Clarify upcoming deadlines** – Review the course calendar, note all due dates, and email the instructor if any deadline is unclear.
# 5. **Reach out for support** – If you encounter technical problems or feel overwhelmed by the workload, contact the tech‑support team and your academic advisor within the next few days.
#
# By following these steps, you can keep leveraging your flexibility while minimizing connectivity hurdles and balancing your assignment load. Good luck!

# %% [markdown]
# ## Student ID: `p20230023`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230023*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners who attend class but tend to participate less actively, benefit from clear structure, and need extra support for interaction and technology use.
#
# ---
#
# ### 2. Main Strengths
# - Shows good **digital‑skill awareness** – you have been able to keep daily expenses low and increase productivity, indicating an ability to manage digital tools efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable connection makes it hard to join online sessions.
# - **Interaction & Communication:** Limited participation in online class activities; you prefer learning directly with lecturers when possible.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Digital Skill Development** | • Review short guides on using the LMS, online libraries, and research tools.<br>• Practice with a few selected educational apps each week. | Strengthens the digital habits you already use for productivity and reduces friction when accessing course material. |
# | **Interaction & Communication** | • Join scheduled Q&A or discussion slots (live or via forum).<br>• Form a small study‑group with classmates for peer collaboration.<br>• Request quicker feedback from lecturers when possible. | Increases engagement, gives you more opportunities to ask questions, and builds a supportive learning community. |
# | **Technical Access & Reliability** | • Use campus Wi‑Fi hotspots or a university‑provided data voucher for stable internet.<br>• Download lecture videos and readings in advance for offline study.<br>• Keep the platform’s “how‑to” guide handy and contact tech support as soon as an issue arises. | Guarantees you can follow online sessions even when home connectivity is poor, and reduces missed content. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the university’s Wi‑Fi hotspot map and request a data voucher (if available). |
# | **Day 3‑4** | Watch the LMS tutorial video (10 min) and bookmark the digital‑research guide. |
# | **Day 5** | Download this week’s lecture slides and recordings for offline review. |
# | **Day 6‑7** | Join a peer‑study group chat (create or join a WhatsApp/Discord channel). |
# | **Day 8** | Attend the first live Q&A session; prepare one question in advance. |
# | **Day 9‑10** | Test the offline materials; note any technical problems and contact tech support. |
# | **Day 11‑12** | Submit a short reflection on what digital tool helped you most this week. |
# | **Day 13‑14** | Review feedback from the lecturer and set a goal for the next two weeks (e.g., ask two questions in class). |
#
# ---
#
# **Remember:** These suggestions are built on the strengths you already demonstrate and the challenges typical for your learner segment. By taking the small steps above, you’ll improve both your digital confidence and your ability to engage fully in blended courses. Good luck!

# %% [markdown]
# ## Student ID: `p20250043`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250043*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** The flexibility of assignments, projects and deadlines.
# - **What feels challenging:** A heavy workload toward the end of the semester, especially many assignments, projects and finals packed together.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to organise your study around flexible deadlines and tasks.
#
# ---
#
# ### 3. Main Challenges
# - **Assessment & Workload** – The concentration of assignments and exams later in the term creates pressure and makes it harder to keep up.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | What to do |
# |----------------|------------------|------------|
# | **Support self‑paced learning** (self‑paced) | You like flexibility, so being able to study when it suits you will keep you engaged. | • Use recorded lectures and short video summaries. <br>• Follow the weekly learning paths provided in the LMS. <br>• Review materials at your own speed before class. |
# | **Manage workload and assessment pressure** (workload_support) | Balancing the timing of tasks will reduce the end‑of‑semester overload you described. | • Check the course calendar for clear, staggered deadlines. <br>• Break large projects into smaller milestones that align with weekly topics. <br>• Use the online task list to see how each assignment fits with in‑person sessions. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# 1. **Set up your self‑paced hub** – Locate the recorded lessons and weekly learning path for the current module; schedule 30‑45 min review slots each day.
# 2. **Create a mini‑timeline** – For the upcoming project, list all required steps and assign a deadline for each step that matches the weekly path.
# 3. **Clarify deadlines** – Post any unclear due‑date questions on the course forum or ask the instructor during the next live session.
# 4. **Monitor workload** – At the end of each week, spend 10 min checking the overall task list to ensure no new assignments are clustering together.
#
# By using recorded resources to study at your own pace and breaking down large assessments into manageable pieces, you can keep the flexibility you value while avoiding the end‑semester overload. Good luck, and remember that the course team is here to support you!

# %% [markdown]
# ## Student ID: `p20250006`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_support", "motivation", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250006*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Overall tone:** Strengths are viewed positively; challenges are felt negatively.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You can easily review past lectures and study resources, which is a solid foundation for self‑study.
#
# ---
#
# ### 3. Main Challenges
# - **Assessment & Workload:** Feeling overloaded and unclear about deadlines.
# - **Learning Difficulty & Clarity:** Instructions often seem vague, making it hard to know what to do next.
# - **Motivation & Self‑Discipline:** Maintaining motivation and staying on schedule are difficult.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on the rule‑based advice) |
# |------|---------------------------------------------|
# | **Content Access** | Ensure that slides, videos, reference links, exercises and any other course material are uploaded **early** in the online platform so you can review them whenever needed. |
# | **Learning Support** | Ask the instructor for **clearer instructions** and concrete examples. Look for recorded explanations or step‑by‑step guides that break tasks into manageable parts. |
# | **Motivation** | Participate in **weekly check‑ins** (e.g., a short online survey or a quick chat with a tutor). Use reminders and a simple progress‑tracking sheet to see how far you’ve come each week. |
# | **Workload Support** | Request a **balanced schedule**: clear deadlines, a reasonable number of assignments, and alignment between online tasks and in‑person sessions. A weekly overview of what is due can help you plan ahead. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s online repository and verify that all lecture slides and videos are posted. If anything is missing, request it from the instructor. |
# | **Day 3** | Create a simple **study schedule**: allocate 30 min–1 h each day for reviewing material and completing assignments. |
# | **Day 4** | Set up a **reminder system** (phone app or calendar) for upcoming deadlines and weekly check‑ins. |
# | **Day 5** | Identify one upcoming assignment and ask for a **step‑by‑step guide** or example from the tutor. |
# | **Day 6–7** | Complete the first portion of the assignment using the clarified instructions; log your progress in a tracker. |
# | **Week 2** | Attend the scheduled **weekly check‑in** (or send a brief status email) to reflect on what worked and what needs adjustment. |
# | **End of Week 2** | Review the workload for the next week, note any overload, and discuss possible re‑balancing with the instructor. |
#
# ---
#
# **Remember:** Your ability to access materials is a strong asset. By improving clarity, managing workload, and building regular motivation habits, you can move from passive engagement to a more active, confident learning experience. Good luck!

# %% [markdown]
# ## Student ID: `p20230027`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment", "learning_support", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230027*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically shows moderate participation and benefits from clear structure, reliable resources, and supportive learning environments.
#
# ### 2. Main Strengths
# - You expressed a positive view of improving the classroom environment, indicating awareness of how the setting can aid learning.
#
# ### 3. Main Challenges
# - **Learning environment:** Need for a better‑organized classroom and study space.
# - **Technical issues:** Unreliable internet connection and limited access to online tools.
# - **Learning clarity:** Desire for more practice labs and clearer instructions.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Learning Environment** | • Keep study materials organized and up‑to‑date.<br>• Arrange a comfortable, distraction‑free workspace (e.g., tidy desk, good lighting). | A clear, comfortable space reduces passive disengagement and supports focus. |
# | **Learning Support** | • Seek out step‑by‑step guides, recorded explanations, and concrete examples for each topic.<br>• Request additional practice labs or worksheets from the instructor. | Clear instructions and extra practice make the material easier to understand and apply. |
# | **Technical Access** | • Use campus Wi‑Fi or a reliable hotspot for online sessions.<br>• Download lecture videos and readings in advance so you can study offline.<br>• Keep a list of quick‑help contacts (IT support, tutoring centre). | Stable access prevents interruptions and lets you follow blended activities without frustration. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Identify a quiet study spot; organize your notes and digital folders. |
# | **Day 3‑4** | Test your internet connection; if unstable, arrange a campus hotspot or download needed materials. |
# | **Day 5‑7** | Locate recorded lectures or ask the instructor for video links; save them for offline use. |
# | **Day 8‑10** | Request a step‑by‑step guide or example problems for the current module; schedule a short meeting with a tutor if needed. |
# | **Day 11‑14** | Complete at least one extra practice lab or worksheet; reflect on what helped you understand the content best. |
#
# ---
#
# **Remember:** These suggestions are based on the characteristics of your learner segment and the specific challenges you reported. Implementing the actions above should make your blended‑learning experience smoother and more effective. If you encounter new difficulties, reach out to your instructor or the university’s support services for additional help.

# %% [markdown]
# ## Student ID: `p20230042`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230042*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You prefer having learning materials available so you can study at your own pace, especially when online components make up most of the course.
# - You noted a lack of online classes, which limits opportunities for interaction and communication with peers and instructors.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value having slides, videos, references, and exercises ready for you.
# - **Flexibility & Time Management** – You are comfortable learning independently when resources are provided.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – With few online classes, you have limited chances for Q&A, group work, and timely feedback.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Ensure all course content is uploaded early so you can study whenever you choose. | • Ask lecturers to post slides, recorded lectures, reading lists, and practice exercises at the start of each week.<br>• Use the learning platform’s “download” folder to keep a personal library of resources. |
# | **Increase interaction and communication** | Add structured opportunities to connect with classmates and instructors. | • Participate in scheduled Q&A sessions or virtual office hours.<br>• Join small‑group discussion boards or peer‑collaboration spaces.<br>• Request quicker feedback on assignments through the LMS messaging system. |
# | **Support self‑paced learning** | Provide clear, weekly learning paths and recordings so you can progress at your own speed. | • Follow a weekly roadmap that outlines which videos, readings, and activities to complete.<br>• Review recorded lessons before or after class meetings.<br>• Use the platform’s “bookmark” feature to mark sections you need to revisit. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Locate the course’s “Resources” folder; download all available slides and videos. | All core materials are ready for self‑paced study. |
# | 2 | Register for at least one live Q&A or virtual office hour. | Direct interaction with the lecturer and clarification of doubts. |
# | 3 | Join a peer discussion board or create a small study group on the LMS. | Regular peer communication and collaborative learning. |
# | 4 | Review the weekly learning path and set personal milestones for each module. | Structured progress tracking and confidence in self‑paced study. |
#
# ---
#
# **Remember:** These suggestions are based on your segment’s typical needs and the strengths and challenges you shared. By improving material access, adding interaction opportunities, and using self‑paced tools, you can make the most of blended learning while keeping the flexibility you value. Good luck!

# %% [markdown]
# ## Student ID: `p20250041`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250041*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you value:** The flexibility and convenience of online study.
# - **Current challenge:** Distractions from social‑media and games that hurt motivation and self‑discipline.
#
# *Because the open‑ended comments are brief, this report leans on the characteristics of the “Highly Engaged” segment together with the specific strengths and challenges you reported.*
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You appreciate being able to study when it fits your schedule, which helps you stay active in your courses.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline:** Social‑media and gaming interruptions make it harder to keep focused and maintain steady progress.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How to Apply it in Your Blended Course |
# |----------------|----------------------------------------|
# | **Support motivation and self‑discipline** | • Set up a **weekly check‑in** (e.g., a short 5‑minute reflection or a quick chat with a tutor). <br>• Use **reminders** (calendar alerts or app notifications) for upcoming deadlines. <br>• Track your progress with a simple **progress bar** or checklist that you update after each study session. <br>• Follow a **structured study schedule** that blocks specific times for learning and separate times for social media/gaming. |
# | **Support self‑paced learning** | • Access **recorded lectures** and downloadable notes so you can review material whenever you want. <br>• Follow the **weekly learning path** provided by the course (outline of what to study each week). <br>• Use the **materials library** to revisit concepts that need extra practice. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a weekly study timetable (2‑hour blocks) and add calendar reminders. |
# | **Tuesday** | Watch the recorded lecture for this week and mark key points in a personal note. |
# | **Wednesday** | Complete a 5‑minute progress check‑in (what you’ve finished, what’s next). |
# | **Thursday** | Set a “no‑social‑media” window during one study block; use an app blocker if needed. |
# | **Friday** | Review the week’s material using the recorded lessons; note any topics that need extra review. |
# | **Weekend** | Reflect on motivation: write down one achievement from the week and plan a small reward. |
# | **Repeat** | Follow the same pattern next week, adjusting study block lengths based on what works best. |
#
# ---
#
# **Keep in mind:** Your ability to learn flexibly is a strong asset. By pairing that flexibility with regular check‑ins, clear reminders, and a self‑paced structure, you can reduce distractions and stay motivated throughout the semester. Good luck, and remember that small, consistent steps lead to big progress!

# %% [markdown]
# ## Student ID: `p20250057`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250057*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You appreciate the flexibility that blended learning offers, especially the ability to study anytime, anywhere and to develop digital skills. At the same time, you experience difficulties with unstable internet, limited interaction with lecturers and peers, and managing your time effectively.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials & Flexibility** – You value being able to obtain slides, videos, and other resources early and to learn at your own pace.
# - **Digital Skills Development** – You recognize that blended learning helps you build useful digital competencies.
# - **Student Engagement** – You notice that technology (videos, apps) can boost your involvement in the course.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Limited real‑time contact with lecturers and classmates.
# - **Internet & Technical Issues** – Unstable connection hampers smooth participation.
# - **Learning Difficulty & Clarity** – Need clearer guidance and more structured support.
# - **Learning Environment** – Desire for better‑organized resources and comfortable study spaces.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Instructors will upload slides, videos, references, exercises, and other course materials **well before class** so you can review them anytime. |
# | **Digital Skills** | Short guides and short videos will show you how to use the LMS, locate online resources, and apply digital research tools. |
# | **Engagement** | Expect regular low‑stakes quizzes, interactive games, practical tasks, and discussion prompts to keep you actively involved. |
# | **Interaction** | Scheduled Q&A sessions, small‑group discussions, and peer‑collaboration activities will increase communication. Lecturers will aim to give faster, targeted feedback. |
# | **Learning Effectiveness** | Online review materials will be paired with in‑person explanations, practice opportunities, and timely feedback to reinforce understanding. |
# | **Learning Environment** | Course materials will be organized clearly (folders, labels) and updated regularly. Study spaces—both virtual and on‑campus—will be improved for comfort and focus. |
# | **Learning Support** | Instructions will include clear examples, recorded step‑by‑step explanations, and concise guides to reduce ambiguity. |
# | **Self‑Paced Learning** | Recorded lectures and a weekly learning path will let you progress at a pace that fits your schedule. |
# | **Technical Issues** | The university will provide stable Wi‑Fi hotspots, offline downloadable content, clear platform tutorials, and a help desk for quick technical assistance. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | How It Helps You |
# |------|--------|------------------|
# | 1 | **Access early‑uploaded materials** (slides, videos) for the upcoming module. | Gives you time to preview content and plan your study schedule. |
# | 2 | Attend the **first live Q&A** and try the new discussion forum. | Increases interaction with the lecturer and peers. |
# | 3 | Complete the **first interactive quiz** and review the feedback. | Boosts engagement and highlights areas needing clarification. |
# | 4 | Use the **offline download** option for any material you struggled with due to connectivity. | Ensures you can study without internet interruptions. |
#
# ---
#
# **Remember:** These recommendations are built from your own feedback and the characteristics of Moderately Engaged (Passive) learners. By following the actions above, you can turn the flexibility of blended learning into a more supportive, interactive, and effective experience. If any recommendation feels unclear, reach out to your course’s learning support team—they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `p20240001`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240001*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from clear structure, self‑paced resources, and reliable technical access.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate that the blended format lets you study when it fits your schedule.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – The LMS crashes intermittently, preventing you from accessing course materials when needed.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Support self‑paced learning** | Use recorded lectures, weekly learning paths, and downloadable materials that you can review anytime. | Aligns with your need for flexibility and lets you keep progressing even if the LMS is temporarily unavailable. |
# | **Improve technical access and reliability** | Access offline copies of readings/video, follow clear step‑by‑step platform guides, and contact the tech‑support desk when the LMS crashes. | Reduces disruption from LMS outages and ensures you always have the resources you need. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Download the week’s lecture recordings and reading PDFs to your device for offline use. |
# | **Week 2** | Follow the “quick‑start” guide for the LMS (provided by the university) and bookmark the tech‑support contact page. |
# | **Week 3** | Create a personal weekly learning path (e.g., “Monday – watch video; Tuesday – read PDF; Thursday – complete quiz”). |
# | **Ongoing** | If the LMS crashes, switch to the offline materials you saved and log the incident for the support team. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset—by pairing self‑paced resources with reliable offline options, you can keep learning smoothly even when technical hiccups occur. If you need further help, reach out to the university’s learning support or IT help desk. Good luck!

# %% [markdown]
# ## Student ID: `p20240045`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240045*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values extra time for self‑study, finds lectures clearer when you can review them, and communicates well with classmates and the professor. The main difficulty you reported is an unreliable internet connection.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | You appreciate having more time to study and want easy access to slides, videos, and references. |
# | **Learning Convenience & Effectiveness** | Reviewing lectures improves your understanding. |
# | **Student Engagement** | Good communication with peers and the instructor supports your active participation. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Internet & Technical Issues** | Frequent connectivity problems can interrupt your study flow. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|------------------|
# | **Strengthen access to learning materials** (content_access) | Upload slides, videos, reference links, and exercises **early** so you can download them for offline study when the internet is unstable. |
# | **Increase learner engagement** (engagement) | Include short quizzes, interactive games, practical tasks, and discussion prompts in each module to keep your active participation high. |
# | **Improve learning effectiveness** (learning_effectiveness) | Pair online review resources with in‑person explanations, practice sessions, and timely feedback to deepen understanding. |
# | **Improve technical access and reliability** (tech_issue) | Provide options for offline copies, clear instructions for the learning platform, and a dedicated technical‑support channel to resolve connectivity issues quickly. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Download all current lecture slides and videos to a personal device (offline folder). |
# | **Day 3** | Complete the first interactive quiz and post a comment in the discussion forum. |
# | **Day 4–5** | Attend the scheduled in‑person session; ask the professor for quick feedback on the practice task. |
# | **Day 6** | Test the platform’s offline mode; note any missing resources and request them from the instructor. |
# | **Day 7** | Contact technical support with a brief description of your internet issue; keep the support ticket number handy. |
# | **Day 8–10** | Repeat the cycle with the next lecture: download, review, quiz, discuss, and seek feedback. |
# | **Day 11–14** | Review the support response; if needed, arrange a backup internet solution (e.g., campus Wi‑Fi hotspot) for the upcoming week. |
#
# Follow this plan to keep your study flow smooth, stay engaged, and minimize the impact of technical problems. You’re already a proactive learner—these steps will help you make the most of the blended environment. Good luck!

# %% [markdown]
# ## Student ID: `p20240011`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "learning_support", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240011*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you told us:** You value *self‑paced learning*.
# - **What we noticed:** You experience challenges around *motivation and guidance*, especially in the areas of learning clarity, resources, and self‑discipline.
#
# ---
#
# ### 2. Main Strengths
# - Ability to work independently and manage your own pace.
#
# ---
#
# ### 3. Main Challenges
# - Finding clear instructions and examples.
# - Accessing up‑to‑date, well‑organized learning materials.
# - Maintaining motivation and a disciplined study routine.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to do | Why it helps |
# |------|------------|--------------|
# | **Learning Environment** | • Keep your digital and physical study spaces tidy.<br>• Use a folder system (or LMS sections) that groups related materials together.<br>• Check that you have the latest versions of readings, videos, and tools. | A clear, comfortable environment reduces confusion and lets you focus on the content you love. |
# | **Learning Support** | • Look for recorded explanations or step‑by‑step guides for complex topics.<br>• Request or create example problems that illustrate key concepts.<br>• Use the course’s FAQ or discussion board when instructions feel vague. | Clear, concrete examples and explanations make self‑paced study more effective. |
# | **Motivation & Self‑Discipline** | • Set a weekly study schedule with specific goals (e.g., “finish Chapter 3 by Friday”).<br>• Use a progress‑tracking tool (checklist, habit app, or LMS tracker).<br>• Arrange a brief weekly check‑in with a tutor, peer, or mentor for accountability. | Structured routines and regular feedback keep motivation high and help you stay on track. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Create a dedicated study folder (digital or paper) and label sections for each course module. |
# | **Day 2** | Identify one topic that feels unclear; locate a recorded explanation or ask the instructor for an example. |
# | **Day 3** | Draft a simple weekly schedule (30‑45 min blocks) and set a reminder in your calendar. |
# | **Day 4** | Choose a progress‑tracking method (e.g., checklist in Notion, Google Sheet, or habit‑tracker app). |
# | **Day 5** | Schedule a 15‑minute check‑in with a peer or tutor for next week. |
# | **Day 6‑7** | Follow the schedule, update your tracker, and note any remaining unclear points. |
# | **Week 2** | Review your tracker on the check‑in day, adjust the schedule if needed, and add any new resources you discovered. |
#
# Stick to the plan, adjust as you learn what works best, and remember that the structure you build now will support the self‑paced learning you already excel at. Good luck!

# %% [markdown]
# ## Student ID: `p20240062`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240062*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** The flexibility and time‑management possibilities that blended learning provides.
# - **What worries you:** Feeling isolated when studying online, missing face‑to‑face interaction with peers, and needing stronger motivation and self‑discipline.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate that blended courses let you organise study time around other commitments and prepare for future work environments.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Limited opportunities to meet and collaborate with classmates.
# - **Learning Resources & Environment** – Need for a more supportive online study space.
# - **Motivation & Self‑Discipline** – Difficulty staying motivated when studying alone.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try (based on rule‑based advice) |
# |------|-------------------------------------------|
# | **Interaction** | • Join scheduled Q&A sessions and live group discussions.<br>• Form small peer‑collaboration groups for assignments.<br>• Request quicker feedback from lecturers to keep the dialogue flowing. |
# | **Learning Environment** | • Use a clearly organised digital folder structure for course materials.<br>• Choose a quiet, comfortable study spot; consider a campus library or a co‑working space for online days.<br>• Check that all resources (videos, readings) are up‑to‑date; ask the instructor if anything is missing. |
# | **Motivation & Self‑Discipline** | • Set a weekly check‑in with yourself (or a study buddy) to review progress.<br>• Enable reminder notifications for upcoming deadlines.<br>• Track your learning milestones in a simple spreadsheet or app to see how far you’ve come. |
# | **Self‑Paced Learning** | • Take advantage of recorded lectures—re‑watch sections that need extra review.<br>• Follow the weekly learning path provided by the course and adjust it only when needed.<br>• Keep a personal “cheat sheet” of key concepts you can revisit anytime. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Locate the course’s discussion forum and introduce yourself; propose a small study group. |
# | **Day 2** | Organise all course files into clearly labelled folders (e.g., Lectures, Readings, Assignments). |
# | **Day 3** | Set up a weekly reminder (e.g., every Sunday evening) to plan the coming week’s study tasks. |
# | **Day 4** | Watch the first recorded lecture twice, noting any questions for the next live Q&A. |
# | **Day 5** | Attend a live Q&A or discussion session; share one question you prepared. |
# | **Day 6** | Choose a comfortable, distraction‑free study spot for the next online study day. |
# | **Day 7** | Review your progress sheet: mark completed tasks and celebrate a small win. |
# | **Week 2** | Repeat the cycle, adding a peer‑feedback exchange on an assignment draft. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset—use it to build a routine that includes regular interaction, a tidy learning environment, and clear motivation checkpoints. Small, consistent steps will turn the passive‑learning tendency into active, confident progress. Good luck!

# %% [markdown]
# ## Student ID: `p20240023`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240023*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You show strong self‑management and are actively involved in your studies.
#
# ### 2. Main Strengths
# - **Self‑management** – you are able to organise your time and tasks effectively.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity** – you find some instructions or concepts unclear.
# - **Learning Resources & Environment** – the study materials or physical/virtual learning space could be better organised.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning environment** | Make your study space and digital resources clearer and more comfortable. | • Keep course files in a consistent folder structure.<br>• Use a tidy, well‑lit workspace.<br>• Update any outdated PDFs or slides you rely on. |
# | **Improve clarity and learning support** | Get clearer guidance and step‑by‑step help for complex topics. | • Ask instructors for written examples or recorded walkthroughs.<br>• Use short “how‑to” guides or checklists for assignments.<br>• Take advantage of any tutoring or peer‑support sessions offered. |
#
# These suggestions are drawn directly from the rule‑based recommendations for your segment and the challenges you reported.
#
# ### 5. Short Action Plan (2‑Week Sprint)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review your current digital folders; rename and reorganise files by course and week. |
# | **Day 3–4** | Set up a dedicated, distraction‑free study spot (good lighting, comfortable chair). |
# | **Day 5** | Identify one upcoming assignment that feels unclear; request a recorded explanation or example from the instructor. |
# | **Day 6–7** | Create a simple checklist for that assignment (steps, resources needed, deadlines). |
# | **Day 8–10** | Attend a peer‑study or tutoring session focused on a topic you find difficult. |
# | **Day 11–12** | Update any outdated PDFs or slides you use; replace them with the latest versions from the LMS. |
# | **Day 13–14** | Reflect: note any improvement in clarity or comfort and adjust the plan for the next two weeks. |
#
# Follow this plan to make your learning environment more organized and to secure clearer guidance, helping you maintain your high level of engagement while reducing confusion. Good luck!

# %% [markdown]
# ## Student ID: `p20240033`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240033*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate being able to reach course materials anytime, anywhere, as long as you have an internet connection.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You find the online resources convenient and value the ability to study at your own pace.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Occasional server downtime or missing features can interrupt your study flow.
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation (title) | What to do |
# |-----|------------------------|------------|
# | **content_access** | **Strengthen access to learning materials** | • Upload slides, videos, references, exercises, and other course content **early** in the semester so they are always available. |
# | **tech_issue** | **Improve technical access and reliability** | • Ensure a **stable internet connection** (e.g., campus Wi‑Fi, backup hotspot). <br>• Provide **offline copies** of key materials (PDFs, downloadable videos). <br>• Offer **clear instructions** for using the learning platform and a **quick‑response technical support** channel. |
#
# These suggestions are drawn directly from the evidence you provided and from the typical needs of your learner segment.
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Check that all lecture slides and reading PDFs are uploaded to the course site. |
# | **2** | Download a backup copy of the week’s materials for offline study. |
# | **3** | Test your internet connection; if it’s unstable, arrange a campus hotspot or a reliable data plan. |
# | **4** | Save the platform’s “Help” page link and note the contact details for technical support. |
# | **Ongoing** | Review new content as soon as it is posted to keep ahead of any server issues. |
#
# By following these steps, you’ll keep learning materials readily available and minimise disruptions caused by technical problems. If you encounter any new difficulties, reach out to your instructor or the tech support team promptly. Good luck with your studies!

# %% [markdown]
# ## Student ID: `p20240061`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240061*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - Students in this segment are motivated, participate actively in class, and thrive when they can manage their own learning pace.
#
# ### 2. Main Strengths
# - You value the flexibility to study independently without needing to be on campus. This aligns with the self‑paced nature of blended learning.
#
# ### 3. Main Challenges
# - You have identified possible **connectivity or technical issues** that could affect online study.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve technical access and reliability** (tech_issue) | Ensure you can connect to course materials reliably, even when internet quality fluctuates. | • Use campus Wi‑Fi hotspots or a reliable mobile data plan when home internet is unstable.<br>• Download lecture videos, readings, and assignments in advance for offline study.<br>• Follow the university’s quick‑start guide for the learning platform to avoid setup problems.<br>• Keep the technical‑support contact information handy and reach out early if you encounter issues. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
# 1. **Test your connection:** Log into the learning platform from home and note any loading problems.
# 2. **Download offline resources:** For each upcoming module, save videos and PDFs to your device.
# 3. **Set up support:** Save the technical‑support email/phone number and note the hours they are available.
# 4. **Create a backup plan:** Identify a nearby library or café with reliable Wi‑Fi you can use if home connectivity fails.
#
# By securing stable technical access and preparing offline materials, you can keep your high level of engagement and make the most of the blended‑learning environment. Good luck!

# %% [markdown]
# ## Student ID: `p20240009`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** p20240009
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You appreciate the **flexibility and time‑management** that blended learning gives you. It lets you study at your own pace and stay motivated even when you miss a class.
#
# **Main Challenges**
# - **Interaction & Communication:** You find it harder to connect with lecturers and get quick feedback during online sessions.
# - **Internet & Technical Issues:** Unreliable university internet sometimes disrupts your learning.
# - **Learning Resources & Environment:** You would like clearer organization of materials and a more comfortable study setting.
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Increase interaction and communication** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request faster feedback from lecturers when you have questions. |
# | **Improve learning resources and environment** | • Use the university’s organized material hubs (folders, playlists) to keep content tidy.<br>• Suggest updates to any outdated resources.<br>• Choose study spaces that are quiet and comfortable; if needed, request improvements (lighting, seating). |
# | **Support self‑paced learning** | • Take advantage of recorded lessons so you can review them anytime.<br>• Follow the weekly learning paths provided by the course platform.<br>• Keep a personal checklist of topics you’ve mastered and those to revisit. |
# | **Improve technical access and reliability** | • Locate reliable Wi‑Fi spots on campus or use the university’s wired connections.<br>• Download offline copies of lectures and readings when you anticipate connectivity problems.<br>• Follow the platform’s quick‑start guide and contact technical support early if issues arise. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Schedule interaction:** Add at least one live Q&A or discussion group to your calendar each week.
# 2. **Organize resources:** Create a personal folder structure that mirrors the course’s official layout; flag any missing or outdated files for the instructor.
# 3. **Set self‑paced checkpoints:** After each recorded lecture, write a 2‑sentence summary and note any questions for the next Q&A.
# 4. **Secure internet access:** Identify the campus location with the strongest Wi‑Fi; download the upcoming week’s videos before leaving home.
#
# By focusing on these four areas—interaction, learning environment, self‑paced study, and technical reliability—you can build on your strong engagement and make blended learning even more effective. Good luck!

# %% [markdown]
# ## Student ID: `p20240006`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** p20240006
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# - **Strengths identified:** Good at **time management** and values flexibility in study schedules.
# - **Challenges identified:** Experiences **internet/technical difficulties** and finds some course material unclear or hard to understand.
#
# *(Because the open‑ended responses are brief, the recommendations rely heavily on the typical profile of Moderately Engaged (Passive) learners.)*
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you can organise your study time effectively and benefit from self‑directed pacing.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – unstable connectivity can interrupt learning.
# - **Learning Difficulty & Clarity** – course instructions and concepts sometimes feel unclear.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What It Means for You | How to Use It |
# |----------------|----------------------|---------------|
# | **Learning Support** | Get clearer guidance and examples. | Look for recorded explanations, step‑by‑step guides, and additional examples provided by the instructor. |
# | **Self‑Paced Learning** | Take advantage of flexible, on‑demand content. | Use recorded lessons and weekly learning paths; review materials as often as needed to fit your schedule. |
# | **Tech Issue** | Reduce the impact of connectivity problems. | Download offline versions of readings and videos when you have good internet, follow platform tutorials, and contact technical support for help. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Day 1‑2** | Locate the course’s recorded lectures and download them for offline use. |
# | **Day 3‑4** | Review the step‑by‑step learning guide for the upcoming module; note any parts that are unclear. |
# | **Day 5‑7** | Schedule a 30‑minute session with the teaching assistant or tutor to clarify the noted difficulties. |
# | **Week 2** | Follow the weekly learning path at your own pace; set specific times each day using your strong time‑management skills. |
# | **Ongoing** | Keep a log of any technical problems and contact the support desk promptly; use campus Wi‑Fi or a reliable hotspot when possible. |
#
# ---
#
# **Keep leveraging your strong time‑management skills while using the recorded, self‑paced resources and technical support offered.** This approach will help you overcome connectivity hurdles and gain clearer understanding of the material. Good luck!

# %% [markdown]
# ## Student ID: `p20240042`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240042*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - This segment typically shows strong motivation, frequent participation, and good digital skills.
#
# ### 2. Main Strengths
# - Your engagement level is high, which is a key asset for blended learning.
#
# ### 3. Main Challenges
# - You reported an **internet/Wi‑Fi connection issue** that makes reliable online access difficult.
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|----------------------|
# | **Improve technical access and reliability** (tag: *tech_issue*) | • Ensure you have a stable internet connection (e.g., upgrade your Wi‑Fi plan, use a wired Ethernet link, or locate a reliable hotspot). <br>• Download offline versions of lecture videos, readings, and assignments when you have good connectivity. <br>• Keep a quick‑reference guide for the learning platform’s basic functions. <br>• Use the university’s technical support service for troubleshooting. |
#
# ### 5. Short Action Plan (Next 2 weeks)
# 1. **Check your current internet plan** – contact your provider to confirm speed and stability.
# 2. **Set up a backup access point** – identify a nearby library, café, or campus hub with reliable Wi‑Fi.
# 3. **Download offline materials** – before each class, download the required videos/ PDFs to your device.
# 4. **Save the platform cheat‑sheet** – create a one‑page guide with login steps and common actions.
# 5. **Contact tech support** – if problems persist, reach out to the university help desk (provide error screenshots).
#
# By securing a dependable connection and having offline resources ready, you can fully leverage your high engagement and continue to succeed in the blended‑learning environment.

# %% [markdown]
# ## Student ID: `p20240066`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240066*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who readily accesses lecture materials and assignments. Your active participation is a strong asset in a blended environment.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You find it easy to obtain slides, videos, and assignments, which helps you stay on track with the course.
#
# ### 3. Main Challenges
# - **Assessment & Workload** – You experience frustration when a quiz question cannot be changed after you realize a mistake, making the assessment feel restrictive.
# - **Learning Resources & Environment** – The current setup of resources and study spaces sometimes hinders smooth learning.
#
# ### 4. Personalized Recommendations
# | Recommendation Tag | Title | What to Do |
# |--------------------|-------|------------|
# | **content_access** | Strengthen access to learning materials | Ensure that all slides, videos, reference links, and practice exercises are uploaded **early** in the module so you can review them before and after class. |
# | **learning_environment** | Improve learning resources and environment | Ask the instructor to organize course files in clearly labeled folders, keep resources up‑to‑date, and provide guidance on optimal study spaces (e.g., quiet corners, ergonomic seating). |
# | **workload_support** | Manage workload and assessment pressure | Request clearer deadlines and a balanced mix of online and in‑person tasks. Suggest that quizzes allow a brief review window or a “reset” option for questions you later identify as incorrect. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course’s online repository; note any missing slides or videos. Send a brief email to the instructor requesting early upload of upcoming materials. |
# | **Day 3–4** | Create a personal folder structure that mirrors the course layout (e.g., Lectures | Readings | Exercises). Move existing files into these folders for quick access. |
# | **Day 5** | Test the current quiz interface. If a question feels unclear, jot down the issue and discuss it with the tutor during the next office hour. |
# | **Day 6–7** | Identify a comfortable, low‑distraction study spot on campus or at home. Adjust lighting and seating as needed. |
# | **Day 8** | Draft a short suggestion (1‑2 sentences) for the instructor about adding a brief “review” period after each quiz question. Submit it via the course feedback form. |
# | **Day 9–10** | Review upcoming assignment deadlines; add them to your digital calendar with reminders 48 hours in advance. |
# | **Day 11–14** | Reflect on how the earlier access to materials and the improved study environment affect your quiz performance. Note any remaining frustrations and plan a follow‑up discussion with the tutor. |
#
# Stay proactive and keep communicating with your instructors—your engagement is a key driver of success in a blended learning setting!

# %% [markdown]
# ## Student ID: `p20230009`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "learning_environment", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230009*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Highly Engaged (Active) Learners” segment. Your open‑ended responses show a strong appreciation for blended learning’s flexibility, access to materials, and overall effectiveness. At the same time, you recognize that these benefits depend on good pedagogy, clear resources, and personal motivation.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | Value the ability to obtain slides, videos, and references quickly. |
# | **Flexibility & Time Management** | Appreciate that blended formats let you study when it fits your schedule. |
# | **Learning Convenience & Effectiveness** | See blended learning as a more engaging and effective way to learn. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you noted |
# |-------|----------------|
# | **Learning Resources & Environment** | Concern that poorly organized or outdated resources can hinder learning. |
# | **Motivation & Self‑Discipline** | Need reliable structures to stay motivated and avoid isolation. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|-----------------|
# | **Strengthen access to learning materials**<br>*Upload slides, videos, references, exercises, and course materials early.* | Guarantees the flexible access you value and prevents gaps in resources. |
# | **Improve learning effectiveness**<br>*Combine online review materials with in‑person explanation, practice, and feedback.* | Marries the convenience of online review with the depth of face‑to‑face interaction, boosting understanding. |
# | **Improve learning resources and environment**<br>*Organize materials clearly, keep resources up‑to‑date, enhance study spaces, and ensure classroom comfort.* | Addresses your concern about resource quality and creates a smoother learning experience. |
# | **Support motivation and self‑discipline**<br>*Use weekly check‑ins, reminders, progress tracking, and structured study schedules.* | Provides the external structure that helps you stay on track and motivated. |
# | **Support self‑paced learning**<br>*Provide recorded lessons, weekly learning paths, and materials you can review at your own pace.* | Reinforces the flexibility you enjoy while allowing you to control the speed of your study. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Review the course’s online repository; note any missing slides or videos. | Identify gaps in material access. |
# | 2 | Attend the first in‑person session and request a brief recap of key concepts. | Blend online review with live explanation. |
# | 3 | Set up a personal study schedule (30 min × 3 days) and use the platform’s progress tracker. | Build routine and monitor motivation. |
# | 4 | Provide feedback on the organization of resources and suggest any needed updates. | Help improve the learning environment for yourself and peers. |
#
# Follow these steps, and you’ll maximize the strengths of blended learning while addressing the challenges you’ve identified. Keep leveraging your high engagement—your proactive approach will make the blended experience both effective and enjoyable.

# %% [markdown]
# ## Student ID: `p20240018`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** p20240018
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values **learning convenience and effectiveness**. You enjoy building soft‑skills and appreciate personalized learning experiences. Your main challenge is **information overload** when multiple sources overlap, which can make assessments and workload feel heavy.
#
# ---
#
# ### 2. Main Strengths
# - Strong motivation to learn actively.
# - Good at developing soft‑skills through personalized approaches.
# - Appreciates convenient, effective learning resources.
#
# ---
#
# ### 3. Main Challenges
# - Overlap of information during discussions leads to overload.
# - Managing the volume and timing of assessments and assignments.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What to Do | Why It Helps |
# |----------------|------------|--------------|
# | **Improve learning effectiveness** | • Use online review materials (e.g., short videos, summaries) **before** in‑person sessions.<br>• During class, focus on explanation, guided practice, and immediate feedback. | Combines the flexibility you like with the clarity of face‑to‑face interaction, reducing overload. |
# | **Manage workload and assessment pressure** | • Create a clear weekly schedule that lists all deadlines.<br>• Align online tasks (quizzes, readings) with the topics covered in upcoming face‑to‑face sessions.<br>• Break larger assignments into smaller, timed milestones. | Gives you a transparent view of what’s due, spreads effort evenly, and links online work directly to classroom learning. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the syllabus and note every assignment deadline in a digital planner. |
# | **Tuesday** | Watch the recommended online review videos for this week’s topic. |
# | **Wednesday** | Attend the in‑person class; focus on the teacher’s explanations and ask for quick practice activities. |
# | **Thursday** | Complete the short online quiz that matches Wednesday’s material. |
# | **Friday** | Break any upcoming larger assignment into 2‑3 sub‑tasks and set mini‑deadlines. |
# | **Weekend** | Reflect on what information felt overlapping; note any confusing points to ask about next class. |
#
# Repeat this cycle each week, adjusting the planner as new tasks appear. By pairing concise online reviews with focused classroom practice and keeping a clear schedule, you’ll maintain high engagement while reducing overload.

# %% [markdown]
# ## Student ID: `p20250031`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250031*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can control the pace of study and when digital tools are available to support your learning.
#
# ### 2. Main Strengths
# - **Digital Skills Development** – you appreciate opportunities to learn and use new digital tools.
# - **Flexibility & Time Management** – you value being able to study at your own speed.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – slow campus Wi‑Fi hampers your online work.
# - **Motivation & Self‑Discipline** – you would like stronger motivation to stay focused.
#
# ### 4. Personalized Recommendations
#
# | Area | What the recommendation means for you | Suggested actions |
# |------|----------------------------------------|-------------------|
# | **Develop digital learning skills** | Get targeted guidance on the learning‑management system (LMS), online resources, and research tools. | • Attend a short “LMS‑tips” workshop or watch the recorded tutorial.<br>• Explore the university’s digital‑research guide. |
# | **Support motivation and self‑discipline** | Use structured check‑ins and progress tracking to keep momentum. | • Set a weekly study schedule and share it with a peer or tutor.<br>• Enable automated reminders in the LMS.<br>• Take part in a brief weekly check‑in (10 min) with your course mentor. |
# | **Support self‑paced learning** | Access recorded lessons and clear weekly learning paths that you can review anytime. | • Use the repository of recorded lectures for review.<br>• Follow the weekly learning path posted in the course module. |
# | **Improve technical access and reliability** | Ensure you can study even when Wi‑Fi is slow and get quick help for technical problems. | • Download offline copies of key materials when you have good connectivity.<br>• Keep the university’s tech‑support contact handy and report Wi‑Fi issues promptly.<br>• Use campus hotspots or library computers as backup connections. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Watch the 15‑minute LMS tutorial (link in Canvas). |
# | **Day 2** | Download this week’s lecture videos for offline use. |
# | **Day 3** | Create a simple weekly study schedule (30 min) and share it with a study buddy. |
# | **Day 4** | Set up LMS reminders for assignment deadlines. |
# | **Day 5** | Attend the “Digital Research Tools” mini‑workshop (online or in‑person). |
# | **Day 6** | Test the campus Wi‑Fi speed; note any problems and submit a ticket to IT. |
# | **Day 7** | Do a 10‑minute self‑check‑in: review what you’ve completed and adjust the schedule if needed. |
# | **Week 2** | Repeat the check‑in on Day 14; continue using offline materials when Wi‑Fi is slow. |
#
# ---
#
# By focusing on these four areas—digital skill building, motivation support, self‑paced resources, and reliable technical access—you can make the most of your highly engaged learning style while overcoming the current challenges. Good luck, and remember the university’s support services are there to help you succeed!

# %% [markdown]
# ## Student ID: `p20240059`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "motivation", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240059*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. Your own comments highlight two key points:
#
# * **Strength:** You appreciate the **enhanced flexibility and accessibility** that blended learning gives you.
# * **Challenge:** You sometimes **forget the schedule**, which can affect motivation and workload management.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What it means for you |
# |-------|-----------------------|
# | **Access to Learning Materials** | You value being able to reach slides, videos, and other resources whenever you need them. |
# | **Flexibility & Time Management** | The ability to study at different times works well for your active learning style. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What it looks like |
# |-------|--------------------|
# | **Assessment & Workload** | Keeping track of deadlines and balancing assignments can feel stressful. |
# | **Motivation & Self‑Discipline** | Forgetting the schedule can reduce momentum and make it harder to stay on track. |
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | How to apply it |
# |----------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | • Upload slides, videos, reference links, and practice exercises **early** in the week.<br>• Keep a central repository (e.g., LMS folder) that you can revisit anytime. |
# | **Support motivation and self‑discipline** (motivation) | • Set up **weekly check‑ins** (e.g., a short 5‑minute self‑review or a reminder from the tutor).<br>• Use a **progress tracker** or checklist to see what’s completed.<br>• Create a **structured study schedule** with fixed study blocks and reminders. |
# | **Support self‑paced learning** (self_paced) | • Provide **recorded lessons** that you can pause and replay.<br>• Follow a **weekly learning path** that outlines what to study each day, but lets you adjust the pace as needed. |
# | **Manage workload and assessment pressure** (workload_support) | • Ensure assignments are **balanced** across the term and clearly **labelled with deadlines**.<br>• Align online tasks with in‑person sessions so you know when each piece fits into the overall schedule. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the week’s uploaded materials; add any missing resources to the LMS folder. |
# | **Tuesday** | Create a simple study schedule (2‑hour blocks) and set calendar reminders. |
# | **Wednesday** | Complete the first checkpoint of the progress tracker; note any upcoming deadlines. |
# | **Thursday** | Watch the recorded lesson for the current topic; add notes to your personal folder. |
# | **Friday** | Attend the in‑person session; compare the online tasks with what was covered live. |
# | **Weekend** | Do a quick 10‑minute review of the week’s progress; adjust next week’s schedule if needed. |
# | **Repeat** | Follow the same pattern for the following week, adding any new assignments to the tracker as they appear. |
#
# By keeping materials easily accessible, using regular check‑ins, and balancing your workload, you’ll be able to maintain the high level of engagement you already show while reducing missed deadlines and motivation dips. Good luck, and enjoy the flexibility that blended learning offers!

# %% [markdown]
# ## Student ID: `p20240038`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240038*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can freely access course materials and submit work at your own pace.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value having slides, videos, references, and exercises available early, which supports your active engagement.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Occasional connectivity problems can interrupt your study flow.
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation (from rule‑based guidance) |
# |-----|--------------------------------------------|
# | **content_access** | **Strengthen access to learning materials** – Upload slides, videos, references, exercises, and other course resources **well before class sessions** so you can review them whenever you need. |
# | **tech_issue** | **Improve technical access and reliability** – Ensure you have **stable internet** (e.g., campus Wi‑Fi, hotspot, or data plan), provide **offline versions** of key materials, give **clear platform instructions**, and make **technical support** readily available. |
#
# ### 5. Short Action Plan
#
# | Week | Action | How it Helps |
# |------|--------|--------------|
# | 1 | Check that all course slides and videos are posted at least 48 hours before the lecture. | Lets you preview content and plan your study time. |
# | 2 | Download offline copies of essential readings and videos to a device you can use without internet. | Reduces disruption when connectivity drops. |
# | 3 | Test your internet connection (speed test) and identify a reliable backup (e.g., campus library Wi‑Fi, mobile hotspot). | Guarantees you can stay connected for live sessions and submissions. |
# | 4 | Review the platform’s “How‑to” guide and bookmark the technical‑support contact page. | Saves time troubleshooting and keeps you focused on learning. |
#
# By following these steps, you can keep leveraging your high engagement while minimizing the impact of technical hiccups. Keep the communication line open with your instructors—let them know if you need additional offline resources or support. Good luck!

# %% [markdown]
# ## Student ID: `p20240019`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["motivation", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240019*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** Learners who can work at their own pace but may need extra prompts to stay motivated and to overcome technical barriers.
#
# ### 2. Main Strengths
# - You are able to take the time you need to explore topics that feel comfortable to you. This self‑paced approach helps you build deeper understanding when you’re interested.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity can interrupt study sessions.
# - **Motivation & Self‑Discipline** – Low motivation and occasional dissociation make it harder to keep a regular study rhythm.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Motivation & Self‑Discipline** | • Set up **weekly check‑ins** with a tutor or study buddy to discuss goals and progress.<br>• Use **reminders** (calendar alerts or app notifications) for study blocks.<br>• Keep a simple **progress tracker** (e.g., checklist or spreadsheet) to see what you’ve completed.<br>• Follow a **structured study schedule** that allocates specific times for each subject. |
# | **Technical Access** | • Arrange for a **stable internet connection** (e.g., campus Wi‑Fi hotspot, mobile data plan, or library access).<br>• Download **offline versions** of lecture videos, readings, and assignments when you have good connectivity.<br>• Review the **platform instructions** early so you know how to navigate resources without extra help.<br>• Keep the university **technical support** contact handy for quick troubleshooting. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Create a weekly study timetable (30 min blocks) and add calendar reminders. |
# | **Day 2** | Identify a reliable internet spot (library, campus hub) and test download of one lecture for offline use. |
# | **Day 3** | Set up a simple progress tracker (paper sheet or app). |
# | **Day 4** | Schedule a 15‑minute check‑in with a peer or tutor for next Monday. |
# | **Day 5** | Review the learning platform’s “Getting Started” guide; note any questions. |
# | **Day 6‑7** | Follow the timetable for two study sessions; record completion in the tracker. |
# | **Week 2** | Repeat the schedule, add a brief reflection on motivation levels, and contact tech support if any connectivity problems arise. |
#
# Stick to the schedule, use the reminders, and keep a backup of materials offline. This routine will help you stay motivated and reduce disruptions caused by technical issues. Good luck!

# %% [markdown]
# ## Student ID: `p20240002`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** p20240002
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who quickly reviews lecture material and prepares thoughtful questions for lecturers. Your main concern is the reliability of your internet connection.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You can review slides and videos rapidly.
# - **Student Engagement:** You actively generate questions, showing strong involvement in class.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unstable Wi‑Fi can disrupt your study flow.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload slides, videos, reference links, exercises, and other course resources **early** in the module. | Gives you everything you need to review ahead of time, matching your fast‑review habit. |
# | **Engagement** | Include short quizzes, interactive games, practical tasks, and discussion prompts within each unit. | Keeps your active participation high and provides immediate feedback on the material you’re reviewing. |
# | **Technical Access** | Provide options for **offline** downloads of videos and PDFs, clear step‑by‑step platform guides, and a dedicated tech‑support channel. | Reduces the impact of unstable Wi‑Fi and ensures you can continue studying even when the connection drops. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the specific strengths and challenge you reported.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Check the course portal for any **offline download** options; download all available slides and videos. |
# | **Day 3–4** | Create a **personal question list** after each lecture (you already do this well). |
# | **Day 5** | Participate in the first **interactive quiz** or game posted for the current topic. |
# | **Day 6–7** | If Wi‑Fi is still unstable, contact the **technical support** service and request guidance on offline access. |
# | **Day 8–10** | Join a **discussion thread** or small‑group chat to share your questions and get peer feedback. |
# | **Day 11–14** | Review the uploaded **exercises** and attempt the practical task; note any technical hiccups and report them. |
#
# Follow this plan to leverage your strengths while minimizing technical disruptions. If you encounter any new issues, reach out to your instructor or the support team—they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `p20240072`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240072*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the ability to review materials ahead of class and to revisit resources online. You appreciate digital tools that make learning convenient and help you deepen your understanding of technology.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You find that having slides, videos, and references available online lets you study in advance and reinforces learning.
# - **Digital Skills Development:** Using a blended‑learning environment supports the growth of your digital research and technology skills.
# - **Learning Convenience & Effectiveness:** The flexibility of online resources enhances your overall learning experience.
#
# ### 3. Main Challenges
# - **Inconsistent Use of the LMS:** Some instructors rely on Telegram or printed copies and do not upload materials to the platform, making it hard to plan ahead.
# - **Unclear Deadlines & Submission Paths:** Assignments are often submitted via Google Drive without clear due dates, creating uncertainty.
# - **Limited Access to Materials:** Occasionally, resources are restricted or posted late, hindering your ability to review them before class.
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Ask instructors to upload slides, videos, references, and exercises **at least 1–2 weeks before the session** so you can prepare in advance. |
# | **Digital Skills** | Take short tutorials on the LMS (e.g., Moodle) that cover navigation, file download, and online research tools. |
# | **Interaction** | Participate in scheduled Q&A or discussion forums; suggest adding peer‑collaboration activities and quicker lecturer feedback. |
# | **Learning Effectiveness** | Combine the pre‑class online review with in‑person practice and feedback to reinforce concepts. |
# | **Learning Environment** | Request that course materials be organized in clearly labeled folders and that study spaces (both virtual and physical) be kept tidy and comfortable. |
# | **Learning Support** | Seek clearer assignment instructions, example solutions, and recorded walkthroughs that break tasks into step‑by‑step guides. |
# | **Technical Issues** | Ensure you have reliable internet; download offline copies of key resources when possible and know where to get technical help. |
# | **Workload Support** | Ask for a consolidated schedule that lists all deadlines; suggest balancing the number of online tasks with face‑to‑face activities. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course’s LMS page; note which materials are missing or posted late. |
# | **Day 3** | Send a polite email to the lecturer requesting early upload of upcoming week’s slides and videos (mention the 1–2 week lead time). |
# | **Day 4** | Join a short LMS tutorial (many universities offer a 30‑minute “Getting Started” video). |
# | **Day 5–7** | Participate in an online discussion or Q&A session; post at least one question about the current topic. |
# | **Day 8** | Create a personal folder structure that mirrors the course layout for easy navigation. |
# | **Day 9** | Download offline copies of all available materials for the next week. |
# | **Day 10** | Draft a simple checklist of assignment deadlines and share it with classmates for mutual tracking. |
# | **Day 11–14** | Review the new materials, complete practice exercises, and request feedback on any unclear points. |
#
# By following these steps, you can leverage your strong engagement while addressing the current gaps in material access, communication, and workload clarity. Keep communicating with your instructors—your proactive feedback helps improve the blended‑learning experience for everyone.

# %% [markdown]
# ## Student ID: `p20240040`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_effectiveness", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240040*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the ability to review material before class and enjoys the mix of online and face‑to‑face activities. Your open responses show strong appreciation for early access to resources, flexibility, and the opportunity to study at your own pace. At the same time, you note that staying motivated and disciplined during self‑study can be challenging.
#
# ---
#
# ### 2. Main Strengths
# | Strength theme | What you highlighted |
# |----------------|----------------------|
# | **Access to Learning Materials** | You like having slides, videos, and exercises available before class. |
# | **Flexibility & Time Management** | Being able to study when it suits you helps you prepare and review. |
# | **Student Engagement** | Combining online and in‑person formats makes the lessons clearer and more interactive. |
# | **Digital Skills Development** | Using digital tools supports independent learning. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge theme | What you reported |
# |-----------------|-------------------|
# | **Motivation & Self‑Discipline** | Maintaining focus during self‑study, especially without direct supervision, can be difficult. |
# | **Learning Clarity** | Occasionally you need clearer instructions or examples to stay on track. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|------------------|
# | **Strengthen access to learning materials** (content_access) | Instructors will upload slides, videos, references, and exercises **early** so you can review them before class. |
# | **Develop digital learning skills** (digital_skill) | Short guides on using the LMS, online research tools, and other educational technologies will boost your confidence in self‑study. |
# | **Increase learner engagement** (engagement) | Quizzes, games, practical tasks, and discussion prompts will keep you actively involved during both online and face‑to‑face sessions. |
# | **Improve learning effectiveness** (learning_effectiveness) | Materials you review online will be linked to in‑class explanations, practice activities, and timely feedback. |
# | **Improve clarity and learning support** (learning_support) | Instructors will provide clearer instructions, step‑by‑step guides, and recorded explanations to reduce confusion. |
# | **Support motivation and self‑discipline** (motivation) | Weekly check‑ins, reminder emails, progress trackers, and a suggested study schedule will help you stay on track. |
# | **Support self‑paced learning** (self_paced) | Recorded lessons and weekly learning paths let you revisit content at your own speed. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|------------------|
# | **1** | Access the **pre‑class folder** (slides, videos, exercises) uploaded by the instructor. | Gives you a head‑start on the upcoming topic. |
# | **2** | Complete the **digital tools tutorial** (LMS navigation, online research tips). | Builds confidence for independent study. |
# | **3** | Participate in a **quiz or interactive activity** during the live session. | Reinforces material and keeps motivation high. |
# | **4** | Attend a **weekly check‑in** (quick 5‑min meeting or online form) to review progress and set next week’s study goals. | Improves self‑discipline and tracks your learning. |
#
# Follow these steps, and you’ll capitalize on your strong engagement while gaining the structure and support needed to stay motivated and clear about the material. Good luck!

# %% [markdown]
# ## Student ID: `p20240048`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240048*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You describe yourself as a learner who enjoys picking up new skills through online resources and likes to prepare with digital material before coming to class. The main obstacle you face is unreliable campus internet, which sometimes prevents smooth access to those online resources.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You actively seek slides, videos, and other digital content.
# - **Digital Skills Development** – You are comfortable learning new tools and technologies.
# - **Learning Convenience & Effectiveness** – Preparing online before in‑person sessions helps you understand the material better.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Spotty campus Wi‑Fi limits your ability to reach online content when needed.
# - **Learning Resources & Environment** – Inconsistent access can make it harder to study efficiently on campus.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Get all course assets early so you can download them before class. | • Instructors will upload slides, videos, readings, and exercises at least a week in advance. <br>• Save copies to your laptop or a USB drive for offline use. |
# | **Develop digital learning skills** (digital_skill) | Boost confidence with the LMS and other online tools. | • Attend a short workshop or watch a tutorial on navigating the LMS, searching scholarly sources, and using collaboration apps. |
# | **Improve learning effectiveness** (learning_effectiveness) | Combine your online prep with active classroom work. | • Review the uploaded materials before class, then use class time for questions, practice problems, and feedback from the instructor. |
# | **Improve learning resources and environment** (learning_environment) | Make your study space and course resources clearer and more comfortable. | • Use the organized folders the instructor provides. <br>• Choose a quiet campus spot (library study rooms) where the Wi‑Fi is more reliable, or set up a personal study nook with good lighting. |
# | **Improve technical access and reliability** (tech_issue) | Reduce the impact of poor internet on your learning. | • Download needed files when you have a strong connection (e.g., at home or in the campus computer lab). <br>• Keep a list of technical support contacts; report connectivity problems promptly. <br>• Request offline versions of essential content if internet remains unstable. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Check the course’s online portal for any already‑uploaded materials. Download all slides and videos to your device. |
# | **Day 3** | Locate a reliable Wi‑Fi spot on campus (library or computer lab) and test the connection. |
# | **Day 4–5** | Watch a 15‑minute LMS tutorial (link provided by the university) and practice uploading a file. |
# | **Day 6** | Review the downloaded materials before the next in‑person class; write down at least three questions. |
# | **Day 7** | Attend class, focus on the instructor’s explanations, and ask your prepared questions. |
# | **Day 8–9** | If any new content is posted, download it immediately. |
# | **Day 10** | Contact technical support to report any recurring internet issues and ask about offline access options. |
# | **Day 11–14** | Repeat the cycle of pre‑class review, active participation, and offline backup. Adjust the study spot if needed. |
#
# ---
#
# **Remember:** Your proactive approach to using online materials is a strong advantage. By securing reliable access, sharpening your digital skills, and pairing online prep with active classroom work, you can turn a passive learning style into a more engaged and effective experience. If you need further help, reach out to your instructor or the university’s learning‑support centre. Good luck!

# %% [markdown]
# ## Student ID: `p20230038`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230038*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are classified as a **Highly Engaged (Active) Learner**. Your responses show that you value **easy access to online material** and you are comfortable using digital resources. The main challenge you mentioned is **internet connection** reliability.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having slides, videos, and other resources readily available online.
# - **Learning Convenience & Effectiveness** – You use digital content to study efficiently.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable or limited internet access can hinder your ability to use online resources consistently.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Keep all course content (slides, videos, readings, exercises) uploaded early so you can plan your study. | Check the course platform weekly for new uploads; download materials when you have a good connection. |
# | **Improve learning effectiveness** (learning_effectiveness) | Blend the online resources you already use with in‑person activities such as explanations, practice sessions, and feedback. | Attend scheduled tutorials or labs; use the online material as pre‑work, then apply what you learn during face‑to‑face time. |
# | **Improve technical access and reliability** (tech_issue) | Ensure you can study even when the internet is unstable. | • Download offline copies of lectures and readings when possible.<br>• Use campus Wi‑Fi or a reliable hotspot for critical sessions.<br>• Keep a quick‑reference guide for the learning platform and know how to contact technical support. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course platform and note which materials are already uploaded. |
# | **Day 3** | Download all available slides, videos, and readings to a local folder for offline use. |
# | **Day 4–5** | Attend the first in‑person tutorial; bring your downloaded materials to follow along. |
# | **Day 6** | Test campus Wi‑Fi or a personal hotspot; note any connectivity gaps. |
# | **Day 7** | Save the platform’s help page and technical‑support contact info on your phone. |
# | **Week 2** | Repeat the download‑review‑attend cycle for new content; use offline copies whenever the internet is slow. |
# | **End of Week 2** | Reflect: Did offline access help? Is the internet issue less disruptive? Adjust your plan accordingly. |
#
# ---
#
# By focusing on early material access, combining online and face‑to‑face learning, and preparing for internet interruptions, you can keep your high level of engagement while minimizing technical barriers. Good luck, and keep leveraging your strengths!

# %% [markdown]
# ## Student ID: `p20230035`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_environment", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230035*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You describe your learning experience as “easy and more efficient,” indicating that you value convenience and effectiveness. At the same time, you would like lectures and labs to be more interactive and fun, with activities such as games rather than only traditional formats.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness** – You are able to learn efficiently when the material is presented in a clear, streamlined way.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You feel current lectures and labs lack engaging, interactive elements.
# - **Learning Resources & Environment** – The study setting and resources could be more supportive and comfortable.
# - **Motivation & Self‑Discipline** – You would benefit from structures that keep you motivated and on track.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | How It Helps |
# |-------|-------------|--------------|
# | **Interaction** | Add short Q&A slots, small‑group discussions, and peer‑collaboration tasks; request quicker feedback from the lecturer. | Increases active participation and makes sessions feel less passive. |
# | **Learning Effectiveness** | Use a blend of online review videos or readings together with in‑person explanations, guided practice, and immediate feedback. | Reinforces concepts and lets you apply knowledge right away, boosting efficiency. |
# | **Learning Environment** | Keep digital and physical materials well‑organized; look for updated resources (e.g., interactive simulations); improve your study space (good lighting, comfortable seating). | A clearer, more comfortable environment reduces distraction and supports focused study. |
# | **Motivation & Self‑Discipline** | Set a weekly check‑in (e.g., a brief self‑review or a reminder app); track progress with a simple checklist or digital tracker; create a structured study schedule that includes short, varied activities. | Regular check‑ins and visible progress keep you motivated and help maintain a steady study rhythm. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify one online resource (video or quiz) that matches your next lecture topic. |
# | **Day 3** | Arrange a 10‑minute Q&A or discussion with a classmate after the lecture. |
# | **Day 4** | Re‑organize your digital folder and physical desk for the current module. |
# | **Day 5** | Set a weekly reminder (e.g., on your phone) to review what you learned on Friday. |
# | **Day 6–7** | Try a short, game‑based activity (e.g., Kahoot or Quizlet Live) for the lab material. |
# | **Week 2** | At the end of the week, complete a quick self‑check: note what worked, what felt more engaging, and adjust the next week’s schedule accordingly. |
#
# By integrating more interaction, combining online and face‑to‑face learning, improving your study environment, and using simple motivation tools, you can turn your already efficient learning style into an even more engaging and rewarding experience. Good luck!

# %% [markdown]
# ## Student ID: `p20240060`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240060*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Moderately Engaged (Passive) Learners** segment. This group typically follows the course content but may need extra support to stay motivated, interact with peers, and manage workload.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You appreciate having recordings of lectures available, especially when you cannot attend live sessions.
#
# ---
#
# ### 3. Main Challenges
# - **Assessment & Workload** – You feel there are too many assignments and would like tasks that connect more directly to real‑life problems.
# - **Learning Resources & Environment** – You would benefit from clearer, better‑organized materials and a more comfortable study setting.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|-----------------------|
# | **Strengthen access to learning materials** (content_access) | The instructor will upload slides, video recordings, reference links, and practice exercises **early** in the week so you can review them at your own pace. |
# | **Improve learning resources and environment** (learning_environment) | Course materials will be organized in a clear folder structure, and any outdated resources will be refreshed. Study spaces (both virtual and physical) will be optimized for comfort and focus. |
# | **Manage workload and assessment pressure** (workload_support) | Assignments will be balanced with clear deadlines, and online tasks will be aligned with what is covered in face‑to‑face sessions, reducing overload. |
#
# These recommendations are drawn directly from the evidence about your strengths, challenges, and the segment profile.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action |
# |------|--------|
# | **Week 1** | Check the course portal for the newly uploaded lecture slides and video recordings. Note any missing items and request them from the instructor. |
# | **Week 2** | Review the organized material folders; use the provided reference links to explore real‑life examples related to the topic. |
# | **Week 3** | Look at the updated assignment schedule. Mark all deadlines in your calendar and plan study sessions that match the in‑person class topics. |
# | **Week 4** | Provide feedback on the study environment (e.g., clarity of resources, comfort of study spaces) so further tweaks can be made. |
# | **Ongoing** | Keep a short weekly log of how the new resources and workload balance affect your understanding and stress level. Share this log with your tutor if you need additional support. |
#
# ---
#
# **Remember:** By taking advantage of early‑access materials, a clearer learning environment, and a balanced workload, you can turn passive engagement into more active, confident learning. If you encounter any difficulties, reach out to your instructor or learning support services—they are there to help you succeed.

# %% [markdown]
# ## Student ID: `p20230039`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230039*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Key strength you reported:** Flexibility (you manage your time well and appreciate being able to study when it suits you).
# - **Main challenge you reported:** Lack of interaction during online learning (you feel isolated and would like more communication with peers and instructors).
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – you are good at arranging your study schedule and can adapt to different learning formats.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – you experience limited opportunities to talk with classmates or receive quick feedback from lecturers in the online environment.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Increase interaction and communication** | Add more live Q&A sessions, group discussions, and peer‑collaboration activities. Seek faster feedback from your lecturer. | • Join scheduled discussion boards or virtual study groups.<br>• Participate in weekly live Q&A slots.<br>• Use the course’s chat or forum to ask questions and share ideas. |
# | **Support self‑paced learning** | Take advantage of recorded lessons and structured weekly learning paths that you can review at your own speed. | • Watch lecture recordings before or after live sessions.<br>• Follow the weekly learning roadmap provided by the instructor.<br>• Re‑visit materials whenever you need clarification. |
#
# These recommendations are drawn directly from the evidence for your segment and the tags identified for you (“interaction” and “self‑paced”).
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day/Week | Action |
# |----------|--------|
# | **Week 1 – Day 1** | Locate the course’s recorded lectures and download the weekly learning path. |
# | **Week 1 – Day 2** | Register for the upcoming live Q&A session (check the syllabus or LMS calendar). |
# | **Week 1 – Day 3** | Join a peer discussion group on the course forum; introduce yourself and post one question about the current topic. |
# | **Week 1 – Day 5** | Review the recorded lecture for the week and note any unclear points. |
# | **Week 2 – Day 1** | Attend the scheduled Q&A; ask the questions you noted. |
# | **Week 2 – Day 3** | Participate in a small‑group breakout discussion (if offered) or start a collaborative document with a classmate. |
# | **Week 2 – Day 5** | Request brief feedback from your lecturer on an assignment draft (use the LMS messaging tool). |
#
# Follow this simple plan, and you’ll strengthen the interaction you need while still benefiting from the flexibility you already excel at. Good luck!

# %% [markdown]
# ## Student ID: `e20210812`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210812*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** *Cluster 2 – Highly Engaged (Active) Learners*
# - You thrive when you can control the pace of study and have ready access to course materials.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You value being able to pause, rewind, and re‑watch online lectures, which lets you learn at a speed that works for you.
# - **Access to Learning Materials:** Having slides, videos, and references available supports your active study style.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You experience delays in getting feedback to digital queries, which can hinder timely progress.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | Why it helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Ensure that slides, videos, reference links, and practice exercises are uploaded **early** in the module. | Gives you the resources you need to review anytime, reinforcing your self‑paced approach. |
# | **Increase interaction and communication** | Add regular **Q&A sessions**, small‑group discussions, and peer‑collaboration activities. Request that lecturers provide **faster feedback** on digital questions. | Reduces the waiting time you currently face, keeping your learning momentum strong. |
# | **Support self‑paced learning** | Provide **recorded lessons** and a **weekly learning path** that outlines what to study and when, while allowing you to revisit any part of the content. | Aligns with your preference for controlling the pace and revisiting material as needed. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Check the course portal for any newly uploaded slides or videos; if missing, ask the instructor to post them early. |
# | **Day 3** | Join the first scheduled **online Q&A** or discussion forum; prepare 1–2 questions you need answered. |
# | **Day 4–5** | Review the week’s recorded lecture at your own speed, using pause/rewind as you prefer. |
# | **Day 6** | Pair with a classmate for a short peer‑review of an exercise; exchange feedback quickly. |
# | **Day 7** | Submit any pending digital queries and note the response time; if delayed, remind the lecturer of the need for faster feedback. |
# | **Week 2** | Follow the **weekly learning path** provided by the instructor; adjust it if you need more time on a topic. |
# | **End of Week 2** | Reflect on how earlier material access and quicker interaction affected your study flow; share feedback with the course team. |
#
# Stay proactive in seeking timely feedback and make the most of the flexible, self‑paced resources available to you. Your active engagement is a strong asset—leveraging these recommendations will help you maintain momentum and deepen your learning.

# %% [markdown]
# ## Student ID: `p20230021`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["engagement", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** p20230021
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate the blended‑learning model for its **flexibility**, the way it **enhances learning effectiveness**, and its potential to **engage students**.
#
# **Main Challenges**
# You note that **inconsistent internet/technology access** can hinder participation and timely completion of tasks. You also mentioned concerns about **assessment workload** and the clarity of learning resources.
#
# **Personalized Recommendations**
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Engagement** | Add short quizzes, quick games, or brief discussion prompts to each online module. | Keeps you actively involved and makes the passive parts of the course more interactive. |
# | **Learning Effectiveness** | Pair the online review materials with short, in‑person practice sessions where you receive immediate feedback. | Reinforces concepts and bridges the gap between theory and application. |
# | **Learning Environment** | Use a clearly organized folder structure for all course files and choose a quiet, comfortable study spot. | Reduces distraction and makes it easier to locate resources when you study at your own pace. |
# | **Learning Support** | Look for recorded explanations, step‑by‑step guides, and concrete examples provided by the instructor. | Improves clarity and helps you work through difficult topics independently. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths; review any segment that feels unclear before the next class. | Lets you control the speed of your study and fit learning around other commitments. |
# | **Technical Issues** | When possible, download offline copies of readings and videos ahead of time; contact the campus IT helpdesk for Wi‑Fi or device support. | Guarantees access even if your internet connection is unstable. |
# | **Workload Support** | Keep a personal calendar with all assignment deadlines clearly marked; ask the instructor to clarify any overlapping tasks. | Helps you balance online and face‑to‑face work and reduces assessment pressure. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Set up a study space** – Choose a quiet corner, organize digital folders, and test your internet speed.
# 2. **Download offline materials** – Save the next week’s readings and videos to avoid connectivity problems.
# 3. **Create a weekly schedule** – Mark lecture times, quiz deadlines, and dedicated review slots for recorded lessons.
# 4. **Engage with one interactive activity** – Complete a quiz or join a short discussion for the upcoming module.
# 5. **Reach out for support** – If you encounter technical or workload issues, contact the IT helpdesk or your course tutor within the first week.
#
# By following these steps, you can leverage the flexibility you value while minimizing the technical and workload challenges you identified. Good luck, and remember that the resources and support are there to help you succeed!

# %% [markdown]
# ## Student ID: `p20230018`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_environment", "motivation", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230018*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from clearer learning environments, motivation support, and reliable technical access.
#
# ### 2. Main Strengths
# - You value having **more time for project building**, which shows a preference for deeper, hands‑on work.
#
# ### 3. Main Challenges
# - **Unstable Wi‑Fi** disrupts your study flow and lowers motivation.
# - You highlighted the need for the university to monitor and improve Wi‑Fi speed.
# *(Your challenge description was positive in tone, indicating you are proactive about finding a solution.)*
#
# ### 4. Personalized Recommendations
#
# | Area | What the recommendation suggests | How it helps you |
# |------|----------------------------------|------------------|
# | **Learning Environment** | Organize course materials clearly, keep resources up‑to‑date, and improve study spaces for comfort. | Makes it easier to locate what you need for project work, reducing friction and keeping you focused. |
# | **Motivation & Self‑Discipline** | Use weekly check‑ins, reminders, progress tracking, and a structured study schedule. | Gives you regular prompts and a visible record of progress, supporting the motivation you need when connectivity issues arise. |
# | **Technical Access (Tech Issue)** | Provide stable internet access, offer offline versions of key materials, give clear platform instructions, and ensure quick technical support. | Reduces the impact of Wi‑Fi instability, letting you continue project work without interruption. |
#
# ### 5. Short Action Plan
#
# | Week | Action | Resources / Support |
# |------|--------|----------------------|
# | **1** | Check the university’s Wi‑Fi status portal; note any “dead zones” on campus. | Campus IT help desk |
# | **2** | Download offline copies of upcoming lecture slides and readings. | Course LMS “offline” feature |
# | **3** | Set a **weekly check‑in** (e.g., 15 min every Friday) to review project milestones and update a simple progress log. | Personal planner or digital app (e.g., Trello) |
# | **4** | Arrange a meeting with a learning‑support advisor to discuss optimal study‑space setup and any needed material updates. | Learning Support Center |
# | **Ongoing** | Use reminders (phone or calendar) to follow the structured study schedule; contact technical support promptly if Wi‑Fi drops. | Campus tech support hotline |
#
# ---
#
# **Remember:** By improving your study environment, keeping motivation tools in place, and securing reliable technical access, you’ll be able to make the most of the extra project time you value. If you encounter any new obstacles, reach out to the relevant campus services—they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `p20230031`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230031*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners who value self‑study time, need clear structure, and benefit from additional support to stay motivated and interact with course material.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You appreciate having more time for self‑study, which helps you absorb material at your own pace.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unstable Wi‑Fi disrupts access to online resources.
# - **Learning Resources & Environment:** The current online setup makes it harder to study efficiently.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Learning Effectiveness** | Pair the online review materials you already use with brief in‑person sessions where the instructor explains key concepts, gives you practice tasks, and provides feedback. This mix reinforces what you study on your own. |
# | **Learning Environment** | Ask the university to organize digital materials in a clear, easy‑to‑navigate way and keep them up‑to‑date. When studying on campus, look for quiet, comfortable study spaces (e.g., library rooms) that support focused work. |
# | **Technical Access** | Request stable campus Wi‑Fi or use the university’s offline download options for lectures and readings. Keep a copy of essential files on your device for times when the connection drops. Familiarize yourself with the platform’s help guides and know where to get quick technical support. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Identify one online module you’ll review this week. Download the videos/reading PDFs for offline use. |
# | **Day 3** | Attend a short in‑person review session (or schedule a 15‑minute office hour) to discuss the module’s key points and get feedback. |
# | **Day 4–5** | Locate a quiet study space on campus (library study room or designated lounge) and set it up for focused work. |
# | **Day 6** | Test the campus Wi‑Fi in that space; if it’s unstable, report the issue to IT and note alternative spots with better connectivity. |
# | **Day 7** | Review the downloaded material again, applying any feedback received. |
# | **Week 2** | Repeat the cycle with a new module, gradually building a habit of combining offline study, in‑person clarification, and a reliable study environment. |
#
# ---
#
# **Remember:** Leveraging your strength of self‑study while securing stable internet and a well‑organized learning environment will make your blended courses more effective and enjoyable. If you encounter any technical problems, contact the university’s IT help desk promptly—they’re there to support you. Good luck!

# %% [markdown]
# ## Student ID: `p20240058`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240058*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you’ve shared:** You describe yourself as “flexible,” and you note occasional “technical issues” that affect your study.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You are able to adapt your schedule and manage your learning time well.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity or platform problems sometimes interrupt your study flow.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | What to do |
# |----------------|------------------|------------|
# | **Support self‑paced learning** | Your flexibility means you can benefit from materials you can access whenever you need them. | • Use recorded lectures and weekly learning paths that are available 24/7.<br>• Review notes, slides, or quizzes at your own speed. |
# | **Improve technical access and reliability** | Reducing technical interruptions will let your engagement stay high. | • Take advantage of any university‑provided stable internet or offline download options.<br>• Keep a copy of essential readings and videos for offline study.<br>• Follow the platform’s quick‑start guide and contact technical support when problems arise. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the repository of recorded lessons and download the next week’s videos for offline use. |
# | **Day 3** | Create a personal weekly learning path (e.g., “Monday – lecture 1; Tuesday – quiz”). |
# | **Day 4–5** | Test the campus Wi‑Fi hotspot or request a loaner hotspot from IT to ensure a stable connection. |
# | **Day 6** | Review the platform’s troubleshooting guide; bookmark the tech‑support contact. |
# | **Day 7–14** | Follow your self‑paced schedule, using offline materials when connectivity drops. Note any technical hiccups and report them promptly. |
#
# ---
#
# **Remember:** Your flexibility is a strong asset—use it to shape a learning routine that works for you, and address technical barriers early so they don’t disrupt your progress. If you need further help, reach out to your course facilitator or the university’s IT support desk. Good luck!

# %% [markdown]
# ## Student ID: `e20210601`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "learning_environment", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210601
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You value **flexibility and time‑management**, appreciating the ability to learn at your own pace.
# - You are naturally **highly engaged**, enjoying interactive and practical activities that keep you motivated.
#
# **Main Challenges**
# - Maintaining **self‑discipline** can be tough when studying independently.
# - Reliable **technology and internet access** are sometimes a barrier, and you may feel isolated without a supportive learning environment.
#
# **Personalized Recommendations**
#
# | Area | What to Do (based on the rule‑based advice) |
# |------|---------------------------------------------|
# | **Engagement** | Incorporate quizzes, games, practical tasks, discussions, and other interactive activities into your study routine to keep motivation high. |
# | **Learning Environment** | Keep your study materials well‑organized, update any outdated resources, and create a comfortable, distraction‑free workspace (e.g., a tidy desk, good lighting). |
# | **Motivation & Self‑Discipline** | Set up weekly check‑ins or brief meetings (with a peer or tutor), use reminders, track your progress in a simple log, and follow a structured weekly schedule. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths; review videos or readings as needed to reinforce understanding. |
# | **Technical Access** | Ensure you have a stable internet connection where possible; download offline copies of essential materials, follow clear platform guides, and reach out to technical support early if issues arise. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Create a weekly schedule** (30 min each Sunday) that blocks time for:
#    - Watching recorded lessons
#    - Completing interactive quizzes or games
#    - A 15‑minute check‑in with a study buddy or tutor.
#
# 2. **Set up your study space**: declutter your desk, add good lighting, and keep all digital resources in a single, well‑named folder.
#
# 3. **Test your internet**: run a speed test; if it’s unstable, download the week’s videos and readings for offline use.
#
# 4. **Track progress**: use a simple spreadsheet or app to mark completed activities, quiz scores, and any technical issues you encounter.
#
# 5. **Reach out for help**: note any platform problems and contact the university’s tech support within the first 24 hours of the issue.
#
# By following these steps, you’ll leverage your strong engagement while building the structure and technical reliability needed for successful self‑paced, blended learning. Good luck!

# %% [markdown]
# ## Student ID: `p20250054`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_effectiveness", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250054*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. You value being able to **access lecture materials online at any time and place**, which gives you flexibility and convenience in managing your study schedule. Your main difficulty is **unstable internet connectivity**, which can interrupt your online learning.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You appreciate having slides, videos, and other resources available online.
# - **Flexibility & Time Management:** The ability to study whenever you choose helps you stay organized.
# - **Learning Convenience & Effectiveness:** Online review supports your understanding of the content.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Poor or unreliable internet can limit your ability to use online resources consistently.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What It Means for You |
# |----------------|-----------------------|
# | **Strengthen access to learning materials** | Instructors should upload slides, videos, references, and exercises **early** so you can download them before class. |
# | **Improve learning effectiveness** | Pair the online review materials with **in‑person explanations, practice activities, and timely feedback** to deepen understanding. |
# | **Support self‑paced learning** | Use **recorded lessons and weekly learning paths** that let you study at your own speed and revisit difficult topics. |
# | **Improve technical access and reliability** | Seek **offline versions of key resources**, clear instructions for the learning platform, and quick technical support when connectivity problems arise. |
#
# These suggestions are drawn directly from the evidence about your strengths, challenges, and the recommendation tags assigned to your segment.
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action |
# |------|--------|
# | **1** | Download all available lecture slides and videos to a local device (e.g., laptop, tablet). |
# | **2** | Follow the weekly learning path provided by the instructor; schedule 30 min review sessions for each recorded lesson. |
# | **3** | Identify any topics that need extra practice and attend the in‑person session for hands‑on feedback. |
# | **4** | Test the university’s offline material package or request downloadable copies; note any technical issues and contact support promptly. |
# | **Ongoing** | Keep a brief log of internet problems and the resources you accessed offline to share with the teaching team for further improvements. |
#
# By following this plan, you can keep leveraging your strong engagement and flexibility while minimizing the impact of technical disruptions. Good luck, and keep up the active learning!

# %% [markdown]
# ## Student ID: `e20211376`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211376*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility and the rich variety of resources that blended learning can offer. You appreciate having easy access to course materials and like to manage your study time independently.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You recognize that blended learning gives you quick access to slides, videos, and other resources.
# - **Flexibility & Time Management** – You enjoy being able to study when it suits you and appreciate self‑paced options.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable internet connections make it hard to participate fully.
# - **Learning Resources & Environment** – You would like clearer organization of materials and more interactive, comfortable class settings.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Strengthen access to learning materials** | Course slides, videos, references and exercises will be uploaded early, so you can plan ahead. | Check the course portal at the start of each week for new content; download what you need for offline study. |
# | **Improve learning resources and environment** | Materials will be organized clearly, study spaces will be better equipped, and classes will be made more interactive. | Use the provided outlines and navigation guides; participate in interactive activities that the instructor schedules. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you review content at your own speed. | Follow the weekly learning path, re‑watch recorded sessions when needed, and complete practice exercises on your schedule. |
# | **Improve technical access and reliability** | The school will work on stable internet, offer offline copies of key resources, and give clear platform instructions plus tech support. | Download offline materials when you have good connectivity; keep the tech‑support contact handy for quick help. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Log into the course portal and locate the “Weekly Learning Path” for the upcoming week. Download all slides and videos for offline use. |
# | **Day 3** | Test your internet connection; if unstable, note the times it works best and plan to download materials during those windows. |
# | **Day 4–5** | Attend the first interactive class session; use the provided navigation guide to follow along. |
# | **Day 6** | Review the recorded lesson at your own pace and complete the associated exercises. |
# | **Day 7** | Reach out to the technical support team with any connectivity issues you experienced; keep their contact info for future reference. |
# | **Week 2** | Repeat the cycle: download, review, interact, and seek support as needed. Adjust your study schedule based on the flexibility the blended format provides. |
#
# By following these steps, you can make the most of the blended learning environment while minimizing technical hurdles and maximizing the flexibility you value. Keep communicating with your instructors and the support team—they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `p20250015`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** p20250015
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate how blended learning gives you **flexible access to materials**, helps you develop **digital skills**, and lets you manage your time by studying at your own pace. You see the mix of classroom and online resources as a way to make learning more convenient and effective.
#
# **Main Challenges**
# You notice that **interaction and communication** can be limited, that **technical or internet problems** sometimes disrupt study, and that instructions or explanations are not always clear enough for smooth learning.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to act on it |
# |----------------|----------------------|------------------|
# | **Strengthen access to learning materials** | Get all slides, videos, readings, and exercises early so you can review whenever you need. | Check the course LMS weekly for newly uploaded content; download files for offline study. |
# | **Develop digital learning skills** | Learn to use the LMS, online libraries, and other tools efficiently. | Attend any short “LMS‑tips” sessions; explore tutorials on digital research and citation tools. |
# | **Increase learner engagement** | Use interactive quizzes, games, and practical tasks to stay involved. | Complete weekly self‑check quizzes; join optional online polls or mini‑projects. |
# | **Increase interaction and communication** | More chances to ask questions, discuss with peers, and receive quick feedback. | Participate in scheduled Q&A slots; use discussion boards or study‑group chats; request clarification promptly. |
# | **Improve learning effectiveness** | Combine your online review with in‑person explanations and practice. | After watching a recorded lecture, attend the related face‑to‑face session to apply concepts and get feedback. |
# | **Improve clarity and learning support** | Clearer instructions, examples, and step‑by‑step guides. | Look for posted “how‑to” guides; if something is unclear, note the specific point and ask the lecturer directly. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you study when it suits you. | Follow the weekly roadmap posted by the instructor; replay recorded sessions before the next class. |
# | **Improve technical access and reliability** | Stable internet, offline options, and quick tech help reduce disruptions. | Save essential files for offline use; keep the university’s tech‑support contact handy; report any platform issues immediately. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1‑2:** Review the course LMS; download all current materials and note any missing items.
# 2. **Day 3‑4:** Watch the first recorded lecture, then attend the corresponding in‑person session and complete the associated quiz.
# 3. **Day 5:** Join a peer discussion board; post one question about the week’s topic.
# 4. **Day 6‑7:** Explore a short tutorial on using the LMS’s search and citation features.
# 5. **Week 2:** Test your internet connection; if unstable, arrange a backup (e.g., campus Wi‑Fi hotspot) and locate offline copies of key resources.
# 6. **End of Week 2:** Reflect on which interactive activity helped you most and plan to repeat it for the next module.
#
# By following these steps, you’ll build on your existing strengths while addressing the interaction, clarity, and technical issues that currently limit your learning experience. Good luck!

# %% [markdown]
# ## Student ID: `e20211443`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211443*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when learning is flexible and can fit around your schedule.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate that blended learning lets you organise study time more freely than a traditional classroom.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You miss regular face‑to‑face contact with lecturers and peers, which can make long solo study sessions feel isolating.
# - **Motivation & Self‑Discipline** – Working alone for extended periods sometimes reduces your motivation.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | How It Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and online group discussions.<br>• Participate in peer‑collaboration activities (e.g., breakout rooms, shared documents).<br>• Request quicker feedback from lecturers on assignments. | Increases contact with instructors and classmates, reducing feelings of isolation. |
# | **Motivation & Self‑Discipline** | • Set up weekly check‑ins (self‑review or with a study buddy).<br>• Use reminders and a simple progress‑tracking tool (e.g., checklist or digital planner).<br>• Follow a structured study schedule that blocks specific times for each task. | Keeps you accountable, maintains momentum, and makes progress visible. |
# | **Self‑Paced Learning** | • Access recorded lectures and supplemental videos whenever needed.<br>• Follow the weekly learning path provided by the course, but feel free to adjust the pace to match your schedule.<br>• Review materials ahead of live sessions to come prepared for discussions. | Lets you leverage the flexibility you value while still staying on track. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the course’s weekly learning path and note any recorded sessions you’ll need to watch. |
# | **Tuesday** | Schedule a 30‑minute check‑in with a classmate or tutor; set a reminder in your calendar. |
# | **Wednesday** | Attend the first live Q&A or discussion session; prepare one question in advance. |
# | **Thursday** | Watch the recorded lecture(s) for the week; add key points to a personal summary. |
# | **Friday** | Update your progress tracker (what you’ve completed, what’s next). |
# | **Weekend** | Reflect on motivation levels; adjust your study schedule if needed and plan the next week’s check‑in. |
# | **Repeat** | Continue the same pattern each week, adding more peer collaboration as you become comfortable. |
#
# ---
#
# By focusing on richer interaction, regular motivation checks, and using the self‑paced resources already available, you can keep the flexibility you enjoy while staying connected and motivated throughout the blended course. Good luck!

# %% [markdown]
# ## Student ID: `p20250061`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250061*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key Strength:** Values flexibility and time‑saving (e.g., “save time”).
# - **Main Challenge:** Finds it hard to stay focused when self‑control is low, indicating a need for stronger motivation and self‑discipline.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You appreciate learning options that let you manage your schedule efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline:** Maintaining focus can be difficult without external structure or reminders.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Looks Like in Your Courses |
# |----------------|--------------------------------------|
# | **Support motivation and self‑discipline** | • Weekly check‑ins (short surveys or brief video updates) <br>• Automated reminders for upcoming deadlines <br>• Progress‑tracking dashboards so you can see your achievements <br>• A structured study schedule that outlines what to tackle each week |
# | **Support self‑paced learning** | • Access to recorded lectures and tutorials you can replay anytime <br>• Weekly learning paths that outline the recommended order of topics <br>• downloadable resources (slides, notes, practice quizzes) for review at your own speed |
#
# These suggestions are drawn directly from the rule‑based recommendations for the “motivation” and “self‑paced” tags, which match both your segment profile and the strengths/challenges you reported.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Set up your personal study schedule using the weekly learning path. Mark key milestones in the progress tracker. |
# | **Week 2** | Attend the first weekly check‑in (10 min) to reflect on what’s working and where you need a reminder. |
# | **Week 3** | Review a recorded lesson you missed or want to deepen; note any questions for the next check‑in. |
# | **Week 4** | Evaluate your focus levels: adjust reminders or schedule blocks if needed. Celebrate any progress shown in the tracker. |
# | **Ongoing** | Continue weekly check‑ins, use recorded materials as needed, and keep the study schedule updated. |
#
# By combining regular motivation supports with flexible, self‑paced resources, you can leverage your time‑saving strength while building stronger focus and discipline. Good luck, and keep the momentum going!

# %% [markdown]
# ## Student ID: `p20230037`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230037*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical characteristics:** Learners who are able to study independently but tend to participate less in live interactions and may need extra cues to stay motivated and clear on course content.
#
# ### 2. Main Strengths
# - You noted that *“I can learn anytime,”* indicating good flexibility and the ability to study at your own pace.
#
# ### 3. Main Challenges
# - You mentioned that *“content should be more detailed,”* suggesting a need for clearer explanations and more supporting material.
#
# *(Because the open‑ended responses are brief, the recommendations below rely primarily on the characteristics of your segment.)*
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | Why it Helps |
# |-------|-------------|--------------|
# | **Interaction** | Join short Q&A sessions, take part in brief group discussions or peer‑collaboration activities, and request quicker feedback from the lecturer. | Increases engagement and gives you opportunities to clarify doubts promptly. |
# | **Learning Support** | Use resources that offer clear step‑by‑step guides, recorded explanations, and concrete examples. | Improves understanding of detailed content and reduces confusion. |
# | **Motivation** | Set up weekly check‑ins (e.g., a quick self‑review or a reminder), track your progress in a simple log, and follow a structured study schedule. | Keeps you on track and builds self‑discipline. |
# | **Self‑Paced Learning** | Take advantage of recorded lessons and weekly learning paths that you can revisit as needed. | Lets you study whenever you’re ready while still following a coherent course flow. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# 1. **Pick a weekly Q&A slot** – add it to your calendar and prepare 1–2 questions in advance.
# 2. **Create a simple progress tracker** – a checklist or spreadsheet with the week’s topics and a “completed” column.
# 3. **Watch one recorded lesson twice** – first for overview, second to note detailed points you missed.
# 4. **Join a peer discussion forum** – post a brief comment or question each day to start interacting.
# 5. **Schedule 15‑minute study blocks** – follow the weekly learning path, using the step‑by‑step guides provided.
#
# Follow these steps, and adjust as you see what works best for you. Small, consistent actions will help turn your flexibility into deeper, more active learning. Good luck!

# %% [markdown]
# ## Student ID: `e20211483`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "learning_support", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211483*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can manage your time flexibly and take an active role in your studies.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to adjust when and how you study, which helps you stay motivated and productive.
#
# ### 3. Main Challenges
# - **Learning Resources & Environment:** You need more organized and up‑to‑date materials (slides, videos, clear instructions).
# - **Learning Difficulty & Clarity:** Clear, step‑by‑step guidance and examples would make tasks easier to follow.
# - **Assessment & Workload:** You would benefit from better‑balanced assignments, clear deadlines, and alignment between online and face‑to‑face activities.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You |
# |----------------|-----------------------|
# | **Improve learning environment** | Ask your instructors to keep course folders well‑structured, use a single platform for all resources, and ensure study spaces (both virtual and physical) are comfortable and distraction‑free. |
# | **Improve learning support** | Look for recorded explanations, detailed examples, and step‑by‑step guides. When instructions are unclear, request clarification early. |
# | **Support self‑paced learning** | Take advantage of recorded lectures and weekly learning paths. Review videos or slides at your own speed before class to reinforce understanding. |
# | **Manage workload and assessment pressure** | Keep a personal calendar of assignment due dates, and compare it with the syllabus to spot any clustering of tasks. If deadlines feel tight, discuss possible extensions or re‑sequencing with the tutor. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course’s online portal; create a personal folder structure that mirrors the module layout. |
# | **Day 3–4** | Download all available slides and videos; note any missing items and email the instructor requesting the gaps. |
# | **Day 5** | Write down each upcoming assignment with its deadline; add buffer days for review. |
# | **Day 6–7** | Watch the first recorded lecture at a comfortable pace; pause to take notes and list any unclear steps. |
# | **Day 8** | Post your clarification questions in the discussion forum or during office hours. |
# | **Day 9–10** | Draft a weekly learning path (what you will study each day) and share it with a study buddy for accountability. |
# | **Day 11–12** | Complete the first assignment using the step‑by‑step guide you created; compare the workload with your calendar. |
# | **Day 13–14** | Reflect on what worked (e.g., organized resources, clear instructions) and adjust your plan for the next two weeks. |
#
# ---
#
# **Keep leveraging your flexibility** while ensuring the learning environment, support materials, and workload are well‑aligned. Small, consistent steps will help you stay engaged and succeed in both online and face‑to‑face components of your courses. Good luck!

# %% [markdown]
# ## Student ID: `p20240063`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20240063*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You appreciate the **flexibility** that blended formats give you for managing your study time.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value being able to study when it best fits your schedule.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You would like lecturers to respond more quickly.
# - **Learning Difficulty & Clarity:** Clear guidance and instructions are sometimes missing.
# - **Learning Resources & Environment:** Better‑organized materials and a comfortable study space would help.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Increase interaction and communication** | Add regular Q&A sessions, group discussions, and peer collaboration; ensure faster lecturer feedback. | Join scheduled live Q&A or discussion boards; ask classmates to form study groups; use the “quick‑question” feature in the LMS for faster replies. |
# | **Improve learning resources and environment** | Organize course materials clearly, keep resources up‑to‑date, and enhance the comfort of study spaces. | Follow the weekly “resource roundup” posted by the instructor; use the campus or library study zones that are set up for blended courses. |
# | **Improve clarity and learning support** | Provide clearer instructions, concrete examples, recorded explanations, and step‑by‑step guides. | Watch the short video walkthroughs that accompany each module; refer to the provided check‑lists before starting assignments. |
# | **Support self‑paced learning** | Access recorded lessons and weekly learning paths that you can review at any time. | Create a personal weekly schedule using the suggested learning path; replay recorded lectures when you need a refresher. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course’s “Weekly Learning Path” and note any upcoming Q&A sessions. |
# | **Day 3** | Join or form a small peer‑study group on the LMS discussion board. |
# | **Day 4–5** | Watch the recorded explanations for the current module; add any unclear points to a “questions list.” |
# | **Day 6** | Submit the questions list to the lecturer and request feedback within 48 hours. |
# | **Day 7** | Organize your digital folder according to the instructor’s recommended structure. |
# | **Day 8–10** | Attend the scheduled live Q&A or discussion; share one tip you found helpful with the group. |
# | **Day 11–14** | Reflect on the clarity of the instructions you received; note any remaining gaps and request a short step‑by‑step guide if needed. |
#
# By focusing on richer interaction, clearer resources, and leveraging the flexibility you already enjoy, you can turn the identified challenges into opportunities for even stronger engagement and success in your blended courses. Good luck!

# %% [markdown]
# ## Student ID: `e20211168`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211168*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** The flexibility of online study saves you time that would otherwise be spent travelling.
# - **What you find challenging:** You would like the course to be more attractive and fun, so you stay interested and avoid boredom.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when and where it suits you, which helps you manage your schedule efficiently.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Limited opportunities to talk with the teacher or peers can make the learning experience feel isolated.
# - **Motivation & Self‑Discipline** – Keeping the course engaging and staying on track without strong external prompts can be difficult.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | How to address it (based on rule‑based advice) |
# |-------|-------------------------------------------------|
# | **Interaction** | • Join live Q&A sessions and scheduled group discussions.<br>• Participate in peer‑collaboration activities (e.g., small project groups).<br>• Expect quicker feedback from the lecturer on assignments and questions. |
# | **Motivation** | • Use weekly check‑ins (short surveys or brief meetings) to set goals.<br>• Set up automated reminders for upcoming deadlines.<br>• Track your progress with a visual dashboard or checklist.<br>• Follow a structured study schedule that breaks the week into manageable blocks. |
# | **Self‑paced Learning** | • Access recorded lectures so you can review material at your own speed.<br>• Follow a weekly learning path that outlines what to study each day.<br>• Keep all course resources (slides, readings, quizzes) available for on‑demand review. |
#
# These three areas—interaction, motivation, and self‑paced study—directly target the challenges you mentioned and build on the flexibility you already enjoy.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **Week 1** | • Enroll in the first live Q&A session.<br>• Set up a personal study calendar with 30‑minute blocks for each topic.<br>• Activate reminder emails for assignment deadlines. |
# | **Week 2** | • Join a peer discussion group for one of your modules.<br>• Review the recorded lecture for a topic you found difficult.<br>• Complete the weekly check‑in survey and note any motivation hurdles. |
# | **Ongoing** | • Keep tracking progress on the course dashboard.<br>• Request feedback on any submitted work within 48 hours.<br>• Adjust your study schedule each week based on what works best. |
#
# By following these steps, you’ll increase engagement, stay motivated, and continue to benefit from the time‑saving flexibility of blended learning. Good luck, and enjoy the journey!

# %% [markdown]
# ## Student ID: `e20211565`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "learning_support", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211565*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the **Highly Engaged (Active) Learners** segment. This group typically makes good use of the flexibility that blended learning offers and is motivated to participate both online and face‑to‑face.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate that blended learning lets you study when it fits your schedule.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Inconsistencies between online content and face‑to‑face sessions make it hard to get clear, up‑to‑date information.
# - **Learning Resources & Environment** – Materials are sometimes unclear or not well organized, affecting how easily you can study.
# - **Learning Difficulty & Clarity** – Instructions and guidance differ between modes, leading to confusion.
# - **Assessment & Workload** – The workload feels uneven, and deadlines are not always clearly aligned across online and in‑person activities.
#
# ---
#
# ### 4. Personalized Recommendations
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | Add short Q&A slots, group discussions, and peer‑collaboration activities; request quicker feedback from lecturers. | Improves communication and reduces the uncertainty you experience when information changes. |
# | **Learning Environment** | Use a single, well‑structured repository for all course materials; ensure study spaces (both virtual and physical) are comfortable and clearly labeled. | Makes it easier to locate resources and reduces the feeling of “mixed messages.” |
# | **Learning Support** | Ask for clearer, step‑by‑step guides, recorded explanations, and concrete examples that match both online and face‑to‑face content. | Provides consistent instructions, so you know exactly what is expected regardless of the delivery mode. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths that you can revisit at your own speed. | Lets you use the flexibility you value while reinforcing concepts that may have been unclear in live sessions. |
# | **Workload Support** | Request a balanced schedule: clear deadlines, alignment of online tasks with in‑person work, and a reasonable number of assignments each week. | Helps you manage the overall workload and reduces pressure from mismatched assessments. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course’s online portal and locate a single folder where all materials are stored. If it’s missing, ask the lecturer to create one. |
# | **Day 3** | Join a peer‑study group (or start one) and schedule a 30‑minute virtual Q&A session to clarify any recent updates. |
# | **Day 4–5** | Download the recorded lectures for the current topic and create a personal “weekly learning path” (e.g., watch video → take notes → do practice questions). |
# | **Day 6** | Write a brief email to the lecturer outlining the specific points where online and face‑to‑face instructions differ, and request a consolidated guide. |
# | **Day 7** | Review upcoming assignment deadlines; make a simple calendar that aligns online tasks with face‑to‑face sessions. |
# | **Week 2** | Attend the first group discussion or peer‑collaboration activity; give feedback on how it helped clarify the material. |
# | **End of Week 2** | Reflect on whether the clarified resources and adjusted schedule have reduced confusion and workload stress. Adjust the plan as needed. |
#
# ---
#
# **Remember:** Your active engagement is a strong asset. By strengthening interaction, clarifying resources, and managing workload, you can make the most of the flexibility that blended learning provides. Good luck!

# %% [markdown]
# ## Student ID: `p20250063`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250063*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive in a blended environment because it gives you flexibility, quick access to materials, and opportunities to develop digital skills. You enjoy being able to review lessons online while still having face‑to‑face interaction with teachers.
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | You value having slides, videos, and exercises available early. |
# | **Digital Skills Development** | Blended learning helps you improve your technology abilities. |
# | **Flexibility & Time Management** | Studying both online and in class saves time and lets you learn at your own pace. |
# | **Student Engagement** | The mix of online and in‑person activities makes learning more interesting. |
#
# ### 3. Main Challenges
# | Theme | What you reported |
# |-------|-------------------|
# | **Interaction & Communication** | Sometimes instructions are unclear and you miss direct contact with teachers. |
# | **Internet & Technical Issues** | Unstable connection makes online sessions difficult. |
# | **Learning Difficulty & Clarity** | Lack of clear guidance can affect focus and understanding. |
# | **Motivation & Self‑Discipline** | Staying motivated is harder without strong structure. |
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|-----------------|
# | **Strengthen access to learning materials** – Upload slides, videos, references, and exercises early. | Guarantees the resources you need are ready whenever you want to review them. |
# | **Develop digital learning skills** – Offer short guides on using the LMS, online research tools, and educational tech. | Boosts the digital confidence you already enjoy building. |
# | **Increase learner engagement** – Include quizzes, games, practical tasks, and discussion prompts. | Keeps the class lively and matches your active learning style. |
# | **Increase interaction and communication** – Add live Q&A sessions, small‑group discussions, peer collaboration, and faster lecturer feedback. | Improves the direct contact you miss and clarifies instructions. |
# | **Improve clarity and learning support** – Provide step‑by‑step guides, recorded explanations, and concrete examples for each task. | Reduces confusion and helps you stay focused during online classes. |
# | **Support motivation and self‑discipline** – Use weekly check‑ins, automated reminders, progress dashboards, and a suggested study schedule. | Gives you a clear structure to maintain motivation. |
# | **Support self‑paced learning** – Make recorded lessons and weekly learning paths available for review at any time. | Aligns with your preference for flexible, self‑directed study. |
# | **Improve technical access and reliability** – Offer offline downloadable materials, clear platform instructions, and a help desk for connectivity issues. | Mitigates the impact of unstable internet on your learning. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | Check that all course slides and videos are uploaded to the LMS **at least 2 days before each class**. | Immediate access to materials for review. |
# | 2 | Attend a 30‑minute “Digital Tools” workshop (recorded for later use). | Faster navigation of LMS and online resources. |
# | 3 | Join a weekly **peer‑study group** that meets online for a 20‑minute Q&A after each lecture. | More direct interaction with classmates and quicker clarification of doubts. |
# | 4 | Set up a personal study schedule using the provided weekly learning path and enable automated reminders. | Better time management and sustained motivation. |
# | Ongoing | Download offline copies of key resources and contact the tech support desk whenever connectivity issues arise. | Reliable access regardless of internet stability. |
#
# ---
#
# **Remember:** Your active engagement is a strong asset. By tightening access to materials, improving communication, and adding clear structure, you can turn the current challenges into opportunities for even greater success in a blended learning environment. Good luck!

# %% [markdown]
# ## Student ID: `e20211258`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_effectiveness", "learning_support", "motivation", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211258*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate how blended learning gives you access to varied materials and makes lessons more interesting. At the same time, you find it hard to stay motivated online and to manage your time and workload.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value having slides, videos, and other resources available early.
# - **Learning Convenience & Effectiveness** – The mix of online and face‑to‑face formats helps you learn more independently.
# - **Student Engagement** – You notice that a variety of learning styles keeps lessons interesting.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Staying motivated during online parts can be difficult.
# - **Interaction & Communication** – You would like clearer, quicker communication with lecturers and peers.
# - **Learning Support & Clarity** – Instructions sometimes feel vague, making it harder to understand tasks.
# - **Assessment & Workload** – Managing deadlines and the amount of work feels stressful.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on evidence) |
# |------|--------------------------------|
# | **Content Access** | Lecturers should upload slides, videos, reference links, and practice exercises **well before class** so you can review them at your own pace. |
# | **Engagement** | Include short quizzes, interactive games, practical tasks, and discussion prompts in each module to keep you actively involved. |
# | **Interaction** | Schedule regular **Q&A sessions**, small‑group discussions, and peer‑collaboration activities; aim for faster feedback from the lecturer. |
# | **Learning Effectiveness** | Pair online review materials with in‑person explanations and guided practice, so concepts are reinforced through multiple modes. |
# | **Learning Support** | Provide **clear, step‑by‑step instructions**, concrete examples, and short recorded explanations for each assignment. |
# | **Motivation** | Use **weekly check‑ins** (e.g., a short survey or brief video call), automated reminders, and a visual progress tracker to help you stay on schedule. |
# | **Workload Support** | Align online tasks with face‑to‑face sessions, **balance the number of assignments**, and state all deadlines clearly at the start of each week. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Who’s Responsible |
# |------|--------|--------------------|
# | 1 | Review the course’s **uploaded materials** (slides, videos, exercises) before the first face‑to‑face session. | You |
# | 2 | Participate in the first **online quiz** and join a **peer discussion group**; note any unclear instructions. | You & Lecturer (provide feedback) |
# | 3 | Attend a **live Q&A**; submit any lingering questions. Lecturer sends a short recorded walkthrough of the upcoming assignment. | You & Lecturer |
# | 4 | Complete the weekly **progress check‑in** (self‑rating of motivation and workload); lecturer adjusts upcoming tasks if needed. | You & Lecturer |
#
# Follow this plan, and you should notice improved motivation, clearer guidance, and a more manageable workload while keeping the benefits you already enjoy from blended learning. Good luck!

# %% [markdown]
# ## Student ID: `e20211437`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211437*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You appreciate the **flexibility** of blended learning – being able to review materials anytime and still benefit from face‑to‑face interaction. At the same time, you notice **low engagement**, occasional **technical problems**, and moments when course materials feel unclear or poorly organized.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you value |
# |-------|----------------|
# | **Access to Learning Materials** | Ability to study at your own pace. |
# | **Flexibility & Time Management** | Convenience of reviewing content whenever needed. |
# | **Student Engagement** | Enjoyment of in‑person interaction when it occurs. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you experience |
# |-------|----------------------|
# | **Interaction & Communication** | Limited opportunities for Q&A and peer collaboration. |
# | **Internet & Technical Issues** | Unstable connections and platform glitches. |
# | **Learning Difficulty & Clarity** | Instructions and examples sometimes unclear. |
# | **Learning Resources & Environment** | Course resources feel disorganized; study spaces can be uncomfortable. |
#
# ---
#
# ### 4. Personalized Recommendations
# (These are drawn directly from the rule‑based suggestions for your segment.)
#
# | Recommendation | How it helps you |
# |----------------|------------------|
# | **Strengthen access to learning materials** – Upload slides, videos, references, exercises, and other resources **early** in the week. | Lets you plan your self‑paced study and reduces last‑minute scrambling. |
# | **Increase learner engagement** – Include short quizzes, games, practical tasks, and discussion prompts. | Keeps you actively involved and makes the material more memorable. |
# | **Increase interaction and communication** – Schedule regular Q&A sessions, small‑group discussions, and peer‑collaboration activities; provide quicker lecturer feedback. | Gives you clearer answers and more chances to connect with classmates. |
# | **Improve learning resources and environment** – Organize content with clear headings, update outdated files, and ensure study spaces (both online and physical) are comfortable and well‑equipped. | Makes it easier to locate what you need and study without distraction. |
# | **Improve clarity and learning support** – Offer step‑by‑step guides, recorded explanations, and concrete examples for each topic. | Reduces confusion and helps you follow the course flow. |
# | **Support self‑paced learning** – Provide recorded lessons and a weekly learning path that you can follow at your own speed. | Aligns with your preference for flexibility while keeping you on track. |
# | **Improve technical access and reliability** – Ensure stable internet options, provide offline copies of key materials, give clear platform instructions, and maintain responsive technical support. | Minimizes disruptions caused by connectivity or platform issues. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Who’s responsible |
# |------|--------|--------------------|
# | 1 | Check that all lecture slides and videos are uploaded **by Monday**. | Lecturer / Course admin |
# | 2 | Participate in a **short quiz** after each lecture to reinforce learning. | You |
# | 3 | Join a **peer‑discussion group** scheduled for Wednesdays; post any questions in the forum. | You & classmates |
# | 4 | Download **offline copies** of the week’s materials and test the university’s Wi‑Fi hotspot in the library. | You & IT support |
#
# Follow these steps, and you should notice smoother access to content, clearer instructions, more interaction with peers and lecturers, and fewer technical hiccups—helping you stay motivated and succeed in a blended learning environment.

# %% [markdown]
# ## Student ID: `e20210439`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210439
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# You appreciate the flexibility that blended learning offers. You value having access to materials that you can review at your own pace, and you recognize the benefit of keeping a personal connection with teachers and classmates.
#
# **Main Challenges**
# You notice inconsistency in how lecturers use blended tools, and you experience occasional technical problems (internet/device access). You would like the online components to be better linked to in‑class activities and clearer overall.
#
# **Personalized Recommendations**
#
# | Area | What to do | Why it helps you |
# |------|------------|------------------|
# | **Content Access** | Lecturers should upload slides, videos, references, exercises, and other course materials **early** in the week. | Gives you the freedom to study when it fits your schedule and reduces stress from waiting for resources. |
# | **Engagement** | Include short quizzes, quick games, practical tasks, and discussion prompts within each module. | Keeps you actively involved and makes the material feel less passive. |
# | **Interaction** | Add regular Q&A sessions, small‑group discussions, and peer‑collaboration tasks; aim for faster feedback from the lecturer. | Improves the connection between online and face‑to‑face classes and reduces the feeling of “just uploading slides.” |
# | **Learning Environment** | Organize all resources in a clear folder structure, keep them up‑to‑date, and ensure classroom spaces are comfortable for hybrid work. | Makes it easier to locate what you need and creates a smoother study environment. |
# | **Learning Support** | Provide step‑by‑step guides, clear examples, and short recorded explanations for complex topics. | Improves clarity and reduces difficulty when you study independently. |
# | **Self‑Paced Learning** | Offer recorded lectures and a weekly learning path that outlines what to study each day. | Lets you review material as many times as needed, matching your preferred pace. |
# | **Technical Issues** | Ensure a reliable internet connection on campus, offer offline downloadable versions of materials, and give clear instructions on how to use the learning platform plus quick tech support. | Minimises disruptions caused by connectivity or device problems. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Check the course portal** each Monday for newly uploaded slides, videos, and exercises.
# 2. **Create a personal weekly schedule** using the provided learning path; allocate 30‑45 min daily for review.
# 3. **Join the first Q&A session** (or propose one) to ask any unclear questions early.
# 4. **Download offline copies** of key materials if you anticipate internet issues.
# 5. **Participate in one interactive activity** (quiz, poll, or discussion) each week to boost engagement.
#
# By following these steps, you can make the most of blended learning’s flexibility while addressing the inconsistencies and technical hurdles you’ve identified. Good luck, and remember that the university’s support services are there to help you succeed!

# %% [markdown]
# ## Student ID: `e20210512`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210512*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You appreciate the flexibility that blended learning offers and value the ability to work at your own pace. At the same time, you feel the workload can become heavy when online and face‑to‑face tasks are not clearly linked, and occasional technical problems add friction.
#
# ### 2. Main Strengths
# - **Access & Flexibility:** You recognize that digital resources let you study when it suits you.
# - **Self‑Paced Learning:** You like being able to review slides, videos, and exercises at your own speed.
# - **Engagement Potential:** You see blended learning as a way to combine convenient online study with high‑impact in‑person mentorship.
#
# ### 3. Main Challenges
# - **Workload Balance:** Managing both online and classroom assignments can feel like a “double burden.”
# - **Content Integration:** Online materials are sometimes not clearly connected to what is covered in class.
# - **Technical Issues:** Unreliable internet or complex platforms create obstacles to smooth learning.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based tags) |
# |------|----------------------------------------|
# | **Content Access** | Upload all slides, videos, references, and exercises **early** so you can plan your study schedule. |
# | **Digital Skills** | Receive short guides on using the LMS, locating online resources, and basic digital research tools. |
# | **Engagement** | Participate in quizzes, quick games, and brief discussion prompts that link directly to the week’s topic. |
# | **Learning Effectiveness** | Use a two‑step approach: first review online materials, then attend the in‑person session for explanation, practice, and feedback. |
# | **Learning Environment** | Keep the course folder organized (clear headings, version dates) and make sure study spaces—both virtual and physical—are comfortable and free from distractions. |
# | **Learning Support** | Look for recorded explanations, step‑by‑step guides, and concrete examples that clarify assignments. |
# | **Self‑Paced** | Follow the weekly learning path provided by the instructor; you can replay recorded lessons whenever needed. |
# | **Technical Issues** | Take advantage of campus Wi‑Fi hotspots or download offline copies of key resources; contact the tech support desk for quick help. |
# | **Workload Support** | Ask the instructor to outline clear deadlines and to align online tasks with the topics covered in the next face‑to‑face class, reducing overlap. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Mon** | Check the course portal for the week’s uploaded materials; download any files you might need offline. |
# | **Tue** | Watch the recorded lecture at your own pace; note any questions for the upcoming class. |
# | **Wed** | Complete the short online quiz that reinforces the lecture content. |
# | **Thu** | Attend the in‑person session; focus on the practical tasks and ask for clarification on any confusing points. |
# | **Fri** | Review the instructor’s feedback and update your study notes; confirm the next assignment’s deadline. |
# | **Weekend** | Test your internet connection; if unstable, locate a campus hotspot or download backup materials for next week. |
# | **Next Mon** | Review the weekly learning path and adjust your personal schedule to balance online and face‑to‑face work. |
#
# By following these steps, you’ll keep your workload manageable, strengthen your digital confidence, and make the most of both online flexibility and in‑person interaction.
#
# *Feel free to reach out to your course coordinator or the university’s learning support team for any of the actions above.*

# %% [markdown]
# ## Student ID: `e20210975`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210975*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from clear, flexible access to materials and from added opportunities for interaction and support.
#
# ### 2. Main Strengths
# - **Access & Flexibility:** You appreciate being able to review lessons “from anywhere at any time.”
# - Themes identified: *Access to Learning Materials* and *Flexibility & Time Management*.
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You find mandatory video lessons where the lecturer only reads slides “not helpful.”
# - Theme identified: *Interaction & Communication*.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Strengthen access to learning materials** (content_access) | Ensure all slides, videos, references, and exercises are available early, so you can study when it suits you. | Look for a course “resources” folder; download the files at the start of the week and keep them organized for quick review. |
# | **Increase interaction and communication** (interaction) | Add live Q&A, group discussions, peer collaboration, and faster lecturer feedback to make lessons more engaging. | Participate in scheduled discussion boards or short live chat sessions; ask questions early and request brief feedback on assignments. |
# | **Support self‑paced learning** (self_paced) | Provide recorded lessons and weekly learning paths that let you progress at your own speed. | Follow the weekly roadmap, watch the recorded lectures when you’re ready, and pause/review sections as needed. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Locate the course’s “Resources” section; download all slides, videos, and reference links for the upcoming week. |
# | **Day 3** | Set up a personal study schedule (e.g., 1 hour each evening) using the weekly learning path provided by the instructor. |
# | **Day 4‑5** | Join the first live Q&A or discussion forum; prepare one question about the current topic. |
# | **Day 6‑7** | Review the recorded lecture at your own pace; pause and take notes on any unclear points. |
# | **Day 8‑10** | Share a brief summary or question in the peer‑collaboration space; request quick feedback from the lecturer. |
# | **Day 11‑14** | Reflect on what worked best (e.g., time of day, type of material) and adjust your schedule for the next week. |
#
# By focusing on easy access to materials, adding purposeful interaction, and using self‑paced resources, you can turn your flexibility into stronger learning outcomes while reducing the frustration with passive video lessons. Keep the plan simple, track your progress, and reach out for support whenever needed. Good luck!

# %% [markdown]
# ## Student ID: `p20250037`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250037*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a moderately engaged learner who appreciates the convenience of online study (quick access to information, digital‑skill development, and time‑saving). At the same time, you notice that distractions, unclear assignment instructions, limited device battery life, and occasional internet problems can hinder your progress. You also feel that more face‑to‑face interaction would help you stay motivated and understand the material better.
#
# ---
#
# ### 2. Main Strengths
# | What you value | Evidence |
# |----------------|----------|
# | **Access to learning materials** – you like being able to find answers on sites like Reddit or Quora. | “improve the digital using skill… know how to seek for answer online… save_time” |
# | **Digital skills development** – you feel the blended format helps you become more comfortable with online tools. | Same passage above |
# | **Flexibility & time management** – studying from anywhere saves you campus travel time. | Same passage above |
#
# ---
#
# ### 3. Main Challenges
# | What makes learning harder | Evidence |
# |----------------------------|----------|
# | **Distractions from devices & apps** (Telegram, YouTube, TikTok). | “sometimes can get distraction from what those devices or app like telegram youtube tiktok” |
# | **Unclear assignment explanations** → late submissions or giving up. | “lack of explanation on some assignments which lead to late submission” |
# | **Technical issues** – weak laptop battery, need for reliable Wi‑Fi. | “my laptop battery is not good… need to bring adapter… studying online requires a lot of things like wifi internet” |
# | **Limited interaction with lecturers** – you prefer more in‑person contact. | “in_person more can improve student understanding… reach to lecturers immediately” |
# | **Motivation & self‑discipline** – you notice laziness can set in without structure. | “reduce the laziness of student” |
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation follows the rule‑based tags that match your strengths and challenges.)
#
# | Recommendation | What to do |
# |----------------|------------|
# | **Strengthen access to learning materials** | Instructors should upload slides, videos, reference links, and practice exercises **early** in the week so you can review them before class. |
# | **Develop digital learning skills** | Short guides or short videos on how to use the LMS, search academic sources, and manage online tools will help you work more efficiently. |
# | **Increase interaction and communication** | Add scheduled Q&A sessions, small‑group discussions, and quicker lecturer feedback (e.g., via chat or short video replies). |
# | **Improve learning effectiveness** | Pair the online review materials with brief in‑person explanations or live demos, then give you time to practice and receive feedback. |
# | **Improve learning environment** | Organize course files in clearly labeled folders, keep resources up‑to‑date, and provide suggestions for comfortable study spaces (e.g., quiet corners in the library). |
# | **Improve clarity and learning support** | Provide step‑by‑step assignment guides, example solutions, and short recorded walkthroughs for complex tasks. |
# | **Support motivation and self‑discipline** | Use weekly check‑ins (email or app reminder), a simple progress tracker, and a suggested study schedule that aligns with your class timetable. |
# | **Support self‑paced learning** | Record all live lectures and make them available for later review; give a weekly learning path that lists what to watch, read, and practice. |
# | **Improve technical access and reliability** | Offer downloadable (offline) versions of videos and PDFs, and a quick‑response tech‑support channel for battery or connectivity problems. |
# | **Manage workload and assessment pressure** | Clarify assignment deadlines well in advance, balance the number of online tasks with in‑person work, and provide a brief “what to expect” sheet for each assessment. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Review the course’s new folder structure; download all lecture videos for offline use. |
# | **Week 2** | Attend the first live Q&A session; note any unclear assignment points and ask for a step‑by‑step example. |
# | **Week 3** | Set a weekly study schedule (e.g., Mon – Wed : watch videos; Thu – Fri : practice exercises; Sat : check‑in). Use the progress tracker to mark completed tasks. |
# | **Week 4** | Meet with the tech‑support team to discuss battery/charging solutions and test the offline material download process. Evaluate whether the workload feels balanced and note any remaining gaps for the instructor. |
#
# ---
#
# **Remember:** You already have strong digital skills and appreciate the flexibility of blended learning. By improving access to clear materials, increasing interaction, and managing technical and motivational hurdles, you can make the most of both online and in‑person components. Good luck, and feel free to reach out to your course coordinator or student support services for any of the steps above.

# %% [markdown]
# ## Student ID: `e20211626`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211626*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility that blended learning provides. You appreciate being able to avoid long commutes, record online sessions for later review, and use digital tools to manage your study time. At the same time, you have noted two main difficulties: occasional internet/technical problems and the challenge of asking questions or receiving clear instructions during online sessions.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | Ability to record lectures and revisit them anytime. |
# | **Flexibility & Time Management** | Saving travel time gives you more self‑study opportunities. |
# | **Student Engagement** | You are active and motivated in blended environments. |
# | **Digital Skills Development** | You are comfortable using digital resources. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you reported |
# |-------|-------------------|
# | **Interaction & Communication** | Hard to ask questions and get quick feedback when teaching is online. |
# | **Internet & Technical Issues** | Unreliable connections for both students and lecturers. |
# | **Learning Difficulty & Clarity** | Instructions can be unclear, making initial adaptation tougher. |
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation follows the rule‑based tags that match your strengths and challenges.)
#
# | Recommendation | How it helps you |
# |----------------|-----------------|
# | **Strengthen access to learning materials** – Upload slides, videos, references, exercises, and other resources **early** in the course. | Gives you more material to review offline when internet is spotty. |
# | **Develop digital learning skills** – Short guides on using the LMS, online research tools, and educational tech. | Boosts confidence in navigating the platform and reduces technical friction. |
# | **Increase learner engagement** – Include quizzes, games, practical tasks, and discussion prompts. | Keeps your high energy directed toward active participation. |
# | **Increase interaction and communication** – Schedule regular Q&A slots, small‑group discussions, and faster lecturer feedback. | Makes it easier to ask questions and receive clarification. |
# | **Improve learning effectiveness** – Pair recorded online content with in‑person explanations, practice activities, and timely feedback. | Helps you connect theory to practice and solidify understanding. |
# | **Improve clarity and learning support** – Provide step‑by‑step guides, clear examples, and recorded explanations for complex topics. | Reduces confusion when instructions are unclear. |
# | **Support self‑paced learning** – Offer weekly learning paths and downloadable recordings so you can study at your own speed. | Lets you take advantage of the extra time saved from commuting. |
# | **Improve technical access and reliability** – Ensure stable internet options, provide offline copies of key materials, and offer a dedicated tech‑support channel. | Minimises disruptions caused by connectivity problems. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|------------------|
# | 1 | Check that all course slides and videos are uploaded to the LMS **at least 48 h before class**. | Easy offline access; less reliance on live streaming. |
# | 2 | Attend a brief **LMS tutorial** (or watch the provided guide) to sharpen digital tool use. | Faster navigation, fewer tech hiccups. |
# | 3 | Participate in a **live Q&A** session and test the “raise‑hand” or chat feature. | Improves comfort asking questions online. |
# | 4 | Download the week’s recorded lectures and **create a personal study checklist** using the weekly learning path. | Supports self‑paced review and reinforces learning. |
#
# Feel free to adapt the timeline to fit your schedule. By leveraging your strong engagement and addressing the technical and communication gaps, you can make the most of blended learning and keep your academic progress on track. Good luck!

# %% [markdown]
# ## Student ID: `p20230007`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230007*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** Flexibility and the ability to learn at your own pace.
# - **What you find challenging:** Distractions while studying online, unstable internet, and limited interaction with lecturers.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate self‑paced learning that lets you fit study around other commitments.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Fewer opportunities to talk with peers and lecturers.
# - **Internet & Technical Issues** – Unstable connection hampers smooth online study.
# - **Motivation & Self‑Discipline** – Distractions make it hard to stay focused.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What the recommendation suggests | How it helps you |
# |------|----------------------------------|------------------|
# | **Interaction** | Add short Q&A sessions, group discussions, peer‑collaboration tasks, and faster lecturer feedback. | Increases contact with classmates and staff, reducing the feeling of isolation. |
# | **Motivation** | Use weekly check‑ins, reminder emails, progress‑tracking dashboards, and a structured study schedule. | Keeps you on track, builds routine, and boosts self‑discipline. |
# | **Self‑paced Learning** | Provide recorded lectures, weekly learning paths, and downloadable materials you can review anytime. | Preserves the flexibility you like while giving you reliable resources. |
# | **Technical Access** | Offer options for offline materials, clear instructions for the learning platform, and a help desk for internet or device problems. | Reduces disruptions caused by unstable connections and technical hiccups. |
#
# These suggestions are drawn directly from the evidence about your strengths, challenges, and the segment profile.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|------------------|
# | **1** | Join a scheduled **online Q&A** or discussion group for your course. | Immediate increase in interaction. |
# |      | Set up a **weekly study schedule** with specific time blocks and add reminders to your calendar. | Improves motivation and reduces distractions. |
# |      | Download the **recorded lectures** for the next module and keep them for offline review. | Guarantees access even if internet is unstable. |
# | **2** | Complete a **progress‑check** (e.g., quiz or self‑assessment) and share results with your lecturer for feedback. | Reinforces self‑discipline and provides quick feedback. |
# |      | Contact the **technical support desk** to test offline material download and troubleshoot any connectivity issues. | Ensures smoother access for future study sessions. |
#
# Follow these steps, adjust as needed, and you’ll strengthen interaction, stay motivated, and make the most of your flexible, self‑paced learning environment. Good luck!

# %% [markdown]
# ## Student ID: `p20230019`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230019*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and like to stay actively involved in your studies. You value being able to revisit lecture material whenever you need it.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You appreciate being able to check lectures again at any time and place.
# - **Digital Skills Development & Flexibility:** Your comment shows confidence in using digital resources and managing your time flexibly.
#
# ### 3. Main Challenges
# - You expressed a preference for having some lectures delivered in person. (No additional challenges were identified.)
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | Why It Helps |
# |----------------|----------------------|--------------|
# | **Strengthen access to learning materials** | Ensure that slides, videos, reference links, and exercises are uploaded to the LMS **early** in the week. | Gives you the ability to review content whenever you need, matching your strength of revisiting lectures. |
# | **Develop digital learning skills** | Receive short guides or short videos on how to use LMS tools, locate online resources, and apply digital research techniques. | Enhances the digital competencies you already enjoy and supports efficient self‑study. |
# | **Support self‑paced learning** | Use recorded lessons and a weekly learning path that outlines what to study each day, allowing you to progress at your own speed. | Aligns with your preference for flexibility and the ability to review material on your schedule. |
#
# ### 5. Short Action Plan
#
# | Week | Action | How to Do It |
# |------|--------|--------------|
# | **1** | Check that all lecture slides and videos are uploaded by Monday. | Look for the “Course Materials” folder in the LMS; if anything is missing, contact the instructor. |
# | **2** | Watch the 5‑minute LMS tutorial posted by the teaching team. | Follow the link in the announcement email; practice creating a study folder. |
# | **3** | Follow the weekly learning path (e.g., 30 min video + 15 min quiz). | Use the “Weekly Planner” tab; set a reminder on your calendar. |
# | **4** | Reflect on whether any topics still feel unclear and note them for the next in‑person session. | Write brief notes in your digital notebook and bring them to class. |
#
# By focusing on easy access to materials, sharpening your digital tools, and structuring your own pace, you can keep the high level of engagement you already demonstrate while also benefiting from occasional in‑person sessions. Good luck, and keep leveraging the flexibility that blended learning offers!

# %% [markdown]
# ## Student ID: `p20250003`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250003*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - This segment is characterized by strong motivation to participate and a preference for interactive, technology‑enabled study experiences.
#
# ### 2. Main Strengths
# - No specific strengths were reported in the open‑ended response.
# - **Note:** The recommendations below are drawn primarily from the characteristics of the “Highly Engaged” segment.
#
# ### 3. Main Challenges
# - No specific challenges were reported in the open‑ended response.
#
# ### 4. Personalized Recommendations
#
# | Recommendation Tag | What It Means for You | Practical Steps |
# |--------------------|----------------------|-----------------|
# | **content_access** | Make sure all learning materials are available early so you can plan and review them as needed. | • Upload slides, videos, reading lists, and exercises at the start of each week.<br>• Keep a shared folder or LMS module where all resources are easy to find. |
# | **digital_skill** | Strengthen your ability to use online tools and research resources effectively. | • Offer short tutorials on LMS navigation, citation managers, and digital libraries.<br>• Provide tips for evaluating online sources and using educational apps. |
# | **engagement** | Keep your high energy focused through interactive activities. | • Include low‑stakes quizzes, gamified tasks, and discussion prompts.<br>• Use breakout rooms or collaborative documents for practical problem‑solving. |
# | **self_paced** | Support your ability to study on your own schedule while staying on track. | • Record lectures and make them available for review.<br>• Publish weekly learning paths that outline what to study and when, allowing you to revisit any part at your own pace. |
#
# ### 5. Short Action Plan
#
# | Week | Action | Goal |
# |------|--------|------|
# | **1** | Upload all course materials for the first two weeks (slides, videos, exercises). | Ensure immediate access for planning and review. |
# | **2** | Provide a 10‑minute LMS tutorial video and a list of recommended digital research tools. | Boost confidence in using online resources. |
# | **3** | Introduce a short quiz and a discussion prompt after the first lecture. | Increase active participation and immediate feedback. |
# | **4** | Release recorded lessons and a clear weekly learning path for weeks 3‑4. | Allow self‑paced review while maintaining progress. |
# | **Ongoing** | Rotate interactive activities (games, practical tasks) each week and gather quick feedback. | Keep engagement high and adapt to student needs. |
#
# ---
#
# **Remember:** As a highly engaged learner, you thrive when materials are readily available, digital tools are clear, activities are interactive, and you can control the pace of your study. Implementing the steps above will help you make the most of a blended learning environment. Good luck!

# %% [markdown]
# ## Student ID: `p20230003`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230003*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What this means:** You tend to participate actively in class and are motivated to learn. Because no specific strengths or challenges were provided in your open‑ended responses, the recommendations below are drawn primarily from the characteristics of your segment.
#
# ---
#
# ### 2. Main Strengths
# - **Highly engaged and active** in learning activities (inferred from segment label).
#
# ---
#
# ### 3. Main Challenges
# - No specific challenges were reported, so the focus will be on enhancing the conditions that support an already active learner.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload all slides, videos, reference links, exercises, and other course materials **early** in the semester. | Gives you and your peers immediate, reliable access to the resources you need to stay ahead. |
# | **Digital Skills** | Offer short guides or short videos on how to use the LMS, locate online resources, and apply digital research tools. | Strengthens your ability to navigate and exploit digital platforms efficiently, saving time for deeper learning. |
# | **Engagement** | Include regular quizzes, quick games, practical tasks, discussion prompts, and other interactive activities. | Keeps the learning experience lively and leverages your natural enthusiasm, reinforcing understanding. |
# | **Self‑Paced Learning** | Provide recorded lectures and a weekly learning path that students can follow at their own speed. | Allows you to review complex topics as needed and fit study into your personal schedule. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Expected Outcome |
# |------|--------|-------------------|
# | 1 | **Check the LMS** for any newly uploaded slides or videos for the current module. | Immediate access to core materials. |
# | 1‑2 | Complete the short “Digital Tools” tutorial (5‑10 min) posted by the instructor. | Faster navigation of online resources. |
# | 2 | Participate in the first interactive quiz/game and post a comment in the discussion forum. | Boosted engagement and deeper recall of concepts. |
# | 2 | Review the recorded lecture for any part you found challenging, then note a question for the next live session. | Reinforces self‑paced learning and clarifies doubts. |
#
# ---
#
# **Keep leveraging your active participation style—these steps will make your blended learning experience smoother, more flexible, and even more rewarding.**

# %% [markdown]
# ## Student ID: `p20230005`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230005*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the convenience of studying from anywhere and appreciates easy access to digital course materials. You notice that staying focused can be difficult and that limited interaction with classmates sometimes hinders your learning experience.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You find online platforms convenient for reaching slides, videos, and other resources.
# - **Digital Skills & Flexibility** – You are comfortable using digital tools and managing your time flexibly.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You miss more peer discussion and quicker lecturer feedback.
# - **Focus & Self‑Discipline** – Maintaining concentration online can be hard.
# - **Learning Environment** – You would like clearer instructions, better‑organized resources, and a more supportive study space.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** so you can review them whenever needed. |
# | **Digital Skills** | Receive short guides on using the LMS, online research tools, and other educational technologies to boost efficiency. |
# | **Interaction** | Participate in scheduled Q&A sessions, group discussions, and peer‑collaboration activities; ask lecturers for faster feedback. |
# | **Learning Effectiveness** | Combine the online review materials with in‑person explanations, practice tasks, and timely feedback to reinforce understanding. |
# | **Learning Environment** | Use clearly organized folders, updated resources, and, where possible, improve your physical study space (quiet, comfortable, well‑lit). |
# | **Learning Support** | Look for recorded explanations, step‑by‑step guides, and concrete examples that clarify complex topics. |
# | **Motivation & Self‑Discipline** | Set up weekly check‑ins, reminders, and a simple progress tracker; follow a structured study schedule to keep focus. |
# | **Self‑Paced Learning** | Take advantage of recorded lessons and weekly learning paths that let you review material at your own speed. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s LMS folder; ensure all slides and videos are uploaded **early**. |
# | **Day 3** | Watch a short tutorial on LMS navigation and digital research tools. |
# | **Day 4** | Join a peer‑discussion group or schedule a 30‑minute Q&A with the lecturer. |
# | **Day 5** | Create a simple weekly study schedule with dedicated focus blocks and short breaks. |
# | **Day 6–7** | Review one recorded lesson and complete the associated practice exercise; note any unclear points. |
# | **Day 8** | Request clarification or an example for any confusing topic (learning support). |
# | **Day 9** | Update your study space: tidy materials, improve lighting, and minimize distractions. |
# | **Day 10** | Set a reminder for a quick self‑check‑in: “Did I stay on task today? What helped?” |
# | **Day 11–14** | Repeat the cycle, adding a brief peer‑feedback session after each module. |
#
# Follow this plan, adjust the schedule as needed, and keep communicating with lecturers and classmates. Your strong engagement combined with these targeted supports will help you stay focused, interact more, and make the most of blended learning. Good luck!

# %% [markdown]
# ## Student ID: `p20230034`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_support", "motivation", "tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** p20230034
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You appreciate the convenience of self‑directed learning and feel that it can be effective.
#
# **Main Challenges**
# - Unreliable internet or technical problems sometimes interrupt your study.
# - You can lose track of the material and find it hard to stay motivated and disciplined.
#
# **Personalized Recommendations**
#
# | Focus | What to do | Why it helps |
# |-------|------------|--------------|
# | **Learning effectiveness** | Pair the online review resources you already use with short, in‑person (or live‑online) sessions where the instructor explains key concepts, gives you practice tasks, and provides immediate feedback. | Combining explanations with practice makes the material clearer and helps you retain what you study on your own. |
# | **Learning support** | Ask for or look for clearer written instructions, concrete examples, and short recorded walkthroughs that break tasks into step‑by‑step guides. | Clear, concrete guidance reduces confusion and makes it easier to follow the material independently. |
# | **Motivation & self‑discipline** | Set up a weekly check‑in (e.g., with a tutor, study group, or the course platform) that includes a reminder of what you planned to study, a quick progress log, and a short goal for the next week. | Regular check‑ins and visible progress tracking keep you on track and boost motivation. |
# | **Technical access** | Download offline copies of lecture slides, readings, and practice files when you have a good connection; keep a list of campus or library locations with reliable Wi‑Fi; and use the course’s technical‑support channel for any platform issues. | Having offline materials and reliable access points reduces interruptions caused by connectivity problems. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Day 1–2:** Identify one upcoming topic and download all related PDFs, slides, and videos for offline use.
# 2. **Day 3:** Schedule a 15‑minute live or in‑person session (or join a virtual office hour) to get a brief explanation and practice questions for that topic.
# 3. **Day 4–7:** Follow a simple study schedule (e.g., 30 min × 2 days) and record what you completed in a notebook or the platform’s progress tracker.
# 4. **Day 8:** Do a quick self‑check‑in: note what you learned, any remaining questions, and set a goal for the next topic.
# 5. **Day 9–14:** Repeat steps 1‑4 for a second topic, and if you encounter connectivity issues, use the campus/library Wi‑Fi or the technical‑support help desk.
#
# By combining concise in‑person guidance, clearer learning resources, regular progress checks, and reliable access to materials, you can turn your self‑learning convenience into more effective, motivated study habits. Good luck!

# %% [markdown]
# ## Student ID: `e20210359`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210359*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You are comfortable joining classes from any location and you already record videos to review later, which shows good access to learning materials.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You can attend from anywhere and keep recorded sessions for future study.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You find the online setting “boring” because there is little live interaction with the professor or classmates.
# - **Motivation & Self‑Discipline** – Sitting alone at the laptop makes it hard to stay motivated and focused.
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do (based on rule‑based advice) |
# |-------|------------------------------------------|
# | **Content Access** | **Upload all course resources early.** Slides, videos, reference links, and practice exercises should be available on the learning platform before each class so you can preview and review them at your own pace. |
# | **Interaction** | **Add structured interaction opportunities.** <br>• Schedule short live Q&A sessions after each lecture. <br>• Organise small‑group discussion boards or breakout rooms for peer collaboration. <br>• Encourage the lecturer to give quick feedback on questions or submitted work. |
# | **Motivation** | **Use regular check‑ins and progress tools.** <br>• Set a weekly study schedule with clear goals. <br>• Receive automated reminders for upcoming deadlines and live sessions. <br>• Track your progress (e.g., completed videos, quiz scores) and celebrate small milestones. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | • Locate the course’s online repository and download all available slides and videos before the first lecture.<br>• Join a newly created “Q&A hour” on the platform (e.g., Tuesdays 4‑5 pm). |
# | **2** | • Form a study pair or small group (2‑3 students) for a 30‑minute discussion after each class.<br>• Set up a personal study calendar with 2‑hour blocks for reviewing recorded videos and completing exercises.<br>• Enable weekly progress notifications from the LMS. |
#
# By strengthening material access, adding purposeful interaction, and building routine check‑ins, you’ll turn a passive experience into a more engaging and motivating blended‑learning journey. Good luck, and feel free to reach out to your instructor or learning support team if you need help setting any of these up!

# %% [markdown]
# ## Student ID: `p20250048`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250048*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What this means:** You are motivated, participate actively in class, and tend to take initiative in your studies.
#
# *Note:* Your open‑ended comments were brief, so this report relies primarily on the characteristics of your segment.
#
# ---
#
# ### 2. Main Strengths
# - Positive attitude toward learning (strength sentiment: positive).
#
# ---
#
# ### 3. Main Challenges
# - Goal‑oriented focus on graduating (challenge sentiment: neutral).
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Content Access** | Upload or request early access to slides, videos, reference links, exercises, and any other course materials. | Having materials ahead of time lets you plan your study schedule and stay ahead of deadlines. |
# | **Digital Skills** | Take short tutorials on the LMS, online research tools, and any educational technologies used in your courses. | Strong digital skills let you navigate resources quickly and make the most of online learning opportunities. |
# | **Engagement** | Participate in quizzes, games, practical tasks, discussion boards, and other interactive activities. | Interactive elements keep your high energy focused and deepen understanding of the content. |
# | **Self‑Paced Learning** | Use recorded lectures and weekly learning paths that you can review at your own speed. | This supports your active style while giving you flexibility to revisit challenging topics before graduation. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s LMS and download all available slides and videos for the upcoming module. |
# | **Day 3** | Complete a 30‑minute tutorial on LMS navigation and digital research tools (many universities offer short videos). |
# | **Day 4–5** | Join a discussion forum or study group for the module; post a question or comment to start engaging. |
# | **Day 6** | Attempt the first online quiz or interactive activity; note any topics that need review. |
# | **Day 7** | Review the recorded lecture for any concepts you found difficult in the quiz. |
# | **Day 8–10** | Follow the weekly learning path: set a personal deadline for each reading/exercise and stick to it. |
# | **Day 11–12** | Share a brief summary of what you learned in the discussion board – this reinforces knowledge and boosts engagement. |
# | **Day 13–14** | Reflect on the week: identify which digital tools helped most and plan how to use them for the next module. |
#
# ---
#
# **Keep up the active approach—you’re already well‑positioned to succeed.** Use the resources and strategies above to stay organized, deepen engagement, and move confidently toward graduation.

# %% [markdown]
# ## Student ID: `p20230013`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20230013*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners who attend class regularly but tend to participate less actively. They benefit from clear structure, frequent interaction opportunities, and support that helps maintain motivation and self‑discipline.
#
# ### 2. Main Strengths
# - **Punctuality:** You noted that you are “hard to be late,” which shows good time‑management habits.
#
# ### 3. Main Challenges
# - **Coding:** You indicated difficulty with coding tasks.
#
# ### 4. Personalized Recommendations
#
# | Focus | What the recommendation means for you | Practical actions you can take |
# |-------|----------------------------------------|--------------------------------|
# | **Interaction** | Increase opportunities to ask questions and work with peers. | • Join the weekly Q&A sessions.<br>• Participate in small‑group discussion boards.<br>• Pair up with a classmate for short coding practice reviews. |
# | **Learning Support** | Get clearer guidance and examples to reduce confusion. | • Use the recorded explanations that accompany each topic.<br>• Follow the step‑by‑step learning guides provided for coding exercises.<br>• Ask the lecturer for brief clarification notes if an instruction is unclear. |
# | **Motivation & Self‑Discipline** | Keep your momentum with regular check‑ins and visible progress tracking. | • Set a personal weekly study schedule (e.g., 2 hours on Monday, 1 hour on Thursday).<br>• Mark completed tasks in the course tracker and celebrate small milestones.<br>• Enable reminder emails or app notifications for upcoming deadlines. |
# | **Self‑Paced Learning** | Use flexible resources so you can review material at your own speed. | • Watch the recorded lessons before attempting coding assignments.<br>• Follow the weekly learning path outline to know what to focus on each day.<br>• Re‑watch any segment that feels difficult, especially coding examples. |
#
# *Because the open‑ended responses were brief, these recommendations are primarily based on the characteristics of your learner segment (Moderately Engaged – Passive). They are designed to reinforce your punctuality, address coding challenges, and boost overall engagement.*
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Goal | Action |
# |------|------|--------|
# | **Week 1** | Build a routine | • Create a simple study schedule (e.g., Mon 10‑11 am, Wed 2‑3 pm).<br>• Attend the first Q&A session and post one question about coding. |
# | **Week 2** | Strengthen coding basics | • Watch the recorded lesson on the current coding topic.<br>• Follow the step‑by‑step guide and complete the practice exercise.<br>• Share your solution in the peer‑collaboration forum for feedback. |
# | **Ongoing** | Track progress & stay motivated | • Update the course progress tracker after each completed task.<br>• Set a reminder for weekly check‑ins with yourself or a study buddy. |
#
# ---
#
# **Remember:** Your punctuality is a solid foundation. By adding more interaction, clearer support, and structured self‑paced study, you’ll gain confidence in coding and stay motivated throughout the course. Good luck!

# %% [markdown]
# ## Student ID: `e20220186`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220186*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to prepare ahead of in‑person sessions, which helps you feel ready for class.
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You are good at getting materials ready before the face‑to‑face component, giving you a solid foundation for class activities.
#
# ### 3. Main Challenges
# - **Assessment & Workload:** Re‑studying the same subjects feels repetitive and time‑consuming.
# - **Motivation & Self‑Discipline:** Keeping up with the material can feel overwhelming, affecting motivation.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What to Do | Why it Helps |
# |----------------|------------|--------------|
# | **Improve learning effectiveness** | • Use the online review resources **before** each in‑person session. <br>• During class, focus on asking questions, doing practice tasks, and getting feedback from the instructor. | Aligns your preparation habit with active classroom work, turning preparation into deeper understanding. |
# | **Support motivation and self‑discipline** | • Set a **weekly check‑in** (e.g., a 5‑minute self‑review or a brief chat with a tutor). <br>• Use a simple **progress tracker** (checklist or app) to mark completed readings, practice problems, and reflections. <br>• Create a **structured study schedule** that blocks short, regular study slots rather than long, irregular sessions. | Regular check‑ins and visible progress keep motivation high and make self‑discipline more manageable. |
# | **Manage workload and assessment pressure** | • Break larger assignments into **smaller milestones** with clear mini‑deadlines. <br>• Align online tasks (e.g., quizzes, discussion posts) with the topics covered in the upcoming in‑person class so you see the purpose of each activity. <br>• Clarify any confusing deadlines with the instructor early on. | A balanced, transparent workload reduces the feeling of repetition and helps you allocate time efficiently. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the syllabus and list upcoming topics. Mark which online review materials correspond to each topic. |
# | **Tuesday** | Create a simple weekly schedule (30 min × 4 days) that pairs an online review session with a short in‑person practice slot. |
# | **Wednesday** | Set up a progress‑tracking sheet (paper or digital) and record today’s completed review. |
# | **Thursday** | Attend the in‑person class; ask at least one question and complete a practice exercise. |
# | **Friday** | Do a 5‑minute self‑check‑in: note what you understood well and what needs more review. |
# | **Weekend** | Break any upcoming assignment into 2‑3 mini‑tasks; set mini‑deadlines for each. |
# | **Next Monday** | Repeat the cycle, adjusting the schedule based on what worked best. |
#
# ---
#
# **Remember:** Your habit of preparing in advance is a strong foundation. By linking that preparation to active class work, tracking progress weekly, and breaking down the workload, you’ll find the blended format more effective and less overwhelming. Good luck!

# %% [markdown]
# ## Student ID: `e20240569`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240569*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Typical traits:** Strong use of digital tools, high participation, and a preference for flexible study options.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value “saving time” and can make good use of flexible learning formats.
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Maintaining consistent self‑discipline can be difficult, especially when study schedules are unstructured.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Support motivation and self‑discipline** | Keep your momentum steady throughout the term. | • Join weekly check‑ins (e.g., a short 5‑minute online meeting or a self‑reflection journal). <br>• Set up automated reminders for upcoming deadlines. <br>• Use a progress‑tracking dashboard to see completed tasks at a glance. <br>• Follow a structured study schedule that blocks specific times for each subject. |
# | **Support self‑paced learning** | Take advantage of your ability to manage time flexibly. | • Access recorded lectures and supplemental videos whenever it fits your day. <br>• Follow the weekly learning path provided by the course – it outlines what to study and when, but lets you move at your own speed. <br>• Keep all course materials (slides, readings, quizzes) in a personal folder for quick review before assessments. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the weekly learning path and add the key tasks to your digital calendar. |
# | **Tuesday** | Watch the first recorded lecture; note any questions in a quick‑capture app. |
# | **Wednesday** | Complete a 10‑minute self‑reflection: what went well, what needs more focus? Set a reminder for Thursday’s check‑in. |
# | **Thursday** | Attend the brief online check‑in (or write a short status update) and update your progress tracker. |
# | **Friday** | Review the week’s material, redo any short quizzes, and adjust next week’s schedule if needed. |
# | **Weekend** | Light review of notes or recorded content if time allows; keep it optional to avoid burnout. |
#
# ---
#
# **Remember:** Your strength in managing time gives you a solid foundation. By adding regular check‑ins, reminders, and a clear weekly path, you’ll strengthen motivation and keep your self‑discipline on track while still enjoying the flexibility you prefer. Good luck!

# %% [markdown]
# ## Student ID: `e20211504`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211504*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can control the pace of your study and appreciate a flexible schedule.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You value being able to learn whenever it fits your timetable and enjoy progressing at your own speed.
#
# ### 3. Main Challenges
# - **Learning Difficulty & Clarity:** Some e‑learning materials feel disorganized and are hard to understand without additional help.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How it helps |
# |----------------|----------------------|--------------|
# | **Learning Support** (tag: *learning_support*) | Provide clearer instructions, concrete examples, recorded explanations, and step‑by‑step guides for each topic. | Reduces confusion, makes complex content easier to follow, and gives you reference material you can revisit. |
# | **Self‑Paced Learning** (tag: *self_paced*) | Offer recorded lessons, weekly learning paths, and downloadable resources that you can access anytime. | Lets you study when it suits you, review difficult sections as needed, and keep the flexibility you value. |
#
# These recommendations are drawn directly from the evidence you supplied and from the characteristics of the “Highly Engaged (Active) Learners” segment.
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Locate the recorded lectures and step‑by‑step guides for your current module in the course portal. |
# | **Week 2** | Create a personal weekly learning path: list the topics you’ll cover each day and set short review checkpoints. |
# | **Week 3** | If a concept remains unclear, use the provided examples and recorded explanations; note any remaining questions. |
# | **Week 4** | Reach out to the tutor or support desk with your questions, referencing the specific guide or video you used. |
# | **Ongoing** | Continue using the recorded lessons and guides to reinforce learning and maintain your flexible schedule. |
#
# By following this plan, you’ll keep the autonomy you enjoy while gaining the extra clarity needed to master the material. Good luck, and keep leveraging your strong engagement!

# %% [markdown]
# ## Student ID: `e20231276`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20231276*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits of this segment:** Learners are generally motivated but tend to participate less actively. They benefit from clear guidance, reliable technical access, and opportunities for self‑paced study and interaction.
#
# ### 2. Main Strengths
# - **Reliable internet connection** (mentioned positively).
#
# ### 3. Main Challenges
# - **Unstable Wi‑Fi / technical access** (the only challenge reported).
#
# ### 4. Personalized Recommendations
# Because the open‑ended input is limited, the advice below draws primarily on your segment profile and the identified technical challenge.
#
# | Recommendation | What it means for you |
# |----------------|-----------------------|
# | **Improve technical access and reliability** | • Ensure you have a stable internet connection (e.g., use a wired Ethernet link or a trusted hotspot when Wi‑Fi is weak).<br>• Download offline copies of lecture videos, readings, and assignments in advance so you can study without needing constant connectivity.<br>• Follow the platform’s short “Getting Started” guide to avoid navigation issues.<br>• Keep the university’s IT help desk contact handy for quick troubleshooting. |
#
# ### 5. Short Action Plan
#
# | Step | Action | Timeline |
# |------|--------|----------|
# | 1 | Test your current Wi‑Fi speed and stability (e.g., using a free speed‑test site). | This week |
# | 2 | Identify a backup connection (home Ethernet, campus library, café hotspot) and note login details. | This week |
# | 3 | At the start of each week, download all required materials (videos, PDFs) to your device for offline use. | Every Monday |
# | 4 | Review the platform’s “Quick Start” tutorial (5‑10 min) before your first login each term. | Before first class |
# | 5 | Save the university IT support phone/email and contact them the first time you experience a connectivity problem. | Ongoing |
#
# ---
#
# **Remember:** A stable technical environment lets you focus on the content and engage more confidently with the course. If you encounter any other difficulties, reach out to your instructor or the learning support team—they’re here to help you succeed.

# %% [markdown]
# ## Student ID: `p20250026`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: p20250026*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What you value:** You highlighted the **flexibility** that blended learning provides, especially for managing your time.
# - **What’s unclear:** You indicated you “have no idea” about your current challenges, so the suggestions below rely mainly on the typical needs of your segment.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when it fits your schedule.
#
# ### 3. Main Challenges
# - No specific challenges were identified in your response. Because of this, the recommendations focus on supporting the strengths and typical hurdles of moderately engaged, more passive learners (e.g., staying on track without constant external prompts).
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it helps you | How to use it |
# |----------------|------------------|---------------|
# | **Support self‑paced learning** (core recommendation) | Allows you to take advantage of the flexibility you value while giving you structure to progress steadily. | • Access recorded lectures and tutorials anytime.<br>• Follow the weekly learning path provided by the course (outline of what to study each week).<br>• Review supplemental materials (slides, readings, quizzes) at your own speed. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Locate the course’s recorded lessons and weekly learning path in the LMS. Set a personal study schedule that fits your daily routine. |
# | **Week 2‑3** | Complete the first two weeks of the learning path. Use the recordings to revisit any concepts that feel unclear. |
# | **Week 4** | Reflect on your progress: Are you keeping up with the weekly path? Adjust your schedule if needed. |
# | **Ongoing** | Continue using recorded content and weekly paths. If you notice any new challenges (e.g., motivation, interaction), reach out to tutors or peers for additional support. |
#
# ---
#
# **Remember:** The flexibility of blended learning works best when you pair it with a clear, self‑paced plan. Stick to the weekly path, use the recordings whenever you need a refresher, and you’ll stay on track while enjoying the freedom to learn on your own schedule. Good luck!

# %% [markdown]
# ## Student ID: `e20210752`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_support", "workload_support"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20210752
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You value being able to **access lecture recordings and other materials repeatedly**, which helps you catch up on anything you missed or didn’t fully understand in class.
#
# **Main Challenges**
# - You find it **hard to ask the lecturer for clarification** when assignment instructions are unclear.
# - This creates uncertainty around assessments, workload, and overall learning clarity.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Strengthen access to learning materials** | Keep all slides, videos, references, and exercises available early in the course. | Check the LMS each week for newly uploaded content; download or bookmark what you’ll need for review. |
# | **Develop digital learning skills** | Learn how to use LMS tools, online research databases, and other educational technologies efficiently. | Attend the short “LMS Tips” tutorial (often recorded) and practice using the search and annotation features. |
# | **Increase interaction and communication** | More opportunities for Q&A, group discussion, and peer collaboration, plus quicker feedback from the lecturer. | Join the weekly online discussion board, post any question you have there, and look for peer‑study groups in the course forum. |
# | **Improve clarity and learning support** | Receive clearer assignment instructions, examples, and step‑by‑step guides. | When an assignment is posted, first read any provided examples or recorded walkthroughs; if anything is still unclear, use the Q&A forum to ask. |
# | **Manage workload and assessment pressure** | Assignments will be balanced, deadlines clearly stated, and online tasks aligned with face‑to‑face sessions. | Use the course calendar to track due dates; break larger tasks into smaller weekly goals. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Check the LMS every Monday** for newly uploaded lecture slides and videos.
# 2. **Watch the “LMS Basics” tutorial** (≈15 min) and try uploading a note to a lecture page.
# 3. **Post at least one question** about the current assignment on the course Q&A forum; read any peer responses.
# 4. **Download the assignment rubric** and any example solutions provided; highlight any steps that are still unclear.
# 5. **Add the assignment deadlines to your personal calendar** and set a reminder 2 days before each due date.
#
# By following these steps, you’ll make the most of the material that’s already available, improve your digital confidence, and get the support you need to clarify tasks and manage your workload. Good luck!

# %% [markdown]
# ## Student ID: `e20201314`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20201314*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can manage your time flexibly and study from a comfortable remote location.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management:** You are able to learn effectively from a comfortable place of your choice, which helps you stay organized and motivated.
#
# ### 3. Main Challenges
# - **Learning Resources & Environment:** You would like a better blend of online course material and in‑person lab sessions, indicating that the current learning environment could be improved.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Use It |
# |----------------|----------------------|---------------|
# | **Improve learning resources and environment** | Organize course materials clearly, keep resources up‑to‑date, and make sure study spaces (both virtual and physical) are comfortable. | • Check the course portal for a consolidated folder of lecture slides, readings, and lab guides.<br>• Use campus study rooms or set up a quiet corner at home with good lighting and ergonomics.<br>• Provide feedback to instructors if any resource feels outdated or hard to locate. |
# | **Support self‑paced learning** | Access recorded lessons and weekly learning paths so you can review content whenever it fits your schedule. | • Watch the recorded lectures before or after class to reinforce concepts.<br>• Follow the weekly learning path (a checklist of videos, readings, and practice tasks) at your own speed.<br>• Use the provided materials for lab preparation and review them before the in‑person session. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the central course folder on the LMS; bookmark it for quick access. |
# | **2** | Set up a comfortable study space (desk, chair, lighting) for both online work and lab prep. |
# | **3** | Begin using the weekly learning path: watch the recorded lecture, then complete the associated practice tasks. |
# | **4** | Attend the first in‑person lab; bring printed or digital notes from the recorded lessons to apply what you’ve reviewed. |
# | **5** | Give brief feedback to the instructor about any resource that could be clearer or more up‑to‑date. |
# | **6** | Review the recorded sessions again if any lab concepts are unclear; adjust your study schedule as needed. |
#
# By organizing your learning environment and taking advantage of self‑paced resources, you can keep your high level of engagement while getting the blended mix of online and hands‑on experiences you prefer. Keep tracking what works best for you, and feel free to share suggestions with your instructors to continuously improve the course setup.

# %% [markdown]
# ## Student ID: `M061209`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: M061209*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **What you said you value:** Flexibility in place and time, and finding effective ways to study.
# - **Current challenges:** You indicated “no idea yet,” so the suggestions below rely mainly on the strengths of your segment.
#
# ---
#
# ### 2. Main Strengths
# 1. **Flexibility & Time Management** – You appreciate being able to choose when and where you learn.
# 2. **Learning Convenience & Effectiveness** – You are motivated to explore methods that make studying more efficient.
#
# ---
#
# ### 3. Main Challenges
# - No specific challenge was identified, so the recommendations focus on enhancing the strengths already evident in your profile.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | Why it fits you | How to apply it |
# |----------------|----------------|-----------------|
# | **Improve learning effectiveness** | Combining the convenience you like with deeper understanding will make your study time even more productive. | Use online review materials (e.g., videos, quizzes) **before** attending in‑person sessions where the instructor explains concepts, you practice, and receive feedback. |
# | **Support self‑paced learning** | Your desire for flexibility matches a self‑paced approach. | Access recorded lessons and weekly learning paths. Review the recordings whenever it suits you, and follow the suggested weekly tasks to stay on track. |
#
# ---
#
# ### 5. Short Action Plan (2‑Week Starter)
#
# | Week | Action | Resources |
# |------|--------|-----------|
# | **1** | Choose one subject/module. Watch the recorded lesson(s) **before** the next face‑to‑face class. | Course LMS – recorded lectures |
# |      | Create a brief personal study schedule (e.g., 30 min each evening). | Calendar or planner app |
# | **2** | Attend the in‑person class, focus on asking questions and doing the practice activities. | Classroom session |
# |      | After class, review the same material again online and complete any quick quizzes for feedback. | Online review materials, quiz portal |
# | **Ongoing** | Follow the weekly learning path provided by the course and adjust timing as needed. | Weekly learning path document |
#
# Stick to this cycle for a few weeks, then reflect on how the blend of online review and in‑person practice is affecting your understanding and efficiency. Adjust the pacing or seek additional feedback as needed.
#
# ---
#
# **Keep leveraging your flexibility and active engagement—these blended strategies are designed to make your study both convenient and highly effective.**

# %% [markdown]
# ## Student ID: `e20210725`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210725*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You appreciate the **flexibility** of blended learning, the ability to **review recorded lectures**, and the use of **digital tools** that help you understand material independently. At the same time, you notice that **inconsistent online content, limited interaction, technical glitches, and an unbalanced workload** can hinder your learning experience.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you value |
# |-------|----------------|
# | **Access to Learning Materials** | Ability to study at your own pace with slides, videos, and resources. |
# | **Digital Skills Development** | Using simulations and online tools to deepen understanding. |
# | **Flexibility & Time Management** | Reviewing content whenever needed. |
# | **Learning Convenience & Effectiveness** | Combining digital and face‑to‑face activities. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What concerns you |
# |-------|-------------------|
# | **Interaction & Communication** | Fewer live discussions and slower feedback. |
# | **Technical Issues** | Unstable internet or limited software access. |
# | **Workload & Assessment Balance** | Online and in‑person tasks sometimes feel uneven. |
# | **Learning Resources & Environment** | Inconsistent quality of online materials and unclear instructions. |
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation follows the rule‑based tags you received.)
#
# | Recommendation | How it helps you |
# |----------------|------------------|
# | **Strengthen access to learning materials** – Upload slides, videos, references, and exercises early. | Guarantees the resources you need are ready for self‑paced review. |
# | **Develop digital learning skills** – Offer short guides on the LMS, online research, and educational tech. | Boosts confidence using the digital tools you already value. |
# | **Increase interaction and communication** – Add scheduled Q&A sessions, group discussions, peer collaboration, and quicker lecturer feedback. | Gives you more opportunities to engage and clarify doubts. |
# | **Improve learning effectiveness** – Pair online review materials with in‑person explanations, practice activities, and feedback. | Helps you connect theory to practice and retain knowledge. |
# | **Improve learning resources and environment** – Organise materials clearly, keep resources up‑to‑date, and ensure comfortable study spaces. | Reduces confusion and creates a smoother learning flow. |
# | **Improve clarity and learning support** – Provide clear instructions, examples, recorded explanations, and step‑by‑step guides. | Makes assignments and concepts easier to follow. |
# | **Support self‑paced learning** – Supply recorded lessons and weekly learning paths that you can revisit anytime. | Reinforces the flexibility you appreciate. |
# | **Improve technical access and reliability** – Ensure stable internet options, offer offline copies of key content, and provide responsive technical support. | Minimises disruptions caused by technical problems. |
# | **Manage workload and assessment pressure** – Balance the number of assignments, clarify deadlines, and align online tasks with face‑to‑face sessions. | Helps you keep a manageable schedule. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action | Who’s Involved |
# |------|--------|----------------|
# | **1** | Check that all lecture slides and videos are uploaded to the LMS at least 48 h before class. | Lecturer / Course admin |
# | **2** | Attend a 30‑min “LMS Quick‑Start” workshop to learn key digital tools. | Student + Teaching support |
# | **3** | Join the new weekly Q&A slot (30 min) and post at least one question per session. | Student + Peers + Lecturer |
# | 4 | Review the revised assignment schedule; note clarified deadlines and plan study blocks using the weekly learning path. | Student (self‑plan) |
#
# Follow these steps, and you should notice smoother access to materials, clearer guidance, more interaction, and a better‑balanced workload—all while keeping the flexibility you value.
#
# **Remember:** Small, consistent adjustments can turn a passive experience into an actively supportive one. Good luck!

# %% [markdown]
# ## Student ID: `e20200834`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "engagement", "interaction"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20200834*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You already see blended learning as a way to turn passive study habits into active, supported learning.
#
# ### 2. Main Strengths
# - **Digital Skills Development** – you value the role of technology in learning.
# - **Student Engagement** – you appreciate how blended formats keep you actively involved.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – you want stronger connections with teachers and classmates when learning online.
#
# ### 4. Personalized Recommendations
#
# | Focus | What the recommendation means for you | Practical actions you can try |
# |-------|----------------------------------------|--------------------------------|
# | **Digital Skill** | Build confidence with the learning platform and digital tools. | • Follow short tutorials on the LMS (how to submit work, track grades, use discussion boards).<br>• Explore curated lists of reliable online research resources.<br>• Experiment with one new educational app each month (e.g., mind‑mapping, citation manager). |
# | **Engagement** | Keep the high energy you already bring to class. | • Participate in quick quizzes or polls during live sessions.<br>• Join game‑based review activities offered in the course.<br>• Take on short, practical tasks that apply theory to real‑world problems. |
# | **Interaction** | Strengthen contact with peers and lecturers despite the screen. | • Schedule brief Q&A slots after each lecture for immediate clarification.<br>• Join or form small study groups on the course’s discussion board.<br>• Request faster feedback on assignments (e.g., use rubric check‑lists or peer‑review drafts). |
#
# ### 5. Short Action Plan (Next 4 weeks)
#
# | Week | Goal | Activity |
# |------|------|----------|
# | 1 | Get comfortable with the LMS | Watch the 10‑minute “LMS Basics” video; complete the practice quiz. |
# | 2 | Boost engagement in one module | Participate in the module’s interactive quiz and submit a short practical task. |
# | 3 | Start a peer‑collaboration group | Post an invitation on the discussion board; schedule a 30‑minute virtual meeting. |
# | 4 | Seek quick feedback | After submitting an assignment, ask the lecturer for a brief feedback checklist within 48 hours. |
#
# By focusing on these three areas—digital skills, active engagement, and richer interaction—you’ll make the most of blended learning while staying connected to your teachers and classmates. Keep the momentum, and feel free to adjust the plan as you discover what works best for you. Good luck!

# %% [markdown]
# ## Student ID: `e20210599`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210599*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically shows steady participation but benefits from stronger interaction, clearer resources, and reliable technology.
#
# ### 2. Main Strengths
# - **Digital Skills Development** – You recognize the importance of a comfortable physical environment (e.g., air‑conditioned classrooms) for effective learning, indicating awareness of factors that support digital study.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Finding it hard to connect with peers and instructors during online sessions.
# - **Internet & Technical Issues** – Unstable or slow Wi‑Fi at home makes it difficult to attend online classes.
# - **Learning Resources & Environment** – Lack of a suitable study space away from the university hampers concentration.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Digital Skill** | • Explore short tutorials on your LMS (how to submit work, join webinars, use discussion boards). <br>• Use university‑provided guides for digital research tools and citation managers. |
# | **Interaction** | • Join scheduled Q&A or “office hour” sessions with your lecturer. <br>• Participate in small‑group discussion boards or peer‑review activities to build communication practice. |
# | **Learning Environment** | • Create a dedicated study nook at home (quiet corner, good lighting). <br>• Keep digital course materials organized in clearly labeled folders; request updated resources from the instructor if needed. |
# | **Tech Issue** | • Test your internet speed before each class; if it’s low, consider campus Wi‑Fi hotspots or a portable data plan. <br>• Download lecture recordings or PDFs in advance so you can study offline. <br>• Use the university’s IT help desk for quick troubleshooting. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1‑2** | Watch the LMS “Getting Started” video on the university portal. |
# | **Day 3‑4** | Identify a quiet corner at home; set up a desk with a lamp and a comfortable chair. |
# | **Day 5** | Test your internet speed; note any issues and contact the campus Wi‑Fi service for a stronger signal. |
# | **Day 6‑7** | Download this week’s lecture slides and recordings for offline review. |
# | **Day 8** | Join a scheduled Q&A session or virtual office hour; ask at least one question. |
# | **Day 9‑10** | Participate in a peer‑discussion forum; reply to a classmate’s post. |
# | **Day 11‑12** | Organize all downloaded files into clearly labeled folders (e.g., “Week 3 Lectures”). |
# | **Day 13‑14** | Review the digital research guide provided by the library; try using one new tool for a short assignment. |
#
# ---
#
# **Remember:** Small, consistent steps—like improving your study space, mastering the LMS, and reaching out for interaction—will make blended learning more effective and enjoyable. If you encounter any technical problems, the university’s IT support is ready to help. Good luck!

# %% [markdown]
# ## Student ID: `e20211572`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["learning_environment", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20211572*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are motivated and actively participate in learning activities. Your main strength that you mentioned is **learning new technologies**.
#
# ### 2. Main Strengths
# - Quick to pick up and experiment with new digital tools and platforms.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unreliable Wi‑Fi or limited bandwidth.
# - **Learning Resources & Environment:** Limited access to high‑quality materials and a study space that supports focused work.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Learning Environment** | • Organise your digital and physical study materials in a clear folder structure.<br>• Keep your study space tidy, well‑lit, and comfortable (e.g., ergonomic chair, minimal distractions).<br>• Check that any required software or e‑books are up‑to‑date before each session. | A well‑structured environment reduces the time spent searching for resources and improves concentration, letting your high engagement translate into deeper learning. |
# | **Technical Access** | • Identify a reliable Wi‑Fi hotspot on campus or a nearby public library for critical sessions.<br>• Download lecture videos, readings, and assignments in advance so you can work offline.<br>• Save the platform’s quick‑start guide and bookmark the tech‑support contact page.<br>• If possible, use a wired Ethernet connection when you need stable bandwidth. | Stable internet and offline options prevent interruptions, ensuring you can stay active in class and continue exploring new technologies without technical setbacks. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | List all current study materials; create a folder system on your computer/cloud (e.g., “Lectures,” “Readings,” “Assignments”). |
# | **Day 3–4** | Locate the nearest reliable Wi‑Fi hotspot (campus library, café) and test connection speed. |
# | **Day 5** | Download this week’s lecture videos and readings for offline use. |
# | **Day 6** | Set up a dedicated, clutter‑free study space (good lighting, comfortable chair). |
# | **Day 7** | Save the platform’s quick‑start guide and note the tech‑support email/phone. |
# | **Week 2** | Use the offline materials when Wi‑Fi is unstable; contact tech support if any platform issues arise. Review the folder system each evening to keep it tidy. |
#
# ---
#
# **Remember:** Your enthusiasm for new technologies is a strong asset. By securing a reliable learning environment and stable internet access, you’ll be able to focus that energy on mastering course content and staying fully engaged. If you encounter any technical problems, reach out to the university’s support services promptly—they’re there to help you succeed.

# %% [markdown]
# ## Student ID: `e20210163`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20210163*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Typical traits:** Learners who appreciate flexibility and can manage their time well but may participate less actively in live sessions.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value the ability to “save time,” indicating that you work best when you can control the pace of your study.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity can disrupt access to online content.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** | Access recorded lessons and weekly learning paths so you can study when it fits your schedule. | • Watch videos or review slides at any time.<br>• Follow the suggested weekly roadmap to stay on track without needing to be online all day. |
# | **Improve technical access and reliability** | Ensure you can study even when the internet is unstable. | • Download offline versions of readings, videos, and quizzes.<br>• Use the university’s Wi‑Fi hotspots or request a loaner hotspot if needed.<br>• Keep the platform’s help guide handy and contact technical support for quick fixes. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **Week 1** | Locate the “Download” button for all lecture videos and readings; save them to your device. |
# | **Week 2** | Follow the weekly learning path for your first module, using the recorded lessons at times that suit you best. |
# | **Week 3** | Test the campus Wi‑Fi hotspot or request a loaner hotspot to ensure you have a backup connection. |
# | **Week 4** | Review the technical support guide; note the contact details for quick assistance if problems arise. |
#
# By focusing on self‑paced resources and securing reliable access to materials, you can make the most of your flexibility while minimizing disruptions from internet issues. Feel free to reach out to your learning support team for any additional help.

# %% [markdown]
# ## Student ID: `e20200269`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "motivation", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** e20200269
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - Values the **flexibility** of blended learning, allowing self‑study and the ability to learn at your own pace.
# - Finds online resources convenient and effective for understanding material.
#
# **Main Challenges**
# - Managing time and staying motivated for self‑directed study.
# - Maintaining self‑discipline to keep up with course requirements.
#
# **Personalized Recommendations**
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Improve learning effectiveness** | Pair the online content you already enjoy with face‑to‑face activities that give you practice and feedback. | Attend scheduled in‑person sessions (labs, tutorials, office hours) where you can apply concepts, ask questions, and receive immediate feedback. |
# | **Support motivation and self‑discipline** | Build routine and accountability to help you stay on track. | • Set a weekly study schedule that blocks specific times for online review and in‑person work.<br>• Use the course’s progress tracker or a simple checklist.<br>• Participate in brief weekly check‑ins (e.g., a 5‑minute reflection or a quick chat with a tutor). |
# | **Support self‑paced learning** | Keep using the recorded lessons and flexible materials you like, but with a clearer structure. | • Follow the weekly learning path provided by the instructor (list of videos, readings, and activities for each week).<br>• Review recorded lessons at your own speed, then apply the concepts during the next face‑to‑face session. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Create a weekly schedule** – Allocate 2‑3 hours for online review and 1‑2 hours for in‑person practice each week.
# 2. **Use the progress tracker** – Mark each completed video, reading, and practice activity; review the tracker every Friday.
# 3. **Attend one in‑person session** – Prepare at least one question from your online study to ask during the session.
# 4. **Set a reminder** – Use a phone or calendar reminder for your weekly check‑in (e.g., Sunday evening) to reflect on what you’ve learned and plan the next week.
#
# By combining flexible online study with regular face‑to‑face practice and a simple routine, you can boost both learning effectiveness and motivation while still enjoying the self‑paced nature of blended learning. Good luck!

# %% [markdown]
# ## Student ID: `e20220304`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20220304
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Moderately Engaged (Passive) Learners” segment. This group tends to participate at a steady but low‑key level and benefits from structures that boost interaction, clarity, motivation, and the ability to study at their own speed. Your open‑ended response about strengths (“if it fit my preference that would be awesome”) was brief, so the recommendations below rely primarily on the typical needs of your segment.
#
# ---
#
# ### 2. Main Strengths
# - Positive attitude toward learning when the format matches your preferences.
#
# ---
#
# ### 3. Main Challenges
# - No specific challenges were listed, but the segment profile indicates a need for more active engagement and clearer support.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Try | Why It Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from lecturers. | Increases engagement and makes the learning experience feel more connected. |
# | **Learning Support** | • Look for clear, step‑by‑step guides and example problems.<br>• Use recorded explanations that break down complex topics.<br>• Ask for additional instructions when needed. | Improves understanding and reduces uncertainty about what to do. |
# | **Motivation** | • Set up weekly check‑ins (with yourself or a study buddy).<br>• Use reminders and a simple progress tracker.<br>• Create a structured study schedule that outlines what to cover each week. | Keeps you on track and builds self‑discipline. |
# | **Self‑Paced Learning** | • Access recorded lectures so you can review them at any time.<br>• Follow the weekly learning path provided by the course.<br>• Keep all materials organized for easy revisiting. | Allows you to learn at a speed that fits your preferences. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the recorded lectures and weekly learning path for your current module. |
# | **Day 3** | Add a 15‑minute reminder in your calendar for a weekly check‑in (self‑review or with a peer). |
# | **Day 4–5** | Join the next scheduled Q&A or discussion forum; ask at least one question. |
# | **Day 6** | Download a step‑by‑step guide or example set for a topic you find tricky. |
# | **Day 7** | Review the recorded lecture for that topic and note any remaining questions. |
# | **Day 8** | Share your question in the peer‑collaboration space and request feedback. |
# | **Day 9–10** | Update your progress tracker with what you’ve completed so far. |
# | **Day 11** | Schedule a brief meeting (or email) with the lecturer for faster feedback on your question. |
# | **Day 12–14** | Reflect on what interaction and support helped most; adjust your study schedule for the next week accordingly. |
#
# Follow this plan, and you’ll gradually build stronger interaction, clearer guidance, steady motivation, and the flexibility to learn at your own pace. Good luck!

# %% [markdown]
# ## Student ID: `e20240672`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20240672*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - This segment typically benefits from more interaction, clearer guidance, motivation support, and flexible pacing.
#
# *Note: Your open‑ended responses about strengths and challenges were brief (“i have no idea”), so the recommendations below are based primarily on the characteristics of your segment.*
#
# ---
#
# ### 2. Main Strengths
# - No specific strengths were reported.
#
# ---
#
# ### 3. Main Challenges
# - No specific challenges were reported.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why It Helps |
# |------|-------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from the lecturer. | Increases engagement and helps you stay connected with the material and classmates. |
# | **Learning Support** | • Look for clearer written instructions and concrete examples.<br>• Use recorded explanations and step‑by‑step guides provided by the instructor. | Makes complex concepts easier to understand and reduces uncertainty. |
# | **Motivation** | • Set up weekly check‑ins (with yourself or a study buddy).<br>• Use reminders and a simple progress tracker.<br>• Follow a structured study schedule. | Keeps you on track, builds self‑discipline, and gives a sense of accomplishment. |
# | **Self‑Paced Learning** | • Access recorded lessons so you can review anytime.<br>• Follow the weekly learning path but feel free to adjust the pace as needed.<br>• Keep all course materials organized for easy reference. | Allows you to learn at a speed that fits your schedule while still meeting course milestones. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the course platform for any recorded lectures and download the weekly learning path. |
# | **Day 2** | Sign up for the next live Q&A or discussion session. |
# | **Day 3** | Create a simple study schedule (e.g., 1 hour / day) and set daily reminders. |
# | **Day 4** | Locate a peer or form a small study group for collaborative tasks. |
# | **Day 5** | Request clarification on any unclear instructions from the lecturer. |
# | **Day 6‑7** | Attend the Q&A, take notes, and share a summary with your study group. |
# | **Week 2** | Use the progress tracker to mark completed tasks; adjust your schedule if needed. |
# | **End of Week 2** | Reflect on what interaction or support helped most and plan the next steps accordingly. |
#
# ---
#
# By focusing on these four areas—interaction, learning support, motivation, and self‑paced study—you’ll create a more engaging and effective learning experience. Feel free to adapt the actions to fit your personal timetable, and reach out to your instructors or peers whenever you need extra help. Good luck!

# %% [markdown]
# ## Student ID: `e20250665`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250665*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - Your self‑reported strengths and challenges were brief, so this report relies mainly on the typical characteristics of your segment.
#
# ### 2. Main Strengths
# - Your overall sentiment about your learning experience is positive.
#
# ### 3. Main Challenges
# - You also expressed a positive outlook on the challenges you face, indicating you are aware of areas that could be improved.
#
# ### 4. Personalized Recommendations
#
# | Focus Area | What It Means for You | Practical Steps |
# |------------|----------------------|-----------------|
# | **Interaction** | Increase opportunities to talk with peers and instructors. | • Join scheduled Q&A sessions.<br>• Participate in small‑group discussions or online forums.<br>• Seek quicker feedback from your lecturer after submitting work. |
# | **Learning Support** | Make course material clearer and easier to follow. | • Look for recorded explanations and step‑by‑step guides provided by the instructor.<br>• Request concrete examples when a concept isn’t clear.<br>• Use any supplemental worksheets or checklists offered. |
# | **Motivation & Self‑Discipline** | Keep yourself on track throughout the term. | • Set a weekly check‑in with yourself (or a study buddy) to review progress.<br>• Use reminders or a digital planner to schedule study blocks.<br>• Track completed tasks in a simple progress log. |
# | **Self‑Paced Learning** | Take advantage of materials you can review at any time. | • Watch recorded lectures before class or when you have free time.<br>• Follow the weekly learning path suggested by the course and pause to revisit any part that feels unclear.<br>• Keep all downloadable resources organized for quick reference. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **Week 1** | • Join at least one Q&A or discussion session.<br>• Download all recorded lessons and create a personal folder.<br>• Set a 30‑minute daily study slot and log what you cover. |
# | **Week 2** | • Request one concrete example or extra explanation for a topic you found tricky.<br>• Complete a brief self‑assessment (e.g., “What did I learn this week?”) and note any gaps.<br>• Share your progress log with a peer or tutor for quick feedback. |
#
# ---
#
# **Remember:** These suggestions are tailored to the typical needs of moderately engaged, passive learners. By adding more interaction, clearer support, and structured self‑pace tools, you can boost both confidence and performance in your blended courses. Good luck!

# %% [markdown]
# ## Student ID: `e20251246`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20251246
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the flexibility of blended learning for multitasking and handling multiple priorities. Your main concern is that communication between lecturers and peers can be unclear, which sometimes makes it harder to grasp course material.
#
# ---
#
# ### 2. Main Strengths
# - **Active engagement:** You make good use of blended formats to manage several tasks and priorities at once.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Information exchange with lecturers and classmates is not always clear.
# - **Learning Difficulty & Clarity:** Instructions and explanations sometimes lack the detail you need.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Increase interaction and communication** | Add more opportunities to ask questions, discuss with peers, and receive quick feedback from lecturers. | • Join scheduled Q&A sessions or virtual office hours.<br>• Participate in small‑group discussion boards.<br>• Use peer‑collaboration tools (e.g., shared docs, breakout rooms). |
# | **Improve clarity and learning support** | Receive clearer instructions, concrete examples, and step‑by‑step guides to help you understand tasks quickly. | • Look for recorded explanations or tutorial videos provided by the instructor.<br>• Request or use detailed rubrics and sample assignments.<br>• Access step‑by‑step learning guides that break down complex topics. |
#
# These recommendations are drawn directly from the evidence for your segment and the specific challenges you reported.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Review the course’s Q&A schedule and add the next session to your calendar. |
# | **Day 3** | Post one question or comment on the discussion board about a current topic. |
# | **Day 4–5** | Download any available recorded explanations or step‑by‑step guides for the week’s material. |
# | **Day 6** | Form a small study group (2–3 peers) for a 30‑minute virtual meeting to recap key concepts. |
# | **Day 7** | Request quick feedback on a draft assignment from your lecturer (use the course’s feedback tool). |
# | **Day 8–10** | Apply the step‑by‑step guide to complete an assignment; note any remaining unclear points. |
# | **Day 11** | Share your clarified notes with the study group and discuss any lingering questions. |
# | **Day 12–14** | Reflect on how the added interaction and clearer resources helped your learning; adjust the plan for the next period accordingly. |
#
# By following this short plan, you’ll strengthen communication with instructors and peers while gaining clearer, more supportive learning materials—helping you stay productive and confident in a blended environment.

# %% [markdown]
# ## Student ID: `e20250244`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20250244*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **What we know:** Your open‑ended responses did not provide specific strengths or challenges, so the recommendations below are based primarily on the typical characteristics of your segment.
#
# ---
#
# ### 2. Main Strengths
# - No specific strengths were reported.
#
# ---
#
# ### 3. Main Challenges
# - No specific challenges were reported.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What it means for you | Suggested actions |
# |-------|----------------------|-------------------|
# | **Interaction** | Passive learners often benefit from more opportunities to talk, ask questions, and work with peers. | • Join scheduled Q&A sessions.<br>• Participate in small‑group discussions or online forums.<br>• Pair up with a classmate for short peer‑collaboration tasks.<br>• Request quicker feedback from the lecturer when you submit work. |
# | **Learning Support** | Clear guidance helps you stay on track and understand expectations. | • Look for detailed instructions and examples posted with each assignment.<br>• Use any recorded explanations the instructor provides.<br>• Follow step‑by‑step learning guides that break down complex topics. |
# | **Motivation & Self‑Discipline** | Keeping momentum can be harder when learning feels passive. | • Set a weekly check‑in with yourself (or a study buddy) to review what you’ve completed.<br>• Enable reminders in your calendar for deadlines and study blocks.<br>• Track your progress in a simple spreadsheet or app.<br>• Follow a structured study schedule (e.g., 2 hours on Monday, 1 hour on Wednesday). |
# | **Self‑Paced Learning** | Having control over timing lets you review material as needed. | • Watch recorded lessons before class and again after if something isn’t clear.<br>• Follow the weekly learning path provided by the course (it outlines what to study each week).<br>• Keep all lecture slides and supplemental PDFs handy for quick review. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How to do it |
# |------|--------|--------------|
# | **Week 1** | Join a Q&A or discussion session | Check the course calendar for the next live Q&A; attend and ask at least one question. |
# | | Set up a simple progress tracker | Create a one‑page table (date, topic, completed?) and update it after each study session. |
# | | Watch the first recorded lecture twice | First watch for overview, second watch to note any unclear points; write down questions. |
# | **Week 2** | Pair with a peer for a short collaboration | Message a classmate and schedule a 30‑minute video call to discuss the week’s topic. |
# | | Use the weekly learning path | Follow the recommended sequence of readings, videos, and practice tasks; tick them off as you finish. |
# | | Review feedback promptly | After submitting any assignment, check the lecturer’s comments within 24 hours and note any suggested improvements. |
#
# ---
#
# **Remember:** These suggestions are tailored to the typical needs of Moderately Engaged (Passive) learners. As you try them out, notice what works best for you and feel free to adjust the plan to fit your personal study style. Good luck!

# %% [markdown]
# ## Student ID: `e20220628`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** e20220628
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# - **Strengths (as you described):** You value flexibility and the ability to manage your time without needing to travel.
# - **Challenges (as you described):** You experience occasional internet or technical difficulties.
#
# Because the open‑ended responses are brief, the recommendations below rely heavily on the typical profile of Moderately Engaged (Passive) learners in this segment.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You prefer learning that can fit around your schedule and does not require commuting.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unreliable connectivity can hinder access to online content.
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | What it means for you |
# |----------------|-----------------------|
# | **Support self‑paced learning** | Access recorded lectures, weekly learning paths, and downloadable materials so you can study whenever you have a stable connection. |
# | **Improve technical access and reliability** | Use offline resources (PDFs, downloadable videos) and clear step‑by‑step platform guides. Take advantage of any campus or university Wi‑Fi hotspots and the technical support service when problems arise. |
#
# ---
#
# ### 5. Short Action Plan
# | Week | Action |
# |------|--------|
# | **1** | Locate where recorded lessons and weekly learning paths are posted on the LMS. Download the first week’s materials for offline use. |
# | **2** | Test your internet connection in different campus locations or cafés; note the most reliable spot. |
# | **3** | Save a backup copy of all essential files on a USB drive or cloud folder you can reach without internet. |
# | **4** | Contact the technical support desk to confirm the process for reporting connectivity issues and ask about loaner Wi‑Fi devices if needed. |
# | **Ongoing** | Review recorded lessons at your own pace, using the weekly learning path to stay on track. |
#
# These steps should help you make the most of your flexibility while minimizing the impact of technical problems. If you encounter new challenges, reach out to your instructor or the support team for additional assistance. Good luck!

# %% [markdown]
# ## Student ID: `e20220234`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: e20220234*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - **Key strength identified:** Time flexibility (ability to manage when you study).
# - **Main challenge identified:** Discipline / maintaining motivation.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to choose when to study, which is a strong asset for blended learning.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Keeping a steady study routine can be difficult without external prompts.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to apply it |
# |----------------|----------------------|-----------------|
# | **Support motivation and self‑discipline** | Build habits that keep you on track. | • Join weekly check‑ins (virtual or with a tutor). <br>• Set up automated reminders for study sessions. <br>• Use a simple progress‑tracking sheet or app. <br>• Follow a structured weekly study schedule that aligns with your flexible timetable. |
# | **Support self‑paced learning** | Take advantage of resources you can access anytime. | • Watch recorded lectures before or after class. <br>• Follow the weekly learning path provided by the course (outline of what to cover each week). <br>• Review notes and supplemental materials at your own speed. |
#
# These suggestions are drawn directly from the rule‑based recommendations for your segment and the specific tags **motivation** and **self_paced**.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Set up a calendar reminder for a 30‑minute study block (choose a time that fits your schedule). |
# | **Wednesday** | Watch the recorded lecture for this week’s topic; add a note of one thing you learned. |
# | **Friday** | Complete the weekly progress check‑in (quick self‑assessment or brief chat with a tutor). |
# | **Saturday** | Review your notes and any unclear points; plan the next week’s study blocks. |
# | **Next Monday** | Adjust your schedule based on what worked; repeat the cycle. |
#
# Stick to this simple loop of **plan → study → check‑in → reflect**. Over time it will strengthen your self‑discipline while still leveraging the flexibility you value.
#
# Good luck, and remember that the blended format is designed to fit your active, engaged learning style!

# %% [markdown]
# ## Student ID: `ext_c92da50e38`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** ext_c92da50e38
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Moderately Engaged (Passive) Learners” segment. This group typically participates in class but prefers a more guided, structured environment and may not seek out interaction on their own. Your open‑ended response highlighted a specific challenge: a **lack of real‑life communication**.
#
# ---
#
# ### 2. Main Strengths
# *No specific strengths were reported.*
# Because the open‑ended strengths field is empty, this report focuses on the challenge you identified and the typical characteristics of your segment.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication:** You feel you have limited opportunities for real‑world communication and collaborative practice.
#
# ---
#
# ### 4. Personalized Recommendations
# **Increase interaction and communication**
# - **Live Q&A sessions:** Join short, scheduled question‑and‑answer slots with the lecturer to clarify concepts quickly.
# - **Group discussions:** Participate in small‑group online discussions or breakout rooms where you can practice speaking about course topics.
# - **Peer collaboration:** Work on short assignments or case studies with a classmate or small team; sharing ideas helps build communication skills.
# - **Faster lecturer feedback:** Use the course’s messaging or comment tools to ask for quick feedback on drafts or questions, keeping the dialogue active.
#
# These actions are directly drawn from the rule‑based recommendation for the “interaction” tag and align with the needs of your learner segment.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | How to Do It | Time Needed |
# |------|--------|--------------|-------------|
# | 1 | Attend a live Q&A | Sign up for the next scheduled Q&A in the LMS calendar. | 30 min |
# | 1 | Join a discussion board | Post a reply to a peer’s comment on the weekly topic. | 20 min |
# | 2 | Pair with a peer | Use the “study buddy” feature to schedule a 30‑minute video chat on the current module. | 30 min |
# | 2 | Request quick feedback | Submit a draft question or short write‑up and ask the lecturer for a brief comment within 24 h. | 15 min |
#
# **Tip:** Keep a simple log of these activities (date, what you did, how it felt). Reflecting on each interaction will help you see progress and stay motivated.
#
# ---
#
# By incorporating more structured interaction opportunities, you’ll strengthen real‑life communication skills while staying comfortable within your preferred learning style. Good luck, and remember that each small step builds confidence!

# %% [markdown]
# ## Student ID: `ext_aac013cd8b`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_aac013cd8b
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are a motivated student who likes to revisit lesson material, but you experience occasional internet instability.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You already make good use of the ability to review lessons and resources after class.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unstable connectivity can interrupt your study flow and limit access to online content.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** (content_access) | Keep all course slides, videos, readings, and exercises available early so you can review them whenever you need. | • Instructors should upload all materials at the start of each week.<br>• Save copies of PDFs or videos to your device for quick reference. |
# | **Improve technical access and reliability** (tech_issue) | Reduce the impact of unstable internet by having offline options and clear technical support. | • Download lecture videos and PDFs when you have a good connection.<br>• Use the platform’s “offline mode” (if available) to study without internet.<br>• Keep a list of support contacts (IT help‑desk, campus Wi‑Fi locations) for quick assistance. |
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Identify which course materials can be downloaded and store them on your laptop/tablet. |
# | **2** | Test the platform’s offline feature (or ask your instructor how to access materials offline). |
# | **3** | Locate the nearest reliable Wi‑Fi spots on campus or in a library; note the contact info for technical support. |
# | **4** | Review a previously uploaded lecture using your offline files to confirm everything works smoothly. |
#
# By following these steps, you can keep leveraging your strong habit of reviewing lessons while minimizing disruptions caused by internet issues. Keep up the active engagement—your proactive approach will help you succeed in a blended learning environment.

# %% [markdown]
# ## Student ID: `ext_66779a0cef`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["tech_issue"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** ext_66779a0cef
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You appreciate the flexibility of studying outside the classroom, which lets you manage your time without needing to be on campus all the time.
#
# **Main Challenges**
# - You experience technical difficulties: limited knowledge of the devices and software you need, and an unreliable internet connection.
#
# **Personalized Recommendations**
# Because your primary challenge is technical, the following recommendation is drawn directly from the rule‑based guidance for the “tech_issue” tag:
#
# - **Improve technical access and reliability** – Seek stable internet (e.g., campus Wi‑Fi hotspots, data plans, or library access), use offline versions of learning materials when possible, follow clear step‑by‑step instructions for the learning platform, and make use of the university’s technical support services.
#
# **Short Action Plan**
#
# | Step | What to Do | How to Do It | When |
# |------|------------|--------------|------|
# | 1 | Check internet options | Compare campus Wi‑Fi, local cafés, or a personal data plan for a more reliable connection. | This week |
# | 2 | Access offline resources | Download lecture videos, PDFs, and readings when you have a good connection so you can study offline later. | Before each class |
# | 3 | Learn the platform basics | Follow any “quick start” guides provided by the course or watch short tutorial videos. | First study session |
# | 4 | Use technical support | Contact the university IT help desk (email or phone) for any device or software issues you can’t resolve yourself. | As needed, keep a log of issues |
# | 5 | Review and adjust | After two weeks, note whether connectivity and platform use have improved and adjust your plan accordingly. | End of week 2 |
#
# By securing reliable internet, preparing offline materials, and using available technical support, you can reduce the barriers that currently limit your learning experience. This will help you make the most of the flexibility you value while staying on track with your coursework.

# %% [markdown]
# ## Student ID: `ext_0228387316`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "motivation"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** ext_0228387316
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You noted that you can use travel or “trip time” for studying. This shows an ability to fit learning into otherwise busy periods.
#
# **Main Challenges**
# - You feel a lack of motivation and notice that some professors are less active, which makes it harder to stay engaged with the material.
# - The challenges fall under the themes **Interaction & Communication** and **Motivation & Self‑Discipline**.
#
# **Personalized Recommendations**
#
# | Focus | What to Try | Why it Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join short, scheduled Q&A sessions or online discussion boards.<br>• Participate in small peer‑collaboration groups for assignments.<br>• Request quicker feedback from lecturers (e.g., via a shared comment sheet). | Increases contact with instructors and classmates, making the learning environment feel more active and supportive. |
# | **Motivation & Self‑Discipline** | • Set a weekly check‑in with yourself (or a study buddy) to review goals.<br>• Use digital reminders or a planner to block “study‑on‑the‑go” slots (e.g., during travel).<br>• Track progress with a simple checklist or app so you can see what you’ve completed. | Provides structure, regular accountability, and visible evidence of progress, which boosts motivation. |
#
# **Short Action Plan (Next 2 Weeks)**
#
# 1. **Pick a platform** (e.g., your university’s LMS or a free tool like Discord) and join a study‑group chat for your course.
# 2. **Schedule one 30‑minute Q&A session** with the lecturer or teaching assistant; add it to your calendar.
# 3. **Create a simple study schedule** that includes at least one “travel‑time” study block (e.g., 20 min on the bus).
# 4. **Set a weekly check‑in** (Monday evening) to review what you’ve accomplished and adjust the next week’s plan.
#
# By adding more interaction opportunities and a clear, self‑monitoring routine, you’ll turn passive engagement into a more active, motivated learning experience. Good luck!

# %% [markdown]
# ## Student ID: `ext_512ca5e936`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: ext_512ca5e936*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values the combination of face‑to‑face teaching and online resources. You appreciate the flexibility to review material anytime, the convenience of digital access, and the opportunity for direct interaction with instructors. Your comments show a strong, positive view of blended learning and a clear awareness of what works well for you.
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You benefit from having slides, videos, and exercises available early.
# - **Digital Skills Development** – You are comfortable using online tools and see them as a way to enhance learning.
# - **Flexibility & Time Management** – Being able to study when it fits your schedule helps you stay on track.
# - **Student Engagement** – Interactive activities keep you motivated and involved.
#
# ### 3. Main Challenges
# - **Interaction & Communication** – You would like more Q&A, peer collaboration, and faster lecturer feedback.
# - **Internet & Technical Issues** – Reliable connectivity and clear platform instructions are important for you.
# - **Learning Difficulty & Clarity** – Clear instructions, examples, and step‑by‑step guides would improve understanding.
# - **Learning Resources & Environment** – Better‑organized materials and comfortable study spaces would support your work.
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Upload slides, videos, references, exercises, and other course materials **early** in the semester. |
# | **Digital Skills** | Offer short guides or workshops on using the LMS, online research tools, and other educational technologies. |
# | **Engagement** | Include regular quizzes, games, practical tasks, and discussion prompts to keep you actively involved. |
# | **Interaction** | Schedule frequent Q&A sessions, group discussions, and peer‑collaboration activities; aim for quicker lecturer feedback. |
# | **Learning Effectiveness** | Pair online review resources with in‑person explanations, practice sessions, and timely feedback. |
# | **Learning Environment** | Keep digital resources well‑organized, update them regularly, and ensure classroom spaces are comfortable and conducive to study. |
# | **Learning Support** | Provide clearer instructions, concrete examples, recorded explanations, and step‑by‑step guides for complex topics. |
# | **Self‑Paced Learning** | Make recorded lessons and weekly learning paths available so you can review material at your own speed. |
# | **Technical Issues** | Ensure stable internet access, offer offline versions of key materials, give clear platform navigation instructions, and provide responsive technical support. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Check that all lecture slides and videos are uploaded to the LMS at least 48 hours before class. |
# | **2** | Attend a 30‑minute LMS “quick‑start” workshop (or watch the recorded guide). |
# | **3** | Participate in a scheduled online Q&A session; submit any questions you have beforehand. |
# | **4** | Review the newly added step‑by‑step guides for the current module and complete the associated quiz for instant feedback. |
#
# By following these steps, you can keep leveraging your strong engagement while addressing the technical and interaction challenges you identified. Feel free to reach out to your lecturers or the support team if you need additional help with any of the recommendations. Good luck!

# %% [markdown]
# ## Student ID: `ext_9a36e5e80e`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** ext_9a36e5e80e
# **Learning Segment:** *Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can **access course materials at any time**, which helps you manage a busy schedule. At the same time, you experience **unstable internet connections** and find it hard to stay focused during live online sessions.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You make good use of recorded lectures and downloadable resources.
# - **Flexibility & Time Management** – Being able to study when it suits you works well for you.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Limited real‑time engagement and peer collaboration.
# - **Internet & Technical Issues** – Connectivity problems disrupt online class participation.
# - **Learning Difficulty & Clarity** – Need clearer explanations and step‑by‑step guidance.
# - **Motivation & Self‑Discipline** – Staying focused and motivated during online sessions is difficult.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | • Instructors will upload slides, videos, references, exercises, and any other course material **well before class** so you can download or view them offline. |
# | **Interaction** | • Short **Q&A slots** and **small‑group discussions** will be added each week. <br>• Peer‑collaboration tasks and faster lecturer feedback will help you stay connected. |
# | **Learning Support** | • Lecturers will provide **clearer instructions**, concrete examples, and short recorded explanations that break down complex topics step‑by‑step. |
# | **Motivation** | • You will receive **weekly check‑ins** (email or chat) with reminders, a simple progress tracker, and a suggested study schedule to keep you on track. |
# | **Self‑Paced Learning** | • All lessons will be recorded and organized into **weekly learning paths** so you can review at your own speed. |
# | **Technical Issues** | • The university will offer **offline versions** of key resources and a **technical‑support helpdesk**. <br>• Guidance on optimizing platform use and, where possible, access to campus Wi‑Fi hotspots will be provided. |
#
# ---
#
# ### 5. Short Action Plan (First 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Download all lecture recordings and slides for the week; set up a personal study schedule using the provided template. |
# | **2** | Join the first live Q&A session; post any unclear points in the discussion forum for quick lecturer feedback. |
# | **3** | Use the offline material pack (PDFs, videos) during a low‑bandwidth day; note any technical issues and contact support. |
# | **4** | Review your progress tracker; attend a peer‑collaboration activity and reflect on what helped you stay focused. |
#
# ---
#
# **Remember:** Your ability to access materials anytime is a strong advantage. By adding structured interaction, clearer guidance, and reliable technical support, you can turn passive engagement into active, self‑directed learning. Feel free to reach out to your course coordinator or the tech support team whenever you need assistance. Good luck!

# %% [markdown]
# ## Student ID: `ext_f3d7c7db94`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "engagement", "interaction", "learning_environment", "motivation", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: ext_f3d7c7db94*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You are a highly engaged learner who values flexibility, digital collaboration, and frequent interaction with classmates. You thrive when you can move easily between online and face‑to‑face activities. At the same time, you experience digital isolation, time‑management pressure, and information overload, especially when assessments pile up.
#
# ---
#
# ### 2. Main Strengths
# | Strength | Evidence |
# |----------|----------|
# | **Digital Skills & Flexibility** | You highlighted “flexibility digital collaboration and enhanced interaction with classmates.” |
# | **Active Engagement** | Your segment label (Highly Engaged) confirms a natural willingness to participate. |
# | **Collaboration** | You enjoy working with peers online. |
#
# ---
#
# ### 3. Main Challenges
# | Challenge | Evidence |
# |-----------|----------|
# | **Digital Isolation & Interaction Gaps** | “digital isolation … for suggestions are creating co‑working space.” |
# | **Time‑Management & Workload** | “time_management and information overload.” |
# | **Motivation / Self‑Discipline** | Linked to workload pressure and the need for quicker feedback. |
#
# ---
#
# ### 4. Personalized Recommendations
# (Each recommendation follows the rule‑based guidance for the tags that match your strengths and challenges.)
#
# | Area | What to Do | Why it Helps |
# |------|------------|--------------|
# | **Digital Skill** | Attend short workshops on LMS navigation, digital research tools, and educational apps. | Strengthens the digital collaboration you already enjoy. |
# | **Engagement** | Use interactive quizzes, gamified tasks, and practical projects in both online and on‑campus sessions. | Keeps your high energy focused and reduces boredom. |
# | **Interaction** | Join scheduled Q&A webinars, peer‑led discussion boards, and group‑work assignments; ask lecturers for faster feedback. | Reduces feelings of digital isolation and improves communication. |
# | **Learning Environment** | Create a personal co‑working space (e.g., campus study lounge or virtual breakout room) and keep digital resources well‑organized. | Provides a comfortable setting for focused study and reduces information overload. |
# | **Motivation & Self‑Discipline** | Set weekly check‑ins with a study buddy or tutor, use reminder apps, and track progress on a visual dashboard. | Helps you stay on schedule and maintain momentum. |
# | **Self‑Paced Learning** | Record lectures for later review, follow a weekly learning path, and revisit materials as needed. | Gives you the flexibility you value while managing workload. |
# | **Workload Support** | Request a clear assignment calendar, break large tasks into micro‑learning chunks, and align online work with face‑to‑face sessions. | Balances assessment pressure and prevents overload. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Review the LMS guide provided by your faculty; bookmark three digital tools you want to try. |
# | **Day 3** | Join a peer‑led study group or book a co‑working slot in the campus lounge. |
# | **Day 5** | Set up a weekly reminder (e.g., Google Calendar) for a 30‑minute “progress check‑in” with a buddy. |
# | **Day 7** | Complete the first micro‑learning module of an upcoming assignment; note any questions for the next Q&A session. |
# | **Day 10** | Attend a short quiz or game‑based activity in your course; reflect on what kept you motivated. |
# | **Day 12** | Request a clear deadline overview from your lecturer and confirm how online tasks connect to in‑person work. |
# | **Day 14** | Review your notes and recorded lecture; update your personal study schedule for the next week. |
#
# Follow these steps, adjust as needed, and you’ll turn your strong engagement into smoother, more balanced learning experiences. If you need further support, reach out to your academic advisor or the university’s learning‑technology help desk. Good luck!

# %% [markdown]
# ## Student ID: `ext_fc1236d764`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_fc1236d764
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# Because the open‑ended responses did not provide specific strengths or challenges, this report draws primarily on the characteristics of the “Highly Engaged (Active) Learners” segment.
#
# ---
#
# ### 2. Main Strengths
# *Based on the segment profile:*
# - Strong motivation to participate in class activities.
# - Tendency to take initiative and stay involved with course content.
#
# ---
#
# ### 3. Main Challenges
# *Based on the segment profile:*
# - May need clearer, readily available digital resources to sustain high engagement.
# - Could benefit from structured support for self‑paced study to complement active participation.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Having slides, videos, readings, and exercises available early lets you dive deeper and keep the momentum. | Upload or request all course resources (slides, recordings, reference links) at the start of each module. |
# | **Develop digital learning skills** | Mastering the LMS, online research tools, and educational tech helps you work efficiently. | Attend a short workshop or watch a tutorial on using the LMS, citation managers, and digital libraries. |
# | **Increase learner engagement** | Interactive quizzes, games, practical tasks, and discussion forums keep your learning lively. | Participate in weekly polls, join discussion boards, and try the course’s gamified quizzes. |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you review concepts whenever you need. | Use the recorded lectures to revisit tricky topics and follow the suggested weekly study schedule. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Locate the course’s central repository (e.g., LMS folder) and download all available slides, videos, and reading lists. |
# | **Day 3** | Watch a 15‑minute tutorial on key LMS features (assignment upload, discussion boards, quiz navigation). |
# | **Day 4–5** | Complete the first interactive quiz or game provided for the current module. |
# | **Day 6** | Join the module’s discussion forum; post a question or comment about the week’s topic. |
# | **Day 7** | Review the recorded lecture for any concepts that felt fast‑paced; take brief notes. |
# | **Day 8–10** | Follow the suggested weekly learning path: read the assigned article, do the practice exercise, and reflect in a short journal entry. |
# | **Day 11–12** | Try a digital research task (e.g., locate a scholarly source using the university library’s online portal). |
# | **Day 13–14** | Summarize what you’ve learned in a 2‑minute video or slide deck to reinforce understanding and share with peers. |
#
# ---
#
# **Keep leveraging your natural enthusiasm—pair it with easy access to materials, solid digital skills, interactive activities, and the flexibility of self‑paced resources.** This combination will help you stay motivated, deepen understanding, and succeed in a blended learning environment.

# %% [markdown]
# ## Student ID: `ext_4db72fc692`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "interaction", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: ext_4db72fc692*
# *Segment: Cluster 1 – Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You belong to the “Moderately Engaged (Passive) Learners” segment. This group generally appreciates the flexibility of blended learning but may struggle with staying focused online, technical reliability, and getting clear guidance from instructors.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You value being able to study both in‑class and online, which helps you organise your schedule.
# - **Access to Learning Materials** – You see the availability of slides, videos, and other resources as a key advantage.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Unstable connections make online work difficult.
# - **Interaction & Communication** – You would like more interactive and clearer online instruction.
# - **Learning Difficulty & Clarity** – Better explanations and step‑by‑step guidance are needed to stay focused.
# - **Motivation & Self‑Discipline** – Maintaining motivation when learning remotely can be hard.
#
# ### 4. Personalized Recommendations
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Lecturers will upload slides, videos, reference links, exercises, and any other course material **early** in the week so you can plan ahead. |
# | **Interaction** | The course will include regular **Q&A sessions, small‑group discussions, and peer‑collaboration tasks**. Expect faster feedback from instructors on your questions. |
# | **Learning Environment** | Materials will be **organized clearly** in the LMS, and study spaces (both physical and virtual) will be improved for comfort and focus. |
# | **Learning Support** | Expect **clearer instructions, concrete examples, and recorded step‑by‑step explanations** for complex topics. |
# | **Motivation** | Weekly check‑ins, gentle reminders, and a simple **progress‑tracking dashboard** will help you see how you’re advancing and keep you motivated. |
# | **Self‑Paced Learning** | All lectures will be **recorded** and made available alongside a **weekly learning path** so you can review at your own speed. |
# | **Technical Issues** | The university will provide **stable campus Wi‑Fi hotspots, offline downloadable resources**, and a dedicated **technical‑support channel** for quick help. |
#
# ### 5. Short Action Plan (First 2 Weeks)
#
# | Week | Action | How it Helps You |
# |------|--------|------------------|
# | 1 | Review the **early‑uploaded course folder** (slides, videos, exercises). | Gives you a clear roadmap and lets you plan your study time. |
# | 1 | Join the **introductory live Q&A** (schedule posted in LMS). | Starts building interaction and clarifies any immediate doubts. |
# | 2 | Complete the **first weekly learning path** and mark progress in the dashboard. | Reinforces self‑paced study and provides visible progress. |
# | 2 | Test the **offline download option** for any video you anticipate needing without internet. | Reduces disruption from unstable connections. |
# | Ongoing | Attend **peer‑collaboration groups** (once per week) and use the **technical‑support chat** when needed. | Improves communication, motivation, and technical reliability. |
#
# ---
#
# **Remember:** These recommendations are built from your own feedback and the typical needs of your learner segment. By following the short action plan and using the resources provided, you can turn the flexibility of blended learning into a stronger, more focused study experience. Good luck!

# %% [markdown]
# ## Student ID: `ext_884f03d7c9`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "engagement", "interaction", "learning_effectiveness", "self_paced", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_884f03d7c9
# - **Segment:** *Cluster 2 – Highly Engaged (Active) Learners*
# - You value the flexibility of digital tools, the personal connection of face‑to‑face teaching, and data‑driven personalization. You are aware of digital fatigue and a possible doubled workload, and you see the need for streamlined platforms and more active in‑person time.
#
# ---
#
# ### 2. Main Strengths
# - Strong digital‑skills mindset and enthusiasm for using technology to learn.
# - Excellent time‑management and appreciation of flexible, convenient learning.
# - High level of engagement and motivation to make learning effective.
#
# ---
#
# ### 3. Main Challenges
# - Risk of digital fatigue and feeling that workload may double when digital and face‑to‑face tasks are not well coordinated.
# - Need for clearer interaction and communication channels between you, peers, and lecturers.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do | Why it Helps you |
# |------|------------|------------------|
# | **Digital Skill** | Follow short guides on your LMS, explore online research tools, and try out new educational technologies. | Strengthens the digital foundation you already value and reduces fatigue by making tools easier to use. |
# | **Engagement** | Participate in quizzes, game‑based activities, practical tasks, and class discussions. | Keeps your high energy focused and makes learning more enjoyable. |
# | **Interaction** | Join scheduled Q&A sessions, small‑group discussions, and peer‑collaboration projects; request quicker feedback from lecturers. | Improves communication, lessens feelings of isolation, and helps you manage workload. |
# | **Learning Effectiveness** | Use a blended approach: review recorded material before class, then use in‑person time for explanations, practice, and feedback. | Combines the convenience you like with the hands‑on support you need. |
# | **Self‑Paced Learning** | Follow weekly learning paths and revisit recorded lessons whenever needed. | Gives you control over pacing while still fitting into the overall course schedule. |
# | **Workload Support** | Keep a personal calendar of assignment deadlines, and look for courses that align online tasks with face‑to‑face sessions. | Balances the amount of work and prevents overload. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Watch the LMS “Getting Started” video (10 min) and bookmark two digital research tools. |
# | **2** | Join a weekly quiz or game activity in one of your modules; note how it affects your motivation. |
# | **3** | Schedule a 15‑minute Q&A slot with a lecturer and start a small study group on a discussion board. |
# | **4** | Create a simple weekly learning path: 1 hour of recorded review, 2 hours of in‑person practice, and 30 minutes of assignment work. Review your deadline list and adjust any overlapping tasks. |
#
# Follow these steps, keep track of what feels most helpful, and adjust as needed. Your active approach and willingness to use both digital and face‑to‑face resources will make blended learning work efficiently for you.

# %% [markdown]
# ## Student ID: `ext_b4f1332dfa`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_environment", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: ext_b4f1332dfa*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You thrive when you can manage your own study schedule, use personal techniques, and apply what you learn through projects. Blended learning gives you the flexibility to explore topics online and deepen classroom concepts.
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You enjoy planning your study time and using self‑directed methods.
# - **Learning Convenience & Effectiveness** – Blended formats let you review material at your own pace and connect classroom learning with internet resources.
#
# ### 3. Main Challenges
# - **Technical & Internet Issues** – Occasional low‑bandwidth or platform problems disrupt learning.
# - **Learning Environment** – You need a quiet, well‑equipped space and reliable study materials.
# - **Interaction & Communication** – Faster feedback and more peer collaboration would help.
# - **Assessment & Workload** – Clear deadlines and balanced assignments are important for you.
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Interaction** | Join scheduled Q&A sessions, take part in small‑group discussions, and use peer‑collaboration tools. Request quicker feedback from lecturers when possible. |
# | **Learning Effectiveness** | Pair online review videos with in‑person explanations and practice activities. Use the feedback loops to refine your project work. |
# | **Learning Environment** | Use organized, clearly labeled digital folders; ask the department to keep study spaces comfortable and well‑lit. |
# | **Self‑Paced Learning** | Take advantage of recorded lectures and weekly learning paths. Review materials whenever you need extra time. |
# | **Technical Issues** | Access the university’s stable Wi‑Fi zones or download offline copies of essential content. Keep the platform’s help guide handy and contact tech support promptly when problems arise. |
# | **Workload Support** | Look for a balanced schedule: clarify assignment deadlines early, and align online tasks with what is covered in class to avoid overload. |
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the recorded lectures for your current module and create a personal weekly learning path. |
# | **2** | Join a peer‑study group or discussion forum; schedule at least one Q&A session with the lecturer. |
# | **3** | Test the campus Wi‑Fi or download offline PDFs of key readings; note any technical glitches and report them. |
# | **4** | Review upcoming assignment deadlines with the course coordinator; request a clear timeline if needed. |
#
# By focusing on these targeted steps, you can keep leveraging your strong self‑management skills while smoothing out the technical, environmental, and interaction challenges you’ve identified. Good luck, and keep the active engagement that makes you a standout learner!

# %% [markdown]
# ## Student ID: `ext_d138e08e00`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_effectiveness", "learning_environment", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_d138e08e00
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - **Overall view:** You are comfortable with self‑study and find the convenience of online learning useful. Your main concern is the limited interaction with lecturers and classmates, which can affect motivation and focus during online sessions.
#
# ---
#
# ### 2. Main Strengths
# - **Self‑study ability:** You have the skills to learn independently, which supports flexible, self‑paced study.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Few opportunities to ask questions, discuss ideas, or receive quick feedback.
# - **Learning Resources & Environment:** Need clearer organization of materials and more supportive study spaces.
# - **Motivation & Self‑Discipline:** Maintaining attention and drive can be difficult without collaborative or innovative activities.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and small‑group discussions.<br>• Participate in peer‑collaboration tasks (e.g., shared documents, breakout rooms).<br>• Request quicker feedback from lecturers on assignments. | Increases dialogue, clarifies doubts, and builds a sense of community. |
# | **Learning Effectiveness** | • Pair online review videos with brief in‑person (or live‑online) explanations and practice exercises.<br>• Seek immediate feedback on practice tasks. | Reinforces concepts and bridges the gap between theory and application. |
# | **Learning Environment** | • Use a dedicated, organized digital folder for each course.<br>• Choose a quiet, comfortable study spot; consider campus study rooms if possible.<br>• Keep course resources up‑to‑date (download PDFs, bookmark links). | A tidy, comfortable space reduces distraction and makes material easier to locate. |
# | **Motivation & Self‑Discipline** | • Set a weekly study schedule with specific goals.<br>• Use a simple progress tracker (checklist or app).<br>• Attend brief weekly check‑ins with a tutor or study buddy for accountability. | Structured routines and visible progress keep you on track and boost confidence. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a folder system for all current courses (e.g., “Course – Week 1”). |
# | **Tuesday** | Sign up for the next live Q&A session in one of your classes. |
# | **Wednesday** | Draft a 30‑minute weekly study schedule; include one peer‑discussion slot. |
# | **Thursday** | Locate a quiet study space on campus or set up a distraction‑free area at home. |
# | **Friday** | Start a simple progress tracker (e.g., checklist of weekly goals). |
# | **Weekend** | Review the week’s material using online videos, then write down 2‑3 questions to bring to the next discussion. |
# | **Next Monday** | Meet (in‑person or virtually) with a classmate to discuss those questions and share notes. |
# | **Following Tuesday** | Request feedback on one recent assignment from the lecturer. |
#
# Follow this cycle, adjusting the schedule as you discover what works best for you. Small, consistent steps will strengthen interaction, improve the learning environment, and keep motivation high while leveraging your strong self‑study skills. Good luck!

# %% [markdown]
# ## Student ID: `ext_9ba29e032d`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["digital_skill", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** ext_9ba29e032d
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive in flexible learning environments that let you combine online work with face‑to‑face interaction. You value digital tools that let you study at your own pace, but you sometimes find it hard to stay interested during online sessions and wish instructions and resources were clearer and easier to locate.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Digital Skills Development** | You appreciate the technology that supports blended learning. |
# | **Flexibility & Time Management** | You like being able to learn online at your own speed while still getting in‑person help. |
# | **Learning Convenience & Effectiveness** | You see blended learning as a way to understand material better through a mix of formats. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you mentioned |
# |-------|--------------------|
# | **Interaction & Communication** | Staying interested in online classes and getting clear, timely feedback can be difficult. |
# | **Learning Difficulty & Clarity** | Instructions are sometimes vague, making it hard to know what is expected. |
# | **Learning Resources & Environment** | Finding and navigating materials is occasionally confusing; you would like a more organized learning space. |
#
# ---
#
# ### 4. Personalized Recommendations
# Based on your strengths, challenges, and the “Highly Engaged (Active) Learners” segment, the following actions are recommended:
#
# | Recommendation | Why it matters for you | Practical steps you can take |
# |----------------|-----------------------|------------------------------|
# | **Develop digital learning skills** | You already value technology; sharpening these skills will make online work smoother. | • Attend a short LMS tutorial (often offered by the university). <br>• Explore the library’s digital research guides. |
# | **Increase interaction and communication** | More active Q&A and peer work will keep you engaged and clarify expectations. | • Join a study‑group chat for each course. <br>• Request brief live Q&A slots after recorded lectures. |
# | **Improve learning effectiveness** | Pairing online review with in‑person practice helps you consolidate knowledge. | • Use the provided “review‑before‑class” videos, then attend the face‑to‑face session for hands‑on activities. |
# | **Improve learning resources and environment** | Clear, well‑organized materials reduce the time spent searching and increase focus. | • Use the course’s “module map” to see where each file belongs. <br>• Give feedback to the module coordinator if folders seem unclear. |
# | **Improve clarity and learning support** | Precise instructions and examples will reduce confusion and keep you motivated. | • Look for recorded walkthroughs that accompany each assignment. <br>• Keep a personal checklist of steps for each task. |
# | **Support self‑paced learning** | You enjoy setting your own pace; structured pathways keep you on track. | • Follow the weekly learning path posted on the LMS. <br>• Bookmark recorded lessons for review before exams. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1–2** | Watch the university’s “Getting Started with the LMS” video (≈15 min). |
# | **Day 3** | Create a personal folder structure that mirrors the course module layout. |
# | **Day 4–5** | Join a course‑specific discussion group on the student platform. |
# | **Day 6** | Draft a list of unclear instructions from the current assignment; share it with the lecturer for clarification. |
# | **Day 7** | Schedule 30 min of self‑paced review using the week’s recorded lessons. |
# | **Day 8–10** | Participate in a live Q&A session (or request one) for any lingering questions. |
# | **Day 11** | Complete a short peer‑collaboration activity (e.g., a 2‑person problem set). |
# | **Day 12–14** | Reflect on what worked best (digital tools, interaction, organized resources) and adjust your study plan for the next module. |
#
# ---
#
# **Keep in mind:** Your active engagement is a strong asset. By fine‑tuning digital skills, boosting interaction, and ensuring resources are clear and well‑organized, you’ll make the most of blended learning and keep your motivation high. Good luck!

# %% [markdown]
# ## Student ID: `ext_ffbae08b83`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_effectiveness", "learning_environment", "learning_support", "motivation"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** ext_ffbae08b83
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can study independently, at your own pace and in a space that works for you. You recognize that building self‑discipline can be challenging at first, but you expect it to improve as you become more familiar with blended learning.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You are comfortable learning on your own schedule and can make good progress when you have clear, self‑paced resources.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline:** Keeping a regular study rhythm can feel difficult.
# - **Learning Difficulty & Clarity:** Occasionally the material or instructions are not clear enough.
# - **Learning Resources & Environment:** A well‑organized study space and up‑to‑date resources would help you focus.
#
# ---
#
# ### 4. Personalized Recommendations
# | Focus | What to Do (based on rule‑based advice) |
# |-------|------------------------------------------|
# | **Learning Effectiveness** | Pair the online review videos or readings with in‑person sessions where the instructor explains concepts, gives you practice tasks, and provides immediate feedback. |
# | **Learning Environment** | Keep your digital files and course materials neatly organized; choose a quiet, comfortable study spot. Ask the course team to update any outdated resources you notice. |
# | **Learning Support** | Look for clear step‑by‑step guides, recorded explanations, and concrete examples. If instructions feel vague, request additional clarification or short tutorial videos. |
# | **Motivation & Self‑Discipline** | Set a weekly study schedule and stick to it. Use reminders or a calendar app, track your progress each week, and attend brief check‑ins (online or in‑person) to stay accountable. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Create a dedicated study folder for the course and upload all lecture slides, notes, and links. |
# | **Tuesday** | Draft a simple weekly timetable (e.g., 2 hrs online review + 1 hr in‑person practice). Set calendar reminders. |
# | **Wednesday** | Watch the first online review video, then attend the scheduled in‑person session to ask questions and do practice exercises. |
# | **Thursday** | Summarize what you learned in a one‑page outline; note any unclear points. |
# | **Friday** | Review the outline, watch a short recorded explanation for any unclear topics, and complete a quick self‑quiz. |
# | **Weekend** | Reflect on your progress: mark completed tasks in your tracker and adjust the timetable if needed. |
# | **Next Monday** | Attend a brief check‑in (virtual or face‑to‑face) with a tutor or peer to discuss any remaining doubts and set goals for the following week. |
#
# Follow this cycle each week, tweaking the schedule as you become more comfortable with the blended format. Consistent organization, clear resources, and regular check‑ins will strengthen both your learning effectiveness and self‑discipline. Good luck!

# %% [markdown]
# ## Student ID: `ext_a9abaf7ae3`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_a9abaf7ae3
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# Because the open‑ended responses did not provide specific strengths or challenges, this report is based primarily on the characteristics of the “Moderately Engaged (Passive)” segment.
#
# ---
#
# ### 2. Main Strengths
# *No specific strengths were reported.*
# The segment generally shows the ability to follow course material when it is clearly presented and when support is available.
#
# ---
#
# ### 3. Main Challenges
# *No specific challenges were reported.*
# Learners in this segment often benefit from more interaction, clearer guidance, and tools that help maintain motivation and self‑discipline.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities.<br>• Request quicker feedback from the lecturer. | Increases engagement and reduces passivity. |
# | **Learning Support** | • Look for detailed instructions, examples, and step‑by‑step guides.<br>• Use recorded explanations when concepts are unclear. | Improves clarity and reduces confusion. |
# | **Motivation** | • Set up weekly check‑ins (with yourself or a study buddy).<br>• Use reminders and a simple progress‑tracking sheet.<br>• Follow a structured study schedule. | Builds self‑discipline and keeps you on track. |
# | **Self‑Paced Learning** | • Access recorded lessons and review them as needed.<br>• Follow the weekly learning path provided by the course.<br>• Keep all materials organized for easy revisiting. | Allows you to learn at a comfortable speed while staying aligned with the course timeline. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | • Attend at least one Q&A or discussion session.<br>• Download the recorded lessons for the current module.<br>• Create a simple weekly schedule with study blocks and set reminders. |
# | **2** | • Complete a peer‑collaboration activity (e.g., a short group assignment).<br>• Review the step‑by‑step guide for any concept you found difficult.<br>• Fill out a quick progress tracker at the end of each study block and note any questions for the lecturer. |
#
# Follow this plan, and adjust the pace as you become more comfortable with the course structure. Remember, increasing interaction, seeking clear support, and maintaining a regular check‑in routine are key steps toward a more active and successful learning experience.

# %% [markdown]
# ## Student ID: `ext_8d5e60eeaf`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_8d5e60eeaf
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# You tend to appreciate having flexible study options and easy access to a variety of learning materials. At the same time, maintaining discipline and consistent motivation can be a challenge.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials** – You value having slides, videos, references, and exercises readily available.
# - **Flexibility & Time Management** – You prefer being able to study when it best fits your schedule.
#
# ---
#
# ### 3. Main Challenges
# - **Motivation & Self‑Discipline** – Keeping a steady study routine and staying motivated can be difficult.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What It Means for You | How to Apply It |
# |----------------|----------------------|-----------------|
# | **Strengthen access to learning materials** | Keep all course content (slides, videos, readings, exercises) uploaded early so you can grab what you need anytime. | Check the course portal each week for new uploads; download or bookmark resources for offline review. |
# | **Support motivation and self‑discipline** | Use structured supports to stay on track. | Set up weekly check‑ins (e.g., a brief self‑review or a reminder from the LMS), follow a simple progress tracker, and create a short, repeatable study schedule. |
# | **Support self‑paced learning** | Take advantage of recorded lessons and weekly learning paths that let you study at your own speed. | Watch recorded lectures before class, then use the weekly learning path to guide what to review or practice that week. |
#
# These suggestions are drawn directly from the recommendations linked to your segment and the strengths/challenges you reported.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the course’s “Week 1” folder; download all slides and videos. |
# | **Tuesday** | Create a simple study schedule (e.g., 1 hour on Tuesday, 1 hour on Thursday). |
# | **Wednesday** | Set a reminder in your phone/calendar for a 5‑minute “progress check” at the end of each study session. |
# | **Thursday** | Watch the recorded lecture for the next topic; note any questions. |
# | **Friday** | Complete one practice exercise and mark it as done in the LMS tracker. |
# | **Weekend** | Reflect on what worked (e.g., did the reminder help?) and adjust the schedule for next week. |
#
# Repeat a similar pattern for the following week, gradually adding more self‑check‑ins or adjusting the study blocks as you find what best supports your motivation.
#
# ---
#
# **Remember:** Your flexibility and access to materials are strong assets—use them to build a routine that keeps you motivated and on track. Good luck!

# %% [markdown]
# ## Student ID: `ext_3c42a480ce`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_support", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_3c42a480ce
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# Because the open‑ended responses did not provide specific strengths or challenges, the recommendations below are drawn primarily from the characteristics of this segment.
#
# ---
#
# ### 2. Main Strengths
# *No explicit strengths were reported.*
# The report therefore focuses on general strengths typical of moderately engaged learners, such as the ability to follow structured material when it is clearly presented.
#
# ---
#
# ### 3. Main Challenges
# *No explicit challenges were reported.*
# Based on the segment profile, passive learners often benefit from more interaction, clearer guidance, and motivation supports.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Focus | What to Do | Why it Helps |
# |-------|------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and online discussion boards.<br>• Participate in small‑group peer collaborations.<br>• Request quicker feedback from lecturers. | Increases engagement and makes learning feel more social. |
# | **Learning Support** | • Look for detailed instructions, examples, and step‑by‑step guides.<br>• Use recorded explanations that you can replay. | Clarifies expectations and reduces confusion when studying independently. |
# | **Motivation & Self‑Discipline** | • Set up weekly check‑ins (with a tutor or study buddy).<br>• Use reminders or a digital planner to track progress.<br>• Follow a structured study schedule. | Keeps you on track and builds momentum throughout the term. |
# | **Self‑Paced Learning** | • Access recorded lectures and supplemental videos.<br>• Follow the weekly learning path provided by the course.<br>• Review materials at a time that suits you. | Allows you to study when you’re most focused while still meeting course deadlines. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | • Register for the upcoming Q&A session and join the course discussion forum.<br>• Download the first set of recorded lessons and accompanying step‑by‑step guides.<br>• Set a weekly reminder to log your study hours. |
# | **2** | • Form a small study group (2‑3 peers) for a 30‑minute collaborative review.<br>• Submit a brief progress update to your lecturer or tutor.<br>• Adjust your study schedule based on the feedback you receive. |
#
# Stick to these steps, and you’ll gradually move from passive participation to a more active, supported, and self‑directed learning experience. Good luck!

# %% [markdown]
# ## Student ID: `ext_db00a81b13`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "motivation", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** ext_db00a81b13
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You value the **flexibility** of blended learning – being able to review online materials anytime and combine them with in‑person classes for questions and interaction. At the same time, you notice that **online communication can be unclear**, motivation may dip during long online periods, and occasional internet or technical problems can disrupt your study.
#
# ---
#
# ### 2. Main Strengths
# - **Access & Flexibility:** You appreciate having slides, videos, and other resources available online so you can learn at your own pace.
# - **Convenient Learning:** The mix of online revision and face‑to‑face sessions helps you understand material more effectively.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication:** Online instructions sometimes lack clarity, and you would like more direct contact with lecturers and peers.
# - **Motivation & Self‑Discipline:** Staying motivated during extended online sessions can be difficult.
# - **Technical Issues:** Unstable internet or platform problems occasionally hinder your learning.
# - **Workload Management:** Balancing online tasks with in‑person work can feel overwhelming.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Content Access** | Lecturers will **upload slides, videos, references, and exercises early** so you can review them whenever you need. |
# | **Engagement** | Course activities will include **quizzes, games, practical tasks, and discussions** to keep you actively involved. |
# | **Interaction** | Expect **regular Q&A sessions, group discussions, peer collaboration**, and faster feedback from lecturers. |
# | **Learning Effectiveness** | Materials will be **combined: online review plus in‑person explanation, practice, and feedback** to reinforce understanding. |
# | **Learning Environment** | Resources will be **clearly organized and regularly updated**; study spaces will be improved for comfort. |
# | **Learning Support** | Instructions will be **clearer, with examples, recorded explanations, and step‑by‑step guides**. |
# | **Motivation** | You’ll receive **weekly check‑ins, reminders, progress tracking, and a structured study schedule** to sustain motivation. |
# | **Self‑Paced Learning** | **Recorded lessons and weekly learning paths** will be provided so you can study at a pace that fits you. |
# | **Technical Issues** | The university will ensure **stable internet access, offline material options, clear platform guides, and dedicated technical support**. |
# | **Workload Support** | Assignments will be **balanced, deadlines clarified, and online tasks aligned with in‑person sessions** to reduce pressure. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Review the newly uploaded slide deck and video recordings for your current module. Mark any unclear points. |
# | **2** | Join the scheduled **online Q&A** and **small‑group discussion**; ask at least one question. |
# | **3** | Complete the **interactive quiz** for the module and note your score; use the feedback to focus revision. |
# | **4** | Meet with your lecturer (or TA) for a **15‑minute check‑in** to discuss progress, clarify any instructions, and adjust your study schedule if needed. |
#
# By following these steps, you’ll make the most of the flexibility you enjoy while strengthening interaction, motivation, and technical reliability in your blended‑learning experience. Good luck!

# %% [markdown]
# ## Student ID: `ext_4e1a6e16f0`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["engagement", "learning_effectiveness", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_4e1a6e16f0
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# You tend to work best when the teacher’s presence is felt, and you notice that a heavy load of documents can make it hard to finish reading them.
#
# ---
#
# ### 2. Main Strengths
# - **Learning Convenience & Effectiveness:** You focus and understand material better when the teacher is actively supervising.
# - **Student Engagement:** Your positive attitude shows you can be engaged when the right support is in place.
#
# ---
#
# ### 3. Main Challenges
# - **Assessment & Workload:** Too many files and limited time make it difficult to read everything and keep up with assignments.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Engagement** | Add short quizzes, quick games, or brief discussion prompts after each topic. | Interactive tasks keep you actively involved and reinforce what you’ve learned. |
# | **Learning Effectiveness** | Pair online review materials (e.g., short videos or slides) with in‑person explanations, practice exercises, and immediate feedback. | Combining digital and face‑to‑face elements builds on the supervision you find helpful. |
# | **Workload Support** | Request a clear schedule that groups related documents together, limits the number of files per week, and aligns online tasks with upcoming class sessions. | A balanced, well‑structured workload reduces overload and gives you more time to read and understand each resource. |
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Review the upcoming week’s syllabus; note the number of documents and set a personal reading goal (e.g., 2‑3 files). |
# | **Wednesday** | Participate in a short in‑class quiz or poll on the material you’ve read. |
# | **Friday** | Meet briefly with the instructor (or TA) to confirm deadlines and ask for any “bundled” reading packs. |
# | **Next Monday** | Complete a quick practice task (e.g., a problem set) and get feedback during the next face‑to‑face session. |
# | **Mid‑week** | Use a 5‑minute game or discussion prompt posted online to recap the week’s key points. |
# | **End of Week** | Reflect on how the reduced file load and interactive activities affected your understanding; adjust the reading goal for the following week if needed. |
#
# ---
#
# **Remember:** Small, interactive steps and a clearer, lighter workload can turn passive study habits into more active, effective learning. Feel free to reach out to your instructor for any clarification or additional support. Good luck!

# %% [markdown]
# ## Student ID: `ext_43d658ebf6`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_43d658ebf6
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# You are an active participant in class and make good use of recorded video material after lectures.
#
# ---
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You already take advantage of video recordings of lectures, which helps you review content after class.
#
# ---
#
# ### 3. Main Challenges
# - **Flexibility:** You find it difficult to switch smoothly between virtual and physical class formats.
#
# *(Because the open‑ended responses are brief, the recommendations below rely mainly on the characteristics of your “Highly Engaged” segment.)*
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Tag | Recommendation |
# |-----|----------------|
# | **content_access** | **Strengthen access to learning materials** – Upload slides, videos, reference links, exercises, and any other course resources **early** (e.g., before the next class session). This gives you a complete set of materials to review whether you are attending online or on‑campus, reducing the stress of switching formats. |
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Check the course’s learning‑management system (LMS) for any missing slides or recordings. If they are not there, request the instructor to upload them promptly. |
# | **2** | Create a personal folder (cloud or local) where you store all uploaded materials as soon as they become available. |
# | **3** | Schedule a 15‑minute review of the week’s slides and video after each lecture, regardless of the delivery mode. |
# | **4** | Reflect on whether having early access helped you feel more flexible between virtual and physical sessions; note any improvements. |
#
# By ensuring that all learning resources are available early, you’ll maintain your high level of engagement while easing the transition between online and face‑to‑face classes. Keep up the active participation!

# %% [markdown]
# ## Student ID: `ext_a32af110c6`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["content_access", "learning_environment", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: ext_a32af110c6*
#
# ---
#
# ### 1. Student Learning Profile
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
# - You tend to engage with course material when it is readily available and you can review it at any time.
# - Your main reported challenges are limited internet reliability and a need for a quieter, more suitable study space.
#
# ### 2. Main Strengths
# - **Access to Learning Materials:** You value being able to revisit slides, videos, and other resources whenever you need.
# - **Flexibility & Time Management:** You appreciate the ability to study at your own pace.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues:** Unstable connectivity can hinder your participation.
# - **Learning Resources & Environment:** A quiet, comfortable place to study is sometimes lacking.
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Strengthen access to learning materials** | All slides, videos, references, and exercises will be uploaded early in the week. | Check the course portal each Monday for new content; download files for offline review. |
# | **Improve learning resources and environment** | Materials will be clearly organized, and guidance on creating a good study space will be provided. | Follow the “Study‑Space Tips” sheet (quiet corner, good lighting, minimal distractions). |
# | **Support self‑paced learning** | Recorded lessons and weekly learning paths let you progress when it suits you. | Follow the weekly roadmap, pause/rewind videos as needed, and complete exercises at your own speed. |
# | **Improve technical access and reliability** | Options for offline materials and clear platform instructions are available, plus technical support. | Download lecture videos before class, use the campus Wi‑Fi hotspot if home internet is unstable, and contact the help desk for any platform issues. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Monday** | Log into the course portal, download all new slides and videos for the week. |
# | **Tuesday** | Set up a dedicated study spot (quiet, good lighting). Use the “Study‑Space Tips” provided. |
# | **Wednesday** | Watch the recorded lecture at a time that fits your schedule; pause and take notes. |
# | **Thursday** | Complete the weekly exercises using the downloaded resources; if internet drops, work offline. |
# | **Friday** | Review any unclear concepts by revisiting the videos or slides; note questions for the tutor. |
# | **Weekend** | Test the campus Wi‑Fi hotspot or another reliable connection for next week’s materials. |
# | **Ongoing** | If you encounter technical problems, contact the technical support desk (email/phone provided in the portal). |
#
# ---
#
# **Remember:** These recommendations are built on the strengths and challenges identified for learners in your segment. By securing reliable access to materials, creating a comfortable study environment, and using the self‑paced resources, you can make the most of the blended learning format. If you need further help, reach out to your instructor or the support services listed in the course portal. Good luck!

# %% [markdown]
# ## Student ID: `ext_47fba872c5`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_47fba872c5
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# You value flexibility in your study routine and prefer learning environments that let you manage your own time.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You appreciate being able to study when it best fits your schedule.
#
# ---
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Limited experience with online tools and occasional connectivity problems can make digital learning harder.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** | Access recorded lessons, weekly learning paths, and downloadable materials so you can study whenever you’re ready. | • Watch videos at a time that suits you.<br>• Follow the weekly roadmap but pause or revisit any part as needed. |
# | **Improve technical access and reliability** | Ensure you have stable internet or offline options, clear instructions for the platform, and quick technical help. | • Download lecture videos and readings when you have good connectivity.<br>• Keep a list of support contacts (e.g., campus IT help desk).<br>• Use any provided offline resources (PDFs, audio files). |
#
# These suggestions are drawn directly from the evidence for your segment and the specific tags identified for you.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate the course’s recorded lectures and download the first week’s videos while you have good internet. |
# | **2** | Follow the weekly learning path; pause any part that feels fast and review it later. |
# | **3** | Test the platform’s offline mode (if available) and note any technical issues. |
# | **4** | Contact technical support with any connectivity problems; keep a log of solutions for future reference. |
# | **Ongoing** | Continue using self‑paced resources and offline copies whenever internet access is unreliable. |
#
# By focusing on self‑paced study and securing reliable technical access, you can make the most of your flexible learning style while minimizing disruptions. Good luck!

# %% [markdown]
# ## Student ID: `ext_fe85df7d35`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_fe85df7d35
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# You are an active participant who values flexibility and can adapt your schedule easily. Your main difficulty occurs when the internet connection is unstable or technical problems arise.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You can adjust your study routine and make the most of varied learning formats.
#
# ### 3. Main Challenges
# - **Internet & Technical Issues** – Poor connectivity or platform glitches disrupt your learning flow.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Recommendation | What it means for you | How to use it |
# |----------------|----------------------|---------------|
# | **Support self‑paced learning** (tag: *self_paced*) | Access recorded lectures, weekly learning paths, and downloadable resources so you can study whenever your connection is reliable. | • Watch videos or review notes at a time that suits you.<br>• Follow the weekly path to stay on track even if you miss a live session. |
# | **Improve technical access and reliability** (tag: *tech_issue*) | Ensure you have stable internet options, offline materials, clear platform guides, and quick technical support. | • Download lecture videos or PDFs when you have good connectivity.<br>• Use campus Wi‑Fi or a reliable hotspot for live sessions.<br>• Keep the platform help guide handy and contact tech support as soon as an issue arises. |
#
# These suggestions are drawn directly from the evidence about your strengths, challenges, and the segment’s recommended tags.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action |
# |------|--------|
# | **1** | Locate and bookmark the repository of recorded lessons and weekly learning paths. |
# | **2** | Test your internet connection; identify a reliable backup (e.g., campus Wi‑Fi, library, or mobile hotspot). |
# | **3** | Download the next week’s lecture videos and reading materials while the connection is good. |
# | **4** | Review the platform’s technical support guide; note the contact method for quick help. |
# | **Ongoing** | Follow the weekly learning path at your own pace, and switch to offline materials whenever connectivity drops. |
#
# By using self‑paced resources and securing reliable technical access, you can keep your high level of engagement while minimizing disruptions. Good luck, and keep leveraging your flexibility!

# %% [markdown]
# ## Student ID: `ext_6a2a2be201`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "interaction", "learning_environment", "motivation", "self_paced", "tech_issue", "workload_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
# *Student ID: ext_6a2a2be201*
# *Segment: Cluster 2 – Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive when you can control the pace of study, engage actively in discussions and labs, and use digital tools that mirror workplace collaboration. The flexibility of blended learning lets you pause or re‑watch content, while in‑person sessions give you the social interaction you value.
#
# At the same time, you notice that online tasks sometimes feel like extra workload, and occasional technical or environment issues (e.g., unreliable internet, limited quiet space) can hurt motivation and lead to procrastination.
#
# ---
#
# ### 2. Main Strengths
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Access to Learning Materials** | Flexibility to learn at your own speed. |
# | **Digital Skills Development** | Building proficiency with collaboration tools. |
# | **Flexibility & Time Management** | Ability to pause/re‑watch digital content. |
# | **Student Engagement** | Preference for interactive debates, labs, and hands‑on work. |
#
# ---
#
# ### 3. Main Challenges
# | Theme | What you highlighted |
# |-------|----------------------|
# | **Assessment & Workload** | Online tasks feel like added work. |
# | **Interaction & Communication** | Less physical interaction can lower motivation. |
# | **Internet & Technical Issues** | Unequal access to high‑speed internet or quiet spaces. |
# | **Learning Resources & Environment** | Need for better study environments. |
# | **Motivation & Self‑Discipline** | Procrastination when isolation increases. |
#
# ---
#
# ### 4. Personalized Recommendations
# | Recommendation | How it helps you |
# |----------------|------------------|
# | **Strengthen access to learning materials** (content_access) | Upload slides, videos, references, and exercises **early** so you can review them whenever you need. |
# | **Develop digital learning skills** (digital_skill) | Offer short guides on LMS tools, online research, and collaboration platforms to boost your workplace‑ready digital competence. |
# | **Increase learner engagement** (engagement) | Include quizzes, games, practical tasks, and discussion prompts that turn passive listening into active participation. |
# | **Increase interaction and communication** (interaction) | Add regular Q&A sessions, small‑group discussions, peer‑collaboration activities, and quicker lecturer feedback to keep you connected. |
# | **Improve learning resources and environment** (learning_environment) | Organise all materials clearly, keep resources up‑to‑date, and provide tips for creating a comfortable study space (e.g., noise‑cancelling headphones, designated work area). |
# | **Support motivation and self‑discipline** (motivation) | Use weekly check‑ins, gentle reminders, progress dashboards, and a suggested study schedule to sustain momentum. |
# | **Support self‑paced learning** (self_paced) | Provide recorded lectures and a weekly learning path so you can revisit content at your own speed. |
# | **Improve technical access and reliability** (tech_issue) | Offer offline copies of key materials, clear platform instructions, and a help‑desk for internet or device problems. |
# | **Manage workload and assessment pressure** (workload_support) | Align online tasks with in‑person sessions, clarify deadlines, and balance the number of assignments to avoid “workload creep.” |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Access the course’s **early‑uploaded** slide deck and video recordings; set up a personal study folder. |
# | **2** | Attend the first **Q&A + peer‑discussion** session; note any technical issues and request offline copies if needed. |
# | **3** | Complete a short **digital‑tools tutorial** (LMS navigation, citation manager). Use the progress tracker to log completed activities. |
# | **4** | Review the **weekly learning path** and schedule 2‑hour blocks for self‑paced study; meet with the tutor for a brief **workload check‑in**. |
#
# Follow these steps, and you’ll keep leveraging your high engagement while minimizing the workload and technical challenges that can arise in a blended environment. Good luck!

# %% [markdown]
# ## Student ID: `ext_b1dc82f3f0`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "motivation", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** ext_b1dc82f3f0
# **Student Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You describe yourself as appreciating the **flexibility** that blended learning offers. At the same time, you note two main challenges: a lack of motivation and limited interaction/communication with lecturers and peers. Your comments are positive in tone, indicating you are aware of these issues and open to improvement.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Time Management** – You can adapt your study schedule to fit personal commitments.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – Need more opportunities to engage with lecturers and classmates.
# - **Motivation & Self‑Discipline** – Finding it hard to stay motivated and keep a consistent study routine.
#
# ---
#
# ### 4. Personalized Recommendations
# | Focus | What to Try | Why it Helps |
# |-------|-------------|--------------|
# | **Interaction** | • Join scheduled Q&A sessions and group discussions.<br>• Participate in peer‑collaboration activities (e.g., shared documents, study groups).<br>• Request quicker feedback from lecturers. | Increases contact with instructors and classmates, reducing the sense of isolation. |
# | **Motivation** | • Use weekly check‑ins (self‑review or with a tutor).<br>• Set up automated reminders for deadlines.<br>• Track progress on a simple visual chart.<br>• Follow a structured weekly study schedule. | Provides external cues and visible evidence of progress, boosting self‑discipline. |
# | **Self‑Paced Learning** | • Access recorded lectures and supplemental videos.<br>• Follow a weekly learning path that outlines what to study each day.<br>• Review materials as needed before assessments. | Lets you take advantage of your flexibility while staying on track with the course timeline. |
#
# These suggestions are drawn directly from the rule‑based recommendations for your segment and the challenges you identified.
#
# ---
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Day | Action |
# |-----|--------|
# | **Day 1** | Locate the course’s recorded lectures and download the weekly learning path. |
# | **Day 2** | Set up calendar reminders for upcoming deadlines and a 30‑minute daily study block. |
# | **Day 3** | Join the first scheduled Q&A session; prepare one question in advance. |
# | **Day 4** | Create a simple progress tracker (e.g., checklist or spreadsheet). |
# | **Day 5** | Form or join a small peer study group (2‑4 members) for a 45‑minute discussion. |
# | **Day 6‑7** | Review the week’s recorded lessons at your own pace; update the progress tracker. |
# | **Week 2** | Repeat the daily study block, attend the second Q&A, and hold a brief group check‑in to share what worked and what didn’t. |
#
# Stick to this routine for two weeks, then reassess how your motivation and interaction levels have changed. Adjust the schedule or seek additional support from your lecturer as needed.
#
# Good luck—you have the flexibility; now let’s add interaction and motivation to make your blended learning experience more effective!

# %% [markdown]
# ## Student ID: `ext_57bfcf7af1`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["engagement", "interaction", "learning_effectiveness", "learning_environment", "learning_support", "self_paced", "tech_issue"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# **Student ID:** ext_57bfcf7af1
# **Student Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# ---
#
# ### 1. Student Learning Profile
# You thrive in a blended environment because it gives you the **flexibility to study online at your own pace** while still benefiting from **in‑person class time** for discussion and practice. You value active engagement and see blended learning as a way to understand material better.
#
# You also note three main challenges:
# * **Time‑management and unclear instructions** – you need clearer guidance and better scheduling.
# * **Internet/technical problems** – unreliable connectivity hampers your study.
# * **Learning resources and environment** – you would like more organized materials and a comfortable study setting.
#
# ---
#
# ### 2. Main Strengths
# - **Flexibility & Convenience** – you make good use of self‑paced online content.
# - **High Engagement** – you enjoy interactive, discussion‑based class sessions.
# - **Positive Attitude** – you view blended learning as a way to improve understanding.
#
# ---
#
# ### 3. Main Challenges
# - **Interaction & Communication** – need for clearer instructions and quicker feedback.
# - **Technical Access** – occasional internet issues disrupt learning.
# - **Learning Environment** – desire for well‑organized resources and comfortable study spaces.
#
# ---
#
# ### 4. Personalized Recommendations
#
# | Area | What to Do (based on rule‑based advice) |
# |------|------------------------------------------|
# | **Engagement** | Incorporate short quizzes, games, practical tasks, and discussion prompts in both online and face‑to‑face sessions. |
# | **Interaction** | Schedule regular Q&A slots, small‑group discussions, and peer‑collaboration activities; ask lecturers for faster feedback on assignments. |
# | **Learning Effectiveness** | Pair online review videos or readings with in‑class explanations, guided practice, and immediate feedback. |
# | **Learning Environment** | Use clearly labeled folders or a learning‑management system (LMS) for all materials; request updated resources and a comfortable, quiet study area on campus. |
# | **Learning Support** | Ask for step‑by‑step guides, example problems, and recorded explanations when instructions feel unclear. |
# | **Self‑Paced Learning** | Follow a weekly learning path that lists which recorded lessons to watch and which practice tasks to complete; revisit recordings as needed. |
# | **Technical Issues** | Keep offline copies of essential readings and videos; locate campus spots with reliable Wi‑Fi; use the university’s tech‑support help desk for quick assistance. |
#
# ---
#
# ### 5. Short Action Plan (Next 4 Weeks)
#
# | Week | Action |
# |------|--------|
# | **1** | Review the course LMS and organize all materials into clearly labeled folders (e.g., “Lectures,” “Practice,” “Examples”). |
# | **2** | Set a personal weekly learning path: pick 2‑3 recorded lessons to watch, then attend the corresponding in‑class discussion. |
# | **3** | Join a study group or peer‑collaboration session to practice Q&A and receive faster feedback. |
# | **4** | Test campus Wi‑Fi locations; download any upcoming lecture videos for offline use. Contact tech support if connectivity issues persist. |
#
# By following these steps, you can keep the high level of engagement you already enjoy while reducing the frustrations caused by unclear instructions and technical hiccups. Good luck, and keep leveraging the flexibility that blended learning offers!

# %% [markdown]
# ## Student ID: `ext_56bf21263d`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_56bf21263d
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
# - You are identified as a highly engaged student who actively participates in class and shows strong motivation to learn. Because no specific strengths or challenges were provided in your open‑ended responses, the recommendations below are drawn primarily from the characteristics of your segment.
#
# ### 2. Main Strengths
# - High engagement and motivation (inferred from the “Highly Engaged” segment).
#
# ### 3. Main Challenges
# - No specific challenges were reported. The suggestions aim to further enhance your already active learning style.
#
# ### 4. Personalized Recommendations
# | Tag | Recommendation Title | What to Do |
# |-----|----------------------|------------|
# | **content_access** | Strengthen access to learning materials | Upload slides, videos, reference links, exercises, and other course resources **early** in the semester so you can review them whenever needed. |
# | **digital_skill** | Develop digital learning skills | Get brief guidance on using the LMS, online research tools, and educational technologies (e.g., video editors, citation managers). |
# | **engagement** | Increase learner engagement | Participate in quizzes, games, practical tasks, discussion forums, and other interactive activities that keep learning lively. |
# | **self_paced** | Support self‑paced learning | Use recorded lessons and weekly learning paths; revisit any material at your own speed to deepen understanding. |
#
# ### 5. Short Action Plan (Next 2 Weeks)
#
# | Week | Action | Expected Benefit |
# |------|--------|-------------------|
# | 1 | Check the course LMS for any **uploaded slides, videos, and exercises**; if missing, request the instructor to post them early. | Immediate access to all core materials. |
# | 1‑2 | Attend a short **digital‑tools tutorial** (often offered by the university’s IT help desk or online). | Faster navigation of LMS and research resources. |
# | 2 | Complete the first **interactive quiz** or game related to the current topic. | Reinforces knowledge and keeps motivation high. |
# | 2 | Review the **recorded lecture** for the week and follow the suggested **weekly learning path** at your own pace. | Consolidates learning and allows you to fill any gaps. |
#
# ---
#
# **Keep leveraging your natural enthusiasm—these steps will give you richer resources, stronger digital skills, and flexible ways to stay engaged throughout the course.**

# %% [markdown]
# ## Student ID: `ext_19c8baf257`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["interaction", "learning_environment", "learning_support", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** ext_19c8baf257
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# **Main Strengths**
# - You describe yourself as **flexible** and **self‑disciplined**, which helps you manage your time and adapt to different study situations.
#
# **Main Challenges**
# - You feel that communication between students and teachers could be stronger.
# - You would like clearer instructions and better‑organized learning resources.
#
# **Personalized Recommendations**
#
# | Area | What to Try | Why it Helps |
# |------|-------------|--------------|
# | **Interaction** | • Join short Q&A sessions or online office‑hours.<br>• Participate in small group discussions or peer‑collaboration activities.<br>• Request quicker feedback on assignments. | Increases communication with lecturers and classmates, addressing the interaction challenge you noted. |
# | **Learning Environment** | • Use the university’s study‑space guidelines to keep your materials organized.<br>• Check that the digital resources (slides, readings) are up‑to‑date; ask the instructor to clarify any outdated items.<br>• Arrange a comfortable, distraction‑free study spot. | Improves the clarity and usability of the resources you rely on. |
# | **Learning Support** | • Look for recorded explanations or step‑by‑step guides that the course provides.<br>• When instructions seem vague, ask for concrete examples or a short walkthrough. | Gives you clearer directions and concrete models, reducing confusion. |
# | **Self‑Paced Learning** | • Download recorded lectures and review them at your own speed.<br>• Follow the weekly learning path outlines and use them to plan your study sessions. | Leverages your flexibility and self‑discipline, letting you learn when it works best for you. |
#
# **Short Action Plan (2‑Week Starter)**
#
# 1. **Week 1** – Identify one upcoming Q&A or discussion slot and attend it. Bring one question about the current topic.
# 2. **Week 1** – Organize your digital folder: rename files, create a clear folder structure, and note any missing resources.
# 3. **Week 2** – Watch a recorded lecture at least once, pause to take notes, and compare your notes with the provided step‑by‑step guide (if available).
# 4. **Week 2** – Request brief feedback on one recent assignment (e.g., via the course’s feedback tool or by emailing the lecturer).
#
# By focusing on these four areas—interaction, environment, support, and self‑paced study—you can turn your flexibility into stronger academic performance while addressing the communication and clarity concerns you raised. Good luck!

# %% [markdown]
# ## Student ID: `ext_f14dd626af`
#
# **Segment:** Cluster 1: Moderately Engaged (Passive) Learners
#
# **Recommendation Tags:** `["learning_support"]`
#
# ---
#
# **Personalized Blended‑Learning Recommendation Report**
#
# ---
#
# ### 1. Student Learning Profile
# - **Student ID:** ext_f14dd626af
# - **Segment:** Cluster 1 – *Moderately Engaged (Passive) Learners*
#
# You tend to feel comfortable studying on your own and prefer not to be in large group settings.
#
# ---
#
# ### 2. Main Strengths
# - You are at ease with independent study and do not feel the need to be constantly surrounded by other people.
#
# ---
#
# ### 3. Main Challenges
# - You mentioned feeling a loss of confidence.
# - The identified theme is **Learning Difficulty & Clarity** – you may find it hard to understand what is expected or how to complete tasks.
#
# ---
#
# ### 4. Personalized Recommendations
# **Learning Support** – To boost confidence and clarify the material:
# - **Clear Instructions:** Look for course pages that break tasks into short, numbered steps.
# - **Examples & Samples:** Review any provided examples before starting an assignment.
# - **Recorded Explanations:** Use video or audio recordings that walk through key concepts at your own pace.
# - **Step‑by‑Step Guides:** Keep a personal checklist of the steps you need to follow for each activity.
#
# These supports are drawn directly from the rule‑based recommendation for your segment.
#
# ---
#
# ### 5. Short Action Plan
#
# | Week | Action | How It Helps |
# |------|--------|--------------|
# | 1 | Locate any **recorded explanations** for your current module and watch them before attempting assignments. | Gives you a clear model of what is expected. |
# | 2 | Create a **step‑by‑step checklist** for one upcoming assignment, using the instructor’s rubric or guidelines. | Makes the task concrete and reduces uncertainty. |
# | 3 | Find **example work** (sample essays, solved problems) and compare it with your own draft. | Shows you concrete standards and builds confidence. |
# | 4 | If instructions are still unclear, post a **specific question** in the course forum or email the tutor. | Direct clarification prevents lingering confusion. |
#
# Repeat this cycle for each new topic or assignment. Over time, the clearer structure and targeted support should help restore confidence and make your independent study even more effective.

# %% [markdown]
# ## Student ID: `ext_903cd93bf9`
#
# **Segment:** Cluster 2: Highly Engaged (Active) Learners
#
# **Recommendation Tags:** `["content_access", "digital_skill", "engagement", "self_paced"]`
#
# ---
#
# **Student Learning Profile**
# - **Student ID:** ext_903cd93bf9
# - **Segment:** Cluster 2 – *Highly Engaged (Active) Learners*
#
# **Main Strengths**
# - You noted “time” as a strength, indicating you are able to allocate sufficient time to your studies.
#
# **Main Challenges**
# - You mentioned “choose your opinion” as a challenge, suggesting difficulty in forming or expressing your own viewpoints.
#
# **Personalized Recommendations**
# Because the open‑ended responses are brief, the recommendations below are drawn primarily from the characteristics of the *Highly Engaged (Active) Learners* segment and the associated recommendation tags:
#
# 1. **Strengthen Access to Learning Materials**
#    - Upload or request early access to slides, videos, reference articles, exercises, and any other course resources. Having everything ready lets you use your available time efficiently.
#
# 2. **Develop Digital Learning Skills**
#    - Seek short guides or tutorials on using the LMS, online research tools, and other educational technologies. Better digital fluency will help you locate and organise information quickly, supporting both your engagement and self‑paced study.
#
# 3. **Increase Learner Engagement**
#    - Participate in quizzes, games, practical tasks, discussion boards, and other interactive activities. These formats encourage you to voice your own opinions and practice critical thinking.
#
# 4. **Support Self‑Paced Learning**
#    - Make use of recorded lectures and weekly learning paths. Review the material at your own speed, which can give you extra space to reflect and form your own viewpoints before contributing to discussions.
#
# **Short Action Plan (Next 2 Weeks)**
#
# | Day | Action | Why it Helps |
# |-----|--------|--------------|
# | 1‑2 | Locate the course’s shared folder or request the instructor to upload all slides, videos, and readings. | Guarantees you have the resources you need early. |
# | 3‑4 | Complete a 30‑minute tutorial on the LMS’s search and bookmarking features. | Improves digital skills and saves time later. |
# | 5‑7 | Join a discussion forum or study group and post one comment expressing your own opinion on a topic. | Practices opinion‑forming in a low‑stakes environment. |
# | 8‑10| Take a short quiz or interactive activity related to the current module. | Reinforces learning and keeps engagement high. |
# | 11‑14| Watch a recorded lecture, pause, and write a brief summary in your own words. | Supports self‑paced review and deepens personal understanding. |
#
# Follow these steps, and you’ll leverage your strong time management while building confidence in expressing your own ideas. Good luck!
