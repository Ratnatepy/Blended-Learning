# %%
import pandas as pd
from blended_learning.config.settings import settings
from blended_learning.utils.decorator import execution_time

# %%
df = pd.read_csv(settings.path['output_cluster_path'])

# %%
columns = [
    'student_id',
    'open_strengths',
    'open_challenges_suggestions',
    'student_segment',
    'student_segment_label',
]
df_selected = df[columns].copy()
print(f"NLP dataframe shape: {df_selected.shape}")
display(df_selected.head(n=5))
# Out:
# NLP dataframe shape: (588, 5)
#   student_id           open_strengths     open_challenges_suggestions  \
# 0  e20210528                      NaN                             NaN
# 1  e20210686                  Nothing                         Nothing
# 2  e20241146     Very good, excellent  No big challenge, i’m the best
# 3  e20240609            Will try hard         Lack of self-discipline
# 4  e20240542  getting more experience    Discipline on daily studying
#
#    student_segment                  student_segment_label
# 0                1       Highly Engaged (Active) Learners
# 1                2  Moderately Engaged (Passive) Learners
# 2                1       Highly Engaged (Active) Learners
# 3                1       Highly Engaged (Active) Learners
# 4                2  Moderately Engaged (Passive) Learners

# %%
"""
Keep only rows with complete text responses in both open-ended
survey questions for downstream NLP analysis.
"""

print(f"Before : Length {len(df_selected)}")

cols = ['open_strengths', 'open_challenges_suggestions']

mask = (
    df_selected[cols].notna().all(axis=1) &
    (df_selected[cols].astype(str).apply(lambda x: x.str.strip() != "")).all(axis=1)
)

df_nlp = df_selected[mask]

print(f"After : Length {len(df_nlp)}")
# Out:
# Before : Length 588
# After : Length 567

# %%
df_selected[~mask]
# Out:
#          student_id                   open_strengths  \
# 0         e20210528                              NaN
# 9         e20240956                              NaN
# 24        e20240618                              NaN
# 25        e20240594             schedule flexibility
# 29        e20220370                              NaN
# 115       e20241074                              NaN
# 216       e20240108                              NaN
# 371       p20250003                              NaN
# 372       p20230003                              NaN
# 450       e20240173                              NaN
# 459       e20241408                              NaN
# 464       e20240711                              NaN
# 510       e20240982                              NaN
# 529       e20241107                    Easy to study
# 538       e20241070  Know more about technical tools
# 550       e20241270                              NaN
# 557  ext_8e07b7b663                              NaN
# 564  ext_7a6b84432e                              NaN
# 571  ext_2df03864aa                              NaN
# 583  ext_50022dd93a                              NaN
# 587  ext_40b9f9937f                              NaN
#
#          open_challenges_suggestions  student_segment  \
# 0                                NaN                1
# 9                                NaN                2
# 24                               NaN                2
# 25                               NaN                1
# 29                               NaN                2
# 115                              NaN                1
# 216                              NaN                2
# 371                              NaN                1
# 372                              NaN                1
# 450                              NaN                1
# 459                              NaN                1
# 464                              NaN                2
# 510                              NaN                1
# 529                              NaN                1
# 538                              NaN                2
# 550                              NaN                2
# 557  Lack of real life communication                2
# 564                              NaN                1
# 571                              NaN                2
# 583                              NaN                1
# 587                              NaN                1
#
#                      student_segment_label
# 0         Highly Engaged (Active) Learners
# 9    Moderately Engaged (Passive) Learners
# 24   Moderately Engaged (Passive) Learners
# 25        Highly Engaged (Active) Learners
# 29   Moderately Engaged (Passive) Learners
# 115       Highly Engaged (Active) Learners
# 216  Moderately Engaged (Passive) Learners
# 371       Highly Engaged (Active) Learners
# 372       Highly Engaged (Active) Learners
# 450       Highly Engaged (Active) Learners
# 459       Highly Engaged (Active) Learners
# 464  Moderately Engaged (Passive) Learners
# 510       Highly Engaged (Active) Learners
# 529       Highly Engaged (Active) Learners
# 538  Moderately Engaged (Passive) Learners
# 550  Moderately Engaged (Passive) Learners
# 557  Moderately Engaged (Passive) Learners
# 564       Highly Engaged (Active) Learners
# 571  Moderately Engaged (Passive) Learners
# 583       Highly Engaged (Active) Learners
# 587       Highly Engaged (Active) Learners

# %%
import re
import pandas as pd

KHMER_REGEX = re.compile(r'[\u1780-\u17FF]')
EN_REGEX = re.compile(r'[A-Za-z]')

def detect_lang_mixed(text):
    if pd.isna(text):
        return "empty"
    
    text = str(text).strip()
    if text == "":
        return "empty"
    
    has_kh = bool(KHMER_REGEX.search(text))
    has_en = bool(EN_REGEX.search(text))
    
    if has_kh and has_en:
        return "mixed"
    elif has_kh:
        return "kh"
    elif has_en:
        return "en"
    else:
        return "other"


# Create language label columns in df_nlp, not df
for col in cols:
    df_nlp[f"{col}_lang"] = df_nlp[col].apply(detect_lang_mixed)


# Print summary counts + percentages per column
all_langs = []

for col in cols:
    cleaned_mask = df_nlp[col].notna() & (df_nlp[col].astype(str).str.strip() != "")
    langs = df_nlp.loc[cleaned_mask, f"{col}_lang"]
    all_langs.append(langs)
    
    counts = langs.value_counts().reindex(["kh", "mixed", "en", "other"], fill_value=0)
    perc = (counts / counts.sum() * 100).round(1)
    
    summary = pd.DataFrame({
        "count": counts,
        "percent (%)": perc
    })
    
    translation_needed = counts["kh"] + counts["mixed"]
    translation_pct = round((translation_needed / counts.sum()) * 100, 1) if counts.sum() > 0 else 0
    
    print(f"\n{'='*60}")
    print(f"SUMMARY FOR: {col}")
    print(f"{'='*60}")
    print(summary)
    print(f"\nTotal needing translation (kh + mixed): {translation_needed} ({translation_pct}%)")


# Aggregate summary across both text columns
all_langs_combined = pd.concat(all_langs, axis=0)

agg_counts = all_langs_combined.value_counts().reindex(["kh", "mixed", "en", "other"], fill_value=0)
agg_perc = (agg_counts / agg_counts.sum() * 100).round(1)

agg_summary = pd.DataFrame({
    "count": agg_counts,
    "percent (%)": agg_perc
})

agg_translation_needed = agg_counts["kh"] + agg_counts["mixed"]
agg_translation_pct = round((agg_translation_needed / agg_counts.sum()) * 100, 1)

print(f"\n{'='*60}")
print("OVERALL LANGUAGE SUMMARY")
print(f"{'='*60}")
print(agg_summary)
print(f"\nOverall needing translation: {agg_translation_needed} ({agg_translation_pct}%)")
# Out:
# ============================================================
# SUMMARY FOR: open_strengths
# ============================================================
#                      count  percent (%)
# open_strengths_lang
# kh                      24          4.2
# mixed                    2          0.4
# en                     535         94.4
# other                    6          1.1
#
# Total needing translation (kh + mixed): 26 (4.6%)
#
# ============================================================
# SUMMARY FOR: open_challenges_suggestions
# ============================================================
#                                   count  percent (%)
# open_challenges_suggestions_lang
# kh                                   23          4.1
# mixed                                 5          0.9
# en                                  533         94.0
# other                                 6          1.1
#
# Total needing translation (kh + mixed): 28 (4.9%)
#
# ============================================================
# OVERALL LANGUAGE SUMMARY
# ============================================================
#        count  percent (%)
# kh        47          4.1
# mixed      7          0.6
# en      1068         94.2
# other     12          1.1
#
# Overall needing translation: 54 (4.8%)

# %% [markdown]
# Translate Khmer and mixed responses

# %%
from blended_learning.nlp.translate_kh_service import TranslateKHService

translator = TranslateKHService()
translation_cache = {}


def translate_if_needed(text, lang):
    if pd.isna(text):
        return ""

    text = str(text).strip()

    if text == "":
        return ""

    if lang not in ["kh", "mixed"]:
        return text

    if text in translation_cache:
        return translation_cache[text]

    translated = translator.translate_one(
        text=text,
        src_lang="kh",
        tgt_lang="eng"
    )

    translation_cache[text] = translated
    return translated

# %%
@execution_time
def translate_column(df_nlp, col):
    translated_col = f"{col}_en"

    df_nlp[translated_col] = df_nlp.apply(
        lambda row: translate_if_needed(
            row[col],
            row[f"{col}_lang"]
        ),
        axis=1
    )

    print(f"Finished translating: {col}")
    return df_nlp


for col in cols:
    df_nlp = translate_column(df_nlp, col)
# Out:
# Finished translating: open_strengths
# translate_column executed in 0.26 min (15.58 sec)
# Finished translating: open_challenges_suggestions
# translate_column executed in 0.30 min (18.00 sec)

# %%
display(
    df_nlp[
        [
            "open_strengths",
            "open_strengths_lang",
            "open_strengths_en",
            "open_challenges_suggestions",
            "open_challenges_suggestions_lang",
            "open_challenges_suggestions_en",
        ]
    ].head(10)
)
# Out:
#                                        open_strengths open_strengths_lang  \
# 1                                             Nothing                  en
# 2                                Very good, excellent                  en
# 3                                       Will try hard                  en
# 4                             getting more experience                  en
# 5   Student could retrieve the lesson once they wa...                  en
# 6         Innovate yourself with the technology world                  en
# 7   Blended learning has many positive aspects. It...                  en
# 8   Give a chance for students who prefer both onl...                  en
# 10                        Give me time to do my stuff                  en
# 11                                              Agree                  en
#
#                                     open_strengths_en  \
# 1                                             Nothing
# 2                                Very good, excellent
# 3                                       Will try hard
# 4                             getting more experience
# 5   Student could retrieve the lesson once they wa...
# 6         Innovate yourself with the technology world
# 7   Blended learning has many positive aspects. It...
# 8   Give a chance for students who prefer both onl...
# 10                        Give me time to do my stuff
# 11                                              Agree
#
#                           open_challenges_suggestions  \
# 1                                             Nothing
# 2                      No big challenge, i’m the best
# 3                             Lack of self-discipline
# 4                        Discipline on daily studying
# 5                                   Add Ai assistance
# 6                Lack of resources and misinformation
# 7   The biggest challenges of blended learning are...
# 8   Internet issues, technical problems, lack of i...
# 10                   Probably the internet connection
# 11                                              Agree
#
#    open_challenges_suggestions_lang  \
# 1                                en
# 2                                en
# 3                                en
# 4                                en
# 5                                en
# 6                                en
# 7                                en
# 8                                en
# 10                               en
# 11                               en
#
#                        open_challenges_suggestions_en
# 1                                             Nothing
# 2                      No big challenge, i’m the best
# 3                             Lack of self-discipline
# 4                        Discipline on daily studying
# 5                                   Add Ai assistance
# 6                Lack of resources and misinformation
# 7   The biggest challenges of blended learning are...
# 8   Internet issues, technical problems, lack of i...
# 10                   Probably the internet connection
# 11                                              Agree

# %%
output_path = settings.root / "data" / "processed" / "nlp_translated_responses.csv"

df_nlp.to_csv(output_path, index=False, encoding="utf-8-sig")

print(f"Saved translated NLP dataset to: {output_path}")

print(f"NLP-ready dataset loaded: {df_nlp.shape}")
display(df_nlp.head())
# Out:
# Saved translated NLP dataset to: C:\Users\Tepy\Documents\tepy\Final Internship Docs\blended_learning\data\processed\nlp_translated_responses.csv
# NLP-ready dataset loaded: (567, 9)
#   student_id                                     open_strengths  \
# 1  e20210686                                            Nothing
# 2  e20241146                               Very good, excellent
# 3  e20240609                                      Will try hard
# 4  e20240542                            getting more experience
# 5  e20220287  Student could retrieve the lesson once they wa...
#
#       open_challenges_suggestions  student_segment  \
# 1                         Nothing                2
# 2  No big challenge, i’m the best                1
# 3         Lack of self-discipline                1
# 4    Discipline on daily studying                2
# 5               Add Ai assistance                2
#
#                    student_segment_label open_strengths_lang  \
# 1  Moderately Engaged (Passive) Learners                  en
# 2       Highly Engaged (Active) Learners                  en
# 3       Highly Engaged (Active) Learners                  en
# 4  Moderately Engaged (Passive) Learners                  en
# 5  Moderately Engaged (Passive) Learners                  en
#
#   open_challenges_suggestions_lang  \
# 1                               en
# 2                               en
# 3                               en
# 4                               en
# 5                               en
#
#                                    open_strengths_en  \
# 1                                            Nothing
# 2                               Very good, excellent
# 3                                      Will try hard
# 4                            getting more experience
# 5  Student could retrieve the lesson once they wa...
#
#    open_challenges_suggestions_en
# 1                         Nothing
# 2  No big challenge, i’m the best
# 3         Lack of self-discipline
# 4    Discipline on daily studying
# 5               Add Ai assistance
